# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='2'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 1.14.0

# %%
num_classes    = 9
batch_size     = 16
train_src_days = 3
train_trg_days = 3
epochs         = 500
learning_rate  = 0.0001

# Notes : 
# updated total_loss to reflect my issue on github 
# https://github.com/xudonmao/VMT/issues/1#issue-476306489
# VMT with first 3 days for train, next 3 days for train unlabeled and rest for test
# Increased Disc hidden dim to 1024 from 100
# added gaussian noise to gen

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation('relu')(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2)):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features):
    super().__init__(name='generator')
    bn_axis = -1

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.relu1 = tf.keras.layers.Activation('relu', name='relu1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a'))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b'))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation='relu',
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.relu1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self):
    super().__init__(name='discriminator')  
    self.dense1 = tf.keras.layers.Dense(1024, activation='relu')
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, inputs):
    x = self.dense1(inputs)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, 256)
discriminator  = Discriminator()
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

for epoch in range(epochs):
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 19:02:49.295243 139829801600768 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/autograph/impl/api.py:255: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.1673, CrossE: 2.2000, CondE: 2.1928, disc: 0.6934, domain: 0.6937, Src VAT: 2.1927, Trg VAT: 2.1928, Src MixUp: 2.1928, Trg MixUp: 2.1928, Src Train Acc: 10.94, Trg Train Acc: 11.72, Src Test Acc: 11.28, Trg Test Acc: 11.11
# Epoch: 002, TotalL: 7.1447, CrossE: 2.1846, CondE: 2.1891, disc: 0.6933, domain: 0.6949, Src VAT: 2.1893, Trg VAT: 2.1891, Src MixUp: 2.1898, Trg MixUp: 2.1899, Src Train Acc: 12.72, Trg Train Acc: 13.80, Src Test Acc: 16.34, Trg Test Acc: 16.17
# Epoch: 003, TotalL: 6.9197, CrossE: 2.1087, CondE: 2.1115, disc: 0.6963, domain: 0.7009, Src VAT: 2.1182, Trg VAT: 2.1115, Src MixUp: 2.1286, Trg MixUp: 2.1287, Src Train Acc: 17.10, Trg Train Acc: 18.06, Src Test Acc: 16.34, Trg Test Acc: 16.43
# Epoch: 004, TotalL: 6.5110, CrossE: 1.9634, CondE: 1.9746, disc: 0.6979, domain: 0.7030, Src VAT: 1.9864, Trg VAT: 1.9746, Src MixUp: 2.0262, Trg MixUp: 2.0344, Src Train Acc: 20.57, Trg Train Acc: 21.44, Src Test Acc: 26.46, Trg Test Acc: 24.94
# Epoch: 005, TotalL: 6.0836, CrossE: 1.8035, CondE: 1.8386, disc: 0.7039, domain: 0.7081, Src VAT: 1.8504, Trg VAT: 1.8386, Src MixUp: 1.9235, Trg MixUp: 1.9425, Src Train Acc: 27.60, Trg Train Acc: 25.91, Src Test Acc: 38.13, Trg Test Acc: 32.54
# Epoch: 006, TotalL: 5.4843, CrossE: 1.5841, CondE: 1.6524, disc: 0.7063, domain: 0.7285, Src VAT: 1.6633, Trg VAT: 1.6524, Src MixUp: 1.7710, Trg MixUp: 1.7922, Src Train Acc: 38.19, Trg Train Acc: 35.50, Src Test Acc: 46.30, Trg Test Acc: 35.35
# Epoch: 007, TotalL: 4.9418, CrossE: 1.3955, CondE: 1.4727, disc: 0.7048, domain: 0.7421, Src VAT: 1.4826, Trg VAT: 1.4727, Src MixUp: 1.6364, Trg MixUp: 1.6539, Src Train Acc: 44.97, Trg Train Acc: 41.80, Src Test Acc: 47.86, Trg Test Acc: 39.62
# Epoch: 008, TotalL: 4.6468, CrossE: 1.2921, CondE: 1.3728, disc: 0.6997, domain: 0.7469, Src VAT: 1.3859, Trg VAT: 1.3728, Src MixUp: 1.5633, Trg MixUp: 1.5764, Src Train Acc: 50.04, Trg Train Acc: 44.79, Src Test Acc: 51.36, Trg Test Acc: 40.73
# Epoch: 009, TotalL: 4.4260, CrossE: 1.2245, CondE: 1.2997, disc: 0.6984, domain: 0.7524, Src VAT: 1.3140, Trg VAT: 1.2997, Src MixUp: 1.4981, Trg MixUp: 1.5174, Src Train Acc: 53.30, Trg Train Acc: 48.26, Src Test Acc: 52.53, Trg Test Acc: 42.89
# Epoch: 010, TotalL: 4.2501, CrossE: 1.1770, CondE: 1.2426, disc: 0.6979, domain: 0.7560, Src VAT: 1.2562, Trg VAT: 1.2426, Src MixUp: 1.4394, Trg MixUp: 1.4777, Src Train Acc: 54.17, Trg Train Acc: 49.74, Src Test Acc: 56.03, Trg Test Acc: 45.73
# Epoch: 011, TotalL: 4.1053, CrossE: 1.1218, CondE: 1.1976, disc: 0.6976, domain: 0.7604, Src VAT: 1.2081, Trg VAT: 1.1976, Src MixUp: 1.4085, Trg MixUp: 1.4302, Src Train Acc: 56.77, Trg Train Acc: 52.21, Src Test Acc: 55.25, Trg Test Acc: 45.73
# Epoch: 012, TotalL: 3.9681, CrossE: 1.0804, CondE: 1.1519, disc: 0.6943, domain: 0.7636, Src VAT: 1.1633, Trg VAT: 1.1519, Src MixUp: 1.3673, Trg MixUp: 1.3963, Src Train Acc: 58.46, Trg Train Acc: 53.47, Src Test Acc: 58.37, Trg Test Acc: 48.30
# Epoch: 013, TotalL: 3.8095, CrossE: 1.0315, CondE: 1.1041, disc: 0.6930, domain: 0.7730, Src VAT: 1.1127, Trg VAT: 1.1041, Src MixUp: 1.3185, Trg MixUp: 1.3538, Src Train Acc: 60.63, Trg Train Acc: 56.12, Src Test Acc: 61.48, Trg Test Acc: 50.44
# Epoch: 014, TotalL: 3.7010, CrossE: 0.9935, CondE: 1.0652, disc: 0.6925, domain: 0.7758, Src VAT: 1.0750, Trg VAT: 1.0652, Src MixUp: 1.2932, Trg MixUp: 1.3343, Src Train Acc: 62.37, Trg Train Acc: 57.94, Src Test Acc: 62.26, Trg Test Acc: 50.67
# Epoch: 015, TotalL: 3.5680, CrossE: 0.9414, CondE: 1.0239, disc: 0.6873, domain: 0.7857, Src VAT: 1.0332, Trg VAT: 1.0239, Src MixUp: 1.2628, Trg MixUp: 1.2990, Src Train Acc: 64.28, Trg Train Acc: 59.46, Src Test Acc: 63.42, Trg Test Acc: 52.49
# Epoch: 016, TotalL: 3.4493, CrossE: 0.9018, CondE: 0.9924, disc: 0.6829, domain: 0.7940, Src VAT: 0.9961, Trg VAT: 0.9924, Src MixUp: 1.2277, Trg MixUp: 1.2669, Src Train Acc: 65.28, Trg Train Acc: 61.76, Src Test Acc: 65.37, Trg Test Acc: 51.70
# Epoch: 017, TotalL: 3.3796, CrossE: 0.8802, CondE: 0.9655, disc: 0.6812, domain: 0.8011, Src VAT: 0.9715, Trg VAT: 0.9655, Src MixUp: 1.2090, Trg MixUp: 1.2529, Src Train Acc: 66.75, Trg Train Acc: 63.06, Src Test Acc: 69.26, Trg Test Acc: 54.74
# Epoch: 018, TotalL: 3.2353, CrossE: 0.8238, CondE: 0.9250, disc: 0.6796, domain: 0.8106, Src VAT: 0.9270, Trg VAT: 0.9250, Src MixUp: 1.1729, Trg MixUp: 1.2342, Src Train Acc: 69.79, Trg Train Acc: 64.32, Src Test Acc: 71.98, Trg Test Acc: 55.88
# Epoch: 019, TotalL: 3.0940, CrossE: 0.7654, CondE: 0.8886, disc: 0.6761, domain: 0.8273, Src VAT: 0.8840, Trg VAT: 0.8886, Src MixUp: 1.1410, Trg MixUp: 1.1905, Src Train Acc: 72.70, Trg Train Acc: 67.14, Src Test Acc: 73.15, Trg Test Acc: 58.60
# Epoch: 020, TotalL: 2.9244, CrossE: 0.7133, CondE: 0.8348, disc: 0.6718, domain: 0.8414, Src VAT: 0.8292, Trg VAT: 0.8348, Src MixUp: 1.0881, Trg MixUp: 1.1602, Src Train Acc: 74.61, Trg Train Acc: 69.05, Src Test Acc: 74.71, Trg Test Acc: 60.79
# Epoch: 021, TotalL: 2.7975, CrossE: 0.6712, CondE: 0.7930, disc: 0.6663, domain: 0.8602, Src VAT: 0.7825, Trg VAT: 0.7930, Src MixUp: 1.0580, Trg MixUp: 1.1265, Src Train Acc: 76.48, Trg Train Acc: 70.75, Src Test Acc: 80.93, Trg Test Acc: 68.51
# Epoch: 022, TotalL: 2.7236, CrossE: 0.6341, CondE: 0.7747, disc: 0.6633, domain: 0.8682, Src VAT: 0.7567, Trg VAT: 0.7747, Src MixUp: 1.0513, Trg MixUp: 1.1007, Src Train Acc: 77.43, Trg Train Acc: 70.66, Src Test Acc: 80.93, Trg Test Acc: 66.14
# Epoch: 023, TotalL: 2.5950, CrossE: 0.5973, CondE: 0.7364, disc: 0.6589, domain: 0.8720, Src VAT: 0.7173, Trg VAT: 0.7364, Src MixUp: 1.0052, Trg MixUp: 1.0962, Src Train Acc: 79.56, Trg Train Acc: 73.13, Src Test Acc: 78.99, Trg Test Acc: 73.36
# Epoch: 024, TotalL: 2.4727, CrossE: 0.5530, CondE: 0.7026, disc: 0.6616, domain: 0.8832, Src VAT: 0.6776, Trg VAT: 0.7026, Src MixUp: 0.9724, Trg MixUp: 1.0823, Src Train Acc: 80.69, Trg Train Acc: 73.35, Src Test Acc: 80.93, Trg Test Acc: 70.41
# Epoch: 025, TotalL: 2.4402, CrossE: 0.5381, CondE: 0.6915, disc: 0.6604, domain: 0.8814, Src VAT: 0.6596, Trg VAT: 0.6915, Src MixUp: 0.9764, Trg MixUp: 1.0614, Src Train Acc: 82.29, Trg Train Acc: 74.13, Src Test Acc: 85.99, Trg Test Acc: 72.34
# Epoch: 026, TotalL: 2.3128, CrossE: 0.4917, CondE: 0.6484, disc: 0.6572, domain: 0.8901, Src VAT: 0.6198, Trg VAT: 0.6484, Src MixUp: 0.9447, Trg MixUp: 1.0209, Src Train Acc: 83.33, Trg Train Acc: 75.30, Src Test Acc: 77.82, Trg Test Acc: 68.04
# Epoch: 027, TotalL: 2.3026, CrossE: 0.4903, CondE: 0.6514, disc: 0.6568, domain: 0.8906, Src VAT: 0.6126, Trg VAT: 0.6514, Src MixUp: 0.9420, Trg MixUp: 1.0280, Src Train Acc: 83.33, Trg Train Acc: 74.39, Src Test Acc: 78.60, Trg Test Acc: 69.39
# Epoch: 028, TotalL: 2.2024, CrossE: 0.4604, CondE: 0.6193, disc: 0.6551, domain: 0.8952, Src VAT: 0.5812, Trg VAT: 0.6193, Src MixUp: 0.9083, Trg MixUp: 1.0230, Src Train Acc: 84.42, Trg Train Acc: 76.26, Src Test Acc: 81.71, Trg Test Acc: 68.01
# Epoch: 029, TotalL: 2.1176, CrossE: 0.4348, CondE: 0.5920, disc: 0.6589, domain: 0.8947, Src VAT: 0.5591, Trg VAT: 0.5920, Src MixUp: 0.8790, Trg MixUp: 0.9791, Src Train Acc: 85.37, Trg Train Acc: 76.30, Src Test Acc: 86.77, Trg Test Acc: 75.85
# Epoch: 030, TotalL: 2.0352, CrossE: 0.4061, CondE: 0.5775, disc: 0.6599, domain: 0.9027, Src VAT: 0.5269, Trg VAT: 0.5775, Src MixUp: 0.8598, Trg MixUp: 0.9721, Src Train Acc: 86.85, Trg Train Acc: 77.95, Src Test Acc: 85.99, Trg Test Acc: 77.28
# Epoch: 031, TotalL: 2.0493, CrossE: 0.4101, CondE: 0.5737, disc: 0.6603, domain: 0.8951, Src VAT: 0.5250, Trg VAT: 0.5737, Src MixUp: 0.8736, Trg MixUp: 0.9653, Src Train Acc: 85.98, Trg Train Acc: 76.82, Src Test Acc: 89.88, Trg Test Acc: 78.30
# Epoch: 032, TotalL: 1.9184, CrossE: 0.3679, CondE: 0.5419, disc: 0.6587, domain: 0.8997, Src VAT: 0.4898, Trg VAT: 0.5419, Src MixUp: 0.8278, Trg MixUp: 0.9260, Src Train Acc: 88.54, Trg Train Acc: 78.73, Src Test Acc: 86.38, Trg Test Acc: 75.38
# Epoch: 033, TotalL: 1.9307, CrossE: 0.3734, CondE: 0.5415, disc: 0.6652, domain: 0.8894, Src VAT: 0.4912, Trg VAT: 0.5415, Src MixUp: 0.8329, Trg MixUp: 0.9426, Src Train Acc: 87.67, Trg Train Acc: 78.95, Src Test Acc: 84.44, Trg Test Acc: 76.05
# Epoch: 034, TotalL: 1.8908, CrossE: 0.3512, CondE: 0.5328, disc: 0.6635, domain: 0.8834, Src VAT: 0.4754, Trg VAT: 0.5328, Src MixUp: 0.8342, Trg MixUp: 0.9275, Src Train Acc: 88.85, Trg Train Acc: 79.60, Src Test Acc: 91.44, Trg Test Acc: 79.44
# Epoch: 035, TotalL: 1.8068, CrossE: 0.3272, CondE: 0.5066, disc: 0.6593, domain: 0.8848, Src VAT: 0.4476, Trg VAT: 0.5066, Src MixUp: 0.8069, Trg MixUp: 0.9151, Src Train Acc: 89.24, Trg Train Acc: 80.34, Src Test Acc: 91.83, Trg Test Acc: 80.09
# Epoch: 036, TotalL: 1.7770, CrossE: 0.3275, CondE: 0.4908, disc: 0.6636, domain: 0.8789, Src VAT: 0.4435, Trg VAT: 0.4908, Src MixUp: 0.7855, Trg MixUp: 0.8963, Src Train Acc: 88.93, Trg Train Acc: 80.03, Src Test Acc: 86.38, Trg Test Acc: 77.31
# Epoch: 037, TotalL: 1.7502, CrossE: 0.3205, CondE: 0.4832, disc: 0.6624, domain: 0.8723, Src VAT: 0.4338, Trg VAT: 0.4832, Src MixUp: 0.7777, Trg MixUp: 0.8889, Src Train Acc: 89.50, Trg Train Acc: 79.95, Src Test Acc: 87.16, Trg Test Acc: 77.75
# Epoch: 038, TotalL: 1.6936, CrossE: 0.2995, CondE: 0.4701, disc: 0.6631, domain: 0.8764, Src VAT: 0.4127, Trg VAT: 0.4701, Src MixUp: 0.7649, Trg MixUp: 0.8902, Src Train Acc: 90.41, Trg Train Acc: 80.73, Src Test Acc: 92.61, Trg Test Acc: 79.88
# Epoch: 039, TotalL: 1.6653, CrossE: 0.2882, CondE: 0.4580, disc: 0.6688, domain: 0.8753, Src VAT: 0.4038, Trg VAT: 0.4580, Src MixUp: 0.7605, Trg MixUp: 0.8673, Src Train Acc: 90.67, Trg Train Acc: 82.16, Src Test Acc: 88.72, Trg Test Acc: 77.95
# Epoch: 040, TotalL: 1.6644, CrossE: 0.2933, CondE: 0.4559, disc: 0.6596, domain: 0.8805, Src VAT: 0.4014, Trg VAT: 0.4559, Src MixUp: 0.7563, Trg MixUp: 0.8759, Src Train Acc: 90.28, Trg Train Acc: 82.07, Src Test Acc: 89.49, Trg Test Acc: 78.89
# Epoch: 041, TotalL: 1.6205, CrossE: 0.2690, CondE: 0.4467, disc: 0.6639, domain: 0.8872, Src VAT: 0.3815, Trg VAT: 0.4467, Src MixUp: 0.7588, Trg MixUp: 0.8588, Src Train Acc: 91.62, Trg Train Acc: 82.16, Src Test Acc: 93.77, Trg Test Acc: 83.36
# Epoch: 042, TotalL: 1.5733, CrossE: 0.2642, CondE: 0.4383, disc: 0.6595, domain: 0.8799, Src VAT: 0.3715, Trg VAT: 0.4383, Src MixUp: 0.7286, Trg MixUp: 0.8558, Src Train Acc: 91.58, Trg Train Acc: 82.90, Src Test Acc: 93.00, Trg Test Acc: 82.13
# Epoch: 043, TotalL: 1.5094, CrossE: 0.2451, CondE: 0.4132, disc: 0.6627, domain: 0.8796, Src VAT: 0.3529, Trg VAT: 0.4132, Src MixUp: 0.7088, Trg MixUp: 0.8259, Src Train Acc: 92.32, Trg Train Acc: 83.25, Src Test Acc: 90.66, Trg Test Acc: 79.62
# Epoch: 044, TotalL: 1.5223, CrossE: 0.2519, CondE: 0.4156, disc: 0.6648, domain: 0.8631, Src VAT: 0.3588, Trg VAT: 0.4156, Src MixUp: 0.7088, Trg MixUp: 0.8395, Src Train Acc: 91.93, Trg Train Acc: 82.68, Src Test Acc: 91.44, Trg Test Acc: 82.95
# Epoch: 045, TotalL: 1.4928, CrossE: 0.2511, CondE: 0.4154, disc: 0.6629, domain: 0.8713, Src VAT: 0.3490, Trg VAT: 0.4154, Src MixUp: 0.6900, Trg MixUp: 0.8332, Src Train Acc: 91.71, Trg Train Acc: 82.90, Src Test Acc: 91.83, Trg Test Acc: 81.96
# Epoch: 046, TotalL: 1.4695, CrossE: 0.2317, CondE: 0.3992, disc: 0.6614, domain: 0.8708, Src VAT: 0.3389, Trg VAT: 0.3992, Src MixUp: 0.6995, Trg MixUp: 0.8230, Src Train Acc: 92.49, Trg Train Acc: 84.03, Src Test Acc: 92.61, Trg Test Acc: 84.18
# Epoch: 047, TotalL: 1.3929, CrossE: 0.2164, CondE: 0.3845, disc: 0.6593, domain: 0.8660, Src VAT: 0.3152, Trg VAT: 0.3845, Src MixUp: 0.6657, Trg MixUp: 0.8103, Src Train Acc: 93.10, Trg Train Acc: 83.94, Src Test Acc: 92.22, Trg Test Acc: 84.21
# Epoch: 048, TotalL: 1.3937, CrossE: 0.2064, CondE: 0.3795, disc: 0.6609, domain: 0.8731, Src VAT: 0.3097, Trg VAT: 0.3795, Src MixUp: 0.6815, Trg MixUp: 0.8179, Src Train Acc: 93.58, Trg Train Acc: 83.98, Src Test Acc: 90.27, Trg Test Acc: 83.89
# Epoch: 049, TotalL: 1.4547, CrossE: 0.2359, CondE: 0.3847, disc: 0.6623, domain: 0.8704, Src VAT: 0.3304, Trg VAT: 0.3847, Src MixUp: 0.6936, Trg MixUp: 0.7948, Src Train Acc: 92.23, Trg Train Acc: 83.68, Src Test Acc: 93.00, Trg Test Acc: 83.16
# Epoch: 050, TotalL: 1.4060, CrossE: 0.2088, CondE: 0.3846, disc: 0.6645, domain: 0.8776, Src VAT: 0.3136, Trg VAT: 0.3846, Src MixUp: 0.6868, Trg MixUp: 0.8127, Src Train Acc: 93.45, Trg Train Acc: 84.68, Src Test Acc: 88.72, Trg Test Acc: 83.83
# Epoch: 051, TotalL: 1.3435, CrossE: 0.2031, CondE: 0.3657, disc: 0.6561, domain: 0.8794, Src VAT: 0.2988, Trg VAT: 0.3657, Src MixUp: 0.6500, Trg MixUp: 0.7834, Src Train Acc: 93.10, Trg Train Acc: 84.98, Src Test Acc: 94.94, Trg Test Acc: 85.06
# Epoch: 052, TotalL: 1.3143, CrossE: 0.1906, CondE: 0.3612, disc: 0.6515, domain: 0.8877, Src VAT: 0.2914, Trg VAT: 0.3612, Src MixUp: 0.6400, Trg MixUp: 0.7929, Src Train Acc: 94.36, Trg Train Acc: 85.46, Src Test Acc: 93.00, Trg Test Acc: 81.81
# Epoch: 053, TotalL: 1.3180, CrossE: 0.1957, CondE: 0.3518, disc: 0.6522, domain: 0.8888, Src VAT: 0.2915, Trg VAT: 0.3518, Src MixUp: 0.6434, Trg MixUp: 0.7513, Src Train Acc: 93.58, Trg Train Acc: 85.33, Src Test Acc: 94.94, Trg Test Acc: 86.17
# Epoch: 054, TotalL: 1.3315, CrossE: 0.1902, CondE: 0.3558, disc: 0.6522, domain: 0.8914, Src VAT: 0.2849, Trg VAT: 0.3558, Src MixUp: 0.6663, Trg MixUp: 0.7736, Src Train Acc: 93.88, Trg Train Acc: 84.46, Src Test Acc: 93.77, Trg Test Acc: 87.05
# Epoch: 055, TotalL: 1.3381, CrossE: 0.1945, CondE: 0.3577, disc: 0.6473, domain: 0.8801, Src VAT: 0.2930, Trg VAT: 0.3577, Src MixUp: 0.6599, Trg MixUp: 0.7876, Src Train Acc: 93.92, Trg Train Acc: 85.11, Src Test Acc: 93.00, Trg Test Acc: 84.68
# Epoch: 056, TotalL: 1.2341, CrossE: 0.1617, CondE: 0.3383, disc: 0.6480, domain: 0.8959, Src VAT: 0.2638, Trg VAT: 0.3383, Src MixUp: 0.6223, Trg MixUp: 0.7560, Src Train Acc: 95.05, Trg Train Acc: 85.98, Src Test Acc: 93.39, Trg Test Acc: 85.56
# Epoch: 057, TotalL: 1.2927, CrossE: 0.1861, CondE: 0.3479, disc: 0.6576, domain: 0.8914, Src VAT: 0.2799, Trg VAT: 0.3479, Src MixUp: 0.6379, Trg MixUp: 0.7735, Src Train Acc: 94.36, Trg Train Acc: 84.46, Src Test Acc: 97.28, Trg Test Acc: 82.75
# Epoch: 058, TotalL: 1.2264, CrossE: 0.1551, CondE: 0.3258, disc: 0.6486, domain: 0.8880, Src VAT: 0.2544, Trg VAT: 0.3258, Src MixUp: 0.6336, Trg MixUp: 0.7532, Src Train Acc: 95.36, Trg Train Acc: 86.81, Src Test Acc: 91.83, Trg Test Acc: 86.40
# Epoch: 059, TotalL: 1.1969, CrossE: 0.1610, CondE: 0.3175, disc: 0.6557, domain: 0.8901, Src VAT: 0.2494, Trg VAT: 0.3175, Src MixUp: 0.6040, Trg MixUp: 0.7559, Src Train Acc: 95.18, Trg Train Acc: 86.46, Src Test Acc: 96.11, Trg Test Acc: 86.64
# Epoch: 060, TotalL: 1.2427, CrossE: 0.1661, CondE: 0.3306, disc: 0.6555, domain: 0.8811, Src VAT: 0.2654, Trg VAT: 0.3306, Src MixUp: 0.6280, Trg MixUp: 0.7487, Src Train Acc: 95.14, Trg Train Acc: 85.85, Src Test Acc: 96.11, Trg Test Acc: 86.37
# Epoch: 061, TotalL: 1.2048, CrossE: 0.1499, CondE: 0.3236, disc: 0.6553, domain: 0.8852, Src VAT: 0.2486, Trg VAT: 0.3236, Src MixUp: 0.6233, Trg MixUp: 0.7546, Src Train Acc: 95.01, Trg Train Acc: 86.37, Src Test Acc: 91.05, Trg Test Acc: 83.77
# Epoch: 062, TotalL: 1.1453, CrossE: 0.1412, CondE: 0.3058, disc: 0.6523, domain: 0.8794, Src VAT: 0.2320, Trg VAT: 0.3058, Src MixUp: 0.5963, Trg MixUp: 0.7067, Src Train Acc: 96.14, Trg Train Acc: 87.67, Src Test Acc: 92.61, Trg Test Acc: 86.17
# Epoch: 063, TotalL: 1.1533, CrossE: 0.1474, CondE: 0.2971, disc: 0.6566, domain: 0.8690, Src VAT: 0.2344, Trg VAT: 0.2971, Src MixUp: 0.5948, Trg MixUp: 0.7459, Src Train Acc: 95.62, Trg Train Acc: 87.72, Src Test Acc: 93.77, Trg Test Acc: 83.30
# Epoch: 064, TotalL: 1.1424, CrossE: 0.1460, CondE: 0.3030, disc: 0.6623, domain: 0.8790, Src VAT: 0.2344, Trg VAT: 0.3030, Src MixUp: 0.5836, Trg MixUp: 0.7452, Src Train Acc: 95.23, Trg Train Acc: 86.68, Src Test Acc: 85.60, Trg Test Acc: 74.39
# Epoch: 065, TotalL: 1.1534, CrossE: 0.1585, CondE: 0.3082, disc: 0.6596, domain: 0.8753, Src VAT: 0.2390, Trg VAT: 0.3082, Src MixUp: 0.5783, Trg MixUp: 0.7280, Src Train Acc: 95.36, Trg Train Acc: 86.02, Src Test Acc: 93.39, Trg Test Acc: 87.51
# Epoch: 066, TotalL: 1.1503, CrossE: 0.1391, CondE: 0.2989, disc: 0.6609, domain: 0.8633, Src VAT: 0.2294, Trg VAT: 0.2989, Src MixUp: 0.6068, Trg MixUp: 0.7264, Src Train Acc: 95.49, Trg Train Acc: 87.28, Src Test Acc: 91.05, Trg Test Acc: 83.48
# Epoch: 067, TotalL: 1.0952, CrossE: 0.1308, CondE: 0.2904, disc: 0.6574, domain: 0.8711, Src VAT: 0.2182, Trg VAT: 0.2904, Src MixUp: 0.5722, Trg MixUp: 0.7227, Src Train Acc: 95.83, Trg Train Acc: 88.50, Src Test Acc: 94.55, Trg Test Acc: 86.78
# Epoch: 068, TotalL: 1.0761, CrossE: 0.1289, CondE: 0.2911, disc: 0.6571, domain: 0.8814, Src VAT: 0.2126, Trg VAT: 0.2911, Src MixUp: 0.5607, Trg MixUp: 0.7097, Src Train Acc: 95.88, Trg Train Acc: 87.20, Src Test Acc: 87.16, Trg Test Acc: 73.98
# Epoch: 069, TotalL: 1.0947, CrossE: 0.1362, CondE: 0.2906, disc: 0.6579, domain: 0.8787, Src VAT: 0.2200, Trg VAT: 0.2906, Src MixUp: 0.5646, Trg MixUp: 0.7138, Src Train Acc: 95.83, Trg Train Acc: 87.20, Src Test Acc: 93.39, Trg Test Acc: 84.56
# Epoch: 070, TotalL: 1.1075, CrossE: 0.1238, CondE: 0.2870, disc: 0.6611, domain: 0.8723, Src VAT: 0.2174, Trg VAT: 0.2870, Src MixUp: 0.5932, Trg MixUp: 0.7181, Src Train Acc: 96.48, Trg Train Acc: 87.72, Src Test Acc: 94.94, Trg Test Acc: 86.14
# Epoch: 071, TotalL: 1.0629, CrossE: 0.1279, CondE: 0.2815, disc: 0.6571, domain: 0.8683, Src VAT: 0.2105, Trg VAT: 0.2815, Src MixUp: 0.5538, Trg MixUp: 0.7041, Src Train Acc: 96.70, Trg Train Acc: 87.28, Src Test Acc: 96.89, Trg Test Acc: 88.74
# Epoch: 072, TotalL: 1.0231, CrossE: 0.1117, CondE: 0.2587, disc: 0.6640, domain: 0.8672, Src VAT: 0.1926, Trg VAT: 0.2587, Src MixUp: 0.5533, Trg MixUp: 0.6846, Src Train Acc: 96.83, Trg Train Acc: 88.41, Src Test Acc: 86.38, Trg Test Acc: 76.23
# Epoch: 073, TotalL: 1.0435, CrossE: 0.1140, CondE: 0.2677, disc: 0.6586, domain: 0.8707, Src VAT: 0.1994, Trg VAT: 0.2677, Src MixUp: 0.5617, Trg MixUp: 0.6988, Src Train Acc: 96.96, Trg Train Acc: 87.98, Src Test Acc: 96.11, Trg Test Acc: 87.05
# Epoch: 074, TotalL: 1.0645, CrossE: 0.1220, CondE: 0.2780, disc: 0.6560, domain: 0.8725, Src VAT: 0.2021, Trg VAT: 0.2780, Src MixUp: 0.5697, Trg MixUp: 0.7055, Src Train Acc: 96.40, Trg Train Acc: 87.67, Src Test Acc: 96.11, Trg Test Acc: 87.22
# Epoch: 075, TotalL: 0.9992, CrossE: 0.0986, CondE: 0.2639, disc: 0.6561, domain: 0.8676, Src VAT: 0.1828, Trg VAT: 0.2639, Src MixUp: 0.5506, Trg MixUp: 0.6950, Src Train Acc: 97.57, Trg Train Acc: 89.32, Src Test Acc: 96.11, Trg Test Acc: 89.39
# Epoch: 076, TotalL: 1.0139, CrossE: 0.1125, CondE: 0.2639, disc: 0.6631, domain: 0.8695, Src VAT: 0.1903, Trg VAT: 0.2639, Src MixUp: 0.5436, Trg MixUp: 0.6964, Src Train Acc: 96.79, Trg Train Acc: 87.89, Src Test Acc: 96.11, Trg Test Acc: 88.42
# Epoch: 077, TotalL: 1.0338, CrossE: 0.1162, CondE: 0.2625, disc: 0.6645, domain: 0.8636, Src VAT: 0.1943, Trg VAT: 0.2625, Src MixUp: 0.5579, Trg MixUp: 0.6790, Src Train Acc: 96.40, Trg Train Acc: 89.02, Src Test Acc: 96.89, Trg Test Acc: 90.06
# Epoch: 078, TotalL: 0.9645, CrossE: 0.0996, CondE: 0.2494, disc: 0.6564, domain: 0.8629, Src VAT: 0.1766, Trg VAT: 0.2494, Src MixUp: 0.5244, Trg MixUp: 0.6863, Src Train Acc: 97.05, Trg Train Acc: 89.11, Src Test Acc: 89.88, Trg Test Acc: 85.82
# Epoch: 079, TotalL: 1.0335, CrossE: 0.1099, CondE: 0.2614, disc: 0.6641, domain: 0.8682, Src VAT: 0.1946, Trg VAT: 0.2614, Src MixUp: 0.5623, Trg MixUp: 0.6932, Src Train Acc: 96.88, Trg Train Acc: 88.89, Src Test Acc: 94.55, Trg Test Acc: 89.06
# Epoch: 080, TotalL: 0.9806, CrossE: 0.0950, CondE: 0.2524, disc: 0.6540, domain: 0.8650, Src VAT: 0.1763, Trg VAT: 0.2524, Src MixUp: 0.5443, Trg MixUp: 0.6919, Src Train Acc: 97.53, Trg Train Acc: 89.67, Src Test Acc: 91.05, Trg Test Acc: 78.27
# Epoch: 081, TotalL: 0.9913, CrossE: 0.0941, CondE: 0.2546, disc: 0.6504, domain: 0.8682, Src VAT: 0.1777, Trg VAT: 0.2546, Src MixUp: 0.5549, Trg MixUp: 0.6790, Src Train Acc: 97.40, Trg Train Acc: 89.67, Src Test Acc: 96.11, Trg Test Acc: 86.32
# Epoch: 082, TotalL: 1.0066, CrossE: 0.1090, CondE: 0.2552, disc: 0.6613, domain: 0.8734, Src VAT: 0.1859, Trg VAT: 0.2552, Src MixUp: 0.5466, Trg MixUp: 0.6787, Src Train Acc: 96.83, Trg Train Acc: 89.93, Src Test Acc: 96.11, Trg Test Acc: 89.04
# Epoch: 083, TotalL: 0.9303, CrossE: 0.0884, CondE: 0.2380, disc: 0.6495, domain: 0.8753, Src VAT: 0.1641, Trg VAT: 0.2380, Src MixUp: 0.5156, Trg MixUp: 0.6763, Src Train Acc: 97.66, Trg Train Acc: 89.80, Src Test Acc: 97.28, Trg Test Acc: 87.34
# Epoch: 084, TotalL: 0.9253, CrossE: 0.0813, CondE: 0.2371, disc: 0.6525, domain: 0.8703, Src VAT: 0.1565, Trg VAT: 0.2371, Src MixUp: 0.5253, Trg MixUp: 0.6827, Src Train Acc: 97.96, Trg Train Acc: 89.19, Src Test Acc: 95.33, Trg Test Acc: 89.09
# Epoch: 085, TotalL: 0.9345, CrossE: 0.0925, CondE: 0.2431, disc: 0.6580, domain: 0.8653, Src VAT: 0.1660, Trg VAT: 0.2431, Src MixUp: 0.5141, Trg MixUp: 0.6716, Src Train Acc: 97.53, Trg Train Acc: 88.85, Src Test Acc: 96.89, Trg Test Acc: 90.70
# Epoch: 086, TotalL: 0.9244, CrossE: 0.0855, CondE: 0.2328, disc: 0.6580, domain: 0.8580, Src VAT: 0.1570, Trg VAT: 0.2328, Src MixUp: 0.5240, Trg MixUp: 0.6506, Src Train Acc: 97.66, Trg Train Acc: 90.36, Src Test Acc: 96.89, Trg Test Acc: 87.95
# Epoch: 087, TotalL: 0.9278, CrossE: 0.0953, CondE: 0.2364, disc: 0.6616, domain: 0.8618, Src VAT: 0.1591, Trg VAT: 0.2364, Src MixUp: 0.5150, Trg MixUp: 0.6458, Src Train Acc: 97.53, Trg Train Acc: 89.71, Src Test Acc: 94.16, Trg Test Acc: 86.55
# Epoch: 088, TotalL: 0.9472, CrossE: 0.0946, CondE: 0.2435, disc: 0.6618, domain: 0.8578, Src VAT: 0.1637, Trg VAT: 0.2435, Src MixUp: 0.5278, Trg MixUp: 0.6684, Src Train Acc: 97.05, Trg Train Acc: 89.02, Src Test Acc: 96.11, Trg Test Acc: 90.32
# Epoch: 089, TotalL: 0.9258, CrossE: 0.0845, CondE: 0.2312, disc: 0.6596, domain: 0.8561, Src VAT: 0.1558, Trg VAT: 0.2312, Src MixUp: 0.5273, Trg MixUp: 0.6577, Src Train Acc: 97.57, Trg Train Acc: 91.41, Src Test Acc: 97.67, Trg Test Acc: 90.09
# Epoch: 090, TotalL: 0.9283, CrossE: 0.0832, CondE: 0.2364, disc: 0.6547, domain: 0.8606, Src VAT: 0.1605, Trg VAT: 0.2364, Src MixUp: 0.5237, Trg MixUp: 0.6780, Src Train Acc: 97.96, Trg Train Acc: 90.36, Src Test Acc: 98.83, Trg Test Acc: 89.88
# Epoch: 091, TotalL: 0.9053, CrossE: 0.0770, CondE: 0.2301, disc: 0.6552, domain: 0.8546, Src VAT: 0.1471, Trg VAT: 0.2301, Src MixUp: 0.5223, Trg MixUp: 0.6719, Src Train Acc: 97.96, Trg Train Acc: 89.06, Src Test Acc: 96.89, Trg Test Acc: 89.36
# Epoch: 092, TotalL: 0.9007, CrossE: 0.0836, CondE: 0.2279, disc: 0.6513, domain: 0.8612, Src VAT: 0.1479, Trg VAT: 0.2279, Src MixUp: 0.5132, Trg MixUp: 0.6344, Src Train Acc: 97.79, Trg Train Acc: 90.76, Src Test Acc: 93.39, Trg Test Acc: 88.68
# Epoch: 093, TotalL: 0.8858, CrossE: 0.0726, CondE: 0.2225, disc: 0.6510, domain: 0.8628, Src VAT: 0.1437, Trg VAT: 0.2225, Src MixUp: 0.5132, Trg MixUp: 0.6457, Src Train Acc: 98.18, Trg Train Acc: 90.71, Src Test Acc: 97.67, Trg Test Acc: 90.96
# Epoch: 094, TotalL: 0.8455, CrossE: 0.0672, CondE: 0.2057, disc: 0.6541, domain: 0.8663, Src VAT: 0.1355, Trg VAT: 0.2057, Src MixUp: 0.4893, Trg MixUp: 0.6396, Src Train Acc: 98.35, Trg Train Acc: 91.45, Src Test Acc: 94.16, Trg Test Acc: 82.63
# Epoch: 095, TotalL: 0.9278, CrossE: 0.0770, CondE: 0.2193, disc: 0.6509, domain: 0.8600, Src VAT: 0.1500, Trg VAT: 0.2193, Src MixUp: 0.5452, Trg MixUp: 0.6454, Src Train Acc: 98.00, Trg Train Acc: 91.19, Src Test Acc: 94.55, Trg Test Acc: 87.60
# Epoch: 096, TotalL: 0.9180, CrossE: 0.0777, CondE: 0.2260, disc: 0.6527, domain: 0.8559, Src VAT: 0.1524, Trg VAT: 0.2260, Src MixUp: 0.5292, Trg MixUp: 0.6764, Src Train Acc: 97.83, Trg Train Acc: 89.97, Src Test Acc: 97.28, Trg Test Acc: 87.87
# Epoch: 097, TotalL: 0.8986, CrossE: 0.0811, CondE: 0.2172, disc: 0.6567, domain: 0.8626, Src VAT: 0.1498, Trg VAT: 0.2172, Src MixUp: 0.5131, Trg MixUp: 0.6357, Src Train Acc: 97.66, Trg Train Acc: 89.93, Src Test Acc: 96.89, Trg Test Acc: 92.11
# Epoch: 098, TotalL: 0.8399, CrossE: 0.0651, CondE: 0.2031, disc: 0.6507, domain: 0.8716, Src VAT: 0.1309, Trg VAT: 0.2031, Src MixUp: 0.4911, Trg MixUp: 0.6321, Src Train Acc: 98.44, Trg Train Acc: 91.75, Src Test Acc: 95.33, Trg Test Acc: 89.33
# Epoch: 099, TotalL: 0.8546, CrossE: 0.0758, CondE: 0.2067, disc: 0.6595, domain: 0.8720, Src VAT: 0.1363, Trg VAT: 0.2067, Src MixUp: 0.4889, Trg MixUp: 0.6350, Src Train Acc: 98.35, Trg Train Acc: 90.84, Src Test Acc: 96.89, Trg Test Acc: 91.49
# Epoch: 100, TotalL: 0.8592, CrossE: 0.0735, CondE: 0.2136, disc: 0.6657, domain: 0.8523, Src VAT: 0.1373, Trg VAT: 0.2136, Src MixUp: 0.4950, Trg MixUp: 0.6393, Src Train Acc: 97.92, Trg Train Acc: 90.06, Src Test Acc: 84.44, Trg Test Acc: 73.10
# Epoch: 101, TotalL: 0.8538, CrossE: 0.0693, CondE: 0.2068, disc: 0.6520, domain: 0.8537, Src VAT: 0.1323, Trg VAT: 0.2068, Src MixUp: 0.5029, Trg MixUp: 0.5994, Src Train Acc: 98.13, Trg Train Acc: 90.58, Src Test Acc: 97.28, Trg Test Acc: 90.41
# Epoch: 102, TotalL: 0.8330, CrossE: 0.0591, CondE: 0.2031, disc: 0.6492, domain: 0.8685, Src VAT: 0.1260, Trg VAT: 0.2031, Src MixUp: 0.4938, Trg MixUp: 0.6511, Src Train Acc: 98.65, Trg Train Acc: 90.41, Src Test Acc: 93.77, Trg Test Acc: 88.10
# Epoch: 103, TotalL: 0.8533, CrossE: 0.0692, CondE: 0.2159, disc: 0.6480, domain: 0.8651, Src VAT: 0.1341, Trg VAT: 0.2159, Src MixUp: 0.4964, Trg MixUp: 0.6239, Src Train Acc: 98.13, Trg Train Acc: 89.97, Src Test Acc: 94.94, Trg Test Acc: 85.96
# Epoch: 104, TotalL: 0.8337, CrossE: 0.0638, CondE: 0.1957, disc: 0.6553, domain: 0.8638, Src VAT: 0.1284, Trg VAT: 0.1957, Src MixUp: 0.4919, Trg MixUp: 0.6151, Src Train Acc: 98.26, Trg Train Acc: 91.41, Src Test Acc: 94.55, Trg Test Acc: 84.44
# Epoch: 105, TotalL: 0.8504, CrossE: 0.0706, CondE: 0.2035, disc: 0.6556, domain: 0.8613, Src VAT: 0.1345, Trg VAT: 0.2035, Src MixUp: 0.4920, Trg MixUp: 0.6478, Src Train Acc: 97.92, Trg Train Acc: 90.76, Src Test Acc: 96.50, Trg Test Acc: 91.40
# Epoch: 106, TotalL: 0.8115, CrossE: 0.0525, CondE: 0.2087, disc: 0.6492, domain: 0.8636, Src VAT: 0.1229, Trg VAT: 0.2087, Src MixUp: 0.4813, Trg MixUp: 0.6538, Src Train Acc: 98.65, Trg Train Acc: 91.75, Src Test Acc: 98.83, Trg Test Acc: 91.75
# Epoch: 107, TotalL: 0.8173, CrossE: 0.0719, CondE: 0.2060, disc: 0.6589, domain: 0.8629, Src VAT: 0.1296, Trg VAT: 0.2060, Src MixUp: 0.4636, Trg MixUp: 0.6274, Src Train Acc: 98.18, Trg Train Acc: 90.89, Src Test Acc: 94.94, Trg Test Acc: 83.86
# Epoch: 108, TotalL: 0.8547, CrossE: 0.0598, CondE: 0.2058, disc: 0.6459, domain: 0.8701, Src VAT: 0.1276, Trg VAT: 0.2058, Src MixUp: 0.5145, Trg MixUp: 0.6267, Src Train Acc: 98.61, Trg Train Acc: 91.32, Src Test Acc: 95.72, Trg Test Acc: 91.70
# Epoch: 109, TotalL: 0.8826, CrossE: 0.0779, CondE: 0.2090, disc: 0.6509, domain: 0.8589, Src VAT: 0.1387, Trg VAT: 0.2090, Src MixUp: 0.5115, Trg MixUp: 0.6544, Src Train Acc: 97.57, Trg Train Acc: 90.84, Src Test Acc: 98.05, Trg Test Acc: 91.58
# Epoch: 110, TotalL: 0.8320, CrossE: 0.0545, CondE: 0.2085, disc: 0.6461, domain: 0.8612, Src VAT: 0.1214, Trg VAT: 0.2085, Src MixUp: 0.5020, Trg MixUp: 0.6481, Src Train Acc: 98.78, Trg Train Acc: 90.97, Src Test Acc: 98.05, Trg Test Acc: 88.92
# Epoch: 111, TotalL: 0.8637, CrossE: 0.0753, CondE: 0.2042, disc: 0.6508, domain: 0.8675, Src VAT: 0.1315, Trg VAT: 0.2042, Src MixUp: 0.5043, Trg MixUp: 0.6318, Src Train Acc: 97.70, Trg Train Acc: 90.97, Src Test Acc: 95.33, Trg Test Acc: 90.23
# Epoch: 112, TotalL: 0.7810, CrossE: 0.0448, CondE: 0.1865, disc: 0.6534, domain: 0.8647, Src VAT: 0.1094, Trg VAT: 0.1865, Src MixUp: 0.4775, Trg MixUp: 0.6279, Src Train Acc: 99.13, Trg Train Acc: 91.97, Src Test Acc: 98.05, Trg Test Acc: 86.40
# Epoch: 113, TotalL: 0.8309, CrossE: 0.0645, CondE: 0.2019, disc: 0.6472, domain: 0.8651, Src VAT: 0.1228, Trg VAT: 0.2019, Src MixUp: 0.4929, Trg MixUp: 0.6152, Src Train Acc: 98.22, Trg Train Acc: 91.36, Src Test Acc: 98.05, Trg Test Acc: 90.50
# Epoch: 114, TotalL: 0.7824, CrossE: 0.0502, CondE: 0.1806, disc: 0.6491, domain: 0.8647, Src VAT: 0.1075, Trg VAT: 0.1806, Src MixUp: 0.4779, Trg MixUp: 0.6105, Src Train Acc: 98.65, Trg Train Acc: 91.84, Src Test Acc: 94.55, Trg Test Acc: 87.22
# Epoch: 115, TotalL: 0.7783, CrossE: 0.0503, CondE: 0.1859, disc: 0.6497, domain: 0.8544, Src VAT: 0.1128, Trg VAT: 0.1859, Src MixUp: 0.4671, Trg MixUp: 0.6247, Src Train Acc: 98.96, Trg Train Acc: 92.10, Src Test Acc: 96.11, Trg Test Acc: 92.69
# Epoch: 116, TotalL: 0.7778, CrossE: 0.0444, CondE: 0.1890, disc: 0.6506, domain: 0.8543, Src VAT: 0.1111, Trg VAT: 0.1890, Src MixUp: 0.4764, Trg MixUp: 0.5923, Src Train Acc: 99.05, Trg Train Acc: 92.06, Src Test Acc: 96.89, Trg Test Acc: 90.67
# Epoch: 117, TotalL: 0.7564, CrossE: 0.0499, CondE: 0.1838, disc: 0.6555, domain: 0.8535, Src VAT: 0.1027, Trg VAT: 0.1838, Src MixUp: 0.4570, Trg MixUp: 0.6139, Src Train Acc: 98.65, Trg Train Acc: 91.93, Src Test Acc: 99.22, Trg Test Acc: 90.73
# Epoch: 118, TotalL: 0.7738, CrossE: 0.0467, CondE: 0.1779, disc: 0.6497, domain: 0.8567, Src VAT: 0.1084, Trg VAT: 0.1779, Src MixUp: 0.4746, Trg MixUp: 0.5896, Src Train Acc: 98.96, Trg Train Acc: 92.10, Src Test Acc: 97.67, Trg Test Acc: 91.08
# Epoch: 119, TotalL: 0.8438, CrossE: 0.0918, CondE: 0.2046, disc: 0.6545, domain: 0.8433, Src VAT: 0.1249, Trg VAT: 0.2046, Src MixUp: 0.4771, Trg MixUp: 0.6226, Src Train Acc: 97.57, Trg Train Acc: 90.58, Src Test Acc: 97.28, Trg Test Acc: 88.25
# Epoch: 120, TotalL: 0.8366, CrossE: 0.0790, CondE: 0.1939, disc: 0.6534, domain: 0.8488, Src VAT: 0.1270, Trg VAT: 0.1939, Src MixUp: 0.4838, Trg MixUp: 0.5975, Src Train Acc: 97.87, Trg Train Acc: 92.19, Src Test Acc: 96.89, Trg Test Acc: 89.59
# Epoch: 121, TotalL: 0.7594, CrossE: 0.0413, CondE: 0.1862, disc: 0.6461, domain: 0.8568, Src VAT: 0.1045, Trg VAT: 0.1862, Src MixUp: 0.4676, Trg MixUp: 0.5956, Src Train Acc: 99.13, Trg Train Acc: 92.32, Src Test Acc: 96.11, Trg Test Acc: 90.41
# Epoch: 122, TotalL: 0.7898, CrossE: 0.0561, CondE: 0.1946, disc: 0.6510, domain: 0.8543, Src VAT: 0.1143, Trg VAT: 0.1946, Src MixUp: 0.4713, Trg MixUp: 0.6077, Src Train Acc: 98.70, Trg Train Acc: 91.62, Src Test Acc: 98.83, Trg Test Acc: 93.51
# Epoch: 123, TotalL: 0.7898, CrossE: 0.0556, CondE: 0.1862, disc: 0.6530, domain: 0.8517, Src VAT: 0.1133, Trg VAT: 0.1862, Src MixUp: 0.4750, Trg MixUp: 0.6004, Src Train Acc: 98.70, Trg Train Acc: 92.27, Src Test Acc: 96.50, Trg Test Acc: 91.78
# Epoch: 124, TotalL: 0.7355, CrossE: 0.0449, CondE: 0.1720, disc: 0.6440, domain: 0.8675, Src VAT: 0.0999, Trg VAT: 0.1720, Src MixUp: 0.4465, Trg MixUp: 0.5918, Src Train Acc: 99.00, Trg Train Acc: 91.49, Src Test Acc: 97.67, Trg Test Acc: 90.35
# Epoch: 125, TotalL: 0.7267, CrossE: 0.0407, CondE: 0.1679, disc: 0.6526, domain: 0.8628, Src VAT: 0.0954, Trg VAT: 0.1679, Src MixUp: 0.4480, Trg MixUp: 0.5841, Src Train Acc: 99.00, Trg Train Acc: 92.84, Src Test Acc: 96.50, Trg Test Acc: 92.16
# Epoch: 126, TotalL: 0.8314, CrossE: 0.0596, CondE: 0.1889, disc: 0.6495, domain: 0.8477, Src VAT: 0.1217, Trg VAT: 0.1889, Src MixUp: 0.5037, Trg MixUp: 0.6049, Src Train Acc: 98.52, Trg Train Acc: 92.19, Src Test Acc: 99.22, Trg Test Acc: 92.31
# Epoch: 127, TotalL: 0.7071, CrossE: 0.0300, CondE: 0.1700, disc: 0.6528, domain: 0.8520, Src VAT: 0.0874, Trg VAT: 0.1700, Src MixUp: 0.4484, Trg MixUp: 0.5740, Src Train Acc: 99.48, Trg Train Acc: 93.32, Src Test Acc: 96.50, Trg Test Acc: 92.31
# Epoch: 128, TotalL: 0.7540, CrossE: 0.0469, CondE: 0.1773, disc: 0.6582, domain: 0.8581, Src VAT: 0.1064, Trg VAT: 0.1773, Src MixUp: 0.4557, Trg MixUp: 0.6009, Src Train Acc: 98.83, Trg Train Acc: 91.75, Src Test Acc: 97.28, Trg Test Acc: 89.47
# Epoch: 129, TotalL: 0.7317, CrossE: 0.0459, CondE: 0.1733, disc: 0.6625, domain: 0.8486, Src VAT: 0.0987, Trg VAT: 0.1733, Src MixUp: 0.4448, Trg MixUp: 0.5841, Src Train Acc: 98.61, Trg Train Acc: 91.71, Src Test Acc: 94.94, Trg Test Acc: 91.73
# Epoch: 130, TotalL: 0.6690, CrossE: 0.0313, CondE: 0.1554, disc: 0.6576, domain: 0.8453, Src VAT: 0.0801, Trg VAT: 0.1554, Src MixUp: 0.4188, Trg MixUp: 0.5787, Src Train Acc: 99.35, Trg Train Acc: 93.84, Src Test Acc: 98.83, Trg Test Acc: 93.57
# Epoch: 131, TotalL: 0.7318, CrossE: 0.0515, CondE: 0.1663, disc: 0.6608, domain: 0.8491, Src VAT: 0.1002, Trg VAT: 0.1663, Src MixUp: 0.4392, Trg MixUp: 0.5796, Src Train Acc: 98.48, Trg Train Acc: 92.23, Src Test Acc: 95.33, Trg Test Acc: 90.06
# Epoch: 132, TotalL: 0.6899, CrossE: 0.0328, CondE: 0.1626, disc: 0.6533, domain: 0.8450, Src VAT: 0.0825, Trg VAT: 0.1626, Src MixUp: 0.4344, Trg MixUp: 0.5827, Src Train Acc: 99.18, Trg Train Acc: 94.05, Src Test Acc: 96.89, Trg Test Acc: 89.47
# Epoch: 133, TotalL: 0.7441, CrossE: 0.0457, CondE: 0.1745, disc: 0.6488, domain: 0.8586, Src VAT: 0.0970, Trg VAT: 0.1745, Src MixUp: 0.4592, Trg MixUp: 0.5693, Src Train Acc: 98.61, Trg Train Acc: 92.45, Src Test Acc: 96.89, Trg Test Acc: 90.12
# Epoch: 134, TotalL: 0.6858, CrossE: 0.0387, CondE: 0.1646, disc: 0.6576, domain: 0.8491, Src VAT: 0.0913, Trg VAT: 0.1646, Src MixUp: 0.4139, Trg MixUp: 0.5958, Src Train Acc: 98.91, Trg Train Acc: 92.10, Src Test Acc: 97.67, Trg Test Acc: 89.85
# Epoch: 135, TotalL: 0.7185, CrossE: 0.0398, CondE: 0.1669, disc: 0.6556, domain: 0.8371, Src VAT: 0.0953, Trg VAT: 0.1669, Src MixUp: 0.4413, Trg MixUp: 0.6053, Src Train Acc: 98.87, Trg Train Acc: 92.88, Src Test Acc: 95.72, Trg Test Acc: 89.12
# Epoch: 136, TotalL: 0.7093, CrossE: 0.0386, CondE: 0.1682, disc: 0.6547, domain: 0.8414, Src VAT: 0.0878, Trg VAT: 0.1682, Src MixUp: 0.4422, Trg MixUp: 0.5807, Src Train Acc: 99.22, Trg Train Acc: 92.40, Src Test Acc: 99.61, Trg Test Acc: 92.49
# Epoch: 137, TotalL: 0.7096, CrossE: 0.0375, CondE: 0.1631, disc: 0.6567, domain: 0.8409, Src VAT: 0.0921, Trg VAT: 0.1631, Src MixUp: 0.4396, Trg MixUp: 0.5879, Src Train Acc: 99.05, Trg Train Acc: 92.49, Src Test Acc: 94.55, Trg Test Acc: 89.42
# Epoch: 138, TotalL: 0.6337, CrossE: 0.0279, CondE: 0.1532, disc: 0.6534, domain: 0.8489, Src VAT: 0.0772, Trg VAT: 0.1532, Src MixUp: 0.3910, Trg MixUp: 0.5657, Src Train Acc: 99.39, Trg Train Acc: 92.62, Src Test Acc: 96.50, Trg Test Acc: 92.92
# Epoch: 139, TotalL: 0.7146, CrossE: 0.0502, CondE: 0.1589, disc: 0.6526, domain: 0.8374, Src VAT: 0.0924, Trg VAT: 0.1589, Src MixUp: 0.4325, Trg MixUp: 0.5875, Src Train Acc: 98.52, Trg Train Acc: 92.80, Src Test Acc: 99.61, Trg Test Acc: 89.62
# Epoch: 140, TotalL: 0.7239, CrossE: 0.0519, CondE: 0.1562, disc: 0.6609, domain: 0.8528, Src VAT: 0.1005, Trg VAT: 0.1562, Src MixUp: 0.4334, Trg MixUp: 0.5624, Src Train Acc: 98.65, Trg Train Acc: 91.97, Src Test Acc: 94.55, Trg Test Acc: 92.05
# Epoch: 141, TotalL: 0.6796, CrossE: 0.0369, CondE: 0.1577, disc: 0.6559, domain: 0.8476, Src VAT: 0.0862, Trg VAT: 0.1577, Src MixUp: 0.4187, Trg MixUp: 0.5593, Src Train Acc: 99.00, Trg Train Acc: 92.93, Src Test Acc: 98.05, Trg Test Acc: 92.84
# Epoch: 142, TotalL: 0.6719, CrossE: 0.0331, CondE: 0.1485, disc: 0.6486, domain: 0.8464, Src VAT: 0.0794, Trg VAT: 0.1485, Src MixUp: 0.4232, Trg MixUp: 0.5592, Src Train Acc: 99.35, Trg Train Acc: 93.58, Src Test Acc: 90.66, Trg Test Acc: 83.16
# Epoch: 143, TotalL: 0.6932, CrossE: 0.0417, CondE: 0.1573, disc: 0.6504, domain: 0.8458, Src VAT: 0.0884, Trg VAT: 0.1573, Src MixUp: 0.4249, Trg MixUp: 0.5669, Src Train Acc: 98.96, Trg Train Acc: 92.66, Src Test Acc: 97.67, Trg Test Acc: 92.92
# Epoch: 144, TotalL: 0.7151, CrossE: 0.0432, CondE: 0.1599, disc: 0.6518, domain: 0.8440, Src VAT: 0.0941, Trg VAT: 0.1599, Src MixUp: 0.4399, Trg MixUp: 0.5605, Src Train Acc: 98.83, Trg Train Acc: 92.93, Src Test Acc: 97.28, Trg Test Acc: 90.20
# Epoch: 145, TotalL: 0.6642, CrossE: 0.0239, CondE: 0.1511, disc: 0.6486, domain: 0.8458, Src VAT: 0.0751, Trg VAT: 0.1511, Src MixUp: 0.4278, Trg MixUp: 0.5691, Src Train Acc: 99.57, Trg Train Acc: 93.14, Src Test Acc: 99.22, Trg Test Acc: 93.36
# Epoch: 146, TotalL: 0.6964, CrossE: 0.0489, CondE: 0.1562, disc: 0.6527, domain: 0.8532, Src VAT: 0.0907, Trg VAT: 0.1562, Src MixUp: 0.4184, Trg MixUp: 0.5639, Src Train Acc: 98.57, Trg Train Acc: 92.32, Src Test Acc: 98.44, Trg Test Acc: 94.59
# Epoch: 147, TotalL: 0.6573, CrossE: 0.0279, CondE: 0.1533, disc: 0.6502, domain: 0.8441, Src VAT: 0.0746, Trg VAT: 0.1533, Src MixUp: 0.4187, Trg MixUp: 0.5506, Src Train Acc: 99.39, Trg Train Acc: 93.27, Src Test Acc: 95.72, Trg Test Acc: 89.33
# Epoch: 148, TotalL: 0.6869, CrossE: 0.0364, CondE: 0.1583, disc: 0.6458, domain: 0.8447, Src VAT: 0.0814, Trg VAT: 0.1583, Src MixUp: 0.4306, Trg MixUp: 0.5689, Src Train Acc: 99.31, Trg Train Acc: 94.10, Src Test Acc: 98.83, Trg Test Acc: 90.20
# Epoch: 149, TotalL: 0.6841, CrossE: 0.0322, CondE: 0.1586, disc: 0.6511, domain: 0.8462, Src VAT: 0.0850, Trg VAT: 0.1586, Src MixUp: 0.4299, Trg MixUp: 0.5489, Src Train Acc: 99.31, Trg Train Acc: 93.01, Src Test Acc: 90.66, Trg Test Acc: 85.29
# Epoch: 150, TotalL: 0.6530, CrossE: 0.0264, CondE: 0.1506, disc: 0.6461, domain: 0.8469, Src VAT: 0.0725, Trg VAT: 0.1506, Src MixUp: 0.4180, Trg MixUp: 0.5527, Src Train Acc: 99.31, Trg Train Acc: 94.66, Src Test Acc: 98.44, Trg Test Acc: 91.32
# Epoch: 151, TotalL: 0.6760, CrossE: 0.0331, CondE: 0.1509, disc: 0.6484, domain: 0.8581, Src VAT: 0.0792, Trg VAT: 0.1509, Src MixUp: 0.4260, Trg MixUp: 0.5623, Src Train Acc: 99.18, Trg Train Acc: 93.19, Src Test Acc: 91.44, Trg Test Acc: 85.38
# Epoch: 152, TotalL: 0.6416, CrossE: 0.0304, CondE: 0.1430, disc: 0.6533, domain: 0.8435, Src VAT: 0.0778, Trg VAT: 0.1430, Src MixUp: 0.4001, Trg MixUp: 0.5372, Src Train Acc: 99.26, Trg Train Acc: 93.36, Src Test Acc: 98.44, Trg Test Acc: 90.73
# Epoch: 153, TotalL: 0.6332, CrossE: 0.0309, CondE: 0.1483, disc: 0.6567, domain: 0.8487, Src VAT: 0.0744, Trg VAT: 0.1483, Src MixUp: 0.3919, Trg MixUp: 0.5539, Src Train Acc: 99.44, Trg Train Acc: 93.71, Src Test Acc: 99.61, Trg Test Acc: 94.94
# Epoch: 154, TotalL: 0.6652, CrossE: 0.0301, CondE: 0.1475, disc: 0.6580, domain: 0.8328, Src VAT: 0.0781, Trg VAT: 0.1475, Src MixUp: 0.4228, Trg MixUp: 0.5489, Src Train Acc: 99.39, Trg Train Acc: 94.14, Src Test Acc: 95.33, Trg Test Acc: 85.38
# Epoch: 155, TotalL: 0.7165, CrossE: 0.0533, CondE: 0.1670, disc: 0.6579, domain: 0.8378, Src VAT: 0.0963, Trg VAT: 0.1670, Src MixUp: 0.4273, Trg MixUp: 0.5735, Src Train Acc: 98.31, Trg Train Acc: 91.19, Src Test Acc: 97.28, Trg Test Acc: 92.28
# Epoch: 156, TotalL: 0.6341, CrossE: 0.0265, CondE: 0.1428, disc: 0.6515, domain: 0.8321, Src VAT: 0.0691, Trg VAT: 0.1428, Src MixUp: 0.4071, Trg MixUp: 0.5243, Src Train Acc: 99.48, Trg Train Acc: 93.45, Src Test Acc: 98.44, Trg Test Acc: 93.48
# Epoch: 157, TotalL: 0.7315, CrossE: 0.0447, CondE: 0.1636, disc: 0.6579, domain: 0.8316, Src VAT: 0.0924, Trg VAT: 0.1636, Src MixUp: 0.4549, Trg MixUp: 0.5834, Src Train Acc: 99.05, Trg Train Acc: 92.58, Src Test Acc: 98.83, Trg Test Acc: 90.99
# Epoch: 158, TotalL: 0.6256, CrossE: 0.0313, CondE: 0.1385, disc: 0.6541, domain: 0.8369, Src VAT: 0.0717, Trg VAT: 0.1385, Src MixUp: 0.3927, Trg MixUp: 0.5096, Src Train Acc: 99.35, Trg Train Acc: 93.58, Src Test Acc: 94.16, Trg Test Acc: 89.33
# Epoch: 159, TotalL: 0.6663, CrossE: 0.0401, CondE: 0.1466, disc: 0.6511, domain: 0.8299, Src VAT: 0.0783, Trg VAT: 0.1466, Src MixUp: 0.4163, Trg MixUp: 0.5231, Src Train Acc: 98.83, Trg Train Acc: 93.58, Src Test Acc: 94.55, Trg Test Acc: 87.22
# Epoch: 160, TotalL: 0.6458, CrossE: 0.0292, CondE: 0.1389, disc: 0.6483, domain: 0.8345, Src VAT: 0.0731, Trg VAT: 0.1389, Src MixUp: 0.4108, Trg MixUp: 0.5469, Src Train Acc: 99.44, Trg Train Acc: 94.05, Src Test Acc: 95.72, Trg Test Acc: 91.96
# Epoch: 161, TotalL: 0.6411, CrossE: 0.0281, CondE: 0.1425, disc: 0.6516, domain: 0.8376, Src VAT: 0.0696, Trg VAT: 0.1425, Src MixUp: 0.4092, Trg MixUp: 0.5542, Src Train Acc: 99.39, Trg Train Acc: 93.97, Src Test Acc: 98.44, Trg Test Acc: 89.47
# Epoch: 162, TotalL: 0.6576, CrossE: 0.0279, CondE: 0.1455, disc: 0.6534, domain: 0.8393, Src VAT: 0.0763, Trg VAT: 0.1455, Src MixUp: 0.4203, Trg MixUp: 0.5328, Src Train Acc: 99.48, Trg Train Acc: 94.27, Src Test Acc: 96.11, Trg Test Acc: 90.50
# Epoch: 163, TotalL: 0.6496, CrossE: 0.0285, CondE: 0.1437, disc: 0.6491, domain: 0.8418, Src VAT: 0.0773, Trg VAT: 0.1437, Src MixUp: 0.4096, Trg MixUp: 0.5480, Src Train Acc: 99.44, Trg Train Acc: 94.14, Src Test Acc: 98.83, Trg Test Acc: 91.78
# Epoch: 164, TotalL: 0.6350, CrossE: 0.0260, CondE: 0.1395, disc: 0.6516, domain: 0.8396, Src VAT: 0.0712, Trg VAT: 0.1395, Src MixUp: 0.4060, Trg MixUp: 0.5288, Src Train Acc: 99.39, Trg Train Acc: 94.36, Src Test Acc: 98.83, Trg Test Acc: 94.62
# Epoch: 165, TotalL: 0.6290, CrossE: 0.0262, CondE: 0.1359, disc: 0.6498, domain: 0.8471, Src VAT: 0.0721, Trg VAT: 0.1359, Src MixUp: 0.4001, Trg MixUp: 0.5132, Src Train Acc: 99.52, Trg Train Acc: 94.40, Src Test Acc: 95.33, Trg Test Acc: 91.64
# Epoch: 166, TotalL: 0.6558, CrossE: 0.0465, CondE: 0.1369, disc: 0.6561, domain: 0.8347, Src VAT: 0.0787, Trg VAT: 0.1369, Src MixUp: 0.3988, Trg MixUp: 0.5379, Src Train Acc: 98.52, Trg Train Acc: 93.40, Src Test Acc: 94.94, Trg Test Acc: 85.70
# Epoch: 167, TotalL: 0.6350, CrossE: 0.0259, CondE: 0.1323, disc: 0.6415, domain: 0.8446, Src VAT: 0.0739, Trg VAT: 0.1323, Src MixUp: 0.4042, Trg MixUp: 0.5274, Src Train Acc: 99.39, Trg Train Acc: 94.10, Src Test Acc: 99.22, Trg Test Acc: 93.39
# Epoch: 168, TotalL: 0.6491, CrossE: 0.0353, CondE: 0.1398, disc: 0.6534, domain: 0.8400, Src VAT: 0.0748, Trg VAT: 0.1398, Src MixUp: 0.4074, Trg MixUp: 0.5238, Src Train Acc: 98.96, Trg Train Acc: 94.62, Src Test Acc: 97.67, Trg Test Acc: 92.49
# Epoch: 169, TotalL: 0.6305, CrossE: 0.0233, CondE: 0.1377, disc: 0.6487, domain: 0.8460, Src VAT: 0.0711, Trg VAT: 0.1377, Src MixUp: 0.4041, Trg MixUp: 0.5283, Src Train Acc: 99.70, Trg Train Acc: 94.97, Src Test Acc: 97.28, Trg Test Acc: 92.72
# Epoch: 170, TotalL: 0.5893, CrossE: 0.0257, CondE: 0.1303, disc: 0.6562, domain: 0.8358, Src VAT: 0.0616, Trg VAT: 0.1303, Src MixUp: 0.3738, Trg MixUp: 0.5060, Src Train Acc: 99.31, Trg Train Acc: 94.66, Src Test Acc: 96.50, Trg Test Acc: 92.60
# Epoch: 171, TotalL: 0.6276, CrossE: 0.0246, CondE: 0.1350, disc: 0.6463, domain: 0.8284, Src VAT: 0.0701, Trg VAT: 0.1350, Src MixUp: 0.4029, Trg MixUp: 0.5273, Src Train Acc: 99.52, Trg Train Acc: 94.44, Src Test Acc: 96.50, Trg Test Acc: 90.85
# Epoch: 172, TotalL: 0.6274, CrossE: 0.0267, CondE: 0.1361, disc: 0.6495, domain: 0.8434, Src VAT: 0.0693, Trg VAT: 0.1361, Src MixUp: 0.3996, Trg MixUp: 0.5325, Src Train Acc: 99.48, Trg Train Acc: 93.58, Src Test Acc: 96.50, Trg Test Acc: 92.63
# Epoch: 173, TotalL: 0.6717, CrossE: 0.0381, CondE: 0.1435, disc: 0.6605, domain: 0.8273, Src VAT: 0.0811, Trg VAT: 0.1435, Src MixUp: 0.4198, Trg MixUp: 0.5441, Src Train Acc: 98.74, Trg Train Acc: 93.88, Src Test Acc: 97.67, Trg Test Acc: 91.87
# Epoch: 174, TotalL: 0.6111, CrossE: 0.0216, CondE: 0.1299, disc: 0.6473, domain: 0.8375, Src VAT: 0.0638, Trg VAT: 0.1299, Src MixUp: 0.3960, Trg MixUp: 0.5247, Src Train Acc: 99.57, Trg Train Acc: 94.79, Src Test Acc: 94.16, Trg Test Acc: 84.80
# Epoch: 175, TotalL: 0.6189, CrossE: 0.0260, CondE: 0.1363, disc: 0.6469, domain: 0.8450, Src VAT: 0.0649, Trg VAT: 0.1363, Src MixUp: 0.3958, Trg MixUp: 0.5343, Src Train Acc: 99.35, Trg Train Acc: 93.79, Src Test Acc: 99.61, Trg Test Acc: 92.13
# Epoch: 176, TotalL: 0.6353, CrossE: 0.0231, CondE: 0.1296, disc: 0.6475, domain: 0.8404, Src VAT: 0.0719, Trg VAT: 0.1296, Src MixUp: 0.4119, Trg MixUp: 0.5054, Src Train Acc: 99.83, Trg Train Acc: 94.75, Src Test Acc: 98.83, Trg Test Acc: 95.12
# Epoch: 177, TotalL: 0.6102, CrossE: 0.0277, CondE: 0.1286, disc: 0.6500, domain: 0.8476, Src VAT: 0.0665, Trg VAT: 0.1286, Src MixUp: 0.3881, Trg MixUp: 0.4937, Src Train Acc: 99.31, Trg Train Acc: 94.75, Src Test Acc: 98.05, Trg Test Acc: 89.42
# Epoch: 178, TotalL: 0.6413, CrossE: 0.0279, CondE: 0.1346, disc: 0.6507, domain: 0.8330, Src VAT: 0.0703, Trg VAT: 0.1346, Src MixUp: 0.4125, Trg MixUp: 0.5310, Src Train Acc: 99.39, Trg Train Acc: 94.23, Src Test Acc: 94.94, Trg Test Acc: 87.05
# Epoch: 179, TotalL: 0.5912, CrossE: 0.0258, CondE: 0.1278, disc: 0.6477, domain: 0.8474, Src VAT: 0.0640, Trg VAT: 0.1278, Src MixUp: 0.3717, Trg MixUp: 0.5182, Src Train Acc: 99.44, Trg Train Acc: 93.88, Src Test Acc: 98.44, Trg Test Acc: 95.12
# Epoch: 180, TotalL: 0.6200, CrossE: 0.0227, CondE: 0.1316, disc: 0.6498, domain: 0.8352, Src VAT: 0.0654, Trg VAT: 0.1316, Src MixUp: 0.4022, Trg MixUp: 0.5228, Src Train Acc: 99.65, Trg Train Acc: 95.05, Src Test Acc: 97.28, Trg Test Acc: 93.27
# Epoch: 181, TotalL: 0.6277, CrossE: 0.0259, CondE: 0.1284, disc: 0.6515, domain: 0.8326, Src VAT: 0.0684, Trg VAT: 0.1284, Src MixUp: 0.4043, Trg MixUp: 0.5239, Src Train Acc: 99.48, Trg Train Acc: 94.97, Src Test Acc: 87.55, Trg Test Acc: 82.43
# Epoch: 182, TotalL: 0.5933, CrossE: 0.0293, CondE: 0.1261, disc: 0.6495, domain: 0.8337, Src VAT: 0.0643, Trg VAT: 0.1261, Src MixUp: 0.3714, Trg MixUp: 0.5183, Src Train Acc: 99.18, Trg Train Acc: 94.66, Src Test Acc: 98.44, Trg Test Acc: 93.16
# Epoch: 183, TotalL: 0.6051, CrossE: 0.0247, CondE: 0.1349, disc: 0.6486, domain: 0.8351, Src VAT: 0.0647, Trg VAT: 0.1349, Src MixUp: 0.3858, Trg MixUp: 0.5192, Src Train Acc: 99.44, Trg Train Acc: 94.53, Src Test Acc: 96.11, Trg Test Acc: 85.12
# Epoch: 184, TotalL: 0.5796, CrossE: 0.0249, CondE: 0.1166, disc: 0.6506, domain: 0.8320, Src VAT: 0.0596, Trg VAT: 0.1166, Src MixUp: 0.3701, Trg MixUp: 0.4968, Src Train Acc: 99.44, Trg Train Acc: 95.10, Src Test Acc: 98.83, Trg Test Acc: 90.61
# Epoch: 185, TotalL: 0.6050, CrossE: 0.0261, CondE: 0.1244, disc: 0.6494, domain: 0.8358, Src VAT: 0.0630, Trg VAT: 0.1244, Src MixUp: 0.3875, Trg MixUp: 0.5202, Src Train Acc: 99.31, Trg Train Acc: 94.53, Src Test Acc: 93.39, Trg Test Acc: 89.47
# Epoch: 186, TotalL: 0.5653, CrossE: 0.0196, CondE: 0.1173, disc: 0.6464, domain: 0.8355, Src VAT: 0.0532, Trg VAT: 0.1173, Src MixUp: 0.3668, Trg MixUp: 0.5001, Src Train Acc: 99.74, Trg Train Acc: 95.18, Src Test Acc: 98.83, Trg Test Acc: 89.85
# Epoch: 187, TotalL: 0.5876, CrossE: 0.0183, CondE: 0.1187, disc: 0.6466, domain: 0.8358, Src VAT: 0.0570, Trg VAT: 0.1187, Src MixUp: 0.3850, Trg MixUp: 0.5175, Src Train Acc: 99.65, Trg Train Acc: 95.70, Src Test Acc: 99.61, Trg Test Acc: 95.06
# Epoch: 188, TotalL: 0.6405, CrossE: 0.0349, CondE: 0.1395, disc: 0.6505, domain: 0.8302, Src VAT: 0.0704, Trg VAT: 0.1395, Src MixUp: 0.4051, Trg MixUp: 0.5170, Src Train Acc: 99.00, Trg Train Acc: 94.40, Src Test Acc: 98.83, Trg Test Acc: 93.48
# Epoch: 189, TotalL: 0.5809, CrossE: 0.0190, CondE: 0.1189, disc: 0.6485, domain: 0.8350, Src VAT: 0.0570, Trg VAT: 0.1189, Src MixUp: 0.3795, Trg MixUp: 0.4966, Src Train Acc: 99.65, Trg Train Acc: 94.97, Src Test Acc: 99.61, Trg Test Acc: 94.27
# Epoch: 190, TotalL: 0.6092, CrossE: 0.0291, CondE: 0.1211, disc: 0.6527, domain: 0.8288, Src VAT: 0.0618, Trg VAT: 0.1211, Src MixUp: 0.3918, Trg MixUp: 0.5101, Src Train Acc: 99.39, Trg Train Acc: 94.84, Src Test Acc: 98.83, Trg Test Acc: 95.00
# Epoch: 191, TotalL: 0.5637, CrossE: 0.0170, CondE: 0.1221, disc: 0.6568, domain: 0.8297, Src VAT: 0.0543, Trg VAT: 0.1221, Src MixUp: 0.3656, Trg MixUp: 0.5120, Src Train Acc: 99.74, Trg Train Acc: 94.36, Src Test Acc: 95.72, Trg Test Acc: 88.92
# Epoch: 192, TotalL: 0.6128, CrossE: 0.0230, CondE: 0.1348, disc: 0.6504, domain: 0.8250, Src VAT: 0.0643, Trg VAT: 0.1348, Src MixUp: 0.3957, Trg MixUp: 0.5287, Src Train Acc: 99.65, Trg Train Acc: 94.05, Src Test Acc: 97.67, Trg Test Acc: 91.67
# Epoch: 193, TotalL: 0.5712, CrossE: 0.0227, CondE: 0.1191, disc: 0.6557, domain: 0.8233, Src VAT: 0.0551, Trg VAT: 0.1191, Src MixUp: 0.3688, Trg MixUp: 0.4960, Src Train Acc: 99.39, Trg Train Acc: 95.36, Src Test Acc: 96.89, Trg Test Acc: 86.99
# ...
# Epoch: 437, TotalL: 0.3836, CrossE: 0.0070, CondE: 0.0557, disc: 0.6689, domain: 0.7735, Src VAT: 0.0202, Trg VAT: 0.0557, Src MixUp: 0.2557, Trg MixUp: 0.3736, Src Train Acc: 99.83, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 94.56
# Epoch: 438, TotalL: 0.3704, CrossE: 0.0052, CondE: 0.0488, disc: 0.6636, domain: 0.7770, Src VAT: 0.0191, Trg VAT: 0.0488, Src MixUp: 0.2479, Trg MixUp: 0.3539, Src Train Acc: 99.91, Trg Train Acc: 98.09, Src Test Acc: 97.28, Trg Test Acc: 90.53
# Epoch: 439, TotalL: 0.3950, CrossE: 0.0069, CondE: 0.0483, disc: 0.6666, domain: 0.7793, Src VAT: 0.0228, Trg VAT: 0.0483, Src MixUp: 0.2657, Trg MixUp: 0.3687, Src Train Acc: 99.87, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 96.11
# Epoch: 440, TotalL: 0.3685, CrossE: 0.0066, CondE: 0.0419, disc: 0.6741, domain: 0.7736, Src VAT: 0.0189, Trg VAT: 0.0419, Src MixUp: 0.2477, Trg MixUp: 0.3347, Src Train Acc: 99.91, Trg Train Acc: 98.74, Src Test Acc: 97.67, Trg Test Acc: 89.44
# Epoch: 441, TotalL: 0.4312, CrossE: 0.0117, CondE: 0.0712, disc: 0.6716, domain: 0.7705, Src VAT: 0.0311, Trg VAT: 0.0712, Src MixUp: 0.2834, Trg MixUp: 0.3999, Src Train Acc: 99.70, Trg Train Acc: 97.79, Src Test Acc: 96.11, Trg Test Acc: 90.18
# Epoch: 442, TotalL: 0.3821, CrossE: 0.0051, CondE: 0.0473, disc: 0.6726, domain: 0.7663, Src VAT: 0.0195, Trg VAT: 0.0473, Src MixUp: 0.2593, Trg MixUp: 0.3671, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 99.61, Trg Test Acc: 92.63
# Epoch: 443, TotalL: 0.3769, CrossE: 0.0054, CondE: 0.0509, disc: 0.6722, domain: 0.7697, Src VAT: 0.0195, Trg VAT: 0.0509, Src MixUp: 0.2534, Trg MixUp: 0.3617, Src Train Acc: 99.87, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 94.88
# Epoch: 444, TotalL: 0.3717, CrossE: 0.0076, CondE: 0.0457, disc: 0.6691, domain: 0.7694, Src VAT: 0.0177, Trg VAT: 0.0457, Src MixUp: 0.2509, Trg MixUp: 0.3331, Src Train Acc: 99.74, Trg Train Acc: 98.31, Src Test Acc: 99.22, Trg Test Acc: 95.20
# Epoch: 445, TotalL: 0.4074, CrossE: 0.0094, CondE: 0.0576, disc: 0.6686, domain: 0.7717, Src VAT: 0.0235, Trg VAT: 0.0576, Src MixUp: 0.2745, Trg MixUp: 0.3630, Src Train Acc: 99.74, Trg Train Acc: 97.96, Src Test Acc: 99.61, Trg Test Acc: 94.94
# Epoch: 446, TotalL: 0.3897, CrossE: 0.0095, CondE: 0.0570, disc: 0.6738, domain: 0.7690, Src VAT: 0.0232, Trg VAT: 0.0570, Src MixUp: 0.2567, Trg MixUp: 0.3709, Src Train Acc: 99.83, Trg Train Acc: 97.48, Src Test Acc: 99.22, Trg Test Acc: 96.26
# Epoch: 447, TotalL: 0.4032, CrossE: 0.0059, CondE: 0.0519, disc: 0.6676, domain: 0.7681, Src VAT: 0.0213, Trg VAT: 0.0519, Src MixUp: 0.2773, Trg MixUp: 0.3607, Src Train Acc: 99.83, Trg Train Acc: 98.05, Src Test Acc: 99.22, Trg Test Acc: 94.04
# Epoch: 448, TotalL: 0.3577, CrossE: 0.0032, CondE: 0.0433, disc: 0.6639, domain: 0.7715, Src VAT: 0.0150, Trg VAT: 0.0433, Src MixUp: 0.2425, Trg MixUp: 0.3539, Src Train Acc: 100.00, Trg Train Acc: 98.52, Src Test Acc: 99.61, Trg Test Acc: 94.53
# Epoch: 449, TotalL: 0.3759, CrossE: 0.0068, CondE: 0.0475, disc: 0.6654, domain: 0.7788, Src VAT: 0.0190, Trg VAT: 0.0475, Src MixUp: 0.2532, Trg MixUp: 0.3391, Src Train Acc: 99.96, Trg Train Acc: 97.92, Src Test Acc: 97.67, Trg Test Acc: 93.86
# Epoch: 450, TotalL: 0.4025, CrossE: 0.0081, CondE: 0.0596, disc: 0.6703, domain: 0.7711, Src VAT: 0.0260, Trg VAT: 0.0596, Src MixUp: 0.2671, Trg MixUp: 0.3764, Src Train Acc: 99.87, Trg Train Acc: 98.05, Src Test Acc: 98.83, Trg Test Acc: 96.29
# Epoch: 451, TotalL: 0.3408, CrossE: 0.0045, CondE: 0.0401, disc: 0.6666, domain: 0.7730, Src VAT: 0.0151, Trg VAT: 0.0401, Src MixUp: 0.2243, Trg MixUp: 0.3578, Src Train Acc: 99.87, Trg Train Acc: 98.61, Src Test Acc: 99.22, Trg Test Acc: 94.01
# Epoch: 452, TotalL: 0.3970, CrossE: 0.0080, CondE: 0.0544, disc: 0.6724, domain: 0.7736, Src VAT: 0.0226, Trg VAT: 0.0544, Src MixUp: 0.2644, Trg MixUp: 0.3922, Src Train Acc: 99.83, Trg Train Acc: 98.00, Src Test Acc: 99.61, Trg Test Acc: 96.20
# Epoch: 453, TotalL: 0.3905, CrossE: 0.0063, CondE: 0.0478, disc: 0.6673, domain: 0.7756, Src VAT: 0.0202, Trg VAT: 0.0478, Src MixUp: 0.2638, Trg MixUp: 0.3818, Src Train Acc: 99.87, Trg Train Acc: 98.39, Src Test Acc: 98.44, Trg Test Acc: 88.33
# Epoch: 454, TotalL: 0.4408, CrossE: 0.0239, CondE: 0.0707, disc: 0.6685, domain: 0.7665, Src VAT: 0.0356, Trg VAT: 0.0707, Src MixUp: 0.2759, Trg MixUp: 0.4092, Src Train Acc: 99.26, Trg Train Acc: 97.66, Src Test Acc: 96.50, Trg Test Acc: 89.30
# Epoch: 455, TotalL: 0.3785, CrossE: 0.0086, CondE: 0.0527, disc: 0.6672, domain: 0.7768, Src VAT: 0.0215, Trg VAT: 0.0527, Src MixUp: 0.2500, Trg MixUp: 0.3485, Src Train Acc: 99.74, Trg Train Acc: 98.13, Src Test Acc: 99.61, Trg Test Acc: 95.44
# Epoch: 456, TotalL: 0.3656, CrossE: 0.0042, CondE: 0.0522, disc: 0.6642, domain: 0.7761, Src VAT: 0.0178, Trg VAT: 0.0522, Src MixUp: 0.2448, Trg MixUp: 0.3551, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 99.22, Trg Test Acc: 93.57
# Epoch: 457, TotalL: 0.3614, CrossE: 0.0051, CondE: 0.0435, disc: 0.6679, domain: 0.7732, Src VAT: 0.0169, Trg VAT: 0.0435, Src MixUp: 0.2443, Trg MixUp: 0.3277, Src Train Acc: 99.83, Trg Train Acc: 98.39, Src Test Acc: 100.00, Trg Test Acc: 95.79
# Epoch: 458, TotalL: 0.3827, CrossE: 0.0043, CondE: 0.0530, disc: 0.6679, domain: 0.7683, Src VAT: 0.0187, Trg VAT: 0.0530, Src MixUp: 0.2602, Trg MixUp: 0.3701, Src Train Acc: 100.00, Trg Train Acc: 97.92, Src Test Acc: 100.00, Trg Test Acc: 93.13
# Epoch: 459, TotalL: 0.3804, CrossE: 0.0065, CondE: 0.0505, disc: 0.6668, domain: 0.7708, Src VAT: 0.0206, Trg VAT: 0.0505, Src MixUp: 0.2551, Trg MixUp: 0.3560, Src Train Acc: 99.83, Trg Train Acc: 98.52, Src Test Acc: 99.61, Trg Test Acc: 95.00
# Epoch: 460, TotalL: 0.3601, CrossE: 0.0043, CondE: 0.0448, disc: 0.6662, domain: 0.7761, Src VAT: 0.0167, Trg VAT: 0.0448, Src MixUp: 0.2415, Trg MixUp: 0.3537, Src Train Acc: 99.96, Trg Train Acc: 98.31, Src Test Acc: 99.61, Trg Test Acc: 96.84
# Epoch: 461, TotalL: 0.3470, CrossE: 0.0022, CondE: 0.0397, disc: 0.6664, domain: 0.7723, Src VAT: 0.0115, Trg VAT: 0.0397, Src MixUp: 0.2385, Trg MixUp: 0.3332, Src Train Acc: 100.00, Trg Train Acc: 98.52, Src Test Acc: 99.61, Trg Test Acc: 96.40
# Epoch: 462, TotalL: 0.3996, CrossE: 0.0097, CondE: 0.0515, disc: 0.6705, domain: 0.7682, Src VAT: 0.0240, Trg VAT: 0.0515, Src MixUp: 0.2667, Trg MixUp: 0.3698, Src Train Acc: 99.78, Trg Train Acc: 98.31, Src Test Acc: 99.61, Trg Test Acc: 96.02
# Epoch: 463, TotalL: 0.4004, CrossE: 0.0054, CondE: 0.0536, disc: 0.6714, domain: 0.7677, Src VAT: 0.0208, Trg VAT: 0.0536, Src MixUp: 0.2749, Trg MixUp: 0.3661, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 98.44, Trg Test Acc: 93.98
# Epoch: 464, TotalL: 0.4001, CrossE: 0.0157, CondE: 0.0553, disc: 0.6697, domain: 0.7695, Src VAT: 0.0244, Trg VAT: 0.0553, Src MixUp: 0.2597, Trg MixUp: 0.3736, Src Train Acc: 99.52, Trg Train Acc: 97.96, Src Test Acc: 97.28, Trg Test Acc: 93.13
# Epoch: 465, TotalL: 0.4048, CrossE: 0.0104, CondE: 0.0624, disc: 0.6712, domain: 0.7698, Src VAT: 0.0263, Trg VAT: 0.0624, Src MixUp: 0.2662, Trg MixUp: 0.3798, Src Train Acc: 99.74, Trg Train Acc: 97.57, Src Test Acc: 99.22, Trg Test Acc: 95.15
# Epoch: 466, TotalL: 0.3736, CrossE: 0.0066, CondE: 0.0474, disc: 0.6703, domain: 0.7712, Src VAT: 0.0187, Trg VAT: 0.0474, Src MixUp: 0.2493, Trg MixUp: 0.3722, Src Train Acc: 99.83, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 96.52
# Epoch: 467, TotalL: 0.3491, CrossE: 0.0055, CondE: 0.0427, disc: 0.6664, domain: 0.7715, Src VAT: 0.0143, Trg VAT: 0.0427, Src MixUp: 0.2342, Trg MixUp: 0.3322, Src Train Acc: 99.91, Trg Train Acc: 98.48, Src Test Acc: 99.22, Trg Test Acc: 96.75
# Epoch: 468, TotalL: 0.3339, CrossE: 0.0051, CondE: 0.0457, disc: 0.6654, domain: 0.7713, Src VAT: 0.0157, Trg VAT: 0.0457, Src MixUp: 0.2175, Trg MixUp: 0.3327, Src Train Acc: 99.91, Trg Train Acc: 98.83, Src Test Acc: 99.22, Trg Test Acc: 92.43
# Epoch: 469, TotalL: 0.4095, CrossE: 0.0107, CondE: 0.0559, disc: 0.6754, domain: 0.7621, Src VAT: 0.0296, Trg VAT: 0.0559, Src MixUp: 0.2697, Trg MixUp: 0.3702, Src Train Acc: 99.74, Trg Train Acc: 98.13, Src Test Acc: 100.00, Trg Test Acc: 93.86
# Epoch: 470, TotalL: 0.3466, CrossE: 0.0039, CondE: 0.0408, disc: 0.6663, domain: 0.7675, Src VAT: 0.0147, Trg VAT: 0.0408, Src MixUp: 0.2332, Trg MixUp: 0.3366, Src Train Acc: 99.91, Trg Train Acc: 98.44, Src Test Acc: 96.50, Trg Test Acc: 86.87
# Epoch: 471, TotalL: 0.4204, CrossE: 0.0086, CondE: 0.0627, disc: 0.6754, domain: 0.7611, Src VAT: 0.0293, Trg VAT: 0.0627, Src MixUp: 0.2804, Trg MixUp: 0.3904, Src Train Acc: 99.91, Trg Train Acc: 98.00, Src Test Acc: 100.00, Trg Test Acc: 96.75
# Epoch: 472, TotalL: 0.3810, CrossE: 0.0061, CondE: 0.0497, disc: 0.6710, domain: 0.7607, Src VAT: 0.0220, Trg VAT: 0.0497, Src MixUp: 0.2547, Trg MixUp: 0.3666, Src Train Acc: 99.96, Trg Train Acc: 98.39, Src Test Acc: 99.22, Trg Test Acc: 90.79
# Epoch: 473, TotalL: 0.3683, CrossE: 0.0037, CondE: 0.0395, disc: 0.6743, domain: 0.7600, Src VAT: 0.0177, Trg VAT: 0.0395, Src MixUp: 0.2519, Trg MixUp: 0.3490, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 99.61, Trg Test Acc: 96.61
# Epoch: 474, TotalL: 0.3682, CrossE: 0.0050, CondE: 0.0463, disc: 0.6778, domain: 0.7568, Src VAT: 0.0199, Trg VAT: 0.0463, Src MixUp: 0.2467, Trg MixUp: 0.3578, Src Train Acc: 99.96, Trg Train Acc: 98.00, Src Test Acc: 99.22, Trg Test Acc: 96.52
# Epoch: 475, TotalL: 0.3987, CrossE: 0.0107, CondE: 0.0549, disc: 0.6764, domain: 0.7567, Src VAT: 0.0244, Trg VAT: 0.0549, Src MixUp: 0.2643, Trg MixUp: 0.3755, Src Train Acc: 99.70, Trg Train Acc: 97.96, Src Test Acc: 99.22, Trg Test Acc: 95.67
# Epoch: 476, TotalL: 0.3784, CrossE: 0.0069, CondE: 0.0496, disc: 0.6756, domain: 0.7603, Src VAT: 0.0203, Trg VAT: 0.0496, Src MixUp: 0.2534, Trg MixUp: 0.3628, Src Train Acc: 99.83, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 95.50
# Epoch: 477, TotalL: 0.3726, CrossE: 0.0052, CondE: 0.0528, disc: 0.6707, domain: 0.7617, Src VAT: 0.0177, Trg VAT: 0.0528, Src MixUp: 0.2502, Trg MixUp: 0.3773, Src Train Acc: 99.91, Trg Train Acc: 98.61, Src Test Acc: 100.00, Trg Test Acc: 95.73
# Epoch: 478, TotalL: 0.3873, CrossE: 0.0068, CondE: 0.0533, disc: 0.6748, domain: 0.7634, Src VAT: 0.0234, Trg VAT: 0.0533, Src MixUp: 0.2572, Trg MixUp: 0.3793, Src Train Acc: 99.96, Trg Train Acc: 98.09, Src Test Acc: 97.28, Trg Test Acc: 91.87
# Epoch: 479, TotalL: 0.4160, CrossE: 0.0114, CondE: 0.0571, disc: 0.6745, domain: 0.7602, Src VAT: 0.0307, Trg VAT: 0.0571, Src MixUp: 0.2743, Trg MixUp: 0.3713, Src Train Acc: 99.83, Trg Train Acc: 98.00, Src Test Acc: 100.00, Trg Test Acc: 95.67
# Epoch: 480, TotalL: 0.4046, CrossE: 0.0088, CondE: 0.0610, disc: 0.6738, domain: 0.7586, Src VAT: 0.0257, Trg VAT: 0.0610, Src MixUp: 0.2690, Trg MixUp: 0.3819, Src Train Acc: 99.83, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 96.96
# Epoch: 481, TotalL: 0.3628, CrossE: 0.0056, CondE: 0.0427, disc: 0.6737, domain: 0.7546, Src VAT: 0.0176, Trg VAT: 0.0427, Src MixUp: 0.2453, Trg MixUp: 0.3390, Src Train Acc: 99.87, Trg Train Acc: 98.70, Src Test Acc: 99.61, Trg Test Acc: 95.44
# Epoch: 482, TotalL: 0.3391, CrossE: 0.0043, CondE: 0.0424, disc: 0.6710, domain: 0.7620, Src VAT: 0.0152, Trg VAT: 0.0424, Src MixUp: 0.2238, Trg MixUp: 0.3510, Src Train Acc: 99.91, Trg Train Acc: 97.79, Src Test Acc: 97.28, Trg Test Acc: 90.26
# Epoch: 483, TotalL: 0.3496, CrossE: 0.0037, CondE: 0.0394, disc: 0.6761, domain: 0.7570, Src VAT: 0.0145, Trg VAT: 0.0394, Src MixUp: 0.2384, Trg MixUp: 0.3255, Src Train Acc: 99.96, Trg Train Acc: 98.78, Src Test Acc: 99.22, Trg Test Acc: 94.91
# Epoch: 484, TotalL: 0.3472, CrossE: 0.0056, CondE: 0.0392, disc: 0.6690, domain: 0.7620, Src VAT: 0.0159, Trg VAT: 0.0392, Src MixUp: 0.2309, Trg MixUp: 0.3446, Src Train Acc: 99.87, Trg Train Acc: 98.91, Src Test Acc: 100.00, Trg Test Acc: 96.61
# Epoch: 485, TotalL: 0.3842, CrossE: 0.0079, CondE: 0.0516, disc: 0.6745, domain: 0.7625, Src VAT: 0.0224, Trg VAT: 0.0516, Src MixUp: 0.2547, Trg MixUp: 0.3742, Src Train Acc: 99.87, Trg Train Acc: 98.31, Src Test Acc: 99.22, Trg Test Acc: 94.91
# Epoch: 486, TotalL: 0.3739, CrossE: 0.0062, CondE: 0.0455, disc: 0.6731, domain: 0.7633, Src VAT: 0.0212, Trg VAT: 0.0455, Src MixUp: 0.2484, Trg MixUp: 0.3718, Src Train Acc: 99.87, Trg Train Acc: 98.39, Src Test Acc: 100.00, Trg Test Acc: 95.20
# Epoch: 487, TotalL: 0.3784, CrossE: 0.0062, CondE: 0.0459, disc: 0.6735, domain: 0.7566, Src VAT: 0.0197, Trg VAT: 0.0459, Src MixUp: 0.2555, Trg MixUp: 0.3635, Src Train Acc: 99.91, Trg Train Acc: 98.22, Src Test Acc: 100.00, Trg Test Acc: 95.64
# Epoch: 488, TotalL: 0.3588, CrossE: 0.0083, CondE: 0.0431, disc: 0.6685, domain: 0.7620, Src VAT: 0.0182, Trg VAT: 0.0431, Src MixUp: 0.2372, Trg MixUp: 0.3405, Src Train Acc: 99.83, Trg Train Acc: 98.57, Src Test Acc: 99.22, Trg Test Acc: 95.15
# Epoch: 489, TotalL: 0.4008, CrossE: 0.0079, CondE: 0.0498, disc: 0.6756, domain: 0.7584, Src VAT: 0.0238, Trg VAT: 0.0498, Src MixUp: 0.2689, Trg MixUp: 0.3945, Src Train Acc: 99.87, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 94.47
# Epoch: 490, TotalL: 0.3566, CrossE: 0.0045, CondE: 0.0405, disc: 0.6727, domain: 0.7622, Src VAT: 0.0175, Trg VAT: 0.0405, Src MixUp: 0.2406, Trg MixUp: 0.3312, Src Train Acc: 99.96, Trg Train Acc: 98.61, Src Test Acc: 100.00, Trg Test Acc: 96.70
# Epoch: 491, TotalL: 0.3738, CrossE: 0.0057, CondE: 0.0494, disc: 0.6764, domain: 0.7581, Src VAT: 0.0190, Trg VAT: 0.0494, Src MixUp: 0.2517, Trg MixUp: 0.3616, Src Train Acc: 99.91, Trg Train Acc: 98.44, Src Test Acc: 98.05, Trg Test Acc: 89.18
# Epoch: 492, TotalL: 0.4167, CrossE: 0.0191, CondE: 0.0574, disc: 0.6811, domain: 0.7566, Src VAT: 0.0318, Trg VAT: 0.0574, Src MixUp: 0.2675, Trg MixUp: 0.3578, Src Train Acc: 99.48, Trg Train Acc: 97.53, Src Test Acc: 98.05, Trg Test Acc: 90.50
# Epoch: 493, TotalL: 0.3423, CrossE: 0.0046, CondE: 0.0395, disc: 0.6705, domain: 0.7578, Src VAT: 0.0167, Trg VAT: 0.0395, Src MixUp: 0.2266, Trg MixUp: 0.3427, Src Train Acc: 100.00, Trg Train Acc: 98.35, Src Test Acc: 99.61, Trg Test Acc: 97.02
# Epoch: 494, TotalL: 0.3596, CrossE: 0.0034, CondE: 0.0369, disc: 0.6732, domain: 0.7563, Src VAT: 0.0152, Trg VAT: 0.0369, Src MixUp: 0.2471, Trg MixUp: 0.3442, Src Train Acc: 100.00, Trg Train Acc: 98.52, Src Test Acc: 100.00, Trg Test Acc: 96.05
# Epoch: 495, TotalL: 0.3575, CrossE: 0.0043, CondE: 0.0377, disc: 0.6721, domain: 0.7577, Src VAT: 0.0167, Trg VAT: 0.0377, Src MixUp: 0.2423, Trg MixUp: 0.3435, Src Train Acc: 99.96, Trg Train Acc: 98.74, Src Test Acc: 98.83, Trg Test Acc: 95.35
# Epoch: 496, TotalL: 0.3516, CrossE: 0.0045, CondE: 0.0399, disc: 0.6759, domain: 0.7557, Src VAT: 0.0173, Trg VAT: 0.0399, Src MixUp: 0.2356, Trg MixUp: 0.3425, Src Train Acc: 99.91, Trg Train Acc: 98.74, Src Test Acc: 98.44, Trg Test Acc: 93.63
# Epoch: 497, TotalL: 0.3942, CrossE: 0.0071, CondE: 0.0495, disc: 0.6771, domain: 0.7552, Src VAT: 0.0225, Trg VAT: 0.0495, Src MixUp: 0.2670, Trg MixUp: 0.3657, Src Train Acc: 99.87, Trg Train Acc: 98.13, Src Test Acc: 96.50, Trg Test Acc: 90.29
# Epoch: 498, TotalL: 0.3677, CrossE: 0.0120, CondE: 0.0461, disc: 0.6766, domain: 0.7551, Src VAT: 0.0212, Trg VAT: 0.0461, Src MixUp: 0.2383, Trg MixUp: 0.3556, Src Train Acc: 99.70, Trg Train Acc: 98.74, Src Test Acc: 96.50, Trg Test Acc: 88.74
# Epoch: 499, TotalL: 0.3310, CrossE: 0.0042, CondE: 0.0330, disc: 0.6737, domain: 0.7553, Src VAT: 0.0152, Trg VAT: 0.0330, Src MixUp: 0.2186, Trg MixUp: 0.3405, Src Train Acc: 99.91, Trg Train Acc: 98.70, Src Test Acc: 99.61, Trg Test Acc: 94.68
# Epoch: 500, TotalL: 0.3645, CrossE: 0.0047, CondE: 0.0473, disc: 0.6753, domain: 0.7566, Src VAT: 0.0178, Trg VAT: 0.0473, Src MixUp: 0.2451, Trg MixUp: 0.3599, Src Train Acc: 99.96, Trg Train Acc: 98.52, Src Test Acc: 98.83, Trg Test Acc: 96.43
