# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='2'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 500
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
disc_activation = 'relu'
gen_activation  = 'selu'
notes           = "updated total_loss to reflect my issue on github, VMT, with gaussian noise" 

log_data = "num_classes-{}_batch_size-{}_train_src_days-{}_train_trg_days-{}_learning_rate-{}_num_hidden-{}_num_features-{}_disc_activation-{}_gen_activation-{}_notes-{}".format(num_classes, 
                                                                                                                                                                                  batch_size, 
                                                                                                                                                                                  train_src_days, 
                                                                                                                                                                                  train_trg_days, 
                                                                                                                                                                                  learning_rate, 
                                                                                                                                                                                  num_hidden, 
                                                                                                                                                                                  num_features,
                                                                                                                                                                                  disc_activation,
                                                                                                                                                                                  gen_activation,
                                                                                                                                                                                  notes)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, num_features, gen_activation)
discriminator  = Discriminator(num_hidden, disc_activation)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    
for epoch in range(epochs):
  global_step.assign_add(1)  
    
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0821 12:50:31.382665 140421356156672 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0821 12:50:36.198677 140421356156672 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.0690, CrossE: 2.1889, CondE: 2.1515, disc: 0.6957, domain: 0.7070, Src VAT: 2.1526, Trg VAT: 2.1515, Src MixUp: 2.1544, Trg MixUp: 2.1536, Src Train Acc: 13.59, Trg Train Acc: 14.02, Src Test Acc: 27.63, Trg Test Acc: 26.87
# Epoch: 002, TotalL: 6.1003, CrossE: 1.7932, CondE: 1.8578, disc: 0.7172, domain: 0.7399, Src VAT: 1.8626, Trg VAT: 1.8578, Src MixUp: 1.9342, Trg MixUp: 1.9236, Src Train Acc: 30.03, Trg Train Acc: 27.95, Src Test Acc: 49.03, Trg Test Acc: 48.33
# Epoch: 003, TotalL: 4.9454, CrossE: 1.3858, CondE: 1.4924, disc: 0.7090, domain: 0.7451, Src VAT: 1.4875, Trg VAT: 1.4924, Src MixUp: 1.6418, Trg MixUp: 1.6501, Src Train Acc: 46.44, Trg Train Acc: 41.62, Src Test Acc: 61.09, Trg Test Acc: 56.81
# Epoch: 004, TotalL: 4.2418, CrossE: 1.1318, CondE: 1.2719, disc: 0.6971, domain: 0.7561, Src VAT: 1.2592, Trg VAT: 1.2719, Src MixUp: 1.4664, Trg MixUp: 1.5041, Src Train Acc: 56.47, Trg Train Acc: 51.30, Src Test Acc: 66.15, Trg Test Acc: 57.75
# Epoch: 005, TotalL: 3.7549, CrossE: 0.9554, CondE: 1.1191, disc: 0.6901, domain: 0.7659, Src VAT: 1.1058, Trg VAT: 1.1191, Src MixUp: 1.3415, Trg MixUp: 1.3988, Src Train Acc: 64.32, Trg Train Acc: 57.64, Src Test Acc: 75.10, Trg Test Acc: 63.63
# Epoch: 006, TotalL: 3.4081, CrossE: 0.8325, CondE: 0.9962, disc: 0.6836, domain: 0.7746, Src VAT: 0.9844, Trg VAT: 0.9962, Src MixUp: 1.2652, Trg MixUp: 1.3076, Src Train Acc: 68.62, Trg Train Acc: 62.24, Src Test Acc: 68.87, Trg Test Acc: 59.82
# Epoch: 007, TotalL: 3.1069, CrossE: 0.7389, CondE: 0.9034, disc: 0.6772, domain: 0.7844, Src VAT: 0.8973, Trg VAT: 0.9034, Src MixUp: 1.1664, Trg MixUp: 1.2125, Src Train Acc: 73.52, Trg Train Acc: 66.58, Src Test Acc: 80.54, Trg Test Acc: 68.92
# Epoch: 008, TotalL: 2.8649, CrossE: 0.6550, CondE: 0.8205, disc: 0.6730, domain: 0.7938, Src VAT: 0.8050, Trg VAT: 0.8205, Src MixUp: 1.1162, Trg MixUp: 1.1747, Src Train Acc: 76.82, Trg Train Acc: 69.05, Src Test Acc: 85.21, Trg Test Acc: 73.42
# Epoch: 009, TotalL: 2.5785, CrossE: 0.5474, CondE: 0.7311, disc: 0.6674, domain: 0.8081, Src VAT: 0.7116, Trg VAT: 0.7311, Src MixUp: 1.0496, Trg MixUp: 1.1043, Src Train Acc: 80.38, Trg Train Acc: 73.52, Src Test Acc: 85.99, Trg Test Acc: 75.47
# Epoch: 010, TotalL: 2.3539, CrossE: 0.4829, CondE: 0.6665, disc: 0.6652, domain: 0.8185, Src VAT: 0.6304, Trg VAT: 0.6665, Src MixUp: 0.9837, Trg MixUp: 1.0606, Src Train Acc: 84.03, Trg Train Acc: 76.35, Src Test Acc: 87.55, Trg Test Acc: 74.88
# Epoch: 011, TotalL: 2.1826, CrossE: 0.4284, CondE: 0.6129, disc: 0.6592, domain: 0.8254, Src VAT: 0.5740, Trg VAT: 0.6129, Src MixUp: 0.9340, Trg MixUp: 1.0268, Src Train Acc: 85.76, Trg Train Acc: 77.47, Src Test Acc: 89.49, Trg Test Acc: 81.26
# Epoch: 012, TotalL: 2.0078, CrossE: 0.3715, CondE: 0.5528, disc: 0.6561, domain: 0.8350, Src VAT: 0.5151, Trg VAT: 0.5528, Src MixUp: 0.8879, Trg MixUp: 0.9752, Src Train Acc: 88.19, Trg Train Acc: 80.38, Src Test Acc: 89.88, Trg Test Acc: 81.84
# Epoch: 013, TotalL: 1.8677, CrossE: 0.3288, CondE: 0.5115, disc: 0.6500, domain: 0.8430, Src VAT: 0.4670, Trg VAT: 0.5115, Src MixUp: 0.8480, Trg MixUp: 0.9324, Src Train Acc: 89.80, Trg Train Acc: 82.16, Src Test Acc: 89.88, Trg Test Acc: 75.76
# Epoch: 014, TotalL: 1.7857, CrossE: 0.2971, CondE: 0.4807, disc: 0.6514, domain: 0.8523, Src VAT: 0.4361, Trg VAT: 0.4807, Src MixUp: 0.8336, Trg MixUp: 0.9224, Src Train Acc: 90.19, Trg Train Acc: 82.34, Src Test Acc: 88.72, Trg Test Acc: 76.02
# Epoch: 015, TotalL: 1.7003, CrossE: 0.2615, CondE: 0.4520, disc: 0.6513, domain: 0.8482, Src VAT: 0.4088, Trg VAT: 0.4520, Src MixUp: 0.8196, Trg MixUp: 0.8787, Src Train Acc: 92.10, Trg Train Acc: 84.42, Src Test Acc: 93.39, Trg Test Acc: 84.88
# Epoch: 016, TotalL: 1.5951, CrossE: 0.2439, CondE: 0.4230, disc: 0.6476, domain: 0.8536, Src VAT: 0.3762, Trg VAT: 0.4230, Src MixUp: 0.7696, Trg MixUp: 0.8678, Src Train Acc: 92.88, Trg Train Acc: 85.20, Src Test Acc: 91.83, Trg Test Acc: 83.83
# Epoch: 017, TotalL: 1.4827, CrossE: 0.2107, CondE: 0.3900, disc: 0.6461, domain: 0.8579, Src VAT: 0.3363, Trg VAT: 0.3900, Src MixUp: 0.7384, Trg MixUp: 0.8292, Src Train Acc: 93.88, Trg Train Acc: 85.85, Src Test Acc: 94.16, Trg Test Acc: 81.20
# Epoch: 018, TotalL: 1.4837, CrossE: 0.2005, CondE: 0.3813, disc: 0.6470, domain: 0.8535, Src VAT: 0.3325, Trg VAT: 0.3813, Src MixUp: 0.7547, Trg MixUp: 0.8345, Src Train Acc: 93.79, Trg Train Acc: 86.37, Src Test Acc: 93.77, Trg Test Acc: 86.35
# Epoch: 019, TotalL: 1.3625, CrossE: 0.1853, CondE: 0.3623, disc: 0.6425, domain: 0.8758, Src VAT: 0.2963, Trg VAT: 0.3623, Src MixUp: 0.6872, Trg MixUp: 0.8198, Src Train Acc: 94.05, Trg Train Acc: 86.28, Src Test Acc: 92.22, Trg Test Acc: 86.96
# Epoch: 020, TotalL: 1.3253, CrossE: 0.1656, CondE: 0.3456, disc: 0.6464, domain: 0.8623, Src VAT: 0.2779, Trg VAT: 0.3456, Src MixUp: 0.6943, Trg MixUp: 0.7897, Src Train Acc: 95.05, Trg Train Acc: 87.67, Src Test Acc: 95.33, Trg Test Acc: 87.60
# Epoch: 021, TotalL: 1.2892, CrossE: 0.1446, CondE: 0.3349, disc: 0.6435, domain: 0.8604, Src VAT: 0.2659, Trg VAT: 0.3349, Src MixUp: 0.6939, Trg MixUp: 0.7794, Src Train Acc: 95.92, Trg Train Acc: 87.33, Src Test Acc: 93.39, Trg Test Acc: 84.21
# Epoch: 022, TotalL: 1.2148, CrossE: 0.1322, CondE: 0.3139, disc: 0.6422, domain: 0.8677, Src VAT: 0.2423, Trg VAT: 0.3139, Src MixUp: 0.6589, Trg MixUp: 0.7726, Src Train Acc: 96.01, Trg Train Acc: 87.72, Src Test Acc: 91.05, Trg Test Acc: 82.72
# Epoch: 023, TotalL: 1.1976, CrossE: 0.1333, CondE: 0.3065, disc: 0.6490, domain: 0.8565, Src VAT: 0.2359, Trg VAT: 0.3065, Src MixUp: 0.6512, Trg MixUp: 0.7443, Src Train Acc: 96.27, Trg Train Acc: 87.89, Src Test Acc: 94.55, Trg Test Acc: 84.91
# Epoch: 024, TotalL: 1.1207, CrossE: 0.1137, CondE: 0.2808, disc: 0.6491, domain: 0.8481, Src VAT: 0.2163, Trg VAT: 0.2808, Src MixUp: 0.6177, Trg MixUp: 0.7524, Src Train Acc: 97.09, Trg Train Acc: 89.89, Src Test Acc: 96.11, Trg Test Acc: 86.14
# Epoch: 025, TotalL: 1.0959, CrossE: 0.1168, CondE: 0.2758, disc: 0.6491, domain: 0.8483, Src VAT: 0.2058, Trg VAT: 0.2758, Src MixUp: 0.6032, Trg MixUp: 0.7261, Src Train Acc: 96.48, Trg Train Acc: 89.71, Src Test Acc: 94.94, Trg Test Acc: 86.14
# Epoch: 026, TotalL: 1.0988, CrossE: 0.1142, CondE: 0.2714, disc: 0.6459, domain: 0.8518, Src VAT: 0.2121, Trg VAT: 0.2714, Src MixUp: 0.6041, Trg MixUp: 0.7111, Src Train Acc: 96.70, Trg Train Acc: 88.63, Src Test Acc: 93.77, Trg Test Acc: 82.28
# Epoch: 027, TotalL: 1.0415, CrossE: 0.0926, CondE: 0.2632, disc: 0.6486, domain: 0.8486, Src VAT: 0.1883, Trg VAT: 0.2632, Src MixUp: 0.5931, Trg MixUp: 0.7188, Src Train Acc: 97.48, Trg Train Acc: 89.76, Src Test Acc: 93.39, Trg Test Acc: 80.35
# Epoch: 028, TotalL: 1.0470, CrossE: 0.1059, CondE: 0.2599, disc: 0.6469, domain: 0.8483, Src VAT: 0.1889, Trg VAT: 0.2599, Src MixUp: 0.5867, Trg MixUp: 0.7003, Src Train Acc: 96.70, Trg Train Acc: 89.32, Src Test Acc: 96.50, Trg Test Acc: 87.11
# Epoch: 029, TotalL: 1.0354, CrossE: 0.0886, CondE: 0.2530, disc: 0.6439, domain: 0.8515, Src VAT: 0.1767, Trg VAT: 0.2530, Src MixUp: 0.6038, Trg MixUp: 0.7209, Src Train Acc: 97.40, Trg Train Acc: 90.45, Src Test Acc: 95.33, Trg Test Acc: 84.80
# Epoch: 030, TotalL: 0.9916, CrossE: 0.0918, CondE: 0.2538, disc: 0.6440, domain: 0.8532, Src VAT: 0.1725, Trg VAT: 0.2538, Src MixUp: 0.5614, Trg MixUp: 0.7129, Src Train Acc: 97.57, Trg Train Acc: 90.49, Src Test Acc: 94.94, Trg Test Acc: 84.33
# Epoch: 031, TotalL: 0.9448, CrossE: 0.0752, CondE: 0.2369, disc: 0.6451, domain: 0.8602, Src VAT: 0.1573, Trg VAT: 0.2369, Src MixUp: 0.5507, Trg MixUp: 0.6870, Src Train Acc: 98.05, Trg Train Acc: 91.15, Src Test Acc: 92.61, Trg Test Acc: 83.07
# Epoch: 032, TotalL: 0.9236, CrossE: 0.0772, CondE: 0.2173, disc: 0.6513, domain: 0.8415, Src VAT: 0.1537, Trg VAT: 0.2173, Src MixUp: 0.5382, Trg MixUp: 0.6547, Src Train Acc: 97.74, Trg Train Acc: 90.80, Src Test Acc: 95.72, Trg Test Acc: 88.13
# Epoch: 033, TotalL: 0.9234, CrossE: 0.0775, CondE: 0.2157, disc: 0.6432, domain: 0.8557, Src VAT: 0.1531, Trg VAT: 0.2157, Src MixUp: 0.5369, Trg MixUp: 0.6605, Src Train Acc: 97.70, Trg Train Acc: 90.62, Src Test Acc: 96.11, Trg Test Acc: 86.67
# Epoch: 034, TotalL: 0.8809, CrossE: 0.0693, CondE: 0.2132, disc: 0.6427, domain: 0.8618, Src VAT: 0.1381, Trg VAT: 0.2132, Src MixUp: 0.5163, Trg MixUp: 0.6756, Src Train Acc: 97.92, Trg Train Acc: 90.84, Src Test Acc: 92.22, Trg Test Acc: 81.02
# Epoch: 035, TotalL: 0.8784, CrossE: 0.0658, CondE: 0.2092, disc: 0.6447, domain: 0.8600, Src VAT: 0.1371, Trg VAT: 0.2092, Src MixUp: 0.5198, Trg MixUp: 0.6665, Src Train Acc: 98.18, Trg Train Acc: 90.89, Src Test Acc: 94.55, Trg Test Acc: 88.80
# Epoch: 036, TotalL: 0.8659, CrossE: 0.0646, CondE: 0.2079, disc: 0.6433, domain: 0.8673, Src VAT: 0.1295, Trg VAT: 0.2079, Src MixUp: 0.5143, Trg MixUp: 0.6866, Src Train Acc: 98.26, Trg Train Acc: 92.27, Src Test Acc: 92.22, Trg Test Acc: 82.63
# Epoch: 037, TotalL: 0.8397, CrossE: 0.0608, CondE: 0.2044, disc: 0.6460, domain: 0.8558, Src VAT: 0.1259, Trg VAT: 0.2044, Src MixUp: 0.5018, Trg MixUp: 0.6248, Src Train Acc: 98.31, Trg Train Acc: 91.58, Src Test Acc: 96.89, Trg Test Acc: 89.80
# Epoch: 038, TotalL: 0.8103, CrossE: 0.0493, CondE: 0.1943, disc: 0.6483, domain: 0.8485, Src VAT: 0.1177, Trg VAT: 0.1943, Src MixUp: 0.4923, Trg MixUp: 0.6503, Src Train Acc: 98.91, Trg Train Acc: 92.75, Src Test Acc: 92.22, Trg Test Acc: 78.51
# Epoch: 039, TotalL: 0.8367, CrossE: 0.0630, CondE: 0.2017, disc: 0.6501, domain: 0.8500, Src VAT: 0.1266, Trg VAT: 0.2017, Src MixUp: 0.4947, Trg MixUp: 0.6522, Src Train Acc: 98.31, Trg Train Acc: 92.36, Src Test Acc: 90.66, Trg Test Acc: 82.60
# Epoch: 040, TotalL: 0.8093, CrossE: 0.0548, CondE: 0.1891, disc: 0.6409, domain: 0.8610, Src VAT: 0.1126, Trg VAT: 0.1891, Src MixUp: 0.4924, Trg MixUp: 0.6306, Src Train Acc: 98.83, Trg Train Acc: 92.40, Src Test Acc: 99.22, Trg Test Acc: 92.49
# Epoch: 041, TotalL: 0.8199, CrossE: 0.0538, CondE: 0.1965, disc: 0.6505, domain: 0.8465, Src VAT: 0.1206, Trg VAT: 0.1965, Src MixUp: 0.4956, Trg MixUp: 0.6341, Src Train Acc: 98.78, Trg Train Acc: 92.23, Src Test Acc: 98.83, Trg Test Acc: 92.54
# Epoch: 042, TotalL: 0.7643, CrossE: 0.0442, CondE: 0.1785, disc: 0.6511, domain: 0.8413, Src VAT: 0.1034, Trg VAT: 0.1785, Src MixUp: 0.4709, Trg MixUp: 0.6244, Src Train Acc: 98.87, Trg Train Acc: 92.80, Src Test Acc: 96.50, Trg Test Acc: 89.88
# Epoch: 043, TotalL: 0.7744, CrossE: 0.0607, CondE: 0.1799, disc: 0.6489, domain: 0.8423, Src VAT: 0.1082, Trg VAT: 0.1799, Src MixUp: 0.4612, Trg MixUp: 0.6011, Src Train Acc: 98.35, Trg Train Acc: 92.53, Src Test Acc: 98.05, Trg Test Acc: 90.99
# Epoch: 044, TotalL: 0.7642, CrossE: 0.0501, CondE: 0.1783, disc: 0.6524, domain: 0.8420, Src VAT: 0.1068, Trg VAT: 0.1783, Src MixUp: 0.4639, Trg MixUp: 0.5937, Src Train Acc: 98.70, Trg Train Acc: 92.71, Src Test Acc: 98.83, Trg Test Acc: 89.27
# Epoch: 045, TotalL: 0.7480, CrossE: 0.0409, CondE: 0.1641, disc: 0.6464, domain: 0.8479, Src VAT: 0.0983, Trg VAT: 0.1641, Src MixUp: 0.4665, Trg MixUp: 0.6027, Src Train Acc: 98.91, Trg Train Acc: 92.84, Src Test Acc: 97.28, Trg Test Acc: 92.75
# Epoch: 046, TotalL: 0.7508, CrossE: 0.0417, CondE: 0.1791, disc: 0.6443, domain: 0.8531, Src VAT: 0.1002, Trg VAT: 0.1791, Src MixUp: 0.4621, Trg MixUp: 0.6244, Src Train Acc: 99.05, Trg Train Acc: 92.62, Src Test Acc: 98.05, Trg Test Acc: 91.81
# Epoch: 047, TotalL: 0.7465, CrossE: 0.0510, CondE: 0.1707, disc: 0.6502, domain: 0.8407, Src VAT: 0.0986, Trg VAT: 0.1707, Src MixUp: 0.4531, Trg MixUp: 0.6157, Src Train Acc: 98.52, Trg Train Acc: 91.58, Src Test Acc: 96.11, Trg Test Acc: 90.41
# Epoch: 048, TotalL: 0.7211, CrossE: 0.0393, CondE: 0.1642, disc: 0.6446, domain: 0.8464, Src VAT: 0.0917, Trg VAT: 0.1642, Src MixUp: 0.4483, Trg MixUp: 0.5960, Src Train Acc: 99.18, Trg Train Acc: 93.19, Src Test Acc: 97.28, Trg Test Acc: 87.51
# Epoch: 049, TotalL: 0.7153, CrossE: 0.0359, CondE: 0.1674, disc: 0.6493, domain: 0.8391, Src VAT: 0.0885, Trg VAT: 0.1674, Src MixUp: 0.4478, Trg MixUp: 0.6151, Src Train Acc: 99.26, Trg Train Acc: 93.23, Src Test Acc: 95.33, Trg Test Acc: 86.84
# Epoch: 050, TotalL: 0.7504, CrossE: 0.0491, CondE: 0.1725, disc: 0.6596, domain: 0.8262, Src VAT: 0.0996, Trg VAT: 0.1725, Src MixUp: 0.4588, Trg MixUp: 0.6151, Src Train Acc: 98.74, Trg Train Acc: 92.32, Src Test Acc: 96.11, Trg Test Acc: 85.91
# Epoch: 051, TotalL: 0.6983, CrossE: 0.0313, CondE: 0.1516, disc: 0.6509, domain: 0.8297, Src VAT: 0.0837, Trg VAT: 0.1516, Src MixUp: 0.4449, Trg MixUp: 0.5984, Src Train Acc: 99.52, Trg Train Acc: 94.05, Src Test Acc: 98.05, Trg Test Acc: 93.04
# Epoch: 052, TotalL: 0.6554, CrossE: 0.0267, CondE: 0.1486, disc: 0.6473, domain: 0.8502, Src VAT: 0.0759, Trg VAT: 0.1486, Src MixUp: 0.4152, Trg MixUp: 0.5725, Src Train Acc: 99.52, Trg Train Acc: 94.36, Src Test Acc: 98.83, Trg Test Acc: 93.01
# Epoch: 053, TotalL: 0.6867, CrossE: 0.0496, CondE: 0.1563, disc: 0.6563, domain: 0.8429, Src VAT: 0.0845, Trg VAT: 0.1563, Src MixUp: 0.4136, Trg MixUp: 0.5812, Src Train Acc: 98.74, Trg Train Acc: 92.75, Src Test Acc: 97.28, Trg Test Acc: 91.78
# Epoch: 054, TotalL: 0.6633, CrossE: 0.0333, CondE: 0.1502, disc: 0.6505, domain: 0.8381, Src VAT: 0.0758, Trg VAT: 0.1502, Src MixUp: 0.4164, Trg MixUp: 0.5844, Src Train Acc: 98.91, Trg Train Acc: 93.71, Src Test Acc: 98.83, Trg Test Acc: 92.22
# Epoch: 055, TotalL: 0.6316, CrossE: 0.0320, CondE: 0.1451, disc: 0.6465, domain: 0.8454, Src VAT: 0.0711, Trg VAT: 0.1451, Src MixUp: 0.3930, Trg MixUp: 0.5572, Src Train Acc: 99.13, Trg Train Acc: 93.32, Src Test Acc: 98.05, Trg Test Acc: 85.26
# Epoch: 056, TotalL: 0.6677, CrossE: 0.0368, CondE: 0.1443, disc: 0.6467, domain: 0.8454, Src VAT: 0.0746, Trg VAT: 0.1443, Src MixUp: 0.4193, Trg MixUp: 0.5784, Src Train Acc: 99.18, Trg Train Acc: 94.18, Src Test Acc: 97.67, Trg Test Acc: 91.17
# Epoch: 057, TotalL: 0.6677, CrossE: 0.0356, CondE: 0.1495, disc: 0.6539, domain: 0.8360, Src VAT: 0.0778, Trg VAT: 0.1495, Src MixUp: 0.4170, Trg MixUp: 0.5823, Src Train Acc: 99.26, Trg Train Acc: 94.40, Src Test Acc: 96.50, Trg Test Acc: 84.77
# Epoch: 058, TotalL: 0.6298, CrossE: 0.0297, CondE: 0.1357, disc: 0.6491, domain: 0.8481, Src VAT: 0.0685, Trg VAT: 0.1357, Src MixUp: 0.3978, Trg MixUp: 0.5546, Src Train Acc: 99.22, Trg Train Acc: 94.49, Src Test Acc: 93.77, Trg Test Acc: 79.59
# Epoch: 059, TotalL: 0.6631, CrossE: 0.0372, CondE: 0.1534, disc: 0.6507, domain: 0.8360, Src VAT: 0.0790, Trg VAT: 0.1534, Src MixUp: 0.4089, Trg MixUp: 0.5823, Src Train Acc: 98.83, Trg Train Acc: 94.01, Src Test Acc: 97.28, Trg Test Acc: 85.38
# Epoch: 060, TotalL: 0.6196, CrossE: 0.0285, CondE: 0.1400, disc: 0.6504, domain: 0.8413, Src VAT: 0.0637, Trg VAT: 0.1400, Src MixUp: 0.3926, Trg MixUp: 0.5643, Src Train Acc: 99.13, Trg Train Acc: 94.44, Src Test Acc: 98.83, Trg Test Acc: 91.52
# Epoch: 061, TotalL: 0.6040, CrossE: 0.0203, CondE: 0.1347, disc: 0.6464, domain: 0.8444, Src VAT: 0.0591, Trg VAT: 0.1347, Src MixUp: 0.3923, Trg MixUp: 0.5414, Src Train Acc: 99.74, Trg Train Acc: 95.18, Src Test Acc: 99.22, Trg Test Acc: 92.49
# Epoch: 062, TotalL: 0.6517, CrossE: 0.0329, CondE: 0.1458, disc: 0.6512, domain: 0.8348, Src VAT: 0.0716, Trg VAT: 0.1458, Src MixUp: 0.4125, Trg MixUp: 0.5573, Src Train Acc: 99.09, Trg Train Acc: 93.40, Src Test Acc: 98.05, Trg Test Acc: 90.29
# Epoch: 063, TotalL: 0.6449, CrossE: 0.0289, CondE: 0.1437, disc: 0.6482, domain: 0.8324, Src VAT: 0.0664, Trg VAT: 0.1437, Src MixUp: 0.4145, Trg MixUp: 0.5691, Src Train Acc: 99.35, Trg Train Acc: 94.31, Src Test Acc: 98.05, Trg Test Acc: 89.44
# Epoch: 064, TotalL: 0.6694, CrossE: 0.0343, CondE: 0.1450, disc: 0.6504, domain: 0.8332, Src VAT: 0.0758, Trg VAT: 0.1450, Src MixUp: 0.4243, Trg MixUp: 0.5645, Src Train Acc: 99.00, Trg Train Acc: 94.62, Src Test Acc: 96.89, Trg Test Acc: 90.58
# Epoch: 065, TotalL: 0.5828, CrossE: 0.0202, CondE: 0.1325, disc: 0.6455, domain: 0.8404, Src VAT: 0.0587, Trg VAT: 0.1325, Src MixUp: 0.3721, Trg MixUp: 0.5421, Src Train Acc: 99.74, Trg Train Acc: 94.66, Src Test Acc: 98.44, Trg Test Acc: 94.24
# Epoch: 066, TotalL: 0.5781, CrossE: 0.0236, CondE: 0.1270, disc: 0.6485, domain: 0.8416, Src VAT: 0.0590, Trg VAT: 0.1270, Src MixUp: 0.3640, Trg MixUp: 0.5491, Src Train Acc: 99.44, Trg Train Acc: 94.62, Src Test Acc: 98.44, Trg Test Acc: 88.16
# Epoch: 067, TotalL: 0.6277, CrossE: 0.0264, CondE: 0.1372, disc: 0.6483, domain: 0.8369, Src VAT: 0.0640, Trg VAT: 0.1372, Src MixUp: 0.4030, Trg MixUp: 0.5676, Src Train Acc: 99.52, Trg Train Acc: 94.40, Src Test Acc: 98.05, Trg Test Acc: 90.94
# Epoch: 068, TotalL: 0.5982, CrossE: 0.0271, CondE: 0.1268, disc: 0.6492, domain: 0.8359, Src VAT: 0.0612, Trg VAT: 0.1268, Src MixUp: 0.3805, Trg MixUp: 0.5278, Src Train Acc: 99.18, Trg Train Acc: 94.01, Src Test Acc: 98.44, Trg Test Acc: 91.87
# Epoch: 069, TotalL: 0.5629, CrossE: 0.0240, CondE: 0.1168, disc: 0.6512, domain: 0.8360, Src VAT: 0.0534, Trg VAT: 0.1168, Src MixUp: 0.3567, Trg MixUp: 0.5392, Src Train Acc: 99.26, Trg Train Acc: 94.53, Src Test Acc: 95.72, Trg Test Acc: 82.57
# Epoch: 070, TotalL: 0.5751, CrossE: 0.0195, CondE: 0.1164, disc: 0.6505, domain: 0.8400, Src VAT: 0.0527, Trg VAT: 0.1164, Src MixUp: 0.3739, Trg MixUp: 0.5398, Src Train Acc: 99.70, Trg Train Acc: 95.18, Src Test Acc: 98.05, Trg Test Acc: 94.04
# Epoch: 071, TotalL: 0.5940, CrossE: 0.0328, CondE: 0.1258, disc: 0.6533, domain: 0.8279, Src VAT: 0.0578, Trg VAT: 0.1258, Src MixUp: 0.3732, Trg MixUp: 0.5482, Src Train Acc: 99.05, Trg Train Acc: 94.23, Src Test Acc: 98.83, Trg Test Acc: 92.75
# Epoch: 072, TotalL: 0.5926, CrossE: 0.0377, CondE: 0.1254, disc: 0.6558, domain: 0.8371, Src VAT: 0.0614, Trg VAT: 0.1254, Src MixUp: 0.3640, Trg MixUp: 0.5310, Src Train Acc: 99.00, Trg Train Acc: 94.66, Src Test Acc: 98.83, Trg Test Acc: 93.39
# Epoch: 073, TotalL: 0.5613, CrossE: 0.0187, CondE: 0.1166, disc: 0.6541, domain: 0.8322, Src VAT: 0.0539, Trg VAT: 0.1166, Src MixUp: 0.3600, Trg MixUp: 0.5430, Src Train Acc: 99.61, Trg Train Acc: 94.62, Src Test Acc: 98.44, Trg Test Acc: 93.16
# Epoch: 074, TotalL: 0.5640, CrossE: 0.0196, CondE: 0.1223, disc: 0.6552, domain: 0.8430, Src VAT: 0.0510, Trg VAT: 0.1223, Src MixUp: 0.3652, Trg MixUp: 0.5163, Src Train Acc: 99.57, Trg Train Acc: 94.66, Src Test Acc: 98.83, Trg Test Acc: 91.08
# Epoch: 075, TotalL: 0.5685, CrossE: 0.0243, CondE: 0.1213, disc: 0.6610, domain: 0.8202, Src VAT: 0.0547, Trg VAT: 0.1213, Src MixUp: 0.3626, Trg MixUp: 0.5232, Src Train Acc: 99.31, Trg Train Acc: 94.84, Src Test Acc: 97.67, Trg Test Acc: 86.43
# Epoch: 076, TotalL: 0.5713, CrossE: 0.0254, CondE: 0.1143, disc: 0.6609, domain: 0.8222, Src VAT: 0.0555, Trg VAT: 0.1143, Src MixUp: 0.3642, Trg MixUp: 0.5266, Src Train Acc: 99.31, Trg Train Acc: 94.84, Src Test Acc: 98.83, Trg Test Acc: 94.50
# Epoch: 077, TotalL: 0.5330, CrossE: 0.0156, CondE: 0.1105, disc: 0.6521, domain: 0.8328, Src VAT: 0.0452, Trg VAT: 0.1105, Src MixUp: 0.3465, Trg MixUp: 0.5174, Src Train Acc: 99.78, Trg Train Acc: 96.18, Src Test Acc: 97.67, Trg Test Acc: 93.60
# Epoch: 078, TotalL: 0.5943, CrossE: 0.0249, CondE: 0.1274, disc: 0.6615, domain: 0.8101, Src VAT: 0.0621, Trg VAT: 0.1274, Src MixUp: 0.3799, Trg MixUp: 0.5270, Src Train Acc: 99.39, Trg Train Acc: 93.88, Src Test Acc: 98.05, Trg Test Acc: 93.30
# Epoch: 079, TotalL: 0.5819, CrossE: 0.0298, CondE: 0.1213, disc: 0.6592, domain: 0.8176, Src VAT: 0.0603, Trg VAT: 0.1213, Src MixUp: 0.3647, Trg MixUp: 0.5285, Src Train Acc: 99.13, Trg Train Acc: 94.66, Src Test Acc: 97.67, Trg Test Acc: 93.74
# Epoch: 080, TotalL: 0.5512, CrossE: 0.0183, CondE: 0.1052, disc: 0.6552, domain: 0.8141, Src VAT: 0.0471, Trg VAT: 0.1052, Src MixUp: 0.3611, Trg MixUp: 0.5346, Src Train Acc: 99.70, Trg Train Acc: 95.66, Src Test Acc: 98.05, Trg Test Acc: 89.82
# Epoch: 081, TotalL: 0.5005, CrossE: 0.0128, CondE: 0.1025, disc: 0.6509, domain: 0.8301, Src VAT: 0.0372, Trg VAT: 0.1025, Src MixUp: 0.3267, Trg MixUp: 0.5113, Src Train Acc: 99.70, Trg Train Acc: 95.40, Src Test Acc: 98.44, Trg Test Acc: 89.77
# Epoch: 082, TotalL: 0.5497, CrossE: 0.0177, CondE: 0.1099, disc: 0.6545, domain: 0.8309, Src VAT: 0.0480, Trg VAT: 0.1099, Src MixUp: 0.3587, Trg MixUp: 0.5157, Src Train Acc: 99.74, Trg Train Acc: 95.36, Src Test Acc: 98.05, Trg Test Acc: 94.71
# Epoch: 083, TotalL: 0.5209, CrossE: 0.0210, CondE: 0.1050, disc: 0.6598, domain: 0.8193, Src VAT: 0.0443, Trg VAT: 0.1050, Src MixUp: 0.3335, Trg MixUp: 0.4979, Src Train Acc: 99.57, Trg Train Acc: 95.44, Src Test Acc: 99.22, Trg Test Acc: 95.82
# Epoch: 084, TotalL: 0.5330, CrossE: 0.0196, CondE: 0.1063, disc: 0.6597, domain: 0.8106, Src VAT: 0.0442, Trg VAT: 0.1063, Src MixUp: 0.3461, Trg MixUp: 0.5164, Src Train Acc: 99.65, Trg Train Acc: 95.01, Src Test Acc: 98.05, Trg Test Acc: 92.31
# Epoch: 085, TotalL: 0.5350, CrossE: 0.0194, CondE: 0.1150, disc: 0.6570, domain: 0.8132, Src VAT: 0.0445, Trg VAT: 0.1150, Src MixUp: 0.3449, Trg MixUp: 0.5336, Src Train Acc: 99.39, Trg Train Acc: 94.40, Src Test Acc: 94.55, Trg Test Acc: 88.80
# Epoch: 086, TotalL: 0.5044, CrossE: 0.0130, CondE: 0.1038, disc: 0.6498, domain: 0.8278, Src VAT: 0.0399, Trg VAT: 0.1038, Src MixUp: 0.3286, Trg MixUp: 0.5005, Src Train Acc: 99.74, Trg Train Acc: 95.49, Src Test Acc: 98.05, Trg Test Acc: 93.60
# Epoch: 087, TotalL: 0.6027, CrossE: 0.0413, CondE: 0.1239, disc: 0.6589, domain: 0.8187, Src VAT: 0.0603, Trg VAT: 0.1239, Src MixUp: 0.3742, Trg MixUp: 0.5211, Src Train Acc: 98.65, Trg Train Acc: 94.49, Src Test Acc: 98.44, Trg Test Acc: 90.67
# Epoch: 088, TotalL: 0.5165, CrossE: 0.0164, CondE: 0.0970, disc: 0.6590, domain: 0.8089, Src VAT: 0.0401, Trg VAT: 0.0970, Src MixUp: 0.3372, Trg MixUp: 0.5322, Src Train Acc: 99.70, Trg Train Acc: 96.05, Src Test Acc: 98.05, Trg Test Acc: 92.75
# Epoch: 089, TotalL: 0.5353, CrossE: 0.0231, CondE: 0.1103, disc: 0.6618, domain: 0.8044, Src VAT: 0.0460, Trg VAT: 0.1103, Src MixUp: 0.3441, Trg MixUp: 0.5001, Src Train Acc: 99.39, Trg Train Acc: 94.79, Src Test Acc: 96.89, Trg Test Acc: 91.64
# Epoch: 090, TotalL: 0.5132, CrossE: 0.0181, CondE: 0.0940, disc: 0.6540, domain: 0.8159, Src VAT: 0.0402, Trg VAT: 0.0940, Src MixUp: 0.3335, Trg MixUp: 0.5132, Src Train Acc: 99.57, Trg Train Acc: 96.40, Src Test Acc: 98.83, Trg Test Acc: 95.00
# Epoch: 091, TotalL: 0.5145, CrossE: 0.0165, CondE: 0.1013, disc: 0.6572, domain: 0.8149, Src VAT: 0.0416, Trg VAT: 0.1013, Src MixUp: 0.3352, Trg MixUp: 0.4962, Src Train Acc: 99.52, Trg Train Acc: 96.27, Src Test Acc: 96.11, Trg Test Acc: 91.05
# Epoch: 092, TotalL: 0.4775, CrossE: 0.0131, CondE: 0.0904, disc: 0.6537, domain: 0.8245, Src VAT: 0.0356, Trg VAT: 0.0904, Src MixUp: 0.3091, Trg MixUp: 0.4917, Src Train Acc: 99.83, Trg Train Acc: 96.05, Src Test Acc: 99.22, Trg Test Acc: 95.50
# Epoch: 093, TotalL: 0.4877, CrossE: 0.0149, CondE: 0.0971, disc: 0.6563, domain: 0.8247, Src VAT: 0.0365, Trg VAT: 0.0971, Src MixUp: 0.3150, Trg MixUp: 0.4975, Src Train Acc: 99.52, Trg Train Acc: 96.35, Src Test Acc: 97.67, Trg Test Acc: 82.72
# Epoch: 094, TotalL: 0.5157, CrossE: 0.0172, CondE: 0.1021, disc: 0.6580, domain: 0.8048, Src VAT: 0.0429, Trg VAT: 0.1021, Src MixUp: 0.3338, Trg MixUp: 0.5121, Src Train Acc: 99.48, Trg Train Acc: 95.79, Src Test Acc: 98.05, Trg Test Acc: 93.39
# Epoch: 095, TotalL: 0.4782, CrossE: 0.0115, CondE: 0.0903, disc: 0.6581, domain: 0.8146, Src VAT: 0.0377, Trg VAT: 0.0903, Src MixUp: 0.3107, Trg MixUp: 0.4838, Src Train Acc: 99.83, Trg Train Acc: 95.83, Src Test Acc: 98.83, Trg Test Acc: 92.11
# Epoch: 096, TotalL: 0.5127, CrossE: 0.0147, CondE: 0.1063, disc: 0.6568, domain: 0.8254, Src VAT: 0.0420, Trg VAT: 0.1063, Src MixUp: 0.3330, Trg MixUp: 0.4978, Src Train Acc: 99.78, Trg Train Acc: 95.49, Src Test Acc: 98.44, Trg Test Acc: 92.81
# Epoch: 097, TotalL: 0.4702, CrossE: 0.0085, CondE: 0.0883, disc: 0.6551, domain: 0.8283, Src VAT: 0.0289, Trg VAT: 0.0883, Src MixUp: 0.3127, Trg MixUp: 0.4957, Src Train Acc: 99.91, Trg Train Acc: 96.53, Src Test Acc: 94.16, Trg Test Acc: 87.25
# Epoch: 098, TotalL: 0.5134, CrossE: 0.0178, CondE: 0.0964, disc: 0.6542, domain: 0.8340, Src VAT: 0.0431, Trg VAT: 0.0964, Src MixUp: 0.3311, Trg MixUp: 0.4913, Src Train Acc: 99.52, Trg Train Acc: 95.57, Src Test Acc: 96.50, Trg Test Acc: 86.20
# Epoch: 099, TotalL: 0.4913, CrossE: 0.0113, CondE: 0.0962, disc: 0.6583, domain: 0.8121, Src VAT: 0.0353, Trg VAT: 0.0962, Src MixUp: 0.3254, Trg MixUp: 0.4866, Src Train Acc: 99.78, Trg Train Acc: 95.27, Src Test Acc: 99.22, Trg Test Acc: 96.11
# Epoch: 100, TotalL: 0.5124, CrossE: 0.0185, CondE: 0.0966, disc: 0.6593, domain: 0.8098, Src VAT: 0.0434, Trg VAT: 0.0966, Src MixUp: 0.3321, Trg MixUp: 0.4790, Src Train Acc: 99.65, Trg Train Acc: 94.66, Src Test Acc: 98.83, Trg Test Acc: 94.30
# Epoch: 101, TotalL: 0.4613, CrossE: 0.0098, CondE: 0.0857, disc: 0.6568, domain: 0.8201, Src VAT: 0.0317, Trg VAT: 0.0857, Src MixUp: 0.3021, Trg MixUp: 0.4793, Src Train Acc: 99.83, Trg Train Acc: 95.83, Src Test Acc: 95.72, Trg Test Acc: 90.09
# Epoch: 102, TotalL: 0.5026, CrossE: 0.0222, CondE: 0.0976, disc: 0.6612, domain: 0.8181, Src VAT: 0.0420, Trg VAT: 0.0976, Src MixUp: 0.3183, Trg MixUp: 0.4879, Src Train Acc: 99.26, Trg Train Acc: 95.14, Src Test Acc: 99.22, Trg Test Acc: 95.50
# Epoch: 103, TotalL: 0.4862, CrossE: 0.0187, CondE: 0.0969, disc: 0.6630, domain: 0.8101, Src VAT: 0.0399, Trg VAT: 0.0969, Src MixUp: 0.3075, Trg MixUp: 0.4958, Src Train Acc: 99.57, Trg Train Acc: 94.92, Src Test Acc: 98.83, Trg Test Acc: 92.22
# Epoch: 104, TotalL: 0.4729, CrossE: 0.0120, CondE: 0.0920, disc: 0.6566, domain: 0.8199, Src VAT: 0.0358, Trg VAT: 0.0920, Src MixUp: 0.3071, Trg MixUp: 0.4715, Src Train Acc: 99.74, Trg Train Acc: 96.01, Src Test Acc: 98.44, Trg Test Acc: 94.65
# Epoch: 105, TotalL: 0.4719, CrossE: 0.0169, CondE: 0.0935, disc: 0.6617, domain: 0.8179, Src VAT: 0.0368, Trg VAT: 0.0935, Src MixUp: 0.3005, Trg MixUp: 0.4665, Src Train Acc: 99.48, Trg Train Acc: 95.75, Src Test Acc: 97.67, Trg Test Acc: 93.86
# Epoch: 106, TotalL: 0.4507, CrossE: 0.0099, CondE: 0.0822, disc: 0.6654, domain: 0.7984, Src VAT: 0.0306, Trg VAT: 0.0822, Src MixUp: 0.2940, Trg MixUp: 0.4906, Src Train Acc: 99.83, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 94.04
# Epoch: 107, TotalL: 0.4773, CrossE: 0.0190, CondE: 0.0952, disc: 0.6686, domain: 0.7935, Src VAT: 0.0373, Trg VAT: 0.0952, Src MixUp: 0.3029, Trg MixUp: 0.4924, Src Train Acc: 99.35, Trg Train Acc: 95.10, Src Test Acc: 98.44, Trg Test Acc: 94.56
# Epoch: 108, TotalL: 0.4377, CrossE: 0.0115, CondE: 0.0731, disc: 0.6646, domain: 0.7987, Src VAT: 0.0286, Trg VAT: 0.0731, Src MixUp: 0.2857, Trg MixUp: 0.4539, Src Train Acc: 99.61, Trg Train Acc: 96.40, Src Test Acc: 97.28, Trg Test Acc: 89.33
# Epoch: 109, TotalL: 0.4821, CrossE: 0.0184, CondE: 0.0985, disc: 0.6662, domain: 0.7873, Src VAT: 0.0391, Trg VAT: 0.0985, Src MixUp: 0.3048, Trg MixUp: 0.5126, Src Train Acc: 99.48, Trg Train Acc: 94.70, Src Test Acc: 94.16, Trg Test Acc: 80.64
# Epoch: 110, TotalL: 0.4739, CrossE: 0.0138, CondE: 0.0830, disc: 0.6637, domain: 0.7920, Src VAT: 0.0347, Trg VAT: 0.0830, Src MixUp: 0.3106, Trg MixUp: 0.4778, Src Train Acc: 99.61, Trg Train Acc: 95.79, Src Test Acc: 98.44, Trg Test Acc: 95.64
# Epoch: 111, TotalL: 0.4184, CrossE: 0.0098, CondE: 0.0683, disc: 0.6578, domain: 0.8074, Src VAT: 0.0239, Trg VAT: 0.0683, Src MixUp: 0.2733, Trg MixUp: 0.4491, Src Train Acc: 99.78, Trg Train Acc: 96.74, Src Test Acc: 98.44, Trg Test Acc: 92.31
# Epoch: 112, TotalL: 0.4518, CrossE: 0.0090, CondE: 0.0820, disc: 0.6640, domain: 0.8013, Src VAT: 0.0279, Trg VAT: 0.0820, Src MixUp: 0.3004, Trg MixUp: 0.4664, Src Train Acc: 99.83, Trg Train Acc: 96.18, Src Test Acc: 98.44, Trg Test Acc: 95.20
# Epoch: 113, TotalL: 0.4381, CrossE: 0.0095, CondE: 0.0771, disc: 0.6657, domain: 0.7913, Src VAT: 0.0272, Trg VAT: 0.0771, Src MixUp: 0.2882, Trg MixUp: 0.4705, Src Train Acc: 99.83, Trg Train Acc: 96.48, Src Test Acc: 98.44, Trg Test Acc: 95.44
# Epoch: 114, TotalL: 0.4498, CrossE: 0.0116, CondE: 0.0769, disc: 0.6634, domain: 0.7963, Src VAT: 0.0294, Trg VAT: 0.0769, Src MixUp: 0.2948, Trg MixUp: 0.4750, Src Train Acc: 99.83, Trg Train Acc: 96.48, Src Test Acc: 99.61, Trg Test Acc: 95.79
# Epoch: 115, TotalL: 0.4086, CrossE: 0.0047, CondE: 0.0664, disc: 0.6592, domain: 0.7999, Src VAT: 0.0204, Trg VAT: 0.0664, Src MixUp: 0.2721, Trg MixUp: 0.4612, Src Train Acc: 100.00, Trg Train Acc: 96.74, Src Test Acc: 99.61, Trg Test Acc: 95.67
# Epoch: 116, TotalL: 0.4255, CrossE: 0.0133, CondE: 0.0829, disc: 0.6599, domain: 0.8141, Src VAT: 0.0308, Trg VAT: 0.0829, Src MixUp: 0.2663, Trg MixUp: 0.4607, Src Train Acc: 99.65, Trg Train Acc: 95.88, Src Test Acc: 98.44, Trg Test Acc: 93.04
# Epoch: 117, TotalL: 0.4688, CrossE: 0.0113, CondE: 0.0796, disc: 0.6610, domain: 0.7988, Src VAT: 0.0330, Trg VAT: 0.0796, Src MixUp: 0.3090, Trg MixUp: 0.4855, Src Train Acc: 99.91, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 95.82
# Epoch: 118, TotalL: 0.4464, CrossE: 0.0123, CondE: 0.0796, disc: 0.6648, domain: 0.7986, Src VAT: 0.0283, Trg VAT: 0.0796, Src MixUp: 0.2906, Trg MixUp: 0.4810, Src Train Acc: 99.70, Trg Train Acc: 95.83, Src Test Acc: 96.89, Trg Test Acc: 93.10
# Epoch: 119, TotalL: 0.4714, CrossE: 0.0125, CondE: 0.0818, disc: 0.6677, domain: 0.7911, Src VAT: 0.0330, Trg VAT: 0.0818, Src MixUp: 0.3115, Trg MixUp: 0.4755, Src Train Acc: 99.70, Trg Train Acc: 95.75, Src Test Acc: 98.83, Trg Test Acc: 96.64
# Epoch: 120, TotalL: 0.4598, CrossE: 0.0137, CondE: 0.0848, disc: 0.6648, domain: 0.7952, Src VAT: 0.0338, Trg VAT: 0.0848, Src MixUp: 0.2981, Trg MixUp: 0.4625, Src Train Acc: 99.70, Trg Train Acc: 96.31, Src Test Acc: 98.83, Trg Test Acc: 93.74
# Epoch: 121, TotalL: 0.4347, CrossE: 0.0146, CondE: 0.0763, disc: 0.6640, domain: 0.7922, Src VAT: 0.0296, Trg VAT: 0.0763, Src MixUp: 0.2776, Trg MixUp: 0.4671, Src Train Acc: 99.70, Trg Train Acc: 96.18, Src Test Acc: 98.83, Trg Test Acc: 93.01
# Epoch: 122, TotalL: 0.4269, CrossE: 0.0108, CondE: 0.0721, disc: 0.6628, domain: 0.7950, Src VAT: 0.0262, Trg VAT: 0.0721, Src MixUp: 0.2787, Trg MixUp: 0.4503, Src Train Acc: 99.70, Trg Train Acc: 96.88, Src Test Acc: 99.22, Trg Test Acc: 90.47
# Epoch: 123, TotalL: 0.4536, CrossE: 0.0169, CondE: 0.0738, disc: 0.6647, domain: 0.7937, Src VAT: 0.0307, Trg VAT: 0.0738, Src MixUp: 0.2941, Trg MixUp: 0.4575, Src Train Acc: 99.61, Trg Train Acc: 96.44, Src Test Acc: 99.61, Trg Test Acc: 94.30
# Epoch: 124, TotalL: 0.4065, CrossE: 0.0053, CondE: 0.0663, disc: 0.6644, domain: 0.7910, Src VAT: 0.0205, Trg VAT: 0.0663, Src MixUp: 0.2703, Trg MixUp: 0.4566, Src Train Acc: 99.96, Trg Train Acc: 97.01, Src Test Acc: 97.67, Trg Test Acc: 89.71
# Epoch: 125, TotalL: 0.4497, CrossE: 0.0123, CondE: 0.0747, disc: 0.6668, domain: 0.7887, Src VAT: 0.0305, Trg VAT: 0.0747, Src MixUp: 0.2953, Trg MixUp: 0.4562, Src Train Acc: 99.78, Trg Train Acc: 96.31, Src Test Acc: 98.44, Trg Test Acc: 94.68
# Epoch: 126, TotalL: 0.4638, CrossE: 0.0147, CondE: 0.0807, disc: 0.6668, domain: 0.7947, Src VAT: 0.0334, Trg VAT: 0.0807, Src MixUp: 0.3004, Trg MixUp: 0.4838, Src Train Acc: 99.65, Trg Train Acc: 95.57, Src Test Acc: 98.44, Trg Test Acc: 94.18
# Epoch: 127, TotalL: 0.4273, CrossE: 0.0091, CondE: 0.0689, disc: 0.6633, domain: 0.7947, Src VAT: 0.0225, Trg VAT: 0.0689, Src MixUp: 0.2853, Trg MixUp: 0.4475, Src Train Acc: 99.87, Trg Train Acc: 96.83, Src Test Acc: 98.83, Trg Test Acc: 90.44
# Epoch: 128, TotalL: 0.4442, CrossE: 0.0119, CondE: 0.0695, disc: 0.6676, domain: 0.7882, Src VAT: 0.0304, Trg VAT: 0.0695, Src MixUp: 0.2906, Trg MixUp: 0.4636, Src Train Acc: 99.74, Trg Train Acc: 96.31, Src Test Acc: 99.22, Trg Test Acc: 96.23
# Epoch: 129, TotalL: 0.3907, CrossE: 0.0098, CondE: 0.0617, disc: 0.6606, domain: 0.7972, Src VAT: 0.0176, Trg VAT: 0.0617, Src MixUp: 0.2549, Trg MixUp: 0.4342, Src Train Acc: 99.74, Trg Train Acc: 96.40, Src Test Acc: 99.22, Trg Test Acc: 96.40
# Epoch: 130, TotalL: 0.4028, CrossE: 0.0047, CondE: 0.0611, disc: 0.6630, domain: 0.7902, Src VAT: 0.0194, Trg VAT: 0.0611, Src MixUp: 0.2716, Trg MixUp: 0.4269, Src Train Acc: 100.00, Trg Train Acc: 96.83, Src Test Acc: 96.89, Trg Test Acc: 89.68
# Epoch: 131, TotalL: 0.4393, CrossE: 0.0125, CondE: 0.0825, disc: 0.6661, domain: 0.7916, Src VAT: 0.0304, Trg VAT: 0.0825, Src MixUp: 0.2832, Trg MixUp: 0.4576, Src Train Acc: 99.65, Trg Train Acc: 96.09, Src Test Acc: 99.22, Trg Test Acc: 94.88
# Epoch: 132, TotalL: 0.4212, CrossE: 0.0111, CondE: 0.0762, disc: 0.6703, domain: 0.7799, Src VAT: 0.0277, Trg VAT: 0.0762, Src MixUp: 0.2714, Trg MixUp: 0.4539, Src Train Acc: 99.70, Trg Train Acc: 95.92, Src Test Acc: 99.22, Trg Test Acc: 96.20
# Epoch: 133, TotalL: 0.3941, CrossE: 0.0071, CondE: 0.0653, disc: 0.6685, domain: 0.7821, Src VAT: 0.0208, Trg VAT: 0.0653, Src MixUp: 0.2583, Trg MixUp: 0.4370, Src Train Acc: 99.78, Trg Train Acc: 97.14, Src Test Acc: 97.28, Trg Test Acc: 93.74
# Epoch: 134, TotalL: 0.4794, CrossE: 0.0391, CondE: 0.0842, disc: 0.6722, domain: 0.7801, Src VAT: 0.0372, Trg VAT: 0.0842, Src MixUp: 0.2910, Trg MixUp: 0.4534, Src Train Acc: 99.22, Trg Train Acc: 95.79, Src Test Acc: 99.22, Trg Test Acc: 94.15
# Epoch: 135, TotalL: 0.3698, CrossE: 0.0050, CondE: 0.0602, disc: 0.6596, domain: 0.7910, Src VAT: 0.0171, Trg VAT: 0.0602, Src MixUp: 0.2415, Trg MixUp: 0.4168, Src Train Acc: 99.91, Trg Train Acc: 97.01, Src Test Acc: 98.83, Trg Test Acc: 96.26
# Epoch: 136, TotalL: 0.4291, CrossE: 0.0134, CondE: 0.0725, disc: 0.6659, domain: 0.7886, Src VAT: 0.0294, Trg VAT: 0.0725, Src MixUp: 0.2754, Trg MixUp: 0.4521, Src Train Acc: 99.70, Trg Train Acc: 96.61, Src Test Acc: 98.83, Trg Test Acc: 93.83
# Epoch: 137, TotalL: 0.3827, CrossE: 0.0040, CondE: 0.0528, disc: 0.6602, domain: 0.7912, Src VAT: 0.0170, Trg VAT: 0.0528, Src MixUp: 0.2553, Trg MixUp: 0.4325, Src Train Acc: 99.96, Trg Train Acc: 98.00, Src Test Acc: 99.22, Trg Test Acc: 94.53
# Epoch: 138, TotalL: 0.4512, CrossE: 0.0255, CondE: 0.0846, disc: 0.6658, domain: 0.7885, Src VAT: 0.0310, Trg VAT: 0.0846, Src MixUp: 0.2806, Trg MixUp: 0.4687, Src Train Acc: 99.39, Trg Train Acc: 96.92, Src Test Acc: 99.22, Trg Test Acc: 93.77
# Epoch: 139, TotalL: 0.3957, CrossE: 0.0052, CondE: 0.0590, disc: 0.6625, domain: 0.7898, Src VAT: 0.0206, Trg VAT: 0.0590, Src MixUp: 0.2630, Trg MixUp: 0.4290, Src Train Acc: 100.00, Trg Train Acc: 97.22, Src Test Acc: 100.00, Trg Test Acc: 94.15
# Epoch: 140, TotalL: 0.3891, CrossE: 0.0056, CondE: 0.0565, disc: 0.6653, domain: 0.7892, Src VAT: 0.0187, Trg VAT: 0.0565, Src MixUp: 0.2572, Trg MixUp: 0.4429, Src Train Acc: 99.96, Trg Train Acc: 97.31, Src Test Acc: 99.61, Trg Test Acc: 96.43
# Epoch: 141, TotalL: 0.4028, CrossE: 0.0136, CondE: 0.0576, disc: 0.6617, domain: 0.7967, Src VAT: 0.0224, Trg VAT: 0.0576, Src MixUp: 0.2593, Trg MixUp: 0.4317, Src Train Acc: 99.74, Trg Train Acc: 97.05, Src Test Acc: 98.44, Trg Test Acc: 93.13
# Epoch: 142, TotalL: 0.4065, CrossE: 0.0115, CondE: 0.0727, disc: 0.6662, domain: 0.7905, Src VAT: 0.0266, Trg VAT: 0.0727, Src MixUp: 0.2568, Trg MixUp: 0.4588, Src Train Acc: 99.83, Trg Train Acc: 95.92, Src Test Acc: 98.83, Trg Test Acc: 92.66
# Epoch: 143, TotalL: 0.3776, CrossE: 0.0078, CondE: 0.0580, disc: 0.6675, domain: 0.7913, Src VAT: 0.0189, Trg VAT: 0.0580, Src MixUp: 0.2461, Trg MixUp: 0.4034, Src Train Acc: 99.78, Trg Train Acc: 96.92, Src Test Acc: 97.67, Trg Test Acc: 87.54
# Epoch: 144, TotalL: 0.4115, CrossE: 0.0106, CondE: 0.0673, disc: 0.6651, domain: 0.7853, Src VAT: 0.0244, Trg VAT: 0.0673, Src MixUp: 0.2681, Trg MixUp: 0.4372, Src Train Acc: 99.78, Trg Train Acc: 96.70, Src Test Acc: 98.44, Trg Test Acc: 89.27
# Epoch: 145, TotalL: 0.4485, CrossE: 0.0131, CondE: 0.0714, disc: 0.6684, domain: 0.7834, Src VAT: 0.0315, Trg VAT: 0.0714, Src MixUp: 0.2937, Trg MixUp: 0.4520, Src Train Acc: 99.65, Trg Train Acc: 96.27, Src Test Acc: 97.67, Trg Test Acc: 92.98
# Epoch: 146, TotalL: 0.3786, CrossE: 0.0073, CondE: 0.0551, disc: 0.6667, domain: 0.7835, Src VAT: 0.0201, Trg VAT: 0.0551, Src MixUp: 0.2445, Trg MixUp: 0.4406, Src Train Acc: 99.74, Trg Train Acc: 97.05, Src Test Acc: 99.22, Trg Test Acc: 94.77
# Epoch: 147, TotalL: 0.3808, CrossE: 0.0066, CondE: 0.0568, disc: 0.6684, domain: 0.7828, Src VAT: 0.0188, Trg VAT: 0.0568, Src MixUp: 0.2498, Trg MixUp: 0.4232, Src Train Acc: 99.83, Trg Train Acc: 97.14, Src Test Acc: 99.22, Trg Test Acc: 94.24
# Epoch: 148, TotalL: 0.3928, CrossE: 0.0085, CondE: 0.0566, disc: 0.6685, domain: 0.7803, Src VAT: 0.0218, Trg VAT: 0.0566, Src MixUp: 0.2586, Trg MixUp: 0.4057, Src Train Acc: 99.70, Trg Train Acc: 97.44, Src Test Acc: 99.22, Trg Test Acc: 94.42
# Epoch: 149, TotalL: 0.4533, CrossE: 0.0233, CondE: 0.0701, disc: 0.6678, domain: 0.7777, Src VAT: 0.0326, Trg VAT: 0.0701, Src MixUp: 0.2872, Trg MixUp: 0.4586, Src Train Acc: 99.35, Trg Train Acc: 96.66, Src Test Acc: 99.22, Trg Test Acc: 95.32
# Epoch: 150, TotalL: 0.4351, CrossE: 0.0093, CondE: 0.0686, disc: 0.6695, domain: 0.7821, Src VAT: 0.0260, Trg VAT: 0.0686, Src MixUp: 0.2912, Trg MixUp: 0.4373, Src Train Acc: 99.83, Trg Train Acc: 96.61, Src Test Acc: 98.44, Trg Test Acc: 91.23
# Epoch: 151, TotalL: 0.3634, CrossE: 0.0043, CondE: 0.0515, disc: 0.6670, domain: 0.7805, Src VAT: 0.0171, Trg VAT: 0.0515, Src MixUp: 0.2361, Trg MixUp: 0.4406, Src Train Acc: 100.00, Trg Train Acc: 97.57, Src Test Acc: 99.61, Trg Test Acc: 92.19
# Epoch: 152, TotalL: 0.4060, CrossE: 0.0070, CondE: 0.0610, disc: 0.6675, domain: 0.7782, Src VAT: 0.0226, Trg VAT: 0.0610, Src MixUp: 0.2707, Trg MixUp: 0.4215, Src Train Acc: 99.78, Trg Train Acc: 97.01, Src Test Acc: 98.44, Trg Test Acc: 93.63
# Epoch: 153, TotalL: 0.4187, CrossE: 0.0145, CondE: 0.0553, disc: 0.6703, domain: 0.7777, Src VAT: 0.0239, Trg VAT: 0.0553, Src MixUp: 0.2730, Trg MixUp: 0.4527, Src Train Acc: 99.57, Trg Train Acc: 97.35, Src Test Acc: 98.44, Trg Test Acc: 94.62
# Epoch: 154, TotalL: 0.3682, CrossE: 0.0035, CondE: 0.0506, disc: 0.6690, domain: 0.7749, Src VAT: 0.0147, Trg VAT: 0.0506, Src MixUp: 0.2478, Trg MixUp: 0.4024, Src Train Acc: 99.96, Trg Train Acc: 97.79, Src Test Acc: 98.83, Trg Test Acc: 92.02
# Epoch: 155, TotalL: 0.3910, CrossE: 0.0075, CondE: 0.0571, disc: 0.6695, domain: 0.7744, Src VAT: 0.0227, Trg VAT: 0.0571, Src MixUp: 0.2544, Trg MixUp: 0.4409, Src Train Acc: 99.78, Trg Train Acc: 97.31, Src Test Acc: 97.28, Trg Test Acc: 94.82
# Epoch: 156, TotalL: 0.3629, CrossE: 0.0033, CondE: 0.0476, disc: 0.6666, domain: 0.7812, Src VAT: 0.0131, Trg VAT: 0.0476, Src MixUp: 0.2433, Trg MixUp: 0.4129, Src Train Acc: 99.96, Trg Train Acc: 97.66, Src Test Acc: 99.61, Trg Test Acc: 97.11
# Epoch: 157, TotalL: 0.4161, CrossE: 0.0219, CondE: 0.0591, disc: 0.6688, domain: 0.7802, Src VAT: 0.0214, Trg VAT: 0.0591, Src MixUp: 0.2659, Trg MixUp: 0.4371, Src Train Acc: 99.70, Trg Train Acc: 97.09, Src Test Acc: 98.05, Trg Test Acc: 94.09
# Epoch: 158, TotalL: 0.3934, CrossE: 0.0085, CondE: 0.0544, disc: 0.6707, domain: 0.7774, Src VAT: 0.0225, Trg VAT: 0.0544, Src MixUp: 0.2564, Trg MixUp: 0.4403, Src Train Acc: 99.83, Trg Train Acc: 97.27, Src Test Acc: 98.83, Trg Test Acc: 93.25
# Epoch: 159, TotalL: 0.4114, CrossE: 0.0105, CondE: 0.0583, disc: 0.6716, domain: 0.7701, Src VAT: 0.0241, Trg VAT: 0.0583, Src MixUp: 0.2726, Trg MixUp: 0.4169, Src Train Acc: 99.65, Trg Train Acc: 97.18, Src Test Acc: 98.83, Trg Test Acc: 92.49
# Epoch: 160, TotalL: 0.3583, CrossE: 0.0056, CondE: 0.0439, disc: 0.6658, domain: 0.7776, Src VAT: 0.0169, Trg VAT: 0.0439, Src MixUp: 0.2339, Trg MixUp: 0.4091, Src Train Acc: 99.91, Trg Train Acc: 98.00, Src Test Acc: 99.22, Trg Test Acc: 94.44
# Epoch: 161, TotalL: 0.3900, CrossE: 0.0116, CondE: 0.0580, disc: 0.6708, domain: 0.7715, Src VAT: 0.0222, Trg VAT: 0.0580, Src MixUp: 0.2516, Trg MixUp: 0.4208, Src Train Acc: 99.65, Trg Train Acc: 97.61, Src Test Acc: 98.44, Trg Test Acc: 94.33
# Epoch: 162, TotalL: 0.3998, CrossE: 0.0113, CondE: 0.0540, disc: 0.6747, domain: 0.7697, Src VAT: 0.0206, Trg VAT: 0.0540, Src MixUp: 0.2628, Trg MixUp: 0.4364, Src Train Acc: 99.78, Trg Train Acc: 97.05, Src Test Acc: 99.61, Trg Test Acc: 95.85
# Epoch: 163, TotalL: 0.3816, CrossE: 0.0107, CondE: 0.0539, disc: 0.6709, domain: 0.7716, Src VAT: 0.0197, Trg VAT: 0.0539, Src MixUp: 0.2473, Trg MixUp: 0.4191, Src Train Acc: 99.70, Trg Train Acc: 97.09, Src Test Acc: 98.05, Trg Test Acc: 95.06
# Epoch: 164, TotalL: 0.3904, CrossE: 0.0100, CondE: 0.0562, disc: 0.6734, domain: 0.7646, Src VAT: 0.0213, Trg VAT: 0.0562, Src MixUp: 0.2561, Trg MixUp: 0.4115, Src Train Acc: 99.78, Trg Train Acc: 97.09, Src Test Acc: 99.22, Trg Test Acc: 94.04
# Epoch: 165, TotalL: 0.3748, CrossE: 0.0071, CondE: 0.0534, disc: 0.6713, domain: 0.7665, Src VAT: 0.0201, Trg VAT: 0.0534, Src MixUp: 0.2437, Trg MixUp: 0.4255, Src Train Acc: 99.87, Trg Train Acc: 97.05, Src Test Acc: 98.44, Trg Test Acc: 90.85
# Epoch: 166, TotalL: 0.3819, CrossE: 0.0102, CondE: 0.0506, disc: 0.6666, domain: 0.7800, Src VAT: 0.0191, Trg VAT: 0.0506, Src MixUp: 0.2495, Trg MixUp: 0.4076, Src Train Acc: 99.65, Trg Train Acc: 97.74, Src Test Acc: 99.61, Trg Test Acc: 93.63
# Epoch: 167, TotalL: 0.3809, CrossE: 0.0097, CondE: 0.0570, disc: 0.6706, domain: 0.7706, Src VAT: 0.0218, Trg VAT: 0.0570, Src MixUp: 0.2443, Trg MixUp: 0.4299, Src Train Acc: 99.74, Trg Train Acc: 97.18, Src Test Acc: 98.05, Trg Test Acc: 94.04
# Epoch: 168, TotalL: 0.3694, CrossE: 0.0086, CondE: 0.0515, disc: 0.6675, domain: 0.7712, Src VAT: 0.0190, Trg VAT: 0.0515, Src MixUp: 0.2384, Trg MixUp: 0.4182, Src Train Acc: 99.78, Trg Train Acc: 97.74, Src Test Acc: 98.44, Trg Test Acc: 94.47
# Epoch: 169, TotalL: 0.3716, CrossE: 0.0078, CondE: 0.0495, disc: 0.6673, domain: 0.7783, Src VAT: 0.0177, Trg VAT: 0.0495, Src MixUp: 0.2425, Trg MixUp: 0.4175, Src Train Acc: 99.83, Trg Train Acc: 97.40, Src Test Acc: 98.83, Trg Test Acc: 93.74
# Epoch: 170, TotalL: 0.3551, CrossE: 0.0035, CondE: 0.0471, disc: 0.6683, domain: 0.7766, Src VAT: 0.0141, Trg VAT: 0.0471, Src MixUp: 0.2353, Trg MixUp: 0.4073, Src Train Acc: 100.00, Trg Train Acc: 97.53, Src Test Acc: 99.61, Trg Test Acc: 95.53
# Epoch: 171, TotalL: 0.4475, CrossE: 0.0214, CondE: 0.0724, disc: 0.6749, domain: 0.7715, Src VAT: 0.0299, Trg VAT: 0.0724, Src MixUp: 0.2861, Trg MixUp: 0.4605, Src Train Acc: 99.26, Trg Train Acc: 96.88, Src Test Acc: 99.61, Trg Test Acc: 93.71
# Epoch: 172, TotalL: 0.3845, CrossE: 0.0072, CondE: 0.0530, disc: 0.6724, domain: 0.7620, Src VAT: 0.0187, Trg VAT: 0.0530, Src MixUp: 0.2559, Trg MixUp: 0.4156, Src Train Acc: 99.78, Trg Train Acc: 97.14, Src Test Acc: 98.83, Trg Test Acc: 94.09
# Epoch: 173, TotalL: 0.3702, CrossE: 0.0065, CondE: 0.0535, disc: 0.6665, domain: 0.7782, Src VAT: 0.0171, Trg VAT: 0.0535, Src MixUp: 0.2412, Trg MixUp: 0.4318, Src Train Acc: 99.87, Trg Train Acc: 97.35, Src Test Acc: 98.83, Trg Test Acc: 94.56
# Epoch: 174, TotalL: 0.3544, CrossE: 0.0045, CondE: 0.0412, disc: 0.6644, domain: 0.7786, Src VAT: 0.0144, Trg VAT: 0.0412, Src MixUp: 0.2337, Trg MixUp: 0.4107, Src Train Acc: 99.91, Trg Train Acc: 97.66, Src Test Acc: 99.22, Trg Test Acc: 94.50
# Epoch: 175, TotalL: 0.3919, CrossE: 0.0132, CondE: 0.0558, disc: 0.6781, domain: 0.7654, Src VAT: 0.0225, Trg VAT: 0.0558, Src MixUp: 0.2540, Trg MixUp: 0.3993, Src Train Acc: 99.52, Trg Train Acc: 97.22, Src Test Acc: 98.83, Trg Test Acc: 94.44
# Epoch: 176, TotalL: 0.3676, CrossE: 0.0058, CondE: 0.0497, disc: 0.6711, domain: 0.7634, Src VAT: 0.0182, Trg VAT: 0.0497, Src MixUp: 0.2425, Trg MixUp: 0.4012, Src Train Acc: 99.87, Trg Train Acc: 97.01, Src Test Acc: 97.67, Trg Test Acc: 92.89
# Epoch: 177, TotalL: 0.3568, CrossE: 0.0082, CondE: 0.0446, disc: 0.6682, domain: 0.7712, Src VAT: 0.0158, Trg VAT: 0.0446, Src MixUp: 0.2327, Trg MixUp: 0.3908, Src Train Acc: 99.78, Trg Train Acc: 97.79, Src Test Acc: 99.61, Trg Test Acc: 96.37
# Epoch: 178, TotalL: 0.3321, CrossE: 0.0024, CondE: 0.0417, disc: 0.6654, domain: 0.7810, Src VAT: 0.0113, Trg VAT: 0.0417, Src MixUp: 0.2179, Trg MixUp: 0.3925, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 99.22, Trg Test Acc: 95.73
# Epoch: 179, TotalL: 0.3607, CrossE: 0.0070, CondE: 0.0569, disc: 0.6704, domain: 0.7797, Src VAT: 0.0180, Trg VAT: 0.0569, Src MixUp: 0.2328, Trg MixUp: 0.3936, Src Train Acc: 99.87, Trg Train Acc: 97.09, Src Test Acc: 98.44, Trg Test Acc: 95.35
# Epoch: 180, TotalL: 0.3889, CrossE: 0.0069, CondE: 0.0560, disc: 0.6708, domain: 0.7687, Src VAT: 0.0214, Trg VAT: 0.0560, Src MixUp: 0.2570, Trg MixUp: 0.4138, Src Train Acc: 99.91, Trg Train Acc: 97.18, Src Test Acc: 93.77, Trg Test Acc: 89.39
# Epoch: 181, TotalL: 0.3722, CrossE: 0.0050, CondE: 0.0533, disc: 0.6674, domain: 0.7802, Src VAT: 0.0181, Trg VAT: 0.0533, Src MixUp: 0.2431, Trg MixUp: 0.4371, Src Train Acc: 99.96, Trg Train Acc: 97.27, Src Test Acc: 99.22, Trg Test Acc: 95.67
# Epoch: 182, TotalL: 0.4172, CrossE: 0.0149, CondE: 0.0623, disc: 0.6748, domain: 0.7750, Src VAT: 0.0275, Trg VAT: 0.0623, Src MixUp: 0.2696, Trg MixUp: 0.4154, Src Train Acc: 99.52, Trg Train Acc: 96.66, Src Test Acc: 99.61, Trg Test Acc: 92.98
# Epoch: 183, TotalL: 0.3429, CrossE: 0.0049, CondE: 0.0446, disc: 0.6714, domain: 0.7665, Src VAT: 0.0146, Trg VAT: 0.0446, Src MixUp: 0.2240, Trg MixUp: 0.3870, Src Train Acc: 99.91, Trg Train Acc: 97.74, Src Test Acc: 98.83, Trg Test Acc: 95.38
# Epoch: 184, TotalL: 0.3518, CrossE: 0.0042, CondE: 0.0502, disc: 0.6668, domain: 0.7743, Src VAT: 0.0144, Trg VAT: 0.0502, Src MixUp: 0.2309, Trg MixUp: 0.4038, Src Train Acc: 99.91, Trg Train Acc: 97.53, Src Test Acc: 99.61, Trg Test Acc: 94.42
# Epoch: 185, TotalL: 0.3931, CrossE: 0.0120, CondE: 0.0518, disc: 0.6759, domain: 0.7731, Src VAT: 0.0222, Trg VAT: 0.0518, Src MixUp: 0.2568, Trg MixUp: 0.3998, Src Train Acc: 99.61, Trg Train Acc: 97.31, Src Test Acc: 99.61, Trg Test Acc: 96.29
# Epoch: 186, TotalL: 0.3332, CrossE: 0.0021, CondE: 0.0393, disc: 0.6663, domain: 0.7741, Src VAT: 0.0099, Trg VAT: 0.0393, Src MixUp: 0.2228, Trg MixUp: 0.3760, Src Train Acc: 100.00, Trg Train Acc: 98.05, Src Test Acc: 98.83, Trg Test Acc: 97.28
# Epoch: 187, TotalL: 0.4067, CrossE: 0.0161, CondE: 0.0590, disc: 0.6710, domain: 0.7804, Src VAT: 0.0208, Trg VAT: 0.0590, Src MixUp: 0.2639, Trg MixUp: 0.4256, Src Train Acc: 99.74, Trg Train Acc: 96.88, Src Test Acc: 99.61, Trg Test Acc: 96.84
# Epoch: 188, TotalL: 0.3649, CrossE: 0.0059, CondE: 0.0526, disc: 0.6671, domain: 0.7754, Src VAT: 0.0153, Trg VAT: 0.0526, Src MixUp: 0.2406, Trg MixUp: 0.4064, Src Train Acc: 99.91, Trg Train Acc: 97.31, Src Test Acc: 98.83, Trg Test Acc: 96.81
# Epoch: 189, TotalL: 0.3453, CrossE: 0.0036, CondE: 0.0451, disc: 0.6672, domain: 0.7816, Src VAT: 0.0137, Trg VAT: 0.0451, Src MixUp: 0.2256, Trg MixUp: 0.4071, Src Train Acc: 99.96, Trg Train Acc: 97.96, Src Test Acc: 99.61, Trg Test Acc: 91.67
# Epoch: 190, TotalL: 0.3568, CrossE: 0.0086, CondE: 0.0458, disc: 0.6735, domain: 0.7661, Src VAT: 0.0196, Trg VAT: 0.0458, Src MixUp: 0.2288, Trg MixUp: 0.3904, Src Train Acc: 99.65, Trg Train Acc: 97.61, Src Test Acc: 98.44, Trg Test Acc: 90.85
# Epoch: 191, TotalL: 0.3959, CrossE: 0.0112, CondE: 0.0521, disc: 0.6777, domain: 0.7550, Src VAT: 0.0206, Trg VAT: 0.0521, Src MixUp: 0.2654, Trg MixUp: 0.3741, Src Train Acc: 99.87, Trg Train Acc: 97.18, Src Test Acc: 99.61, Trg Test Acc: 96.23
# ...
# Epoch: 437, TotalL: 0.2654, CrossE: 0.0010, CondE: 0.0137, disc: 0.6840, domain: 0.7260, Src VAT: 0.0048, Trg VAT: 0.0137, Src MixUp: 0.1761, Trg MixUp: 0.2916, Src Train Acc: 100.00, Trg Train Acc: 98.44, Src Test Acc: 88.72, Trg Test Acc: 78.98
# Epoch: 438, TotalL: 0.3043, CrossE: 0.0075, CondE: 0.0190, disc: 0.6847, domain: 0.7257, Src VAT: 0.0119, Trg VAT: 0.0190, Src MixUp: 0.1995, Trg MixUp: 0.3036, Src Train Acc: 99.70, Trg Train Acc: 98.09, Src Test Acc: 98.83, Trg Test Acc: 97.28
# Epoch: 439, TotalL: 0.2697, CrossE: 0.0024, CondE: 0.0180, disc: 0.6819, domain: 0.7299, Src VAT: 0.0076, Trg VAT: 0.0180, Src MixUp: 0.1734, Trg MixUp: 0.3126, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 96.35
# Epoch: 440, TotalL: 0.2547, CrossE: 0.0025, CondE: 0.0099, disc: 0.6842, domain: 0.7259, Src VAT: 0.0055, Trg VAT: 0.0099, Src MixUp: 0.1653, Trg MixUp: 0.2723, Src Train Acc: 99.87, Trg Train Acc: 98.48, Src Test Acc: 99.61, Trg Test Acc: 97.22
# Epoch: 441, TotalL: 0.2778, CrossE: 0.0047, CondE: 0.0224, disc: 0.6831, domain: 0.7293, Src VAT: 0.0106, Trg VAT: 0.0224, Src MixUp: 0.1767, Trg MixUp: 0.2974, Src Train Acc: 99.83, Trg Train Acc: 97.74, Src Test Acc: 99.22, Trg Test Acc: 97.13
# Epoch: 442, TotalL: 0.2498, CrossE: 0.0016, CondE: 0.0124, disc: 0.6822, domain: 0.7275, Src VAT: 0.0046, Trg VAT: 0.0124, Src MixUp: 0.1600, Trg MixUp: 0.2923, Src Train Acc: 99.96, Trg Train Acc: 98.61, Src Test Acc: 99.61, Trg Test Acc: 95.76
# Epoch: 443, TotalL: 0.2910, CrossE: 0.0049, CondE: 0.0185, disc: 0.6869, domain: 0.7245, Src VAT: 0.0102, Trg VAT: 0.0185, Src MixUp: 0.1903, Trg MixUp: 0.3089, Src Train Acc: 99.87, Trg Train Acc: 98.18, Src Test Acc: 99.61, Trg Test Acc: 98.13
# Epoch: 444, TotalL: 0.2638, CrossE: 0.0018, CondE: 0.0136, disc: 0.6837, domain: 0.7247, Src VAT: 0.0050, Trg VAT: 0.0136, Src MixUp: 0.1740, Trg MixUp: 0.2853, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 95.76
# Epoch: 445, TotalL: 0.2938, CrossE: 0.0045, CondE: 0.0207, disc: 0.6864, domain: 0.7229, Src VAT: 0.0101, Trg VAT: 0.0207, Src MixUp: 0.1948, Trg MixUp: 0.2903, Src Train Acc: 99.87, Trg Train Acc: 97.70, Src Test Acc: 99.61, Trg Test Acc: 97.51
# Epoch: 446, TotalL: 0.2757, CrossE: 0.0054, CondE: 0.0173, disc: 0.6868, domain: 0.7236, Src VAT: 0.0091, Trg VAT: 0.0173, Src MixUp: 0.1780, Trg MixUp: 0.2829, Src Train Acc: 99.74, Trg Train Acc: 98.13, Src Test Acc: 99.22, Trg Test Acc: 94.39
# Epoch: 447, TotalL: 0.2638, CrossE: 0.0016, CondE: 0.0168, disc: 0.6860, domain: 0.7221, Src VAT: 0.0064, Trg VAT: 0.0168, Src MixUp: 0.1722, Trg MixUp: 0.2891, Src Train Acc: 100.00, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 95.32
# Epoch: 448, TotalL: 0.2761, CrossE: 0.0071, CondE: 0.0163, disc: 0.6882, domain: 0.7207, Src VAT: 0.0086, Trg VAT: 0.0163, Src MixUp: 0.1757, Trg MixUp: 0.3048, Src Train Acc: 99.83, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 97.63
# Epoch: 449, TotalL: 0.2353, CrossE: 0.0008, CondE: 0.0111, disc: 0.6824, domain: 0.7264, Src VAT: 0.0039, Trg VAT: 0.0111, Src MixUp: 0.1488, Trg MixUp: 0.2745, Src Train Acc: 100.00, Trg Train Acc: 98.48, Src Test Acc: 98.05, Trg Test Acc: 91.02
# Epoch: 450, TotalL: 0.3023, CrossE: 0.0049, CondE: 0.0211, disc: 0.6840, domain: 0.7318, Src VAT: 0.0107, Trg VAT: 0.0211, Src MixUp: 0.1985, Trg MixUp: 0.3282, Src Train Acc: 99.87, Trg Train Acc: 98.22, Src Test Acc: 99.22, Trg Test Acc: 96.81
# Epoch: 451, TotalL: 0.2601, CrossE: 0.0016, CondE: 0.0137, disc: 0.6809, domain: 0.7307, Src VAT: 0.0061, Trg VAT: 0.0137, Src MixUp: 0.1697, Trg MixUp: 0.2750, Src Train Acc: 100.00, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 97.95
# Epoch: 452, TotalL: 0.2864, CrossE: 0.0069, CondE: 0.0169, disc: 0.6880, domain: 0.7220, Src VAT: 0.0100, Trg VAT: 0.0169, Src MixUp: 0.1860, Trg MixUp: 0.2870, Src Train Acc: 99.70, Trg Train Acc: 98.18, Src Test Acc: 99.61, Trg Test Acc: 98.48
# Epoch: 453, TotalL: 0.2622, CrossE: 0.0032, CondE: 0.0143, disc: 0.6859, domain: 0.7230, Src VAT: 0.0085, Trg VAT: 0.0143, Src MixUp: 0.1660, Trg MixUp: 0.3055, Src Train Acc: 99.96, Trg Train Acc: 98.57, Src Test Acc: 98.83, Trg Test Acc: 96.29
# Epoch: 454, TotalL: 0.2382, CrossE: 0.0013, CondE: 0.0125, disc: 0.6813, domain: 0.7241, Src VAT: 0.0047, Trg VAT: 0.0125, Src MixUp: 0.1501, Trg MixUp: 0.2769, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 98.83, Trg Test Acc: 96.35
# Epoch: 455, TotalL: 0.2539, CrossE: 0.0017, CondE: 0.0106, disc: 0.6825, domain: 0.7273, Src VAT: 0.0043, Trg VAT: 0.0106, Src MixUp: 0.1647, Trg MixUp: 0.2915, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 97.60
# Epoch: 456, TotalL: 0.2439, CrossE: 0.0014, CondE: 0.0109, disc: 0.6829, domain: 0.7262, Src VAT: 0.0042, Trg VAT: 0.0109, Src MixUp: 0.1564, Trg MixUp: 0.2769, Src Train Acc: 99.96, Trg Train Acc: 98.44, Src Test Acc: 99.22, Trg Test Acc: 94.85
# Epoch: 457, TotalL: 0.2929, CrossE: 0.0040, CondE: 0.0194, disc: 0.6906, domain: 0.7209, Src VAT: 0.0100, Trg VAT: 0.0194, Src MixUp: 0.1938, Trg MixUp: 0.3041, Src Train Acc: 99.91, Trg Train Acc: 98.13, Src Test Acc: 100.00, Trg Test Acc: 97.19
# Epoch: 458, TotalL: 0.2993, CrossE: 0.0151, CondE: 0.0185, disc: 0.6883, domain: 0.7188, Src VAT: 0.0098, Trg VAT: 0.0185, Src MixUp: 0.1902, Trg MixUp: 0.2959, Src Train Acc: 99.74, Trg Train Acc: 98.18, Src Test Acc: 98.44, Trg Test Acc: 96.87
# Epoch: 459, TotalL: 0.2684, CrossE: 0.0015, CondE: 0.0122, disc: 0.6834, domain: 0.7219, Src VAT: 0.0056, Trg VAT: 0.0122, Src MixUp: 0.1790, Trg MixUp: 0.2827, Src Train Acc: 99.96, Trg Train Acc: 98.39, Src Test Acc: 98.83, Trg Test Acc: 96.49
# Epoch: 460, TotalL: 0.2606, CrossE: 0.0014, CondE: 0.0175, disc: 0.6866, domain: 0.7200, Src VAT: 0.0058, Trg VAT: 0.0175, Src MixUp: 0.1687, Trg MixUp: 0.3031, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 99.61, Trg Test Acc: 97.11
# Epoch: 461, TotalL: 0.2366, CrossE: 0.0008, CondE: 0.0104, disc: 0.6835, domain: 0.7258, Src VAT: 0.0035, Trg VAT: 0.0104, Src MixUp: 0.1511, Trg MixUp: 0.2679, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 95.44
# Epoch: 462, TotalL: 0.2530, CrossE: 0.0028, CondE: 0.0156, disc: 0.6883, domain: 0.7177, Src VAT: 0.0066, Trg VAT: 0.0156, Src MixUp: 0.1600, Trg MixUp: 0.2968, Src Train Acc: 99.96, Trg Train Acc: 98.31, Src Test Acc: 96.50, Trg Test Acc: 90.18
# Epoch: 463, TotalL: 0.2660, CrossE: 0.0032, CondE: 0.0171, disc: 0.6849, domain: 0.7242, Src VAT: 0.0085, Trg VAT: 0.0171, Src MixUp: 0.1720, Trg MixUp: 0.2705, Src Train Acc: 99.96, Trg Train Acc: 97.96, Src Test Acc: 99.61, Trg Test Acc: 97.13
# Epoch: 464, TotalL: 0.2598, CrossE: 0.0034, CondE: 0.0147, disc: 0.6837, domain: 0.7230, Src VAT: 0.0061, Trg VAT: 0.0147, Src MixUp: 0.1683, Trg MixUp: 0.2719, Src Train Acc: 99.91, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 97.28
# Epoch: 465, TotalL: 0.2387, CrossE: 0.0008, CondE: 0.0105, disc: 0.6830, domain: 0.7290, Src VAT: 0.0036, Trg VAT: 0.0105, Src MixUp: 0.1519, Trg MixUp: 0.2796, Src Train Acc: 100.00, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 98.13
# Epoch: 466, TotalL: 0.2664, CrossE: 0.0020, CondE: 0.0155, disc: 0.6861, domain: 0.7231, Src VAT: 0.0068, Trg VAT: 0.0155, Src MixUp: 0.1741, Trg MixUp: 0.2898, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 97.11
# Epoch: 467, TotalL: 0.2577, CrossE: 0.0011, CondE: 0.0115, disc: 0.6839, domain: 0.7253, Src VAT: 0.0052, Trg VAT: 0.0115, Src MixUp: 0.1678, Trg MixUp: 0.2970, Src Train Acc: 100.00, Trg Train Acc: 98.44, Src Test Acc: 99.61, Trg Test Acc: 94.82
# Epoch: 468, TotalL: 0.2594, CrossE: 0.0034, CondE: 0.0151, disc: 0.6838, domain: 0.7257, Src VAT: 0.0075, Trg VAT: 0.0151, Src MixUp: 0.1651, Trg MixUp: 0.2866, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 94.65
# Epoch: 469, TotalL: 0.2638, CrossE: 0.0044, CondE: 0.0158, disc: 0.6843, domain: 0.7261, Src VAT: 0.0072, Trg VAT: 0.0158, Src MixUp: 0.1693, Trg MixUp: 0.2782, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 96.96
# Epoch: 470, TotalL: 0.2629, CrossE: 0.0037, CondE: 0.0099, disc: 0.6836, domain: 0.7265, Src VAT: 0.0051, Trg VAT: 0.0099, Src MixUp: 0.1721, Trg MixUp: 0.2782, Src Train Acc: 99.96, Trg Train Acc: 98.39, Src Test Acc: 98.83, Trg Test Acc: 93.30
# Epoch: 471, TotalL: 0.2999, CrossE: 0.0045, CondE: 0.0220, disc: 0.6878, domain: 0.7222, Src VAT: 0.0118, Trg VAT: 0.0220, Src MixUp: 0.1979, Trg MixUp: 0.3053, Src Train Acc: 99.91, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 98.48
# Epoch: 472, TotalL: 0.2785, CrossE: 0.0047, CondE: 0.0171, disc: 0.6853, domain: 0.7213, Src VAT: 0.0097, Trg VAT: 0.0171, Src MixUp: 0.1793, Trg MixUp: 0.3049, Src Train Acc: 99.87, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 95.67
# Epoch: 473, TotalL: 0.3186, CrossE: 0.0110, CondE: 0.0274, disc: 0.6905, domain: 0.7262, Src VAT: 0.0146, Trg VAT: 0.0274, Src MixUp: 0.2052, Trg MixUp: 0.3166, Src Train Acc: 99.61, Trg Train Acc: 97.87, Src Test Acc: 99.61, Trg Test Acc: 96.70
# Epoch: 474, TotalL: 0.2665, CrossE: 0.0015, CondE: 0.0111, disc: 0.6865, domain: 0.7168, Src VAT: 0.0062, Trg VAT: 0.0111, Src MixUp: 0.1752, Trg MixUp: 0.3051, Src Train Acc: 100.00, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 96.52
# Epoch: 475, TotalL: 0.2783, CrossE: 0.0014, CondE: 0.0124, disc: 0.6833, domain: 0.7229, Src VAT: 0.0061, Trg VAT: 0.0124, Src MixUp: 0.1887, Trg MixUp: 0.2775, Src Train Acc: 100.00, Trg Train Acc: 98.31, Src Test Acc: 98.44, Trg Test Acc: 93.42
# Epoch: 476, TotalL: 0.2468, CrossE: 0.0011, CondE: 0.0099, disc: 0.6853, domain: 0.7206, Src VAT: 0.0046, Trg VAT: 0.0099, Src MixUp: 0.1602, Trg MixUp: 0.2710, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 97.25
# Epoch: 477, TotalL: 0.2533, CrossE: 0.0016, CondE: 0.0117, disc: 0.6842, domain: 0.7243, Src VAT: 0.0059, Trg VAT: 0.0117, Src MixUp: 0.1641, Trg MixUp: 0.2732, Src Train Acc: 100.00, Trg Train Acc: 98.35, Src Test Acc: 99.61, Trg Test Acc: 94.68
# Epoch: 478, TotalL: 0.2565, CrossE: 0.0026, CondE: 0.0117, disc: 0.6867, domain: 0.7212, Src VAT: 0.0059, Trg VAT: 0.0117, Src MixUp: 0.1672, Trg MixUp: 0.2656, Src Train Acc: 99.91, Trg Train Acc: 98.39, Src Test Acc: 95.72, Trg Test Acc: 89.27
# Epoch: 479, TotalL: 0.3393, CrossE: 0.0217, CondE: 0.0329, disc: 0.6888, domain: 0.7290, Src VAT: 0.0188, Trg VAT: 0.0329, Src MixUp: 0.2090, Trg MixUp: 0.3280, Src Train Acc: 99.57, Trg Train Acc: 97.74, Src Test Acc: 99.61, Trg Test Acc: 97.98
# Epoch: 480, TotalL: 0.2972, CrossE: 0.0019, CondE: 0.0198, disc: 0.6829, domain: 0.7244, Src VAT: 0.0081, Trg VAT: 0.0198, Src MixUp: 0.1989, Trg MixUp: 0.3395, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 98.36
# Epoch: 481, TotalL: 0.2514, CrossE: 0.0010, CondE: 0.0118, disc: 0.6820, domain: 0.7271, Src VAT: 0.0048, Trg VAT: 0.0118, Src MixUp: 0.1640, Trg MixUp: 0.2697, Src Train Acc: 100.00, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 97.51
# Epoch: 482, TotalL: 0.2480, CrossE: 0.0014, CondE: 0.0106, disc: 0.6837, domain: 0.7254, Src VAT: 0.0048, Trg VAT: 0.0106, Src MixUp: 0.1606, Trg MixUp: 0.2679, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 99.22, Trg Test Acc: 95.47
# Epoch: 483, TotalL: 0.2672, CrossE: 0.0021, CondE: 0.0155, disc: 0.6879, domain: 0.7196, Src VAT: 0.0069, Trg VAT: 0.0155, Src MixUp: 0.1749, Trg MixUp: 0.2898, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 99.22, Trg Test Acc: 96.32
# Epoch: 484, TotalL: 0.2875, CrossE: 0.0041, CondE: 0.0238, disc: 0.6860, domain: 0.7226, Src VAT: 0.0101, Trg VAT: 0.0238, Src MixUp: 0.1885, Trg MixUp: 0.2903, Src Train Acc: 99.91, Trg Train Acc: 97.83, Src Test Acc: 98.83, Trg Test Acc: 93.80
# Epoch: 485, TotalL: 0.2508, CrossE: 0.0018, CondE: 0.0122, disc: 0.6870, domain: 0.7209, Src VAT: 0.0062, Trg VAT: 0.0122, Src MixUp: 0.1601, Trg MixUp: 0.2897, Src Train Acc: 99.96, Trg Train Acc: 98.52, Src Test Acc: 99.61, Trg Test Acc: 97.08
# Epoch: 486, TotalL: 0.2486, CrossE: 0.0032, CondE: 0.0107, disc: 0.6852, domain: 0.7215, Src VAT: 0.0045, Trg VAT: 0.0107, Src MixUp: 0.1588, Trg MixUp: 0.2840, Src Train Acc: 99.91, Trg Train Acc: 98.31, Src Test Acc: 99.61, Trg Test Acc: 96.93
# Epoch: 487, TotalL: 0.3171, CrossE: 0.0144, CondE: 0.0278, disc: 0.6864, domain: 0.7190, Src VAT: 0.0163, Trg VAT: 0.0278, Src MixUp: 0.2004, Trg MixUp: 0.3011, Src Train Acc: 99.48, Trg Train Acc: 97.53, Src Test Acc: 99.61, Trg Test Acc: 98.13
# Epoch: 488, TotalL: 0.2598, CrossE: 0.0023, CondE: 0.0161, disc: 0.6849, domain: 0.7262, Src VAT: 0.0052, Trg VAT: 0.0161, Src MixUp: 0.1686, Trg MixUp: 0.2877, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 99.61, Trg Test Acc: 97.31
# Epoch: 489, TotalL: 0.2606, CrossE: 0.0053, CondE: 0.0103, disc: 0.6827, domain: 0.7263, Src VAT: 0.0044, Trg VAT: 0.0103, Src MixUp: 0.1692, Trg MixUp: 0.2734, Src Train Acc: 99.87, Trg Train Acc: 98.35, Src Test Acc: 98.44, Trg Test Acc: 92.98
# Epoch: 490, TotalL: 0.2428, CrossE: 0.0014, CondE: 0.0088, disc: 0.6828, domain: 0.7237, Src VAT: 0.0039, Trg VAT: 0.0088, Src MixUp: 0.1569, Trg MixUp: 0.2665, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 99.61, Trg Test Acc: 97.46
# Epoch: 491, TotalL: 0.2678, CrossE: 0.0011, CondE: 0.0160, disc: 0.6852, domain: 0.7215, Src VAT: 0.0058, Trg VAT: 0.0160, Src MixUp: 0.1783, Trg MixUp: 0.2783, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 98.83, Trg Test Acc: 96.90
# Epoch: 492, TotalL: 0.2403, CrossE: 0.0016, CondE: 0.0088, disc: 0.6855, domain: 0.7251, Src VAT: 0.0044, Trg VAT: 0.0088, Src MixUp: 0.1548, Trg MixUp: 0.2507, Src Train Acc: 99.91, Trg Train Acc: 98.35, Src Test Acc: 98.44, Trg Test Acc: 95.47
# Epoch: 493, TotalL: 0.2826, CrossE: 0.0039, CondE: 0.0178, disc: 0.6855, domain: 0.7253, Src VAT: 0.0092, Trg VAT: 0.0178, Src MixUp: 0.1847, Trg MixUp: 0.2983, Src Train Acc: 99.83, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 97.22
# Epoch: 494, TotalL: 0.3028, CrossE: 0.0108, CondE: 0.0250, disc: 0.6891, domain: 0.7175, Src VAT: 0.0127, Trg VAT: 0.0250, Src MixUp: 0.1933, Trg MixUp: 0.3069, Src Train Acc: 99.78, Trg Train Acc: 97.74, Src Test Acc: 99.22, Trg Test Acc: 96.90
# Epoch: 495, TotalL: 0.2502, CrossE: 0.0016, CondE: 0.0086, disc: 0.6866, domain: 0.7192, Src VAT: 0.0045, Trg VAT: 0.0086, Src MixUp: 0.1644, Trg MixUp: 0.2592, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 97.67, Trg Test Acc: 91.37
# Epoch: 496, TotalL: 0.2338, CrossE: 0.0007, CondE: 0.0082, disc: 0.6817, domain: 0.7254, Src VAT: 0.0035, Trg VAT: 0.0082, Src MixUp: 0.1491, Trg MixUp: 0.2649, Src Train Acc: 100.00, Trg Train Acc: 98.44, Src Test Acc: 98.44, Trg Test Acc: 94.50
# Epoch: 497, TotalL: 0.2913, CrossE: 0.0051, CondE: 0.0184, disc: 0.6856, domain: 0.7270, Src VAT: 0.0119, Trg VAT: 0.0184, Src MixUp: 0.1908, Trg MixUp: 0.2814, Src Train Acc: 99.91, Trg Train Acc: 97.70, Src Test Acc: 99.22, Trg Test Acc: 97.11
# Epoch: 498, TotalL: 0.2496, CrossE: 0.0014, CondE: 0.0099, disc: 0.6842, domain: 0.7195, Src VAT: 0.0046, Trg VAT: 0.0099, Src MixUp: 0.1631, Trg MixUp: 0.2668, Src Train Acc: 99.96, Trg Train Acc: 98.39, Src Test Acc: 99.22, Trg Test Acc: 97.87
# Epoch: 499, TotalL: 0.2558, CrossE: 0.0024, CondE: 0.0121, disc: 0.6844, domain: 0.7248, Src VAT: 0.0065, Trg VAT: 0.0121, Src MixUp: 0.1655, Trg MixUp: 0.2688, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 98.83, Trg Test Acc: 97.60
# Epoch: 500, TotalL: 0.2815, CrossE: 0.0102, CondE: 0.0211, disc: 0.6869, domain: 0.7262, Src VAT: 0.0092, Trg VAT: 0.0211, Src MixUp: 0.1775, Trg MixUp: 0.2881, Src Train Acc: 99.70, Trg Train Acc: 98.18, Src Test Acc: 98.83, Trg Test Acc: 95.00
