# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='1'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 16
train_src_days  = 3
train_trg_days  = 3
epochs          = 1000
learning_rate   = 0.0001
decay_rate      = 0.96
decay_steps     = 10000
num_hidden      = [1024, 512]
num_features    = 256
disc_activation = 'selu'
gen_activation  = 'selu'
notes           = "VMT_GaussianNoise_baseline_CV-Data" 

log_data = "classes-{}_batch_size-{}_train_src_days-{}_train_trg_days-{}_lr-{}_decay-{}_decay_steps-{}_num_hidden-{}_num_features-{}_disc_act-{}_gen_act-{}_notes-{}".format(num_classes, 
                                                                                                                                                                                  batch_size, 
                                                                                                                                                                                  train_src_days, 
                                                                                                                                                                                  train_trg_days, 
                                                                                                                                                                                  learning_rate, 
                                                                                                                                                                                  decay_rate,
                                                                                                                                                                                  decay_steps,
                                                                                                                                                                                  num_hidden, 
                                                                                                                                                                                  num_features,
                                                                                                                                                                                  disc_activation,
                                                                                                                                                                                  gen_activation,
                                                                                                                                                                                  notes)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9127, 128, 1024, 1) (9127, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8737, 128, 1024, 1) (8737, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8547, 128, 1024, 1) (8547, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2563, 128, 1024, 1) (2563, 9) (3419, 128, 1024, 1) (3419, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2563, 128, 1024, 1) (2563, 9) (3419, 128, 1024, 1) (3419, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

initial_learning_rate = learning_rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate,
    staircase=True)

generator      = ResNet50(num_classes, num_features, gen_activation)
discriminator  = Discriminator(num_hidden, disc_activation)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = lr_schedule, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = lr_schedule, beta_1 = 0.5)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    
for epoch in range(epochs):
  global_step.assign_add(1)  
    
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0824 17:01:42.949040 140373749249792 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0824 17:01:47.603847 140373749249792 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.1623, CrossE: 2.2120, CondE: 2.1653, disc: 1.3885, domain: 1.2507, Src VAT: 2.1652, Trg VAT: 2.1653, Src MixUp: 2.1654, Trg MixUp: 2.1656, Src Train Acc: 12.46, Trg Train Acc: 11.89, Src Test Acc: 11.67, Trg Test Acc: 11.52
# Epoch: 002, TotalL: 7.1312, CrossE: 2.1970, CondE: 2.1643, disc: 1.1623, domain: 1.0813, Src VAT: 2.1639, Trg VAT: 2.1643, Src MixUp: 2.1644, Trg MixUp: 2.1647, Src Train Acc: 13.45, Trg Train Acc: 13.45, Src Test Acc: 13.23, Trg Test Acc: 14.65
# Epoch: 003, TotalL: 7.0650, CrossE: 2.1666, CondE: 2.1462, disc: 0.7985, domain: 1.1044, Src VAT: 2.1456, Trg VAT: 2.1462, Src MixUp: 2.1491, Trg MixUp: 2.1498, Src Train Acc: 13.85, Trg Train Acc: 14.24, Src Test Acc: 19.07, Trg Test Acc: 19.22
# Epoch: 004, TotalL: 6.8792, CrossE: 2.0716, CondE: 2.1127, disc: 1.4571, domain: 0.8493, Src VAT: 2.1088, Trg VAT: 2.1127, Src MixUp: 2.1228, Trg MixUp: 2.1263, Src Train Acc: 17.40, Trg Train Acc: 17.14, Src Test Acc: 23.35, Trg Test Acc: 18.89
# Epoch: 005, TotalL: 6.6102, CrossE: 1.9500, CondE: 2.0361, disc: 1.3510, domain: 0.9415, Src VAT: 2.0304, Trg VAT: 2.0361, Src MixUp: 2.0632, Trg MixUp: 2.0690, Src Train Acc: 22.74, Trg Train Acc: 21.09, Src Test Acc: 28.40, Trg Test Acc: 24.63
# Epoch: 006, TotalL: 6.1296, CrossE: 1.7766, CondE: 1.8872, disc: 0.9092, domain: 0.8786, Src VAT: 1.8767, Trg VAT: 1.8872, Src MixUp: 1.9472, Trg MixUp: 1.9605, Src Train Acc: 29.04, Trg Train Acc: 28.30, Src Test Acc: 34.24, Trg Test Acc: 31.76
# Epoch: 007, TotalL: 5.6840, CrossE: 1.6292, CondE: 1.7444, disc: 0.8221, domain: 0.7753, Src VAT: 1.7317, Trg VAT: 1.7444, Src MixUp: 1.8337, Trg MixUp: 1.8547, Src Train Acc: 33.98, Trg Train Acc: 31.86, Src Test Acc: 35.80, Trg Test Acc: 33.61
# Epoch: 008, TotalL: 5.4664, CrossE: 1.5321, CondE: 1.6804, disc: 0.8733, domain: 0.8997, Src VAT: 1.6656, Trg VAT: 1.6804, Src MixUp: 1.7830, Trg MixUp: 1.8118, Src Train Acc: 38.72, Trg Train Acc: 35.59, Src Test Acc: 39.69, Trg Test Acc: 34.72
# Epoch: 009, TotalL: 5.3177, CrossE: 1.4799, CondE: 1.6230, disc: 0.8724, domain: 1.0764, Src VAT: 1.6100, Trg VAT: 1.6230, Src MixUp: 1.7418, Trg MixUp: 1.7533, Src Train Acc: 43.10, Trg Train Acc: 38.02, Src Test Acc: 41.63, Trg Test Acc: 38.05
# Epoch: 010, TotalL: 5.0379, CrossE: 1.3573, CondE: 1.5568, disc: 0.7919, domain: 0.8668, Src VAT: 1.5414, Trg VAT: 1.5568, Src MixUp: 1.6831, Trg MixUp: 1.7198, Src Train Acc: 49.13, Trg Train Acc: 44.05, Src Test Acc: 52.53, Trg Test Acc: 46.12
# Epoch: 011, TotalL: 4.5672, CrossE: 1.1548, CondE: 1.4078, disc: 0.8733, domain: 1.0709, Src VAT: 1.3911, Trg VAT: 1.4078, Src MixUp: 1.5817, Trg MixUp: 1.6084, Src Train Acc: 58.29, Trg Train Acc: 51.04, Src Test Acc: 59.14, Trg Test Acc: 51.59
# Epoch: 012, TotalL: 4.1117, CrossE: 1.0169, CondE: 1.2598, disc: 0.8163, domain: 1.0870, Src VAT: 1.2328, Trg VAT: 1.2598, Src MixUp: 1.4537, Trg MixUp: 1.4956, Src Train Acc: 63.24, Trg Train Acc: 55.69, Src Test Acc: 63.04, Trg Test Acc: 51.80
# Epoch: 013, TotalL: 3.7770, CrossE: 0.9195, CondE: 1.1444, disc: 0.7535, domain: 0.9179, Src VAT: 1.1225, Trg VAT: 1.1444, Src MixUp: 1.3655, Trg MixUp: 1.4120, Src Train Acc: 67.40, Trg Train Acc: 59.07, Src Test Acc: 63.04, Trg Test Acc: 56.48
# Epoch: 014, TotalL: 3.4450, CrossE: 0.8315, CondE: 1.0329, disc: 0.7023, domain: 0.7808, Src VAT: 1.0070, Trg VAT: 1.0329, Src MixUp: 1.2717, Trg MixUp: 1.3391, Src Train Acc: 69.36, Trg Train Acc: 61.41, Src Test Acc: 64.59, Trg Test Acc: 56.74
# Epoch: 015, TotalL: 3.2307, CrossE: 0.7621, CondE: 0.9596, disc: 0.7020, domain: 0.7890, Src VAT: 0.9363, Trg VAT: 0.9596, Src MixUp: 1.2140, Trg MixUp: 1.2708, Src Train Acc: 71.88, Trg Train Acc: 63.98, Src Test Acc: 72.76, Trg Test Acc: 58.94
# Epoch: 016, TotalL: 3.0670, CrossE: 0.7084, CondE: 0.9080, disc: 0.7020, domain: 0.7973, Src VAT: 0.8776, Trg VAT: 0.9080, Src MixUp: 1.1738, Trg MixUp: 1.2266, Src Train Acc: 73.78, Trg Train Acc: 66.67, Src Test Acc: 72.37, Trg Test Acc: 63.88
# Epoch: 017, TotalL: 2.9114, CrossE: 0.6570, CondE: 0.8568, disc: 0.7035, domain: 0.8073, Src VAT: 0.8264, Trg VAT: 0.8568, Src MixUp: 1.1308, Trg MixUp: 1.1930, Src Train Acc: 76.26, Trg Train Acc: 67.93, Src Test Acc: 75.88, Trg Test Acc: 64.84
# Epoch: 018, TotalL: 2.7940, CrossE: 0.6173, CondE: 0.8192, disc: 0.7001, domain: 0.8117, Src VAT: 0.7894, Trg VAT: 0.8192, Src MixUp: 1.0986, Trg MixUp: 1.1594, Src Train Acc: 78.30, Trg Train Acc: 69.79, Src Test Acc: 82.10, Trg Test Acc: 68.15
# Epoch: 019, TotalL: 2.6240, CrossE: 0.5671, CondE: 0.7698, disc: 0.6998, domain: 0.8222, Src VAT: 0.7358, Trg VAT: 0.7698, Src MixUp: 1.0431, Trg MixUp: 1.1139, Src Train Acc: 80.25, Trg Train Acc: 72.22, Src Test Acc: 84.44, Trg Test Acc: 71.89
# Epoch: 020, TotalL: 2.4886, CrossE: 0.5205, CondE: 0.7261, disc: 0.6937, domain: 0.8346, Src VAT: 0.6856, Trg VAT: 0.7261, Src MixUp: 1.0134, Trg MixUp: 1.0769, Src Train Acc: 81.73, Trg Train Acc: 74.09, Src Test Acc: 83.66, Trg Test Acc: 69.87
# Epoch: 021, TotalL: 2.3888, CrossE: 0.4999, CondE: 0.6926, disc: 0.6924, domain: 0.8494, Src VAT: 0.6531, Trg VAT: 0.6926, Src MixUp: 0.9722, Trg MixUp: 1.0609, Src Train Acc: 82.51, Trg Train Acc: 73.74, Src Test Acc: 85.21, Trg Test Acc: 75.87
# Epoch: 022, TotalL: 2.2312, CrossE: 0.4455, CondE: 0.6528, disc: 0.6847, domain: 0.8549, Src VAT: 0.6059, Trg VAT: 0.6528, Src MixUp: 0.9234, Trg MixUp: 1.0446, Src Train Acc: 84.33, Trg Train Acc: 76.09, Src Test Acc: 85.99, Trg Test Acc: 75.11
# Epoch: 023, TotalL: 2.1594, CrossE: 0.4198, CondE: 0.6235, disc: 0.6877, domain: 0.8603, Src VAT: 0.5737, Trg VAT: 0.6235, Src MixUp: 0.9179, Trg MixUp: 0.9914, Src Train Acc: 85.72, Trg Train Acc: 76.43, Src Test Acc: 87.94, Trg Test Acc: 77.45
# Epoch: 024, TotalL: 2.0499, CrossE: 0.3874, CondE: 0.5866, disc: 0.6794, domain: 0.8627, Src VAT: 0.5410, Trg VAT: 0.5866, Src MixUp: 0.8818, Trg MixUp: 0.9602, Src Train Acc: 86.94, Trg Train Acc: 77.86, Src Test Acc: 86.77, Trg Test Acc: 77.36
# Epoch: 025, TotalL: 1.9314, CrossE: 0.3523, CondE: 0.5669, disc: 0.6774, domain: 0.8718, Src VAT: 0.5033, Trg VAT: 0.5669, Src MixUp: 0.8399, Trg MixUp: 0.9423, Src Train Acc: 88.54, Trg Train Acc: 79.60, Src Test Acc: 88.72, Trg Test Acc: 79.85
# Epoch: 026, TotalL: 1.8579, CrossE: 0.3292, CondE: 0.5349, disc: 0.6743, domain: 0.8832, Src VAT: 0.4740, Trg VAT: 0.5349, Src MixUp: 0.8244, Trg MixUp: 0.9251, Src Train Acc: 89.54, Trg Train Acc: 80.34, Src Test Acc: 91.05, Trg Test Acc: 82.89
# Epoch: 027, TotalL: 1.8201, CrossE: 0.3139, CondE: 0.5273, disc: 0.6767, domain: 0.8881, Src VAT: 0.4619, Trg VAT: 0.5273, Src MixUp: 0.8165, Trg MixUp: 0.9050, Src Train Acc: 89.63, Trg Train Acc: 80.60, Src Test Acc: 90.66, Trg Test Acc: 81.90
# Epoch: 028, TotalL: 1.7423, CrossE: 0.2925, CondE: 0.5064, disc: 0.6696, domain: 0.8949, Src VAT: 0.4317, Trg VAT: 0.5064, Src MixUp: 0.7946, Trg MixUp: 0.8868, Src Train Acc: 90.58, Trg Train Acc: 81.86, Src Test Acc: 91.83, Trg Test Acc: 83.09
# Epoch: 029, TotalL: 1.6664, CrossE: 0.2659, CondE: 0.4848, disc: 0.6606, domain: 0.9081, Src VAT: 0.4074, Trg VAT: 0.4848, Src MixUp: 0.7724, Trg MixUp: 0.8808, Src Train Acc: 91.62, Trg Train Acc: 82.68, Src Test Acc: 91.83, Trg Test Acc: 83.77
# Epoch: 030, TotalL: 1.6713, CrossE: 0.2742, CondE: 0.4761, disc: 0.6633, domain: 0.9070, Src VAT: 0.4025, Trg VAT: 0.4761, Src MixUp: 0.7756, Trg MixUp: 0.8780, Src Train Acc: 91.93, Trg Train Acc: 82.47, Src Test Acc: 93.77, Trg Test Acc: 85.26
# Epoch: 031, TotalL: 1.5783, CrossE: 0.2409, CondE: 0.4532, disc: 0.6581, domain: 0.9156, Src VAT: 0.3786, Trg VAT: 0.4532, Src MixUp: 0.7452, Trg MixUp: 0.8467, Src Train Acc: 92.23, Trg Train Acc: 82.90, Src Test Acc: 93.39, Trg Test Acc: 85.00
# Epoch: 032, TotalL: 1.4746, CrossE: 0.2153, CondE: 0.4213, disc: 0.6565, domain: 0.9223, Src VAT: 0.3471, Trg VAT: 0.4213, Src MixUp: 0.7047, Trg MixUp: 0.8290, Src Train Acc: 93.49, Trg Train Acc: 84.55, Src Test Acc: 90.66, Trg Test Acc: 84.41
# Epoch: 033, TotalL: 1.4826, CrossE: 0.2146, CondE: 0.4149, disc: 0.6582, domain: 0.9192, Src VAT: 0.3445, Trg VAT: 0.4149, Src MixUp: 0.7199, Trg MixUp: 0.7970, Src Train Acc: 93.23, Trg Train Acc: 84.42, Src Test Acc: 94.55, Trg Test Acc: 86.37
# Epoch: 034, TotalL: 1.4210, CrossE: 0.1990, CondE: 0.3941, disc: 0.6532, domain: 0.9272, Src VAT: 0.3242, Trg VAT: 0.3941, Src MixUp: 0.6957, Trg MixUp: 0.8103, Src Train Acc: 94.14, Trg Train Acc: 85.50, Src Test Acc: 90.27, Trg Test Acc: 85.02
# Epoch: 035, TotalL: 1.4245, CrossE: 0.1878, CondE: 0.4053, disc: 0.6548, domain: 0.9193, Src VAT: 0.3184, Trg VAT: 0.4053, Src MixUp: 0.7160, Trg MixUp: 0.7978, Src Train Acc: 94.97, Trg Train Acc: 85.55, Src Test Acc: 93.00, Trg Test Acc: 87.28
# Epoch: 036, TotalL: 1.3346, CrossE: 0.1703, CondE: 0.3723, disc: 0.6512, domain: 0.9362, Src VAT: 0.2937, Trg VAT: 0.3723, Src MixUp: 0.6737, Trg MixUp: 0.7806, Src Train Acc: 94.75, Trg Train Acc: 86.33, Src Test Acc: 86.77, Trg Test Acc: 80.05
# Epoch: 037, TotalL: 1.3171, CrossE: 0.1697, CondE: 0.3662, disc: 0.6495, domain: 0.9301, Src VAT: 0.2881, Trg VAT: 0.3662, Src MixUp: 0.6641, Trg MixUp: 0.7772, Src Train Acc: 95.49, Trg Train Acc: 86.07, Src Test Acc: 93.39, Trg Test Acc: 87.51
# Epoch: 038, TotalL: 1.2463, CrossE: 0.1474, CondE: 0.3503, disc: 0.6514, domain: 0.9429, Src VAT: 0.2680, Trg VAT: 0.3503, Src MixUp: 0.6390, Trg MixUp: 0.7552, Src Train Acc: 96.22, Trg Train Acc: 87.15, Src Test Acc: 93.00, Trg Test Acc: 85.81
# Epoch: 039, TotalL: 1.2297, CrossE: 0.1442, CondE: 0.3332, disc: 0.6527, domain: 0.9438, Src VAT: 0.2579, Trg VAT: 0.3332, Src MixUp: 0.6392, Trg MixUp: 0.7452, Src Train Acc: 96.22, Trg Train Acc: 86.89, Src Test Acc: 89.88, Trg Test Acc: 84.06
# Epoch: 040, TotalL: 1.1951, CrossE: 0.1354, CondE: 0.3201, disc: 0.6491, domain: 0.9375, Src VAT: 0.2460, Trg VAT: 0.3201, Src MixUp: 0.6299, Trg MixUp: 0.7192, Src Train Acc: 96.40, Trg Train Acc: 87.98, Src Test Acc: 94.94, Trg Test Acc: 87.54
# Epoch: 041, TotalL: 1.1656, CrossE: 0.1254, CondE: 0.3194, disc: 0.6507, domain: 0.9467, Src VAT: 0.2336, Trg VAT: 0.3194, Src MixUp: 0.6221, Trg MixUp: 0.7218, Src Train Acc: 96.61, Trg Train Acc: 87.80, Src Test Acc: 94.55, Trg Test Acc: 88.97
# Epoch: 042, TotalL: 1.2018, CrossE: 0.1420, CondE: 0.3224, disc: 0.6487, domain: 0.9388, Src VAT: 0.2491, Trg VAT: 0.3224, Src MixUp: 0.6247, Trg MixUp: 0.7418, Src Train Acc: 96.35, Trg Train Acc: 87.07, Src Test Acc: 95.33, Trg Test Acc: 88.77
# Epoch: 043, TotalL: 1.1642, CrossE: 0.1284, CondE: 0.3196, disc: 0.6427, domain: 0.9482, Src VAT: 0.2330, Trg VAT: 0.3196, Src MixUp: 0.6177, Trg MixUp: 0.7265, Src Train Acc: 96.70, Trg Train Acc: 88.15, Src Test Acc: 94.16, Trg Test Acc: 87.42
# Epoch: 044, TotalL: 1.1376, CrossE: 0.1127, CondE: 0.3121, disc: 0.6513, domain: 0.9483, Src VAT: 0.2215, Trg VAT: 0.3121, Src MixUp: 0.6206, Trg MixUp: 0.7128, Src Train Acc: 97.14, Trg Train Acc: 89.63, Src Test Acc: 92.22, Trg Test Acc: 86.93
# Epoch: 045, TotalL: 1.1219, CrossE: 0.1171, CondE: 0.3006, disc: 0.6507, domain: 0.9454, Src VAT: 0.2195, Trg VAT: 0.3006, Src MixUp: 0.6062, Trg MixUp: 0.6923, Src Train Acc: 97.22, Trg Train Acc: 88.67, Src Test Acc: 95.72, Trg Test Acc: 89.35
# Epoch: 046, TotalL: 1.0706, CrossE: 0.0971, CondE: 0.2809, disc: 0.6465, domain: 0.9580, Src VAT: 0.2004, Trg VAT: 0.2809, Src MixUp: 0.5986, Trg MixUp: 0.6617, Src Train Acc: 97.96, Trg Train Acc: 89.41, Src Test Acc: 94.16, Trg Test Acc: 87.19
# Epoch: 047, TotalL: 1.0667, CrossE: 0.1024, CondE: 0.2886, disc: 0.6486, domain: 0.9522, Src VAT: 0.2009, Trg VAT: 0.2886, Src MixUp: 0.5850, Trg MixUp: 0.7011, Src Train Acc: 97.27, Trg Train Acc: 89.54, Src Test Acc: 94.55, Trg Test Acc: 86.90
# Epoch: 048, TotalL: 1.0893, CrossE: 0.1147, CondE: 0.2901, disc: 0.6570, domain: 0.9333, Src VAT: 0.2075, Trg VAT: 0.2901, Src MixUp: 0.5903, Trg MixUp: 0.6949, Src Train Acc: 97.09, Trg Train Acc: 89.06, Src Test Acc: 95.33, Trg Test Acc: 88.42
# Epoch: 049, TotalL: 1.0178, CrossE: 0.0876, CondE: 0.2793, disc: 0.6478, domain: 0.9344, Src VAT: 0.1843, Trg VAT: 0.2793, Src MixUp: 0.5702, Trg MixUp: 0.7031, Src Train Acc: 97.87, Trg Train Acc: 89.80, Src Test Acc: 93.00, Trg Test Acc: 87.39
# Epoch: 050, TotalL: 1.0077, CrossE: 0.0947, CondE: 0.2840, disc: 0.6458, domain: 0.9492, Src VAT: 0.1860, Trg VAT: 0.2840, Src MixUp: 0.5491, Trg MixUp: 0.7067, Src Train Acc: 97.31, Trg Train Acc: 89.11, Src Test Acc: 94.55, Trg Test Acc: 89.12
# Epoch: 051, TotalL: 0.9874, CrossE: 0.0950, CondE: 0.2601, disc: 0.6533, domain: 0.9399, Src VAT: 0.1786, Trg VAT: 0.2601, Src MixUp: 0.5446, Trg MixUp: 0.6552, Src Train Acc: 97.53, Trg Train Acc: 89.76, Src Test Acc: 94.55, Trg Test Acc: 88.97
# Epoch: 052, TotalL: 0.9900, CrossE: 0.0870, CondE: 0.2590, disc: 0.6555, domain: 0.9309, Src VAT: 0.1779, Trg VAT: 0.2590, Src MixUp: 0.5555, Trg MixUp: 0.6718, Src Train Acc: 97.61, Trg Train Acc: 91.10, Src Test Acc: 92.61, Trg Test Acc: 83.91
# Epoch: 053, TotalL: 0.9723, CrossE: 0.0856, CondE: 0.2573, disc: 0.6462, domain: 0.9329, Src VAT: 0.1683, Trg VAT: 0.2573, Src MixUp: 0.5497, Trg MixUp: 0.6613, Src Train Acc: 97.83, Trg Train Acc: 91.10, Src Test Acc: 95.72, Trg Test Acc: 89.59
# Epoch: 054, TotalL: 0.9295, CrossE: 0.0738, CondE: 0.2479, disc: 0.6517, domain: 0.9253, Src VAT: 0.1584, Trg VAT: 0.2479, Src MixUp: 0.5311, Trg MixUp: 0.6570, Src Train Acc: 98.22, Trg Train Acc: 90.19, Src Test Acc: 96.11, Trg Test Acc: 89.18
# Epoch: 055, TotalL: 0.9059, CrossE: 0.0657, CondE: 0.2475, disc: 0.6476, domain: 0.9349, Src VAT: 0.1482, Trg VAT: 0.2475, Src MixUp: 0.5260, Trg MixUp: 0.6451, Src Train Acc: 98.61, Trg Train Acc: 90.62, Src Test Acc: 95.33, Trg Test Acc: 89.97
# Epoch: 056, TotalL: 0.9190, CrossE: 0.0704, CondE: 0.2394, disc: 0.6494, domain: 0.9263, Src VAT: 0.1515, Trg VAT: 0.2394, Src MixUp: 0.5328, Trg MixUp: 0.6487, Src Train Acc: 98.22, Trg Train Acc: 91.36, Src Test Acc: 95.72, Trg Test Acc: 89.85
# Epoch: 057, TotalL: 0.9015, CrossE: 0.0741, CondE: 0.2300, disc: 0.6535, domain: 0.9340, Src VAT: 0.1465, Trg VAT: 0.2300, Src MixUp: 0.5183, Trg MixUp: 0.6389, Src Train Acc: 98.13, Trg Train Acc: 91.97, Src Test Acc: 91.44, Trg Test Acc: 86.05
# Epoch: 058, TotalL: 0.9332, CrossE: 0.0798, CondE: 0.2434, disc: 0.6532, domain: 0.9162, Src VAT: 0.1563, Trg VAT: 0.2434, Src MixUp: 0.5342, Trg MixUp: 0.6330, Src Train Acc: 97.31, Trg Train Acc: 90.02, Src Test Acc: 95.72, Trg Test Acc: 89.85
# Epoch: 059, TotalL: 0.8455, CrossE: 0.0542, CondE: 0.2255, disc: 0.6409, domain: 0.9298, Src VAT: 0.1282, Trg VAT: 0.2255, Src MixUp: 0.5022, Trg MixUp: 0.6321, Src Train Acc: 98.65, Trg Train Acc: 91.28, Src Test Acc: 95.33, Trg Test Acc: 90.00
# Epoch: 060, TotalL: 0.8632, CrossE: 0.0601, CondE: 0.2261, disc: 0.6499, domain: 0.9274, Src VAT: 0.1363, Trg VAT: 0.2261, Src MixUp: 0.5073, Trg MixUp: 0.6148, Src Train Acc: 98.74, Trg Train Acc: 91.19, Src Test Acc: 95.72, Trg Test Acc: 91.08
# Epoch: 061, TotalL: 0.8404, CrossE: 0.0642, CondE: 0.2166, disc: 0.6496, domain: 0.9262, Src VAT: 0.1283, Trg VAT: 0.2166, Src MixUp: 0.4897, Trg MixUp: 0.6183, Src Train Acc: 98.18, Trg Train Acc: 91.45, Src Test Acc: 94.94, Trg Test Acc: 87.69
# Epoch: 062, TotalL: 0.8291, CrossE: 0.0551, CondE: 0.2140, disc: 0.6521, domain: 0.9235, Src VAT: 0.1248, Trg VAT: 0.2140, Src MixUp: 0.4914, Trg MixUp: 0.6199, Src Train Acc: 98.87, Trg Train Acc: 92.10, Src Test Acc: 97.28, Trg Test Acc: 91.46
# Epoch: 063, TotalL: 0.8298, CrossE: 0.0606, CondE: 0.2071, disc: 0.6507, domain: 0.9037, Src VAT: 0.1301, Trg VAT: 0.2071, Src MixUp: 0.4853, Trg MixUp: 0.6039, Src Train Acc: 98.44, Trg Train Acc: 91.62, Src Test Acc: 94.16, Trg Test Acc: 87.63
# Epoch: 064, TotalL: 0.8457, CrossE: 0.0587, CondE: 0.2150, disc: 0.6513, domain: 0.9225, Src VAT: 0.1298, Trg VAT: 0.2150, Src MixUp: 0.5004, Trg MixUp: 0.6066, Src Train Acc: 98.65, Trg Train Acc: 91.32, Src Test Acc: 96.50, Trg Test Acc: 90.23
# Epoch: 065, TotalL: 0.8487, CrossE: 0.0704, CondE: 0.2115, disc: 0.6428, domain: 0.9265, Src VAT: 0.1307, Trg VAT: 0.2115, Src MixUp: 0.4909, Trg MixUp: 0.6095, Src Train Acc: 98.05, Trg Train Acc: 90.76, Src Test Acc: 96.11, Trg Test Acc: 91.17
# Epoch: 066, TotalL: 0.7987, CrossE: 0.0523, CondE: 0.1999, disc: 0.6403, domain: 0.9376, Src VAT: 0.1145, Trg VAT: 0.1999, Src MixUp: 0.4757, Trg MixUp: 0.6157, Src Train Acc: 98.52, Trg Train Acc: 91.97, Src Test Acc: 94.94, Trg Test Acc: 89.38
# Epoch: 067, TotalL: 0.7914, CrossE: 0.0545, CondE: 0.2036, disc: 0.6532, domain: 0.9213, Src VAT: 0.1145, Trg VAT: 0.2036, Src MixUp: 0.4694, Trg MixUp: 0.5843, Src Train Acc: 98.52, Trg Train Acc: 92.23, Src Test Acc: 97.28, Trg Test Acc: 92.10
# Epoch: 068, TotalL: 0.7859, CrossE: 0.0489, CondE: 0.1953, disc: 0.6533, domain: 0.9178, Src VAT: 0.1143, Trg VAT: 0.1953, Src MixUp: 0.4718, Trg MixUp: 0.5774, Src Train Acc: 98.96, Trg Train Acc: 91.75, Src Test Acc: 96.11, Trg Test Acc: 90.52
# Epoch: 069, TotalL: 0.7743, CrossE: 0.0544, CondE: 0.1948, disc: 0.6540, domain: 0.9059, Src VAT: 0.1124, Trg VAT: 0.1948, Src MixUp: 0.4590, Trg MixUp: 0.5600, Src Train Acc: 98.57, Trg Train Acc: 91.97, Src Test Acc: 96.11, Trg Test Acc: 91.25
# Epoch: 070, TotalL: 0.7807, CrossE: 0.0483, CondE: 0.1913, disc: 0.6563, domain: 0.9029, Src VAT: 0.1105, Trg VAT: 0.1913, Src MixUp: 0.4725, Trg MixUp: 0.5832, Src Train Acc: 98.96, Trg Train Acc: 92.66, Src Test Acc: 96.50, Trg Test Acc: 91.93
# Epoch: 071, TotalL: 0.7457, CrossE: 0.0451, CondE: 0.1809, disc: 0.6486, domain: 0.9177, Src VAT: 0.1067, Trg VAT: 0.1809, Src MixUp: 0.4457, Trg MixUp: 0.5724, Src Train Acc: 99.05, Trg Train Acc: 92.71, Src Test Acc: 96.89, Trg Test Acc: 92.95
# Epoch: 072, TotalL: 0.7149, CrossE: 0.0385, CondE: 0.1809, disc: 0.6476, domain: 0.9190, Src VAT: 0.0960, Trg VAT: 0.1809, Src MixUp: 0.4332, Trg MixUp: 0.5584, Src Train Acc: 99.09, Trg Train Acc: 92.40, Src Test Acc: 96.11, Trg Test Acc: 91.34
# Epoch: 073, TotalL: 0.7465, CrossE: 0.0459, CondE: 0.1859, disc: 0.6482, domain: 0.9130, Src VAT: 0.1012, Trg VAT: 0.1859, Src MixUp: 0.4508, Trg MixUp: 0.5728, Src Train Acc: 98.78, Trg Train Acc: 92.27, Src Test Acc: 96.11, Trg Test Acc: 90.90
# Epoch: 074, TotalL: 0.7522, CrossE: 0.0545, CondE: 0.1826, disc: 0.6498, domain: 0.9022, Src VAT: 0.1036, Trg VAT: 0.1826, Src MixUp: 0.4475, Trg MixUp: 0.5645, Src Train Acc: 98.61, Trg Train Acc: 92.62, Src Test Acc: 97.67, Trg Test Acc: 89.21
# Epoch: 075, TotalL: 0.7122, CrossE: 0.0336, CondE: 0.1786, disc: 0.6488, domain: 0.9094, Src VAT: 0.0916, Trg VAT: 0.1786, Src MixUp: 0.4395, Trg MixUp: 0.5764, Src Train Acc: 99.39, Trg Train Acc: 92.32, Src Test Acc: 96.89, Trg Test Acc: 92.51
# Epoch: 076, TotalL: 0.7303, CrossE: 0.0403, CondE: 0.1830, disc: 0.6488, domain: 0.9188, Src VAT: 0.0977, Trg VAT: 0.1830, Src MixUp: 0.4441, Trg MixUp: 0.5669, Src Train Acc: 98.96, Trg Train Acc: 91.15, Src Test Acc: 96.89, Trg Test Acc: 90.96
# Epoch: 077, TotalL: 0.7245, CrossE: 0.0423, CondE: 0.1800, disc: 0.6461, domain: 0.9249, Src VAT: 0.0963, Trg VAT: 0.1800, Src MixUp: 0.4394, Trg MixUp: 0.5471, Src Train Acc: 99.05, Trg Train Acc: 92.62, Src Test Acc: 97.28, Trg Test Acc: 92.37
# Epoch: 078, TotalL: 0.7143, CrossE: 0.0408, CondE: 0.1699, disc: 0.6445, domain: 0.9079, Src VAT: 0.0896, Trg VAT: 0.1699, Src MixUp: 0.4395, Trg MixUp: 0.5576, Src Train Acc: 98.87, Trg Train Acc: 92.14, Src Test Acc: 96.89, Trg Test Acc: 93.68
# Epoch: 079, TotalL: 0.6942, CrossE: 0.0404, CondE: 0.1690, disc: 0.6453, domain: 0.9137, Src VAT: 0.0868, Trg VAT: 0.1690, Src MixUp: 0.4235, Trg MixUp: 0.5415, Src Train Acc: 98.87, Trg Train Acc: 93.36, Src Test Acc: 95.33, Trg Test Acc: 89.12
# Epoch: 080, TotalL: 0.7238, CrossE: 0.0408, CondE: 0.1708, disc: 0.6490, domain: 0.9166, Src VAT: 0.0911, Trg VAT: 0.1708, Src MixUp: 0.4473, Trg MixUp: 0.5488, Src Train Acc: 98.78, Trg Train Acc: 93.23, Src Test Acc: 96.89, Trg Test Acc: 93.48
# Epoch: 081, TotalL: 0.6843, CrossE: 0.0352, CondE: 0.1567, disc: 0.6457, domain: 0.9142, Src VAT: 0.0867, Trg VAT: 0.1567, Src MixUp: 0.4205, Trg MixUp: 0.5467, Src Train Acc: 99.22, Trg Train Acc: 93.32, Src Test Acc: 94.94, Trg Test Acc: 90.41
# Epoch: 082, TotalL: 0.6783, CrossE: 0.0418, CondE: 0.1624, disc: 0.6518, domain: 0.9036, Src VAT: 0.0843, Trg VAT: 0.1624, Src MixUp: 0.4116, Trg MixUp: 0.5304, Src Train Acc: 99.00, Trg Train Acc: 93.45, Src Test Acc: 97.28, Trg Test Acc: 91.46
# Epoch: 083, TotalL: 0.7016, CrossE: 0.0396, CondE: 0.1685, disc: 0.6496, domain: 0.8976, Src VAT: 0.0855, Trg VAT: 0.1685, Src MixUp: 0.4350, Trg MixUp: 0.5340, Src Train Acc: 98.83, Trg Train Acc: 93.79, Src Test Acc: 96.11, Trg Test Acc: 93.42
# Epoch: 084, TotalL: 0.6894, CrossE: 0.0431, CondE: 0.1591, disc: 0.6436, domain: 0.9112, Src VAT: 0.0854, Trg VAT: 0.1591, Src MixUp: 0.4214, Trg MixUp: 0.5141, Src Train Acc: 98.91, Trg Train Acc: 93.49, Src Test Acc: 97.28, Trg Test Acc: 92.48
# Epoch: 085, TotalL: 0.6651, CrossE: 0.0333, CondE: 0.1528, disc: 0.6521, domain: 0.9094, Src VAT: 0.0774, Trg VAT: 0.1528, Src MixUp: 0.4157, Trg MixUp: 0.5187, Src Train Acc: 99.22, Trg Train Acc: 93.62, Src Test Acc: 95.72, Trg Test Acc: 93.27
# Epoch: 086, TotalL: 0.6874, CrossE: 0.0338, CondE: 0.1598, disc: 0.6515, domain: 0.9049, Src VAT: 0.0829, Trg VAT: 0.1598, Src MixUp: 0.4304, Trg MixUp: 0.5285, Src Train Acc: 99.31, Trg Train Acc: 93.45, Src Test Acc: 96.50, Trg Test Acc: 92.57
# Epoch: 087, TotalL: 0.6408, CrossE: 0.0262, CondE: 0.1518, disc: 0.6525, domain: 0.9054, Src VAT: 0.0706, Trg VAT: 0.1518, Src MixUp: 0.4064, Trg MixUp: 0.5118, Src Train Acc: 99.48, Trg Train Acc: 93.36, Src Test Acc: 97.67, Trg Test Acc: 92.63
# Epoch: 088, TotalL: 0.6811, CrossE: 0.0405, CondE: 0.1565, disc: 0.6540, domain: 0.8938, Src VAT: 0.0836, Trg VAT: 0.1565, Src MixUp: 0.4158, Trg MixUp: 0.5582, Src Train Acc: 98.91, Trg Train Acc: 93.66, Src Test Acc: 96.50, Trg Test Acc: 90.38
# Epoch: 089, TotalL: 0.6361, CrossE: 0.0336, CondE: 0.1507, disc: 0.6487, domain: 0.9013, Src VAT: 0.0702, Trg VAT: 0.1507, Src MixUp: 0.3938, Trg MixUp: 0.5291, Src Train Acc: 99.26, Trg Train Acc: 93.79, Src Test Acc: 96.50, Trg Test Acc: 91.20
# Epoch: 090, TotalL: 0.6576, CrossE: 0.0243, CondE: 0.1484, disc: 0.6446, domain: 0.9055, Src VAT: 0.0696, Trg VAT: 0.1484, Src MixUp: 0.4244, Trg MixUp: 0.5393, Src Train Acc: 99.61, Trg Train Acc: 94.05, Src Test Acc: 98.05, Trg Test Acc: 92.95
# Epoch: 091, TotalL: 0.6731, CrossE: 0.0381, CondE: 0.1467, disc: 0.6585, domain: 0.8965, Src VAT: 0.0806, Trg VAT: 0.1467, Src MixUp: 0.4183, Trg MixUp: 0.5122, Src Train Acc: 98.83, Trg Train Acc: 94.01, Src Test Acc: 97.28, Trg Test Acc: 92.13
# Epoch: 092, TotalL: 0.6600, CrossE: 0.0334, CondE: 0.1480, disc: 0.6547, domain: 0.8859, Src VAT: 0.0745, Trg VAT: 0.1480, Src MixUp: 0.4175, Trg MixUp: 0.5007, Src Train Acc: 99.22, Trg Train Acc: 93.75, Src Test Acc: 97.28, Trg Test Acc: 92.10
# Epoch: 093, TotalL: 0.6168, CrossE: 0.0302, CondE: 0.1477, disc: 0.6451, domain: 0.8949, Src VAT: 0.0658, Trg VAT: 0.1477, Src MixUp: 0.3858, Trg MixUp: 0.4970, Src Train Acc: 99.44, Trg Train Acc: 93.66, Src Test Acc: 96.89, Trg Test Acc: 92.19
# Epoch: 094, TotalL: 0.6273, CrossE: 0.0318, CondE: 0.1477, disc: 0.6490, domain: 0.8998, Src VAT: 0.0691, Trg VAT: 0.1477, Src MixUp: 0.3897, Trg MixUp: 0.5121, Src Train Acc: 99.31, Trg Train Acc: 93.19, Src Test Acc: 96.11, Trg Test Acc: 91.93
# Epoch: 095, TotalL: 0.6187, CrossE: 0.0263, CondE: 0.1418, disc: 0.6547, domain: 0.8970, Src VAT: 0.0659, Trg VAT: 0.1418, Src MixUp: 0.3918, Trg MixUp: 0.5019, Src Train Acc: 99.44, Trg Train Acc: 93.92, Src Test Acc: 95.72, Trg Test Acc: 87.25
# Epoch: 096, TotalL: 0.6467, CrossE: 0.0343, CondE: 0.1516, disc: 0.6565, domain: 0.8847, Src VAT: 0.0714, Trg VAT: 0.1516, Src MixUp: 0.4038, Trg MixUp: 0.5266, Src Train Acc: 99.26, Trg Train Acc: 93.40, Src Test Acc: 94.94, Trg Test Acc: 90.03
# Epoch: 097, TotalL: 0.6009, CrossE: 0.0225, CondE: 0.1396, disc: 0.6464, domain: 0.8936, Src VAT: 0.0617, Trg VAT: 0.1396, Src MixUp: 0.3821, Trg MixUp: 0.5100, Src Train Acc: 99.65, Trg Train Acc: 94.10, Src Test Acc: 96.89, Trg Test Acc: 93.10
# Epoch: 098, TotalL: 0.6039, CrossE: 0.0215, CondE: 0.1435, disc: 0.6500, domain: 0.8961, Src VAT: 0.0591, Trg VAT: 0.1435, Src MixUp: 0.3885, Trg MixUp: 0.5016, Src Train Acc: 99.70, Trg Train Acc: 94.05, Src Test Acc: 93.77, Trg Test Acc: 83.59
# Epoch: 099, TotalL: 0.6128, CrossE: 0.0318, CondE: 0.1428, disc: 0.6601, domain: 0.8785, Src VAT: 0.0644, Trg VAT: 0.1428, Src MixUp: 0.3843, Trg MixUp: 0.4902, Src Train Acc: 99.09, Trg Train Acc: 93.75, Src Test Acc: 97.28, Trg Test Acc: 93.57
# Epoch: 100, TotalL: 0.6520, CrossE: 0.0282, CondE: 0.1465, disc: 0.6579, domain: 0.8871, Src VAT: 0.0725, Trg VAT: 0.1465, Src MixUp: 0.4150, Trg MixUp: 0.5235, Src Train Acc: 99.35, Trg Train Acc: 92.84, Src Test Acc: 97.28, Trg Test Acc: 90.14
# Epoch: 101, TotalL: 0.6124, CrossE: 0.0299, CondE: 0.1371, disc: 0.6507, domain: 0.8864, Src VAT: 0.0624, Trg VAT: 0.1371, Src MixUp: 0.3868, Trg MixUp: 0.5065, Src Train Acc: 99.35, Trg Train Acc: 93.88, Src Test Acc: 94.16, Trg Test Acc: 86.98
# Epoch: 102, TotalL: 0.6555, CrossE: 0.0475, CondE: 0.1476, disc: 0.6522, domain: 0.8862, Src VAT: 0.0732, Trg VAT: 0.1476, Src MixUp: 0.3991, Trg MixUp: 0.5143, Src Train Acc: 98.52, Trg Train Acc: 93.40, Src Test Acc: 98.05, Trg Test Acc: 89.91
# Epoch: 103, TotalL: 0.5882, CrossE: 0.0204, CondE: 0.1250, disc: 0.6531, domain: 0.8862, Src VAT: 0.0576, Trg VAT: 0.1250, Src MixUp: 0.3792, Trg MixUp: 0.5027, Src Train Acc: 99.65, Trg Train Acc: 94.14, Src Test Acc: 96.89, Trg Test Acc: 93.19
# Epoch: 104, TotalL: 0.5765, CrossE: 0.0206, CondE: 0.1198, disc: 0.6499, domain: 0.8854, Src VAT: 0.0532, Trg VAT: 0.1198, Src MixUp: 0.3720, Trg MixUp: 0.5081, Src Train Acc: 99.61, Trg Train Acc: 95.18, Src Test Acc: 97.67, Trg Test Acc: 91.81
# Epoch: 105, TotalL: 0.6593, CrossE: 0.0362, CondE: 0.1458, disc: 0.6503, domain: 0.8824, Src VAT: 0.0763, Trg VAT: 0.1458, Src MixUp: 0.4120, Trg MixUp: 0.5120, Src Train Acc: 99.05, Trg Train Acc: 93.53, Src Test Acc: 97.67, Trg Test Acc: 91.05
# Epoch: 106, TotalL: 0.5813, CrossE: 0.0183, CondE: 0.1224, disc: 0.6584, domain: 0.8787, Src VAT: 0.0522, Trg VAT: 0.1224, Src MixUp: 0.3819, Trg MixUp: 0.4888, Src Train Acc: 99.57, Trg Train Acc: 94.70, Src Test Acc: 98.05, Trg Test Acc: 92.22
# Epoch: 107, TotalL: 0.6191, CrossE: 0.0320, CondE: 0.1349, disc: 0.6629, domain: 0.8700, Src VAT: 0.0701, Trg VAT: 0.1349, Src MixUp: 0.3875, Trg MixUp: 0.4789, Src Train Acc: 99.22, Trg Train Acc: 93.14, Src Test Acc: 96.11, Trg Test Acc: 91.14
# Epoch: 108, TotalL: 0.5943, CrossE: 0.0240, CondE: 0.1266, disc: 0.6545, domain: 0.8651, Src VAT: 0.0565, Trg VAT: 0.1266, Src MixUp: 0.3838, Trg MixUp: 0.5057, Src Train Acc: 99.48, Trg Train Acc: 94.10, Src Test Acc: 97.28, Trg Test Acc: 93.95
# Epoch: 109, TotalL: 0.5578, CrossE: 0.0169, CondE: 0.1141, disc: 0.6494, domain: 0.8779, Src VAT: 0.0492, Trg VAT: 0.1141, Src MixUp: 0.3666, Trg MixUp: 0.4579, Src Train Acc: 99.61, Trg Train Acc: 94.79, Src Test Acc: 98.05, Trg Test Acc: 93.04
# Epoch: 110, TotalL: 0.5767, CrossE: 0.0217, CondE: 0.1229, disc: 0.6540, domain: 0.8749, Src VAT: 0.0559, Trg VAT: 0.1229, Src MixUp: 0.3715, Trg MixUp: 0.4732, Src Train Acc: 99.39, Trg Train Acc: 95.01, Src Test Acc: 98.05, Trg Test Acc: 91.46
# Epoch: 111, TotalL: 0.6414, CrossE: 0.0390, CondE: 0.1394, disc: 0.6631, domain: 0.8585, Src VAT: 0.0689, Trg VAT: 0.1394, Src MixUp: 0.4017, Trg MixUp: 0.5103, Src Train Acc: 99.09, Trg Train Acc: 93.23, Src Test Acc: 96.89, Trg Test Acc: 92.69
# Epoch: 112, TotalL: 0.5861, CrossE: 0.0244, CondE: 0.1239, disc: 0.6508, domain: 0.8703, Src VAT: 0.0590, Trg VAT: 0.1239, Src MixUp: 0.3761, Trg MixUp: 0.4650, Src Train Acc: 99.57, Trg Train Acc: 94.10, Src Test Acc: 98.05, Trg Test Acc: 92.42
# Epoch: 113, TotalL: 0.5422, CrossE: 0.0190, CondE: 0.1139, disc: 0.6479, domain: 0.8900, Src VAT: 0.0439, Trg VAT: 0.1139, Src MixUp: 0.3522, Trg MixUp: 0.4711, Src Train Acc: 99.74, Trg Train Acc: 95.36, Src Test Acc: 98.44, Trg Test Acc: 93.42
# Epoch: 114, TotalL: 0.5724, CrossE: 0.0211, CondE: 0.1201, disc: 0.6630, domain: 0.8603, Src VAT: 0.0566, Trg VAT: 0.1201, Src MixUp: 0.3684, Trg MixUp: 0.4778, Src Train Acc: 99.57, Trg Train Acc: 93.92, Src Test Acc: 98.05, Trg Test Acc: 94.68
# Epoch: 115, TotalL: 0.5302, CrossE: 0.0189, CondE: 0.1092, disc: 0.6553, domain: 0.8735, Src VAT: 0.0466, Trg VAT: 0.1092, Src MixUp: 0.3406, Trg MixUp: 0.4590, Src Train Acc: 99.57, Trg Train Acc: 94.79, Src Test Acc: 97.67, Trg Test Acc: 93.19
# Epoch: 116, TotalL: 0.5466, CrossE: 0.0213, CondE: 0.1098, disc: 0.6566, domain: 0.8785, Src VAT: 0.0472, Trg VAT: 0.1098, Src MixUp: 0.3517, Trg MixUp: 0.4814, Src Train Acc: 99.52, Trg Train Acc: 95.10, Src Test Acc: 96.50, Trg Test Acc: 91.05
# Epoch: 117, TotalL: 0.5497, CrossE: 0.0205, CondE: 0.1180, disc: 0.6508, domain: 0.8682, Src VAT: 0.0468, Trg VAT: 0.1180, Src MixUp: 0.3569, Trg MixUp: 0.4651, Src Train Acc: 99.48, Trg Train Acc: 94.62, Src Test Acc: 96.50, Trg Test Acc: 91.81
# Epoch: 118, TotalL: 0.5421, CrossE: 0.0249, CondE: 0.1126, disc: 0.6495, domain: 0.8817, Src VAT: 0.0503, Trg VAT: 0.1126, Src MixUp: 0.3413, Trg MixUp: 0.4624, Src Train Acc: 99.26, Trg Train Acc: 95.10, Src Test Acc: 96.50, Trg Test Acc: 89.79
# Epoch: 119, TotalL: 0.5539, CrossE: 0.0240, CondE: 0.1147, disc: 0.6554, domain: 0.8748, Src VAT: 0.0536, Trg VAT: 0.1147, Src MixUp: 0.3509, Trg MixUp: 0.4638, Src Train Acc: 99.26, Trg Train Acc: 94.14, Src Test Acc: 96.11, Trg Test Acc: 89.68
# Epoch: 120, TotalL: 0.5564, CrossE: 0.0206, CondE: 0.1147, disc: 0.6588, domain: 0.8587, Src VAT: 0.0499, Trg VAT: 0.1147, Src MixUp: 0.3643, Trg MixUp: 0.4309, Src Train Acc: 99.61, Trg Train Acc: 94.18, Src Test Acc: 96.89, Trg Test Acc: 94.41
# Epoch: 121, TotalL: 0.5539, CrossE: 0.0255, CondE: 0.1142, disc: 0.6578, domain: 0.8762, Src VAT: 0.0487, Trg VAT: 0.1142, Src MixUp: 0.3543, Trg MixUp: 0.4633, Src Train Acc: 99.22, Trg Train Acc: 95.27, Src Test Acc: 98.05, Trg Test Acc: 95.41
# Epoch: 122, TotalL: 0.5494, CrossE: 0.0188, CondE: 0.1116, disc: 0.6552, domain: 0.8658, Src VAT: 0.0478, Trg VAT: 0.1116, Src MixUp: 0.3593, Trg MixUp: 0.4553, Src Train Acc: 99.52, Trg Train Acc: 94.66, Src Test Acc: 97.28, Trg Test Acc: 94.71
# Epoch: 123, TotalL: 0.6235, CrossE: 0.0474, CondE: 0.1315, disc: 0.6632, domain: 0.8617, Src VAT: 0.0657, Trg VAT: 0.1315, Src MixUp: 0.3814, Trg MixUp: 0.4890, Src Train Acc: 98.57, Trg Train Acc: 93.84, Src Test Acc: 97.28, Trg Test Acc: 86.34
# Epoch: 124, TotalL: 0.5154, CrossE: 0.0133, CondE: 0.0982, disc: 0.6491, domain: 0.8641, Src VAT: 0.0410, Trg VAT: 0.0982, Src MixUp: 0.3411, Trg MixUp: 0.4396, Src Train Acc: 99.83, Trg Train Acc: 95.57, Src Test Acc: 97.67, Trg Test Acc: 91.81
# Epoch: 125, TotalL: 0.5388, CrossE: 0.0254, CondE: 0.1117, disc: 0.6627, domain: 0.8464, Src VAT: 0.0478, Trg VAT: 0.1117, Src MixUp: 0.3426, Trg MixUp: 0.4674, Src Train Acc: 99.26, Trg Train Acc: 95.36, Src Test Acc: 98.05, Trg Test Acc: 94.30
# Epoch: 126, TotalL: 0.5228, CrossE: 0.0132, CondE: 0.1073, disc: 0.6546, domain: 0.8698, Src VAT: 0.0438, Trg VAT: 0.1073, Src MixUp: 0.3413, Trg MixUp: 0.4725, Src Train Acc: 99.91, Trg Train Acc: 95.49, Src Test Acc: 97.28, Trg Test Acc: 92.34
# Epoch: 127, TotalL: 0.5403, CrossE: 0.0155, CondE: 0.1027, disc: 0.6520, domain: 0.8666, Src VAT: 0.0414, Trg VAT: 0.1027, Src MixUp: 0.3631, Trg MixUp: 0.4319, Src Train Acc: 99.52, Trg Train Acc: 96.01, Src Test Acc: 96.50, Trg Test Acc: 90.00
# Epoch: 128, TotalL: 0.4999, CrossE: 0.0101, CondE: 0.1004, disc: 0.6458, domain: 0.8721, Src VAT: 0.0333, Trg VAT: 0.1004, Src MixUp: 0.3354, Trg MixUp: 0.4415, Src Train Acc: 99.91, Trg Train Acc: 95.62, Src Test Acc: 96.11, Trg Test Acc: 92.80
# Epoch: 129, TotalL: 0.5530, CrossE: 0.0280, CondE: 0.1084, disc: 0.6570, domain: 0.8628, Src VAT: 0.0496, Trg VAT: 0.1084, Src MixUp: 0.3528, Trg MixUp: 0.4527, Src Train Acc: 99.22, Trg Train Acc: 95.23, Src Test Acc: 96.89, Trg Test Acc: 93.83
# Epoch: 130, TotalL: 0.5090, CrossE: 0.0163, CondE: 0.0966, disc: 0.6590, domain: 0.8544, Src VAT: 0.0426, Trg VAT: 0.0966, Src MixUp: 0.3321, Trg MixUp: 0.4264, Src Train Acc: 99.70, Trg Train Acc: 95.53, Src Test Acc: 98.44, Trg Test Acc: 94.36
# Epoch: 131, TotalL: 0.5305, CrossE: 0.0241, CondE: 0.1020, disc: 0.6603, domain: 0.8493, Src VAT: 0.0490, Trg VAT: 0.1020, Src MixUp: 0.3381, Trg MixUp: 0.4380, Src Train Acc: 99.39, Trg Train Acc: 95.53, Src Test Acc: 96.89, Trg Test Acc: 90.58
# Epoch: 132, TotalL: 0.5445, CrossE: 0.0210, CondE: 0.1040, disc: 0.6571, domain: 0.8477, Src VAT: 0.0445, Trg VAT: 0.1040, Src MixUp: 0.3584, Trg MixUp: 0.4519, Src Train Acc: 99.48, Trg Train Acc: 95.66, Src Test Acc: 97.67, Trg Test Acc: 93.65
# Epoch: 133, TotalL: 0.5489, CrossE: 0.0210, CondE: 0.1042, disc: 0.6593, domain: 0.8579, Src VAT: 0.0503, Trg VAT: 0.1042, Src MixUp: 0.3569, Trg MixUp: 0.4416, Src Train Acc: 99.26, Trg Train Acc: 95.18, Src Test Acc: 96.11, Trg Test Acc: 93.04
# Epoch: 134, TotalL: 0.5395, CrossE: 0.0203, CondE: 0.1073, disc: 0.6554, domain: 0.8549, Src VAT: 0.0473, Trg VAT: 0.1073, Src MixUp: 0.3504, Trg MixUp: 0.4492, Src Train Acc: 99.44, Trg Train Acc: 95.23, Src Test Acc: 98.05, Trg Test Acc: 91.40
# Epoch: 135, TotalL: 0.5105, CrossE: 0.0171, CondE: 0.1079, disc: 0.6600, domain: 0.8616, Src VAT: 0.0423, Trg VAT: 0.1079, Src MixUp: 0.3291, Trg MixUp: 0.4473, Src Train Acc: 99.52, Trg Train Acc: 94.92, Src Test Acc: 98.05, Trg Test Acc: 94.12
# Epoch: 136, TotalL: 0.5216, CrossE: 0.0170, CondE: 0.1058, disc: 0.6558, domain: 0.8557, Src VAT: 0.0443, Trg VAT: 0.1058, Src MixUp: 0.3395, Trg MixUp: 0.4425, Src Train Acc: 99.61, Trg Train Acc: 95.62, Src Test Acc: 97.28, Trg Test Acc: 94.79
# Epoch: 137, TotalL: 0.5184, CrossE: 0.0195, CondE: 0.0992, disc: 0.6586, domain: 0.8561, Src VAT: 0.0455, Trg VAT: 0.0992, Src MixUp: 0.3321, Trg MixUp: 0.4611, Src Train Acc: 99.48, Trg Train Acc: 95.44, Src Test Acc: 97.28, Trg Test Acc: 94.85
# Epoch: 138, TotalL: 0.5320, CrossE: 0.0205, CondE: 0.1037, disc: 0.6547, domain: 0.8600, Src VAT: 0.0474, Trg VAT: 0.1037, Src MixUp: 0.3434, Trg MixUp: 0.4406, Src Train Acc: 99.48, Trg Train Acc: 94.70, Src Test Acc: 96.89, Trg Test Acc: 91.46
# Epoch: 139, TotalL: 0.5026, CrossE: 0.0185, CondE: 0.1049, disc: 0.6573, domain: 0.8566, Src VAT: 0.0424, Trg VAT: 0.1049, Src MixUp: 0.3199, Trg MixUp: 0.4558, Src Train Acc: 99.52, Trg Train Acc: 95.18, Src Test Acc: 98.44, Trg Test Acc: 91.81
# Epoch: 140, TotalL: 0.5341, CrossE: 0.0253, CondE: 0.1089, disc: 0.6691, domain: 0.8467, Src VAT: 0.0536, Trg VAT: 0.1089, Src MixUp: 0.3359, Trg MixUp: 0.4269, Src Train Acc: 99.26, Trg Train Acc: 94.92, Src Test Acc: 96.50, Trg Test Acc: 89.76
# Epoch: 141, TotalL: 0.5179, CrossE: 0.0165, CondE: 0.1008, disc: 0.6530, domain: 0.8449, Src VAT: 0.0394, Trg VAT: 0.1008, Src MixUp: 0.3433, Trg MixUp: 0.4368, Src Train Acc: 99.52, Trg Train Acc: 95.49, Src Test Acc: 97.67, Trg Test Acc: 93.97
# Epoch: 142, TotalL: 0.5253, CrossE: 0.0217, CondE: 0.1035, disc: 0.6572, domain: 0.8567, Src VAT: 0.0451, Trg VAT: 0.1035, Src MixUp: 0.3367, Trg MixUp: 0.4588, Src Train Acc: 99.44, Trg Train Acc: 94.88, Src Test Acc: 98.44, Trg Test Acc: 94.79
# Epoch: 143, TotalL: 0.5094, CrossE: 0.0158, CondE: 0.1017, disc: 0.6491, domain: 0.8608, Src VAT: 0.0373, Trg VAT: 0.1017, Src MixUp: 0.3354, Trg MixUp: 0.4478, Src Train Acc: 99.57, Trg Train Acc: 96.22, Src Test Acc: 97.67, Trg Test Acc: 95.41
# Epoch: 144, TotalL: 0.5093, CrossE: 0.0222, CondE: 0.0999, disc: 0.6622, domain: 0.8466, Src VAT: 0.0419, Trg VAT: 0.0999, Src MixUp: 0.3267, Trg MixUp: 0.4358, Src Train Acc: 99.22, Trg Train Acc: 96.22, Src Test Acc: 96.89, Trg Test Acc: 93.86
# Epoch: 145, TotalL: 0.4941, CrossE: 0.0129, CondE: 0.0848, disc: 0.6551, domain: 0.8439, Src VAT: 0.0352, Trg VAT: 0.0848, Src MixUp: 0.3301, Trg MixUp: 0.4351, Src Train Acc: 99.74, Trg Train Acc: 96.14, Src Test Acc: 97.67, Trg Test Acc: 93.77
# Epoch: 146, TotalL: 0.5325, CrossE: 0.0427, CondE: 0.0964, disc: 0.6570, domain: 0.8509, Src VAT: 0.0412, Trg VAT: 0.0964, Src MixUp: 0.3308, Trg MixUp: 0.4284, Src Train Acc: 99.00, Trg Train Acc: 94.88, Src Test Acc: 96.89, Trg Test Acc: 94.76
# Epoch: 147, TotalL: 0.5006, CrossE: 0.0145, CondE: 0.0950, disc: 0.6533, domain: 0.8502, Src VAT: 0.0374, Trg VAT: 0.0950, Src MixUp: 0.3309, Trg MixUp: 0.4328, Src Train Acc: 99.74, Trg Train Acc: 96.05, Src Test Acc: 97.28, Trg Test Acc: 94.76
# Epoch: 148, TotalL: 0.4705, CrossE: 0.0089, CondE: 0.0903, disc: 0.6499, domain: 0.8611, Src VAT: 0.0291, Trg VAT: 0.0903, Src MixUp: 0.3153, Trg MixUp: 0.4245, Src Train Acc: 99.83, Trg Train Acc: 96.01, Src Test Acc: 96.89, Trg Test Acc: 92.22
# Epoch: 149, TotalL: 0.5455, CrossE: 0.0266, CondE: 0.0948, disc: 0.6630, domain: 0.8354, Src VAT: 0.0453, Trg VAT: 0.0948, Src MixUp: 0.3567, Trg MixUp: 0.4364, Src Train Acc: 99.13, Trg Train Acc: 95.57, Src Test Acc: 98.05, Trg Test Acc: 95.50
# Epoch: 150, TotalL: 0.5012, CrossE: 0.0229, CondE: 0.0899, disc: 0.6530, domain: 0.8552, Src VAT: 0.0362, Trg VAT: 0.0899, Src MixUp: 0.3260, Trg MixUp: 0.4163, Src Train Acc: 99.26, Trg Train Acc: 95.79, Src Test Acc: 97.67, Trg Test Acc: 94.30
# Epoch: 151, TotalL: 0.4982, CrossE: 0.0151, CondE: 0.0905, disc: 0.6640, domain: 0.8371, Src VAT: 0.0409, Trg VAT: 0.0905, Src MixUp: 0.3273, Trg MixUp: 0.4196, Src Train Acc: 99.57, Trg Train Acc: 95.23, Src Test Acc: 98.05, Trg Test Acc: 93.16
# Epoch: 152, TotalL: 0.4714, CrossE: 0.0110, CondE: 0.0907, disc: 0.6537, domain: 0.8472, Src VAT: 0.0335, Trg VAT: 0.0907, Src MixUp: 0.3116, Trg MixUp: 0.4131, Src Train Acc: 99.87, Trg Train Acc: 96.01, Src Test Acc: 97.67, Trg Test Acc: 94.88
# Epoch: 153, TotalL: 0.5107, CrossE: 0.0230, CondE: 0.0913, disc: 0.6527, domain: 0.8566, Src VAT: 0.0412, Trg VAT: 0.0913, Src MixUp: 0.3279, Trg MixUp: 0.4439, Src Train Acc: 99.26, Trg Train Acc: 95.88, Src Test Acc: 98.05, Trg Test Acc: 92.95
# Epoch: 154, TotalL: 0.5144, CrossE: 0.0162, CondE: 0.0954, disc: 0.6616, domain: 0.8441, Src VAT: 0.0441, Trg VAT: 0.0954, Src MixUp: 0.3365, Trg MixUp: 0.4365, Src Train Acc: 99.74, Trg Train Acc: 95.96, Src Test Acc: 97.28, Trg Test Acc: 91.69
# Epoch: 155, TotalL: 0.5373, CrossE: 0.0240, CondE: 0.1018, disc: 0.6637, domain: 0.8296, Src VAT: 0.0451, Trg VAT: 0.1018, Src MixUp: 0.3489, Trg MixUp: 0.4575, Src Train Acc: 99.48, Trg Train Acc: 95.23, Src Test Acc: 98.44, Trg Test Acc: 94.12
# Epoch: 156, TotalL: 0.4789, CrossE: 0.0126, CondE: 0.0959, disc: 0.6585, domain: 0.8450, Src VAT: 0.0333, Trg VAT: 0.0959, Src MixUp: 0.3169, Trg MixUp: 0.4147, Src Train Acc: 99.74, Trg Train Acc: 96.31, Src Test Acc: 98.05, Trg Test Acc: 94.62
# Epoch: 157, TotalL: 0.4570, CrossE: 0.0090, CondE: 0.0864, disc: 0.6579, domain: 0.8436, Src VAT: 0.0291, Trg VAT: 0.0864, Src MixUp: 0.3032, Trg MixUp: 0.4289, Src Train Acc: 99.91, Trg Train Acc: 96.27, Src Test Acc: 96.89, Trg Test Acc: 89.91
# Epoch: 158, TotalL: 0.4826, CrossE: 0.0139, CondE: 0.0813, disc: 0.6593, domain: 0.8432, Src VAT: 0.0383, Trg VAT: 0.0813, Src MixUp: 0.3163, Trg MixUp: 0.4197, Src Train Acc: 99.74, Trg Train Acc: 96.31, Src Test Acc: 94.55, Trg Test Acc: 93.24
# Epoch: 159, TotalL: 0.5003, CrossE: 0.0195, CondE: 0.0860, disc: 0.6665, domain: 0.8360, Src VAT: 0.0438, Trg VAT: 0.0860, Src MixUp: 0.3222, Trg MixUp: 0.4267, Src Train Acc: 99.48, Trg Train Acc: 96.01, Src Test Acc: 96.89, Trg Test Acc: 90.49
# Epoch: 160, TotalL: 0.5043, CrossE: 0.0165, CondE: 0.0988, disc: 0.6568, domain: 0.8405, Src VAT: 0.0391, Trg VAT: 0.0988, Src MixUp: 0.3293, Trg MixUp: 0.4537, Src Train Acc: 99.57, Trg Train Acc: 95.44, Src Test Acc: 98.05, Trg Test Acc: 95.00
# Epoch: 161, TotalL: 0.5166, CrossE: 0.0221, CondE: 0.1013, disc: 0.6621, domain: 0.8387, Src VAT: 0.0431, Trg VAT: 0.1013, Src MixUp: 0.3324, Trg MixUp: 0.4475, Src Train Acc: 99.35, Trg Train Acc: 95.01, Src Test Acc: 98.44, Trg Test Acc: 91.87
# Epoch: 162, TotalL: 0.4841, CrossE: 0.0163, CondE: 0.0923, disc: 0.6575, domain: 0.8389, Src VAT: 0.0370, Trg VAT: 0.0923, Src MixUp: 0.3136, Trg MixUp: 0.4409, Src Train Acc: 99.48, Trg Train Acc: 95.62, Src Test Acc: 98.05, Trg Test Acc: 95.00
# Epoch: 163, TotalL: 0.4674, CrossE: 0.0113, CondE: 0.0889, disc: 0.6525, domain: 0.8477, Src VAT: 0.0313, Trg VAT: 0.0889, Src MixUp: 0.3083, Trg MixUp: 0.4311, Src Train Acc: 99.65, Trg Train Acc: 96.53, Src Test Acc: 98.05, Trg Test Acc: 91.87
# Epoch: 164, TotalL: 0.4894, CrossE: 0.0185, CondE: 0.0962, disc: 0.6540, domain: 0.8422, Src VAT: 0.0363, Trg VAT: 0.0962, Src MixUp: 0.3176, Trg MixUp: 0.4291, Src Train Acc: 99.52, Trg Train Acc: 96.44, Src Test Acc: 98.05, Trg Test Acc: 94.65
# Epoch: 165, TotalL: 0.4606, CrossE: 0.0109, CondE: 0.0812, disc: 0.6555, domain: 0.8456, Src VAT: 0.0327, Trg VAT: 0.0812, Src MixUp: 0.3031, Trg MixUp: 0.4148, Src Train Acc: 99.74, Trg Train Acc: 96.05, Src Test Acc: 98.05, Trg Test Acc: 95.23
# Epoch: 166, TotalL: 0.5061, CrossE: 0.0197, CondE: 0.0916, disc: 0.6602, domain: 0.8396, Src VAT: 0.0443, Trg VAT: 0.0916, Src MixUp: 0.3254, Trg MixUp: 0.4350, Src Train Acc: 99.48, Trg Train Acc: 95.05, Src Test Acc: 96.89, Trg Test Acc: 91.14
# Epoch: 167, TotalL: 0.4719, CrossE: 0.0175, CondE: 0.0848, disc: 0.6567, domain: 0.8528, Src VAT: 0.0382, Trg VAT: 0.0848, Src MixUp: 0.3011, Trg MixUp: 0.4161, Src Train Acc: 99.44, Trg Train Acc: 95.57, Src Test Acc: 98.44, Trg Test Acc: 93.07
# Epoch: 168, TotalL: 0.4946, CrossE: 0.0194, CondE: 0.0864, disc: 0.6545, domain: 0.8455, Src VAT: 0.0373, Trg VAT: 0.0864, Src MixUp: 0.3234, Trg MixUp: 0.4140, Src Train Acc: 99.39, Trg Train Acc: 95.70, Src Test Acc: 98.44, Trg Test Acc: 92.69
# Epoch: 169, TotalL: 0.4751, CrossE: 0.0147, CondE: 0.0805, disc: 0.6614, domain: 0.8329, Src VAT: 0.0319, Trg VAT: 0.0805, Src MixUp: 0.3156, Trg MixUp: 0.4157, Src Train Acc: 99.65, Trg Train Acc: 96.66, Src Test Acc: 98.05, Trg Test Acc: 93.27
# Epoch: 170, TotalL: 0.4899, CrossE: 0.0181, CondE: 0.0904, disc: 0.6559, domain: 0.8456, Src VAT: 0.0372, Trg VAT: 0.0904, Src MixUp: 0.3182, Trg MixUp: 0.4279, Src Train Acc: 99.52, Trg Train Acc: 95.70, Src Test Acc: 97.28, Trg Test Acc: 92.07
# Epoch: 171, TotalL: 0.4464, CrossE: 0.0105, CondE: 0.0798, disc: 0.6513, domain: 0.8529, Src VAT: 0.0312, Trg VAT: 0.0798, Src MixUp: 0.2915, Trg MixUp: 0.4034, Src Train Acc: 99.83, Trg Train Acc: 96.14, Src Test Acc: 97.67, Trg Test Acc: 94.38
# Epoch: 172, TotalL: 0.4851, CrossE: 0.0167, CondE: 0.0812, disc: 0.6563, domain: 0.8492, Src VAT: 0.0402, Trg VAT: 0.0812, Src MixUp: 0.3128, Trg MixUp: 0.4305, Src Train Acc: 99.74, Trg Train Acc: 96.48, Src Test Acc: 96.50, Trg Test Acc: 88.59
# Epoch: 173, TotalL: 0.4807, CrossE: 0.0142, CondE: 0.0916, disc: 0.6573, domain: 0.8484, Src VAT: 0.0350, Trg VAT: 0.0916, Src MixUp: 0.3147, Trg MixUp: 0.4293, Src Train Acc: 99.65, Trg Train Acc: 96.09, Src Test Acc: 95.72, Trg Test Acc: 92.10
# Epoch: 174, TotalL: 0.4755, CrossE: 0.0141, CondE: 0.0824, disc: 0.6592, domain: 0.8517, Src VAT: 0.0370, Trg VAT: 0.0824, Src MixUp: 0.3098, Trg MixUp: 0.4144, Src Train Acc: 99.65, Trg Train Acc: 96.27, Src Test Acc: 96.89, Trg Test Acc: 94.21
# Epoch: 175, TotalL: 0.4408, CrossE: 0.0097, CondE: 0.0821, disc: 0.6567, domain: 0.8348, Src VAT: 0.0275, Trg VAT: 0.0821, Src MixUp: 0.2919, Trg MixUp: 0.3961, Src Train Acc: 99.83, Trg Train Acc: 96.61, Src Test Acc: 97.28, Trg Test Acc: 94.21
# Epoch: 176, TotalL: 0.5113, CrossE: 0.0214, CondE: 0.0908, disc: 0.6586, domain: 0.8462, Src VAT: 0.0446, Trg VAT: 0.0908, Src MixUp: 0.3298, Trg MixUp: 0.4162, Src Train Acc: 99.31, Trg Train Acc: 95.14, Src Test Acc: 97.67, Trg Test Acc: 93.16
# Epoch: 177, TotalL: 0.4664, CrossE: 0.0091, CondE: 0.0826, disc: 0.6606, domain: 0.8314, Src VAT: 0.0288, Trg VAT: 0.0826, Src MixUp: 0.3149, Trg MixUp: 0.4243, Src Train Acc: 99.83, Trg Train Acc: 96.22, Src Test Acc: 97.67, Trg Test Acc: 96.23
# Epoch: 178, TotalL: 0.4403, CrossE: 0.0111, CondE: 0.0775, disc: 0.6549, domain: 0.8420, Src VAT: 0.0284, Trg VAT: 0.0775, Src MixUp: 0.2883, Trg MixUp: 0.4088, Src Train Acc: 99.65, Trg Train Acc: 96.66, Src Test Acc: 96.89, Trg Test Acc: 93.74
# Epoch: 179, TotalL: 0.4717, CrossE: 0.0128, CondE: 0.0880, disc: 0.6635, domain: 0.8286, Src VAT: 0.0369, Trg VAT: 0.0880, Src MixUp: 0.3079, Trg MixUp: 0.4214, Src Train Acc: 99.78, Trg Train Acc: 95.27, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 180, TotalL: 0.4630, CrossE: 0.0106, CondE: 0.0771, disc: 0.6558, domain: 0.8355, Src VAT: 0.0288, Trg VAT: 0.0771, Src MixUp: 0.3111, Trg MixUp: 0.4182, Src Train Acc: 99.65, Trg Train Acc: 95.70, Src Test Acc: 98.44, Trg Test Acc: 95.82
# Epoch: 181, TotalL: 0.4168, CrossE: 0.0049, CondE: 0.0688, disc: 0.6499, domain: 0.8511, Src VAT: 0.0201, Trg VAT: 0.0688, Src MixUp: 0.2829, Trg MixUp: 0.3735, Src Train Acc: 99.96, Trg Train Acc: 97.14, Src Test Acc: 98.05, Trg Test Acc: 93.19
# Epoch: 182, TotalL: 0.4728, CrossE: 0.0178, CondE: 0.0815, disc: 0.6587, domain: 0.8371, Src VAT: 0.0346, Trg VAT: 0.0815, Src MixUp: 0.3079, Trg MixUp: 0.4074, Src Train Acc: 99.35, Trg Train Acc: 95.79, Src Test Acc: 97.67, Trg Test Acc: 95.70
# Epoch: 183, TotalL: 0.4647, CrossE: 0.0172, CondE: 0.0736, disc: 0.6620, domain: 0.8371, Src VAT: 0.0308, Trg VAT: 0.0736, Src MixUp: 0.3066, Trg MixUp: 0.3923, Src Train Acc: 99.35, Trg Train Acc: 96.53, Src Test Acc: 96.89, Trg Test Acc: 87.34
# Epoch: 184, TotalL: 0.4620, CrossE: 0.0159, CondE: 0.0835, disc: 0.6590, domain: 0.8295, Src VAT: 0.0301, Trg VAT: 0.0835, Src MixUp: 0.3034, Trg MixUp: 0.4100, Src Train Acc: 99.57, Trg Train Acc: 96.14, Src Test Acc: 97.28, Trg Test Acc: 94.62
# Epoch: 185, TotalL: 0.4356, CrossE: 0.0091, CondE: 0.0744, disc: 0.6487, domain: 0.8510, Src VAT: 0.0274, Trg VAT: 0.0744, Src MixUp: 0.2865, Trg MixUp: 0.4076, Src Train Acc: 99.74, Trg Train Acc: 96.61, Src Test Acc: 96.50, Trg Test Acc: 91.40
# Epoch: 186, TotalL: 0.4696, CrossE: 0.0176, CondE: 0.0854, disc: 0.6601, domain: 0.8336, Src VAT: 0.0339, Trg VAT: 0.0854, Src MixUp: 0.3044, Trg MixUp: 0.4171, Src Train Acc: 99.61, Trg Train Acc: 95.70, Src Test Acc: 97.28, Trg Test Acc: 93.89
# Epoch: 187, TotalL: 0.4621, CrossE: 0.0111, CondE: 0.0727, disc: 0.6602, domain: 0.8323, Src VAT: 0.0294, Trg VAT: 0.0727, Src MixUp: 0.3122, Trg MixUp: 0.3895, Src Train Acc: 99.70, Trg Train Acc: 96.40, Src Test Acc: 96.89, Trg Test Acc: 90.64
# Epoch: 188, TotalL: 0.5124, CrossE: 0.0268, CondE: 0.0912, disc: 0.6546, domain: 0.8403, Src VAT: 0.0435, Trg VAT: 0.0912, Src MixUp: 0.3289, Trg MixUp: 0.3926, Src Train Acc: 99.26, Trg Train Acc: 95.66, Src Test Acc: 97.28, Trg Test Acc: 93.71
# Epoch: 189, TotalL: 0.4612, CrossE: 0.0145, CondE: 0.0767, disc: 0.6559, domain: 0.8367, Src VAT: 0.0352, Trg VAT: 0.0767, Src MixUp: 0.2994, Trg MixUp: 0.4117, Src Train Acc: 99.70, Trg Train Acc: 96.31, Src Test Acc: 96.11, Trg Test Acc: 89.82
# Epoch: 190, TotalL: 0.4646, CrossE: 0.0149, CondE: 0.0811, disc: 0.6577, domain: 0.8303, Src VAT: 0.0334, Trg VAT: 0.0811, Src MixUp: 0.3051, Trg MixUp: 0.3979, Src Train Acc: 99.74, Trg Train Acc: 96.40, Src Test Acc: 98.83, Trg Test Acc: 93.62
# Epoch: 191, TotalL: 0.4355, CrossE: 0.0096, CondE: 0.0751, disc: 0.6623, domain: 0.8342, Src VAT: 0.0276, Trg VAT: 0.0751, Src MixUp: 0.2875, Trg MixUp: 0.3997, Src Train Acc: 99.83, Trg Train Acc: 96.27, Src Test Acc: 96.50, Trg Test Acc: 92.83
# ...
# Epoch: 937, TotalL: 0.2735, CrossE: 0.0039, CondE: 0.0190, disc: 0.6825, domain: 0.7271, Src VAT: 0.0110, Trg VAT: 0.0190, Src MixUp: 0.1775, Trg MixUp: 0.2493, Src Train Acc: 99.91, Trg Train Acc: 98.18, Src Test Acc: 97.67, Trg Test Acc: 97.08
# Epoch: 938, TotalL: 0.2384, CrossE: 0.0034, CondE: 0.0127, disc: 0.6851, domain: 0.7248, Src VAT: 0.0070, Trg VAT: 0.0127, Src MixUp: 0.1496, Trg MixUp: 0.2297, Src Train Acc: 99.87, Trg Train Acc: 98.70, Src Test Acc: 96.89, Trg Test Acc: 96.23
# Epoch: 939, TotalL: 0.2330, CrossE: 0.0010, CondE: 0.0076, disc: 0.6839, domain: 0.7237, Src VAT: 0.0042, Trg VAT: 0.0076, Src MixUp: 0.1512, Trg MixUp: 0.2177, Src Train Acc: 100.00, Trg Train Acc: 98.57, Src Test Acc: 99.22, Trg Test Acc: 96.90
# Epoch: 940, TotalL: 0.2481, CrossE: 0.0041, CondE: 0.0115, disc: 0.6898, domain: 0.7232, Src VAT: 0.0066, Trg VAT: 0.0115, Src MixUp: 0.1594, Trg MixUp: 0.2293, Src Train Acc: 99.91, Trg Train Acc: 98.65, Src Test Acc: 97.67, Trg Test Acc: 96.23
# Epoch: 941, TotalL: 0.2216, CrossE: 0.0047, CondE: 0.0134, disc: 0.6872, domain: 0.7187, Src VAT: 0.0053, Trg VAT: 0.0134, Src MixUp: 0.1332, Trg MixUp: 0.2345, Src Train Acc: 99.91, Trg Train Acc: 98.87, Src Test Acc: 98.05, Trg Test Acc: 94.06
# Epoch: 942, TotalL: 0.2685, CrossE: 0.0054, CondE: 0.0139, disc: 0.6853, domain: 0.7227, Src VAT: 0.0065, Trg VAT: 0.0139, Src MixUp: 0.1767, Trg MixUp: 0.2478, Src Train Acc: 99.83, Trg Train Acc: 98.65, Src Test Acc: 99.22, Trg Test Acc: 96.90
# Epoch: 943, TotalL: 0.2185, CrossE: 0.0013, CondE: 0.0100, disc: 0.6853, domain: 0.7223, Src VAT: 0.0050, Trg VAT: 0.0100, Src MixUp: 0.1356, Trg MixUp: 0.2154, Src Train Acc: 100.00, Trg Train Acc: 98.57, Src Test Acc: 98.83, Trg Test Acc: 97.08
# Epoch: 944, TotalL: 0.2552, CrossE: 0.0026, CondE: 0.0139, disc: 0.6858, domain: 0.7230, Src VAT: 0.0077, Trg VAT: 0.0139, Src MixUp: 0.1651, Trg MixUp: 0.2460, Src Train Acc: 99.96, Trg Train Acc: 98.70, Src Test Acc: 98.44, Trg Test Acc: 96.75
# Epoch: 945, TotalL: 0.2416, CrossE: 0.0025, CondE: 0.0101, disc: 0.6838, domain: 0.7223, Src VAT: 0.0048, Trg VAT: 0.0101, Src MixUp: 0.1584, Trg MixUp: 0.2055, Src Train Acc: 99.91, Trg Train Acc: 98.65, Src Test Acc: 99.61, Trg Test Acc: 97.86
# Epoch: 946, TotalL: 0.2374, CrossE: 0.0013, CondE: 0.0083, disc: 0.6881, domain: 0.7204, Src VAT: 0.0043, Trg VAT: 0.0083, Src MixUp: 0.1549, Trg MixUp: 0.2238, Src Train Acc: 100.00, Trg Train Acc: 98.70, Src Test Acc: 98.44, Trg Test Acc: 96.40
# Epoch: 947, TotalL: 0.2119, CrossE: 0.0006, CondE: 0.0073, disc: 0.6844, domain: 0.7221, Src VAT: 0.0021, Trg VAT: 0.0073, Src MixUp: 0.1338, Trg MixUp: 0.2061, Src Train Acc: 100.00, Trg Train Acc: 98.70, Src Test Acc: 98.83, Trg Test Acc: 95.64
# Epoch: 948, TotalL: 0.2532, CrossE: 0.0037, CondE: 0.0164, disc: 0.6866, domain: 0.7230, Src VAT: 0.0078, Trg VAT: 0.0164, Src MixUp: 0.1633, Trg MixUp: 0.2244, Src Train Acc: 99.91, Trg Train Acc: 98.31, Src Test Acc: 97.67, Trg Test Acc: 94.85
# Epoch: 949, TotalL: 0.2275, CrossE: 0.0009, CondE: 0.0090, disc: 0.6841, domain: 0.7213, Src VAT: 0.0039, Trg VAT: 0.0090, Src MixUp: 0.1449, Trg MixUp: 0.2331, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 99.22, Trg Test Acc: 97.57
# Epoch: 950, TotalL: 0.2360, CrossE: 0.0017, CondE: 0.0096, disc: 0.6860, domain: 0.7217, Src VAT: 0.0050, Trg VAT: 0.0096, Src MixUp: 0.1521, Trg MixUp: 0.2243, Src Train Acc: 99.96, Trg Train Acc: 98.57, Src Test Acc: 99.22, Trg Test Acc: 97.16
# Epoch: 951, TotalL: 0.2317, CrossE: 0.0036, CondE: 0.0100, disc: 0.6864, domain: 0.7211, Src VAT: 0.0059, Trg VAT: 0.0100, Src MixUp: 0.1463, Trg MixUp: 0.2068, Src Train Acc: 99.83, Trg Train Acc: 98.61, Src Test Acc: 98.83, Trg Test Acc: 98.07
# Epoch: 952, TotalL: 0.2332, CrossE: 0.0009, CondE: 0.0071, disc: 0.6845, domain: 0.7237, Src VAT: 0.0035, Trg VAT: 0.0071, Src MixUp: 0.1520, Trg MixUp: 0.2212, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 99.22, Trg Test Acc: 92.95
# Epoch: 953, TotalL: 0.2367, CrossE: 0.0011, CondE: 0.0130, disc: 0.6841, domain: 0.7229, Src VAT: 0.0047, Trg VAT: 0.0130, Src MixUp: 0.1524, Trg MixUp: 0.2327, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 99.61, Trg Test Acc: 97.92
# Epoch: 954, TotalL: 0.2508, CrossE: 0.0028, CondE: 0.0118, disc: 0.6887, domain: 0.7216, Src VAT: 0.0062, Trg VAT: 0.0118, Src MixUp: 0.1621, Trg MixUp: 0.2509, Src Train Acc: 99.96, Trg Train Acc: 98.70, Src Test Acc: 99.61, Trg Test Acc: 97.54
# Epoch: 955, TotalL: 0.2543, CrossE: 0.0019, CondE: 0.0111, disc: 0.6861, domain: 0.7224, Src VAT: 0.0065, Trg VAT: 0.0111, Src MixUp: 0.1664, Trg MixUp: 0.2492, Src Train Acc: 99.96, Trg Train Acc: 98.57, Src Test Acc: 99.22, Trg Test Acc: 97.37
# Epoch: 956, TotalL: 0.2333, CrossE: 0.0011, CondE: 0.0074, disc: 0.6866, domain: 0.7214, Src VAT: 0.0035, Trg VAT: 0.0074, Src MixUp: 0.1509, Trg MixUp: 0.2367, Src Train Acc: 99.96, Trg Train Acc: 98.74, Src Test Acc: 99.22, Trg Test Acc: 96.52
# Epoch: 957, TotalL: 0.2055, CrossE: 0.0017, CondE: 0.0059, disc: 0.6833, domain: 0.7241, Src VAT: 0.0021, Trg VAT: 0.0059, Src MixUp: 0.1270, Trg MixUp: 0.1974, Src Train Acc: 99.91, Trg Train Acc: 98.83, Src Test Acc: 98.44, Trg Test Acc: 96.52
# Epoch: 958, TotalL: 0.2426, CrossE: 0.0014, CondE: 0.0082, disc: 0.6860, domain: 0.7224, Src VAT: 0.0043, Trg VAT: 0.0082, Src MixUp: 0.1589, Trg MixUp: 0.2371, Src Train Acc: 99.96, Trg Train Acc: 98.87, Src Test Acc: 98.05, Trg Test Acc: 94.24
# Epoch: 959, TotalL: 0.2520, CrossE: 0.0021, CondE: 0.0134, disc: 0.6874, domain: 0.7197, Src VAT: 0.0067, Trg VAT: 0.0134, Src MixUp: 0.1648, Trg MixUp: 0.2337, Src Train Acc: 99.96, Trg Train Acc: 98.65, Src Test Acc: 98.05, Trg Test Acc: 95.06
# Epoch: 960, TotalL: 0.2170, CrossE: 0.0011, CondE: 0.0077, disc: 0.6850, domain: 0.7216, Src VAT: 0.0034, Trg VAT: 0.0077, Src MixUp: 0.1359, Trg MixUp: 0.2198, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 98.83, Trg Test Acc: 96.84
# Epoch: 961, TotalL: 0.2341, CrossE: 0.0021, CondE: 0.0143, disc: 0.6872, domain: 0.7223, Src VAT: 0.0059, Trg VAT: 0.0143, Src MixUp: 0.1474, Trg MixUp: 0.2332, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 98.44, Trg Test Acc: 96.96
# Epoch: 962, TotalL: 0.2443, CrossE: 0.0036, CondE: 0.0090, disc: 0.6866, domain: 0.7202, Src VAT: 0.0054, Trg VAT: 0.0090, Src MixUp: 0.1586, Trg MixUp: 0.2215, Src Train Acc: 99.87, Trg Train Acc: 98.83, Src Test Acc: 98.44, Trg Test Acc: 95.44
# Epoch: 963, TotalL: 0.2306, CrossE: 0.0009, CondE: 0.0068, disc: 0.6852, domain: 0.7238, Src VAT: 0.0039, Trg VAT: 0.0068, Src MixUp: 0.1484, Trg MixUp: 0.2290, Src Train Acc: 100.00, Trg Train Acc: 98.87, Src Test Acc: 99.22, Trg Test Acc: 97.75
# Epoch: 964, TotalL: 0.2151, CrossE: 0.0005, CondE: 0.0070, disc: 0.6829, domain: 0.7213, Src VAT: 0.0021, Trg VAT: 0.0070, Src MixUp: 0.1373, Trg MixUp: 0.2059, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 98.44, Trg Test Acc: 95.64
# Epoch: 965, TotalL: 0.2115, CrossE: 0.0007, CondE: 0.0100, disc: 0.6843, domain: 0.7239, Src VAT: 0.0027, Trg VAT: 0.0100, Src MixUp: 0.1313, Trg MixUp: 0.2173, Src Train Acc: 100.00, Trg Train Acc: 98.61, Src Test Acc: 98.44, Trg Test Acc: 96.78
# Epoch: 966, TotalL: 0.2246, CrossE: 0.0023, CondE: 0.0098, disc: 0.6824, domain: 0.7259, Src VAT: 0.0039, Trg VAT: 0.0098, Src MixUp: 0.1401, Trg MixUp: 0.2337, Src Train Acc: 99.96, Trg Train Acc: 98.83, Src Test Acc: 94.55, Trg Test Acc: 93.04
# Epoch: 967, TotalL: 0.2059, CrossE: 0.0006, CondE: 0.0068, disc: 0.6821, domain: 0.7255, Src VAT: 0.0022, Trg VAT: 0.0068, Src MixUp: 0.1276, Trg MixUp: 0.2044, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 95.72, Trg Test Acc: 94.62
# Epoch: 968, TotalL: 0.2254, CrossE: 0.0007, CondE: 0.0077, disc: 0.6852, domain: 0.7233, Src VAT: 0.0032, Trg VAT: 0.0077, Src MixUp: 0.1449, Trg MixUp: 0.2187, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 98.44, Trg Test Acc: 96.02
# Epoch: 969, TotalL: 0.2047, CrossE: 0.0011, CondE: 0.0049, disc: 0.6895, domain: 0.7148, Src VAT: 0.0020, Trg VAT: 0.0049, Src MixUp: 0.1270, Trg MixUp: 0.2069, Src Train Acc: 99.91, Trg Train Acc: 98.83, Src Test Acc: 99.22, Trg Test Acc: 96.11
# Epoch: 970, TotalL: 0.2366, CrossE: 0.0027, CondE: 0.0140, disc: 0.6865, domain: 0.7196, Src VAT: 0.0060, Trg VAT: 0.0140, Src MixUp: 0.1488, Trg MixUp: 0.2418, Src Train Acc: 99.96, Trg Train Acc: 98.61, Src Test Acc: 98.44, Trg Test Acc: 96.49
# Epoch: 971, TotalL: 0.2317, CrossE: 0.0015, CondE: 0.0106, disc: 0.6858, domain: 0.7217, Src VAT: 0.0042, Trg VAT: 0.0106, Src MixUp: 0.1490, Trg MixUp: 0.2196, Src Train Acc: 99.96, Trg Train Acc: 98.52, Src Test Acc: 98.05, Trg Test Acc: 93.97
# Epoch: 972, TotalL: 0.2769, CrossE: 0.0063, CondE: 0.0215, disc: 0.6878, domain: 0.7211, Src VAT: 0.0110, Trg VAT: 0.0215, Src MixUp: 0.1779, Trg MixUp: 0.2568, Src Train Acc: 99.78, Trg Train Acc: 98.57, Src Test Acc: 97.67, Trg Test Acc: 93.59
# Epoch: 973, TotalL: 0.2350, CrossE: 0.0008, CondE: 0.0089, disc: 0.6823, domain: 0.7261, Src VAT: 0.0026, Trg VAT: 0.0089, Src MixUp: 0.1518, Trg MixUp: 0.2548, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 98.44, Trg Test Acc: 94.94
# Epoch: 974, TotalL: 0.2242, CrossE: 0.0009, CondE: 0.0092, disc: 0.6848, domain: 0.7218, Src VAT: 0.0029, Trg VAT: 0.0092, Src MixUp: 0.1422, Trg MixUp: 0.2368, Src Train Acc: 99.96, Trg Train Acc: 98.78, Src Test Acc: 98.05, Trg Test Acc: 95.29
# Epoch: 975, TotalL: 0.2178, CrossE: 0.0004, CondE: 0.0075, disc: 0.6794, domain: 0.7279, Src VAT: 0.0020, Trg VAT: 0.0075, Src MixUp: 0.1384, Trg MixUp: 0.2193, Src Train Acc: 100.00, Trg Train Acc: 98.87, Src Test Acc: 99.22, Trg Test Acc: 96.43
# Epoch: 976, TotalL: 0.2549, CrossE: 0.0039, CondE: 0.0139, disc: 0.6857, domain: 0.7258, Src VAT: 0.0082, Trg VAT: 0.0139, Src MixUp: 0.1629, Trg MixUp: 0.2443, Src Train Acc: 99.83, Trg Train Acc: 98.65, Src Test Acc: 98.83, Trg Test Acc: 97.28
# Epoch: 977, TotalL: 0.2153, CrossE: 0.0013, CondE: 0.0069, disc: 0.6857, domain: 0.7217, Src VAT: 0.0036, Trg VAT: 0.0069, Src MixUp: 0.1342, Trg MixUp: 0.2174, Src Train Acc: 99.96, Trg Train Acc: 98.78, Src Test Acc: 94.16, Trg Test Acc: 85.55
# Epoch: 978, TotalL: 0.2576, CrossE: 0.0043, CondE: 0.0116, disc: 0.6874, domain: 0.7193, Src VAT: 0.0095, Trg VAT: 0.0116, Src MixUp: 0.1641, Trg MixUp: 0.2548, Src Train Acc: 99.87, Trg Train Acc: 98.70, Src Test Acc: 96.11, Trg Test Acc: 94.68
# Epoch: 979, TotalL: 0.2087, CrossE: 0.0010, CondE: 0.0064, disc: 0.6863, domain: 0.7178, Src VAT: 0.0035, Trg VAT: 0.0064, Src MixUp: 0.1283, Trg MixUp: 0.2174, Src Train Acc: 100.00, Trg Train Acc: 98.78, Src Test Acc: 98.83, Trg Test Acc: 96.87
# Epoch: 980, TotalL: 0.2344, CrossE: 0.0012, CondE: 0.0102, disc: 0.6860, domain: 0.7209, Src VAT: 0.0044, Trg VAT: 0.0102, Src MixUp: 0.1516, Trg MixUp: 0.2231, Src Train Acc: 100.00, Trg Train Acc: 98.70, Src Test Acc: 98.44, Trg Test Acc: 95.35
# Epoch: 981, TotalL: 0.2485, CrossE: 0.0017, CondE: 0.0165, disc: 0.6836, domain: 0.7215, Src VAT: 0.0069, Trg VAT: 0.0165, Src MixUp: 0.1587, Trg MixUp: 0.2596, Src Train Acc: 100.00, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 97.69
# Epoch: 982, TotalL: 0.2452, CrossE: 0.0054, CondE: 0.0130, disc: 0.6883, domain: 0.7174, Src VAT: 0.0069, Trg VAT: 0.0130, Src MixUp: 0.1547, Trg MixUp: 0.2351, Src Train Acc: 99.83, Trg Train Acc: 98.83, Src Test Acc: 99.61, Trg Test Acc: 95.64
# Epoch: 983, TotalL: 0.2060, CrossE: 0.0006, CondE: 0.0079, disc: 0.6843, domain: 0.7207, Src VAT: 0.0024, Trg VAT: 0.0079, Src MixUp: 0.1283, Trg MixUp: 0.1970, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 98.44, Trg Test Acc: 96.67
# Epoch: 984, TotalL: 0.2192, CrossE: 0.0008, CondE: 0.0094, disc: 0.6845, domain: 0.7206, Src VAT: 0.0034, Trg VAT: 0.0094, Src MixUp: 0.1376, Trg MixUp: 0.2285, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 96.89, Trg Test Acc: 94.44
# Epoch: 985, TotalL: 0.2397, CrossE: 0.0023, CondE: 0.0149, disc: 0.6838, domain: 0.7215, Src VAT: 0.0054, Trg VAT: 0.0149, Src MixUp: 0.1539, Trg MixUp: 0.2244, Src Train Acc: 99.91, Trg Train Acc: 98.78, Src Test Acc: 99.22, Trg Test Acc: 97.98
# Epoch: 986, TotalL: 0.2065, CrossE: 0.0004, CondE: 0.0068, disc: 0.6849, domain: 0.7227, Src VAT: 0.0020, Trg VAT: 0.0068, Src MixUp: 0.1297, Trg MixUp: 0.1932, Src Train Acc: 100.00, Trg Train Acc: 99.00, Src Test Acc: 97.67, Trg Test Acc: 95.41
# Epoch: 987, TotalL: 0.2469, CrossE: 0.0034, CondE: 0.0125, disc: 0.6871, domain: 0.7190, Src VAT: 0.0059, Trg VAT: 0.0125, Src MixUp: 0.1592, Trg MixUp: 0.2365, Src Train Acc: 99.91, Trg Train Acc: 98.52, Src Test Acc: 99.61, Trg Test Acc: 96.17
# Epoch: 988, TotalL: 0.2415, CrossE: 0.0010, CondE: 0.0125, disc: 0.6843, domain: 0.7226, Src VAT: 0.0043, Trg VAT: 0.0125, Src MixUp: 0.1557, Trg MixUp: 0.2591, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 97.67, Trg Test Acc: 93.74
# Epoch: 989, TotalL: 0.2248, CrossE: 0.0006, CondE: 0.0098, disc: 0.6834, domain: 0.7268, Src VAT: 0.0024, Trg VAT: 0.0098, Src MixUp: 0.1438, Trg MixUp: 0.2285, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 98.83, Trg Test Acc: 97.51
# Epoch: 990, TotalL: 0.2639, CrossE: 0.0033, CondE: 0.0131, disc: 0.6879, domain: 0.7204, Src VAT: 0.0064, Trg VAT: 0.0131, Src MixUp: 0.1745, Trg MixUp: 0.2502, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 98.44, Trg Test Acc: 95.73
# Epoch: 991, TotalL: 0.2335, CrossE: 0.0024, CondE: 0.0158, disc: 0.6888, domain: 0.7189, Src VAT: 0.0067, Trg VAT: 0.0158, Src MixUp: 0.1444, Trg MixUp: 0.2485, Src Train Acc: 99.91, Trg Train Acc: 98.70, Src Test Acc: 98.83, Trg Test Acc: 95.91
# Epoch: 992, TotalL: 0.2161, CrossE: 0.0004, CondE: 0.0056, disc: 0.6846, domain: 0.7230, Src VAT: 0.0019, Trg VAT: 0.0056, Src MixUp: 0.1373, Trg MixUp: 0.2221, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 98.05, Trg Test Acc: 97.10
# Epoch: 993, TotalL: 0.2240, CrossE: 0.0014, CondE: 0.0083, disc: 0.6860, domain: 0.7184, Src VAT: 0.0048, Trg VAT: 0.0083, Src MixUp: 0.1425, Trg MixUp: 0.2058, Src Train Acc: 100.00, Trg Train Acc: 98.87, Src Test Acc: 99.22, Trg Test Acc: 97.34
# Epoch: 994, TotalL: 0.2240, CrossE: 0.0019, CondE: 0.0072, disc: 0.6882, domain: 0.7140, Src VAT: 0.0034, Trg VAT: 0.0072, Src MixUp: 0.1445, Trg MixUp: 0.1987, Src Train Acc: 99.91, Trg Train Acc: 98.74, Src Test Acc: 92.61, Trg Test Acc: 82.60
# Epoch: 995, TotalL: 0.2356, CrossE: 0.0041, CondE: 0.0152, disc: 0.6840, domain: 0.7219, Src VAT: 0.0065, Trg VAT: 0.0152, Src MixUp: 0.1468, Trg MixUp: 0.2254, Src Train Acc: 99.87, Trg Train Acc: 98.52, Src Test Acc: 99.22, Trg Test Acc: 96.17
# Epoch: 996, TotalL: 0.2131, CrossE: 0.0007, CondE: 0.0069, disc: 0.6847, domain: 0.7202, Src VAT: 0.0036, Trg VAT: 0.0069, Src MixUp: 0.1333, Trg MixUp: 0.2099, Src Train Acc: 100.00, Trg Train Acc: 98.78, Src Test Acc: 98.44, Trg Test Acc: 94.82
# Epoch: 997, TotalL: 0.2460, CrossE: 0.0015, CondE: 0.0122, disc: 0.6898, domain: 0.7144, Src VAT: 0.0063, Trg VAT: 0.0122, Src MixUp: 0.1593, Trg MixUp: 0.2465, Src Train Acc: 100.00, Trg Train Acc: 98.61, Src Test Acc: 98.44, Trg Test Acc: 95.03
# Epoch: 998, TotalL: 0.2127, CrossE: 0.0006, CondE: 0.0079, disc: 0.6848, domain: 0.7197, Src VAT: 0.0030, Trg VAT: 0.0079, Src MixUp: 0.1321, Trg MixUp: 0.2276, Src Train Acc: 100.00, Trg Train Acc: 98.78, Src Test Acc: 97.67, Trg Test Acc: 95.20
# Epoch: 999, TotalL: 0.2174, CrossE: 0.0007, CondE: 0.0084, disc: 0.6851, domain: 0.7192, Src VAT: 0.0029, Trg VAT: 0.0084, Src MixUp: 0.1385, Trg MixUp: 0.2062, Src Train Acc: 100.00, Trg Train Acc: 98.87, Src Test Acc: 98.05, Trg Test Acc: 95.41
# Epoch: 1000, TotalL: 0.2399, CrossE: 0.0014, CondE: 0.0118, disc: 0.6885, domain: 0.7183, Src VAT: 0.0058, Trg VAT: 0.0118, Src MixUp: 0.1552, Trg MixUp: 0.2271, Src Train Acc: 100.00, Trg Train Acc: 98.83, Src Test Acc: 98.05, Trg Test Acc: 97.48
