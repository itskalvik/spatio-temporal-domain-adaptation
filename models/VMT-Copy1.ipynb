# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='1'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 500
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
disc_activation = 'selu'
gen_activation  = 'selu'
notes           = "updated total_loss to reflect my issue on github, VMT, with gaussian noise" 

log_data = "num_classes-{}_batch_size-{}_train_src_days-{}_train_trg_days-{}_learning_rate-{}_num_hidden-{}_num_features-{}_disc_activation-{}_gen_activation-{}_notes-{}".format(num_classes, 
                                                                                                                                                                                  batch_size, 
                                                                                                                                                                                  train_src_days, 
                                                                                                                                                                                  train_trg_days, 
                                                                                                                                                                                  learning_rate, 
                                                                                                                                                                                  num_hidden, 
                                                                                                                                                                                  num_features,
                                                                                                                                                                                  disc_activation,
                                                                                                                                                                                  gen_activation,
                                                                                                                                                                                  notes)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, num_features, gen_activation)
discriminator  = Discriminator(num_hidden, disc_activation)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    
for epoch in range(epochs):
  global_step.assign_add(1)  
    
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0821 12:50:20.655977 140214165063424 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0821 12:50:25.357041 140214165063424 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.1414, CrossE: 2.2220, CondE: 2.1552, disc: 1.1942, domain: 1.1477, Src VAT: 2.1551, Trg VAT: 2.1552, Src MixUp: 2.1552, Trg MixUp: 2.1554, Src Train Acc: 11.63, Trg Train Acc: 10.72, Src Test Acc: 11.28, Trg Test Acc: 11.11
# Epoch: 002, TotalL: 7.0914, CrossE: 2.1706, CondE: 2.1692, disc: 0.8521, domain: 0.7149, Src VAT: 2.1705, Trg VAT: 2.1692, Src MixUp: 2.1723, Trg MixUp: 2.1717, Src Train Acc: 14.19, Trg Train Acc: 15.45, Src Test Acc: 27.63, Trg Test Acc: 23.77
# Epoch: 003, TotalL: 6.4779, CrossE: 1.9012, CondE: 1.9852, disc: 1.0202, domain: 0.8807, Src VAT: 1.9899, Trg VAT: 1.9852, Src MixUp: 2.0356, Trg MixUp: 2.0390, Src Train Acc: 24.83, Trg Train Acc: 23.13, Src Test Acc: 32.30, Trg Test Acc: 31.08
# Epoch: 004, TotalL: 5.6596, CrossE: 1.5863, CondE: 1.7467, disc: 0.9523, domain: 0.9274, Src VAT: 1.7328, Trg VAT: 1.7467, Src MixUp: 1.8378, Trg MixUp: 1.8634, Src Train Acc: 39.15, Trg Train Acc: 34.59, Src Test Acc: 31.91, Trg Test Acc: 31.14
# Epoch: 005, TotalL: 4.8037, CrossE: 1.2906, CondE: 1.4774, disc: 0.8992, domain: 0.9823, Src VAT: 1.4558, Trg VAT: 1.4774, Src MixUp: 1.6102, Trg MixUp: 1.6518, Src Train Acc: 49.70, Trg Train Acc: 42.93, Src Test Acc: 41.25, Trg Test Acc: 40.35
# Epoch: 006, TotalL: 4.2183, CrossE: 1.0883, CondE: 1.2840, disc: 0.8601, domain: 0.9703, Src VAT: 1.2590, Trg VAT: 1.2840, Src MixUp: 1.4673, Trg MixUp: 1.5077, Src Train Acc: 59.29, Trg Train Acc: 50.91, Src Test Acc: 67.70, Trg Test Acc: 56.84
# Epoch: 007, TotalL: 3.6019, CrossE: 0.9041, CondE: 1.0747, disc: 0.8050, domain: 0.8493, Src VAT: 1.0523, Trg VAT: 1.0747, Src MixUp: 1.2974, Trg MixUp: 1.3532, Src Train Acc: 66.23, Trg Train Acc: 58.38, Src Test Acc: 65.37, Trg Test Acc: 58.54
# Epoch: 008, TotalL: 3.2641, CrossE: 0.8020, CondE: 0.9684, disc: 0.7742, domain: 0.8425, Src VAT: 0.9382, Trg VAT: 0.9684, Src MixUp: 1.1991, Trg MixUp: 1.2792, Src Train Acc: 71.22, Trg Train Acc: 62.80, Src Test Acc: 65.37, Trg Test Acc: 59.71
# Epoch: 009, TotalL: 3.0329, CrossE: 0.7230, CondE: 0.8918, disc: 0.7577, domain: 0.8604, Src VAT: 0.8574, Trg VAT: 0.8918, Src MixUp: 1.1434, Trg MixUp: 1.2189, Src Train Acc: 74.83, Trg Train Acc: 66.02, Src Test Acc: 73.54, Trg Test Acc: 66.55
# Epoch: 010, TotalL: 2.7261, CrossE: 0.6176, CondE: 0.8096, disc: 0.7411, domain: 0.8763, Src VAT: 0.7634, Trg VAT: 0.8096, Src MixUp: 1.0534, Trg MixUp: 1.1510, Src Train Acc: 78.60, Trg Train Acc: 71.27, Src Test Acc: 79.38, Trg Test Acc: 71.05
# Epoch: 011, TotalL: 2.5054, CrossE: 0.5406, CondE: 0.7470, disc: 0.7252, domain: 0.8842, Src VAT: 0.6887, Trg VAT: 0.7470, Src MixUp: 0.9961, Trg MixUp: 1.1226, Src Train Acc: 81.42, Trg Train Acc: 73.18, Src Test Acc: 82.10, Trg Test Acc: 73.45
# Epoch: 012, TotalL: 2.3240, CrossE: 0.4727, CondE: 0.6887, disc: 0.7157, domain: 0.8895, Src VAT: 0.6205, Trg VAT: 0.6887, Src MixUp: 0.9649, Trg MixUp: 1.0572, Src Train Acc: 84.46, Trg Train Acc: 76.30, Src Test Acc: 90.27, Trg Test Acc: 80.35
# Epoch: 013, TotalL: 2.1131, CrossE: 0.4029, CondE: 0.6220, disc: 0.7090, domain: 0.8894, Src VAT: 0.5516, Trg VAT: 0.6220, Src MixUp: 0.9062, Trg MixUp: 1.0222, Src Train Acc: 87.24, Trg Train Acc: 80.08, Src Test Acc: 87.16, Trg Test Acc: 74.18
# Epoch: 014, TotalL: 1.9303, CrossE: 0.3503, CondE: 0.5714, disc: 0.6964, domain: 0.8918, Src VAT: 0.4900, Trg VAT: 0.5714, Src MixUp: 0.8486, Trg MixUp: 0.9823, Src Train Acc: 88.72, Trg Train Acc: 80.99, Src Test Acc: 94.16, Trg Test Acc: 84.85
# Epoch: 015, TotalL: 1.7667, CrossE: 0.2927, CondE: 0.5206, disc: 0.6955, domain: 0.8960, Src VAT: 0.4282, Trg VAT: 0.5206, Src MixUp: 0.8155, Trg MixUp: 0.9419, Src Train Acc: 90.67, Trg Train Acc: 83.72, Src Test Acc: 94.94, Trg Test Acc: 84.80
# Epoch: 016, TotalL: 1.6634, CrossE: 0.2571, CondE: 0.4829, disc: 0.6981, domain: 0.8945, Src VAT: 0.3981, Trg VAT: 0.4829, Src MixUp: 0.7873, Trg MixUp: 0.9004, Src Train Acc: 91.88, Trg Train Acc: 84.59, Src Test Acc: 95.33, Trg Test Acc: 84.74
# Epoch: 017, TotalL: 1.5632, CrossE: 0.2476, CondE: 0.4534, disc: 0.6906, domain: 0.8870, Src VAT: 0.3628, Trg VAT: 0.4534, Src MixUp: 0.7391, Trg MixUp: 0.8778, Src Train Acc: 91.41, Trg Train Acc: 85.07, Src Test Acc: 93.00, Trg Test Acc: 80.09
# Epoch: 018, TotalL: 1.4523, CrossE: 0.2048, CondE: 0.4109, disc: 0.6844, domain: 0.8935, Src VAT: 0.3290, Trg VAT: 0.4109, Src MixUp: 0.7120, Trg MixUp: 0.8665, Src Train Acc: 94.23, Trg Train Acc: 87.02, Src Test Acc: 95.72, Trg Test Acc: 85.67
# Epoch: 019, TotalL: 1.4268, CrossE: 0.1969, CondE: 0.3927, disc: 0.6791, domain: 0.8963, Src VAT: 0.3117, Trg VAT: 0.3927, Src MixUp: 0.7178, Trg MixUp: 0.8231, Src Train Acc: 94.10, Trg Train Acc: 87.07, Src Test Acc: 84.44, Trg Test Acc: 69.91
# Epoch: 020, TotalL: 1.2796, CrossE: 0.1732, CondE: 0.3599, disc: 0.6827, domain: 0.8869, Src VAT: 0.2711, Trg VAT: 0.3599, Src MixUp: 0.6418, Trg MixUp: 0.8118, Src Train Acc: 94.92, Trg Train Acc: 88.24, Src Test Acc: 97.67, Trg Test Acc: 90.09
# Epoch: 021, TotalL: 1.2374, CrossE: 0.1522, CondE: 0.3396, disc: 0.6802, domain: 0.8770, Src VAT: 0.2592, Trg VAT: 0.3396, Src MixUp: 0.6378, Trg MixUp: 0.7968, Src Train Acc: 95.01, Trg Train Acc: 88.28, Src Test Acc: 96.89, Trg Test Acc: 88.68
# Epoch: 022, TotalL: 1.2068, CrossE: 0.1474, CondE: 0.3246, disc: 0.6809, domain: 0.8771, Src VAT: 0.2489, Trg VAT: 0.3246, Src MixUp: 0.6265, Trg MixUp: 0.7743, Src Train Acc: 95.36, Trg Train Acc: 89.28, Src Test Acc: 96.11, Trg Test Acc: 87.60
# Epoch: 023, TotalL: 1.1476, CrossE: 0.1320, CondE: 0.3093, disc: 0.6747, domain: 0.8778, Src VAT: 0.2275, Trg VAT: 0.3093, Src MixUp: 0.6065, Trg MixUp: 0.7733, Src Train Acc: 96.14, Trg Train Acc: 89.54, Src Test Acc: 92.61, Trg Test Acc: 80.06
# Epoch: 024, TotalL: 1.1616, CrossE: 0.1348, CondE: 0.3056, disc: 0.6748, domain: 0.8757, Src VAT: 0.2285, Trg VAT: 0.3056, Src MixUp: 0.6169, Trg MixUp: 0.7796, Src Train Acc: 95.83, Trg Train Acc: 89.32, Src Test Acc: 94.94, Trg Test Acc: 85.29
# Epoch: 025, TotalL: 1.0750, CrossE: 0.1143, CondE: 0.2864, disc: 0.6742, domain: 0.8844, Src VAT: 0.2014, Trg VAT: 0.2864, Src MixUp: 0.5839, Trg MixUp: 0.7354, Src Train Acc: 96.74, Trg Train Acc: 89.93, Src Test Acc: 96.89, Trg Test Acc: 90.56
# Epoch: 026, TotalL: 1.0047, CrossE: 0.0981, CondE: 0.2742, disc: 0.6723, domain: 0.8757, Src VAT: 0.1841, Trg VAT: 0.2742, Src MixUp: 0.5499, Trg MixUp: 0.7338, Src Train Acc: 97.09, Trg Train Acc: 91.32, Src Test Acc: 95.33, Trg Test Acc: 88.25
# Epoch: 027, TotalL: 1.0098, CrossE: 0.0938, CondE: 0.2603, disc: 0.6756, domain: 0.8751, Src VAT: 0.1787, Trg VAT: 0.2603, Src MixUp: 0.5696, Trg MixUp: 0.7007, Src Train Acc: 97.40, Trg Train Acc: 91.19, Src Test Acc: 92.61, Trg Test Acc: 81.93
# Epoch: 028, TotalL: 1.0086, CrossE: 0.1072, CondE: 0.2637, disc: 0.6791, domain: 0.8581, Src VAT: 0.1857, Trg VAT: 0.2637, Src MixUp: 0.5482, Trg MixUp: 0.7087, Src Train Acc: 96.61, Trg Train Acc: 90.97, Src Test Acc: 97.67, Trg Test Acc: 90.82
# Epoch: 029, TotalL: 0.9110, CrossE: 0.0830, CondE: 0.2416, disc: 0.6667, domain: 0.8712, Src VAT: 0.1567, Trg VAT: 0.2416, Src MixUp: 0.5075, Trg MixUp: 0.6935, Src Train Acc: 97.66, Trg Train Acc: 90.54, Src Test Acc: 97.67, Trg Test Acc: 91.35
# Epoch: 030, TotalL: 0.9216, CrossE: 0.0868, CondE: 0.2404, disc: 0.6686, domain: 0.8741, Src VAT: 0.1606, Trg VAT: 0.2404, Src MixUp: 0.5115, Trg MixUp: 0.6811, Src Train Acc: 97.79, Trg Train Acc: 90.10, Src Test Acc: 97.67, Trg Test Acc: 90.61
# Epoch: 031, TotalL: 0.9099, CrossE: 0.0818, CondE: 0.2310, disc: 0.6707, domain: 0.8724, Src VAT: 0.1519, Trg VAT: 0.2310, Src MixUp: 0.5163, Trg MixUp: 0.6646, Src Train Acc: 97.53, Trg Train Acc: 90.71, Src Test Acc: 94.16, Trg Test Acc: 85.09
# Epoch: 032, TotalL: 0.8527, CrossE: 0.0682, CondE: 0.2025, disc: 0.6750, domain: 0.8691, Src VAT: 0.1362, Trg VAT: 0.2025, Src MixUp: 0.4943, Trg MixUp: 0.6510, Src Train Acc: 98.35, Trg Train Acc: 91.97, Src Test Acc: 96.11, Trg Test Acc: 85.85
# Epoch: 033, TotalL: 0.8616, CrossE: 0.0698, CondE: 0.2147, disc: 0.6671, domain: 0.8715, Src VAT: 0.1352, Trg VAT: 0.2147, Src MixUp: 0.4997, Trg MixUp: 0.6605, Src Train Acc: 98.22, Trg Train Acc: 91.80, Src Test Acc: 94.94, Trg Test Acc: 86.46
# Epoch: 034, TotalL: 0.7785, CrossE: 0.0525, CondE: 0.1925, disc: 0.6609, domain: 0.8800, Src VAT: 0.1147, Trg VAT: 0.1925, Src MixUp: 0.4585, Trg MixUp: 0.6466, Src Train Acc: 98.87, Trg Train Acc: 92.06, Src Test Acc: 98.05, Trg Test Acc: 88.86
# Epoch: 035, TotalL: 0.8256, CrossE: 0.0706, CondE: 0.2028, disc: 0.6701, domain: 0.8711, Src VAT: 0.1247, Trg VAT: 0.2028, Src MixUp: 0.4767, Trg MixUp: 0.6445, Src Train Acc: 98.09, Trg Train Acc: 90.80, Src Test Acc: 98.44, Trg Test Acc: 92.22
# Epoch: 036, TotalL: 0.8036, CrossE: 0.0646, CondE: 0.1907, disc: 0.6670, domain: 0.8658, Src VAT: 0.1201, Trg VAT: 0.1907, Src MixUp: 0.4672, Trg MixUp: 0.6481, Src Train Acc: 98.39, Trg Train Acc: 92.06, Src Test Acc: 97.67, Trg Test Acc: 92.37
# Epoch: 037, TotalL: 0.7929, CrossE: 0.0644, CondE: 0.1933, disc: 0.6640, domain: 0.8722, Src VAT: 0.1183, Trg VAT: 0.1933, Src MixUp: 0.4589, Trg MixUp: 0.6318, Src Train Acc: 98.26, Trg Train Acc: 91.28, Src Test Acc: 96.89, Trg Test Acc: 91.73
# Epoch: 038, TotalL: 0.7442, CrossE: 0.0520, CondE: 0.1876, disc: 0.6651, domain: 0.8708, Src VAT: 0.1075, Trg VAT: 0.1876, Src MixUp: 0.4337, Trg MixUp: 0.6415, Src Train Acc: 98.61, Trg Train Acc: 92.06, Src Test Acc: 95.33, Trg Test Acc: 83.16
# Epoch: 039, TotalL: 0.8053, CrossE: 0.0668, CondE: 0.1841, disc: 0.6644, domain: 0.8668, Src VAT: 0.1165, Trg VAT: 0.1841, Src MixUp: 0.4740, Trg MixUp: 0.6152, Src Train Acc: 98.26, Trg Train Acc: 91.80, Src Test Acc: 92.22, Trg Test Acc: 80.70
# Epoch: 040, TotalL: 0.7026, CrossE: 0.0473, CondE: 0.1699, disc: 0.6627, domain: 0.8742, Src VAT: 0.0949, Trg VAT: 0.1699, Src MixUp: 0.4141, Trg MixUp: 0.6148, Src Train Acc: 98.52, Trg Train Acc: 92.71, Src Test Acc: 99.22, Trg Test Acc: 93.16
# Epoch: 041, TotalL: 0.6971, CrossE: 0.0439, CondE: 0.1716, disc: 0.6643, domain: 0.8647, Src VAT: 0.0847, Trg VAT: 0.1716, Src MixUp: 0.4222, Trg MixUp: 0.6204, Src Train Acc: 98.87, Trg Train Acc: 93.49, Src Test Acc: 96.89, Trg Test Acc: 94.42
# Epoch: 042, TotalL: 0.7394, CrossE: 0.0487, CondE: 0.1719, disc: 0.6656, domain: 0.8527, Src VAT: 0.0965, Trg VAT: 0.1719, Src MixUp: 0.4476, Trg MixUp: 0.6357, Src Train Acc: 98.70, Trg Train Acc: 92.71, Src Test Acc: 94.94, Trg Test Acc: 91.26
# Epoch: 043, TotalL: 0.7139, CrossE: 0.0462, CondE: 0.1647, disc: 0.6607, domain: 0.8684, Src VAT: 0.0911, Trg VAT: 0.1647, Src MixUp: 0.4317, Trg MixUp: 0.6134, Src Train Acc: 98.87, Trg Train Acc: 93.45, Src Test Acc: 96.11, Trg Test Acc: 88.63
# Epoch: 044, TotalL: 0.6430, CrossE: 0.0332, CondE: 0.1523, disc: 0.6605, domain: 0.8626, Src VAT: 0.0748, Trg VAT: 0.1523, Src MixUp: 0.3936, Trg MixUp: 0.6003, Src Train Acc: 99.31, Trg Train Acc: 93.36, Src Test Acc: 97.67, Trg Test Acc: 94.47
# Epoch: 045, TotalL: 0.7076, CrossE: 0.0554, CondE: 0.1602, disc: 0.6664, domain: 0.8604, Src VAT: 0.0918, Trg VAT: 0.1602, Src MixUp: 0.4194, Trg MixUp: 0.5807, Src Train Acc: 98.74, Trg Train Acc: 92.71, Src Test Acc: 96.50, Trg Test Acc: 91.29
# Epoch: 046, TotalL: 0.6508, CrossE: 0.0426, CondE: 0.1460, disc: 0.6638, domain: 0.8529, Src VAT: 0.0762, Trg VAT: 0.1460, Src MixUp: 0.3930, Trg MixUp: 0.5925, Src Train Acc: 98.70, Trg Train Acc: 94.18, Src Test Acc: 94.55, Trg Test Acc: 90.76
# Epoch: 047, TotalL: 0.6542, CrossE: 0.0342, CondE: 0.1441, disc: 0.6664, domain: 0.8525, Src VAT: 0.0791, Trg VAT: 0.1441, Src MixUp: 0.4028, Trg MixUp: 0.5854, Src Train Acc: 99.18, Trg Train Acc: 94.05, Src Test Acc: 98.44, Trg Test Acc: 90.03
# Epoch: 048, TotalL: 0.6512, CrossE: 0.0430, CondE: 0.1510, disc: 0.6639, domain: 0.8565, Src VAT: 0.0752, Trg VAT: 0.1510, Src MixUp: 0.3936, Trg MixUp: 0.5852, Src Train Acc: 98.83, Trg Train Acc: 93.53, Src Test Acc: 97.28, Trg Test Acc: 93.71
# Epoch: 049, TotalL: 0.6808, CrossE: 0.0388, CondE: 0.1662, disc: 0.6666, domain: 0.8406, Src VAT: 0.0820, Trg VAT: 0.1662, Src MixUp: 0.4217, Trg MixUp: 0.5549, Src Train Acc: 99.05, Trg Train Acc: 92.93, Src Test Acc: 90.66, Trg Test Acc: 75.20
# Epoch: 050, TotalL: 0.7015, CrossE: 0.0507, CondE: 0.1618, disc: 0.6621, domain: 0.8496, Src VAT: 0.0795, Trg VAT: 0.1618, Src MixUp: 0.4302, Trg MixUp: 0.5905, Src Train Acc: 98.44, Trg Train Acc: 92.88, Src Test Acc: 96.89, Trg Test Acc: 87.40
# Epoch: 051, TotalL: 0.6685, CrossE: 0.0437, CondE: 0.1482, disc: 0.6680, domain: 0.8449, Src VAT: 0.0819, Trg VAT: 0.1482, Src MixUp: 0.4054, Trg MixUp: 0.5792, Src Train Acc: 98.83, Trg Train Acc: 93.49, Src Test Acc: 97.28, Trg Test Acc: 90.73
# Epoch: 052, TotalL: 0.6537, CrossE: 0.0465, CondE: 0.1386, disc: 0.6621, domain: 0.8487, Src VAT: 0.0754, Trg VAT: 0.1386, Src MixUp: 0.3958, Trg MixUp: 0.5732, Src Train Acc: 98.91, Trg Train Acc: 93.92, Src Test Acc: 97.28, Trg Test Acc: 92.22
# Epoch: 053, TotalL: 0.6352, CrossE: 0.0283, CondE: 0.1429, disc: 0.6608, domain: 0.8583, Src VAT: 0.0706, Trg VAT: 0.1429, Src MixUp: 0.3983, Trg MixUp: 0.5806, Src Train Acc: 99.31, Trg Train Acc: 94.14, Src Test Acc: 97.28, Trg Test Acc: 93.16
# Epoch: 054, TotalL: 0.5932, CrossE: 0.0234, CondE: 0.1326, disc: 0.6638, domain: 0.8413, Src VAT: 0.0631, Trg VAT: 0.1326, Src MixUp: 0.3736, Trg MixUp: 0.5569, Src Train Acc: 99.48, Trg Train Acc: 94.01, Src Test Acc: 96.50, Trg Test Acc: 91.17
# Epoch: 055, TotalL: 0.6126, CrossE: 0.0329, CondE: 0.1329, disc: 0.6609, domain: 0.8532, Src VAT: 0.0656, Trg VAT: 0.1329, Src MixUp: 0.3793, Trg MixUp: 0.5654, Src Train Acc: 99.05, Trg Train Acc: 94.49, Src Test Acc: 97.28, Trg Test Acc: 93.57
# Epoch: 056, TotalL: 0.6255, CrossE: 0.0316, CondE: 0.1497, disc: 0.6657, domain: 0.8457, Src VAT: 0.0721, Trg VAT: 0.1497, Src MixUp: 0.3846, Trg MixUp: 0.5701, Src Train Acc: 99.09, Trg Train Acc: 92.66, Src Test Acc: 96.11, Trg Test Acc: 88.77
# Epoch: 057, TotalL: 0.5633, CrossE: 0.0271, CondE: 0.1243, disc: 0.6642, domain: 0.8527, Src VAT: 0.0560, Trg VAT: 0.1243, Src MixUp: 0.3480, Trg MixUp: 0.5501, Src Train Acc: 99.05, Trg Train Acc: 94.70, Src Test Acc: 98.05, Trg Test Acc: 94.15
# Epoch: 058, TotalL: 0.5917, CrossE: 0.0295, CondE: 0.1174, disc: 0.6695, domain: 0.8399, Src VAT: 0.0589, Trg VAT: 0.1174, Src MixUp: 0.3747, Trg MixUp: 0.5342, Src Train Acc: 99.18, Trg Train Acc: 94.88, Src Test Acc: 95.33, Trg Test Acc: 92.89
# Epoch: 059, TotalL: 0.5533, CrossE: 0.0234, CondE: 0.1238, disc: 0.6640, domain: 0.8321, Src VAT: 0.0537, Trg VAT: 0.1238, Src MixUp: 0.3471, Trg MixUp: 0.5331, Src Train Acc: 99.39, Trg Train Acc: 93.75, Src Test Acc: 96.11, Trg Test Acc: 93.65
# Epoch: 060, TotalL: 0.6046, CrossE: 0.0342, CondE: 0.1305, disc: 0.6691, domain: 0.8348, Src VAT: 0.0660, Trg VAT: 0.1305, Src MixUp: 0.3723, Trg MixUp: 0.5556, Src Train Acc: 99.22, Trg Train Acc: 93.79, Src Test Acc: 97.28, Trg Test Acc: 95.50
# Epoch: 061, TotalL: 0.5587, CrossE: 0.0219, CondE: 0.1159, disc: 0.6602, domain: 0.8418, Src VAT: 0.0509, Trg VAT: 0.1159, Src MixUp: 0.3573, Trg MixUp: 0.5350, Src Train Acc: 99.48, Trg Train Acc: 94.31, Src Test Acc: 98.44, Trg Test Acc: 87.89
# Epoch: 062, TotalL: 0.5995, CrossE: 0.0387, CondE: 0.1259, disc: 0.6625, domain: 0.8466, Src VAT: 0.0634, Trg VAT: 0.1259, Src MixUp: 0.3652, Trg MixUp: 0.5545, Src Train Acc: 98.87, Trg Train Acc: 93.88, Src Test Acc: 98.44, Trg Test Acc: 94.06
# Epoch: 063, TotalL: 0.5920, CrossE: 0.0399, CondE: 0.1214, disc: 0.6666, domain: 0.8365, Src VAT: 0.0589, Trg VAT: 0.1214, Src MixUp: 0.3649, Trg MixUp: 0.5245, Src Train Acc: 98.61, Trg Train Acc: 93.36, Src Test Acc: 91.05, Trg Test Acc: 83.19
# Epoch: 064, TotalL: 0.5667, CrossE: 0.0303, CondE: 0.1199, disc: 0.6623, domain: 0.8398, Src VAT: 0.0530, Trg VAT: 0.1199, Src MixUp: 0.3527, Trg MixUp: 0.5537, Src Train Acc: 99.22, Trg Train Acc: 94.10, Src Test Acc: 98.83, Trg Test Acc: 94.15
# Epoch: 065, TotalL: 0.5431, CrossE: 0.0253, CondE: 0.1138, disc: 0.6608, domain: 0.8359, Src VAT: 0.0481, Trg VAT: 0.1138, Src MixUp: 0.3441, Trg MixUp: 0.5069, Src Train Acc: 99.48, Trg Train Acc: 94.97, Src Test Acc: 97.67, Trg Test Acc: 94.27
# Epoch: 066, TotalL: 0.5342, CrossE: 0.0227, CondE: 0.1136, disc: 0.6645, domain: 0.8354, Src VAT: 0.0478, Trg VAT: 0.1136, Src MixUp: 0.3347, Trg MixUp: 0.5501, Src Train Acc: 99.39, Trg Train Acc: 94.84, Src Test Acc: 98.05, Trg Test Acc: 92.37
# Epoch: 067, TotalL: 0.5385, CrossE: 0.0275, CondE: 0.1136, disc: 0.6640, domain: 0.8364, Src VAT: 0.0503, Trg VAT: 0.1136, Src MixUp: 0.3352, Trg MixUp: 0.5059, Src Train Acc: 99.26, Trg Train Acc: 93.75, Src Test Acc: 98.44, Trg Test Acc: 94.62
# Epoch: 068, TotalL: 0.5566, CrossE: 0.0295, CondE: 0.1125, disc: 0.6552, domain: 0.8432, Src VAT: 0.0519, Trg VAT: 0.1125, Src MixUp: 0.3487, Trg MixUp: 0.5124, Src Train Acc: 99.05, Trg Train Acc: 94.40, Src Test Acc: 94.16, Trg Test Acc: 91.26
# Epoch: 069, TotalL: 0.5375, CrossE: 0.0246, CondE: 0.1135, disc: 0.6655, domain: 0.8328, Src VAT: 0.0500, Trg VAT: 0.1135, Src MixUp: 0.3368, Trg MixUp: 0.5164, Src Train Acc: 99.31, Trg Train Acc: 94.40, Src Test Acc: 88.33, Trg Test Acc: 74.06
# Epoch: 070, TotalL: 0.5684, CrossE: 0.0280, CondE: 0.1096, disc: 0.6630, domain: 0.8238, Src VAT: 0.0541, Trg VAT: 0.1096, Src MixUp: 0.3600, Trg MixUp: 0.5356, Src Train Acc: 99.22, Trg Train Acc: 94.23, Src Test Acc: 97.67, Trg Test Acc: 94.44
# Epoch: 071, TotalL: 0.5066, CrossE: 0.0201, CondE: 0.1076, disc: 0.6651, domain: 0.8245, Src VAT: 0.0428, Trg VAT: 0.1076, Src MixUp: 0.3179, Trg MixUp: 0.5340, Src Train Acc: 99.65, Trg Train Acc: 95.10, Src Test Acc: 98.05, Trg Test Acc: 97.19
# Epoch: 072, TotalL: 0.5492, CrossE: 0.0308, CondE: 0.1106, disc: 0.6615, domain: 0.8333, Src VAT: 0.0491, Trg VAT: 0.1106, Src MixUp: 0.3423, Trg MixUp: 0.5325, Src Train Acc: 99.22, Trg Train Acc: 94.27, Src Test Acc: 99.22, Trg Test Acc: 95.26
# Epoch: 073, TotalL: 0.5131, CrossE: 0.0171, CondE: 0.1090, disc: 0.6585, domain: 0.8370, Src VAT: 0.0410, Trg VAT: 0.1090, Src MixUp: 0.3265, Trg MixUp: 0.5530, Src Train Acc: 99.57, Trg Train Acc: 95.70, Src Test Acc: 98.44, Trg Test Acc: 92.02
# Epoch: 074, TotalL: 0.5268, CrossE: 0.0279, CondE: 0.1027, disc: 0.6643, domain: 0.8376, Src VAT: 0.0465, Trg VAT: 0.1027, Src MixUp: 0.3280, Trg MixUp: 0.5123, Src Train Acc: 99.35, Trg Train Acc: 95.23, Src Test Acc: 99.22, Trg Test Acc: 93.86
# Epoch: 075, TotalL: 0.5257, CrossE: 0.0183, CondE: 0.1059, disc: 0.6612, domain: 0.8327, Src VAT: 0.0433, Trg VAT: 0.1059, Src MixUp: 0.3381, Trg MixUp: 0.5296, Src Train Acc: 99.65, Trg Train Acc: 95.18, Src Test Acc: 96.11, Trg Test Acc: 94.50
# Epoch: 076, TotalL: 0.5025, CrossE: 0.0258, CondE: 0.1040, disc: 0.6682, domain: 0.8264, Src VAT: 0.0442, Trg VAT: 0.1040, Src MixUp: 0.3086, Trg MixUp: 0.5141, Src Train Acc: 99.26, Trg Train Acc: 94.27, Src Test Acc: 97.28, Trg Test Acc: 92.31
# Epoch: 077, TotalL: 0.5148, CrossE: 0.0270, CondE: 0.1069, disc: 0.6648, domain: 0.8248, Src VAT: 0.0472, Trg VAT: 0.1069, Src MixUp: 0.3173, Trg MixUp: 0.5027, Src Train Acc: 99.09, Trg Train Acc: 94.18, Src Test Acc: 95.72, Trg Test Acc: 94.50
# Epoch: 078, TotalL: 0.4922, CrossE: 0.0195, CondE: 0.0944, disc: 0.6572, domain: 0.8388, Src VAT: 0.0373, Trg VAT: 0.0944, Src MixUp: 0.3123, Trg MixUp: 0.5103, Src Train Acc: 99.48, Trg Train Acc: 95.36, Src Test Acc: 97.28, Trg Test Acc: 95.26
# Epoch: 079, TotalL: 0.5242, CrossE: 0.0212, CondE: 0.1014, disc: 0.6656, domain: 0.8212, Src VAT: 0.0440, Trg VAT: 0.1014, Src MixUp: 0.3360, Trg MixUp: 0.5130, Src Train Acc: 99.39, Trg Train Acc: 95.14, Src Test Acc: 92.22, Trg Test Acc: 84.50
# Epoch: 080, TotalL: 0.5369, CrossE: 0.0279, CondE: 0.1101, disc: 0.6686, domain: 0.8243, Src VAT: 0.0505, Trg VAT: 0.1101, Src MixUp: 0.3336, Trg MixUp: 0.5175, Src Train Acc: 99.39, Trg Train Acc: 94.31, Src Test Acc: 95.33, Trg Test Acc: 95.15
# Epoch: 081, TotalL: 0.4833, CrossE: 0.0168, CondE: 0.0935, disc: 0.6574, domain: 0.8391, Src VAT: 0.0360, Trg VAT: 0.0935, Src MixUp: 0.3080, Trg MixUp: 0.5052, Src Train Acc: 99.39, Trg Train Acc: 95.01, Src Test Acc: 98.44, Trg Test Acc: 97.34
# Epoch: 082, TotalL: 0.4681, CrossE: 0.0128, CondE: 0.0887, disc: 0.6660, domain: 0.8206, Src VAT: 0.0337, Trg VAT: 0.0887, Src MixUp: 0.3011, Trg MixUp: 0.5093, Src Train Acc: 99.70, Trg Train Acc: 95.92, Src Test Acc: 95.72, Trg Test Acc: 94.39
# Epoch: 083, TotalL: 0.5318, CrossE: 0.0266, CondE: 0.1074, disc: 0.6651, domain: 0.8276, Src VAT: 0.0485, Trg VAT: 0.1074, Src MixUp: 0.3322, Trg MixUp: 0.5127, Src Train Acc: 99.22, Trg Train Acc: 94.57, Src Test Acc: 98.05, Trg Test Acc: 95.99
# Epoch: 084, TotalL: 0.4776, CrossE: 0.0193, CondE: 0.0873, disc: 0.6655, domain: 0.8163, Src VAT: 0.0386, Trg VAT: 0.0873, Src MixUp: 0.3012, Trg MixUp: 0.4889, Src Train Acc: 99.48, Trg Train Acc: 95.31, Src Test Acc: 98.05, Trg Test Acc: 91.26
# Epoch: 085, TotalL: 0.4876, CrossE: 0.0193, CondE: 0.0827, disc: 0.6687, domain: 0.8150, Src VAT: 0.0415, Trg VAT: 0.0827, Src MixUp: 0.3079, Trg MixUp: 0.5063, Src Train Acc: 99.48, Trg Train Acc: 95.05, Src Test Acc: 97.67, Trg Test Acc: 93.25
# Epoch: 086, TotalL: 0.5001, CrossE: 0.0198, CondE: 0.0946, disc: 0.6630, domain: 0.8113, Src VAT: 0.0387, Trg VAT: 0.0946, Src MixUp: 0.3205, Trg MixUp: 0.5127, Src Train Acc: 99.44, Trg Train Acc: 96.01, Src Test Acc: 91.05, Trg Test Acc: 78.68
# Epoch: 087, TotalL: 0.4901, CrossE: 0.0169, CondE: 0.0831, disc: 0.6670, domain: 0.8072, Src VAT: 0.0386, Trg VAT: 0.0831, Src MixUp: 0.3166, Trg MixUp: 0.5028, Src Train Acc: 99.70, Trg Train Acc: 95.62, Src Test Acc: 96.50, Trg Test Acc: 96.32
# Epoch: 088, TotalL: 0.4660, CrossE: 0.0154, CondE: 0.0859, disc: 0.6615, domain: 0.8195, Src VAT: 0.0324, Trg VAT: 0.0859, Src MixUp: 0.3008, Trg MixUp: 0.4763, Src Train Acc: 99.48, Trg Train Acc: 95.96, Src Test Acc: 98.83, Trg Test Acc: 96.96
# Epoch: 089, TotalL: 0.5076, CrossE: 0.0196, CondE: 0.0951, disc: 0.6689, domain: 0.8123, Src VAT: 0.0386, Trg VAT: 0.0951, Src MixUp: 0.3286, Trg MixUp: 0.5072, Src Train Acc: 99.52, Trg Train Acc: 95.18, Src Test Acc: 98.05, Trg Test Acc: 95.96
# Epoch: 090, TotalL: 0.5060, CrossE: 0.0258, CondE: 0.1048, disc: 0.6617, domain: 0.8213, Src VAT: 0.0450, Trg VAT: 0.1048, Src MixUp: 0.3129, Trg MixUp: 0.4981, Src Train Acc: 99.22, Trg Train Acc: 94.14, Src Test Acc: 98.05, Trg Test Acc: 96.29
# Epoch: 091, TotalL: 0.4421, CrossE: 0.0099, CondE: 0.0772, disc: 0.6603, domain: 0.8257, Src VAT: 0.0304, Trg VAT: 0.0772, Src MixUp: 0.2848, Trg MixUp: 0.4816, Src Train Acc: 99.91, Trg Train Acc: 95.57, Src Test Acc: 94.55, Trg Test Acc: 85.73
# Epoch: 092, TotalL: 0.4856, CrossE: 0.0276, CondE: 0.1023, disc: 0.6615, domain: 0.8233, Src VAT: 0.0398, Trg VAT: 0.1023, Src MixUp: 0.2973, Trg MixUp: 0.4826, Src Train Acc: 99.39, Trg Train Acc: 95.27, Src Test Acc: 97.28, Trg Test Acc: 95.15
# Epoch: 093, TotalL: 0.4682, CrossE: 0.0144, CondE: 0.0895, disc: 0.6648, domain: 0.8136, Src VAT: 0.0364, Trg VAT: 0.0895, Src MixUp: 0.2986, Trg MixUp: 0.4912, Src Train Acc: 99.61, Trg Train Acc: 95.40, Src Test Acc: 97.28, Trg Test Acc: 96.14
# Epoch: 094, TotalL: 0.4980, CrossE: 0.0263, CondE: 0.0904, disc: 0.6700, domain: 0.8050, Src VAT: 0.0398, Trg VAT: 0.0904, Src MixUp: 0.3131, Trg MixUp: 0.4998, Src Train Acc: 99.13, Trg Train Acc: 95.10, Src Test Acc: 96.50, Trg Test Acc: 91.02
# Epoch: 095, TotalL: 0.4495, CrossE: 0.0147, CondE: 0.0830, disc: 0.6639, domain: 0.8161, Src VAT: 0.0274, Trg VAT: 0.0830, Src MixUp: 0.2910, Trg MixUp: 0.4724, Src Train Acc: 99.57, Trg Train Acc: 95.75, Src Test Acc: 97.67, Trg Test Acc: 94.62
# Epoch: 096, TotalL: 0.4881, CrossE: 0.0184, CondE: 0.0887, disc: 0.6687, domain: 0.8059, Src VAT: 0.0388, Trg VAT: 0.0887, Src MixUp: 0.3143, Trg MixUp: 0.4752, Src Train Acc: 99.57, Trg Train Acc: 95.40, Src Test Acc: 94.16, Trg Test Acc: 83.68
# Epoch: 097, TotalL: 0.5338, CrossE: 0.0540, CondE: 0.0930, disc: 0.6719, domain: 0.8118, Src VAT: 0.0440, Trg VAT: 0.0930, Src MixUp: 0.3166, Trg MixUp: 0.4938, Src Train Acc: 98.70, Trg Train Acc: 94.97, Src Test Acc: 95.72, Trg Test Acc: 94.39
# Epoch: 098, TotalL: 0.4493, CrossE: 0.0107, CondE: 0.0816, disc: 0.6613, domain: 0.8066, Src VAT: 0.0291, Trg VAT: 0.0816, Src MixUp: 0.2922, Trg MixUp: 0.4967, Src Train Acc: 99.70, Trg Train Acc: 95.92, Src Test Acc: 97.67, Trg Test Acc: 90.32
# Epoch: 099, TotalL: 0.4775, CrossE: 0.0293, CondE: 0.0855, disc: 0.6693, domain: 0.8021, Src VAT: 0.0389, Trg VAT: 0.0855, Src MixUp: 0.2920, Trg MixUp: 0.4935, Src Train Acc: 99.31, Trg Train Acc: 95.53, Src Test Acc: 98.05, Trg Test Acc: 95.99
# Epoch: 100, TotalL: 0.4428, CrossE: 0.0102, CondE: 0.0808, disc: 0.6617, domain: 0.8125, Src VAT: 0.0276, Trg VAT: 0.0808, Src MixUp: 0.2889, Trg MixUp: 0.4761, Src Train Acc: 99.74, Trg Train Acc: 95.49, Src Test Acc: 97.28, Trg Test Acc: 95.03
# Epoch: 101, TotalL: 0.4527, CrossE: 0.0127, CondE: 0.0831, disc: 0.6639, domain: 0.8140, Src VAT: 0.0298, Trg VAT: 0.0831, Src MixUp: 0.2954, Trg MixUp: 0.4549, Src Train Acc: 99.65, Trg Train Acc: 95.70, Src Test Acc: 97.28, Trg Test Acc: 93.71
# Epoch: 102, TotalL: 0.4414, CrossE: 0.0194, CondE: 0.0882, disc: 0.6674, domain: 0.8078, Src VAT: 0.0314, Trg VAT: 0.0882, Src MixUp: 0.2733, Trg MixUp: 0.4838, Src Train Acc: 99.48, Trg Train Acc: 94.84, Src Test Acc: 98.83, Trg Test Acc: 95.70
# Epoch: 103, TotalL: 0.4552, CrossE: 0.0141, CondE: 0.0745, disc: 0.6632, domain: 0.8139, Src VAT: 0.0310, Trg VAT: 0.0745, Src MixUp: 0.2949, Trg MixUp: 0.4779, Src Train Acc: 99.48, Trg Train Acc: 95.75, Src Test Acc: 98.05, Trg Test Acc: 96.58
# Epoch: 104, TotalL: 0.4368, CrossE: 0.0229, CondE: 0.0772, disc: 0.6710, domain: 0.8009, Src VAT: 0.0334, Trg VAT: 0.0772, Src MixUp: 0.2679, Trg MixUp: 0.4531, Src Train Acc: 99.31, Trg Train Acc: 95.18, Src Test Acc: 97.28, Trg Test Acc: 96.37
# Epoch: 105, TotalL: 0.4703, CrossE: 0.0255, CondE: 0.0847, disc: 0.6714, domain: 0.7943, Src VAT: 0.0383, Trg VAT: 0.0847, Src MixUp: 0.2910, Trg MixUp: 0.4796, Src Train Acc: 99.39, Trg Train Acc: 95.10, Src Test Acc: 97.28, Trg Test Acc: 95.56
# Epoch: 106, TotalL: 0.4065, CrossE: 0.0065, CondE: 0.0719, disc: 0.6628, domain: 0.8064, Src VAT: 0.0218, Trg VAT: 0.0719, Src MixUp: 0.2656, Trg MixUp: 0.4585, Src Train Acc: 99.91, Trg Train Acc: 96.09, Src Test Acc: 99.61, Trg Test Acc: 95.00
# Epoch: 107, TotalL: 0.4423, CrossE: 0.0190, CondE: 0.0795, disc: 0.6670, domain: 0.8033, Src VAT: 0.0262, Trg VAT: 0.0795, Src MixUp: 0.2815, Trg MixUp: 0.4837, Src Train Acc: 99.39, Trg Train Acc: 95.10, Src Test Acc: 97.67, Trg Test Acc: 95.00
# Epoch: 108, TotalL: 0.4345, CrossE: 0.0163, CondE: 0.0823, disc: 0.6683, domain: 0.8035, Src VAT: 0.0267, Trg VAT: 0.0823, Src MixUp: 0.2773, Trg MixUp: 0.4597, Src Train Acc: 99.57, Trg Train Acc: 95.66, Src Test Acc: 96.89, Trg Test Acc: 95.82
# Epoch: 109, TotalL: 0.4577, CrossE: 0.0183, CondE: 0.0853, disc: 0.6630, domain: 0.8081, Src VAT: 0.0307, Trg VAT: 0.0853, Src MixUp: 0.2932, Trg MixUp: 0.4669, Src Train Acc: 99.48, Trg Train Acc: 95.49, Src Test Acc: 98.05, Trg Test Acc: 94.47
# Epoch: 110, TotalL: 0.4597, CrossE: 0.0220, CondE: 0.0862, disc: 0.6639, domain: 0.8071, Src VAT: 0.0302, Trg VAT: 0.0862, Src MixUp: 0.2899, Trg MixUp: 0.4911, Src Train Acc: 99.35, Trg Train Acc: 95.44, Src Test Acc: 98.05, Trg Test Acc: 92.22
# Epoch: 111, TotalL: 0.4337, CrossE: 0.0107, CondE: 0.0779, disc: 0.6651, domain: 0.8031, Src VAT: 0.0268, Trg VAT: 0.0779, Src MixUp: 0.2825, Trg MixUp: 0.4626, Src Train Acc: 99.78, Trg Train Acc: 95.49, Src Test Acc: 98.05, Trg Test Acc: 95.64
# Epoch: 112, TotalL: 0.4655, CrossE: 0.0204, CondE: 0.0764, disc: 0.6619, domain: 0.8156, Src VAT: 0.0310, Trg VAT: 0.0764, Src MixUp: 0.2999, Trg MixUp: 0.4595, Src Train Acc: 99.39, Trg Train Acc: 95.79, Src Test Acc: 98.44, Trg Test Acc: 97.08
# Epoch: 113, TotalL: 0.4646, CrossE: 0.0142, CondE: 0.0785, disc: 0.6661, domain: 0.8073, Src VAT: 0.0326, Trg VAT: 0.0785, Src MixUp: 0.3035, Trg MixUp: 0.4630, Src Train Acc: 99.52, Trg Train Acc: 96.01, Src Test Acc: 96.89, Trg Test Acc: 93.48
# Epoch: 114, TotalL: 0.4411, CrossE: 0.0168, CondE: 0.0761, disc: 0.6698, domain: 0.7953, Src VAT: 0.0304, Trg VAT: 0.0761, Src MixUp: 0.2818, Trg MixUp: 0.4534, Src Train Acc: 99.31, Trg Train Acc: 95.75, Src Test Acc: 98.05, Trg Test Acc: 96.96
# Epoch: 115, TotalL: 0.4029, CrossE: 0.0067, CondE: 0.0604, disc: 0.6625, domain: 0.8074, Src VAT: 0.0203, Trg VAT: 0.0604, Src MixUp: 0.2668, Trg MixUp: 0.4363, Src Train Acc: 99.87, Trg Train Acc: 95.96, Src Test Acc: 97.67, Trg Test Acc: 95.88
# Epoch: 116, TotalL: 0.3991, CrossE: 0.0107, CondE: 0.0697, disc: 0.6634, domain: 0.8130, Src VAT: 0.0248, Trg VAT: 0.0697, Src MixUp: 0.2525, Trg MixUp: 0.4355, Src Train Acc: 99.74, Trg Train Acc: 95.70, Src Test Acc: 94.16, Trg Test Acc: 91.02
# Epoch: 117, TotalL: 0.4240, CrossE: 0.0137, CondE: 0.0693, disc: 0.6623, domain: 0.8070, Src VAT: 0.0278, Trg VAT: 0.0693, Src MixUp: 0.2720, Trg MixUp: 0.4354, Src Train Acc: 99.57, Trg Train Acc: 95.92, Src Test Acc: 97.28, Trg Test Acc: 93.51
# Epoch: 118, TotalL: 0.4182, CrossE: 0.0146, CondE: 0.0673, disc: 0.6663, domain: 0.8032, Src VAT: 0.0240, Trg VAT: 0.0673, Src MixUp: 0.2691, Trg MixUp: 0.4440, Src Train Acc: 99.61, Trg Train Acc: 95.79, Src Test Acc: 99.22, Trg Test Acc: 96.55
# Epoch: 119, TotalL: 0.4343, CrossE: 0.0136, CondE: 0.0774, disc: 0.6722, domain: 0.7934, Src VAT: 0.0285, Trg VAT: 0.0774, Src MixUp: 0.2803, Trg MixUp: 0.4502, Src Train Acc: 99.65, Trg Train Acc: 95.66, Src Test Acc: 96.50, Trg Test Acc: 90.76
# Epoch: 120, TotalL: 0.4156, CrossE: 0.0184, CondE: 0.0687, disc: 0.6677, domain: 0.7953, Src VAT: 0.0263, Trg VAT: 0.0687, Src MixUp: 0.2620, Trg MixUp: 0.4296, Src Train Acc: 99.44, Trg Train Acc: 96.66, Src Test Acc: 95.72, Trg Test Acc: 90.99
# Epoch: 121, TotalL: 0.4173, CrossE: 0.0122, CondE: 0.0710, disc: 0.6655, domain: 0.8025, Src VAT: 0.0270, Trg VAT: 0.0710, Src MixUp: 0.2673, Trg MixUp: 0.4393, Src Train Acc: 99.74, Trg Train Acc: 95.79, Src Test Acc: 87.94, Trg Test Acc: 77.81
# Epoch: 122, TotalL: 0.4580, CrossE: 0.0273, CondE: 0.0753, disc: 0.6651, domain: 0.8045, Src VAT: 0.0357, Trg VAT: 0.0753, Src MixUp: 0.2830, Trg MixUp: 0.4447, Src Train Acc: 99.31, Trg Train Acc: 95.96, Src Test Acc: 97.28, Trg Test Acc: 92.08
# Epoch: 123, TotalL: 0.4069, CrossE: 0.0107, CondE: 0.0679, disc: 0.6678, domain: 0.7981, Src VAT: 0.0223, Trg VAT: 0.0679, Src MixUp: 0.2629, Trg MixUp: 0.4527, Src Train Acc: 99.74, Trg Train Acc: 96.18, Src Test Acc: 98.05, Trg Test Acc: 96.58
# Epoch: 124, TotalL: 0.4025, CrossE: 0.0096, CondE: 0.0626, disc: 0.6668, domain: 0.7983, Src VAT: 0.0234, Trg VAT: 0.0626, Src MixUp: 0.2600, Trg MixUp: 0.4449, Src Train Acc: 99.78, Trg Train Acc: 96.88, Src Test Acc: 93.39, Trg Test Acc: 89.53
# Epoch: 125, TotalL: 0.4036, CrossE: 0.0093, CondE: 0.0651, disc: 0.6661, domain: 0.7996, Src VAT: 0.0188, Trg VAT: 0.0651, Src MixUp: 0.2652, Trg MixUp: 0.4497, Src Train Acc: 99.74, Trg Train Acc: 96.74, Src Test Acc: 98.44, Trg Test Acc: 95.79
# Epoch: 126, TotalL: 0.4112, CrossE: 0.0136, CondE: 0.0657, disc: 0.6692, domain: 0.7987, Src VAT: 0.0240, Trg VAT: 0.0657, Src MixUp: 0.2635, Trg MixUp: 0.4451, Src Train Acc: 99.65, Trg Train Acc: 96.57, Src Test Acc: 98.05, Trg Test Acc: 97.05
# Epoch: 127, TotalL: 0.3704, CrossE: 0.0080, CondE: 0.0555, disc: 0.6652, domain: 0.8009, Src VAT: 0.0199, Trg VAT: 0.0555, Src MixUp: 0.2362, Trg MixUp: 0.4165, Src Train Acc: 99.70, Trg Train Acc: 96.74, Src Test Acc: 92.61, Trg Test Acc: 90.09
# Epoch: 128, TotalL: 0.4121, CrossE: 0.0169, CondE: 0.0693, disc: 0.6648, domain: 0.8076, Src VAT: 0.0278, Trg VAT: 0.0693, Src MixUp: 0.2571, Trg MixUp: 0.4319, Src Train Acc: 99.44, Trg Train Acc: 96.27, Src Test Acc: 100.00, Trg Test Acc: 95.38
# Epoch: 129, TotalL: 0.3682, CrossE: 0.0056, CondE: 0.0599, disc: 0.6596, domain: 0.8163, Src VAT: 0.0157, Trg VAT: 0.0599, Src MixUp: 0.2370, Trg MixUp: 0.4374, Src Train Acc: 99.91, Trg Train Acc: 96.48, Src Test Acc: 98.44, Trg Test Acc: 93.92
# Epoch: 130, TotalL: 0.4380, CrossE: 0.0261, CondE: 0.0659, disc: 0.6713, domain: 0.7947, Src VAT: 0.0285, Trg VAT: 0.0659, Src MixUp: 0.2714, Trg MixUp: 0.4727, Src Train Acc: 99.48, Trg Train Acc: 96.53, Src Test Acc: 98.83, Trg Test Acc: 96.64
# Epoch: 131, TotalL: 0.3706, CrossE: 0.0080, CondE: 0.0548, disc: 0.6685, domain: 0.7900, Src VAT: 0.0178, Trg VAT: 0.0548, Src MixUp: 0.2377, Trg MixUp: 0.4398, Src Train Acc: 99.83, Trg Train Acc: 97.14, Src Test Acc: 98.44, Trg Test Acc: 94.47
# Epoch: 132, TotalL: 0.3990, CrossE: 0.0130, CondE: 0.0669, disc: 0.6668, domain: 0.7964, Src VAT: 0.0231, Trg VAT: 0.0669, Src MixUp: 0.2534, Trg MixUp: 0.4392, Src Train Acc: 99.61, Trg Train Acc: 96.57, Src Test Acc: 95.72, Trg Test Acc: 91.11
# Epoch: 133, TotalL: 0.4053, CrossE: 0.0135, CondE: 0.0682, disc: 0.6664, domain: 0.7920, Src VAT: 0.0246, Trg VAT: 0.0682, Src MixUp: 0.2563, Trg MixUp: 0.4569, Src Train Acc: 99.65, Trg Train Acc: 96.01, Src Test Acc: 95.72, Trg Test Acc: 95.47
# Epoch: 134, TotalL: 0.3978, CrossE: 0.0138, CondE: 0.0595, disc: 0.6613, domain: 0.8045, Src VAT: 0.0209, Trg VAT: 0.0595, Src MixUp: 0.2548, Trg MixUp: 0.4288, Src Train Acc: 99.65, Trg Train Acc: 96.96, Src Test Acc: 98.83, Trg Test Acc: 96.84
# Epoch: 135, TotalL: 0.3766, CrossE: 0.0072, CondE: 0.0581, disc: 0.6625, domain: 0.8056, Src VAT: 0.0200, Trg VAT: 0.0581, Src MixUp: 0.2429, Trg MixUp: 0.4084, Src Train Acc: 99.87, Trg Train Acc: 96.31, Src Test Acc: 94.55, Trg Test Acc: 94.82
# Epoch: 136, TotalL: 0.3915, CrossE: 0.0104, CondE: 0.0614, disc: 0.6673, domain: 0.8104, Src VAT: 0.0201, Trg VAT: 0.0614, Src MixUp: 0.2503, Trg MixUp: 0.4496, Src Train Acc: 99.65, Trg Train Acc: 96.27, Src Test Acc: 97.28, Trg Test Acc: 92.43
# Epoch: 137, TotalL: 0.3747, CrossE: 0.0085, CondE: 0.0592, disc: 0.6620, domain: 0.8073, Src VAT: 0.0195, Trg VAT: 0.0592, Src MixUp: 0.2370, Trg MixUp: 0.4445, Src Train Acc: 99.78, Trg Train Acc: 96.40, Src Test Acc: 98.44, Trg Test Acc: 96.58
# Epoch: 138, TotalL: 0.3899, CrossE: 0.0105, CondE: 0.0648, disc: 0.6657, domain: 0.8017, Src VAT: 0.0235, Trg VAT: 0.0648, Src MixUp: 0.2475, Trg MixUp: 0.4233, Src Train Acc: 99.78, Trg Train Acc: 96.05, Src Test Acc: 99.22, Trg Test Acc: 97.34
# Epoch: 139, TotalL: 0.4181, CrossE: 0.0210, CondE: 0.0634, disc: 0.6677, domain: 0.8032, Src VAT: 0.0211, Trg VAT: 0.0634, Src MixUp: 0.2663, Trg MixUp: 0.4398, Src Train Acc: 99.52, Trg Train Acc: 96.14, Src Test Acc: 99.61, Trg Test Acc: 97.37
# Epoch: 140, TotalL: 0.3838, CrossE: 0.0091, CondE: 0.0611, disc: 0.6710, domain: 0.7861, Src VAT: 0.0197, Trg VAT: 0.0611, Src MixUp: 0.2469, Trg MixUp: 0.4428, Src Train Acc: 99.74, Trg Train Acc: 96.61, Src Test Acc: 98.44, Trg Test Acc: 93.01
# Epoch: 141, TotalL: 0.3797, CrossE: 0.0096, CondE: 0.0534, disc: 0.6685, domain: 0.7895, Src VAT: 0.0204, Trg VAT: 0.0534, Src MixUp: 0.2445, Trg MixUp: 0.4188, Src Train Acc: 99.74, Trg Train Acc: 97.27, Src Test Acc: 98.44, Trg Test Acc: 96.75
# Epoch: 142, TotalL: 0.4062, CrossE: 0.0210, CondE: 0.0646, disc: 0.6660, domain: 0.8017, Src VAT: 0.0250, Trg VAT: 0.0646, Src MixUp: 0.2531, Trg MixUp: 0.4087, Src Train Acc: 99.44, Trg Train Acc: 96.27, Src Test Acc: 98.05, Trg Test Acc: 92.95
# Epoch: 143, TotalL: 0.3811, CrossE: 0.0097, CondE: 0.0576, disc: 0.6697, domain: 0.7901, Src VAT: 0.0214, Trg VAT: 0.0576, Src MixUp: 0.2443, Trg MixUp: 0.4167, Src Train Acc: 99.70, Trg Train Acc: 96.96, Src Test Acc: 98.83, Trg Test Acc: 96.11
# Epoch: 144, TotalL: 0.3751, CrossE: 0.0110, CondE: 0.0602, disc: 0.6671, domain: 0.7953, Src VAT: 0.0181, Trg VAT: 0.0602, Src MixUp: 0.2393, Trg MixUp: 0.4184, Src Train Acc: 99.74, Trg Train Acc: 96.18, Src Test Acc: 99.22, Trg Test Acc: 96.64
# Epoch: 145, TotalL: 0.3966, CrossE: 0.0162, CondE: 0.0573, disc: 0.6642, domain: 0.7954, Src VAT: 0.0214, Trg VAT: 0.0573, Src MixUp: 0.2521, Trg MixUp: 0.4263, Src Train Acc: 99.39, Trg Train Acc: 96.35, Src Test Acc: 97.67, Trg Test Acc: 96.87
# Epoch: 146, TotalL: 0.3738, CrossE: 0.0146, CondE: 0.0543, disc: 0.6659, domain: 0.8000, Src VAT: 0.0173, Trg VAT: 0.0543, Src MixUp: 0.2368, Trg MixUp: 0.4050, Src Train Acc: 99.61, Trg Train Acc: 96.83, Src Test Acc: 99.22, Trg Test Acc: 97.25
# Epoch: 147, TotalL: 0.3445, CrossE: 0.0042, CondE: 0.0448, disc: 0.6630, domain: 0.7937, Src VAT: 0.0130, Trg VAT: 0.0448, Src MixUp: 0.2241, Trg MixUp: 0.4057, Src Train Acc: 99.96, Trg Train Acc: 97.35, Src Test Acc: 98.83, Trg Test Acc: 94.65
# Epoch: 148, TotalL: 0.3820, CrossE: 0.0092, CondE: 0.0551, disc: 0.6695, domain: 0.7948, Src VAT: 0.0188, Trg VAT: 0.0551, Src MixUp: 0.2475, Trg MixUp: 0.4271, Src Train Acc: 99.83, Trg Train Acc: 96.83, Src Test Acc: 99.22, Trg Test Acc: 97.87
# Epoch: 149, TotalL: 0.3674, CrossE: 0.0088, CondE: 0.0550, disc: 0.6689, domain: 0.7920, Src VAT: 0.0182, Trg VAT: 0.0550, Src MixUp: 0.2337, Trg MixUp: 0.4317, Src Train Acc: 99.83, Trg Train Acc: 96.66, Src Test Acc: 93.00, Trg Test Acc: 93.92
# Epoch: 150, TotalL: 0.4009, CrossE: 0.0085, CondE: 0.0614, disc: 0.6655, domain: 0.7958, Src VAT: 0.0206, Trg VAT: 0.0614, Src MixUp: 0.2652, Trg MixUp: 0.4141, Src Train Acc: 99.74, Trg Train Acc: 96.40, Src Test Acc: 96.11, Trg Test Acc: 95.70
# Epoch: 151, TotalL: 0.4151, CrossE: 0.0195, CondE: 0.0618, disc: 0.6729, domain: 0.7844, Src VAT: 0.0265, Trg VAT: 0.0618, Src MixUp: 0.2612, Trg MixUp: 0.4399, Src Train Acc: 99.57, Trg Train Acc: 96.44, Src Test Acc: 98.05, Trg Test Acc: 95.70
# Epoch: 152, TotalL: 0.3702, CrossE: 0.0096, CondE: 0.0536, disc: 0.6713, domain: 0.7872, Src VAT: 0.0188, Trg VAT: 0.0536, Src MixUp: 0.2375, Trg MixUp: 0.4100, Src Train Acc: 99.65, Trg Train Acc: 96.79, Src Test Acc: 98.44, Trg Test Acc: 96.52
# Epoch: 153, TotalL: 0.3563, CrossE: 0.0052, CondE: 0.0457, disc: 0.6676, domain: 0.7838, Src VAT: 0.0148, Trg VAT: 0.0457, Src MixUp: 0.2317, Trg MixUp: 0.4309, Src Train Acc: 99.91, Trg Train Acc: 97.14, Src Test Acc: 98.44, Trg Test Acc: 96.70
# Epoch: 154, TotalL: 0.3428, CrossE: 0.0042, CondE: 0.0459, disc: 0.6671, domain: 0.7905, Src VAT: 0.0140, Trg VAT: 0.0459, Src MixUp: 0.2204, Trg MixUp: 0.4199, Src Train Acc: 99.96, Trg Train Acc: 97.53, Src Test Acc: 88.72, Trg Test Acc: 85.09
# Epoch: 155, TotalL: 0.4165, CrossE: 0.0180, CondE: 0.0614, disc: 0.6726, domain: 0.7857, Src VAT: 0.0278, Trg VAT: 0.0614, Src MixUp: 0.2641, Trg MixUp: 0.4250, Src Train Acc: 99.39, Trg Train Acc: 96.44, Src Test Acc: 94.94, Trg Test Acc: 93.74
# Epoch: 156, TotalL: 0.3504, CrossE: 0.0123, CondE: 0.0503, disc: 0.6656, domain: 0.7909, Src VAT: 0.0156, Trg VAT: 0.0503, Src MixUp: 0.2169, Trg MixUp: 0.4275, Src Train Acc: 99.57, Trg Train Acc: 97.01, Src Test Acc: 98.05, Trg Test Acc: 95.85
# Epoch: 157, TotalL: 0.3438, CrossE: 0.0045, CondE: 0.0458, disc: 0.6679, domain: 0.7896, Src VAT: 0.0140, Trg VAT: 0.0458, Src MixUp: 0.2226, Trg MixUp: 0.4021, Src Train Acc: 99.87, Trg Train Acc: 97.40, Src Test Acc: 98.44, Trg Test Acc: 97.60
# Epoch: 158, TotalL: 0.3774, CrossE: 0.0073, CondE: 0.0497, disc: 0.6715, domain: 0.7869, Src VAT: 0.0178, Trg VAT: 0.0497, Src MixUp: 0.2478, Trg MixUp: 0.4204, Src Train Acc: 99.74, Trg Train Acc: 97.35, Src Test Acc: 98.05, Trg Test Acc: 96.40
# Epoch: 159, TotalL: 0.3712, CrossE: 0.0069, CondE: 0.0508, disc: 0.6716, domain: 0.7847, Src VAT: 0.0178, Trg VAT: 0.0508, Src MixUp: 0.2442, Trg MixUp: 0.3933, Src Train Acc: 99.83, Trg Train Acc: 96.74, Src Test Acc: 88.72, Trg Test Acc: 82.63
# Epoch: 160, TotalL: 0.3502, CrossE: 0.0064, CondE: 0.0447, disc: 0.6701, domain: 0.7845, Src VAT: 0.0166, Trg VAT: 0.0447, Src MixUp: 0.2236, Trg MixUp: 0.4205, Src Train Acc: 99.87, Trg Train Acc: 96.70, Src Test Acc: 97.67, Trg Test Acc: 96.32
# Epoch: 161, TotalL: 0.3528, CrossE: 0.0082, CondE: 0.0446, disc: 0.6738, domain: 0.7768, Src VAT: 0.0183, Trg VAT: 0.0446, Src MixUp: 0.2244, Trg MixUp: 0.4074, Src Train Acc: 99.83, Trg Train Acc: 97.44, Src Test Acc: 98.44, Trg Test Acc: 95.15
# Epoch: 162, TotalL: 0.3780, CrossE: 0.0096, CondE: 0.0494, disc: 0.6672, domain: 0.7862, Src VAT: 0.0186, Trg VAT: 0.0494, Src MixUp: 0.2463, Trg MixUp: 0.4093, Src Train Acc: 99.74, Trg Train Acc: 96.22, Src Test Acc: 98.05, Trg Test Acc: 97.72
# Epoch: 163, TotalL: 0.3889, CrossE: 0.0080, CondE: 0.0558, disc: 0.6712, domain: 0.7902, Src VAT: 0.0202, Trg VAT: 0.0558, Src MixUp: 0.2532, Trg MixUp: 0.4425, Src Train Acc: 99.74, Trg Train Acc: 96.88, Src Test Acc: 95.72, Trg Test Acc: 94.82
# Epoch: 164, TotalL: 0.3574, CrossE: 0.0076, CondE: 0.0461, disc: 0.6722, domain: 0.7841, Src VAT: 0.0187, Trg VAT: 0.0461, Src MixUp: 0.2287, Trg MixUp: 0.4039, Src Train Acc: 99.83, Trg Train Acc: 97.09, Src Test Acc: 96.89, Trg Test Acc: 92.13
# Epoch: 165, TotalL: 0.3241, CrossE: 0.0062, CondE: 0.0380, disc: 0.6669, domain: 0.7903, Src VAT: 0.0113, Trg VAT: 0.0380, Src MixUp: 0.2070, Trg MixUp: 0.3776, Src Train Acc: 99.74, Trg Train Acc: 97.27, Src Test Acc: 96.89, Trg Test Acc: 94.36
# Epoch: 166, TotalL: 0.3499, CrossE: 0.0099, CondE: 0.0444, disc: 0.6706, domain: 0.7833, Src VAT: 0.0139, Trg VAT: 0.0444, Src MixUp: 0.2220, Trg MixUp: 0.4276, Src Train Acc: 99.70, Trg Train Acc: 97.01, Src Test Acc: 97.67, Trg Test Acc: 95.58
# Epoch: 167, TotalL: 0.3517, CrossE: 0.0070, CondE: 0.0517, disc: 0.6689, domain: 0.7894, Src VAT: 0.0170, Trg VAT: 0.0517, Src MixUp: 0.2234, Trg MixUp: 0.4108, Src Train Acc: 99.87, Trg Train Acc: 97.05, Src Test Acc: 97.67, Trg Test Acc: 95.58
# Epoch: 168, TotalL: 0.3800, CrossE: 0.0105, CondE: 0.0544, disc: 0.6711, domain: 0.7852, Src VAT: 0.0199, Trg VAT: 0.0544, Src MixUp: 0.2461, Trg MixUp: 0.3996, Src Train Acc: 99.70, Trg Train Acc: 96.40, Src Test Acc: 97.67, Trg Test Acc: 95.06
# Epoch: 169, TotalL: 0.3195, CrossE: 0.0045, CondE: 0.0476, disc: 0.6646, domain: 0.7945, Src VAT: 0.0130, Trg VAT: 0.0476, Src MixUp: 0.1996, Trg MixUp: 0.3898, Src Train Acc: 99.87, Trg Train Acc: 97.05, Src Test Acc: 97.67, Trg Test Acc: 91.96
# Epoch: 170, TotalL: 0.3569, CrossE: 0.0106, CondE: 0.0478, disc: 0.6676, domain: 0.7921, Src VAT: 0.0181, Trg VAT: 0.0478, Src MixUp: 0.2238, Trg MixUp: 0.4175, Src Train Acc: 99.74, Trg Train Acc: 96.92, Src Test Acc: 94.55, Trg Test Acc: 93.04
# Epoch: 171, TotalL: 0.4103, CrossE: 0.0191, CondE: 0.0611, disc: 0.6718, domain: 0.7969, Src VAT: 0.0253, Trg VAT: 0.0611, Src MixUp: 0.2565, Trg MixUp: 0.4465, Src Train Acc: 99.57, Trg Train Acc: 96.09, Src Test Acc: 98.44, Trg Test Acc: 94.94
# Epoch: 172, TotalL: 0.3303, CrossE: 0.0069, CondE: 0.0379, disc: 0.6696, domain: 0.7836, Src VAT: 0.0124, Trg VAT: 0.0379, Src MixUp: 0.2088, Trg MixUp: 0.4184, Src Train Acc: 99.83, Trg Train Acc: 97.66, Src Test Acc: 98.83, Trg Test Acc: 96.73
# Epoch: 173, TotalL: 0.3039, CrossE: 0.0035, CondE: 0.0357, disc: 0.6641, domain: 0.8049, Src VAT: 0.0081, Trg VAT: 0.0357, Src MixUp: 0.1922, Trg MixUp: 0.3740, Src Train Acc: 99.91, Trg Train Acc: 97.53, Src Test Acc: 99.22, Trg Test Acc: 96.43
# Epoch: 174, TotalL: 0.3624, CrossE: 0.0159, CondE: 0.0499, disc: 0.6715, domain: 0.7888, Src VAT: 0.0164, Trg VAT: 0.0499, Src MixUp: 0.2260, Trg MixUp: 0.4130, Src Train Acc: 99.65, Trg Train Acc: 96.48, Src Test Acc: 98.44, Trg Test Acc: 96.70
# Epoch: 175, TotalL: 0.3307, CrossE: 0.0057, CondE: 0.0378, disc: 0.6719, domain: 0.7825, Src VAT: 0.0141, Trg VAT: 0.0378, Src MixUp: 0.2094, Trg MixUp: 0.4110, Src Train Acc: 99.91, Trg Train Acc: 97.22, Src Test Acc: 96.11, Trg Test Acc: 92.89
# Epoch: 176, TotalL: 0.4349, CrossE: 0.0263, CondE: 0.0605, disc: 0.6765, domain: 0.7832, Src VAT: 0.0279, Trg VAT: 0.0605, Src MixUp: 0.2738, Trg MixUp: 0.4312, Src Train Acc: 99.44, Trg Train Acc: 97.14, Src Test Acc: 98.44, Trg Test Acc: 96.96
# Epoch: 177, TotalL: 0.3637, CrossE: 0.0118, CondE: 0.0471, disc: 0.6709, domain: 0.7791, Src VAT: 0.0166, Trg VAT: 0.0471, Src MixUp: 0.2344, Trg MixUp: 0.3877, Src Train Acc: 99.65, Trg Train Acc: 97.05, Src Test Acc: 97.67, Trg Test Acc: 97.02
# Epoch: 178, TotalL: 0.3367, CrossE: 0.0051, CondE: 0.0419, disc: 0.6663, domain: 0.7916, Src VAT: 0.0119, Trg VAT: 0.0419, Src MixUp: 0.2186, Trg MixUp: 0.3879, Src Train Acc: 99.87, Trg Train Acc: 97.22, Src Test Acc: 98.05, Trg Test Acc: 97.43
# Epoch: 179, TotalL: 0.3409, CrossE: 0.0058, CondE: 0.0429, disc: 0.6649, domain: 0.7913, Src VAT: 0.0145, Trg VAT: 0.0429, Src MixUp: 0.2172, Trg MixUp: 0.4156, Src Train Acc: 99.83, Trg Train Acc: 96.74, Src Test Acc: 98.44, Trg Test Acc: 97.57
# Epoch: 180, TotalL: 0.3193, CrossE: 0.0047, CondE: 0.0378, disc: 0.6670, domain: 0.7929, Src VAT: 0.0100, Trg VAT: 0.0378, Src MixUp: 0.2041, Trg MixUp: 0.3874, Src Train Acc: 99.83, Trg Train Acc: 97.57, Src Test Acc: 98.05, Trg Test Acc: 97.46
# Epoch: 181, TotalL: 0.3382, CrossE: 0.0040, CondE: 0.0363, disc: 0.6674, domain: 0.7865, Src VAT: 0.0120, Trg VAT: 0.0363, Src MixUp: 0.2228, Trg MixUp: 0.3838, Src Train Acc: 99.91, Trg Train Acc: 97.14, Src Test Acc: 92.22, Trg Test Acc: 90.26
# Epoch: 182, TotalL: 0.3844, CrossE: 0.0160, CondE: 0.0510, disc: 0.6705, domain: 0.7914, Src VAT: 0.0216, Trg VAT: 0.0510, Src MixUp: 0.2428, Trg MixUp: 0.4072, Src Train Acc: 99.61, Trg Train Acc: 96.14, Src Test Acc: 94.94, Trg Test Acc: 93.63
# Epoch: 183, TotalL: 0.3570, CrossE: 0.0137, CondE: 0.0464, disc: 0.6744, domain: 0.7775, Src VAT: 0.0181, Trg VAT: 0.0464, Src MixUp: 0.2232, Trg MixUp: 0.4047, Src Train Acc: 99.52, Trg Train Acc: 96.70, Src Test Acc: 98.83, Trg Test Acc: 97.72
# Epoch: 184, TotalL: 0.3124, CrossE: 0.0056, CondE: 0.0397, disc: 0.6743, domain: 0.7822, Src VAT: 0.0110, Trg VAT: 0.0397, Src MixUp: 0.1949, Trg MixUp: 0.4016, Src Train Acc: 99.83, Trg Train Acc: 97.09, Src Test Acc: 98.83, Trg Test Acc: 95.82
# Epoch: 185, TotalL: 0.3474, CrossE: 0.0066, CondE: 0.0396, disc: 0.6709, domain: 0.7808, Src VAT: 0.0152, Trg VAT: 0.0396, Src MixUp: 0.2243, Trg MixUp: 0.4067, Src Train Acc: 99.87, Trg Train Acc: 97.27, Src Test Acc: 96.50, Trg Test Acc: 96.49
# Epoch: 186, TotalL: 0.3473, CrossE: 0.0113, CondE: 0.0486, disc: 0.6749, domain: 0.7760, Src VAT: 0.0159, Trg VAT: 0.0486, Src MixUp: 0.2190, Trg MixUp: 0.3912, Src Train Acc: 99.70, Trg Train Acc: 96.53, Src Test Acc: 97.67, Trg Test Acc: 96.29
# Epoch: 187, TotalL: 0.3013, CrossE: 0.0029, CondE: 0.0318, disc: 0.6712, domain: 0.7784, Src VAT: 0.0089, Trg VAT: 0.0318, Src MixUp: 0.1921, Trg MixUp: 0.3754, Src Train Acc: 99.96, Trg Train Acc: 97.74, Src Test Acc: 95.72, Trg Test Acc: 88.27
# Epoch: 188, TotalL: 0.3406, CrossE: 0.0067, CondE: 0.0455, disc: 0.6693, domain: 0.7839, Src VAT: 0.0164, Trg VAT: 0.0455, Src MixUp: 0.2151, Trg MixUp: 0.4053, Src Train Acc: 99.87, Trg Train Acc: 96.31, Src Test Acc: 95.33, Trg Test Acc: 94.21
# Epoch: 189, TotalL: 0.3115, CrossE: 0.0037, CondE: 0.0343, disc: 0.6697, domain: 0.7822, Src VAT: 0.0107, Trg VAT: 0.0343, Src MixUp: 0.1986, Trg MixUp: 0.3808, Src Train Acc: 99.91, Trg Train Acc: 97.61, Src Test Acc: 98.05, Trg Test Acc: 94.97
# Epoch: 190, TotalL: 0.3362, CrossE: 0.0090, CondE: 0.0367, disc: 0.6717, domain: 0.7825, Src VAT: 0.0141, Trg VAT: 0.0367, Src MixUp: 0.2128, Trg MixUp: 0.3993, Src Train Acc: 99.65, Trg Train Acc: 96.79, Src Test Acc: 98.44, Trg Test Acc: 96.23
# Epoch: 191, TotalL: 0.3546, CrossE: 0.0154, CondE: 0.0424, disc: 0.6684, domain: 0.7867, Src VAT: 0.0139, Trg VAT: 0.0424, Src MixUp: 0.2233, Trg MixUp: 0.4025, Src Train Acc: 99.70, Trg Train Acc: 97.18, Src Test Acc: 97.67, Trg Test Acc: 94.36
# ...
# Epoch: 437, TotalL: 0.2268, CrossE: 0.0010, CondE: 0.0121, disc: 0.6777, domain: 0.7428, Src VAT: 0.0039, Trg VAT: 0.0121, Src MixUp: 0.1369, Trg MixUp: 0.2957, Src Train Acc: 100.00, Trg Train Acc: 98.52, Src Test Acc: 98.44, Trg Test Acc: 95.85
# Epoch: 438, TotalL: 0.2795, CrossE: 0.0061, CondE: 0.0219, disc: 0.6869, domain: 0.7321, Src VAT: 0.0097, Trg VAT: 0.0219, Src MixUp: 0.1727, Trg MixUp: 0.3612, Src Train Acc: 99.74, Trg Train Acc: 97.74, Src Test Acc: 100.00, Trg Test Acc: 97.49
# Epoch: 439, TotalL: 0.2465, CrossE: 0.0010, CondE: 0.0144, disc: 0.6821, domain: 0.7309, Src VAT: 0.0035, Trg VAT: 0.0144, Src MixUp: 0.1572, Trg MixUp: 0.2996, Src Train Acc: 99.96, Trg Train Acc: 98.05, Src Test Acc: 99.22, Trg Test Acc: 96.49
# Epoch: 440, TotalL: 0.2743, CrossE: 0.0044, CondE: 0.0188, disc: 0.6850, domain: 0.7367, Src VAT: 0.0080, Trg VAT: 0.0188, Src MixUp: 0.1736, Trg MixUp: 0.3304, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 96.99
# Epoch: 441, TotalL: 0.2307, CrossE: 0.0017, CondE: 0.0137, disc: 0.6780, domain: 0.7495, Src VAT: 0.0028, Trg VAT: 0.0137, Src MixUp: 0.1390, Trg MixUp: 0.3116, Src Train Acc: 99.96, Trg Train Acc: 98.31, Src Test Acc: 98.44, Trg Test Acc: 96.75
# Epoch: 442, TotalL: 0.2372, CrossE: 0.0029, CondE: 0.0135, disc: 0.6799, domain: 0.7413, Src VAT: 0.0063, Trg VAT: 0.0135, Src MixUp: 0.1417, Trg MixUp: 0.3109, Src Train Acc: 99.91, Trg Train Acc: 98.13, Src Test Acc: 98.83, Trg Test Acc: 95.64
# Epoch: 443, TotalL: 0.2372, CrossE: 0.0040, CondE: 0.0124, disc: 0.6803, domain: 0.7393, Src VAT: 0.0058, Trg VAT: 0.0124, Src MixUp: 0.1417, Trg MixUp: 0.3084, Src Train Acc: 99.87, Trg Train Acc: 98.22, Src Test Acc: 99.22, Trg Test Acc: 97.16
# Epoch: 444, TotalL: 0.2614, CrossE: 0.0032, CondE: 0.0207, disc: 0.6836, domain: 0.7355, Src VAT: 0.0074, Trg VAT: 0.0207, Src MixUp: 0.1647, Trg MixUp: 0.2995, Src Train Acc: 99.91, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 97.92
# Epoch: 445, TotalL: 0.2529, CrossE: 0.0032, CondE: 0.0180, disc: 0.6826, domain: 0.7341, Src VAT: 0.0074, Trg VAT: 0.0180, Src MixUp: 0.1559, Trg MixUp: 0.3104, Src Train Acc: 99.87, Trg Train Acc: 98.26, Src Test Acc: 96.89, Trg Test Acc: 95.94
# Epoch: 446, TotalL: 0.2319, CrossE: 0.0023, CondE: 0.0163, disc: 0.6807, domain: 0.7398, Src VAT: 0.0044, Trg VAT: 0.0163, Src MixUp: 0.1384, Trg MixUp: 0.3140, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 98.63
# Epoch: 447, TotalL: 0.2213, CrossE: 0.0012, CondE: 0.0109, disc: 0.6806, domain: 0.7381, Src VAT: 0.0028, Trg VAT: 0.0109, Src MixUp: 0.1313, Trg MixUp: 0.3152, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 99.61, Trg Test Acc: 97.72
# Epoch: 448, TotalL: 0.2875, CrossE: 0.0107, CondE: 0.0196, disc: 0.6846, domain: 0.7366, Src VAT: 0.0105, Trg VAT: 0.0196, Src MixUp: 0.1777, Trg MixUp: 0.3313, Src Train Acc: 99.74, Trg Train Acc: 97.87, Src Test Acc: 99.61, Trg Test Acc: 97.31
# Epoch: 449, TotalL: 0.2585, CrossE: 0.0061, CondE: 0.0140, disc: 0.6846, domain: 0.7380, Src VAT: 0.0052, Trg VAT: 0.0140, Src MixUp: 0.1600, Trg MixUp: 0.3246, Src Train Acc: 99.83, Trg Train Acc: 98.35, Src Test Acc: 97.67, Trg Test Acc: 93.63
# Epoch: 450, TotalL: 0.2392, CrossE: 0.0037, CondE: 0.0130, disc: 0.6848, domain: 0.7283, Src VAT: 0.0049, Trg VAT: 0.0130, Src MixUp: 0.1476, Trg MixUp: 0.2848, Src Train Acc: 99.87, Trg Train Acc: 98.31, Src Test Acc: 96.50, Trg Test Acc: 94.71
# Epoch: 451, TotalL: 0.2407, CrossE: 0.0021, CondE: 0.0129, disc: 0.6829, domain: 0.7288, Src VAT: 0.0058, Trg VAT: 0.0129, Src MixUp: 0.1486, Trg MixUp: 0.2978, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 99.22, Trg Test Acc: 96.96
# Epoch: 452, TotalL: 0.2210, CrossE: 0.0030, CondE: 0.0144, disc: 0.6787, domain: 0.7448, Src VAT: 0.0036, Trg VAT: 0.0144, Src MixUp: 0.1298, Trg MixUp: 0.2837, Src Train Acc: 99.91, Trg Train Acc: 97.96, Src Test Acc: 98.44, Trg Test Acc: 95.56
# Epoch: 453, TotalL: 0.2555, CrossE: 0.0034, CondE: 0.0131, disc: 0.6799, domain: 0.7505, Src VAT: 0.0055, Trg VAT: 0.0131, Src MixUp: 0.1601, Trg MixUp: 0.3052, Src Train Acc: 99.83, Trg Train Acc: 98.13, Src Test Acc: 99.22, Trg Test Acc: 97.78
# Epoch: 454, TotalL: 0.2467, CrossE: 0.0102, CondE: 0.0168, disc: 0.6843, domain: 0.7345, Src VAT: 0.0069, Trg VAT: 0.0168, Src MixUp: 0.1440, Trg MixUp: 0.3001, Src Train Acc: 99.70, Trg Train Acc: 98.13, Src Test Acc: 99.22, Trg Test Acc: 97.87
# Epoch: 455, TotalL: 0.2432, CrossE: 0.0031, CondE: 0.0111, disc: 0.6816, domain: 0.7348, Src VAT: 0.0063, Trg VAT: 0.0111, Src MixUp: 0.1481, Trg MixUp: 0.3149, Src Train Acc: 99.91, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 96.87
# Epoch: 456, TotalL: 0.2665, CrossE: 0.0116, CondE: 0.0201, disc: 0.6822, domain: 0.7368, Src VAT: 0.0083, Trg VAT: 0.0201, Src MixUp: 0.1589, Trg MixUp: 0.3186, Src Train Acc: 99.65, Trg Train Acc: 97.70, Src Test Acc: 99.22, Trg Test Acc: 96.35
# Epoch: 457, TotalL: 0.2232, CrossE: 0.0011, CondE: 0.0125, disc: 0.6789, domain: 0.7406, Src VAT: 0.0038, Trg VAT: 0.0125, Src MixUp: 0.1340, Trg MixUp: 0.2888, Src Train Acc: 100.00, Trg Train Acc: 98.39, Src Test Acc: 98.44, Trg Test Acc: 96.55
# Epoch: 458, TotalL: 0.2271, CrossE: 0.0014, CondE: 0.0112, disc: 0.6815, domain: 0.7362, Src VAT: 0.0040, Trg VAT: 0.0112, Src MixUp: 0.1370, Trg MixUp: 0.2995, Src Train Acc: 99.96, Trg Train Acc: 98.22, Src Test Acc: 95.72, Trg Test Acc: 92.69
# Epoch: 459, TotalL: 0.2553, CrossE: 0.0045, CondE: 0.0190, disc: 0.6840, domain: 0.7407, Src VAT: 0.0078, Trg VAT: 0.0190, Src MixUp: 0.1564, Trg MixUp: 0.3037, Src Train Acc: 99.78, Trg Train Acc: 97.92, Src Test Acc: 100.00, Trg Test Acc: 97.46
# Epoch: 460, TotalL: 0.2495, CrossE: 0.0042, CondE: 0.0174, disc: 0.6787, domain: 0.7451, Src VAT: 0.0047, Trg VAT: 0.0174, Src MixUp: 0.1519, Trg MixUp: 0.3292, Src Train Acc: 99.91, Trg Train Acc: 98.00, Src Test Acc: 96.50, Trg Test Acc: 96.08
# Epoch: 461, TotalL: 0.2507, CrossE: 0.0045, CondE: 0.0162, disc: 0.6833, domain: 0.7355, Src VAT: 0.0064, Trg VAT: 0.0162, Src MixUp: 0.1530, Trg MixUp: 0.3173, Src Train Acc: 99.83, Trg Train Acc: 98.22, Src Test Acc: 99.22, Trg Test Acc: 96.67
# Epoch: 462, TotalL: 0.2448, CrossE: 0.0029, CondE: 0.0171, disc: 0.6803, domain: 0.7403, Src VAT: 0.0066, Trg VAT: 0.0171, Src MixUp: 0.1480, Trg MixUp: 0.3176, Src Train Acc: 99.87, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 98.10
# Epoch: 463, TotalL: 0.2416, CrossE: 0.0047, CondE: 0.0128, disc: 0.6829, domain: 0.7368, Src VAT: 0.0073, Trg VAT: 0.0128, Src MixUp: 0.1437, Trg MixUp: 0.3103, Src Train Acc: 99.83, Trg Train Acc: 98.31, Src Test Acc: 98.05, Trg Test Acc: 96.64
# Epoch: 464, TotalL: 0.2406, CrossE: 0.0033, CondE: 0.0157, disc: 0.6842, domain: 0.7343, Src VAT: 0.0051, Trg VAT: 0.0157, Src MixUp: 0.1466, Trg MixUp: 0.3038, Src Train Acc: 99.91, Trg Train Acc: 98.18, Src Test Acc: 98.05, Trg Test Acc: 96.75
# Epoch: 465, TotalL: 0.2526, CrossE: 0.0044, CondE: 0.0160, disc: 0.6853, domain: 0.7308, Src VAT: 0.0070, Trg VAT: 0.0160, Src MixUp: 0.1563, Trg MixUp: 0.2993, Src Train Acc: 99.91, Trg Train Acc: 98.00, Src Test Acc: 98.44, Trg Test Acc: 97.60
# Epoch: 466, TotalL: 0.2111, CrossE: 0.0023, CondE: 0.0089, disc: 0.6822, domain: 0.7256, Src VAT: 0.0032, Trg VAT: 0.0089, Src MixUp: 0.1247, Trg MixUp: 0.2680, Src Train Acc: 99.87, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 98.30
# Epoch: 467, TotalL: 0.2207, CrossE: 0.0017, CondE: 0.0137, disc: 0.6826, domain: 0.7433, Src VAT: 0.0047, Trg VAT: 0.0137, Src MixUp: 0.1279, Trg MixUp: 0.3087, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 99.22, Trg Test Acc: 97.11
# Epoch: 468, TotalL: 0.2226, CrossE: 0.0018, CondE: 0.0131, disc: 0.6821, domain: 0.7358, Src VAT: 0.0043, Trg VAT: 0.0131, Src MixUp: 0.1307, Trg MixUp: 0.3099, Src Train Acc: 99.91, Trg Train Acc: 98.22, Src Test Acc: 99.22, Trg Test Acc: 98.04
# Epoch: 469, TotalL: 0.2507, CrossE: 0.0043, CondE: 0.0122, disc: 0.6825, domain: 0.7362, Src VAT: 0.0056, Trg VAT: 0.0122, Src MixUp: 0.1546, Trg MixUp: 0.3174, Src Train Acc: 99.83, Trg Train Acc: 98.52, Src Test Acc: 99.22, Trg Test Acc: 96.64
# Epoch: 470, TotalL: 0.2368, CrossE: 0.0021, CondE: 0.0146, disc: 0.6840, domain: 0.7359, Src VAT: 0.0062, Trg VAT: 0.0146, Src MixUp: 0.1446, Trg MixUp: 0.2828, Src Train Acc: 99.96, Trg Train Acc: 98.18, Src Test Acc: 91.05, Trg Test Acc: 90.23
# Epoch: 471, TotalL: 0.2701, CrossE: 0.0076, CondE: 0.0199, disc: 0.6821, domain: 0.7363, Src VAT: 0.0088, Trg VAT: 0.0199, Src MixUp: 0.1673, Trg MixUp: 0.3051, Src Train Acc: 99.83, Trg Train Acc: 97.96, Src Test Acc: 99.22, Trg Test Acc: 97.84
# Epoch: 472, TotalL: 0.2400, CrossE: 0.0010, CondE: 0.0103, disc: 0.6866, domain: 0.7233, Src VAT: 0.0045, Trg VAT: 0.0103, Src MixUp: 0.1525, Trg MixUp: 0.2797, Src Train Acc: 100.00, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 98.25
# Epoch: 473, TotalL: 0.2742, CrossE: 0.0090, CondE: 0.0228, disc: 0.6845, domain: 0.7263, Src VAT: 0.0104, Trg VAT: 0.0228, Src MixUp: 0.1665, Trg MixUp: 0.3317, Src Train Acc: 99.52, Trg Train Acc: 98.05, Src Test Acc: 98.83, Trg Test Acc: 97.25
# Epoch: 474, TotalL: 0.2374, CrossE: 0.0045, CondE: 0.0146, disc: 0.6795, domain: 0.7393, Src VAT: 0.0064, Trg VAT: 0.0146, Src MixUp: 0.1394, Trg MixUp: 0.3209, Src Train Acc: 99.87, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 97.08
# Epoch: 475, TotalL: 0.2375, CrossE: 0.0044, CondE: 0.0166, disc: 0.6831, domain: 0.7314, Src VAT: 0.0048, Trg VAT: 0.0166, Src MixUp: 0.1432, Trg MixUp: 0.2994, Src Train Acc: 99.87, Trg Train Acc: 98.13, Src Test Acc: 96.89, Trg Test Acc: 96.96
# Epoch: 476, TotalL: 0.2192, CrossE: 0.0032, CondE: 0.0131, disc: 0.6820, domain: 0.7361, Src VAT: 0.0039, Trg VAT: 0.0131, Src MixUp: 0.1270, Trg MixUp: 0.3018, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 97.60
# Epoch: 477, TotalL: 0.2178, CrossE: 0.0026, CondE: 0.0121, disc: 0.6846, domain: 0.7294, Src VAT: 0.0061, Trg VAT: 0.0121, Src MixUp: 0.1247, Trg MixUp: 0.3014, Src Train Acc: 99.96, Trg Train Acc: 98.22, Src Test Acc: 97.28, Trg Test Acc: 95.94
# Epoch: 478, TotalL: 0.2487, CrossE: 0.0060, CondE: 0.0173, disc: 0.6845, domain: 0.7382, Src VAT: 0.0058, Trg VAT: 0.0173, Src MixUp: 0.1494, Trg MixUp: 0.3213, Src Train Acc: 99.87, Trg Train Acc: 98.22, Src Test Acc: 98.44, Trg Test Acc: 96.08
# Epoch: 479, TotalL: 0.2497, CrossE: 0.0045, CondE: 0.0126, disc: 0.6860, domain: 0.7227, Src VAT: 0.0065, Trg VAT: 0.0126, Src MixUp: 0.1543, Trg MixUp: 0.3062, Src Train Acc: 99.83, Trg Train Acc: 98.31, Src Test Acc: 99.61, Trg Test Acc: 97.66
# Epoch: 480, TotalL: 0.2377, CrossE: 0.0021, CondE: 0.0134, disc: 0.6817, domain: 0.7367, Src VAT: 0.0042, Trg VAT: 0.0134, Src MixUp: 0.1456, Trg MixUp: 0.3093, Src Train Acc: 99.96, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 97.98
# Epoch: 481, TotalL: 0.2336, CrossE: 0.0049, CondE: 0.0147, disc: 0.6830, domain: 0.7358, Src VAT: 0.0056, Trg VAT: 0.0147, Src MixUp: 0.1389, Trg MixUp: 0.2862, Src Train Acc: 99.83, Trg Train Acc: 98.31, Src Test Acc: 99.61, Trg Test Acc: 98.33
# Epoch: 482, TotalL: 0.2493, CrossE: 0.0056, CondE: 0.0151, disc: 0.6872, domain: 0.7225, Src VAT: 0.0073, Trg VAT: 0.0151, Src MixUp: 0.1515, Trg MixUp: 0.3080, Src Train Acc: 99.83, Trg Train Acc: 98.39, Src Test Acc: 98.83, Trg Test Acc: 95.79
# Epoch: 483, TotalL: 0.2614, CrossE: 0.0042, CondE: 0.0195, disc: 0.6819, domain: 0.7359, Src VAT: 0.0064, Trg VAT: 0.0195, Src MixUp: 0.1618, Trg MixUp: 0.3367, Src Train Acc: 99.83, Trg Train Acc: 97.96, Src Test Acc: 100.00, Trg Test Acc: 97.72
# Epoch: 484, TotalL: 0.2138, CrossE: 0.0013, CondE: 0.0109, disc: 0.6810, domain: 0.7356, Src VAT: 0.0030, Trg VAT: 0.0109, Src MixUp: 0.1250, Trg MixUp: 0.2979, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 95.72, Trg Test Acc: 94.65
# Epoch: 485, TotalL: 0.2215, CrossE: 0.0013, CondE: 0.0105, disc: 0.6827, domain: 0.7343, Src VAT: 0.0044, Trg VAT: 0.0105, Src MixUp: 0.1319, Trg MixUp: 0.2938, Src Train Acc: 100.00, Trg Train Acc: 98.44, Src Test Acc: 98.44, Trg Test Acc: 96.78
# Epoch: 486, TotalL: 0.2120, CrossE: 0.0013, CondE: 0.0096, disc: 0.6824, domain: 0.7362, Src VAT: 0.0030, Trg VAT: 0.0096, Src MixUp: 0.1239, Trg MixUp: 0.2928, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 97.67, Trg Test Acc: 96.37
# Epoch: 487, TotalL: 0.2926, CrossE: 0.0108, CondE: 0.0189, disc: 0.6855, domain: 0.7265, Src VAT: 0.0096, Trg VAT: 0.0189, Src MixUp: 0.1861, Trg MixUp: 0.3103, Src Train Acc: 99.57, Trg Train Acc: 98.18, Src Test Acc: 99.22, Trg Test Acc: 96.40
# Epoch: 488, TotalL: 0.2607, CrossE: 0.0049, CondE: 0.0183, disc: 0.6856, domain: 0.7267, Src VAT: 0.0079, Trg VAT: 0.0183, Src MixUp: 0.1632, Trg MixUp: 0.2949, Src Train Acc: 99.87, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 98.25
# Epoch: 489, TotalL: 0.2298, CrossE: 0.0018, CondE: 0.0108, disc: 0.6818, domain: 0.7338, Src VAT: 0.0037, Trg VAT: 0.0108, Src MixUp: 0.1404, Trg MixUp: 0.2927, Src Train Acc: 99.96, Trg Train Acc: 98.48, Src Test Acc: 98.83, Trg Test Acc: 97.54
# Epoch: 490, TotalL: 0.2336, CrossE: 0.0065, CondE: 0.0142, disc: 0.6817, domain: 0.7331, Src VAT: 0.0048, Trg VAT: 0.0142, Src MixUp: 0.1371, Trg MixUp: 0.3033, Src Train Acc: 99.87, Trg Train Acc: 98.00, Src Test Acc: 98.83, Trg Test Acc: 96.37
# Epoch: 491, TotalL: 0.2803, CrossE: 0.0114, CondE: 0.0178, disc: 0.6864, domain: 0.7283, Src VAT: 0.0109, Trg VAT: 0.0178, Src MixUp: 0.1722, Trg MixUp: 0.3082, Src Train Acc: 99.61, Trg Train Acc: 98.52, Src Test Acc: 99.22, Trg Test Acc: 98.36
# Epoch: 492, TotalL: 0.2146, CrossE: 0.0007, CondE: 0.0103, disc: 0.6804, domain: 0.7338, Src VAT: 0.0022, Trg VAT: 0.0103, Src MixUp: 0.1285, Trg MixUp: 0.2867, Src Train Acc: 100.00, Trg Train Acc: 98.31, Src Test Acc: 98.83, Trg Test Acc: 94.47
# Epoch: 493, TotalL: 0.2547, CrossE: 0.0067, CondE: 0.0158, disc: 0.6820, domain: 0.7352, Src VAT: 0.0069, Trg VAT: 0.0158, Src MixUp: 0.1565, Trg MixUp: 0.2912, Src Train Acc: 99.87, Trg Train Acc: 98.09, Src Test Acc: 98.44, Trg Test Acc: 95.03
# Epoch: 494, TotalL: 0.2274, CrossE: 0.0004, CondE: 0.0112, disc: 0.6764, domain: 0.7446, Src VAT: 0.0020, Trg VAT: 0.0112, Src MixUp: 0.1417, Trg MixUp: 0.2755, Src Train Acc: 100.00, Trg Train Acc: 98.26, Src Test Acc: 97.67, Trg Test Acc: 95.50
# Epoch: 495, TotalL: 0.2274, CrossE: 0.0021, CondE: 0.0145, disc: 0.6756, domain: 0.7496, Src VAT: 0.0047, Trg VAT: 0.0145, Src MixUp: 0.1348, Trg MixUp: 0.2936, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 99.22, Trg Test Acc: 97.98
# Epoch: 496, TotalL: 0.2336, CrossE: 0.0020, CondE: 0.0111, disc: 0.6834, domain: 0.7332, Src VAT: 0.0042, Trg VAT: 0.0111, Src MixUp: 0.1436, Trg MixUp: 0.2921, Src Train Acc: 99.96, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 98.80
# Epoch: 497, TotalL: 0.2454, CrossE: 0.0099, CondE: 0.0113, disc: 0.6837, domain: 0.7405, Src VAT: 0.0054, Trg VAT: 0.0113, Src MixUp: 0.1464, Trg MixUp: 0.2825, Src Train Acc: 99.83, Trg Train Acc: 98.26, Src Test Acc: 99.61, Trg Test Acc: 96.52
# Epoch: 498, TotalL: 0.2189, CrossE: 0.0009, CondE: 0.0134, disc: 0.6848, domain: 0.7330, Src VAT: 0.0035, Trg VAT: 0.0134, Src MixUp: 0.1297, Trg MixUp: 0.2992, Src Train Acc: 100.00, Trg Train Acc: 98.48, Src Test Acc: 99.61, Trg Test Acc: 98.22
# Epoch: 499, TotalL: 0.2579, CrossE: 0.0089, CondE: 0.0178, disc: 0.6863, domain: 0.7343, Src VAT: 0.0095, Trg VAT: 0.0178, Src MixUp: 0.1527, Trg MixUp: 0.3149, Src Train Acc: 99.74, Trg Train Acc: 98.13, Src Test Acc: 99.61, Trg Test Acc: 97.78
# Epoch: 500, TotalL: 0.2201, CrossE: 0.0012, CondE: 0.0133, disc: 0.6782, domain: 0.7375, Src VAT: 0.0034, Trg VAT: 0.0133, Src MixUp: 0.1313, Trg MixUp: 0.2876, Src Train Acc: 100.00, Trg Train Acc: 98.26, Src Test Acc: 100.00, Trg Test Acc: 96.40
