# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='1'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 1.14.0

# %%
num_classes    = 9
batch_size     = 16
train_src_days = 3
train_trg_days = 3
epochs         = 500
learning_rate  = 0.0001

# Notes : 
# updated total_loss to reflect my issue on github 
# https://github.com/xudonmao/VMT/issues/1#issue-476306489
# VMT with first 3 days for train, next 3 days for train unlabeled and rest for test
# added gaussian noise to gen

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation('relu')(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2)):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features):
    super().__init__(name='generator')
    bn_axis = -1

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.relu1 = tf.keras.layers.Activation('relu', name='relu1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a'))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b'))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation='relu',
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.relu1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self):
    super().__init__(name='discriminator')  
    self.dense1 = tf.keras.layers.Dense(100, activation='relu')
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, inputs):
    x = self.dense1(inputs)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, 256)
discriminator  = Discriminator()
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

for epoch in range(epochs):
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 19:02:26.800927 139810244335360 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/autograph/impl/api.py:255: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.1693, CrossE: 2.2010, CondE: 2.1932, disc: 0.6942, domain: 0.6941, Src VAT: 2.1932, Trg VAT: 2.1932, Src MixUp: 2.1932, Trg MixUp: 2.1933, Src Train Acc: 11.41, Trg Train Acc: 11.11, Src Test Acc: 11.28, Trg Test Acc: 11.43
# Epoch: 002, TotalL: 7.1271, CrossE: 2.1804, CondE: 2.1829, disc: 0.6943, domain: 0.6934, Src VAT: 2.1832, Trg VAT: 2.1829, Src MixUp: 2.1840, Trg MixUp: 2.1844, Src Train Acc: 13.02, Trg Train Acc: 13.89, Src Test Acc: 19.84, Trg Test Acc: 19.91
# Epoch: 003, TotalL: 6.8915, CrossE: 2.1008, CondE: 2.1011, disc: 0.6955, domain: 0.6947, Src VAT: 2.1075, Trg VAT: 2.1011, Src MixUp: 2.1219, Trg MixUp: 2.1193, Src Train Acc: 17.75, Trg Train Acc: 18.45, Src Test Acc: 21.01, Trg Test Acc: 19.44
# Epoch: 004, TotalL: 6.5406, CrossE: 1.9798, CondE: 1.9820, disc: 0.6974, domain: 0.6963, Src VAT: 1.9956, Trg VAT: 1.9820, Src MixUp: 2.0297, Trg MixUp: 2.0335, Src Train Acc: 20.92, Trg Train Acc: 20.88, Src Test Acc: 24.51, Trg Test Acc: 20.47
# Epoch: 005, TotalL: 6.0488, CrossE: 1.8043, CondE: 1.8278, disc: 0.7010, domain: 0.6993, Src VAT: 1.8359, Trg VAT: 1.8278, Src MixUp: 1.9074, Trg MixUp: 1.9103, Src Train Acc: 28.12, Trg Train Acc: 26.87, Src Test Acc: 26.46, Trg Test Acc: 23.83
# Epoch: 006, TotalL: 5.3916, CrossE: 1.5601, CondE: 1.6256, disc: 0.7103, domain: 0.7036, Src VAT: 1.6362, Trg VAT: 1.6256, Src MixUp: 1.7386, Trg MixUp: 1.7543, Src Train Acc: 39.32, Trg Train Acc: 35.89, Src Test Acc: 46.69, Trg Test Acc: 43.60
# Epoch: 007, TotalL: 4.8295, CrossE: 1.3733, CondE: 1.4362, disc: 0.7140, domain: 0.7049, Src VAT: 1.4505, Trg VAT: 1.4362, Src MixUp: 1.5898, Trg MixUp: 1.6225, Src Train Acc: 46.61, Trg Train Acc: 41.45, Src Test Acc: 49.03, Trg Test Acc: 45.15
# Epoch: 008, TotalL: 4.4999, CrossE: 1.2717, CondE: 1.3242, disc: 0.7193, domain: 0.7057, Src VAT: 1.3453, Trg VAT: 1.3242, Src MixUp: 1.4934, Trg MixUp: 1.5142, Src Train Acc: 50.65, Trg Train Acc: 46.22, Src Test Acc: 51.36, Trg Test Acc: 46.73
# Epoch: 009, TotalL: 4.2630, CrossE: 1.1984, CondE: 1.2434, disc: 0.7191, domain: 0.7131, Src VAT: 1.2684, Trg VAT: 1.2434, Src MixUp: 1.4245, Trg MixUp: 1.4468, Src Train Acc: 53.52, Trg Train Acc: 49.65, Src Test Acc: 52.92, Trg Test Acc: 47.57
# Epoch: 010, TotalL: 4.0682, CrossE: 1.1354, CondE: 1.1797, disc: 0.7198, domain: 0.7151, Src VAT: 1.2097, Trg VAT: 1.1797, Src MixUp: 1.3662, Trg MixUp: 1.3877, Src Train Acc: 55.56, Trg Train Acc: 50.61, Src Test Acc: 55.25, Trg Test Acc: 47.08
# Epoch: 011, TotalL: 3.8575, CrossE: 1.0664, CondE: 1.1116, disc: 0.7222, domain: 0.7197, Src VAT: 1.1430, Trg VAT: 1.1116, Src MixUp: 1.3055, Trg MixUp: 1.3400, Src Train Acc: 58.12, Trg Train Acc: 52.47, Src Test Acc: 53.70, Trg Test Acc: 46.37
# Epoch: 012, TotalL: 3.7173, CrossE: 1.0203, CondE: 1.0629, disc: 0.7185, domain: 0.7216, Src VAT: 1.0948, Trg VAT: 1.0629, Src MixUp: 1.2707, Trg MixUp: 1.2977, Src Train Acc: 61.15, Trg Train Acc: 54.30, Src Test Acc: 49.42, Trg Test Acc: 43.63
# Epoch: 013, TotalL: 3.5643, CrossE: 0.9651, CondE: 1.0163, disc: 0.7258, domain: 0.7199, Src VAT: 1.0474, Trg VAT: 1.0163, Src MixUp: 1.2310, Trg MixUp: 1.2579, Src Train Acc: 62.63, Trg Train Acc: 57.12, Src Test Acc: 54.86, Trg Test Acc: 46.14
# Epoch: 014, TotalL: 3.3564, CrossE: 0.8981, CondE: 0.9546, disc: 0.7246, domain: 0.7262, Src VAT: 0.9825, Trg VAT: 0.9546, Src MixUp: 1.1681, Trg MixUp: 1.2107, Src Train Acc: 65.80, Trg Train Acc: 57.86, Src Test Acc: 61.09, Trg Test Acc: 50.53
# Epoch: 015, TotalL: 3.2209, CrossE: 0.8527, CondE: 0.9128, disc: 0.7256, domain: 0.7302, Src VAT: 0.9335, Trg VAT: 0.9128, Src MixUp: 1.1353, Trg MixUp: 1.1868, Src Train Acc: 66.88, Trg Train Acc: 59.68, Src Test Acc: 57.98, Trg Test Acc: 49.21
# Epoch: 016, TotalL: 3.0893, CrossE: 0.8036, CondE: 0.8739, disc: 0.7171, domain: 0.7492, Src VAT: 0.8918, Trg VAT: 0.8739, Src MixUp: 1.1014, Trg MixUp: 1.1586, Src Train Acc: 69.36, Trg Train Acc: 60.72, Src Test Acc: 60.70, Trg Test Acc: 52.31
# Epoch: 017, TotalL: 2.9678, CrossE: 0.7674, CondE: 0.8410, disc: 0.7139, domain: 0.7576, Src VAT: 0.8506, Trg VAT: 0.8410, Src MixUp: 1.0645, Trg MixUp: 1.1271, Src Train Acc: 71.01, Trg Train Acc: 62.46, Src Test Acc: 61.09, Trg Test Acc: 49.27
# Epoch: 018, TotalL: 2.8584, CrossE: 0.7307, CondE: 0.8039, disc: 0.7091, domain: 0.7706, Src VAT: 0.8137, Trg VAT: 0.8039, Src MixUp: 1.0364, Trg MixUp: 1.0920, Src Train Acc: 72.31, Trg Train Acc: 63.02, Src Test Acc: 63.04, Trg Test Acc: 51.11
# Epoch: 019, TotalL: 2.7782, CrossE: 0.7009, CondE: 0.7900, disc: 0.7068, domain: 0.7818, Src VAT: 0.7892, Trg VAT: 0.7900, Src MixUp: 1.0124, Trg MixUp: 1.0844, Src Train Acc: 74.39, Trg Train Acc: 64.54, Src Test Acc: 60.70, Trg Test Acc: 57.60
# Epoch: 020, TotalL: 2.6448, CrossE: 0.6522, CondE: 0.7552, disc: 0.7069, domain: 0.7866, Src VAT: 0.7471, Trg VAT: 0.7552, Src MixUp: 0.9784, Trg MixUp: 1.0428, Src Train Acc: 76.87, Trg Train Acc: 66.19, Src Test Acc: 64.98, Trg Test Acc: 58.89
# Epoch: 021, TotalL: 2.5476, CrossE: 0.6255, CondE: 0.7247, disc: 0.7121, domain: 0.7895, Src VAT: 0.7205, Trg VAT: 0.7247, Src MixUp: 0.9399, Trg MixUp: 1.0324, Src Train Acc: 77.08, Trg Train Acc: 68.66, Src Test Acc: 66.93, Trg Test Acc: 60.32
# Epoch: 022, TotalL: 2.4628, CrossE: 0.5836, CondE: 0.6940, disc: 0.7138, domain: 0.7985, Src VAT: 0.6867, Trg VAT: 0.6940, Src MixUp: 0.9371, Trg MixUp: 1.0058, Src Train Acc: 79.60, Trg Train Acc: 69.57, Src Test Acc: 73.15, Trg Test Acc: 62.95
# Epoch: 023, TotalL: 2.3327, CrossE: 0.5490, CondE: 0.6602, disc: 0.7133, domain: 0.8033, Src VAT: 0.6482, Trg VAT: 0.6602, Src MixUp: 0.8873, Trg MixUp: 0.9794, Src Train Acc: 81.29, Trg Train Acc: 71.44, Src Test Acc: 67.70, Trg Test Acc: 60.61
# Epoch: 024, TotalL: 2.2293, CrossE: 0.5137, CondE: 0.6244, disc: 0.7042, domain: 0.7979, Src VAT: 0.6122, Trg VAT: 0.6244, Src MixUp: 0.8634, Trg MixUp: 0.9532, Src Train Acc: 82.25, Trg Train Acc: 73.09, Src Test Acc: 79.77, Trg Test Acc: 71.93
# Epoch: 025, TotalL: 2.1223, CrossE: 0.4813, CondE: 0.5948, disc: 0.7013, domain: 0.7968, Src VAT: 0.5777, Trg VAT: 0.5948, Src MixUp: 0.8313, Trg MixUp: 0.9145, Src Train Acc: 83.72, Trg Train Acc: 75.13, Src Test Acc: 80.16, Trg Test Acc: 73.63
# Epoch: 026, TotalL: 2.0497, CrossE: 0.4402, CondE: 0.5736, disc: 0.6971, domain: 0.8071, Src VAT: 0.5554, Trg VAT: 0.5736, Src MixUp: 0.8265, Trg MixUp: 0.8911, Src Train Acc: 85.11, Trg Train Acc: 76.35, Src Test Acc: 76.26, Trg Test Acc: 68.51
# Epoch: 027, TotalL: 1.9817, CrossE: 0.4315, CondE: 0.5576, disc: 0.7013, domain: 0.8122, Src VAT: 0.5318, Trg VAT: 0.5576, Src MixUp: 0.7919, Trg MixUp: 0.9041, Src Train Acc: 85.37, Trg Train Acc: 77.78, Src Test Acc: 84.82, Trg Test Acc: 76.37
# Epoch: 028, TotalL: 1.9199, CrossE: 0.3984, CondE: 0.5333, disc: 0.6936, domain: 0.8162, Src VAT: 0.5122, Trg VAT: 0.5333, Src MixUp: 0.7865, Trg MixUp: 0.9038, Src Train Acc: 86.50, Trg Train Acc: 78.39, Src Test Acc: 82.10, Trg Test Acc: 72.54
# Epoch: 029, TotalL: 1.8507, CrossE: 0.3852, CondE: 0.5131, disc: 0.6883, domain: 0.8153, Src VAT: 0.4851, Trg VAT: 0.5131, Src MixUp: 0.7636, Trg MixUp: 0.8680, Src Train Acc: 86.85, Trg Train Acc: 79.64, Src Test Acc: 84.44, Trg Test Acc: 75.06
# Epoch: 030, TotalL: 1.8232, CrossE: 0.3769, CondE: 0.5055, disc: 0.7062, domain: 0.8172, Src VAT: 0.4779, Trg VAT: 0.5055, Src MixUp: 0.7527, Trg MixUp: 0.8672, Src Train Acc: 87.59, Trg Train Acc: 79.99, Src Test Acc: 82.49, Trg Test Acc: 75.41
# Epoch: 031, TotalL: 1.8420, CrossE: 0.3793, CondE: 0.5024, disc: 0.7170, domain: 0.8077, Src VAT: 0.4807, Trg VAT: 0.5024, Src MixUp: 0.7671, Trg MixUp: 0.8732, Src Train Acc: 87.67, Trg Train Acc: 79.51, Src Test Acc: 83.66, Trg Test Acc: 73.19
# Epoch: 032, TotalL: 1.7378, CrossE: 0.3473, CondE: 0.4824, disc: 0.6986, domain: 0.8116, Src VAT: 0.4483, Trg VAT: 0.4824, Src MixUp: 0.7344, Trg MixUp: 0.8212, Src Train Acc: 88.80, Trg Train Acc: 81.21, Src Test Acc: 82.10, Trg Test Acc: 72.75
# Epoch: 033, TotalL: 1.6932, CrossE: 0.3343, CondE: 0.4647, disc: 0.7105, domain: 0.8046, Src VAT: 0.4374, Trg VAT: 0.4647, Src MixUp: 0.7161, Trg MixUp: 0.8338, Src Train Acc: 89.28, Trg Train Acc: 82.03, Src Test Acc: 80.54, Trg Test Acc: 69.88
# Epoch: 034, TotalL: 1.6221, CrossE: 0.3122, CondE: 0.4419, disc: 0.7195, domain: 0.7945, Src VAT: 0.4130, Trg VAT: 0.4419, Src MixUp: 0.6969, Trg MixUp: 0.8211, Src Train Acc: 90.10, Trg Train Acc: 82.77, Src Test Acc: 86.77, Trg Test Acc: 75.32
# Epoch: 035, TotalL: 1.5762, CrossE: 0.3051, CondE: 0.4281, disc: 0.7214, domain: 0.8004, Src VAT: 0.4020, Trg VAT: 0.4281, Src MixUp: 0.6719, Trg MixUp: 0.8100, Src Train Acc: 90.23, Trg Train Acc: 83.42, Src Test Acc: 86.38, Trg Test Acc: 76.61
# Epoch: 036, TotalL: 1.5353, CrossE: 0.2866, CondE: 0.4051, disc: 0.7229, domain: 0.8052, Src VAT: 0.3861, Trg VAT: 0.4051, Src MixUp: 0.6709, Trg MixUp: 0.7799, Src Train Acc: 90.58, Trg Train Acc: 83.77, Src Test Acc: 88.72, Trg Test Acc: 79.24
# Epoch: 037, TotalL: 1.4812, CrossE: 0.2749, CondE: 0.3936, disc: 0.7255, domain: 0.7912, Src VAT: 0.3679, Trg VAT: 0.3936, Src MixUp: 0.6512, Trg MixUp: 0.7609, Src Train Acc: 91.02, Trg Train Acc: 83.42, Src Test Acc: 89.49, Trg Test Acc: 79.01
# Epoch: 038, TotalL: 1.4692, CrossE: 0.2768, CondE: 0.3917, disc: 0.7358, domain: 0.7825, Src VAT: 0.3633, Trg VAT: 0.3917, Src MixUp: 0.6425, Trg MixUp: 0.7667, Src Train Acc: 90.67, Trg Train Acc: 84.11, Src Test Acc: 89.11, Trg Test Acc: 77.22
# Epoch: 039, TotalL: 1.4514, CrossE: 0.2641, CondE: 0.3951, disc: 0.7208, domain: 0.7988, Src VAT: 0.3581, Trg VAT: 0.3951, Src MixUp: 0.6390, Trg MixUp: 0.7886, Src Train Acc: 90.97, Trg Train Acc: 83.25, Src Test Acc: 82.49, Trg Test Acc: 73.42
# Epoch: 040, TotalL: 1.4181, CrossE: 0.2501, CondE: 0.3849, disc: 0.7222, domain: 0.7958, Src VAT: 0.3477, Trg VAT: 0.3849, Src MixUp: 0.6345, Trg MixUp: 0.7565, Src Train Acc: 92.10, Trg Train Acc: 83.59, Src Test Acc: 89.88, Trg Test Acc: 78.30
# Epoch: 041, TotalL: 1.3887, CrossE: 0.2446, CondE: 0.3731, disc: 0.7298, domain: 0.7902, Src VAT: 0.3409, Trg VAT: 0.3731, Src MixUp: 0.6196, Trg MixUp: 0.7579, Src Train Acc: 92.32, Trg Train Acc: 84.81, Src Test Acc: 85.60, Trg Test Acc: 77.31
# Epoch: 042, TotalL: 1.3640, CrossE: 0.2438, CondE: 0.3724, disc: 0.7276, domain: 0.7920, Src VAT: 0.3281, Trg VAT: 0.3724, Src MixUp: 0.6081, Trg MixUp: 0.7622, Src Train Acc: 92.27, Trg Train Acc: 84.38, Src Test Acc: 90.27, Trg Test Acc: 81.73
# Epoch: 043, TotalL: 1.3076, CrossE: 0.2187, CondE: 0.3547, disc: 0.7157, domain: 0.7888, Src VAT: 0.3127, Trg VAT: 0.3547, Src MixUp: 0.5957, Trg MixUp: 0.7587, Src Train Acc: 92.97, Trg Train Acc: 85.81, Src Test Acc: 93.00, Trg Test Acc: 85.88
# Epoch: 044, TotalL: 1.3490, CrossE: 0.2303, CondE: 0.3693, disc: 0.7214, domain: 0.7890, Src VAT: 0.3242, Trg VAT: 0.3693, Src MixUp: 0.6125, Trg MixUp: 0.7473, Src Train Acc: 92.93, Trg Train Acc: 85.42, Src Test Acc: 84.05, Trg Test Acc: 72.16
# Epoch: 045, TotalL: 1.2969, CrossE: 0.2120, CondE: 0.3443, disc: 0.7073, domain: 0.8066, Src VAT: 0.3055, Trg VAT: 0.3443, Src MixUp: 0.5989, Trg MixUp: 0.7603, Src Train Acc: 93.23, Trg Train Acc: 85.68, Src Test Acc: 87.94, Trg Test Acc: 75.29
# Epoch: 046, TotalL: 1.2704, CrossE: 0.2124, CondE: 0.3428, disc: 0.7106, domain: 0.7953, Src VAT: 0.3010, Trg VAT: 0.3428, Src MixUp: 0.5800, Trg MixUp: 0.7306, Src Train Acc: 93.62, Trg Train Acc: 85.68, Src Test Acc: 92.22, Trg Test Acc: 80.20
# Epoch: 047, TotalL: 1.2138, CrossE: 0.1941, CondE: 0.3270, disc: 0.7006, domain: 0.8042, Src VAT: 0.2828, Trg VAT: 0.3270, Src MixUp: 0.5622, Trg MixUp: 0.7260, Src Train Acc: 93.88, Trg Train Acc: 86.59, Src Test Acc: 91.05, Trg Test Acc: 77.16
# Epoch: 048, TotalL: 1.2499, CrossE: 0.2085, CondE: 0.3348, disc: 0.7107, domain: 0.8069, Src VAT: 0.2884, Trg VAT: 0.3348, Src MixUp: 0.5765, Trg MixUp: 0.7309, Src Train Acc: 92.75, Trg Train Acc: 86.68, Src Test Acc: 92.61, Trg Test Acc: 83.77
# Epoch: 049, TotalL: 1.2207, CrossE: 0.1988, CondE: 0.3251, disc: 0.6993, domain: 0.8040, Src VAT: 0.2833, Trg VAT: 0.3251, Src MixUp: 0.5642, Trg MixUp: 0.7261, Src Train Acc: 93.97, Trg Train Acc: 86.94, Src Test Acc: 91.44, Trg Test Acc: 81.55
# Epoch: 050, TotalL: 1.2194, CrossE: 0.2001, CondE: 0.3193, disc: 0.7027, domain: 0.8089, Src VAT: 0.2802, Trg VAT: 0.3193, Src MixUp: 0.5658, Trg MixUp: 0.7191, Src Train Acc: 93.23, Trg Train Acc: 86.85, Src Test Acc: 91.44, Trg Test Acc: 83.07
# Epoch: 051, TotalL: 1.1598, CrossE: 0.1788, CondE: 0.3144, disc: 0.6915, domain: 0.8257, Src VAT: 0.2652, Trg VAT: 0.3144, Src MixUp: 0.5428, Trg MixUp: 0.7082, Src Train Acc: 94.62, Trg Train Acc: 86.59, Src Test Acc: 93.39, Trg Test Acc: 82.13
# Epoch: 052, TotalL: 1.1495, CrossE: 0.1791, CondE: 0.3090, disc: 0.6913, domain: 0.8282, Src VAT: 0.2610, Trg VAT: 0.3090, Src MixUp: 0.5374, Trg MixUp: 0.7041, Src Train Acc: 94.36, Trg Train Acc: 86.24, Src Test Acc: 90.27, Trg Test Acc: 79.91
# Epoch: 053, TotalL: 1.1164, CrossE: 0.1681, CondE: 0.2936, disc: 0.6843, domain: 0.8232, Src VAT: 0.2529, Trg VAT: 0.2936, Src MixUp: 0.5259, Trg MixUp: 0.7084, Src Train Acc: 94.97, Trg Train Acc: 86.59, Src Test Acc: 94.16, Trg Test Acc: 82.43
# Epoch: 054, TotalL: 1.1006, CrossE: 0.1712, CondE: 0.2941, disc: 0.6866, domain: 0.8359, Src VAT: 0.2448, Trg VAT: 0.2941, Src MixUp: 0.5150, Trg MixUp: 0.6956, Src Train Acc: 94.66, Trg Train Acc: 88.41, Src Test Acc: 92.61, Trg Test Acc: 81.81
# Epoch: 055, TotalL: 1.1057, CrossE: 0.1588, CondE: 0.2948, disc: 0.6852, domain: 0.8293, Src VAT: 0.2453, Trg VAT: 0.2948, Src MixUp: 0.5337, Trg MixUp: 0.6798, Src Train Acc: 95.23, Trg Train Acc: 88.19, Src Test Acc: 88.72, Trg Test Acc: 75.96
# Epoch: 056, TotalL: 1.0893, CrossE: 0.1526, CondE: 0.2914, disc: 0.6882, domain: 0.8167, Src VAT: 0.2393, Trg VAT: 0.2914, Src MixUp: 0.5314, Trg MixUp: 0.6745, Src Train Acc: 95.53, Trg Train Acc: 87.02, Src Test Acc: 87.16, Trg Test Acc: 74.80
# Epoch: 057, TotalL: 1.0739, CrossE: 0.1598, CondE: 0.2873, disc: 0.7019, domain: 0.8148, Src VAT: 0.2369, Trg VAT: 0.2873, Src MixUp: 0.5107, Trg MixUp: 0.6927, Src Train Acc: 94.84, Trg Train Acc: 88.15, Src Test Acc: 86.38, Trg Test Acc: 75.91
# Epoch: 058, TotalL: 1.0340, CrossE: 0.1417, CondE: 0.2782, disc: 0.6981, domain: 0.8000, Src VAT: 0.2199, Trg VAT: 0.2782, Src MixUp: 0.5105, Trg MixUp: 0.6679, Src Train Acc: 96.05, Trg Train Acc: 88.19, Src Test Acc: 96.11, Trg Test Acc: 85.18
# Epoch: 059, TotalL: 1.0091, CrossE: 0.1484, CondE: 0.2648, disc: 0.7043, domain: 0.8101, Src VAT: 0.2187, Trg VAT: 0.2648, Src MixUp: 0.4817, Trg MixUp: 0.6635, Src Train Acc: 95.62, Trg Train Acc: 88.59, Src Test Acc: 86.38, Trg Test Acc: 75.44
# Epoch: 060, TotalL: 0.9937, CrossE: 0.1342, CondE: 0.2634, disc: 0.7036, domain: 0.7973, Src VAT: 0.2116, Trg VAT: 0.2634, Src MixUp: 0.4898, Trg MixUp: 0.6535, Src Train Acc: 96.27, Trg Train Acc: 88.63, Src Test Acc: 96.11, Trg Test Acc: 85.85
# Epoch: 061, TotalL: 0.9842, CrossE: 0.1452, CondE: 0.2524, disc: 0.7062, domain: 0.7930, Src VAT: 0.2135, Trg VAT: 0.2524, Src MixUp: 0.4704, Trg MixUp: 0.6402, Src Train Acc: 95.23, Trg Train Acc: 88.06, Src Test Acc: 88.72, Trg Test Acc: 81.23
# Epoch: 062, TotalL: 0.9790, CrossE: 0.1359, CondE: 0.2585, disc: 0.7008, domain: 0.7904, Src VAT: 0.2062, Trg VAT: 0.2585, Src MixUp: 0.4807, Trg MixUp: 0.6444, Src Train Acc: 95.36, Trg Train Acc: 89.02, Src Test Acc: 93.39, Trg Test Acc: 83.71
# Epoch: 063, TotalL: 0.9523, CrossE: 0.1280, CondE: 0.2469, disc: 0.6924, domain: 0.7946, Src VAT: 0.2010, Trg VAT: 0.2469, Src MixUp: 0.4705, Trg MixUp: 0.6230, Src Train Acc: 96.09, Trg Train Acc: 88.72, Src Test Acc: 91.83, Trg Test Acc: 83.13
# Epoch: 064, TotalL: 1.0216, CrossE: 0.1483, CondE: 0.2663, disc: 0.6905, domain: 0.8011, Src VAT: 0.2151, Trg VAT: 0.2663, Src MixUp: 0.4976, Trg MixUp: 0.6730, Src Train Acc: 95.66, Trg Train Acc: 88.98, Src Test Acc: 95.72, Trg Test Acc: 86.37
# Epoch: 065, TotalL: 0.9357, CrossE: 0.1133, CondE: 0.2517, disc: 0.6861, domain: 0.8011, Src VAT: 0.1933, Trg VAT: 0.2517, Src MixUp: 0.4731, Trg MixUp: 0.6457, Src Train Acc: 96.96, Trg Train Acc: 89.19, Src Test Acc: 96.50, Trg Test Acc: 83.89
# Epoch: 066, TotalL: 0.9199, CrossE: 0.1158, CondE: 0.2535, disc: 0.6986, domain: 0.7955, Src VAT: 0.1903, Trg VAT: 0.2535, Src MixUp: 0.4583, Trg MixUp: 0.6403, Src Train Acc: 96.83, Trg Train Acc: 89.11, Src Test Acc: 90.27, Trg Test Acc: 84.21
# Epoch: 067, TotalL: 0.9061, CrossE: 0.1151, CondE: 0.2490, disc: 0.6984, domain: 0.7957, Src VAT: 0.1861, Trg VAT: 0.2490, Src MixUp: 0.4499, Trg MixUp: 0.6430, Src Train Acc: 96.53, Trg Train Acc: 88.72, Src Test Acc: 92.61, Trg Test Acc: 81.90
# Epoch: 068, TotalL: 0.9232, CrossE: 0.1237, CondE: 0.2414, disc: 0.6942, domain: 0.8000, Src VAT: 0.1901, Trg VAT: 0.2414, Src MixUp: 0.4558, Trg MixUp: 0.6374, Src Train Acc: 96.61, Trg Train Acc: 88.85, Src Test Acc: 92.22, Trg Test Acc: 81.99
# Epoch: 069, TotalL: 0.8829, CrossE: 0.1124, CondE: 0.2310, disc: 0.7005, domain: 0.7940, Src VAT: 0.1763, Trg VAT: 0.2310, Src MixUp: 0.4457, Trg MixUp: 0.6007, Src Train Acc: 96.79, Trg Train Acc: 89.28, Src Test Acc: 92.61, Trg Test Acc: 81.84
# Epoch: 070, TotalL: 0.8848, CrossE: 0.1143, CondE: 0.2321, disc: 0.6977, domain: 0.7899, Src VAT: 0.1786, Trg VAT: 0.2321, Src MixUp: 0.4425, Trg MixUp: 0.6134, Src Train Acc: 96.57, Trg Train Acc: 89.84, Src Test Acc: 96.11, Trg Test Acc: 86.23
# Epoch: 071, TotalL: 0.8440, CrossE: 0.1056, CondE: 0.2209, disc: 0.7014, domain: 0.7786, Src VAT: 0.1659, Trg VAT: 0.2209, Src MixUp: 0.4270, Trg MixUp: 0.5989, Src Train Acc: 96.88, Trg Train Acc: 90.19, Src Test Acc: 91.05, Trg Test Acc: 84.80
# Epoch: 072, TotalL: 0.8357, CrossE: 0.0916, CondE: 0.2180, disc: 0.6945, domain: 0.7824, Src VAT: 0.1641, Trg VAT: 0.2180, Src MixUp: 0.4338, Trg MixUp: 0.6088, Src Train Acc: 97.40, Trg Train Acc: 91.02, Src Test Acc: 97.67, Trg Test Acc: 89.77
# Epoch: 073, TotalL: 0.8988, CrossE: 0.1143, CondE: 0.2387, disc: 0.7079, domain: 0.7904, Src VAT: 0.1791, Trg VAT: 0.2387, Src MixUp: 0.4550, Trg MixUp: 0.6125, Src Train Acc: 96.66, Trg Train Acc: 89.63, Src Test Acc: 94.55, Trg Test Acc: 85.26
# Epoch: 074, TotalL: 0.8669, CrossE: 0.1158, CondE: 0.2264, disc: 0.7016, domain: 0.7945, Src VAT: 0.1727, Trg VAT: 0.2264, Src MixUp: 0.4302, Trg MixUp: 0.6056, Src Train Acc: 96.48, Trg Train Acc: 90.71, Src Test Acc: 97.28, Trg Test Acc: 89.27
# Epoch: 075, TotalL: 0.8792, CrossE: 0.1118, CondE: 0.2267, disc: 0.7018, domain: 0.7852, Src VAT: 0.1693, Trg VAT: 0.2267, Src MixUp: 0.4508, Trg MixUp: 0.6034, Src Train Acc: 96.70, Trg Train Acc: 90.15, Src Test Acc: 94.94, Trg Test Acc: 86.67
# Epoch: 076, TotalL: 0.8508, CrossE: 0.0937, CondE: 0.2217, disc: 0.6928, domain: 0.7972, Src VAT: 0.1660, Trg VAT: 0.2217, Src MixUp: 0.4438, Trg MixUp: 0.6001, Src Train Acc: 97.40, Trg Train Acc: 91.06, Src Test Acc: 95.33, Trg Test Acc: 88.30
# Epoch: 077, TotalL: 0.7774, CrossE: 0.0893, CondE: 0.2052, disc: 0.6934, domain: 0.8017, Src VAT: 0.1500, Trg VAT: 0.2052, Src MixUp: 0.3951, Trg MixUp: 0.5751, Src Train Acc: 97.40, Trg Train Acc: 90.76, Src Test Acc: 93.77, Trg Test Acc: 84.09
# Epoch: 078, TotalL: 0.7962, CrossE: 0.0969, CondE: 0.2097, disc: 0.6979, domain: 0.8038, Src VAT: 0.1543, Trg VAT: 0.2097, Src MixUp: 0.4011, Trg MixUp: 0.5759, Src Train Acc: 97.31, Trg Train Acc: 90.23, Src Test Acc: 96.50, Trg Test Acc: 89.24
# Epoch: 079, TotalL: 0.7422, CrossE: 0.0691, CondE: 0.2010, disc: 0.6991, domain: 0.7897, Src VAT: 0.1360, Trg VAT: 0.2010, Src MixUp: 0.3959, Trg MixUp: 0.5730, Src Train Acc: 98.13, Trg Train Acc: 91.23, Src Test Acc: 93.39, Trg Test Acc: 84.56
# Epoch: 080, TotalL: 0.7748, CrossE: 0.0879, CondE: 0.2148, disc: 0.7029, domain: 0.7955, Src VAT: 0.1469, Trg VAT: 0.2148, Src MixUp: 0.3967, Trg MixUp: 0.5665, Src Train Acc: 97.40, Trg Train Acc: 90.58, Src Test Acc: 92.22, Trg Test Acc: 83.54
# Epoch: 081, TotalL: 0.8126, CrossE: 0.1002, CondE: 0.2036, disc: 0.7083, domain: 0.7943, Src VAT: 0.1519, Trg VAT: 0.2036, Src MixUp: 0.4156, Trg MixUp: 0.6092, Src Train Acc: 96.88, Trg Train Acc: 90.80, Src Test Acc: 98.05, Trg Test Acc: 90.96
# Epoch: 082, TotalL: 0.7328, CrossE: 0.0757, CondE: 0.1902, disc: 0.6998, domain: 0.7977, Src VAT: 0.1301, Trg VAT: 0.1902, Src MixUp: 0.3884, Trg MixUp: 0.5552, Src Train Acc: 98.31, Trg Train Acc: 91.97, Src Test Acc: 93.39, Trg Test Acc: 84.71
# Epoch: 083, TotalL: 0.7514, CrossE: 0.0820, CondE: 0.1953, disc: 0.7010, domain: 0.7852, Src VAT: 0.1363, Trg VAT: 0.1953, Src MixUp: 0.3948, Trg MixUp: 0.5536, Src Train Acc: 97.74, Trg Train Acc: 91.49, Src Test Acc: 93.00, Trg Test Acc: 79.91
# Epoch: 084, TotalL: 0.7604, CrossE: 0.0765, CondE: 0.1942, disc: 0.7121, domain: 0.7782, Src VAT: 0.1380, Trg VAT: 0.1942, Src MixUp: 0.4070, Trg MixUp: 0.5701, Src Train Acc: 97.87, Trg Train Acc: 91.32, Src Test Acc: 95.33, Trg Test Acc: 88.51
# Epoch: 085, TotalL: 0.7648, CrossE: 0.0876, CondE: 0.1927, disc: 0.7060, domain: 0.7820, Src VAT: 0.1403, Trg VAT: 0.1927, Src MixUp: 0.3970, Trg MixUp: 0.5822, Src Train Acc: 97.66, Trg Train Acc: 91.06, Src Test Acc: 94.55, Trg Test Acc: 87.02
# Epoch: 086, TotalL: 0.7194, CrossE: 0.0662, CondE: 0.1874, disc: 0.7079, domain: 0.7740, Src VAT: 0.1304, Trg VAT: 0.1874, Src MixUp: 0.3858, Trg MixUp: 0.5647, Src Train Acc: 98.13, Trg Train Acc: 91.54, Src Test Acc: 98.44, Trg Test Acc: 90.99
# Epoch: 087, TotalL: 0.7280, CrossE: 0.0698, CondE: 0.1886, disc: 0.6995, domain: 0.7748, Src VAT: 0.1306, Trg VAT: 0.1886, Src MixUp: 0.3902, Trg MixUp: 0.5664, Src Train Acc: 98.22, Trg Train Acc: 90.67, Src Test Acc: 94.94, Trg Test Acc: 88.65
# Epoch: 088, TotalL: 0.7176, CrossE: 0.0737, CondE: 0.1906, disc: 0.7025, domain: 0.7872, Src VAT: 0.1269, Trg VAT: 0.1906, Src MixUp: 0.3787, Trg MixUp: 0.5615, Src Train Acc: 97.79, Trg Train Acc: 91.19, Src Test Acc: 94.94, Trg Test Acc: 89.12
# Epoch: 089, TotalL: 0.6880, CrossE: 0.0596, CondE: 0.1835, disc: 0.6952, domain: 0.7887, Src VAT: 0.1169, Trg VAT: 0.1835, Src MixUp: 0.3736, Trg MixUp: 0.5682, Src Train Acc: 98.48, Trg Train Acc: 91.45, Src Test Acc: 98.05, Trg Test Acc: 90.73
# Epoch: 090, TotalL: 0.8031, CrossE: 0.0901, CondE: 0.2060, disc: 0.7032, domain: 0.7926, Src VAT: 0.1472, Trg VAT: 0.2060, Src MixUp: 0.4228, Trg MixUp: 0.5832, Src Train Acc: 97.35, Trg Train Acc: 91.02, Src Test Acc: 93.77, Trg Test Acc: 82.66
# Epoch: 091, TotalL: 0.7570, CrossE: 0.0751, CondE: 0.1944, disc: 0.7036, domain: 0.7914, Src VAT: 0.1350, Trg VAT: 0.1944, Src MixUp: 0.4052, Trg MixUp: 0.5916, Src Train Acc: 98.18, Trg Train Acc: 91.67, Src Test Acc: 88.72, Trg Test Acc: 79.36
# Epoch: 092, TotalL: 0.6775, CrossE: 0.0579, CondE: 0.1741, disc: 0.7029, domain: 0.7883, Src VAT: 0.1170, Trg VAT: 0.1741, Src MixUp: 0.3668, Trg MixUp: 0.5603, Src Train Acc: 98.65, Trg Train Acc: 92.58, Src Test Acc: 96.11, Trg Test Acc: 88.71
# Epoch: 093, TotalL: 0.6828, CrossE: 0.0588, CondE: 0.1750, disc: 0.6894, domain: 0.7926, Src VAT: 0.1113, Trg VAT: 0.1750, Src MixUp: 0.3772, Trg MixUp: 0.5517, Src Train Acc: 98.31, Trg Train Acc: 91.97, Src Test Acc: 98.44, Trg Test Acc: 87.28
# Epoch: 094, TotalL: 0.6608, CrossE: 0.0611, CondE: 0.1781, disc: 0.6960, domain: 0.7997, Src VAT: 0.1098, Trg VAT: 0.1781, Src MixUp: 0.3536, Trg MixUp: 0.5473, Src Train Acc: 98.18, Trg Train Acc: 91.36, Src Test Acc: 96.89, Trg Test Acc: 87.87
# Epoch: 095, TotalL: 0.6946, CrossE: 0.0729, CondE: 0.1801, disc: 0.6874, domain: 0.8028, Src VAT: 0.1164, Trg VAT: 0.1801, Src MixUp: 0.3684, Trg MixUp: 0.5479, Src Train Acc: 97.79, Trg Train Acc: 92.14, Src Test Acc: 98.05, Trg Test Acc: 91.64
# Epoch: 096, TotalL: 0.6997, CrossE: 0.0645, CondE: 0.1748, disc: 0.6901, domain: 0.8077, Src VAT: 0.1215, Trg VAT: 0.1748, Src MixUp: 0.3780, Trg MixUp: 0.5384, Src Train Acc: 98.35, Trg Train Acc: 91.75, Src Test Acc: 96.50, Trg Test Acc: 90.47
# Epoch: 097, TotalL: 0.6885, CrossE: 0.0689, CondE: 0.1740, disc: 0.6831, domain: 0.8071, Src VAT: 0.1181, Trg VAT: 0.1740, Src MixUp: 0.3664, Trg MixUp: 0.5334, Src Train Acc: 97.96, Trg Train Acc: 91.71, Src Test Acc: 98.05, Trg Test Acc: 91.67
# Epoch: 098, TotalL: 0.6786, CrossE: 0.0641, CondE: 0.1712, disc: 0.6836, domain: 0.8097, Src VAT: 0.1113, Trg VAT: 0.1712, Src MixUp: 0.3680, Trg MixUp: 0.5374, Src Train Acc: 98.31, Trg Train Acc: 91.75, Src Test Acc: 98.44, Trg Test Acc: 92.22
# Epoch: 099, TotalL: 0.7053, CrossE: 0.0621, CondE: 0.1771, disc: 0.6778, domain: 0.8099, Src VAT: 0.1209, Trg VAT: 0.1771, Src MixUp: 0.3840, Trg MixUp: 0.5643, Src Train Acc: 98.35, Trg Train Acc: 91.97, Src Test Acc: 95.72, Trg Test Acc: 90.06
# Epoch: 100, TotalL: 0.6227, CrossE: 0.0497, CondE: 0.1614, disc: 0.6745, domain: 0.8033, Src VAT: 0.0995, Trg VAT: 0.1614, Src MixUp: 0.3407, Trg MixUp: 0.5341, Src Train Acc: 98.78, Trg Train Acc: 93.66, Src Test Acc: 98.83, Trg Test Acc: 91.26
# Epoch: 101, TotalL: 0.7845, CrossE: 0.1027, CondE: 0.2002, disc: 0.6820, domain: 0.7999, Src VAT: 0.1352, Trg VAT: 0.2002, Src MixUp: 0.4042, Trg MixUp: 0.5798, Src Train Acc: 97.57, Trg Train Acc: 92.49, Src Test Acc: 95.72, Trg Test Acc: 88.48
# Epoch: 102, TotalL: 0.6412, CrossE: 0.0463, CondE: 0.1613, disc: 0.6685, domain: 0.8084, Src VAT: 0.1035, Trg VAT: 0.1613, Src MixUp: 0.3571, Trg MixUp: 0.5465, Src Train Acc: 99.00, Trg Train Acc: 93.32, Src Test Acc: 94.16, Trg Test Acc: 87.28
# Epoch: 103, TotalL: 0.6714, CrossE: 0.0675, CondE: 0.1757, disc: 0.6708, domain: 0.8179, Src VAT: 0.1140, Trg VAT: 0.1757, Src MixUp: 0.3530, Trg MixUp: 0.5426, Src Train Acc: 98.13, Trg Train Acc: 92.19, Src Test Acc: 94.94, Trg Test Acc: 88.30
# Epoch: 104, TotalL: 0.6702, CrossE: 0.0553, CondE: 0.1751, disc: 0.6733, domain: 0.8093, Src VAT: 0.1096, Trg VAT: 0.1751, Src MixUp: 0.3711, Trg MixUp: 0.5189, Src Train Acc: 98.70, Trg Train Acc: 91.97, Src Test Acc: 98.83, Trg Test Acc: 90.41
# Epoch: 105, TotalL: 0.6538, CrossE: 0.0478, CondE: 0.1611, disc: 0.6789, domain: 0.8020, Src VAT: 0.1048, Trg VAT: 0.1611, Src MixUp: 0.3673, Trg MixUp: 0.5491, Src Train Acc: 99.05, Trg Train Acc: 93.49, Src Test Acc: 95.33, Trg Test Acc: 87.49
# Epoch: 106, TotalL: 0.6836, CrossE: 0.0667, CondE: 0.1748, disc: 0.6730, domain: 0.8000, Src VAT: 0.1108, Trg VAT: 0.1748, Src MixUp: 0.3705, Trg MixUp: 0.5441, Src Train Acc: 98.05, Trg Train Acc: 92.27, Src Test Acc: 96.11, Trg Test Acc: 87.87
# Epoch: 107, TotalL: 0.6427, CrossE: 0.0477, CondE: 0.1626, disc: 0.6758, domain: 0.7967, Src VAT: 0.1000, Trg VAT: 0.1626, Src MixUp: 0.3609, Trg MixUp: 0.5560, Src Train Acc: 98.78, Trg Train Acc: 92.58, Src Test Acc: 95.72, Trg Test Acc: 85.76
# Epoch: 108, TotalL: 0.5811, CrossE: 0.0376, CondE: 0.1468, disc: 0.6773, domain: 0.8010, Src VAT: 0.0853, Trg VAT: 0.1468, Src MixUp: 0.3271, Trg MixUp: 0.5435, Src Train Acc: 99.09, Trg Train Acc: 93.92, Src Test Acc: 98.44, Trg Test Acc: 92.81
# Epoch: 109, TotalL: 0.6661, CrossE: 0.0638, CondE: 0.1608, disc: 0.6863, domain: 0.7878, Src VAT: 0.1069, Trg VAT: 0.1608, Src MixUp: 0.3633, Trg MixUp: 0.5427, Src Train Acc: 98.35, Trg Train Acc: 92.10, Src Test Acc: 92.61, Trg Test Acc: 84.47
# Epoch: 110, TotalL: 0.6409, CrossE: 0.0502, CondE: 0.1658, disc: 0.6871, domain: 0.7804, Src VAT: 0.1010, Trg VAT: 0.1658, Src MixUp: 0.3582, Trg MixUp: 0.5316, Src Train Acc: 98.48, Trg Train Acc: 92.84, Src Test Acc: 92.22, Trg Test Acc: 84.42
# Epoch: 111, TotalL: 0.6279, CrossE: 0.0491, CondE: 0.1567, disc: 0.6898, domain: 0.7835, Src VAT: 0.0989, Trg VAT: 0.1567, Src MixUp: 0.3500, Trg MixUp: 0.5263, Src Train Acc: 98.74, Trg Train Acc: 93.10, Src Test Acc: 95.72, Trg Test Acc: 87.75
# Epoch: 112, TotalL: 0.6270, CrossE: 0.0446, CondE: 0.1610, disc: 0.6819, domain: 0.7955, Src VAT: 0.0975, Trg VAT: 0.1610, Src MixUp: 0.3542, Trg MixUp: 0.5168, Src Train Acc: 98.91, Trg Train Acc: 91.88, Src Test Acc: 96.11, Trg Test Acc: 90.61
# Epoch: 113, TotalL: 0.6008, CrossE: 0.0444, CondE: 0.1508, disc: 0.6853, domain: 0.7914, Src VAT: 0.0914, Trg VAT: 0.1508, Src MixUp: 0.3356, Trg MixUp: 0.5241, Src Train Acc: 98.87, Trg Train Acc: 92.62, Src Test Acc: 94.94, Trg Test Acc: 88.83
# Epoch: 114, TotalL: 0.6262, CrossE: 0.0478, CondE: 0.1564, disc: 0.6922, domain: 0.7739, Src VAT: 0.0950, Trg VAT: 0.1564, Src MixUp: 0.3542, Trg MixUp: 0.5284, Src Train Acc: 98.74, Trg Train Acc: 93.14, Src Test Acc: 97.67, Trg Test Acc: 92.95
# Epoch: 115, TotalL: 0.5966, CrossE: 0.0610, CondE: 0.1448, disc: 0.6848, domain: 0.7870, Src VAT: 0.0874, Trg VAT: 0.1448, Src MixUp: 0.3215, Trg MixUp: 0.5088, Src Train Acc: 98.09, Trg Train Acc: 92.88, Src Test Acc: 94.55, Trg Test Acc: 83.74
# Epoch: 116, TotalL: 0.5762, CrossE: 0.0405, CondE: 0.1416, disc: 0.6887, domain: 0.7749, Src VAT: 0.0824, Trg VAT: 0.1416, Src MixUp: 0.3271, Trg MixUp: 0.5195, Src Train Acc: 98.83, Trg Train Acc: 93.84, Src Test Acc: 98.44, Trg Test Acc: 91.96
# Epoch: 117, TotalL: 0.5729, CrossE: 0.0465, CondE: 0.1398, disc: 0.6875, domain: 0.7841, Src VAT: 0.0835, Trg VAT: 0.1398, Src MixUp: 0.3183, Trg MixUp: 0.4936, Src Train Acc: 98.78, Trg Train Acc: 93.92, Src Test Acc: 98.44, Trg Test Acc: 91.17
# Epoch: 118, TotalL: 0.5936, CrossE: 0.0402, CondE: 0.1472, disc: 0.6877, domain: 0.7799, Src VAT: 0.0867, Trg VAT: 0.1472, Src MixUp: 0.3378, Trg MixUp: 0.5362, Src Train Acc: 98.83, Trg Train Acc: 93.36, Src Test Acc: 97.28, Trg Test Acc: 90.56
# Epoch: 119, TotalL: 0.6015, CrossE: 0.0433, CondE: 0.1463, disc: 0.6831, domain: 0.7885, Src VAT: 0.0887, Trg VAT: 0.1463, Src MixUp: 0.3435, Trg MixUp: 0.4948, Src Train Acc: 98.78, Trg Train Acc: 93.53, Src Test Acc: 95.33, Trg Test Acc: 87.57
# Epoch: 120, TotalL: 0.6355, CrossE: 0.0547, CondE: 0.1579, disc: 0.6858, domain: 0.7834, Src VAT: 0.0959, Trg VAT: 0.1579, Src MixUp: 0.3551, Trg MixUp: 0.5221, Src Train Acc: 98.44, Trg Train Acc: 93.62, Src Test Acc: 93.77, Trg Test Acc: 86.20
# Epoch: 121, TotalL: 0.5824, CrossE: 0.0452, CondE: 0.1497, disc: 0.6844, domain: 0.7894, Src VAT: 0.0866, Trg VAT: 0.1497, Src MixUp: 0.3218, Trg MixUp: 0.5202, Src Train Acc: 98.61, Trg Train Acc: 93.23, Src Test Acc: 94.94, Trg Test Acc: 88.63
# Epoch: 122, TotalL: 0.6221, CrossE: 0.0493, CondE: 0.1543, disc: 0.6867, domain: 0.7814, Src VAT: 0.0932, Trg VAT: 0.1543, Src MixUp: 0.3489, Trg MixUp: 0.5433, Src Train Acc: 98.57, Trg Train Acc: 93.23, Src Test Acc: 95.33, Trg Test Acc: 88.13
# Epoch: 123, TotalL: 0.6252, CrossE: 0.0472, CondE: 0.1577, disc: 0.6875, domain: 0.7827, Src VAT: 0.0934, Trg VAT: 0.1577, Src MixUp: 0.3538, Trg MixUp: 0.5367, Src Train Acc: 98.78, Trg Train Acc: 92.93, Src Test Acc: 97.67, Trg Test Acc: 90.79
# Epoch: 124, TotalL: 0.6444, CrossE: 0.0493, CondE: 0.1550, disc: 0.6842, domain: 0.7902, Src VAT: 0.0965, Trg VAT: 0.1550, Src MixUp: 0.3684, Trg MixUp: 0.5276, Src Train Acc: 98.65, Trg Train Acc: 92.49, Src Test Acc: 97.28, Trg Test Acc: 90.03
# Epoch: 125, TotalL: 0.6123, CrossE: 0.0495, CondE: 0.1575, disc: 0.6896, domain: 0.7732, Src VAT: 0.0906, Trg VAT: 0.1575, Src MixUp: 0.3422, Trg MixUp: 0.5373, Src Train Acc: 98.91, Trg Train Acc: 93.01, Src Test Acc: 97.67, Trg Test Acc: 88.68
# Epoch: 126, TotalL: 0.6327, CrossE: 0.0582, CondE: 0.1534, disc: 0.6848, domain: 0.7750, Src VAT: 0.0974, Trg VAT: 0.1534, Src MixUp: 0.3473, Trg MixUp: 0.5412, Src Train Acc: 98.26, Trg Train Acc: 92.45, Src Test Acc: 97.28, Trg Test Acc: 90.91
# Epoch: 127, TotalL: 0.5746, CrossE: 0.0417, CondE: 0.1356, disc: 0.6845, domain: 0.7731, Src VAT: 0.0837, Trg VAT: 0.1356, Src MixUp: 0.3257, Trg MixUp: 0.5005, Src Train Acc: 98.70, Trg Train Acc: 93.66, Src Test Acc: 97.28, Trg Test Acc: 90.99
# Epoch: 128, TotalL: 0.5448, CrossE: 0.0337, CondE: 0.1420, disc: 0.6843, domain: 0.7717, Src VAT: 0.0758, Trg VAT: 0.1420, Src MixUp: 0.3100, Trg MixUp: 0.5092, Src Train Acc: 99.18, Trg Train Acc: 93.27, Src Test Acc: 96.11, Trg Test Acc: 82.25
# Epoch: 129, TotalL: 0.5825, CrossE: 0.0377, CondE: 0.1404, disc: 0.6808, domain: 0.7745, Src VAT: 0.0806, Trg VAT: 0.1404, Src MixUp: 0.3397, Trg MixUp: 0.5017, Src Train Acc: 99.00, Trg Train Acc: 94.10, Src Test Acc: 97.67, Trg Test Acc: 89.27
# Epoch: 130, TotalL: 0.5706, CrossE: 0.0353, CondE: 0.1390, disc: 0.6852, domain: 0.7674, Src VAT: 0.0791, Trg VAT: 0.1390, Src MixUp: 0.3336, Trg MixUp: 0.4886, Src Train Acc: 99.09, Trg Train Acc: 94.53, Src Test Acc: 97.67, Trg Test Acc: 92.40
# Epoch: 131, TotalL: 0.5527, CrossE: 0.0363, CondE: 0.1371, disc: 0.6977, domain: 0.7762, Src VAT: 0.0742, Trg VAT: 0.1371, Src MixUp: 0.3177, Trg MixUp: 0.5070, Src Train Acc: 98.96, Trg Train Acc: 93.88, Src Test Acc: 95.72, Trg Test Acc: 88.10
# Epoch: 132, TotalL: 0.6383, CrossE: 0.0554, CondE: 0.1587, disc: 0.6913, domain: 0.7761, Src VAT: 0.0984, Trg VAT: 0.1587, Src MixUp: 0.3550, Trg MixUp: 0.5260, Src Train Acc: 98.65, Trg Train Acc: 93.06, Src Test Acc: 99.22, Trg Test Acc: 93.92
# Epoch: 133, TotalL: 0.5619, CrossE: 0.0397, CondE: 0.1313, disc: 0.6899, domain: 0.7743, Src VAT: 0.0770, Trg VAT: 0.1313, Src MixUp: 0.3200, Trg MixUp: 0.5266, Src Train Acc: 98.70, Trg Train Acc: 93.97, Src Test Acc: 95.72, Trg Test Acc: 86.20
# Epoch: 134, TotalL: 0.5478, CrossE: 0.0397, CondE: 0.1346, disc: 0.6826, domain: 0.7761, Src VAT: 0.0761, Trg VAT: 0.1346, Src MixUp: 0.3089, Trg MixUp: 0.4938, Src Train Acc: 98.91, Trg Train Acc: 93.62, Src Test Acc: 97.67, Trg Test Acc: 90.29
# Epoch: 135, TotalL: 0.5604, CrossE: 0.0325, CondE: 0.1409, disc: 0.6832, domain: 0.7690, Src VAT: 0.0768, Trg VAT: 0.1409, Src MixUp: 0.3261, Trg MixUp: 0.5112, Src Train Acc: 99.31, Trg Train Acc: 92.88, Src Test Acc: 97.67, Trg Test Acc: 92.13
# Epoch: 136, TotalL: 0.5413, CrossE: 0.0380, CondE: 0.1382, disc: 0.6838, domain: 0.7775, Src VAT: 0.0740, Trg VAT: 0.1382, Src MixUp: 0.3052, Trg MixUp: 0.4982, Src Train Acc: 99.13, Trg Train Acc: 94.01, Src Test Acc: 96.11, Trg Test Acc: 91.58
# Epoch: 137, TotalL: 0.5160, CrossE: 0.0333, CondE: 0.1356, disc: 0.6836, domain: 0.7729, Src VAT: 0.0691, Trg VAT: 0.1356, Src MixUp: 0.2903, Trg MixUp: 0.4964, Src Train Acc: 99.00, Trg Train Acc: 94.23, Src Test Acc: 98.05, Trg Test Acc: 92.81
# Epoch: 138, TotalL: 0.5192, CrossE: 0.0243, CondE: 0.1276, disc: 0.6778, domain: 0.7659, Src VAT: 0.0642, Trg VAT: 0.1276, Src MixUp: 0.3090, Trg MixUp: 0.5001, Src Train Acc: 99.39, Trg Train Acc: 94.84, Src Test Acc: 98.44, Trg Test Acc: 92.57
# Epoch: 139, TotalL: 0.5732, CrossE: 0.0459, CondE: 0.1392, disc: 0.6796, domain: 0.7723, Src VAT: 0.0794, Trg VAT: 0.1392, Src MixUp: 0.3227, Trg MixUp: 0.5135, Src Train Acc: 98.78, Trg Train Acc: 92.88, Src Test Acc: 98.83, Trg Test Acc: 90.26
# Epoch: 140, TotalL: 0.5779, CrossE: 0.0392, CondE: 0.1439, disc: 0.6807, domain: 0.7692, Src VAT: 0.0830, Trg VAT: 0.1439, Src MixUp: 0.3302, Trg MixUp: 0.5101, Src Train Acc: 98.74, Trg Train Acc: 92.97, Src Test Acc: 96.50, Trg Test Acc: 91.49
# Epoch: 141, TotalL: 0.5430, CrossE: 0.0296, CondE: 0.1356, disc: 0.6776, domain: 0.7772, Src VAT: 0.0702, Trg VAT: 0.1356, Src MixUp: 0.3179, Trg MixUp: 0.5186, Src Train Acc: 99.39, Trg Train Acc: 94.23, Src Test Acc: 94.16, Trg Test Acc: 89.42
# Epoch: 142, TotalL: 0.4744, CrossE: 0.0312, CondE: 0.1143, disc: 0.6777, domain: 0.7764, Src VAT: 0.0590, Trg VAT: 0.1143, Src MixUp: 0.2657, Trg MixUp: 0.4776, Src Train Acc: 99.09, Trg Train Acc: 94.44, Src Test Acc: 88.33, Trg Test Acc: 79.30
# Epoch: 143, TotalL: 0.5288, CrossE: 0.0306, CondE: 0.1355, disc: 0.6761, domain: 0.7743, Src VAT: 0.0666, Trg VAT: 0.1355, Src MixUp: 0.3089, Trg MixUp: 0.4886, Src Train Acc: 99.18, Trg Train Acc: 93.53, Src Test Acc: 95.72, Trg Test Acc: 87.22
# Epoch: 144, TotalL: 0.5027, CrossE: 0.0288, CondE: 0.1181, disc: 0.6710, domain: 0.7882, Src VAT: 0.0610, Trg VAT: 0.1181, Src MixUp: 0.2931, Trg MixUp: 0.4725, Src Train Acc: 99.22, Trg Train Acc: 95.40, Src Test Acc: 92.22, Trg Test Acc: 82.81
# Epoch: 145, TotalL: 0.5823, CrossE: 0.0446, CondE: 0.1413, disc: 0.6776, domain: 0.7829, Src VAT: 0.0812, Trg VAT: 0.1413, Src MixUp: 0.3304, Trg MixUp: 0.5112, Src Train Acc: 98.48, Trg Train Acc: 93.71, Src Test Acc: 95.33, Trg Test Acc: 89.06
# Epoch: 146, TotalL: 0.5457, CrossE: 0.0331, CondE: 0.1388, disc: 0.6717, domain: 0.7846, Src VAT: 0.0734, Trg VAT: 0.1388, Src MixUp: 0.3137, Trg MixUp: 0.5065, Src Train Acc: 99.31, Trg Train Acc: 93.71, Src Test Acc: 99.22, Trg Test Acc: 92.72
# Epoch: 147, TotalL: 0.4932, CrossE: 0.0205, CondE: 0.1233, disc: 0.6716, domain: 0.7811, Src VAT: 0.0589, Trg VAT: 0.1233, Src MixUp: 0.2928, Trg MixUp: 0.4843, Src Train Acc: 99.70, Trg Train Acc: 94.40, Src Test Acc: 96.50, Trg Test Acc: 90.64
# Epoch: 148, TotalL: 0.5270, CrossE: 0.0319, CondE: 0.1207, disc: 0.6738, domain: 0.7809, Src VAT: 0.0705, Trg VAT: 0.1207, Src MixUp: 0.3047, Trg MixUp: 0.4755, Src Train Acc: 99.26, Trg Train Acc: 94.57, Src Test Acc: 99.22, Trg Test Acc: 92.60
# Epoch: 149, TotalL: 0.5689, CrossE: 0.0340, CondE: 0.1400, disc: 0.6734, domain: 0.7779, Src VAT: 0.0755, Trg VAT: 0.1400, Src MixUp: 0.3359, Trg MixUp: 0.4868, Src Train Acc: 99.22, Trg Train Acc: 93.71, Src Test Acc: 95.33, Trg Test Acc: 91.14
# Epoch: 150, TotalL: 0.4612, CrossE: 0.0225, CondE: 0.1178, disc: 0.6764, domain: 0.7723, Src VAT: 0.0562, Trg VAT: 0.1178, Src MixUp: 0.2642, Trg MixUp: 0.4698, Src Train Acc: 99.44, Trg Train Acc: 95.23, Src Test Acc: 97.28, Trg Test Acc: 90.94
# Epoch: 151, TotalL: 0.5485, CrossE: 0.0411, CondE: 0.1300, disc: 0.6797, domain: 0.7781, Src VAT: 0.0747, Trg VAT: 0.1300, Src MixUp: 0.3109, Trg MixUp: 0.4852, Src Train Acc: 98.78, Trg Train Acc: 93.66, Src Test Acc: 98.44, Trg Test Acc: 94.27
# Epoch: 152, TotalL: 0.4678, CrossE: 0.0220, CondE: 0.1092, disc: 0.6712, domain: 0.7798, Src VAT: 0.0537, Trg VAT: 0.1092, Src MixUp: 0.2744, Trg MixUp: 0.4741, Src Train Acc: 99.44, Trg Train Acc: 95.10, Src Test Acc: 99.22, Trg Test Acc: 92.81
# Epoch: 153, TotalL: 0.5123, CrossE: 0.0311, CondE: 0.1207, disc: 0.6792, domain: 0.7684, Src VAT: 0.0634, Trg VAT: 0.1207, Src MixUp: 0.3007, Trg MixUp: 0.4537, Src Train Acc: 99.26, Trg Train Acc: 94.18, Src Test Acc: 99.22, Trg Test Acc: 95.09
# Epoch: 154, TotalL: 0.4775, CrossE: 0.0246, CondE: 0.1177, disc: 0.6773, domain: 0.7728, Src VAT: 0.0576, Trg VAT: 0.1177, Src MixUp: 0.2768, Trg MixUp: 0.4718, Src Train Acc: 99.35, Trg Train Acc: 94.57, Src Test Acc: 94.94, Trg Test Acc: 87.78
# Epoch: 155, TotalL: 0.5823, CrossE: 0.0506, CondE: 0.1415, disc: 0.6767, domain: 0.7688, Src VAT: 0.0790, Trg VAT: 0.1415, Src MixUp: 0.3285, Trg MixUp: 0.4993, Src Train Acc: 98.52, Trg Train Acc: 93.75, Src Test Acc: 94.55, Trg Test Acc: 89.50
# Epoch: 156, TotalL: 0.5163, CrossE: 0.0284, CondE: 0.1182, disc: 0.6751, domain: 0.7735, Src VAT: 0.0665, Trg VAT: 0.1182, Src MixUp: 0.3029, Trg MixUp: 0.4706, Src Train Acc: 99.26, Trg Train Acc: 94.66, Src Test Acc: 98.05, Trg Test Acc: 93.30
# Epoch: 157, TotalL: 0.4855, CrossE: 0.0204, CondE: 0.1240, disc: 0.6750, domain: 0.7708, Src VAT: 0.0560, Trg VAT: 0.1240, Src MixUp: 0.2881, Trg MixUp: 0.4923, Src Train Acc: 99.52, Trg Train Acc: 94.44, Src Test Acc: 96.50, Trg Test Acc: 92.84
# Epoch: 158, TotalL: 0.5450, CrossE: 0.0346, CondE: 0.1277, disc: 0.6839, domain: 0.7645, Src VAT: 0.0755, Trg VAT: 0.1277, Src MixUp: 0.3151, Trg MixUp: 0.4773, Src Train Acc: 99.18, Trg Train Acc: 94.31, Src Test Acc: 90.27, Trg Test Acc: 83.25
# Epoch: 159, TotalL: 0.5027, CrossE: 0.0245, CondE: 0.1183, disc: 0.6745, domain: 0.7680, Src VAT: 0.0608, Trg VAT: 0.1183, Src MixUp: 0.3009, Trg MixUp: 0.4516, Src Train Acc: 99.61, Trg Train Acc: 94.84, Src Test Acc: 99.22, Trg Test Acc: 93.68
# Epoch: 160, TotalL: 0.4828, CrossE: 0.0257, CondE: 0.1174, disc: 0.6769, domain: 0.7712, Src VAT: 0.0592, Trg VAT: 0.1174, Src MixUp: 0.2791, Trg MixUp: 0.4778, Src Train Acc: 99.22, Trg Train Acc: 93.71, Src Test Acc: 94.16, Trg Test Acc: 86.26
# Epoch: 161, TotalL: 0.5496, CrossE: 0.0412, CondE: 0.1247, disc: 0.6827, domain: 0.7666, Src VAT: 0.0700, Trg VAT: 0.1247, Src MixUp: 0.3182, Trg MixUp: 0.4875, Src Train Acc: 98.65, Trg Train Acc: 94.05, Src Test Acc: 94.94, Trg Test Acc: 86.64
# Epoch: 162, TotalL: 0.5256, CrossE: 0.0260, CondE: 0.1284, disc: 0.6785, domain: 0.7670, Src VAT: 0.0624, Trg VAT: 0.1284, Src MixUp: 0.3149, Trg MixUp: 0.5049, Src Train Acc: 99.35, Trg Train Acc: 94.75, Src Test Acc: 96.50, Trg Test Acc: 91.14
# Epoch: 163, TotalL: 0.5079, CrossE: 0.0237, CondE: 0.1155, disc: 0.6745, domain: 0.7690, Src VAT: 0.0602, Trg VAT: 0.1155, Src MixUp: 0.3064, Trg MixUp: 0.4707, Src Train Acc: 99.52, Trg Train Acc: 95.05, Src Test Acc: 98.05, Trg Test Acc: 93.63
# Epoch: 164, TotalL: 0.4896, CrossE: 0.0218, CondE: 0.1205, disc: 0.6741, domain: 0.7744, Src VAT: 0.0595, Trg VAT: 0.1205, Src MixUp: 0.2901, Trg MixUp: 0.4629, Src Train Acc: 99.61, Trg Train Acc: 94.49, Src Test Acc: 98.83, Trg Test Acc: 94.50
# Epoch: 165, TotalL: 0.5294, CrossE: 0.0337, CondE: 0.1316, disc: 0.6788, domain: 0.7720, Src VAT: 0.0665, Trg VAT: 0.1316, Src MixUp: 0.3088, Trg MixUp: 0.4699, Src Train Acc: 99.09, Trg Train Acc: 94.44, Src Test Acc: 96.50, Trg Test Acc: 90.94
# Epoch: 166, TotalL: 0.4653, CrossE: 0.0228, CondE: 0.1093, disc: 0.6708, domain: 0.7843, Src VAT: 0.0504, Trg VAT: 0.1093, Src MixUp: 0.2760, Trg MixUp: 0.4477, Src Train Acc: 99.44, Trg Train Acc: 94.92, Src Test Acc: 97.28, Trg Test Acc: 90.70
# Epoch: 167, TotalL: 0.5728, CrossE: 0.0525, CondE: 0.1404, disc: 0.6781, domain: 0.7730, Src VAT: 0.0801, Trg VAT: 0.1404, Src MixUp: 0.3140, Trg MixUp: 0.5235, Src Train Acc: 98.61, Trg Train Acc: 94.18, Src Test Acc: 85.99, Trg Test Acc: 78.48
# Epoch: 168, TotalL: 0.5313, CrossE: 0.0344, CondE: 0.1213, disc: 0.6755, domain: 0.7748, Src VAT: 0.0661, Trg VAT: 0.1213, Src MixUp: 0.3108, Trg MixUp: 0.4828, Src Train Acc: 98.91, Trg Train Acc: 94.97, Src Test Acc: 98.83, Trg Test Acc: 92.37
# Epoch: 169, TotalL: 0.5292, CrossE: 0.0283, CondE: 0.1189, disc: 0.6740, domain: 0.7761, Src VAT: 0.0670, Trg VAT: 0.1189, Src MixUp: 0.3133, Trg MixUp: 0.4937, Src Train Acc: 99.13, Trg Train Acc: 94.97, Src Test Acc: 98.83, Trg Test Acc: 95.00
# Epoch: 170, TotalL: 0.4626, CrossE: 0.0157, CondE: 0.1122, disc: 0.6701, domain: 0.7764, Src VAT: 0.0488, Trg VAT: 0.1122, Src MixUp: 0.2814, Trg MixUp: 0.4577, Src Train Acc: 99.74, Trg Train Acc: 95.57, Src Test Acc: 98.83, Trg Test Acc: 95.20
# Epoch: 171, TotalL: 0.5074, CrossE: 0.0255, CondE: 0.1216, disc: 0.6717, domain: 0.7776, Src VAT: 0.0629, Trg VAT: 0.1216, Src MixUp: 0.3000, Trg MixUp: 0.4667, Src Train Acc: 99.48, Trg Train Acc: 94.27, Src Test Acc: 98.44, Trg Test Acc: 93.77
# Epoch: 172, TotalL: 0.4699, CrossE: 0.0192, CondE: 0.1175, disc: 0.6764, domain: 0.7692, Src VAT: 0.0499, Trg VAT: 0.1175, Src MixUp: 0.2807, Trg MixUp: 0.4964, Src Train Acc: 99.57, Trg Train Acc: 95.10, Src Test Acc: 97.28, Trg Test Acc: 91.49
# Epoch: 173, TotalL: 0.4595, CrossE: 0.0219, CondE: 0.1026, disc: 0.6728, domain: 0.7664, Src VAT: 0.0526, Trg VAT: 0.1026, Src MixUp: 0.2710, Trg MixUp: 0.4541, Src Train Acc: 99.57, Trg Train Acc: 95.10, Src Test Acc: 95.33, Trg Test Acc: 90.50
# Epoch: 174, TotalL: 0.4747, CrossE: 0.0255, CondE: 0.1142, disc: 0.6764, domain: 0.7722, Src VAT: 0.0551, Trg VAT: 0.1142, Src MixUp: 0.2761, Trg MixUp: 0.4732, Src Train Acc: 99.35, Trg Train Acc: 94.84, Src Test Acc: 97.67, Trg Test Acc: 93.39
# Epoch: 175, TotalL: 0.4872, CrossE: 0.0244, CondE: 0.1129, disc: 0.6730, domain: 0.7713, Src VAT: 0.0571, Trg VAT: 0.1129, Src MixUp: 0.2889, Trg MixUp: 0.4627, Src Train Acc: 99.35, Trg Train Acc: 95.10, Src Test Acc: 92.61, Trg Test Acc: 86.02
# Epoch: 176, TotalL: 0.5515, CrossE: 0.0394, CondE: 0.1350, disc: 0.6732, domain: 0.7753, Src VAT: 0.0684, Trg VAT: 0.1350, Src MixUp: 0.3194, Trg MixUp: 0.5085, Src Train Acc: 99.05, Trg Train Acc: 93.84, Src Test Acc: 97.28, Trg Test Acc: 90.18
# Epoch: 177, TotalL: 0.4864, CrossE: 0.0310, CondE: 0.1219, disc: 0.6791, domain: 0.7683, Src VAT: 0.0569, Trg VAT: 0.1219, Src MixUp: 0.2808, Trg MixUp: 0.4588, Src Train Acc: 99.48, Trg Train Acc: 94.88, Src Test Acc: 85.60, Trg Test Acc: 84.97
# Epoch: 178, TotalL: 0.5568, CrossE: 0.0483, CondE: 0.1270, disc: 0.6814, domain: 0.7672, Src VAT: 0.0766, Trg VAT: 0.1270, Src MixUp: 0.3106, Trg MixUp: 0.4958, Src Train Acc: 98.52, Trg Train Acc: 95.49, Src Test Acc: 95.33, Trg Test Acc: 91.58
# Epoch: 179, TotalL: 0.4455, CrossE: 0.0166, CondE: 0.1083, disc: 0.6802, domain: 0.7631, Src VAT: 0.0483, Trg VAT: 0.1083, Src MixUp: 0.2650, Trg MixUp: 0.4645, Src Train Acc: 99.61, Trg Train Acc: 96.09, Src Test Acc: 98.44, Trg Test Acc: 94.53
# Epoch: 180, TotalL: 0.4761, CrossE: 0.0264, CondE: 0.1147, disc: 0.6830, domain: 0.7596, Src VAT: 0.0576, Trg VAT: 0.1147, Src MixUp: 0.2771, Trg MixUp: 0.4485, Src Train Acc: 99.22, Trg Train Acc: 95.10, Src Test Acc: 97.67, Trg Test Acc: 94.04
# Epoch: 181, TotalL: 0.4677, CrossE: 0.0191, CondE: 0.1044, disc: 0.6814, domain: 0.7601, Src VAT: 0.0516, Trg VAT: 0.1044, Src MixUp: 0.2811, Trg MixUp: 0.4787, Src Train Acc: 99.65, Trg Train Acc: 95.66, Src Test Acc: 98.44, Trg Test Acc: 92.40
# Epoch: 182, TotalL: 0.4788, CrossE: 0.0224, CondE: 0.1097, disc: 0.6782, domain: 0.7680, Src VAT: 0.0537, Trg VAT: 0.1097, Src MixUp: 0.2855, Trg MixUp: 0.4783, Src Train Acc: 99.31, Trg Train Acc: 94.88, Src Test Acc: 94.16, Trg Test Acc: 88.65
# Epoch: 183, TotalL: 0.4944, CrossE: 0.0187, CondE: 0.1202, disc: 0.6825, domain: 0.7658, Src VAT: 0.0559, Trg VAT: 0.1202, Src MixUp: 0.3015, Trg MixUp: 0.4732, Src Train Acc: 99.70, Trg Train Acc: 95.10, Src Test Acc: 97.67, Trg Test Acc: 93.22
# Epoch: 184, TotalL: 0.4736, CrossE: 0.0273, CondE: 0.1103, disc: 0.6802, domain: 0.7638, Src VAT: 0.0537, Trg VAT: 0.1103, Src MixUp: 0.2756, Trg MixUp: 0.4782, Src Train Acc: 99.52, Trg Train Acc: 95.53, Src Test Acc: 95.72, Trg Test Acc: 84.09
# Epoch: 185, TotalL: 0.4915, CrossE: 0.0220, CondE: 0.1108, disc: 0.6798, domain: 0.7612, Src VAT: 0.0585, Trg VAT: 0.1108, Src MixUp: 0.2939, Trg MixUp: 0.4806, Src Train Acc: 99.52, Trg Train Acc: 95.70, Src Test Acc: 97.28, Trg Test Acc: 93.07
# Epoch: 186, TotalL: 0.4641, CrossE: 0.0188, CondE: 0.0958, disc: 0.6769, domain: 0.7682, Src VAT: 0.0487, Trg VAT: 0.0958, Src MixUp: 0.2818, Trg MixUp: 0.4751, Src Train Acc: 99.70, Trg Train Acc: 96.01, Src Test Acc: 88.72, Trg Test Acc: 81.73
# Epoch: 187, TotalL: 0.4507, CrossE: 0.0164, CondE: 0.1018, disc: 0.6789, domain: 0.7672, Src VAT: 0.0467, Trg VAT: 0.1018, Src MixUp: 0.2744, Trg MixUp: 0.4440, Src Train Acc: 99.65, Trg Train Acc: 95.49, Src Test Acc: 96.11, Trg Test Acc: 92.37
# Epoch: 188, TotalL: 0.4704, CrossE: 0.0225, CondE: 0.1029, disc: 0.6760, domain: 0.7734, Src VAT: 0.0534, Trg VAT: 0.1029, Src MixUp: 0.2804, Trg MixUp: 0.4462, Src Train Acc: 99.52, Trg Train Acc: 95.66, Src Test Acc: 97.67, Trg Test Acc: 93.71
# Epoch: 189, TotalL: 0.4597, CrossE: 0.0226, CondE: 0.1074, disc: 0.6828, domain: 0.7687, Src VAT: 0.0536, Trg VAT: 0.1074, Src MixUp: 0.2691, Trg MixUp: 0.4470, Src Train Acc: 99.31, Trg Train Acc: 94.97, Src Test Acc: 96.50, Trg Test Acc: 90.96
# Epoch: 190, TotalL: 0.4865, CrossE: 0.0220, CondE: 0.1098, disc: 0.6795, domain: 0.7657, Src VAT: 0.0540, Trg VAT: 0.1098, Src MixUp: 0.2942, Trg MixUp: 0.4683, Src Train Acc: 99.57, Trg Train Acc: 95.66, Src Test Acc: 96.50, Trg Test Acc: 92.05
# Epoch: 191, TotalL: 0.5348, CrossE: 0.0355, CondE: 0.1300, disc: 0.6815, domain: 0.7705, Src VAT: 0.0684, Trg VAT: 0.1300, Src MixUp: 0.3072, Trg MixUp: 0.5163, Src Train Acc: 99.05, Trg Train Acc: 94.36, Src Test Acc: 99.22, Trg Test Acc: 92.43
# Epoch: 192, TotalL: 0.4756, CrossE: 0.0173, CondE: 0.1155, disc: 0.6754, domain: 0.7671, Src VAT: 0.0523, Trg VAT: 0.1155, Src MixUp: 0.2888, Trg MixUp: 0.4663, Src Train Acc: 99.74, Trg Train Acc: 95.31, Src Test Acc: 98.83, Trg Test Acc: 95.09
# Epoch: 193, TotalL: 0.4662, CrossE: 0.0186, CondE: 0.1082, disc: 0.6786, domain: 0.7575, Src VAT: 0.0504, Trg VAT: 0.1082, Src MixUp: 0.2831, Trg MixUp: 0.4520, Src Train Acc: 99.65, Trg Train Acc: 95.83, Src Test Acc: 97.28, Trg Test Acc: 94.15
# ...
# Epoch: 437, TotalL: 0.2815, CrossE: 0.0075, CondE: 0.0423, disc: 0.6833, domain: 0.7429, Src VAT: 0.0191, Trg VAT: 0.0423, Src MixUp: 0.1638, Trg MixUp: 0.3105, Src Train Acc: 99.78, Trg Train Acc: 98.83, Src Test Acc: 96.89, Trg Test Acc: 91.84
# Epoch: 438, TotalL: 0.3132, CrossE: 0.0098, CondE: 0.0508, disc: 0.6840, domain: 0.7416, Src VAT: 0.0196, Trg VAT: 0.0508, Src MixUp: 0.1884, Trg MixUp: 0.3493, Src Train Acc: 99.78, Trg Train Acc: 98.70, Src Test Acc: 99.61, Trg Test Acc: 95.76
# Epoch: 439, TotalL: 0.2986, CrossE: 0.0076, CondE: 0.0506, disc: 0.6832, domain: 0.7448, Src VAT: 0.0192, Trg VAT: 0.0506, Src MixUp: 0.1777, Trg MixUp: 0.3299, Src Train Acc: 99.78, Trg Train Acc: 98.22, Src Test Acc: 97.28, Trg Test Acc: 91.87
# Epoch: 440, TotalL: 0.2610, CrossE: 0.0043, CondE: 0.0382, disc: 0.6797, domain: 0.7456, Src VAT: 0.0155, Trg VAT: 0.0382, Src MixUp: 0.1497, Trg MixUp: 0.3213, Src Train Acc: 100.00, Trg Train Acc: 98.70, Src Test Acc: 98.83, Trg Test Acc: 96.90
# Epoch: 441, TotalL: 0.2815, CrossE: 0.0037, CondE: 0.0360, disc: 0.6814, domain: 0.7381, Src VAT: 0.0153, Trg VAT: 0.0360, Src MixUp: 0.1709, Trg MixUp: 0.3346, Src Train Acc: 99.96, Trg Train Acc: 99.09, Src Test Acc: 95.72, Trg Test Acc: 91.02
# Epoch: 442, TotalL: 0.3042, CrossE: 0.0122, CondE: 0.0451, disc: 0.6832, domain: 0.7436, Src VAT: 0.0231, Trg VAT: 0.0451, Src MixUp: 0.1756, Trg MixUp: 0.3338, Src Train Acc: 99.65, Trg Train Acc: 98.57, Src Test Acc: 98.83, Trg Test Acc: 95.73
# Epoch: 443, TotalL: 0.2633, CrossE: 0.0033, CondE: 0.0358, disc: 0.6792, domain: 0.7467, Src VAT: 0.0134, Trg VAT: 0.0358, Src MixUp: 0.1553, Trg MixUp: 0.3228, Src Train Acc: 99.96, Trg Train Acc: 98.83, Src Test Acc: 82.10, Trg Test Acc: 75.56
# Epoch: 444, TotalL: 0.2773, CrossE: 0.0061, CondE: 0.0394, disc: 0.6823, domain: 0.7391, Src VAT: 0.0149, Trg VAT: 0.0394, Src MixUp: 0.1643, Trg MixUp: 0.3327, Src Train Acc: 99.87, Trg Train Acc: 98.61, Src Test Acc: 99.22, Trg Test Acc: 97.28
# Epoch: 445, TotalL: 0.2903, CrossE: 0.0065, CondE: 0.0386, disc: 0.6817, domain: 0.7435, Src VAT: 0.0168, Trg VAT: 0.0386, Src MixUp: 0.1750, Trg MixUp: 0.3279, Src Train Acc: 99.87, Trg Train Acc: 98.83, Src Test Acc: 98.44, Trg Test Acc: 96.93
# Epoch: 446, TotalL: 0.2517, CrossE: 0.0030, CondE: 0.0320, disc: 0.6815, domain: 0.7403, Src VAT: 0.0113, Trg VAT: 0.0320, Src MixUp: 0.1472, Trg MixUp: 0.3230, Src Train Acc: 99.96, Trg Train Acc: 99.26, Src Test Acc: 99.61, Trg Test Acc: 96.46
# Epoch: 447, TotalL: 0.2778, CrossE: 0.0062, CondE: 0.0410, disc: 0.6822, domain: 0.7419, Src VAT: 0.0156, Trg VAT: 0.0410, Src MixUp: 0.1638, Trg MixUp: 0.3297, Src Train Acc: 99.87, Trg Train Acc: 98.52, Src Test Acc: 95.72, Trg Test Acc: 89.97
# Epoch: 448, TotalL: 0.2993, CrossE: 0.0086, CondE: 0.0427, disc: 0.6813, domain: 0.7397, Src VAT: 0.0197, Trg VAT: 0.0427, Src MixUp: 0.1795, Trg MixUp: 0.3196, Src Train Acc: 99.78, Trg Train Acc: 98.78, Src Test Acc: 99.61, Trg Test Acc: 97.51
# Epoch: 449, TotalL: 0.2733, CrossE: 0.0053, CondE: 0.0433, disc: 0.6812, domain: 0.7432, Src VAT: 0.0171, Trg VAT: 0.0433, Src MixUp: 0.1568, Trg MixUp: 0.3465, Src Train Acc: 99.87, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 97.60
# Epoch: 450, TotalL: 0.2530, CrossE: 0.0020, CondE: 0.0319, disc: 0.6822, domain: 0.7412, Src VAT: 0.0102, Trg VAT: 0.0319, Src MixUp: 0.1500, Trg MixUp: 0.3305, Src Train Acc: 100.00, Trg Train Acc: 99.22, Src Test Acc: 98.44, Trg Test Acc: 96.81
# Epoch: 451, TotalL: 0.3114, CrossE: 0.0069, CondE: 0.0415, disc: 0.6854, domain: 0.7397, Src VAT: 0.0216, Trg VAT: 0.0415, Src MixUp: 0.1892, Trg MixUp: 0.3477, Src Train Acc: 99.87, Trg Train Acc: 99.00, Src Test Acc: 98.44, Trg Test Acc: 96.46
# Epoch: 452, TotalL: 0.2902, CrossE: 0.0057, CondE: 0.0398, disc: 0.6821, domain: 0.7425, Src VAT: 0.0194, Trg VAT: 0.0398, Src MixUp: 0.1725, Trg MixUp: 0.3346, Src Train Acc: 99.87, Trg Train Acc: 98.65, Src Test Acc: 99.61, Trg Test Acc: 97.43
# Epoch: 453, TotalL: 0.3120, CrossE: 0.0103, CondE: 0.0460, disc: 0.6860, domain: 0.7360, Src VAT: 0.0232, Trg VAT: 0.0460, Src MixUp: 0.1842, Trg MixUp: 0.3501, Src Train Acc: 99.74, Trg Train Acc: 98.78, Src Test Acc: 98.83, Trg Test Acc: 97.22
# Epoch: 454, TotalL: 0.3126, CrossE: 0.0108, CondE: 0.0452, disc: 0.6872, domain: 0.7337, Src VAT: 0.0221, Trg VAT: 0.0452, Src MixUp: 0.1860, Trg MixUp: 0.3468, Src Train Acc: 99.70, Trg Train Acc: 98.74, Src Test Acc: 98.05, Trg Test Acc: 96.37
# Epoch: 455, TotalL: 0.2689, CrossE: 0.0032, CondE: 0.0343, disc: 0.6842, domain: 0.7398, Src VAT: 0.0144, Trg VAT: 0.0343, Src MixUp: 0.1612, Trg MixUp: 0.3186, Src Train Acc: 100.00, Trg Train Acc: 98.61, Src Test Acc: 98.83, Trg Test Acc: 97.13
# Epoch: 456, TotalL: 0.2713, CrossE: 0.0062, CondE: 0.0334, disc: 0.6820, domain: 0.7373, Src VAT: 0.0163, Trg VAT: 0.0334, Src MixUp: 0.1591, Trg MixUp: 0.3160, Src Train Acc: 99.78, Trg Train Acc: 98.96, Src Test Acc: 98.83, Trg Test Acc: 98.01
# Epoch: 457, TotalL: 0.2688, CrossE: 0.0034, CondE: 0.0418, disc: 0.6891, domain: 0.7309, Src VAT: 0.0150, Trg VAT: 0.0418, Src MixUp: 0.1604, Trg MixUp: 0.3119, Src Train Acc: 100.00, Trg Train Acc: 98.74, Src Test Acc: 98.44, Trg Test Acc: 94.80
# Epoch: 458, TotalL: 0.2845, CrossE: 0.0068, CondE: 0.0405, disc: 0.6840, domain: 0.7355, Src VAT: 0.0201, Trg VAT: 0.0405, Src MixUp: 0.1674, Trg MixUp: 0.3106, Src Train Acc: 99.87, Trg Train Acc: 98.35, Src Test Acc: 99.22, Trg Test Acc: 94.39
# Epoch: 459, TotalL: 0.2548, CrossE: 0.0036, CondE: 0.0342, disc: 0.6847, domain: 0.7363, Src VAT: 0.0138, Trg VAT: 0.0342, Src MixUp: 0.1472, Trg MixUp: 0.3241, Src Train Acc: 99.96, Trg Train Acc: 98.96, Src Test Acc: 99.61, Trg Test Acc: 96.99
# Epoch: 460, TotalL: 0.2605, CrossE: 0.0054, CondE: 0.0309, disc: 0.6837, domain: 0.7390, Src VAT: 0.0132, Trg VAT: 0.0309, Src MixUp: 0.1521, Trg MixUp: 0.3212, Src Train Acc: 99.83, Trg Train Acc: 99.13, Src Test Acc: 98.83, Trg Test Acc: 96.93
# Epoch: 461, TotalL: 0.2793, CrossE: 0.0066, CondE: 0.0426, disc: 0.6875, domain: 0.7372, Src VAT: 0.0176, Trg VAT: 0.0426, Src MixUp: 0.1621, Trg MixUp: 0.3412, Src Train Acc: 99.83, Trg Train Acc: 98.57, Src Test Acc: 99.22, Trg Test Acc: 97.31
# Epoch: 462, TotalL: 0.2654, CrossE: 0.0044, CondE: 0.0317, disc: 0.6857, domain: 0.7331, Src VAT: 0.0135, Trg VAT: 0.0317, Src MixUp: 0.1589, Trg MixUp: 0.3114, Src Train Acc: 99.91, Trg Train Acc: 99.13, Src Test Acc: 99.22, Trg Test Acc: 97.37
# Epoch: 463, TotalL: 0.3022, CrossE: 0.0057, CondE: 0.0513, disc: 0.6841, domain: 0.7352, Src VAT: 0.0196, Trg VAT: 0.0513, Src MixUp: 0.1822, Trg MixUp: 0.3472, Src Train Acc: 99.91, Trg Train Acc: 98.39, Src Test Acc: 98.83, Trg Test Acc: 97.78
# Epoch: 464, TotalL: 0.2801, CrossE: 0.0039, CondE: 0.0389, disc: 0.6834, domain: 0.7335, Src VAT: 0.0152, Trg VAT: 0.0389, Src MixUp: 0.1687, Trg MixUp: 0.3427, Src Train Acc: 100.00, Trg Train Acc: 98.70, Src Test Acc: 99.22, Trg Test Acc: 97.37
# Epoch: 465, TotalL: 0.2996, CrossE: 0.0083, CondE: 0.0434, disc: 0.6848, domain: 0.7308, Src VAT: 0.0207, Trg VAT: 0.0434, Src MixUp: 0.1770, Trg MixUp: 0.3519, Src Train Acc: 99.78, Trg Train Acc: 98.87, Src Test Acc: 99.61, Trg Test Acc: 97.25
# Epoch: 466, TotalL: 0.3143, CrossE: 0.0095, CondE: 0.0505, disc: 0.6905, domain: 0.7303, Src VAT: 0.0245, Trg VAT: 0.0505, Src MixUp: 0.1870, Trg MixUp: 0.3340, Src Train Acc: 99.65, Trg Train Acc: 97.92, Src Test Acc: 98.83, Trg Test Acc: 96.40
# Epoch: 467, TotalL: 0.2578, CrossE: 0.0031, CondE: 0.0370, disc: 0.6872, domain: 0.7314, Src VAT: 0.0117, Trg VAT: 0.0370, Src MixUp: 0.1528, Trg MixUp: 0.3228, Src Train Acc: 99.96, Trg Train Acc: 98.83, Src Test Acc: 98.05, Trg Test Acc: 95.06
# Epoch: 468, TotalL: 0.2731, CrossE: 0.0043, CondE: 0.0383, disc: 0.6884, domain: 0.7306, Src VAT: 0.0154, Trg VAT: 0.0383, Src MixUp: 0.1641, Trg MixUp: 0.3103, Src Train Acc: 99.91, Trg Train Acc: 98.57, Src Test Acc: 98.83, Trg Test Acc: 97.02
# Epoch: 469, TotalL: 0.2791, CrossE: 0.0048, CondE: 0.0389, disc: 0.6922, domain: 0.7241, Src VAT: 0.0160, Trg VAT: 0.0389, Src MixUp: 0.1675, Trg MixUp: 0.3317, Src Train Acc: 99.96, Trg Train Acc: 99.09, Src Test Acc: 99.22, Trg Test Acc: 98.01
# Epoch: 470, TotalL: 0.2753, CrossE: 0.0071, CondE: 0.0360, disc: 0.6871, domain: 0.7300, Src VAT: 0.0164, Trg VAT: 0.0360, Src MixUp: 0.1620, Trg MixUp: 0.3213, Src Train Acc: 99.87, Trg Train Acc: 98.87, Src Test Acc: 99.22, Trg Test Acc: 96.67
# Epoch: 471, TotalL: 0.2902, CrossE: 0.0092, CondE: 0.0390, disc: 0.6885, domain: 0.7299, Src VAT: 0.0176, Trg VAT: 0.0390, Src MixUp: 0.1730, Trg MixUp: 0.3211, Src Train Acc: 99.70, Trg Train Acc: 98.91, Src Test Acc: 99.22, Trg Test Acc: 97.25
# Epoch: 472, TotalL: 0.2592, CrossE: 0.0022, CondE: 0.0324, disc: 0.6866, domain: 0.7293, Src VAT: 0.0108, Trg VAT: 0.0324, Src MixUp: 0.1577, Trg MixUp: 0.3134, Src Train Acc: 100.00, Trg Train Acc: 99.00, Src Test Acc: 98.44, Trg Test Acc: 95.88
# Epoch: 473, TotalL: 0.3194, CrossE: 0.0102, CondE: 0.0436, disc: 0.6870, domain: 0.7323, Src VAT: 0.0243, Trg VAT: 0.0436, Src MixUp: 0.1930, Trg MixUp: 0.3294, Src Train Acc: 99.70, Trg Train Acc: 99.00, Src Test Acc: 98.83, Trg Test Acc: 96.75
# Epoch: 474, TotalL: 0.3181, CrossE: 0.0079, CondE: 0.0484, disc: 0.6894, domain: 0.7262, Src VAT: 0.0239, Trg VAT: 0.0484, Src MixUp: 0.1928, Trg MixUp: 0.3455, Src Train Acc: 99.91, Trg Train Acc: 98.74, Src Test Acc: 98.83, Trg Test Acc: 97.81
# Epoch: 475, TotalL: 0.2943, CrossE: 0.0086, CondE: 0.0413, disc: 0.6897, domain: 0.7310, Src VAT: 0.0219, Trg VAT: 0.0413, Src MixUp: 0.1723, Trg MixUp: 0.3306, Src Train Acc: 99.78, Trg Train Acc: 98.52, Src Test Acc: 94.94, Trg Test Acc: 88.01
# Epoch: 476, TotalL: 0.2793, CrossE: 0.0040, CondE: 0.0370, disc: 0.6870, domain: 0.7288, Src VAT: 0.0170, Trg VAT: 0.0370, Src MixUp: 0.1672, Trg MixUp: 0.3354, Src Train Acc: 100.00, Trg Train Acc: 98.78, Src Test Acc: 99.22, Trg Test Acc: 96.55
# Epoch: 477, TotalL: 0.2689, CrossE: 0.0036, CondE: 0.0342, disc: 0.6873, domain: 0.7274, Src VAT: 0.0140, Trg VAT: 0.0342, Src MixUp: 0.1625, Trg MixUp: 0.3142, Src Train Acc: 99.96, Trg Train Acc: 98.91, Src Test Acc: 99.61, Trg Test Acc: 96.99
# Epoch: 478, TotalL: 0.2714, CrossE: 0.0029, CondE: 0.0355, disc: 0.6845, domain: 0.7337, Src VAT: 0.0136, Trg VAT: 0.0355, Src MixUp: 0.1651, Trg MixUp: 0.3181, Src Train Acc: 100.00, Trg Train Acc: 98.87, Src Test Acc: 99.61, Trg Test Acc: 97.34
# Epoch: 479, TotalL: 0.2931, CrossE: 0.0094, CondE: 0.0419, disc: 0.6884, domain: 0.7286, Src VAT: 0.0175, Trg VAT: 0.0419, Src MixUp: 0.1744, Trg MixUp: 0.3350, Src Train Acc: 99.70, Trg Train Acc: 98.65, Src Test Acc: 98.44, Trg Test Acc: 97.66
# Epoch: 480, TotalL: 0.2469, CrossE: 0.0030, CondE: 0.0275, disc: 0.6860, domain: 0.7316, Src VAT: 0.0101, Trg VAT: 0.0275, Src MixUp: 0.1465, Trg MixUp: 0.3051, Src Train Acc: 99.91, Trg Train Acc: 99.35, Src Test Acc: 98.05, Trg Test Acc: 97.81
# Epoch: 481, TotalL: 0.2953, CrossE: 0.0061, CondE: 0.0365, disc: 0.6880, domain: 0.7319, Src VAT: 0.0182, Trg VAT: 0.0365, Src MixUp: 0.1806, Trg MixUp: 0.3250, Src Train Acc: 99.91, Trg Train Acc: 98.87, Src Test Acc: 99.22, Trg Test Acc: 95.96
# Epoch: 482, TotalL: 0.2799, CrossE: 0.0044, CondE: 0.0374, disc: 0.6886, domain: 0.7292, Src VAT: 0.0157, Trg VAT: 0.0374, Src MixUp: 0.1693, Trg MixUp: 0.3266, Src Train Acc: 99.96, Trg Train Acc: 98.74, Src Test Acc: 99.61, Trg Test Acc: 95.32
# Epoch: 483, TotalL: 0.2775, CrossE: 0.0041, CondE: 0.0366, disc: 0.6882, domain: 0.7270, Src VAT: 0.0161, Trg VAT: 0.0366, Src MixUp: 0.1669, Trg MixUp: 0.3298, Src Train Acc: 99.96, Trg Train Acc: 98.91, Src Test Acc: 98.44, Trg Test Acc: 97.02
# Epoch: 484, TotalL: 0.2946, CrossE: 0.0067, CondE: 0.0423, disc: 0.6910, domain: 0.7333, Src VAT: 0.0199, Trg VAT: 0.0423, Src MixUp: 0.1752, Trg MixUp: 0.3430, Src Train Acc: 99.87, Trg Train Acc: 98.39, Src Test Acc: 99.61, Trg Test Acc: 97.69
# Epoch: 485, TotalL: 0.2574, CrossE: 0.0040, CondE: 0.0377, disc: 0.6861, domain: 0.7301, Src VAT: 0.0133, Trg VAT: 0.0377, Src MixUp: 0.1506, Trg MixUp: 0.3140, Src Train Acc: 99.91, Trg Train Acc: 98.96, Src Test Acc: 98.44, Trg Test Acc: 96.70
# Epoch: 486, TotalL: 0.2461, CrossE: 0.0028, CondE: 0.0270, disc: 0.6843, domain: 0.7319, Src VAT: 0.0110, Trg VAT: 0.0270, Src MixUp: 0.1454, Trg MixUp: 0.3001, Src Train Acc: 99.96, Trg Train Acc: 99.13, Src Test Acc: 98.83, Trg Test Acc: 95.88
# Epoch: 487, TotalL: 0.2884, CrossE: 0.0034, CondE: 0.0365, disc: 0.6865, domain: 0.7322, Src VAT: 0.0153, Trg VAT: 0.0365, Src MixUp: 0.1781, Trg MixUp: 0.3396, Src Train Acc: 100.00, Trg Train Acc: 98.96, Src Test Acc: 94.16, Trg Test Acc: 88.98
# Epoch: 488, TotalL: 0.2497, CrossE: 0.0026, CondE: 0.0278, disc: 0.6856, domain: 0.7303, Src VAT: 0.0110, Trg VAT: 0.0278, Src MixUp: 0.1482, Trg MixUp: 0.3132, Src Train Acc: 99.96, Trg Train Acc: 99.31, Src Test Acc: 99.22, Trg Test Acc: 97.25
# Epoch: 489, TotalL: 0.2870, CrossE: 0.0068, CondE: 0.0420, disc: 0.6895, domain: 0.7319, Src VAT: 0.0180, Trg VAT: 0.0420, Src MixUp: 0.1715, Trg MixUp: 0.3170, Src Train Acc: 99.83, Trg Train Acc: 98.70, Src Test Acc: 98.05, Trg Test Acc: 93.98
# Epoch: 490, TotalL: 0.3079, CrossE: 0.0074, CondE: 0.0493, disc: 0.6889, domain: 0.7243, Src VAT: 0.0210, Trg VAT: 0.0493, Src MixUp: 0.1853, Trg MixUp: 0.3559, Src Train Acc: 99.87, Trg Train Acc: 98.65, Src Test Acc: 99.22, Trg Test Acc: 97.34
# Epoch: 491, TotalL: 0.2832, CrossE: 0.0053, CondE: 0.0366, disc: 0.6876, domain: 0.7268, Src VAT: 0.0168, Trg VAT: 0.0366, Src MixUp: 0.1705, Trg MixUp: 0.3331, Src Train Acc: 99.83, Trg Train Acc: 98.70, Src Test Acc: 99.22, Trg Test Acc: 96.35
# Epoch: 492, TotalL: 0.2850, CrossE: 0.0075, CondE: 0.0429, disc: 0.6875, domain: 0.7332, Src VAT: 0.0193, Trg VAT: 0.0429, Src MixUp: 0.1664, Trg MixUp: 0.3284, Src Train Acc: 99.83, Trg Train Acc: 98.91, Src Test Acc: 98.44, Trg Test Acc: 97.16
# Epoch: 493, TotalL: 0.2657, CrossE: 0.0036, CondE: 0.0379, disc: 0.6823, domain: 0.7378, Src VAT: 0.0144, Trg VAT: 0.0379, Src MixUp: 0.1565, Trg MixUp: 0.3244, Src Train Acc: 99.96, Trg Train Acc: 98.57, Src Test Acc: 99.61, Trg Test Acc: 97.25
# Epoch: 494, TotalL: 0.2909, CrossE: 0.0064, CondE: 0.0440, disc: 0.6867, domain: 0.7356, Src VAT: 0.0198, Trg VAT: 0.0440, Src MixUp: 0.1717, Trg MixUp: 0.3381, Src Train Acc: 99.83, Trg Train Acc: 98.65, Src Test Acc: 99.22, Trg Test Acc: 97.25
# Epoch: 495, TotalL: 0.3095, CrossE: 0.0167, CondE: 0.0420, disc: 0.6871, domain: 0.7315, Src VAT: 0.0232, Trg VAT: 0.0420, Src MixUp: 0.1779, Trg MixUp: 0.3305, Src Train Acc: 99.61, Trg Train Acc: 98.26, Src Test Acc: 96.89, Trg Test Acc: 97.25
# Epoch: 496, TotalL: 0.2877, CrossE: 0.0032, CondE: 0.0330, disc: 0.6835, domain: 0.7299, Src VAT: 0.0141, Trg VAT: 0.0330, Src MixUp: 0.1796, Trg MixUp: 0.3395, Src Train Acc: 99.96, Trg Train Acc: 99.31, Src Test Acc: 98.44, Trg Test Acc: 96.17
# Epoch: 497, TotalL: 0.2664, CrossE: 0.0029, CondE: 0.0363, disc: 0.6849, domain: 0.7309, Src VAT: 0.0131, Trg VAT: 0.0363, Src MixUp: 0.1611, Trg MixUp: 0.3147, Src Train Acc: 100.00, Trg Train Acc: 99.09, Src Test Acc: 99.61, Trg Test Acc: 97.02
# Epoch: 498, TotalL: 0.2822, CrossE: 0.0058, CondE: 0.0329, disc: 0.6909, domain: 0.7245, Src VAT: 0.0175, Trg VAT: 0.0329, Src MixUp: 0.1694, Trg MixUp: 0.3280, Src Train Acc: 99.91, Trg Train Acc: 99.18, Src Test Acc: 97.28, Trg Test Acc: 96.05
# Epoch: 499, TotalL: 0.2788, CrossE: 0.0041, CondE: 0.0385, disc: 0.6859, domain: 0.7315, Src VAT: 0.0161, Trg VAT: 0.0385, Src MixUp: 0.1690, Trg MixUp: 0.3104, Src Train Acc: 100.00, Trg Train Acc: 98.78, Src Test Acc: 99.61, Trg Test Acc: 97.46
# Epoch: 500, TotalL: 0.3115, CrossE: 0.0095, CondE: 0.0436, disc: 0.6859, domain: 0.7309, Src VAT: 0.0205, Trg VAT: 0.0436, Src MixUp: 0.1879, Trg MixUp: 0.3518, Src Train Acc: 99.87, Trg Train Acc: 98.35, Src Test Acc: 97.28, Trg Test Acc: 94.56
