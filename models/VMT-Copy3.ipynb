# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='3'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 1.14.0

# %%
num_classes    = 9
batch_size     = 16
train_src_days = 3
train_trg_days = 3
epochs         = 500
learning_rate  = 0.0001

# Notes : 
# updated total_loss to reflect my issue on github 
# https://github.com/xudonmao/VMT/issues/1#issue-476306489
# VMT with first 3 days for train, next 3 days for train unlabeled and rest for test
# Increased Disc hidden dim to 512 from 100
# added gaussian noise to gen

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation('relu')(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2)):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features):
    super().__init__(name='generator')
    bn_axis = -1

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.relu1 = tf.keras.layers.Activation('relu', name='relu1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a'))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b'))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation='relu',
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.relu1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self):
    super().__init__(name='discriminator')  
    self.dense1 = tf.keras.layers.Dense(512, activation='relu')
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, inputs):
    x = self.dense1(inputs)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, 256)
discriminator  = Discriminator()
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

for epoch in range(epochs):
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 19:03:04.646845 139796317972224 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/autograph/impl/api.py:255: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.1706, CrossE: 2.1998, CondE: 2.1943, disc: 0.6933, domain: 0.6933, Src VAT: 2.1943, Trg VAT: 2.1943, Src MixUp: 2.1943, Trg MixUp: 2.1943, Src Train Acc: 11.76, Trg Train Acc: 10.42, Src Test Acc: 11.28, Trg Test Acc: 11.11
# Epoch: 002, TotalL: 7.1646, CrossE: 2.1948, CondE: 2.1939, disc: 0.6931, domain: 0.6934, Src VAT: 2.1939, Trg VAT: 2.1939, Src MixUp: 2.1940, Trg MixUp: 2.1940, Src Train Acc: 12.67, Trg Train Acc: 12.37, Src Test Acc: 11.28, Trg Test Acc: 11.75
# Epoch: 003, TotalL: 7.0991, CrossE: 2.1707, CondE: 2.1731, disc: 0.6940, domain: 0.6944, Src VAT: 2.1741, Trg VAT: 2.1731, Src MixUp: 2.1769, Trg MixUp: 2.1766, Src Train Acc: 14.45, Trg Train Acc: 14.54, Src Test Acc: 22.18, Trg Test Acc: 23.01
# Epoch: 004, TotalL: 6.8614, CrossE: 2.0901, CondE: 2.0891, disc: 0.6960, domain: 0.6970, Src VAT: 2.0962, Trg VAT: 2.0891, Src MixUp: 2.1160, Trg MixUp: 2.1128, Src Train Acc: 18.84, Trg Train Acc: 18.06, Src Test Acc: 28.40, Trg Test Acc: 24.68
# Epoch: 005, TotalL: 6.5843, CrossE: 1.9850, CondE: 1.9990, disc: 0.6960, domain: 0.6996, Src VAT: 2.0073, Trg VAT: 1.9990, Src MixUp: 2.0524, Trg MixUp: 2.0469, Src Train Acc: 21.22, Trg Train Acc: 20.49, Src Test Acc: 24.90, Trg Test Acc: 24.47
# Epoch: 006, TotalL: 6.2444, CrossE: 1.8556, CondE: 1.8907, disc: 0.6980, domain: 0.7051, Src VAT: 1.8972, Trg VAT: 1.8907, Src MixUp: 1.9752, Trg MixUp: 1.9683, Src Train Acc: 26.04, Trg Train Acc: 22.31, Src Test Acc: 26.07, Trg Test Acc: 22.13
# Epoch: 007, TotalL: 5.9350, CrossE: 1.7491, CondE: 1.7923, disc: 0.7008, domain: 0.7088, Src VAT: 1.7971, Trg VAT: 1.7923, Src MixUp: 1.8935, Trg MixUp: 1.8980, Src Train Acc: 29.86, Trg Train Acc: 25.78, Src Test Acc: 27.63, Trg Test Acc: 23.42
# Epoch: 008, TotalL: 5.4462, CrossE: 1.5560, CondE: 1.6481, disc: 0.7006, domain: 0.7245, Src VAT: 1.6483, Trg VAT: 1.6481, Src MixUp: 1.7775, Trg MixUp: 1.7843, Src Train Acc: 39.93, Trg Train Acc: 35.37, Src Test Acc: 42.41, Trg Test Acc: 37.95
# Epoch: 009, TotalL: 4.8996, CrossE: 1.3720, CondE: 1.4613, disc: 0.6966, domain: 0.7390, Src VAT: 1.4613, Trg VAT: 1.4613, Src MixUp: 1.6422, Trg MixUp: 1.6394, Src Train Acc: 47.96, Trg Train Acc: 41.28, Src Test Acc: 49.81, Trg Test Acc: 44.15
# Epoch: 010, TotalL: 4.5782, CrossE: 1.2629, CondE: 1.3557, disc: 0.6968, domain: 0.7447, Src VAT: 1.3574, Trg VAT: 1.3557, Src MixUp: 1.5573, Trg MixUp: 1.5512, Src Train Acc: 51.91, Trg Train Acc: 45.31, Src Test Acc: 50.19, Trg Test Acc: 44.62
# Epoch: 011, TotalL: 4.3834, CrossE: 1.2025, CondE: 1.2901, disc: 0.6951, domain: 0.7520, Src VAT: 1.2933, Trg VAT: 1.2901, Src MixUp: 1.5021, Trg MixUp: 1.4879, Src Train Acc: 54.25, Trg Train Acc: 47.96, Src Test Acc: 52.14, Trg Test Acc: 46.67
# Epoch: 012, TotalL: 4.2157, CrossE: 1.1532, CondE: 1.2320, disc: 0.6924, domain: 0.7577, Src VAT: 1.2358, Trg VAT: 1.2320, Src MixUp: 1.4529, Trg MixUp: 1.4513, Src Train Acc: 56.25, Trg Train Acc: 49.18, Src Test Acc: 54.47, Trg Test Acc: 51.05
# Epoch: 013, TotalL: 4.0871, CrossE: 1.1123, CondE: 1.1907, disc: 0.6929, domain: 0.7606, Src VAT: 1.1964, Trg VAT: 1.1907, Src MixUp: 1.4148, Trg MixUp: 1.4030, Src Train Acc: 57.81, Trg Train Acc: 50.35, Src Test Acc: 54.86, Trg Test Acc: 50.18
# Epoch: 014, TotalL: 3.9344, CrossE: 1.0691, CondE: 1.1421, disc: 0.6919, domain: 0.7641, Src VAT: 1.1463, Trg VAT: 1.1421, Src MixUp: 1.3663, Trg MixUp: 1.3598, Src Train Acc: 58.64, Trg Train Acc: 50.95, Src Test Acc: 57.59, Trg Test Acc: 51.75
# Epoch: 015, TotalL: 3.8198, CrossE: 1.0286, CondE: 1.1035, disc: 0.6921, domain: 0.7675, Src VAT: 1.1098, Trg VAT: 1.1035, Src MixUp: 1.3368, Trg MixUp: 1.3325, Src Train Acc: 61.76, Trg Train Acc: 53.21, Src Test Acc: 58.37, Trg Test Acc: 53.51
# Epoch: 016, TotalL: 3.6987, CrossE: 0.9877, CondE: 1.0690, disc: 0.6912, domain: 0.7705, Src VAT: 1.0735, Trg VAT: 1.0690, Src MixUp: 1.3008, Trg MixUp: 1.2999, Src Train Acc: 63.02, Trg Train Acc: 54.43, Src Test Acc: 61.48, Trg Test Acc: 56.43
# Epoch: 017, TotalL: 3.5703, CrossE: 0.9540, CondE: 1.0283, disc: 0.6921, domain: 0.7699, Src VAT: 1.0309, Trg VAT: 1.0283, Src MixUp: 1.2586, Trg MixUp: 1.2582, Src Train Acc: 65.19, Trg Train Acc: 55.69, Src Test Acc: 61.48, Trg Test Acc: 55.15
# Epoch: 018, TotalL: 3.4693, CrossE: 0.9065, CondE: 0.9969, disc: 0.6893, domain: 0.7762, Src VAT: 0.9972, Trg VAT: 0.9969, Src MixUp: 1.2447, Trg MixUp: 1.2407, Src Train Acc: 66.28, Trg Train Acc: 58.16, Src Test Acc: 63.42, Trg Test Acc: 58.60
# Epoch: 019, TotalL: 3.3946, CrossE: 0.8742, CondE: 0.9796, disc: 0.6915, domain: 0.7786, Src VAT: 0.9678, Trg VAT: 0.9796, Src MixUp: 1.2350, Trg MixUp: 1.2316, Src Train Acc: 67.62, Trg Train Acc: 59.59, Src Test Acc: 64.20, Trg Test Acc: 57.95
# Epoch: 020, TotalL: 3.2377, CrossE: 0.8114, CondE: 0.9373, disc: 0.6868, domain: 0.7867, Src VAT: 0.9243, Trg VAT: 0.9373, Src MixUp: 1.1929, Trg MixUp: 1.2037, Src Train Acc: 70.23, Trg Train Acc: 62.15, Src Test Acc: 65.76, Trg Test Acc: 59.12
# Epoch: 021, TotalL: 3.0780, CrossE: 0.7623, CondE: 0.8852, disc: 0.6850, domain: 0.7933, Src VAT: 0.8730, Trg VAT: 0.8852, Src MixUp: 1.1449, Trg MixUp: 1.1581, Src Train Acc: 73.13, Trg Train Acc: 64.97, Src Test Acc: 68.87, Trg Test Acc: 61.26
# Epoch: 022, TotalL: 2.9383, CrossE: 0.7184, CondE: 0.8434, disc: 0.6850, domain: 0.7940, Src VAT: 0.8256, Trg VAT: 0.8434, Src MixUp: 1.1064, Trg MixUp: 1.1172, Src Train Acc: 75.04, Trg Train Acc: 66.45, Src Test Acc: 70.04, Trg Test Acc: 62.28
# Epoch: 023, TotalL: 2.8767, CrossE: 0.6849, CondE: 0.8303, disc: 0.6808, domain: 0.7968, Src VAT: 0.8077, Trg VAT: 0.8303, Src MixUp: 1.0993, Trg MixUp: 1.1036, Src Train Acc: 76.56, Trg Train Acc: 68.58, Src Test Acc: 70.82, Trg Test Acc: 60.99
# Epoch: 024, TotalL: 2.7674, CrossE: 0.6553, CondE: 0.7959, disc: 0.6801, domain: 0.8027, Src VAT: 0.7678, Trg VAT: 0.7959, Src MixUp: 1.0659, Trg MixUp: 1.0843, Src Train Acc: 77.47, Trg Train Acc: 68.79, Src Test Acc: 77.43, Trg Test Acc: 64.94
# Epoch: 025, TotalL: 2.6516, CrossE: 0.6032, CondE: 0.7637, disc: 0.6779, domain: 0.8082, Src VAT: 0.7301, Trg VAT: 0.7637, Src MixUp: 1.0463, Trg MixUp: 1.0642, Src Train Acc: 78.78, Trg Train Acc: 70.62, Src Test Acc: 76.26, Trg Test Acc: 65.41
# Epoch: 026, TotalL: 2.5535, CrossE: 0.5726, CondE: 0.7342, disc: 0.6721, domain: 0.8168, Src VAT: 0.6955, Trg VAT: 0.7342, Src MixUp: 1.0188, Trg MixUp: 1.0461, Src Train Acc: 80.25, Trg Train Acc: 72.18, Src Test Acc: 83.66, Trg Test Acc: 69.39
# Epoch: 027, TotalL: 2.5349, CrossE: 0.5595, CondE: 0.7117, disc: 0.6708, domain: 0.8193, Src VAT: 0.6843, Trg VAT: 0.7117, Src MixUp: 1.0284, Trg MixUp: 1.0415, Src Train Acc: 80.25, Trg Train Acc: 73.44, Src Test Acc: 77.43, Trg Test Acc: 66.02
# Epoch: 028, TotalL: 2.4049, CrossE: 0.5116, CondE: 0.6875, disc: 0.6614, domain: 0.8278, Src VAT: 0.6461, Trg VAT: 0.6875, Src MixUp: 0.9899, Trg MixUp: 1.0135, Src Train Acc: 83.07, Trg Train Acc: 74.61, Src Test Acc: 86.77, Trg Test Acc: 70.85
# Epoch: 029, TotalL: 2.3810, CrossE: 0.5129, CondE: 0.6778, disc: 0.6703, domain: 0.8200, Src VAT: 0.6412, Trg VAT: 0.6778, Src MixUp: 0.9711, Trg MixUp: 1.0215, Src Train Acc: 82.86, Trg Train Acc: 75.00, Src Test Acc: 86.38, Trg Test Acc: 68.98
# Epoch: 030, TotalL: 2.2620, CrossE: 0.4739, CondE: 0.6462, disc: 0.6656, domain: 0.8375, Src VAT: 0.6000, Trg VAT: 0.6462, Src MixUp: 0.9374, Trg MixUp: 1.0031, Src Train Acc: 84.29, Trg Train Acc: 76.35, Src Test Acc: 82.88, Trg Test Acc: 69.42
# Epoch: 069, TotalL: 1.2007, CrossE: 0.1466, CondE: 0.3014, disc: 0.6560, domain: 0.8662, Src VAT: 0.2372, Trg VAT: 0.3014, Src MixUp: 0.6431, Trg MixUp: 0.7039, Src Train Acc: 95.66, Trg Train Acc: 89.19, Src Test Acc: 96.50, Trg Test Acc: 86.61
# Epoch: 070, TotalL: 1.1914, CrossE: 0.1375, CondE: 0.3093, disc: 0.6594, domain: 0.8656, Src VAT: 0.2329, Trg VAT: 0.3093, Src MixUp: 0.6464, Trg MixUp: 0.6976, Src Train Acc: 95.57, Trg Train Acc: 89.63, Src Test Acc: 90.27, Trg Test Acc: 76.67
# Epoch: 071, TotalL: 1.1747, CrossE: 0.1388, CondE: 0.3093, disc: 0.6676, domain: 0.8676, Src VAT: 0.2294, Trg VAT: 0.3093, Src MixUp: 0.6314, Trg MixUp: 0.7016, Src Train Acc: 95.96, Trg Train Acc: 88.67, Src Test Acc: 95.72, Trg Test Acc: 85.58
# Epoch: 072, TotalL: 1.1344, CrossE: 0.1284, CondE: 0.2858, disc: 0.6671, domain: 0.8693, Src VAT: 0.2081, Trg VAT: 0.2858, Src MixUp: 0.6289, Trg MixUp: 0.6713, Src Train Acc: 95.96, Trg Train Acc: 90.62, Src Test Acc: 92.22, Trg Test Acc: 78.16
# Epoch: 073, TotalL: 1.1548, CrossE: 0.1353, CondE: 0.2959, disc: 0.6684, domain: 0.8647, Src VAT: 0.2245, Trg VAT: 0.2959, Src MixUp: 0.6231, Trg MixUp: 0.6915, Src Train Acc: 96.35, Trg Train Acc: 89.37, Src Test Acc: 83.27, Trg Test Acc: 70.50
# Epoch: 074, TotalL: 1.0787, CrossE: 0.1128, CondE: 0.2722, disc: 0.6642, domain: 0.8618, Src VAT: 0.2023, Trg VAT: 0.2722, Src MixUp: 0.5985, Trg MixUp: 0.6589, Src Train Acc: 97.01, Trg Train Acc: 90.76, Src Test Acc: 89.11, Trg Test Acc: 76.46
# Epoch: 075, TotalL: 1.1192, CrossE: 0.1227, CondE: 0.2860, disc: 0.6612, domain: 0.8610, Src VAT: 0.2095, Trg VAT: 0.2860, Src MixUp: 0.6175, Trg MixUp: 0.6856, Src Train Acc: 96.22, Trg Train Acc: 89.71, Src Test Acc: 96.11, Trg Test Acc: 84.24
# Epoch: 076, TotalL: 1.0896, CrossE: 0.1214, CondE: 0.2764, disc: 0.6679, domain: 0.8557, Src VAT: 0.2038, Trg VAT: 0.2764, Src MixUp: 0.5993, Trg MixUp: 0.6564, Src Train Acc: 96.27, Trg Train Acc: 89.19, Src Test Acc: 79.77, Trg Test Acc: 67.75
# Epoch: 077, TotalL: 1.0846, CrossE: 0.1125, CondE: 0.2722, disc: 0.6715, domain: 0.8574, Src VAT: 0.1982, Trg VAT: 0.2722, Src MixUp: 0.6080, Trg MixUp: 0.6728, Src Train Acc: 96.79, Trg Train Acc: 89.50, Src Test Acc: 85.21, Trg Test Acc: 71.37
# Epoch: 078, TotalL: 1.0900, CrossE: 0.1162, CondE: 0.2627, disc: 0.6736, domain: 0.8514, Src VAT: 0.2004, Trg VAT: 0.2627, Src MixUp: 0.6119, Trg MixUp: 0.6421, Src Train Acc: 96.92, Trg Train Acc: 88.80, Src Test Acc: 95.72, Trg Test Acc: 88.07
# Epoch: 126, TotalL: 0.7427, CrossE: 0.0424, CondE: 0.1595, disc: 0.6659, domain: 0.8364, Src VAT: 0.1008, Trg VAT: 0.1595, Src MixUp: 0.4644, Trg MixUp: 0.5324, Src Train Acc: 99.09, Trg Train Acc: 93.62, Src Test Acc: 76.26, Trg Test Acc: 61.11
# Epoch: 127, TotalL: 0.8473, CrossE: 0.0819, CondE: 0.1889, disc: 0.6709, domain: 0.8285, Src VAT: 0.1343, Trg VAT: 0.1889, Src MixUp: 0.4891, Trg MixUp: 0.5677, Src Train Acc: 97.79, Trg Train Acc: 91.58, Src Test Acc: 97.28, Trg Test Acc: 92.63
# Epoch: 128, TotalL: 0.6542, CrossE: 0.0308, CondE: 0.1491, disc: 0.6598, domain: 0.8400, Src VAT: 0.0781, Trg VAT: 0.1491, Src MixUp: 0.4126, Trg MixUp: 0.5199, Src Train Acc: 99.22, Trg Train Acc: 94.44, Src Test Acc: 98.05, Trg Test Acc: 88.25
# Epoch: 129, TotalL: 0.7022, CrossE: 0.0410, CondE: 0.1628, disc: 0.6631, domain: 0.8349, Src VAT: 0.0928, Trg VAT: 0.1628, Src MixUp: 0.4321, Trg MixUp: 0.5426, Src Train Acc: 99.09, Trg Train Acc: 94.27, Src Test Acc: 96.89, Trg Test Acc: 84.24
# Epoch: 130, TotalL: 0.7733, CrossE: 0.0543, CondE: 0.1649, disc: 0.6742, domain: 0.8268, Src VAT: 0.1046, Trg VAT: 0.1649, Src MixUp: 0.4798, Trg MixUp: 0.5251, Src Train Acc: 98.31, Trg Train Acc: 93.32, Src Test Acc: 93.00, Trg Test Acc: 83.83
# Epoch: 131, TotalL: 0.7150, CrossE: 0.0497, CondE: 0.1534, disc: 0.6696, domain: 0.8276, Src VAT: 0.0941, Trg VAT: 0.1534, Src MixUp: 0.4387, Trg MixUp: 0.5226, Src Train Acc: 98.70, Trg Train Acc: 94.14, Src Test Acc: 88.33, Trg Test Acc: 75.64
# Epoch: 132, TotalL: 0.7183, CrossE: 0.0360, CondE: 0.1588, disc: 0.6718, domain: 0.8234, Src VAT: 0.0907, Trg VAT: 0.1588, Src MixUp: 0.4580, Trg MixUp: 0.5290, Src Train Acc: 99.26, Trg Train Acc: 93.97, Src Test Acc: 98.05, Trg Test Acc: 88.92
# Epoch: 133, TotalL: 0.7033, CrossE: 0.0488, CondE: 0.1561, disc: 0.6694, domain: 0.8295, Src VAT: 0.0893, Trg VAT: 0.1561, Src MixUp: 0.4324, Trg MixUp: 0.5188, Src Train Acc: 98.78, Trg Train Acc: 94.18, Src Test Acc: 88.72, Trg Test Acc: 75.03
# Epoch: 134, TotalL: 0.6853, CrossE: 0.0414, CondE: 0.1530, disc: 0.6673, domain: 0.8339, Src VAT: 0.0875, Trg VAT: 0.1530, Src MixUp: 0.4231, Trg MixUp: 0.5283, Src Train Acc: 98.83, Trg Train Acc: 94.10, Src Test Acc: 94.16, Trg Test Acc: 87.66
# Epoch: 154, TotalL: 0.6920, CrossE: 0.0473, CondE: 0.1444, disc: 0.6554, domain: 0.8249, Src VAT: 0.0876, Trg VAT: 0.1444, Src MixUp: 0.4286, Trg MixUp: 0.4921, Src Train Acc: 98.74, Trg Train Acc: 94.88, Src Test Acc: 96.89, Trg Test Acc: 91.90
# Epoch: 155, TotalL: 0.6865, CrossE: 0.0340, CondE: 0.1500, disc: 0.6607, domain: 0.8309, Src VAT: 0.0797, Trg VAT: 0.1500, Src MixUp: 0.4398, Trg MixUp: 0.5323, Src Train Acc: 99.18, Trg Train Acc: 94.27, Src Test Acc: 98.05, Trg Test Acc: 94.09
# Epoch: 156, TotalL: 0.6163, CrossE: 0.0339, CondE: 0.1314, disc: 0.6564, domain: 0.8348, Src VAT: 0.0684, Trg VAT: 0.1314, Src MixUp: 0.3876, Trg MixUp: 0.4829, Src Train Acc: 98.96, Trg Train Acc: 94.70, Src Test Acc: 94.16, Trg Test Acc: 92.60
# Epoch: 157, TotalL: 0.6507, CrossE: 0.0327, CondE: 0.1418, disc: 0.6608, domain: 0.8352, Src VAT: 0.0786, Trg VAT: 0.1418, Src MixUp: 0.4090, Trg MixUp: 0.5112, Src Train Acc: 99.18, Trg Train Acc: 94.27, Src Test Acc: 91.05, Trg Test Acc: 77.02
# Epoch: 158, TotalL: 0.6246, CrossE: 0.0265, CondE: 0.1240, disc: 0.6598, domain: 0.8353, Src VAT: 0.0672, Trg VAT: 0.1240, Src MixUp: 0.4058, Trg MixUp: 0.4805, Src Train Acc: 99.35, Trg Train Acc: 94.92, Src Test Acc: 95.33, Trg Test Acc: 83.01
# Epoch: 159, TotalL: 0.6951, CrossE: 0.0490, CondE: 0.1453, disc: 0.6645, domain: 0.8295, Src VAT: 0.0810, Trg VAT: 0.1453, Src MixUp: 0.4351, Trg MixUp: 0.5054, Src Train Acc: 98.78, Trg Train Acc: 93.97, Src Test Acc: 93.39, Trg Test Acc: 87.43
# Epoch: 160, TotalL: 0.6561, CrossE: 0.0385, CondE: 0.1408, disc: 0.6562, domain: 0.8414, Src VAT: 0.0784, Trg VAT: 0.1408, Src MixUp: 0.4088, Trg MixUp: 0.5066, Src Train Acc: 98.96, Trg Train Acc: 94.92, Src Test Acc: 87.55, Trg Test Acc: 73.25
# Epoch: 161, TotalL: 0.6069, CrossE: 0.0241, CondE: 0.1349, disc: 0.6474, domain: 0.8487, Src VAT: 0.0644, Trg VAT: 0.1349, Src MixUp: 0.3889, Trg MixUp: 0.5002, Src Train Acc: 99.22, Trg Train Acc: 94.18, Src Test Acc: 97.67, Trg Test Acc: 90.15
# Epoch: 162, TotalL: 0.6343, CrossE: 0.0297, CondE: 0.1300, disc: 0.6537, domain: 0.8470, Src VAT: 0.0724, Trg VAT: 0.1300, Src MixUp: 0.4044, Trg MixUp: 0.4906, Src Train Acc: 99.39, Trg Train Acc: 94.84, Src Test Acc: 74.71, Trg Test Acc: 63.27
# Epoch: 163, TotalL: 0.6389, CrossE: 0.0322, CondE: 0.1315, disc: 0.6563, domain: 0.8386, Src VAT: 0.0699, Trg VAT: 0.1315, Src MixUp: 0.4100, Trg MixUp: 0.4827, Src Train Acc: 99.35, Trg Train Acc: 94.79, Src Test Acc: 97.28, Trg Test Acc: 93.71
# Epoch: 164, TotalL: 0.6502, CrossE: 0.0363, CondE: 0.1410, disc: 0.6585, domain: 0.8387, Src VAT: 0.0794, Trg VAT: 0.1410, Src MixUp: 0.4044, Trg MixUp: 0.5056, Src Train Acc: 99.09, Trg Train Acc: 94.49, Src Test Acc: 99.61, Trg Test Acc: 93.74
# Epoch: 165, TotalL: 0.6508, CrossE: 0.0401, CondE: 0.1382, disc: 0.6579, domain: 0.8371, Src VAT: 0.0759, Trg VAT: 0.1382, Src MixUp: 0.4057, Trg MixUp: 0.4998, Src Train Acc: 98.78, Trg Train Acc: 93.88, Src Test Acc: 95.33, Trg Test Acc: 87.22
# Epoch: 166, TotalL: 0.6402, CrossE: 0.0249, CondE: 0.1340, disc: 0.6542, domain: 0.8319, Src VAT: 0.0686, Trg VAT: 0.1340, Src MixUp: 0.4169, Trg MixUp: 0.5226, Src Train Acc: 99.48, Trg Train Acc: 95.14, Src Test Acc: 96.11, Trg Test Acc: 94.04
# Epoch: 167, TotalL: 0.5885, CrossE: 0.0208, CondE: 0.1254, disc: 0.6534, domain: 0.8364, Src VAT: 0.0608, Trg VAT: 0.1254, Src MixUp: 0.3815, Trg MixUp: 0.4806, Src Train Acc: 99.52, Trg Train Acc: 95.18, Src Test Acc: 97.67, Trg Test Acc: 91.11
# Epoch: 168, TotalL: 0.6255, CrossE: 0.0268, CondE: 0.1255, disc: 0.6546, domain: 0.8388, Src VAT: 0.0674, Trg VAT: 0.1255, Src MixUp: 0.4054, Trg MixUp: 0.4830, Src Train Acc: 99.39, Trg Train Acc: 94.57, Src Test Acc: 98.44, Trg Test Acc: 94.80
# Epoch: 169, TotalL: 0.6044, CrossE: 0.0257, CondE: 0.1268, disc: 0.6641, domain: 0.8280, Src VAT: 0.0668, Trg VAT: 0.1268, Src MixUp: 0.3865, Trg MixUp: 0.4867, Src Train Acc: 99.48, Trg Train Acc: 94.62, Src Test Acc: 96.89, Trg Test Acc: 89.44
# Epoch: 170, TotalL: 0.6432, CrossE: 0.0341, CondE: 0.1438, disc: 0.6578, domain: 0.8392, Src VAT: 0.0726, Trg VAT: 0.1438, Src MixUp: 0.4071, Trg MixUp: 0.4904, Src Train Acc: 99.18, Trg Train Acc: 94.97, Src Test Acc: 95.33, Trg Test Acc: 85.18
# Epoch: 171, TotalL: 0.5831, CrossE: 0.0256, CondE: 0.1241, disc: 0.6571, domain: 0.8411, Src VAT: 0.0574, Trg VAT: 0.1241, Src MixUp: 0.3751, Trg MixUp: 0.4748, Src Train Acc: 99.61, Trg Train Acc: 95.62, Src Test Acc: 92.22, Trg Test Acc: 82.13
# Epoch: 172, TotalL: 0.6716, CrossE: 0.0379, CondE: 0.1322, disc: 0.6559, domain: 0.8372, Src VAT: 0.0762, Trg VAT: 0.1322, Src MixUp: 0.4290, Trg MixUp: 0.5045, Src Train Acc: 98.91, Trg Train Acc: 95.31, Src Test Acc: 98.83, Trg Test Acc: 92.78
# Epoch: 173, TotalL: 0.6842, CrossE: 0.0370, CondE: 0.1344, disc: 0.6575, domain: 0.8386, Src VAT: 0.0800, Trg VAT: 0.1344, Src MixUp: 0.4388, Trg MixUp: 0.4973, Src Train Acc: 98.83, Trg Train Acc: 94.88, Src Test Acc: 93.00, Trg Test Acc: 84.53
# Epoch: 174, TotalL: 0.6293, CrossE: 0.0303, CondE: 0.1318, disc: 0.6540, domain: 0.8294, Src VAT: 0.0706, Trg VAT: 0.1318, Src MixUp: 0.4029, Trg MixUp: 0.4747, Src Train Acc: 99.35, Trg Train Acc: 94.88, Src Test Acc: 91.83, Trg Test Acc: 80.67
# Epoch: 175, TotalL: 0.6278, CrossE: 0.0311, CondE: 0.1321, disc: 0.6586, domain: 0.8345, Src VAT: 0.0675, Trg VAT: 0.1321, Src MixUp: 0.4010, Trg MixUp: 0.5032, Src Train Acc: 99.13, Trg Train Acc: 94.49, Src Test Acc: 97.67, Trg Test Acc: 89.88
# Epoch: 176, TotalL: 0.6369, CrossE: 0.0351, CondE: 0.1318, disc: 0.6583, domain: 0.8277, Src VAT: 0.0705, Trg VAT: 0.1318, Src MixUp: 0.4042, Trg MixUp: 0.4969, Src Train Acc: 99.00, Trg Train Acc: 94.97, Src Test Acc: 98.44, Trg Test Acc: 93.92
# Epoch: 177, TotalL: 0.6039, CrossE: 0.0266, CondE: 0.1258, disc: 0.6550, domain: 0.8351, Src VAT: 0.0629, Trg VAT: 0.1258, Src MixUp: 0.3894, Trg MixUp: 0.4749, Src Train Acc: 99.44, Trg Train Acc: 95.27, Src Test Acc: 96.89, Trg Test Acc: 88.92
# Epoch: 178, TotalL: 0.5959, CrossE: 0.0222, CondE: 0.1191, disc: 0.6531, domain: 0.8350, Src VAT: 0.0591, Trg VAT: 0.1191, Src MixUp: 0.3911, Trg MixUp: 0.4706, Src Train Acc: 99.52, Trg Train Acc: 95.75, Src Test Acc: 97.67, Trg Test Acc: 85.67
# Epoch: 179, TotalL: 0.6104, CrossE: 0.0269, CondE: 0.1214, disc: 0.6527, domain: 0.8289, Src VAT: 0.0661, Trg VAT: 0.1214, Src MixUp: 0.3944, Trg MixUp: 0.4663, Src Train Acc: 99.52, Trg Train Acc: 94.88, Src Test Acc: 89.49, Trg Test Acc: 80.85
# Epoch: 180, TotalL: 0.5885, CrossE: 0.0216, CondE: 0.1139, disc: 0.6580, domain: 0.8348, Src VAT: 0.0568, Trg VAT: 0.1139, Src MixUp: 0.3866, Trg MixUp: 0.4809, Src Train Acc: 99.70, Trg Train Acc: 95.31, Src Test Acc: 99.61, Trg Test Acc: 95.41
# Epoch: 181, TotalL: 0.6416, CrossE: 0.0308, CondE: 0.1284, disc: 0.6666, domain: 0.8232, Src VAT: 0.0717, Trg VAT: 0.1284, Src MixUp: 0.4145, Trg MixUp: 0.4780, Src Train Acc: 99.35, Trg Train Acc: 94.97, Src Test Acc: 98.05, Trg Test Acc: 86.14
# Epoch: 182, TotalL: 0.6258, CrossE: 0.0271, CondE: 0.1259, disc: 0.6631, domain: 0.8225, Src VAT: 0.0652, Trg VAT: 0.1259, Src MixUp: 0.4078, Trg MixUp: 0.4980, Src Train Acc: 99.39, Trg Train Acc: 95.10, Src Test Acc: 96.50, Trg Test Acc: 87.75
# Epoch: 183, TotalL: 0.5889, CrossE: 0.0254, CondE: 0.1283, disc: 0.6563, domain: 0.8358, Src VAT: 0.0577, Trg VAT: 0.1283, Src MixUp: 0.3796, Trg MixUp: 0.4848, Src Train Acc: 99.39, Trg Train Acc: 95.18, Src Test Acc: 99.22, Trg Test Acc: 95.47
# Epoch: 184, TotalL: 0.6536, CrossE: 0.0487, CondE: 0.1383, disc: 0.6586, domain: 0.8224, Src VAT: 0.0726, Trg VAT: 0.1383, Src MixUp: 0.4042, Trg MixUp: 0.5026, Src Train Acc: 98.74, Trg Train Acc: 94.84, Src Test Acc: 89.11, Trg Test Acc: 75.79
# Epoch: 185, TotalL: 0.6249, CrossE: 0.0349, CondE: 0.1239, disc: 0.6575, domain: 0.8193, Src VAT: 0.0715, Trg VAT: 0.1239, Src MixUp: 0.3949, Trg MixUp: 0.4778, Src Train Acc: 99.09, Trg Train Acc: 95.57, Src Test Acc: 100.00, Trg Test Acc: 93.54
# Epoch: 186, TotalL: 0.5897, CrossE: 0.0181, CondE: 0.1178, disc: 0.6562, domain: 0.8315, Src VAT: 0.0556, Trg VAT: 0.1178, Src MixUp: 0.3906, Trg MixUp: 0.5002, Src Train Acc: 99.70, Trg Train Acc: 96.31, Src Test Acc: 97.28, Trg Test Acc: 90.03
# Epoch: 187, TotalL: 0.5960, CrossE: 0.0198, CondE: 0.1250, disc: 0.6563, domain: 0.8290, Src VAT: 0.0582, Trg VAT: 0.1250, Src MixUp: 0.3921, Trg MixUp: 0.4938, Src Train Acc: 99.74, Trg Train Acc: 95.44, Src Test Acc: 97.28, Trg Test Acc: 88.92
# Epoch: 188, TotalL: 0.5948, CrossE: 0.0263, CondE: 0.1275, disc: 0.6582, domain: 0.8284, Src VAT: 0.0660, Trg VAT: 0.1275, Src MixUp: 0.3764, Trg MixUp: 0.4931, Src Train Acc: 99.52, Trg Train Acc: 95.40, Src Test Acc: 94.55, Trg Test Acc: 86.08
# Epoch: 189, TotalL: 0.6377, CrossE: 0.0250, CondE: 0.1216, disc: 0.6548, domain: 0.8272, Src VAT: 0.0668, Trg VAT: 0.1216, Src MixUp: 0.4199, Trg MixUp: 0.5046, Src Train Acc: 99.39, Trg Train Acc: 96.09, Src Test Acc: 98.44, Trg Test Acc: 89.27
# Epoch: 190, TotalL: 0.5796, CrossE: 0.0245, CondE: 0.1197, disc: 0.6620, domain: 0.8247, Src VAT: 0.0568, Trg VAT: 0.1197, Src MixUp: 0.3756, Trg MixUp: 0.4706, Src Train Acc: 99.31, Trg Train Acc: 95.75, Src Test Acc: 98.44, Trg Test Acc: 91.46
# Epoch: 191, TotalL: 0.5724, CrossE: 0.0194, CondE: 0.1088, disc: 0.6589, domain: 0.8360, Src VAT: 0.0549, Trg VAT: 0.1088, Src MixUp: 0.3780, Trg MixUp: 0.4480, Src Train Acc: 99.52, Trg Train Acc: 95.83, Src Test Acc: 97.67, Trg Test Acc: 90.73
# Epoch: 192, TotalL: 0.6732, CrossE: 0.0415, CondE: 0.1399, disc: 0.6613, domain: 0.8294, Src VAT: 0.0837, Trg VAT: 0.1399, Src MixUp: 0.4191, Trg MixUp: 0.5028, Src Train Acc: 98.83, Trg Train Acc: 94.31, Src Test Acc: 96.89, Trg Test Acc: 89.80
# Epoch: 193, TotalL: 0.5705, CrossE: 0.0225, CondE: 0.1193, disc: 0.6530, domain: 0.8353, Src VAT: 0.0530, Trg VAT: 0.1193, Src MixUp: 0.3704, Trg MixUp: 0.4829, Src Train Acc: 99.39, Trg Train Acc: 95.92, Src Test Acc: 96.50, Trg Test Acc: 85.99
# ...
# Epoch: 437, TotalL: 0.3572, CrossE: 0.0058, CondE: 0.0446, disc: 0.6722, domain: 0.7717, Src VAT: 0.0183, Trg VAT: 0.0446, Src MixUp: 0.2366, Trg MixUp: 0.3452, Src Train Acc: 99.87, Trg Train Acc: 98.44, Src Test Acc: 99.22, Trg Test Acc: 97.43
# Epoch: 438, TotalL: 0.3853, CrossE: 0.0085, CondE: 0.0516, disc: 0.6755, domain: 0.7642, Src VAT: 0.0219, Trg VAT: 0.0516, Src MixUp: 0.2566, Trg MixUp: 0.3603, Src Train Acc: 99.74, Trg Train Acc: 97.96, Src Test Acc: 99.61, Trg Test Acc: 96.23
# Epoch: 439, TotalL: 0.3753, CrossE: 0.0050, CondE: 0.0453, disc: 0.6673, domain: 0.7751, Src VAT: 0.0187, Trg VAT: 0.0453, Src MixUp: 0.2549, Trg MixUp: 0.3432, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 99.61, Trg Test Acc: 95.76
# Epoch: 440, TotalL: 0.3970, CrossE: 0.0073, CondE: 0.0509, disc: 0.6713, domain: 0.7705, Src VAT: 0.0224, Trg VAT: 0.0509, Src MixUp: 0.2691, Trg MixUp: 0.3537, Src Train Acc: 99.83, Trg Train Acc: 97.74, Src Test Acc: 98.44, Trg Test Acc: 95.79
# Epoch: 441, TotalL: 0.3521, CrossE: 0.0033, CondE: 0.0420, disc: 0.6709, domain: 0.7672, Src VAT: 0.0136, Trg VAT: 0.0420, Src MixUp: 0.2392, Trg MixUp: 0.3493, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 98.05, Trg Test Acc: 87.78
# Epoch: 442, TotalL: 0.4131, CrossE: 0.0133, CondE: 0.0636, disc: 0.6709, domain: 0.7701, Src VAT: 0.0260, Trg VAT: 0.0636, Src MixUp: 0.2722, Trg MixUp: 0.3726, Src Train Acc: 99.65, Trg Train Acc: 97.18, Src Test Acc: 99.22, Trg Test Acc: 96.58
# Epoch: 443, TotalL: 0.4131, CrossE: 0.0071, CondE: 0.0561, disc: 0.6690, domain: 0.7690, Src VAT: 0.0228, Trg VAT: 0.0561, Src MixUp: 0.2828, Trg MixUp: 0.3749, Src Train Acc: 99.87, Trg Train Acc: 97.66, Src Test Acc: 99.22, Trg Test Acc: 95.06
# Epoch: 444, TotalL: 0.3741, CrossE: 0.0063, CondE: 0.0466, disc: 0.6709, domain: 0.7677, Src VAT: 0.0205, Trg VAT: 0.0466, Src MixUp: 0.2493, Trg MixUp: 0.3629, Src Train Acc: 99.91, Trg Train Acc: 98.48, Src Test Acc: 99.61, Trg Test Acc: 95.53
# Epoch: 445, TotalL: 0.3970, CrossE: 0.0086, CondE: 0.0571, disc: 0.6698, domain: 0.7721, Src VAT: 0.0232, Trg VAT: 0.0571, Src MixUp: 0.2654, Trg MixUp: 0.3614, Src Train Acc: 99.78, Trg Train Acc: 97.83, Src Test Acc: 97.67, Trg Test Acc: 90.79
# Epoch: 446, TotalL: 0.3848, CrossE: 0.0054, CondE: 0.0480, disc: 0.6726, domain: 0.7650, Src VAT: 0.0193, Trg VAT: 0.0480, Src MixUp: 0.2617, Trg MixUp: 0.3700, Src Train Acc: 99.91, Trg Train Acc: 97.83, Src Test Acc: 97.28, Trg Test Acc: 91.81
# Epoch: 447, TotalL: 0.3704, CrossE: 0.0076, CondE: 0.0472, disc: 0.6679, domain: 0.7711, Src VAT: 0.0180, Trg VAT: 0.0472, Src MixUp: 0.2452, Trg MixUp: 0.3801, Src Train Acc: 99.83, Trg Train Acc: 98.48, Src Test Acc: 97.67, Trg Test Acc: 90.82
# Epoch: 448, TotalL: 0.3841, CrossE: 0.0079, CondE: 0.0489, disc: 0.6750, domain: 0.7683, Src VAT: 0.0222, Trg VAT: 0.0489, Src MixUp: 0.2556, Trg MixUp: 0.3634, Src Train Acc: 99.74, Trg Train Acc: 97.96, Src Test Acc: 93.39, Trg Test Acc: 86.32
# Epoch: 449, TotalL: 0.3953, CrossE: 0.0042, CondE: 0.0477, disc: 0.6689, domain: 0.7692, Src VAT: 0.0195, Trg VAT: 0.0477, Src MixUp: 0.2738, Trg MixUp: 0.3576, Src Train Acc: 100.00, Trg Train Acc: 98.52, Src Test Acc: 99.22, Trg Test Acc: 95.85
# Epoch: 450, TotalL: 0.3844, CrossE: 0.0055, CondE: 0.0472, disc: 0.6678, domain: 0.7713, Src VAT: 0.0199, Trg VAT: 0.0472, Src MixUp: 0.2611, Trg MixUp: 0.3576, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 98.83, Trg Test Acc: 95.47
# Epoch: 451, TotalL: 0.3957, CrossE: 0.0065, CondE: 0.0469, disc: 0.6709, domain: 0.7750, Src VAT: 0.0238, Trg VAT: 0.0469, Src MixUp: 0.2664, Trg MixUp: 0.3691, Src Train Acc: 99.96, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 96.20
# Epoch: 452, TotalL: 0.3899, CrossE: 0.0057, CondE: 0.0459, disc: 0.6703, domain: 0.7758, Src VAT: 0.0204, Trg VAT: 0.0459, Src MixUp: 0.2660, Trg MixUp: 0.3547, Src Train Acc: 99.91, Trg Train Acc: 98.31, Src Test Acc: 100.00, Trg Test Acc: 95.76
# Epoch: 453, TotalL: 0.3625, CrossE: 0.0050, CondE: 0.0472, disc: 0.6661, domain: 0.7745, Src VAT: 0.0157, Trg VAT: 0.0472, Src MixUp: 0.2436, Trg MixUp: 0.3596, Src Train Acc: 99.87, Trg Train Acc: 98.61, Src Test Acc: 100.00, Trg Test Acc: 96.70
# Epoch: 454, TotalL: 0.3812, CrossE: 0.0055, CondE: 0.0458, disc: 0.6706, domain: 0.7727, Src VAT: 0.0180, Trg VAT: 0.0458, Src MixUp: 0.2593, Trg MixUp: 0.3655, Src Train Acc: 99.91, Trg Train Acc: 98.39, Src Test Acc: 98.44, Trg Test Acc: 96.87
# Epoch: 455, TotalL: 0.3504, CrossE: 0.0050, CondE: 0.0427, disc: 0.6690, domain: 0.7732, Src VAT: 0.0178, Trg VAT: 0.0427, Src MixUp: 0.2318, Trg MixUp: 0.3376, Src Train Acc: 99.96, Trg Train Acc: 98.35, Src Test Acc: 97.67, Trg Test Acc: 90.85
# Epoch: 456, TotalL: 0.3926, CrossE: 0.0059, CondE: 0.0480, disc: 0.6696, domain: 0.7762, Src VAT: 0.0199, Trg VAT: 0.0480, Src MixUp: 0.2686, Trg MixUp: 0.3559, Src Train Acc: 99.83, Trg Train Acc: 97.79, Src Test Acc: 98.83, Trg Test Acc: 95.47
# Epoch: 457, TotalL: 0.3762, CrossE: 0.0049, CondE: 0.0425, disc: 0.6737, domain: 0.7661, Src VAT: 0.0173, Trg VAT: 0.0425, Src MixUp: 0.2571, Trg MixUp: 0.3605, Src Train Acc: 99.91, Trg Train Acc: 98.39, Src Test Acc: 100.00, Trg Test Acc: 96.58
# Epoch: 458, TotalL: 0.3848, CrossE: 0.0077, CondE: 0.0480, disc: 0.6781, domain: 0.7594, Src VAT: 0.0217, Trg VAT: 0.0480, Src MixUp: 0.2590, Trg MixUp: 0.3486, Src Train Acc: 99.83, Trg Train Acc: 97.79, Src Test Acc: 99.22, Trg Test Acc: 96.29
# Epoch: 459, TotalL: 0.4039, CrossE: 0.0085, CondE: 0.0569, disc: 0.6716, domain: 0.7625, Src VAT: 0.0235, Trg VAT: 0.0569, Src MixUp: 0.2720, Trg MixUp: 0.3727, Src Train Acc: 99.78, Trg Train Acc: 97.92, Src Test Acc: 100.00, Trg Test Acc: 97.66
# Epoch: 460, TotalL: 0.3911, CrossE: 0.0072, CondE: 0.0493, disc: 0.6730, domain: 0.7631, Src VAT: 0.0208, Trg VAT: 0.0493, Src MixUp: 0.2638, Trg MixUp: 0.3801, Src Train Acc: 99.83, Trg Train Acc: 97.87, Src Test Acc: 99.61, Trg Test Acc: 93.83
# Epoch: 461, TotalL: 0.3735, CrossE: 0.0045, CondE: 0.0413, disc: 0.6718, domain: 0.7602, Src VAT: 0.0179, Trg VAT: 0.0413, Src MixUp: 0.2555, Trg MixUp: 0.3517, Src Train Acc: 99.91, Trg Train Acc: 98.52, Src Test Acc: 99.61, Trg Test Acc: 95.53
# Epoch: 462, TotalL: 0.3941, CrossE: 0.0060, CondE: 0.0525, disc: 0.6718, domain: 0.7668, Src VAT: 0.0217, Trg VAT: 0.0525, Src MixUp: 0.2666, Trg MixUp: 0.3752, Src Train Acc: 99.96, Trg Train Acc: 97.92, Src Test Acc: 98.05, Trg Test Acc: 93.04
# Epoch: 463, TotalL: 0.3968, CrossE: 0.0075, CondE: 0.0495, disc: 0.6692, domain: 0.7673, Src VAT: 0.0226, Trg VAT: 0.0495, Src MixUp: 0.2690, Trg MixUp: 0.3551, Src Train Acc: 99.91, Trg Train Acc: 98.26, Src Test Acc: 97.67, Trg Test Acc: 93.10
# Epoch: 464, TotalL: 0.4040, CrossE: 0.0051, CondE: 0.0496, disc: 0.6703, domain: 0.7655, Src VAT: 0.0211, Trg VAT: 0.0496, Src MixUp: 0.2804, Trg MixUp: 0.3540, Src Train Acc: 99.96, Trg Train Acc: 98.22, Src Test Acc: 93.39, Trg Test Acc: 87.66
# Epoch: 465, TotalL: 0.3973, CrossE: 0.0057, CondE: 0.0491, disc: 0.6698, domain: 0.7653, Src VAT: 0.0217, Trg VAT: 0.0491, Src MixUp: 0.2723, Trg MixUp: 0.3568, Src Train Acc: 99.91, Trg Train Acc: 98.31, Src Test Acc: 98.83, Trg Test Acc: 91.70
# Epoch: 466, TotalL: 0.3679, CrossE: 0.0033, CondE: 0.0432, disc: 0.6706, domain: 0.7730, Src VAT: 0.0142, Trg VAT: 0.0432, Src MixUp: 0.2525, Trg MixUp: 0.3644, Src Train Acc: 100.00, Trg Train Acc: 98.44, Src Test Acc: 100.00, Trg Test Acc: 95.61
# Epoch: 467, TotalL: 0.3983, CrossE: 0.0062, CondE: 0.0518, disc: 0.6756, domain: 0.7663, Src VAT: 0.0207, Trg VAT: 0.0518, Src MixUp: 0.2737, Trg MixUp: 0.3507, Src Train Acc: 99.87, Trg Train Acc: 98.18, Src Test Acc: 98.44, Trg Test Acc: 92.05
# Epoch: 468, TotalL: 0.3958, CrossE: 0.0098, CondE: 0.0542, disc: 0.6785, domain: 0.7656, Src VAT: 0.0236, Trg VAT: 0.0542, Src MixUp: 0.2642, Trg MixUp: 0.3540, Src Train Acc: 99.65, Trg Train Acc: 97.57, Src Test Acc: 100.00, Trg Test Acc: 97.40
# Epoch: 469, TotalL: 0.3634, CrossE: 0.0042, CondE: 0.0427, disc: 0.6734, domain: 0.7644, Src VAT: 0.0159, Trg VAT: 0.0427, Src MixUp: 0.2473, Trg MixUp: 0.3500, Src Train Acc: 99.96, Trg Train Acc: 98.09, Src Test Acc: 98.44, Trg Test Acc: 93.27
# Epoch: 470, TotalL: 0.3704, CrossE: 0.0057, CondE: 0.0410, disc: 0.6763, domain: 0.7620, Src VAT: 0.0179, Trg VAT: 0.0410, Src MixUp: 0.2515, Trg MixUp: 0.3471, Src Train Acc: 99.83, Trg Train Acc: 98.18, Src Test Acc: 98.44, Trg Test Acc: 95.29
# Epoch: 471, TotalL: 0.3947, CrossE: 0.0075, CondE: 0.0505, disc: 0.6779, domain: 0.7607, Src VAT: 0.0222, Trg VAT: 0.0505, Src MixUp: 0.2661, Trg MixUp: 0.3745, Src Train Acc: 99.87, Trg Train Acc: 98.61, Src Test Acc: 98.83, Trg Test Acc: 94.56
# Epoch: 472, TotalL: 0.3882, CrossE: 0.0080, CondE: 0.0486, disc: 0.6771, domain: 0.7609, Src VAT: 0.0228, Trg VAT: 0.0486, Src MixUp: 0.2610, Trg MixUp: 0.3463, Src Train Acc: 99.83, Trg Train Acc: 97.70, Src Test Acc: 99.22, Trg Test Acc: 96.08
# Epoch: 473, TotalL: 0.3920, CrossE: 0.0125, CondE: 0.0513, disc: 0.6784, domain: 0.7533, Src VAT: 0.0254, Trg VAT: 0.0513, Src MixUp: 0.2566, Trg MixUp: 0.3629, Src Train Acc: 99.65, Trg Train Acc: 97.96, Src Test Acc: 99.61, Trg Test Acc: 96.49
# Epoch: 474, TotalL: 0.3955, CrossE: 0.0060, CondE: 0.0536, disc: 0.6732, domain: 0.7543, Src VAT: 0.0220, Trg VAT: 0.0536, Src MixUp: 0.2694, Trg MixUp: 0.3658, Src Train Acc: 99.91, Trg Train Acc: 98.18, Src Test Acc: 99.61, Trg Test Acc: 96.49
# Epoch: 475, TotalL: 0.3537, CrossE: 0.0027, CondE: 0.0381, disc: 0.6688, domain: 0.7591, Src VAT: 0.0131, Trg VAT: 0.0381, Src MixUp: 0.2445, Trg MixUp: 0.3340, Src Train Acc: 100.00, Trg Train Acc: 98.78, Src Test Acc: 100.00, Trg Test Acc: 96.58
# Epoch: 476, TotalL: 0.4189, CrossE: 0.0084, CondE: 0.0570, disc: 0.6753, domain: 0.7666, Src VAT: 0.0246, Trg VAT: 0.0570, Src MixUp: 0.2847, Trg MixUp: 0.3847, Src Train Acc: 99.78, Trg Train Acc: 97.79, Src Test Acc: 98.83, Trg Test Acc: 95.44
# Epoch: 477, TotalL: 0.3875, CrossE: 0.0132, CondE: 0.0541, disc: 0.6705, domain: 0.7680, Src VAT: 0.0244, Trg VAT: 0.0541, Src MixUp: 0.2515, Trg MixUp: 0.3544, Src Train Acc: 99.61, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 96.37
# Epoch: 478, TotalL: 0.3246, CrossE: 0.0036, CondE: 0.0359, disc: 0.6692, domain: 0.7639, Src VAT: 0.0129, Trg VAT: 0.0359, Src MixUp: 0.2165, Trg MixUp: 0.3091, Src Train Acc: 99.96, Trg Train Acc: 98.22, Src Test Acc: 99.61, Trg Test Acc: 96.37
# Epoch: 479, TotalL: 0.3546, CrossE: 0.0047, CondE: 0.0450, disc: 0.6724, domain: 0.7616, Src VAT: 0.0164, Trg VAT: 0.0450, Src MixUp: 0.2388, Trg MixUp: 0.3323, Src Train Acc: 99.91, Trg Train Acc: 97.83, Src Test Acc: 99.61, Trg Test Acc: 97.25
# Epoch: 480, TotalL: 0.3806, CrossE: 0.0082, CondE: 0.0526, disc: 0.6777, domain: 0.7669, Src VAT: 0.0233, Trg VAT: 0.0526, Src MixUp: 0.2507, Trg MixUp: 0.3581, Src Train Acc: 99.78, Trg Train Acc: 97.70, Src Test Acc: 99.61, Trg Test Acc: 96.20
# Epoch: 481, TotalL: 0.4173, CrossE: 0.0129, CondE: 0.0527, disc: 0.6777, domain: 0.7618, Src VAT: 0.0285, Trg VAT: 0.0527, Src MixUp: 0.2784, Trg MixUp: 0.3513, Src Train Acc: 99.57, Trg Train Acc: 98.00, Src Test Acc: 99.22, Trg Test Acc: 97.49
# Epoch: 482, TotalL: 0.3801, CrossE: 0.0041, CondE: 0.0449, disc: 0.6742, domain: 0.7567, Src VAT: 0.0180, Trg VAT: 0.0449, Src MixUp: 0.2617, Trg MixUp: 0.3570, Src Train Acc: 100.00, Trg Train Acc: 98.22, Src Test Acc: 97.28, Trg Test Acc: 91.96
# Epoch: 483, TotalL: 0.3974, CrossE: 0.0080, CondE: 0.0565, disc: 0.6760, domain: 0.7607, Src VAT: 0.0221, Trg VAT: 0.0565, Src MixUp: 0.2699, Trg MixUp: 0.3456, Src Train Acc: 99.78, Trg Train Acc: 97.70, Src Test Acc: 100.00, Trg Test Acc: 96.64
# Epoch: 484, TotalL: 0.3926, CrossE: 0.0062, CondE: 0.0489, disc: 0.6751, domain: 0.7575, Src VAT: 0.0187, Trg VAT: 0.0489, Src MixUp: 0.2720, Trg MixUp: 0.3408, Src Train Acc: 99.83, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 94.15
# Epoch: 485, TotalL: 0.3385, CrossE: 0.0051, CondE: 0.0378, disc: 0.6678, domain: 0.7636, Src VAT: 0.0126, Trg VAT: 0.0378, Src MixUp: 0.2259, Trg MixUp: 0.3462, Src Train Acc: 99.96, Trg Train Acc: 98.57, Src Test Acc: 99.61, Trg Test Acc: 94.62
# Epoch: 486, TotalL: 0.3407, CrossE: 0.0040, CondE: 0.0399, disc: 0.6719, domain: 0.7693, Src VAT: 0.0147, Trg VAT: 0.0399, Src MixUp: 0.2260, Trg MixUp: 0.3518, Src Train Acc: 99.96, Trg Train Acc: 98.18, Src Test Acc: 98.83, Trg Test Acc: 92.95
# Epoch: 487, TotalL: 0.3786, CrossE: 0.0072, CondE: 0.0483, disc: 0.6731, domain: 0.7713, Src VAT: 0.0202, Trg VAT: 0.0483, Src MixUp: 0.2521, Trg MixUp: 0.3695, Src Train Acc: 99.91, Trg Train Acc: 97.96, Src Test Acc: 99.22, Trg Test Acc: 95.70
# Epoch: 488, TotalL: 0.3742, CrossE: 0.0066, CondE: 0.0460, disc: 0.6719, domain: 0.7687, Src VAT: 0.0182, Trg VAT: 0.0460, Src MixUp: 0.2520, Trg MixUp: 0.3559, Src Train Acc: 99.87, Trg Train Acc: 98.22, Src Test Acc: 95.33, Trg Test Acc: 89.36
# Epoch: 489, TotalL: 0.3746, CrossE: 0.0092, CondE: 0.0494, disc: 0.6755, domain: 0.7652, Src VAT: 0.0205, Trg VAT: 0.0494, Src MixUp: 0.2477, Trg MixUp: 0.3510, Src Train Acc: 99.70, Trg Train Acc: 97.70, Src Test Acc: 100.00, Trg Test Acc: 97.46
# Epoch: 490, TotalL: 0.3632, CrossE: 0.0057, CondE: 0.0471, disc: 0.6743, domain: 0.7604, Src VAT: 0.0180, Trg VAT: 0.0471, Src MixUp: 0.2428, Trg MixUp: 0.3543, Src Train Acc: 99.87, Trg Train Acc: 97.83, Src Test Acc: 100.00, Trg Test Acc: 97.60
# Epoch: 491, TotalL: 0.3610, CrossE: 0.0047, CondE: 0.0443, disc: 0.6701, domain: 0.7690, Src VAT: 0.0165, Trg VAT: 0.0443, Src MixUp: 0.2440, Trg MixUp: 0.3391, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 98.44, Trg Test Acc: 94.91
# Epoch: 492, TotalL: 0.3865, CrossE: 0.0081, CondE: 0.0471, disc: 0.6725, domain: 0.7699, Src VAT: 0.0220, Trg VAT: 0.0471, Src MixUp: 0.2580, Trg MixUp: 0.3657, Src Train Acc: 99.87, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 96.35
# Epoch: 493, TotalL: 0.3550, CrossE: 0.0033, CondE: 0.0409, disc: 0.6713, domain: 0.7626, Src VAT: 0.0148, Trg VAT: 0.0409, Src MixUp: 0.2425, Trg MixUp: 0.3352, Src Train Acc: 100.00, Trg Train Acc: 98.26, Src Test Acc: 99.22, Trg Test Acc: 95.67
# Epoch: 494, TotalL: 0.3527, CrossE: 0.0046, CondE: 0.0433, disc: 0.6730, domain: 0.7635, Src VAT: 0.0169, Trg VAT: 0.0433, Src MixUp: 0.2352, Trg MixUp: 0.3503, Src Train Acc: 99.96, Trg Train Acc: 98.26, Src Test Acc: 98.44, Trg Test Acc: 91.26
# Epoch: 495, TotalL: 0.3721, CrossE: 0.0044, CondE: 0.0452, disc: 0.6651, domain: 0.7673, Src VAT: 0.0170, Trg VAT: 0.0452, Src MixUp: 0.2530, Trg MixUp: 0.3646, Src Train Acc: 99.96, Trg Train Acc: 98.05, Src Test Acc: 100.00, Trg Test Acc: 97.60
# Epoch: 496, TotalL: 0.4096, CrossE: 0.0077, CondE: 0.0448, disc: 0.6699, domain: 0.7630, Src VAT: 0.0229, Trg VAT: 0.0448, Src MixUp: 0.2812, Trg MixUp: 0.3710, Src Train Acc: 99.83, Trg Train Acc: 98.26, Src Test Acc: 98.83, Trg Test Acc: 93.39
# Epoch: 497, TotalL: 0.3743, CrossE: 0.0059, CondE: 0.0458, disc: 0.6695, domain: 0.7657, Src VAT: 0.0186, Trg VAT: 0.0458, Src MixUp: 0.2545, Trg MixUp: 0.3330, Src Train Acc: 99.78, Trg Train Acc: 98.18, Src Test Acc: 97.67, Trg Test Acc: 90.00
# Epoch: 498, TotalL: 0.3416, CrossE: 0.0034, CondE: 0.0426, disc: 0.6754, domain: 0.7633, Src VAT: 0.0150, Trg VAT: 0.0426, Src MixUp: 0.2286, Trg MixUp: 0.3336, Src Train Acc: 100.00, Trg Train Acc: 98.22, Src Test Acc: 98.05, Trg Test Acc: 91.90
# Epoch: 499, TotalL: 0.3556, CrossE: 0.0048, CondE: 0.0399, disc: 0.6701, domain: 0.7654, Src VAT: 0.0158, Trg VAT: 0.0399, Src MixUp: 0.2403, Trg MixUp: 0.3383, Src Train Acc: 99.96, Trg Train Acc: 98.61, Src Test Acc: 98.05, Trg Test Acc: 92.19
# Epoch: 500, TotalL: 0.3721, CrossE: 0.0048, CondE: 0.0463, disc: 0.6721, domain: 0.7621, Src VAT: 0.0187, Trg VAT: 0.0463, Src MixUp: 0.2519, Trg MixUp: 0.3537, Src Train Acc: 99.96, Trg Train Acc: 98.52, Src Test Acc: 98.44, Trg Test Acc: 90.67
