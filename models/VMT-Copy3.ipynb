# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='3'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 500
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
disc_activation = 'selu'
gen_activation  = 'relu'
notes           = "updated total_loss to reflect my issue on github, VMT, with gaussian noise" 

log_data = "num_classes-{}_batch_size-{}_train_src_days-{}_train_trg_days-{}_learning_rate-{}_num_hidden-{}_num_features-{}_disc_activation-{}_gen_activation-{}_notes-{}".format(num_classes, 
                                                                                                                                                                                  batch_size, 
                                                                                                                                                                                  train_src_days, 
                                                                                                                                                                                  train_trg_days, 
                                                                                                                                                                                  learning_rate, 
                                                                                                                                                                                  num_hidden, 
                                                                                                                                                                                  num_features,
                                                                                                                                                                                  disc_activation,
                                                                                                                                                                                  gen_activation,
                                                                                                                                                                                  notes)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2565, 128, 1024, 1) (2565, 9) (3420, 128, 1024, 1) (3420, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, num_features, gen_activation)
discriminator  = Discriminator(num_hidden, disc_activation)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    
for epoch in range(epochs):
  global_step.assign_add(1)  
    
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0821 12:50:41.429383 140022178883328 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0821 12:50:46.352362 140022178883328 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/autograph/impl/api.py:255: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 7.1711, CrossE: 2.2007, CondE: 2.1940, disc: 0.6958, domain: 0.6974, Src VAT: 2.1940, Trg VAT: 2.1940, Src MixUp: 2.1940, Trg MixUp: 2.1940, Src Train Acc: 11.02, Trg Train Acc: 11.02, Src Test Acc: 11.28, Trg Test Acc: 11.11
# Epoch: 002, TotalL: 7.1592, CrossE: 2.1914, CondE: 2.1926, disc: 0.7013, domain: 0.7051, Src VAT: 2.1925, Trg VAT: 2.1926, Src MixUp: 2.1926, Trg MixUp: 2.1927, Src Train Acc: 12.07, Trg Train Acc: 11.63, Src Test Acc: 19.46, Trg Test Acc: 19.24
# Epoch: 003, TotalL: 6.8236, CrossE: 2.0605, CondE: 2.0944, disc: 0.7583, domain: 0.7908, Src VAT: 2.0883, Trg VAT: 2.0944, Src MixUp: 2.1075, Trg MixUp: 2.1118, Src Train Acc: 17.80, Trg Train Acc: 18.66, Src Test Acc: 25.68, Trg Test Acc: 21.29
# Epoch: 004, TotalL: 6.0033, CrossE: 1.7703, CondE: 1.8289, disc: 0.7664, domain: 0.7894, Src VAT: 1.8239, Trg VAT: 1.8289, Src MixUp: 1.9017, Trg MixUp: 1.8941, Src Train Acc: 28.91, Trg Train Acc: 30.25, Src Test Acc: 29.96, Trg Test Acc: 29.65
# Epoch: 005, TotalL: 5.3191, CrossE: 1.5434, CondE: 1.6027, disc: 0.7710, domain: 0.7951, Src VAT: 1.6058, Trg VAT: 1.6027, Src MixUp: 1.7135, Trg MixUp: 1.7030, Src Train Acc: 40.49, Trg Train Acc: 37.11, Src Test Acc: 31.91, Trg Test Acc: 28.10
# Epoch: 043, TotalL: 1.1879, CrossE: 0.1694, CondE: 0.3149, disc: 0.6542, domain: 0.8887, Src VAT: 0.2607, Trg VAT: 0.3149, Src MixUp: 0.5857, Trg MixUp: 0.6331, Src Train Acc: 94.31, Trg Train Acc: 88.80, Src Test Acc: 92.22, Trg Test Acc: 88.10
# Epoch: 044, TotalL: 1.1556, CrossE: 0.1679, CondE: 0.3000, disc: 0.6626, domain: 0.8778, Src VAT: 0.2505, Trg VAT: 0.3000, Src MixUp: 0.5691, Trg MixUp: 0.6231, Src Train Acc: 94.79, Trg Train Acc: 87.80, Src Test Acc: 83.66, Trg Test Acc: 80.64
# Epoch: 045, TotalL: 1.1530, CrossE: 0.1562, CondE: 0.2950, disc: 0.6585, domain: 0.8784, Src VAT: 0.2443, Trg VAT: 0.2950, Src MixUp: 0.5845, Trg MixUp: 0.6315, Src Train Acc: 95.57, Trg Train Acc: 88.67, Src Test Acc: 91.44, Trg Test Acc: 88.45
# Epoch: 046, TotalL: 1.1307, CrossE: 0.1468, CondE: 0.3054, disc: 0.6520, domain: 0.8825, Src VAT: 0.2396, Trg VAT: 0.3054, Src MixUp: 0.5733, Trg MixUp: 0.6433, Src Train Acc: 95.23, Trg Train Acc: 88.59, Src Test Acc: 91.44, Trg Test Acc: 87.81
# Epoch: 047, TotalL: 1.1153, CrossE: 0.1554, CondE: 0.2869, disc: 0.6585, domain: 0.8872, Src VAT: 0.2325, Trg VAT: 0.2869, Src MixUp: 0.5617, Trg MixUp: 0.6092, Src Train Acc: 95.53, Trg Train Acc: 89.11, Src Test Acc: 87.16, Trg Test Acc: 85.73
# Epoch: 048, TotalL: 1.0759, CrossE: 0.1302, CondE: 0.2818, disc: 0.6472, domain: 0.8948, Src VAT: 0.2231, Trg VAT: 0.2818, Src MixUp: 0.5559, Trg MixUp: 0.6254, Src Train Acc: 96.22, Trg Train Acc: 89.80, Src Test Acc: 89.49, Trg Test Acc: 86.40
# Epoch: 049, TotalL: 1.1007, CrossE: 0.1496, CondE: 0.2791, disc: 0.6511, domain: 0.8927, Src VAT: 0.2336, Trg VAT: 0.2791, Src MixUp: 0.5524, Trg MixUp: 0.6130, Src Train Acc: 95.79, Trg Train Acc: 88.98, Src Test Acc: 89.88, Trg Test Acc: 87.08
# Epoch: 050, TotalL: 1.0773, CrossE: 0.1347, CondE: 0.2750, disc: 0.6487, domain: 0.9036, Src VAT: 0.2160, Trg VAT: 0.2750, Src MixUp: 0.5614, Trg MixUp: 0.6127, Src Train Acc: 96.01, Trg Train Acc: 89.11, Src Test Acc: 89.11, Trg Test Acc: 85.18
# Epoch: 051, TotalL: 1.0589, CrossE: 0.1356, CondE: 0.2743, disc: 0.6493, domain: 0.9007, Src VAT: 0.2191, Trg VAT: 0.2743, Src MixUp: 0.5405, Trg MixUp: 0.5973, Src Train Acc: 96.01, Trg Train Acc: 90.41, Src Test Acc: 91.83, Trg Test Acc: 86.81
# Epoch: 136, TotalL: 0.5491, CrossE: 0.0303, CondE: 0.1141, disc: 0.6527, domain: 0.8328, Src VAT: 0.0629, Trg VAT: 0.1141, Src MixUp: 0.3380, Trg MixUp: 0.4122, Src Train Acc: 99.22, Trg Train Acc: 95.10, Src Test Acc: 96.11, Trg Test Acc: 87.66
# Epoch: 137, TotalL: 0.5543, CrossE: 0.0323, CondE: 0.1220, disc: 0.6572, domain: 0.8267, Src VAT: 0.0633, Trg VAT: 0.1220, Src MixUp: 0.3401, Trg MixUp: 0.4112, Src Train Acc: 99.22, Trg Train Acc: 94.75, Src Test Acc: 96.50, Trg Test Acc: 88.04
# Epoch: 138, TotalL: 0.5779, CrossE: 0.0297, CondE: 0.1443, disc: 0.6538, domain: 0.8350, Src VAT: 0.0715, Trg VAT: 0.1443, Src MixUp: 0.3503, Trg MixUp: 0.4563, Src Train Acc: 99.26, Trg Train Acc: 93.40, Src Test Acc: 99.22, Trg Test Acc: 95.09
# Epoch: 139, TotalL: 0.5333, CrossE: 0.0320, CondE: 0.1207, disc: 0.6518, domain: 0.8412, Src VAT: 0.0602, Trg VAT: 0.1207, Src MixUp: 0.3219, Trg MixUp: 0.4087, Src Train Acc: 99.18, Trg Train Acc: 95.49, Src Test Acc: 98.83, Trg Test Acc: 93.36
# Epoch: 140, TotalL: 0.5525, CrossE: 0.0249, CondE: 0.1208, disc: 0.6480, domain: 0.8449, Src VAT: 0.0605, Trg VAT: 0.1208, Src MixUp: 0.3489, Trg MixUp: 0.3917, Src Train Acc: 99.52, Trg Train Acc: 94.31, Src Test Acc: 98.44, Trg Test Acc: 91.96
# Epoch: 141, TotalL: 0.5239, CrossE: 0.0289, CondE: 0.1086, disc: 0.6515, domain: 0.8478, Src VAT: 0.0606, Trg VAT: 0.1086, Src MixUp: 0.3169, Trg MixUp: 0.4041, Src Train Acc: 99.00, Trg Train Acc: 94.92, Src Test Acc: 96.11, Trg Test Acc: 92.16
# Epoch: 142, TotalL: 0.5235, CrossE: 0.0357, CondE: 0.1125, disc: 0.6563, domain: 0.8377, Src VAT: 0.0645, Trg VAT: 0.1125, Src MixUp: 0.3066, Trg MixUp: 0.3965, Src Train Acc: 99.09, Trg Train Acc: 94.44, Src Test Acc: 94.55, Trg Test Acc: 90.09
# Epoch: 143, TotalL: 0.5269, CrossE: 0.0268, CondE: 0.1101, disc: 0.6510, domain: 0.8315, Src VAT: 0.0570, Trg VAT: 0.1101, Src MixUp: 0.3260, Trg MixUp: 0.4136, Src Train Acc: 99.22, Trg Train Acc: 94.62, Src Test Acc: 98.83, Trg Test Acc: 90.44
# Epoch: 144, TotalL: 0.5135, CrossE: 0.0229, CondE: 0.1179, disc: 0.6528, domain: 0.8416, Src VAT: 0.0559, Trg VAT: 0.1179, Src MixUp: 0.3152, Trg MixUp: 0.4156, Src Train Acc: 99.44, Trg Train Acc: 94.44, Src Test Acc: 98.05, Trg Test Acc: 94.39
# Epoch: 164, TotalL: 0.4720, CrossE: 0.0204, CondE: 0.0983, disc: 0.6502, domain: 0.8482, Src VAT: 0.0443, Trg VAT: 0.0983, Src MixUp: 0.2934, Trg MixUp: 0.3791, Src Train Acc: 99.44, Trg Train Acc: 95.66, Src Test Acc: 89.88, Trg Test Acc: 84.09
# Epoch: 165, TotalL: 0.5300, CrossE: 0.0246, CondE: 0.1118, disc: 0.6581, domain: 0.8351, Src VAT: 0.0604, Trg VAT: 0.1118, Src MixUp: 0.3272, Trg MixUp: 0.4138, Src Train Acc: 99.44, Trg Train Acc: 94.92, Src Test Acc: 98.05, Trg Test Acc: 90.35
# Epoch: 166, TotalL: 0.5188, CrossE: 0.0185, CondE: 0.1077, disc: 0.6546, domain: 0.8272, Src VAT: 0.0539, Trg VAT: 0.1077, Src MixUp: 0.3321, Trg MixUp: 0.3869, Src Train Acc: 99.61, Trg Train Acc: 95.18, Src Test Acc: 97.28, Trg Test Acc: 93.83
# Epoch: 167, TotalL: 0.4621, CrossE: 0.0142, CondE: 0.1001, disc: 0.6509, domain: 0.8379, Src VAT: 0.0439, Trg VAT: 0.1001, Src MixUp: 0.2891, Trg MixUp: 0.3987, Src Train Acc: 99.74, Trg Train Acc: 95.83, Src Test Acc: 97.67, Trg Test Acc: 91.90
# Epoch: 168, TotalL: 0.5054, CrossE: 0.0180, CondE: 0.1128, disc: 0.6561, domain: 0.8289, Src VAT: 0.0538, Trg VAT: 0.1128, Src MixUp: 0.3183, Trg MixUp: 0.3864, Src Train Acc: 99.61, Trg Train Acc: 95.70, Src Test Acc: 99.22, Trg Test Acc: 94.04
# Epoch: 169, TotalL: 0.5079, CrossE: 0.0238, CondE: 0.1134, disc: 0.6590, domain: 0.8293, Src VAT: 0.0535, Trg VAT: 0.1134, Src MixUp: 0.3150, Trg MixUp: 0.3889, Src Train Acc: 99.31, Trg Train Acc: 95.57, Src Test Acc: 99.61, Trg Test Acc: 94.30
# Epoch: 170, TotalL: 0.5112, CrossE: 0.0218, CondE: 0.0993, disc: 0.6529, domain: 0.8360, Src VAT: 0.0522, Trg VAT: 0.0993, Src MixUp: 0.3219, Trg MixUp: 0.4053, Src Train Acc: 99.44, Trg Train Acc: 95.18, Src Test Acc: 98.44, Trg Test Acc: 93.39
# Epoch: 171, TotalL: 0.4862, CrossE: 0.0211, CondE: 0.1062, disc: 0.6527, domain: 0.8370, Src VAT: 0.0489, Trg VAT: 0.1062, Src MixUp: 0.3015, Trg MixUp: 0.3846, Src Train Acc: 99.44, Trg Train Acc: 95.36, Src Test Acc: 98.83, Trg Test Acc: 93.25
# Epoch: 172, TotalL: 0.4517, CrossE: 0.0141, CondE: 0.0973, disc: 0.6541, domain: 0.8362, Src VAT: 0.0396, Trg VAT: 0.0973, Src MixUp: 0.2849, Trg MixUp: 0.3829, Src Train Acc: 99.70, Trg Train Acc: 96.05, Src Test Acc: 97.28, Trg Test Acc: 92.63
# Epoch: 173, TotalL: 0.4899, CrossE: 0.0254, CondE: 0.1016, disc: 0.6660, domain: 0.8216, Src VAT: 0.0493, Trg VAT: 0.1016, Src MixUp: 0.3028, Trg MixUp: 0.3806, Src Train Acc: 99.22, Trg Train Acc: 94.92, Src Test Acc: 98.44, Trg Test Acc: 94.77
# Epoch: 174, TotalL: 0.5153, CrossE: 0.0241, CondE: 0.1050, disc: 0.6575, domain: 0.8184, Src VAT: 0.0555, Trg VAT: 0.1050, Src MixUp: 0.3230, Trg MixUp: 0.3797, Src Train Acc: 99.44, Trg Train Acc: 94.75, Src Test Acc: 98.83, Trg Test Acc: 93.39
# Epoch: 175, TotalL: 0.5062, CrossE: 0.0204, CondE: 0.1163, disc: 0.6588, domain: 0.8173, Src VAT: 0.0517, Trg VAT: 0.1163, Src MixUp: 0.3191, Trg MixUp: 0.3888, Src Train Acc: 99.39, Trg Train Acc: 95.27, Src Test Acc: 96.50, Trg Test Acc: 94.15
# Epoch: 176, TotalL: 0.4179, CrossE: 0.0184, CondE: 0.0808, disc: 0.6492, domain: 0.8414, Src VAT: 0.0395, Trg VAT: 0.0808, Src MixUp: 0.2511, Trg MixUp: 0.3577, Src Train Acc: 99.57, Trg Train Acc: 95.62, Src Test Acc: 97.67, Trg Test Acc: 91.08
# Epoch: 177, TotalL: 0.4868, CrossE: 0.0287, CondE: 0.0957, disc: 0.6609, domain: 0.8278, Src VAT: 0.0519, Trg VAT: 0.0957, Src MixUp: 0.2938, Trg MixUp: 0.3852, Src Train Acc: 99.35, Trg Train Acc: 95.18, Src Test Acc: 98.83, Trg Test Acc: 92.11
# Epoch: 178, TotalL: 0.4345, CrossE: 0.0157, CondE: 0.0833, disc: 0.6518, domain: 0.8380, Src VAT: 0.0392, Trg VAT: 0.0833, Src MixUp: 0.2690, Trg MixUp: 0.3770, Src Train Acc: 99.61, Trg Train Acc: 95.88, Src Test Acc: 99.22, Trg Test Acc: 93.98
# Epoch: 179, TotalL: 0.4747, CrossE: 0.0245, CondE: 0.0945, disc: 0.6590, domain: 0.8322, Src VAT: 0.0473, Trg VAT: 0.0945, Src MixUp: 0.2910, Trg MixUp: 0.3782, Src Train Acc: 99.26, Trg Train Acc: 95.57, Src Test Acc: 98.83, Trg Test Acc: 92.89
# Epoch: 180, TotalL: 0.5196, CrossE: 0.0280, CondE: 0.1143, disc: 0.6583, domain: 0.8197, Src VAT: 0.0539, Trg VAT: 0.1143, Src MixUp: 0.3221, Trg MixUp: 0.3960, Src Train Acc: 99.39, Trg Train Acc: 95.44, Src Test Acc: 99.22, Trg Test Acc: 95.23
# Epoch: 181, TotalL: 0.4620, CrossE: 0.0193, CondE: 0.0913, disc: 0.6544, domain: 0.8225, Src VAT: 0.0428, Trg VAT: 0.0913, Src MixUp: 0.2889, Trg MixUp: 0.3834, Src Train Acc: 99.44, Trg Train Acc: 96.05, Src Test Acc: 98.83, Trg Test Acc: 91.67
# Epoch: 182, TotalL: 0.4461, CrossE: 0.0193, CondE: 0.0946, disc: 0.6612, domain: 0.8265, Src VAT: 0.0427, Trg VAT: 0.0946, Src MixUp: 0.2728, Trg MixUp: 0.3752, Src Train Acc: 99.57, Trg Train Acc: 95.96, Src Test Acc: 96.89, Trg Test Acc: 90.88
# Epoch: 183, TotalL: 0.4530, CrossE: 0.0203, CondE: 0.0954, disc: 0.6583, domain: 0.8154, Src VAT: 0.0389, Trg VAT: 0.0954, Src MixUp: 0.2820, Trg MixUp: 0.3907, Src Train Acc: 99.35, Trg Train Acc: 95.66, Src Test Acc: 96.89, Trg Test Acc: 93.33
# Epoch: 184, TotalL: 0.4881, CrossE: 0.0166, CondE: 0.0982, disc: 0.6603, domain: 0.8151, Src VAT: 0.0465, Trg VAT: 0.0982, Src MixUp: 0.3132, Trg MixUp: 0.3857, Src Train Acc: 99.57, Trg Train Acc: 95.49, Src Test Acc: 98.83, Trg Test Acc: 93.19
# Epoch: 185, TotalL: 0.4572, CrossE: 0.0239, CondE: 0.0905, disc: 0.6596, domain: 0.8270, Src VAT: 0.0425, Trg VAT: 0.0905, Src MixUp: 0.2795, Trg MixUp: 0.3839, Src Train Acc: 99.44, Trg Train Acc: 95.83, Src Test Acc: 99.22, Trg Test Acc: 94.24
# Epoch: 186, TotalL: 0.4606, CrossE: 0.0207, CondE: 0.0877, disc: 0.6581, domain: 0.8178, Src VAT: 0.0425, Trg VAT: 0.0877, Src MixUp: 0.2879, Trg MixUp: 0.3750, Src Train Acc: 99.35, Trg Train Acc: 96.27, Src Test Acc: 98.83, Trg Test Acc: 92.49
# Epoch: 187, TotalL: 0.4547, CrossE: 0.0185, CondE: 0.0921, disc: 0.6608, domain: 0.8230, Src VAT: 0.0423, Trg VAT: 0.0921, Src MixUp: 0.2820, Trg MixUp: 0.3906, Src Train Acc: 99.44, Trg Train Acc: 95.88, Src Test Acc: 96.50, Trg Test Acc: 94.12
# Epoch: 188, TotalL: 0.4727, CrossE: 0.0194, CondE: 0.0865, disc: 0.6572, domain: 0.8220, Src VAT: 0.0459, Trg VAT: 0.0865, Src MixUp: 0.2974, Trg MixUp: 0.3787, Src Train Acc: 99.48, Trg Train Acc: 95.62, Src Test Acc: 99.22, Trg Test Acc: 93.71
# Epoch: 189, TotalL: 0.4610, CrossE: 0.0252, CondE: 0.0896, disc: 0.6579, domain: 0.8183, Src VAT: 0.0435, Trg VAT: 0.0896, Src MixUp: 0.2828, Trg MixUp: 0.3712, Src Train Acc: 99.44, Trg Train Acc: 95.49, Src Test Acc: 97.67, Trg Test Acc: 95.58
# Epoch: 190, TotalL: 0.4400, CrossE: 0.0186, CondE: 0.0839, disc: 0.6595, domain: 0.8221, Src VAT: 0.0395, Trg VAT: 0.0839, Src MixUp: 0.2726, Trg MixUp: 0.3764, Src Train Acc: 99.57, Trg Train Acc: 96.35, Src Test Acc: 98.44, Trg Test Acc: 96.02
# Epoch: 191, TotalL: 0.4711, CrossE: 0.0195, CondE: 0.0883, disc: 0.6625, domain: 0.8119, Src VAT: 0.0461, Trg VAT: 0.0883, Src MixUp: 0.2946, Trg MixUp: 0.3976, Src Train Acc: 99.52, Trg Train Acc: 95.92, Src Test Acc: 98.05, Trg Test Acc: 94.65
# ...
# Epoch: 436, TotalL: 0.2576, CrossE: 0.0042, CondE: 0.0301, disc: 0.6707, domain: 0.7689, Src VAT: 0.0105, Trg VAT: 0.0301, Src MixUp: 0.1559, Trg MixUp: 0.2584, Src Train Acc: 99.96, Trg Train Acc: 97.70, Src Test Acc: 98.83, Trg Test Acc: 94.27
# Epoch: 437, TotalL: 0.2956, CrossE: 0.0110, CondE: 0.0378, disc: 0.6777, domain: 0.7611, Src VAT: 0.0168, Trg VAT: 0.0378, Src MixUp: 0.1797, Trg MixUp: 0.2649, Src Train Acc: 99.48, Trg Train Acc: 97.09, Src Test Acc: 98.44, Trg Test Acc: 94.71
# Epoch: 438, TotalL: 0.2920, CrossE: 0.0119, CondE: 0.0363, disc: 0.6724, domain: 0.7657, Src VAT: 0.0150, Trg VAT: 0.0363, Src MixUp: 0.1777, Trg MixUp: 0.2530, Src Train Acc: 99.78, Trg Train Acc: 97.61, Src Test Acc: 98.05, Trg Test Acc: 92.92
# Epoch: 439, TotalL: 0.2619, CrossE: 0.0063, CondE: 0.0306, disc: 0.6710, domain: 0.7673, Src VAT: 0.0106, Trg VAT: 0.0306, Src MixUp: 0.1569, Trg MixUp: 0.2732, Src Train Acc: 99.87, Trg Train Acc: 97.14, Src Test Acc: 98.05, Trg Test Acc: 94.21
# Epoch: 440, TotalL: 0.2733, CrossE: 0.0090, CondE: 0.0315, disc: 0.6718, domain: 0.7668, Src VAT: 0.0125, Trg VAT: 0.0315, Src MixUp: 0.1644, Trg MixUp: 0.2634, Src Train Acc: 99.74, Trg Train Acc: 97.66, Src Test Acc: 98.05, Trg Test Acc: 93.60
# Epoch: 441, TotalL: 0.2975, CrossE: 0.0073, CondE: 0.0390, disc: 0.6742, domain: 0.7644, Src VAT: 0.0145, Trg VAT: 0.0390, Src MixUp: 0.1849, Trg MixUp: 0.2920, Src Train Acc: 99.74, Trg Train Acc: 97.40, Src Test Acc: 98.05, Trg Test Acc: 94.33
# Epoch: 442, TotalL: 0.2677, CrossE: 0.0064, CondE: 0.0321, disc: 0.6734, domain: 0.7615, Src VAT: 0.0125, Trg VAT: 0.0321, Src MixUp: 0.1625, Trg MixUp: 0.2522, Src Train Acc: 99.78, Trg Train Acc: 97.57, Src Test Acc: 99.61, Trg Test Acc: 95.20
# Epoch: 443, TotalL: 0.2679, CrossE: 0.0061, CondE: 0.0301, disc: 0.6724, domain: 0.7708, Src VAT: 0.0136, Trg VAT: 0.0301, Src MixUp: 0.1611, Trg MixUp: 0.2582, Src Train Acc: 99.87, Trg Train Acc: 97.31, Src Test Acc: 98.05, Trg Test Acc: 94.62
# Epoch: 444, TotalL: 0.2787, CrossE: 0.0039, CondE: 0.0283, disc: 0.6764, domain: 0.7563, Src VAT: 0.0128, Trg VAT: 0.0283, Src MixUp: 0.1764, Trg MixUp: 0.2570, Src Train Acc: 99.96, Trg Train Acc: 97.57, Src Test Acc: 97.67, Trg Test Acc: 92.28
# Epoch: 445, TotalL: 0.2685, CrossE: 0.0032, CondE: 0.0265, disc: 0.6720, domain: 0.7582, Src VAT: 0.0100, Trg VAT: 0.0265, Src MixUp: 0.1690, Trg MixUp: 0.2675, Src Train Acc: 99.91, Trg Train Acc: 97.92, Src Test Acc: 99.61, Trg Test Acc: 96.73
# Epoch: 446, TotalL: 0.2654, CrossE: 0.0058, CondE: 0.0289, disc: 0.6720, domain: 0.7679, Src VAT: 0.0117, Trg VAT: 0.0289, Src MixUp: 0.1613, Trg MixUp: 0.2577, Src Train Acc: 99.83, Trg Train Acc: 97.87, Src Test Acc: 98.05, Trg Test Acc: 95.18
# Epoch: 447, TotalL: 0.2954, CrossE: 0.0174, CondE: 0.0364, disc: 0.6769, domain: 0.7618, Src VAT: 0.0189, Trg VAT: 0.0364, Src MixUp: 0.1697, Trg MixUp: 0.2823, Src Train Acc: 99.57, Trg Train Acc: 97.27, Src Test Acc: 99.61, Trg Test Acc: 96.81
# Epoch: 448, TotalL: 0.3001, CrossE: 0.0071, CondE: 0.0405, disc: 0.6732, domain: 0.7686, Src VAT: 0.0167, Trg VAT: 0.0405, Src MixUp: 0.1848, Trg MixUp: 0.2935, Src Train Acc: 99.74, Trg Train Acc: 97.05, Src Test Acc: 98.83, Trg Test Acc: 95.88
# Epoch: 449, TotalL: 0.2545, CrossE: 0.0061, CondE: 0.0264, disc: 0.6728, domain: 0.7674, Src VAT: 0.0136, Trg VAT: 0.0264, Src MixUp: 0.1500, Trg MixUp: 0.2395, Src Train Acc: 99.83, Trg Train Acc: 97.83, Src Test Acc: 98.44, Trg Test Acc: 94.09
# Epoch: 450, TotalL: 0.2651, CrossE: 0.0044, CondE: 0.0317, disc: 0.6703, domain: 0.7681, Src VAT: 0.0117, Trg VAT: 0.0317, Src MixUp: 0.1613, Trg MixUp: 0.2645, Src Train Acc: 99.87, Trg Train Acc: 97.35, Src Test Acc: 99.22, Trg Test Acc: 96.73
# Epoch: 451, TotalL: 0.2521, CrossE: 0.0053, CondE: 0.0267, disc: 0.6743, domain: 0.7680, Src VAT: 0.0106, Trg VAT: 0.0267, Src MixUp: 0.1504, Trg MixUp: 0.2514, Src Train Acc: 99.87, Trg Train Acc: 98.31, Src Test Acc: 98.83, Trg Test Acc: 95.09
# Epoch: 452, TotalL: 0.2548, CrossE: 0.0067, CondE: 0.0285, disc: 0.6744, domain: 0.7664, Src VAT: 0.0114, Trg VAT: 0.0285, Src MixUp: 0.1503, Trg MixUp: 0.2564, Src Train Acc: 99.70, Trg Train Acc: 97.83, Src Test Acc: 98.83, Trg Test Acc: 96.64
# Epoch: 453, TotalL: 0.3030, CrossE: 0.0074, CondE: 0.0389, disc: 0.6753, domain: 0.7657, Src VAT: 0.0166, Trg VAT: 0.0389, Src MixUp: 0.1881, Trg MixUp: 0.2946, Src Train Acc: 99.91, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 94.36
# Epoch: 454, TotalL: 0.2414, CrossE: 0.0022, CondE: 0.0250, disc: 0.6713, domain: 0.7646, Src VAT: 0.0084, Trg VAT: 0.0250, Src MixUp: 0.1448, Trg MixUp: 0.2596, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 98.44, Trg Test Acc: 95.91
# Epoch: 455, TotalL: 0.2783, CrossE: 0.0076, CondE: 0.0334, disc: 0.6730, domain: 0.7676, Src VAT: 0.0129, Trg VAT: 0.0334, Src MixUp: 0.1711, Trg MixUp: 0.2481, Src Train Acc: 99.74, Trg Train Acc: 97.35, Src Test Acc: 95.33, Trg Test Acc: 89.85
# Epoch: 456, TotalL: 0.2669, CrossE: 0.0041, CondE: 0.0261, disc: 0.6749, domain: 0.7564, Src VAT: 0.0109, Trg VAT: 0.0261, Src MixUp: 0.1664, Trg MixUp: 0.2609, Src Train Acc: 99.96, Trg Train Acc: 98.00, Src Test Acc: 98.83, Trg Test Acc: 94.30
# Epoch: 457, TotalL: 0.3020, CrossE: 0.0044, CondE: 0.0373, disc: 0.6754, domain: 0.7633, Src VAT: 0.0150, Trg VAT: 0.0373, Src MixUp: 0.1934, Trg MixUp: 0.2764, Src Train Acc: 99.96, Trg Train Acc: 97.83, Src Test Acc: 99.22, Trg Test Acc: 96.29
# Epoch: 458, TotalL: 0.2828, CrossE: 0.0066, CondE: 0.0302, disc: 0.6741, domain: 0.7609, Src VAT: 0.0147, Trg VAT: 0.0302, Src MixUp: 0.1754, Trg MixUp: 0.2543, Src Train Acc: 99.74, Trg Train Acc: 97.66, Src Test Acc: 98.83, Trg Test Acc: 95.32
# Epoch: 459, TotalL: 0.2991, CrossE: 0.0123, CondE: 0.0383, disc: 0.6786, domain: 0.7566, Src VAT: 0.0167, Trg VAT: 0.0383, Src MixUp: 0.1802, Trg MixUp: 0.2908, Src Train Acc: 99.52, Trg Train Acc: 97.53, Src Test Acc: 98.44, Trg Test Acc: 96.08
# Epoch: 460, TotalL: 0.2832, CrossE: 0.0057, CondE: 0.0426, disc: 0.6711, domain: 0.7635, Src VAT: 0.0148, Trg VAT: 0.0426, Src MixUp: 0.1711, Trg MixUp: 0.2957, Src Train Acc: 99.87, Trg Train Acc: 97.22, Src Test Acc: 99.61, Trg Test Acc: 95.76
# Epoch: 461, TotalL: 0.2594, CrossE: 0.0036, CondE: 0.0264, disc: 0.6669, domain: 0.7706, Src VAT: 0.0116, Trg VAT: 0.0264, Src MixUp: 0.1580, Trg MixUp: 0.2542, Src Train Acc: 99.91, Trg Train Acc: 98.00, Src Test Acc: 98.44, Trg Test Acc: 95.26
# Epoch: 462, TotalL: 0.2663, CrossE: 0.0068, CondE: 0.0302, disc: 0.6778, domain: 0.7579, Src VAT: 0.0117, Trg VAT: 0.0302, Src MixUp: 0.1617, Trg MixUp: 0.2577, Src Train Acc: 99.87, Trg Train Acc: 97.53, Src Test Acc: 97.67, Trg Test Acc: 94.04
# Epoch: 463, TotalL: 0.2518, CrossE: 0.0075, CondE: 0.0263, disc: 0.6762, domain: 0.7607, Src VAT: 0.0122, Trg VAT: 0.0263, Src MixUp: 0.1461, Trg MixUp: 0.2609, Src Train Acc: 99.74, Trg Train Acc: 97.61, Src Test Acc: 99.61, Trg Test Acc: 96.58
# Epoch: 464, TotalL: 0.2614, CrossE: 0.0078, CondE: 0.0313, disc: 0.6713, domain: 0.7660, Src VAT: 0.0126, Trg VAT: 0.0313, Src MixUp: 0.1549, Trg MixUp: 0.2478, Src Train Acc: 99.78, Trg Train Acc: 97.79, Src Test Acc: 98.83, Trg Test Acc: 94.77
# Epoch: 465, TotalL: 0.3217, CrossE: 0.0097, CondE: 0.0419, disc: 0.6753, domain: 0.7691, Src VAT: 0.0200, Trg VAT: 0.0419, Src MixUp: 0.2002, Trg MixUp: 0.2939, Src Train Acc: 99.74, Trg Train Acc: 96.57, Src Test Acc: 95.72, Trg Test Acc: 83.95
# Epoch: 466, TotalL: 0.2871, CrossE: 0.0116, CondE: 0.0378, disc: 0.6769, domain: 0.7583, Src VAT: 0.0144, Trg VAT: 0.0378, Src MixUp: 0.1732, Trg MixUp: 0.2656, Src Train Acc: 99.78, Trg Train Acc: 96.83, Src Test Acc: 98.83, Trg Test Acc: 94.39
# Epoch: 467, TotalL: 0.2636, CrossE: 0.0053, CondE: 0.0343, disc: 0.6761, domain: 0.7554, Src VAT: 0.0105, Trg VAT: 0.0343, Src MixUp: 0.1607, Trg MixUp: 0.2649, Src Train Acc: 99.87, Trg Train Acc: 97.79, Src Test Acc: 99.22, Trg Test Acc: 96.49
# Epoch: 468, TotalL: 0.2605, CrossE: 0.0031, CondE: 0.0284, disc: 0.6774, domain: 0.7522, Src VAT: 0.0112, Trg VAT: 0.0284, Src MixUp: 0.1606, Trg MixUp: 0.2614, Src Train Acc: 99.96, Trg Train Acc: 97.87, Src Test Acc: 98.83, Trg Test Acc: 94.39
# Epoch: 469, TotalL: 0.2455, CrossE: 0.0046, CondE: 0.0290, disc: 0.6734, domain: 0.7665, Src VAT: 0.0098, Trg VAT: 0.0290, Src MixUp: 0.1429, Trg MixUp: 0.2776, Src Train Acc: 99.78, Trg Train Acc: 97.79, Src Test Acc: 99.61, Trg Test Acc: 97.43
# Epoch: 470, TotalL: 0.2639, CrossE: 0.0049, CondE: 0.0274, disc: 0.6777, domain: 0.7549, Src VAT: 0.0113, Trg VAT: 0.0274, Src MixUp: 0.1616, Trg MixUp: 0.2672, Src Train Acc: 99.87, Trg Train Acc: 97.96, Src Test Acc: 97.67, Trg Test Acc: 92.75
# Epoch: 471, TotalL: 0.3228, CrossE: 0.0175, CondE: 0.0462, disc: 0.6756, domain: 0.7554, Src VAT: 0.0220, Trg VAT: 0.0462, Src MixUp: 0.1912, Trg MixUp: 0.3039, Src Train Acc: 99.61, Trg Train Acc: 96.05, Src Test Acc: 95.33, Trg Test Acc: 88.16
# Epoch: 472, TotalL: 0.2387, CrossE: 0.0051, CondE: 0.0238, disc: 0.6710, domain: 0.7664, Src VAT: 0.0074, Trg VAT: 0.0238, Src MixUp: 0.1425, Trg MixUp: 0.2324, Src Train Acc: 99.96, Trg Train Acc: 97.83, Src Test Acc: 100.00, Trg Test Acc: 96.90
# Epoch: 473, TotalL: 0.2680, CrossE: 0.0040, CondE: 0.0304, disc: 0.6732, domain: 0.7667, Src VAT: 0.0118, Trg VAT: 0.0304, Src MixUp: 0.1647, Trg MixUp: 0.2666, Src Train Acc: 99.91, Trg Train Acc: 97.74, Src Test Acc: 97.67, Trg Test Acc: 91.87
# Epoch: 474, TotalL: 0.2724, CrossE: 0.0063, CondE: 0.0322, disc: 0.6783, domain: 0.7536, Src VAT: 0.0159, Trg VAT: 0.0322, Src MixUp: 0.1659, Trg MixUp: 0.2350, Src Train Acc: 99.83, Trg Train Acc: 97.70, Src Test Acc: 98.44, Trg Test Acc: 94.74
# Epoch: 475, TotalL: 0.2695, CrossE: 0.0098, CondE: 0.0331, disc: 0.6738, domain: 0.7626, Src VAT: 0.0141, Trg VAT: 0.0331, Src MixUp: 0.1576, Trg MixUp: 0.2712, Src Train Acc: 99.74, Trg Train Acc: 97.74, Src Test Acc: 98.83, Trg Test Acc: 95.32
# Epoch: 476, TotalL: 0.2798, CrossE: 0.0054, CondE: 0.0304, disc: 0.6782, domain: 0.7518, Src VAT: 0.0154, Trg VAT: 0.0304, Src MixUp: 0.1726, Trg MixUp: 0.2660, Src Train Acc: 99.96, Trg Train Acc: 97.92, Src Test Acc: 98.05, Trg Test Acc: 93.39
# Epoch: 477, TotalL: 0.2578, CrossE: 0.0055, CondE: 0.0292, disc: 0.6727, domain: 0.7629, Src VAT: 0.0105, Trg VAT: 0.0292, Src MixUp: 0.1548, Trg MixUp: 0.2655, Src Train Acc: 99.83, Trg Train Acc: 97.48, Src Test Acc: 99.61, Trg Test Acc: 97.19
# Epoch: 478, TotalL: 0.2700, CrossE: 0.0034, CondE: 0.0302, disc: 0.6775, domain: 0.7497, Src VAT: 0.0119, Trg VAT: 0.0302, Src MixUp: 0.1687, Trg MixUp: 0.2651, Src Train Acc: 99.96, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 95.03
# Epoch: 479, TotalL: 0.2962, CrossE: 0.0062, CondE: 0.0347, disc: 0.6731, domain: 0.7619, Src VAT: 0.0172, Trg VAT: 0.0347, Src MixUp: 0.1843, Trg MixUp: 0.2752, Src Train Acc: 99.91, Trg Train Acc: 97.79, Src Test Acc: 97.67, Trg Test Acc: 93.57
# Epoch: 480, TotalL: 0.2634, CrossE: 0.0038, CondE: 0.0280, disc: 0.6728, domain: 0.7727, Src VAT: 0.0127, Trg VAT: 0.0280, Src MixUp: 0.1600, Trg MixUp: 0.2567, Src Train Acc: 99.96, Trg Train Acc: 98.18, Src Test Acc: 97.28, Trg Test Acc: 93.92
# Epoch: 481, TotalL: 0.2316, CrossE: 0.0034, CondE: 0.0216, disc: 0.6770, domain: 0.7589, Src VAT: 0.0082, Trg VAT: 0.0216, Src MixUp: 0.1363, Trg MixUp: 0.2441, Src Train Acc: 99.91, Trg Train Acc: 98.13, Src Test Acc: 97.67, Trg Test Acc: 92.66
# Epoch: 482, TotalL: 0.2887, CrossE: 0.0066, CondE: 0.0337, disc: 0.6774, domain: 0.7559, Src VAT: 0.0131, Trg VAT: 0.0337, Src MixUp: 0.1805, Trg MixUp: 0.2823, Src Train Acc: 99.78, Trg Train Acc: 97.40, Src Test Acc: 97.67, Trg Test Acc: 96.55
# Epoch: 483, TotalL: 0.2709, CrossE: 0.0103, CondE: 0.0340, disc: 0.6776, domain: 0.7547, Src VAT: 0.0155, Trg VAT: 0.0340, Src MixUp: 0.1585, Trg MixUp: 0.2588, Src Train Acc: 99.61, Trg Train Acc: 97.57, Src Test Acc: 95.33, Trg Test Acc: 84.56
# Epoch: 484, TotalL: 0.2695, CrossE: 0.0060, CondE: 0.0314, disc: 0.6745, domain: 0.7590, Src VAT: 0.0133, Trg VAT: 0.0314, Src MixUp: 0.1640, Trg MixUp: 0.2566, Src Train Acc: 99.78, Trg Train Acc: 97.44, Src Test Acc: 99.61, Trg Test Acc: 95.91
# Epoch: 485, TotalL: 0.2575, CrossE: 0.0031, CondE: 0.0272, disc: 0.6775, domain: 0.7543, Src VAT: 0.0099, Trg VAT: 0.0272, Src MixUp: 0.1572, Trg MixUp: 0.2834, Src Train Acc: 99.91, Trg Train Acc: 97.96, Src Test Acc: 99.22, Trg Test Acc: 95.67
# Epoch: 486, TotalL: 0.2617, CrossE: 0.0042, CondE: 0.0301, disc: 0.6800, domain: 0.7489, Src VAT: 0.0113, Trg VAT: 0.0301, Src MixUp: 0.1604, Trg MixUp: 0.2627, Src Train Acc: 99.83, Trg Train Acc: 97.66, Src Test Acc: 98.05, Trg Test Acc: 96.26
# Epoch: 487, TotalL: 0.2596, CrossE: 0.0042, CondE: 0.0281, disc: 0.6762, domain: 0.7544, Src VAT: 0.0097, Trg VAT: 0.0281, Src MixUp: 0.1589, Trg MixUp: 0.2748, Src Train Acc: 99.87, Trg Train Acc: 97.83, Src Test Acc: 98.44, Trg Test Acc: 94.18
# Epoch: 488, TotalL: 0.3063, CrossE: 0.0082, CondE: 0.0373, disc: 0.6760, domain: 0.7564, Src VAT: 0.0174, Trg VAT: 0.0373, Src MixUp: 0.1907, Trg MixUp: 0.2947, Src Train Acc: 99.74, Trg Train Acc: 97.40, Src Test Acc: 99.61, Trg Test Acc: 95.82
# Epoch: 489, TotalL: 0.2985, CrossE: 0.0074, CondE: 0.0370, disc: 0.6764, domain: 0.7591, Src VAT: 0.0161, Trg VAT: 0.0370, Src MixUp: 0.1849, Trg MixUp: 0.2928, Src Train Acc: 99.87, Trg Train Acc: 97.22, Src Test Acc: 99.61, Trg Test Acc: 97.16
# Epoch: 490, TotalL: 0.2578, CrossE: 0.0078, CondE: 0.0298, disc: 0.6787, domain: 0.7564, Src VAT: 0.0118, Trg VAT: 0.0298, Src MixUp: 0.1510, Trg MixUp: 0.2745, Src Train Acc: 99.74, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 95.99
# Epoch: 491, TotalL: 0.2271, CrossE: 0.0021, CondE: 0.0231, disc: 0.6753, domain: 0.7545, Src VAT: 0.0063, Trg VAT: 0.0231, Src MixUp: 0.1340, Trg MixUp: 0.2589, Src Train Acc: 99.91, Trg Train Acc: 97.83, Src Test Acc: 98.44, Trg Test Acc: 91.67
# Epoch: 492, TotalL: 0.2934, CrossE: 0.0066, CondE: 0.0338, disc: 0.6779, domain: 0.7574, Src VAT: 0.0156, Trg VAT: 0.0338, Src MixUp: 0.1816, Trg MixUp: 0.2942, Src Train Acc: 99.78, Trg Train Acc: 97.79, Src Test Acc: 99.22, Trg Test Acc: 94.39
# Epoch: 493, TotalL: 0.2569, CrossE: 0.0030, CondE: 0.0259, disc: 0.6773, domain: 0.7544, Src VAT: 0.0100, Trg VAT: 0.0259, Src MixUp: 0.1597, Trg MixUp: 0.2469, Src Train Acc: 99.96, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 94.97
# Epoch: 494, TotalL: 0.2660, CrossE: 0.0072, CondE: 0.0285, disc: 0.6776, domain: 0.7579, Src VAT: 0.0142, Trg VAT: 0.0285, Src MixUp: 0.1582, Trg MixUp: 0.2642, Src Train Acc: 99.78, Trg Train Acc: 97.53, Src Test Acc: 92.61, Trg Test Acc: 88.22
# Epoch: 495, TotalL: 0.2760, CrossE: 0.0051, CondE: 0.0289, disc: 0.6759, domain: 0.7513, Src VAT: 0.0127, Trg VAT: 0.0289, Src MixUp: 0.1723, Trg MixUp: 0.2655, Src Train Acc: 99.83, Trg Train Acc: 98.00, Src Test Acc: 99.22, Trg Test Acc: 97.11
# Epoch: 496, TotalL: 0.2779, CrossE: 0.0048, CondE: 0.0309, disc: 0.6775, domain: 0.7541, Src VAT: 0.0133, Trg VAT: 0.0309, Src MixUp: 0.1723, Trg MixUp: 0.2772, Src Train Acc: 99.87, Trg Train Acc: 97.74, Src Test Acc: 97.67, Trg Test Acc: 92.66
# Epoch: 497, TotalL: 0.2481, CrossE: 0.0069, CondE: 0.0268, disc: 0.6784, domain: 0.7541, Src VAT: 0.0093, Trg VAT: 0.0268, Src MixUp: 0.1475, Trg MixUp: 0.2483, Src Train Acc: 99.83, Trg Train Acc: 97.96, Src Test Acc: 97.67, Trg Test Acc: 93.33
# Epoch: 498, TotalL: 0.3030, CrossE: 0.0081, CondE: 0.0361, disc: 0.6815, domain: 0.7448, Src VAT: 0.0180, Trg VAT: 0.0361, Src MixUp: 0.1912, Trg MixUp: 0.2528, Src Train Acc: 99.61, Trg Train Acc: 97.35, Src Test Acc: 99.61, Trg Test Acc: 96.61
# Epoch: 499, TotalL: 0.2641, CrossE: 0.0055, CondE: 0.0289, disc: 0.6753, domain: 0.7514, Src VAT: 0.0123, Trg VAT: 0.0289, Src MixUp: 0.1604, Trg MixUp: 0.2641, Src Train Acc: 99.91, Trg Train Acc: 97.70, Src Test Acc: 97.67, Trg Test Acc: 91.64
# Epoch: 500, TotalL: 0.2720, CrossE: 0.0056, CondE: 0.0316, disc: 0.6767, domain: 0.7516, Src VAT: 0.0129, Trg VAT: 0.0316, Src MixUp: 0.1664, Trg MixUp: 0.2747, Src Train Acc: 99.83, Trg Train Acc: 97.79, Src Test Acc: 99.22, Trg Test Acc: 96.02
