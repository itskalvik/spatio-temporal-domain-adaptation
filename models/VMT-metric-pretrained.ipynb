# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='2'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 1000
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
alpha           = 0.05
disc_activation = 'selu'
gen_activation  = 'selu'
notes           = "VMT_gauss_noise_cv_data_center_loss_pretrained_init" 

log_data = "num_classes-{}_batch_size-{}_train_src_days-{}_train_trg_days-{}_lr-{}_num_hidden-{}_num_features-{}_disc_act-{}_gen_act-{}_center_alpha-{}_notes-{}".format(num_classes, 
                                                                                                                                                                                  batch_size, 
                                                                                                                                                                                  train_src_days, 
                                                                                                                                                                                  train_trg_days, 
                                                                                                                                                                                  learning_rate, 
                                                                                                                                                                                  num_hidden, 
                                                                                                                                                                                  num_features,
                                                                                                                                                                                  disc_activation,
                                                                                                                                                                                  gen_activation,
                                                                                                                                                                                  alpha,
                                                                                                                                                                                  notes)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
classes = [n.decode("ascii", "ignore") for n in classes]
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9127, 128, 1024, 1) (9127, 2)
#  ['arahman3', 'harika', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8737, 128, 1024, 1) (8737, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8547, 128, 1024, 1) (8547, 2)
#  ['arahman3', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2563, 128, 1024, 1) (2563, 9) (3419, 128, 1024, 1) (3419, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2563, 128, 1024, 1) (2563, 9) (3419, 128, 1024, 1) (3419, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/target_conf_data.h5', 'r')
X_data_conf = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data_conf = np.array(hf.get('y_data')).astype(np.int32)
classes_conf = list(hf.get('classes'))
classes_conf = [n.decode("ascii", "ignore") for n in classes_conf]
hf.close()

#map labels to source dataset labels
y_data_conf = np.array([classes.index(classes_conf[y_data_conf[i, 0]]) for i in range(y_data_conf.shape[0])])
y_data_conf = np.eye(len(classes))[y_data_conf]

print(X_data_conf.shape, y_data_conf.shape)

#standardise dataset
conf_mean = np.mean(X_data_conf)
X_data_conf -= conf_mean
conf_std  = np.std(X_data_conf)
X_data_conf /= conf_std

conf_test_set = tf.data.Dataset.from_tensor_slices((X_data_conf, y_data_conf))
conf_test_set = conf_test_set.batch(batch_size, drop_remainder=False)
conf_test_set = conf_test_set.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# (1350, 128, 1024, 1) (1350, 9)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/target_server_data.h5', 'r')
X_data_server = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data_server = np.array(hf.get('y_data')).astype(np.int32)
classes_server = list(hf.get('classes'))
classes_server = [n.decode("ascii", "ignore") for n in classes_server]
hf.close()

#map labels to source dataset labels
y_data_server = np.array([classes.index(classes_server[y_data_server[i, 0]]) for i in range(y_data_server.shape[0])])
y_data_server = np.eye(len(classes))[y_data_server]

print(X_data_server.shape, y_data_server.shape)

#standardise dataset
server_mean = np.mean(X_data_server)
X_data_server -= server_mean
server_std  = np.std(X_data_server)
X_data_server /= server_std

server_test_set = tf.data.Dataset.from_tensor_slices((X_data_server, y_data_server))
server_test_set = server_test_set.batch(batch_size, drop_remainder=False)
server_test_set = server_test_set.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# (1346, 128, 1024, 1) (1346, 9)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/target_office_data.h5', 'r')
X_data_office = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data_office = np.array(hf.get('y_data')).astype(np.int32)
classes_office = list(hf.get('classes'))
classes_office = [n.decode("ascii", "ignore") for n in classes_office]
hf.close()

#map labels to source dataset labels
y_data_office = np.array([classes.index(classes_office[y_data_office[i, 0]]) for i in range(y_data_office.shape[0])])
y_data_office = np.eye(len(classes))[y_data_office]

print(X_data_office.shape, y_data_office.shape)

#standardise dataset
office_mean = np.mean(X_data_office)
X_data_office -= office_mean
office_std  = np.std(X_data_office)
X_data_office /= office_std

office_test_set = tf.data.Dataset.from_tensor_slices((X_data_office, y_data_office))
office_test_set = office_test_set.batch(batch_size, drop_remainder=False)
office_test_set = office_test_set.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# (899, 128, 1024, 1) (899, 9)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

class CenterLoss():
    def __init__(self, batch_size, num_classes, len_features, alpha):
      self.centers = tf.Variable(tf.zeros([num_classes, len_features]),
                                 dtype=tf.float32,
                                 trainable=False)
      self.alpha = alpha
      self.num_classes = num_classes
      self.batch_size = batch_size    
      self.margin = tf.constant(100, dtype="float32")
      self.norm = lambda x: tf.reduce_sum(tf.square(x), 1)
      self.EdgeWeights = tf.ones((self.num_classes,self.num_classes)) - \
                                  tf.eye(self.num_classes)

    def get_center_loss(self, features, labels):
      labels = tf.reshape(tf.argmax(labels, axis=-1), [-1])
      centers0 = tf.math.unsorted_segment_mean(features, 
                                               labels, 
                                               self.num_classes)
      center_pairwise_dist = tf.transpose(self.norm(tf.expand_dims(centers0, 2) - \
                                                    tf.transpose(centers0)))
      self.inter_loss = tf.math.reduce_sum(tf.multiply(tf.maximum(0.0, self.margin - center_pairwise_dist), 
                                                       self.EdgeWeights))

      unique_label, unique_idx, unique_count = tf.unique_with_counts(labels)
      appear_times = tf.gather(unique_count, unique_idx)
      appear_times = tf.reshape(appear_times, [-1, 1])
      centers_batch = tf.gather(self.centers, labels)
      diff = centers_batch - features
      diff /= tf.cast((1 + appear_times), tf.float32)
      diff *= self.alpha
      self.centers_update_op = tf.compat.v1.scatter_sub(self.centers, 
                                                        labels, 
                                                        diff)

      self.intra_loss   = tf.nn.l2_loss(features - centers_batch)
      self.center_loss  = self.intra_loss + self.inter_loss
      self.center_loss /= (self.num_classes*self.batch_size+self.num_classes*self.num_classes)
      return self.center_loss
      
def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
office_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='office_test_accuracy')
server_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='server_test_accuracy')
conf_test_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='conf_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)
    batch_center_loss   = center_loss.get_center_loss(src_enc, src_labels)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss + \
                 1    * batch_center_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  with tf.control_dependencies([center_loss.centers_update_op]):
    gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)
  
@tf.function
def test_office_step(office_images, office_labels):
  office_logits, _ = generator(office_images, training=False)
  office_test_accuracy(office_labels, office_logits)
  
@tf.function
def test_server_step(server_images, server_labels):
  server_logits, _ = generator(server_images, training=False)
  server_test_accuracy(server_labels, server_logits)
  
@tf.function
def test_conf_step(conf_images, conf_labels):
  conf_logits, _ = generator(conf_images, training=False)
  conf_test_accuracy(conf_labels, conf_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}, Server Test Acc: {:.2f}, Office Test Acc: {:.2f}, Conf Test Acc: {:.2f}'

generator      = ResNet50(14, num_features, gen_activation)
generator.load_weights("../checkpoints/resnet_pretrained_epoch-200_test_accuracy-96.40")
inputs = tf.keras.layers.Input((128, 1024, 1))
x = generator.layers[0](inputs)
for i in range(1, len(generator.layers)-1):
  x = generator.layers[i](x)
logits = tf.keras.layers.Dense(num_classes, activation=None, name="logits")(x)
generator = tf.keras.models.Model(inputs, [logits, x])

discriminator  = Discriminator(num_hidden, disc_activation)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
center_loss    = CenterLoss(batch_size, num_classes, num_features, alpha)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    tf.contrib.summary.scalar("office_test_accuracy", office_test_accuracy.result())
    tf.contrib.summary.scalar("server_test_accuracy", server_test_accuracy.result())
    tf.contrib.summary.scalar("conf_test_accuracy", conf_test_accuracy.result())
    
for epoch in range(epochs):
  global_step.assign_add(1)  
    
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  for data in office_test_set:
    test_office_step(data[0], data[1])

  for data in server_test_set:
    test_server_step(data[0], data[1])
    
  for data in conf_test_set:
    test_conf_step(data[0], data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100,
                             server_test_accuracy.result()*100,
                             office_test_accuracy.result()*100,
                             conf_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
  server_test_accuracy.reset_states()
  office_test_accuracy.reset_states()
  conf_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0829 19:25:27.711865 139828007835392 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0829 19:25:29.086974 139828007835392 util.py:244] Unresolved object in checkpoint: (root).logits.kernel
# W0829 19:25:29.088023 139828007835392 util.py:244] Unresolved object in checkpoint: (root).logits._callable_losses
# W0829 19:25:29.088705 139828007835392 util.py:244] Unresolved object in checkpoint: (root).logits._eager_losses
# W0829 19:25:29.089295 139828007835392 util.py:244] Unresolved object in checkpoint: (root).logits.bias
# W0829 19:25:29.089892 139828007835392 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0829 19:25:29.348061 139828007835392 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# Epoch: 001, TotalL: 19.3233, CrossE: 1.7477, CondE: 1.9076, disc: 0.7083, domain: 0.7373, Src VAT: 1.9074, Trg VAT: 1.9076, Src MixUp: 2.0032, Trg MixUp: 2.0194, Src Train Acc: 36.59, Trg Train Acc: 35.29, Src Test Acc: 60.70, Trg Test Acc: 54.20, Server Test Acc: 32.32, Office Test Acc: 23.58, Conf Test Acc: 38.44
# Epoch: 002, TotalL: 13.6060, CrossE: 1.2210, CondE: 1.5223, disc: 0.6971, domain: 0.7596, Src VAT: 1.5033, Trg VAT: 1.5223, Src MixUp: 1.6970, Trg MixUp: 1.7570, Src Train Acc: 56.51, Trg Train Acc: 50.43, Src Test Acc: 51.75, Trg Test Acc: 48.38, Server Test Acc: 30.01, Office Test Acc: 24.92, Conf Test Acc: 34.89
# Epoch: 003, TotalL: 12.7475, CrossE: 1.0524, CondE: 1.3434, disc: 0.6896, domain: 0.7686, Src VAT: 1.3125, Trg VAT: 1.3434, Src MixUp: 1.5492, Trg MixUp: 1.6334, Src Train Acc: 62.63, Trg Train Acc: 57.12, Src Test Acc: 57.20, Trg Test Acc: 51.71, Server Test Acc: 27.79, Office Test Acc: 24.25, Conf Test Acc: 33.33
# Epoch: 004, TotalL: 12.1303, CrossE: 0.9345, CondE: 1.2303, disc: 0.6839, domain: 0.7794, Src VAT: 1.1843, Trg VAT: 1.2303, Src MixUp: 1.4556, Trg MixUp: 1.5482, Src Train Acc: 67.49, Trg Train Acc: 60.68, Src Test Acc: 63.81, Trg Test Acc: 59.84, Server Test Acc: 33.66, Office Test Acc: 35.93, Conf Test Acc: 40.00
# Epoch: 005, TotalL: 11.6963, CrossE: 0.8481, CondE: 1.1634, disc: 0.6792, domain: 0.7909, Src VAT: 1.1076, Trg VAT: 1.1634, Src MixUp: 1.3859, Trg MixUp: 1.5099, Src Train Acc: 71.18, Trg Train Acc: 63.67, Src Test Acc: 73.15, Trg Test Acc: 64.02, Server Test Acc: 31.58, Office Test Acc: 35.60, Conf Test Acc: 42.07
# Epoch: 006, TotalL: 11.3578, CrossE: 0.7729, CondE: 1.0935, disc: 0.6750, domain: 0.7983, Src VAT: 1.0384, Trg VAT: 1.0935, Src MixUp: 1.3471, Trg MixUp: 1.4558, Src Train Acc: 73.48, Trg Train Acc: 66.32, Src Test Acc: 74.32, Trg Test Acc: 68.35, Server Test Acc: 39.23, Office Test Acc: 45.94, Conf Test Acc: 45.04
# Epoch: 007, TotalL: 11.0186, CrossE: 0.7068, CondE: 1.0400, disc: 0.6714, domain: 0.8043, Src VAT: 0.9734, Trg VAT: 1.0400, Src MixUp: 1.2747, Trg MixUp: 1.4110, Src Train Acc: 76.69, Trg Train Acc: 68.66, Src Test Acc: 75.10, Trg Test Acc: 68.94, Server Test Acc: 41.01, Office Test Acc: 42.27, Conf Test Acc: 47.78
# Epoch: 008, TotalL: 10.7848, CrossE: 0.6575, CondE: 0.9870, disc: 0.6703, domain: 0.8077, Src VAT: 0.9213, Trg VAT: 0.9870, Src MixUp: 1.2454, Trg MixUp: 1.3733, Src Train Acc: 79.21, Trg Train Acc: 70.31, Src Test Acc: 79.38, Trg Test Acc: 71.51, Server Test Acc: 41.01, Office Test Acc: 47.16, Conf Test Acc: 47.63
# Epoch: 009, TotalL: 10.4959, CrossE: 0.6015, CondE: 0.9436, disc: 0.6682, domain: 0.8144, Src VAT: 0.8643, Trg VAT: 0.9436, Src MixUp: 1.1802, Trg MixUp: 1.3349, Src Train Acc: 80.51, Trg Train Acc: 71.61, Src Test Acc: 85.60, Trg Test Acc: 73.47, Server Test Acc: 41.08, Office Test Acc: 46.16, Conf Test Acc: 48.81
# Epoch: 010, TotalL: 10.3019, CrossE: 0.5506, CondE: 0.8961, disc: 0.6669, domain: 0.8144, Src VAT: 0.8204, Trg VAT: 0.8961, Src MixUp: 1.1574, Trg MixUp: 1.3066, Src Train Acc: 84.24, Trg Train Acc: 73.65, Src Test Acc: 82.10, Trg Test Acc: 73.12, Server Test Acc: 46.43, Office Test Acc: 52.95, Conf Test Acc: 52.74
# Epoch: 011, TotalL: 10.0460, CrossE: 0.4939, CondE: 0.8495, disc: 0.6653, domain: 0.8158, Src VAT: 0.7611, Trg VAT: 0.8495, Src MixUp: 1.1116, Trg MixUp: 1.2712, Src Train Acc: 85.55, Trg Train Acc: 75.78, Src Test Acc: 89.49, Trg Test Acc: 79.18, Server Test Acc: 43.46, Office Test Acc: 45.49, Conf Test Acc: 58.22
# Epoch: 012, TotalL: 9.8569, CrossE: 0.4509, CondE: 0.8178, disc: 0.6643, domain: 0.8162, Src VAT: 0.7199, Trg VAT: 0.8178, Src MixUp: 1.0790, Trg MixUp: 1.2326, Src Train Acc: 88.37, Trg Train Acc: 76.61, Src Test Acc: 86.77, Trg Test Acc: 77.95, Server Test Acc: 49.93, Office Test Acc: 52.28, Conf Test Acc: 55.19
# Epoch: 013, TotalL: 9.6674, CrossE: 0.4111, CondE: 0.7819, disc: 0.6625, domain: 0.8194, Src VAT: 0.6780, Trg VAT: 0.7819, Src MixUp: 1.0427, Trg MixUp: 1.2179, Src Train Acc: 88.67, Trg Train Acc: 78.99, Src Test Acc: 85.21, Trg Test Acc: 77.63, Server Test Acc: 46.73, Office Test Acc: 54.73, Conf Test Acc: 56.52
# Epoch: 014, TotalL: 9.4419, CrossE: 0.3670, CondE: 0.7346, disc: 0.6590, domain: 0.8287, Src VAT: 0.6226, Trg VAT: 0.7346, Src MixUp: 0.9806, Trg MixUp: 1.1946, Src Train Acc: 90.15, Trg Train Acc: 79.51, Src Test Acc: 93.39, Trg Test Acc: 77.60, Server Test Acc: 50.89, Office Test Acc: 51.28, Conf Test Acc: 59.48
# Epoch: 015, TotalL: 9.2898, CrossE: 0.3339, CondE: 0.6956, disc: 0.6593, domain: 0.8324, Src VAT: 0.5828, Trg VAT: 0.6956, Src MixUp: 0.9625, Trg MixUp: 1.1496, Src Train Acc: 91.80, Trg Train Acc: 80.51, Src Test Acc: 93.00, Trg Test Acc: 81.84, Server Test Acc: 57.88, Office Test Acc: 61.18, Conf Test Acc: 61.33
# Epoch: 016, TotalL: 9.1005, CrossE: 0.3040, CondE: 0.6608, disc: 0.6575, domain: 0.8336, Src VAT: 0.5441, Trg VAT: 0.6608, Src MixUp: 0.8961, Trg MixUp: 1.1047, Src Train Acc: 92.27, Trg Train Acc: 81.42, Src Test Acc: 87.16, Trg Test Acc: 75.05, Server Test Acc: 46.43, Office Test Acc: 41.05, Conf Test Acc: 52.22
# Epoch: 017, TotalL: 8.9734, CrossE: 0.2761, CondE: 0.6362, disc: 0.6548, domain: 0.8374, Src VAT: 0.5107, Trg VAT: 0.6362, Src MixUp: 0.8765, Trg MixUp: 1.1112, Src Train Acc: 93.97, Trg Train Acc: 82.81, Src Test Acc: 96.50, Trg Test Acc: 84.94, Server Test Acc: 62.33, Office Test Acc: 61.74, Conf Test Acc: 69.33
# Epoch: 018, TotalL: 8.8475, CrossE: 0.2521, CondE: 0.6054, disc: 0.6518, domain: 0.8485, Src VAT: 0.4754, Trg VAT: 0.6054, Src MixUp: 0.8483, Trg MixUp: 1.0590, Src Train Acc: 93.84, Trg Train Acc: 82.99, Src Test Acc: 92.22, Trg Test Acc: 78.82, Server Test Acc: 54.61, Office Test Acc: 49.28, Conf Test Acc: 56.96
# Epoch: 019, TotalL: 8.7070, CrossE: 0.2291, CondE: 0.5898, disc: 0.6532, domain: 0.8447, Src VAT: 0.4527, Trg VAT: 0.5898, Src MixUp: 0.8012, Trg MixUp: 1.0452, Src Train Acc: 94.92, Trg Train Acc: 83.64, Src Test Acc: 95.72, Trg Test Acc: 83.62, Server Test Acc: 60.48, Office Test Acc: 59.84, Conf Test Acc: 67.78
# Epoch: 020, TotalL: 8.6205, CrossE: 0.2062, CondE: 0.5711, disc: 0.6510, domain: 0.8463, Src VAT: 0.4262, Trg VAT: 0.5711, Src MixUp: 0.7968, Trg MixUp: 1.0498, Src Train Acc: 95.88, Trg Train Acc: 84.29, Src Test Acc: 89.88, Trg Test Acc: 78.06, Server Test Acc: 53.42, Office Test Acc: 45.49, Conf Test Acc: 58.89
# Epoch: 021, TotalL: 8.5196, CrossE: 0.1955, CondE: 0.5452, disc: 0.6502, domain: 0.8479, Src VAT: 0.4013, Trg VAT: 0.5452, Src MixUp: 0.7573, Trg MixUp: 1.0086, Src Train Acc: 95.83, Trg Train Acc: 84.98, Src Test Acc: 93.77, Trg Test Acc: 82.98, Server Test Acc: 61.07, Office Test Acc: 59.51, Conf Test Acc: 64.44
# Epoch: 022, TotalL: 8.4397, CrossE: 0.1774, CondE: 0.5323, disc: 0.6474, domain: 0.8577, Src VAT: 0.3796, Trg VAT: 0.5323, Src MixUp: 0.7507, Trg MixUp: 0.9918, Src Train Acc: 96.61, Trg Train Acc: 84.59, Src Test Acc: 91.44, Trg Test Acc: 78.03, Server Test Acc: 57.36, Office Test Acc: 54.06, Conf Test Acc: 59.48
# Epoch: 023, TotalL: 8.3878, CrossE: 0.1652, CondE: 0.5160, disc: 0.6464, domain: 0.8599, Src VAT: 0.3627, Trg VAT: 0.5160, Src MixUp: 0.7404, Trg MixUp: 0.9787, Src Train Acc: 96.74, Trg Train Acc: 86.11, Src Test Acc: 95.33, Trg Test Acc: 85.41, Server Test Acc: 65.90, Office Test Acc: 62.51, Conf Test Acc: 72.74
# Epoch: 024, TotalL: 8.2503, CrossE: 0.1471, CondE: 0.4998, disc: 0.6450, domain: 0.8621, Src VAT: 0.3400, Trg VAT: 0.4998, Src MixUp: 0.6996, Trg MixUp: 0.9489, Src Train Acc: 97.18, Trg Train Acc: 85.85, Src Test Acc: 91.44, Trg Test Acc: 83.39, Server Test Acc: 61.81, Office Test Acc: 60.07, Conf Test Acc: 67.41
# Epoch: 025, TotalL: 8.2112, CrossE: 0.1397, CondE: 0.4873, disc: 0.6431, domain: 0.8662, Src VAT: 0.3238, Trg VAT: 0.4873, Src MixUp: 0.6923, Trg MixUp: 0.9395, Src Train Acc: 96.92, Trg Train Acc: 86.11, Src Test Acc: 93.77, Trg Test Acc: 82.04, Server Test Acc: 60.40, Office Test Acc: 57.29, Conf Test Acc: 64.37
# Epoch: 026, TotalL: 8.1227, CrossE: 0.1275, CondE: 0.4635, disc: 0.6430, domain: 0.8712, Src VAT: 0.3046, Trg VAT: 0.4635, Src MixUp: 0.6572, Trg MixUp: 0.9298, Src Train Acc: 97.66, Trg Train Acc: 86.55, Src Test Acc: 98.44, Trg Test Acc: 87.10, Server Test Acc: 64.56, Office Test Acc: 53.62, Conf Test Acc: 74.30
# Epoch: 027, TotalL: 8.0778, CrossE: 0.1170, CondE: 0.4535, disc: 0.6439, domain: 0.8712, Src VAT: 0.2901, Trg VAT: 0.4535, Src MixUp: 0.6392, Trg MixUp: 0.9059, Src Train Acc: 97.70, Trg Train Acc: 87.33, Src Test Acc: 94.16, Trg Test Acc: 85.11, Server Test Acc: 62.18, Office Test Acc: 48.94, Conf Test Acc: 68.22
# Epoch: 028, TotalL: 8.0073, CrossE: 0.1072, CondE: 0.4452, disc: 0.6350, domain: 0.8837, Src VAT: 0.2755, Trg VAT: 0.4452, Src MixUp: 0.6220, Trg MixUp: 0.8970, Src Train Acc: 98.05, Trg Train Acc: 87.41, Src Test Acc: 89.49, Trg Test Acc: 79.35, Server Test Acc: 60.77, Office Test Acc: 57.62, Conf Test Acc: 62.00
# Epoch: 029, TotalL: 7.9495, CrossE: 0.0970, CondE: 0.4295, disc: 0.6376, domain: 0.8886, Src VAT: 0.2580, Trg VAT: 0.4295, Src MixUp: 0.6017, Trg MixUp: 0.8850, Src Train Acc: 98.35, Trg Train Acc: 87.15, Src Test Acc: 97.67, Trg Test Acc: 86.55, Server Test Acc: 69.32, Office Test Acc: 66.30, Conf Test Acc: 71.33
# Epoch: 030, TotalL: 7.8925, CrossE: 0.0887, CondE: 0.4269, disc: 0.6339, domain: 0.8967, Src VAT: 0.2484, Trg VAT: 0.4269, Src MixUp: 0.5874, Trg MixUp: 0.8734, Src Train Acc: 98.83, Trg Train Acc: 87.28, Src Test Acc: 94.16, Trg Test Acc: 84.97, Server Test Acc: 63.08, Office Test Acc: 57.62, Conf Test Acc: 70.30
# Epoch: 031, TotalL: 7.8273, CrossE: 0.0800, CondE: 0.4161, disc: 0.6300, domain: 0.9056, Src VAT: 0.2346, Trg VAT: 0.4161, Src MixUp: 0.5654, Trg MixUp: 0.8691, Src Train Acc: 99.22, Trg Train Acc: 88.80, Src Test Acc: 97.28, Trg Test Acc: 85.26, Server Test Acc: 62.33, Office Test Acc: 54.73, Conf Test Acc: 70.07
# Epoch: 032, TotalL: 7.7949, CrossE: 0.0819, CondE: 0.3978, disc: 0.6340, domain: 0.9032, Src VAT: 0.2231, Trg VAT: 0.3978, Src MixUp: 0.5445, Trg MixUp: 0.8528, Src Train Acc: 98.52, Trg Train Acc: 88.72, Src Test Acc: 96.50, Trg Test Acc: 88.15, Server Test Acc: 70.58, Office Test Acc: 63.74, Conf Test Acc: 76.81
# Epoch: 033, TotalL: 7.7542, CrossE: 0.0741, CondE: 0.3914, disc: 0.6299, domain: 0.9168, Src VAT: 0.2112, Trg VAT: 0.3914, Src MixUp: 0.5433, Trg MixUp: 0.8310, Src Train Acc: 98.96, Trg Train Acc: 88.93, Src Test Acc: 97.28, Trg Test Acc: 86.52, Server Test Acc: 63.37, Office Test Acc: 55.95, Conf Test Acc: 69.85
# Epoch: 034, TotalL: 7.7436, CrossE: 0.0656, CondE: 0.3898, disc: 0.6241, domain: 0.9240, Src VAT: 0.2068, Trg VAT: 0.3898, Src MixUp: 0.5406, Trg MixUp: 0.8200, Src Train Acc: 99.26, Trg Train Acc: 88.45, Src Test Acc: 95.33, Trg Test Acc: 86.52, Server Test Acc: 63.45, Office Test Acc: 53.73, Conf Test Acc: 68.37
# Epoch: 035, TotalL: 7.6876, CrossE: 0.0624, CondE: 0.3699, disc: 0.6297, domain: 0.9154, Src VAT: 0.1985, Trg VAT: 0.3699, Src MixUp: 0.5164, Trg MixUp: 0.8302, Src Train Acc: 99.18, Trg Train Acc: 89.63, Src Test Acc: 94.94, Trg Test Acc: 89.76, Server Test Acc: 67.24, Office Test Acc: 54.62, Conf Test Acc: 75.85
# Epoch: 036, TotalL: 7.6567, CrossE: 0.0583, CondE: 0.3646, disc: 0.6238, domain: 0.9281, Src VAT: 0.1848, Trg VAT: 0.3646, Src MixUp: 0.5183, Trg MixUp: 0.8205, Src Train Acc: 99.18, Trg Train Acc: 90.41, Src Test Acc: 94.94, Trg Test Acc: 84.47, Server Test Acc: 62.33, Office Test Acc: 48.05, Conf Test Acc: 65.41
# Epoch: 037, TotalL: 7.5917, CrossE: 0.0501, CondE: 0.3485, disc: 0.6251, domain: 0.9297, Src VAT: 0.1751, Trg VAT: 0.3485, Src MixUp: 0.4895, Trg MixUp: 0.8000, Src Train Acc: 99.65, Trg Train Acc: 90.10, Src Test Acc: 96.89, Trg Test Acc: 89.38, Server Test Acc: 67.68, Office Test Acc: 55.06, Conf Test Acc: 74.67
# Epoch: 038, TotalL: 7.6050, CrossE: 0.0502, CondE: 0.3458, disc: 0.6231, domain: 0.9340, Src VAT: 0.1675, Trg VAT: 0.3458, Src MixUp: 0.4963, Trg MixUp: 0.8053, Src Train Acc: 99.35, Trg Train Acc: 89.58, Src Test Acc: 95.72, Trg Test Acc: 86.72, Server Test Acc: 61.96, Office Test Acc: 50.95, Conf Test Acc: 70.30
# Epoch: 039, TotalL: 7.5520, CrossE: 0.0461, CondE: 0.3465, disc: 0.6134, domain: 0.9551, Src VAT: 0.1628, Trg VAT: 0.3465, Src MixUp: 0.4825, Trg MixUp: 0.8070, Src Train Acc: 99.57, Trg Train Acc: 90.58, Src Test Acc: 96.50, Trg Test Acc: 83.33, Server Test Acc: 63.45, Office Test Acc: 57.06, Conf Test Acc: 73.33
# Epoch: 040, TotalL: 7.5585, CrossE: 0.0461, CondE: 0.3376, disc: 0.6200, domain: 0.9535, Src VAT: 0.1590, Trg VAT: 0.3376, Src MixUp: 0.4804, Trg MixUp: 0.7847, Src Train Acc: 99.65, Trg Train Acc: 90.28, Src Test Acc: 98.44, Trg Test Acc: 90.47, Server Test Acc: 69.39, Office Test Acc: 61.62, Conf Test Acc: 75.78
# Epoch: 041, TotalL: 7.5308, CrossE: 0.0420, CondE: 0.3282, disc: 0.6175, domain: 0.9538, Src VAT: 0.1514, Trg VAT: 0.3282, Src MixUp: 0.4637, Trg MixUp: 0.7894, Src Train Acc: 99.70, Trg Train Acc: 90.28, Src Test Acc: 95.72, Trg Test Acc: 87.45, Server Test Acc: 67.24, Office Test Acc: 63.74, Conf Test Acc: 73.33
# Epoch: 042, TotalL: 7.4622, CrossE: 0.0358, CondE: 0.3237, disc: 0.6111, domain: 0.9675, Src VAT: 0.1391, Trg VAT: 0.3237, Src MixUp: 0.4503, Trg MixUp: 0.7858, Src Train Acc: 99.91, Trg Train Acc: 90.67, Src Test Acc: 96.50, Trg Test Acc: 86.78, Server Test Acc: 72.36, Office Test Acc: 56.73, Conf Test Acc: 79.85
# Epoch: 043, TotalL: 7.4495, CrossE: 0.0348, CondE: 0.3101, disc: 0.6144, domain: 0.9658, Src VAT: 0.1363, Trg VAT: 0.3101, Src MixUp: 0.4374, Trg MixUp: 0.7585, Src Train Acc: 99.74, Trg Train Acc: 91.06, Src Test Acc: 98.05, Trg Test Acc: 88.59, Server Test Acc: 70.36, Office Test Acc: 60.07, Conf Test Acc: 79.41
# Epoch: 044, TotalL: 7.4095, CrossE: 0.0334, CondE: 0.3094, disc: 0.6143, domain: 0.9690, Src VAT: 0.1334, Trg VAT: 0.3094, Src MixUp: 0.4218, Trg MixUp: 0.7506, Src Train Acc: 99.87, Trg Train Acc: 91.23, Src Test Acc: 97.28, Trg Test Acc: 86.78, Server Test Acc: 67.98, Office Test Acc: 53.17, Conf Test Acc: 72.59
# Epoch: 045, TotalL: 7.4280, CrossE: 0.0351, CondE: 0.3033, disc: 0.6115, domain: 0.9818, Src VAT: 0.1310, Trg VAT: 0.3033, Src MixUp: 0.4332, Trg MixUp: 0.7244, Src Train Acc: 99.65, Trg Train Acc: 91.45, Src Test Acc: 96.89, Trg Test Acc: 89.15, Server Test Acc: 74.67, Office Test Acc: 66.07, Conf Test Acc: 83.11
# Epoch: 046, TotalL: 7.3889, CrossE: 0.0297, CondE: 0.2992, disc: 0.6084, domain: 0.9816, Src VAT: 0.1227, Trg VAT: 0.2992, Src MixUp: 0.4322, Trg MixUp: 0.7260, Src Train Acc: 99.83, Trg Train Acc: 91.71, Src Test Acc: 98.05, Trg Test Acc: 89.18, Server Test Acc: 67.98, Office Test Acc: 52.50, Conf Test Acc: 76.96
# Epoch: 047, TotalL: 7.3966, CrossE: 0.0315, CondE: 0.2953, disc: 0.6090, domain: 0.9885, Src VAT: 0.1237, Trg VAT: 0.2953, Src MixUp: 0.4228, Trg MixUp: 0.7073, Src Train Acc: 99.87, Trg Train Acc: 90.84, Src Test Acc: 96.89, Trg Test Acc: 91.02, Server Test Acc: 64.19, Office Test Acc: 50.28, Conf Test Acc: 76.89
# Epoch: 048, TotalL: 7.3222, CrossE: 0.0265, CondE: 0.2894, disc: 0.6028, domain: 0.9966, Src VAT: 0.1136, Trg VAT: 0.2894, Src MixUp: 0.3928, Trg MixUp: 0.7149, Src Train Acc: 99.91, Trg Train Acc: 92.19, Src Test Acc: 98.44, Trg Test Acc: 90.55, Server Test Acc: 64.78, Office Test Acc: 47.94, Conf Test Acc: 77.19
# Epoch: 049, TotalL: 7.3415, CrossE: 0.0250, CondE: 0.2844, disc: 0.6057, domain: 1.0012, Src VAT: 0.1101, Trg VAT: 0.2844, Src MixUp: 0.4073, Trg MixUp: 0.6851, Src Train Acc: 99.96, Trg Train Acc: 92.36, Src Test Acc: 98.44, Trg Test Acc: 89.12, Server Test Acc: 71.84, Office Test Acc: 56.84, Conf Test Acc: 75.26
# Epoch: 050, TotalL: 7.3211, CrossE: 0.0252, CondE: 0.2822, disc: 0.6059, domain: 0.9992, Src VAT: 0.1074, Trg VAT: 0.2822, Src MixUp: 0.3897, Trg MixUp: 0.6843, Src Train Acc: 99.91, Trg Train Acc: 91.88, Src Test Acc: 98.83, Trg Test Acc: 87.98, Server Test Acc: 73.40, Office Test Acc: 57.95, Conf Test Acc: 76.67
# Epoch: 051, TotalL: 7.2989, CrossE: 0.0240, CondE: 0.2750, disc: 0.6057, domain: 1.0016, Src VAT: 0.1030, Trg VAT: 0.2750, Src MixUp: 0.3847, Trg MixUp: 0.6847, Src Train Acc: 99.87, Trg Train Acc: 91.93, Src Test Acc: 98.83, Trg Test Acc: 91.75, Server Test Acc: 74.22, Office Test Acc: 68.85, Conf Test Acc: 78.07
# Epoch: 052, TotalL: 7.2825, CrossE: 0.0238, CondE: 0.2699, disc: 0.6066, domain: 1.0013, Src VAT: 0.1015, Trg VAT: 0.2699, Src MixUp: 0.3644, Trg MixUp: 0.6955, Src Train Acc: 99.91, Trg Train Acc: 92.97, Src Test Acc: 97.67, Trg Test Acc: 89.65, Server Test Acc: 70.13, Office Test Acc: 54.06, Conf Test Acc: 77.85
# Epoch: 053, TotalL: 7.2430, CrossE: 0.0199, CondE: 0.2646, disc: 0.6007, domain: 1.0083, Src VAT: 0.0935, Trg VAT: 0.2646, Src MixUp: 0.3598, Trg MixUp: 0.6761, Src Train Acc: 100.00, Trg Train Acc: 91.93, Src Test Acc: 98.44, Trg Test Acc: 91.99, Server Test Acc: 71.84, Office Test Acc: 64.74, Conf Test Acc: 82.15
# Epoch: 054, TotalL: 7.2434, CrossE: 0.0209, CondE: 0.2572, disc: 0.6044, domain: 1.0122, Src VAT: 0.0933, Trg VAT: 0.2572, Src MixUp: 0.3528, Trg MixUp: 0.6418, Src Train Acc: 99.87, Trg Train Acc: 93.19, Src Test Acc: 96.50, Trg Test Acc: 91.84, Server Test Acc: 71.77, Office Test Acc: 55.17, Conf Test Acc: 80.22
# Epoch: 055, TotalL: 7.2481, CrossE: 0.0217, CondE: 0.2547, disc: 0.6022, domain: 1.0107, Src VAT: 0.0928, Trg VAT: 0.2547, Src MixUp: 0.3527, Trg MixUp: 0.6791, Src Train Acc: 99.91, Trg Train Acc: 92.06, Src Test Acc: 97.67, Trg Test Acc: 91.25, Server Test Acc: 71.25, Office Test Acc: 58.51, Conf Test Acc: 79.11
# Epoch: 056, TotalL: 7.2322, CrossE: 0.0206, CondE: 0.2535, disc: 0.6056, domain: 1.0154, Src VAT: 0.0904, Trg VAT: 0.2535, Src MixUp: 0.3560, Trg MixUp: 0.6605, Src Train Acc: 99.96, Trg Train Acc: 93.01, Src Test Acc: 98.44, Trg Test Acc: 91.66, Server Test Acc: 70.28, Office Test Acc: 58.95, Conf Test Acc: 80.52
# Epoch: 057, TotalL: 7.1915, CrossE: 0.0171, CondE: 0.2468, disc: 0.5991, domain: 1.0185, Src VAT: 0.0836, Trg VAT: 0.2468, Src MixUp: 0.3456, Trg MixUp: 0.6619, Src Train Acc: 100.00, Trg Train Acc: 93.10, Src Test Acc: 97.28, Trg Test Acc: 88.13, Server Test Acc: 76.75, Office Test Acc: 65.52, Conf Test Acc: 84.15
# Epoch: 058, TotalL: 7.2180, CrossE: 0.0192, CondE: 0.2439, disc: 0.6026, domain: 1.0218, Src VAT: 0.0841, Trg VAT: 0.2439, Src MixUp: 0.3523, Trg MixUp: 0.6510, Src Train Acc: 99.91, Trg Train Acc: 92.40, Src Test Acc: 97.28, Trg Test Acc: 89.50, Server Test Acc: 65.53, Office Test Acc: 53.50, Conf Test Acc: 75.70
# Epoch: 059, TotalL: 7.1868, CrossE: 0.0167, CondE: 0.2463, disc: 0.5970, domain: 1.0321, Src VAT: 0.0809, Trg VAT: 0.2463, Src MixUp: 0.3464, Trg MixUp: 0.6508, Src Train Acc: 100.00, Trg Train Acc: 92.97, Src Test Acc: 98.44, Trg Test Acc: 89.79, Server Test Acc: 72.44, Office Test Acc: 59.18, Conf Test Acc: 81.63
# Epoch: 060, TotalL: 7.1842, CrossE: 0.0166, CondE: 0.2418, disc: 0.5939, domain: 1.0383, Src VAT: 0.0791, Trg VAT: 0.2418, Src MixUp: 0.3387, Trg MixUp: 0.6569, Src Train Acc: 99.96, Trg Train Acc: 92.97, Src Test Acc: 98.83, Trg Test Acc: 92.63, Server Test Acc: 73.92, Office Test Acc: 59.40, Conf Test Acc: 83.93
# Epoch: 061, TotalL: 7.1317, CrossE: 0.0153, CondE: 0.2313, disc: 0.5950, domain: 1.0457, Src VAT: 0.0741, Trg VAT: 0.2313, Src MixUp: 0.3080, Trg MixUp: 0.6375, Src Train Acc: 99.96, Trg Train Acc: 92.80, Src Test Acc: 98.05, Trg Test Acc: 93.65, Server Test Acc: 72.29, Office Test Acc: 55.17, Conf Test Acc: 83.26
# Epoch: 062, TotalL: 7.1562, CrossE: 0.0150, CondE: 0.2291, disc: 0.5958, domain: 1.0364, Src VAT: 0.0749, Trg VAT: 0.2291, Src MixUp: 0.3332, Trg MixUp: 0.6520, Src Train Acc: 100.00, Trg Train Acc: 93.27, Src Test Acc: 97.28, Trg Test Acc: 89.82, Server Test Acc: 73.40, Office Test Acc: 63.07, Conf Test Acc: 76.30
# Epoch: 063, TotalL: 7.1729, CrossE: 0.0183, CondE: 0.2310, disc: 0.6005, domain: 1.0353, Src VAT: 0.0779, Trg VAT: 0.2310, Src MixUp: 0.3315, Trg MixUp: 0.6216, Src Train Acc: 99.87, Trg Train Acc: 93.01, Src Test Acc: 98.05, Trg Test Acc: 92.80, Server Test Acc: 76.00, Office Test Acc: 58.95, Conf Test Acc: 88.30
# Epoch: 064, TotalL: 7.1343, CrossE: 0.0145, CondE: 0.2277, disc: 0.5915, domain: 1.0508, Src VAT: 0.0707, Trg VAT: 0.2277, Src MixUp: 0.3226, Trg MixUp: 0.6274, Src Train Acc: 99.91, Trg Train Acc: 93.75, Src Test Acc: 98.44, Trg Test Acc: 93.39, Server Test Acc: 74.81, Office Test Acc: 60.18, Conf Test Acc: 83.19
# Epoch: 065, TotalL: 7.1358, CrossE: 0.0157, CondE: 0.2254, disc: 0.5968, domain: 1.0509, Src VAT: 0.0704, Trg VAT: 0.2254, Src MixUp: 0.3201, Trg MixUp: 0.6110, Src Train Acc: 99.91, Trg Train Acc: 93.32, Src Test Acc: 95.72, Trg Test Acc: 92.22, Server Test Acc: 71.92, Office Test Acc: 62.18, Conf Test Acc: 81.48
# Epoch: 066, TotalL: 7.1152, CrossE: 0.0126, CondE: 0.2179, disc: 0.5932, domain: 1.0446, Src VAT: 0.0671, Trg VAT: 0.2179, Src MixUp: 0.3187, Trg MixUp: 0.5763, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 98.05, Trg Test Acc: 93.59, Server Test Acc: 75.78, Office Test Acc: 67.74, Conf Test Acc: 84.37
# Epoch: 067, TotalL: 7.0962, CrossE: 0.0135, CondE: 0.2143, disc: 0.5890, domain: 1.0550, Src VAT: 0.0651, Trg VAT: 0.2143, Src MixUp: 0.3064, Trg MixUp: 0.6043, Src Train Acc: 99.96, Trg Train Acc: 93.49, Src Test Acc: 98.05, Trg Test Acc: 92.22, Server Test Acc: 75.85, Office Test Acc: 74.53, Conf Test Acc: 81.41
# Epoch: 068, TotalL: 7.1124, CrossE: 0.0134, CondE: 0.2122, disc: 0.5914, domain: 1.0643, Src VAT: 0.0663, Trg VAT: 0.2122, Src MixUp: 0.3094, Trg MixUp: 0.5928, Src Train Acc: 100.00, Trg Train Acc: 93.27, Src Test Acc: 98.83, Trg Test Acc: 93.39, Server Test Acc: 75.11, Office Test Acc: 54.73, Conf Test Acc: 82.81
# Epoch: 069, TotalL: 7.0753, CrossE: 0.0121, CondE: 0.2119, disc: 0.5952, domain: 1.0586, Src VAT: 0.0631, Trg VAT: 0.2119, Src MixUp: 0.2979, Trg MixUp: 0.5989, Src Train Acc: 99.96, Trg Train Acc: 93.14, Src Test Acc: 98.83, Trg Test Acc: 92.48, Server Test Acc: 72.51, Office Test Acc: 49.28, Conf Test Acc: 82.81
# Epoch: 070, TotalL: 7.0863, CrossE: 0.0125, CondE: 0.2053, disc: 0.5991, domain: 1.0441, Src VAT: 0.0635, Trg VAT: 0.2053, Src MixUp: 0.2937, Trg MixUp: 0.5930, Src Train Acc: 100.00, Trg Train Acc: 93.49, Src Test Acc: 97.67, Trg Test Acc: 85.46, Server Test Acc: 79.72, Office Test Acc: 69.86, Conf Test Acc: 82.22
# Epoch: 071, TotalL: 7.0671, CrossE: 0.0116, CondE: 0.2030, disc: 0.5946, domain: 1.0476, Src VAT: 0.0612, Trg VAT: 0.2030, Src MixUp: 0.2925, Trg MixUp: 0.5868, Src Train Acc: 100.00, Trg Train Acc: 93.45, Src Test Acc: 98.44, Trg Test Acc: 90.20, Server Test Acc: 74.15, Office Test Acc: 64.74, Conf Test Acc: 83.26
# Epoch: 072, TotalL: 7.0606, CrossE: 0.0102, CondE: 0.2028, disc: 0.5937, domain: 1.0530, Src VAT: 0.0568, Trg VAT: 0.2028, Src MixUp: 0.2923, Trg MixUp: 0.6008, Src Train Acc: 100.00, Trg Train Acc: 93.79, Src Test Acc: 98.44, Trg Test Acc: 93.42, Server Test Acc: 74.22, Office Test Acc: 65.29, Conf Test Acc: 82.30
# Epoch: 073, TotalL: 7.0290, CrossE: 0.0099, CondE: 0.2003, disc: 0.5881, domain: 1.0635, Src VAT: 0.0559, Trg VAT: 0.2003, Src MixUp: 0.2754, Trg MixUp: 0.5787, Src Train Acc: 100.00, Trg Train Acc: 93.75, Src Test Acc: 99.61, Trg Test Acc: 92.75, Server Test Acc: 78.97, Office Test Acc: 65.29, Conf Test Acc: 86.44
# Epoch: 074, TotalL: 7.0418, CrossE: 0.0096, CondE: 0.1975, disc: 0.5942, domain: 1.0668, Src VAT: 0.0537, Trg VAT: 0.1975, Src MixUp: 0.2877, Trg MixUp: 0.5908, Src Train Acc: 100.00, Trg Train Acc: 93.88, Src Test Acc: 98.83, Trg Test Acc: 94.15, Server Test Acc: 79.42, Office Test Acc: 66.96, Conf Test Acc: 86.59
# Epoch: 075, TotalL: 7.0507, CrossE: 0.0102, CondE: 0.1942, disc: 0.5904, domain: 1.0717, Src VAT: 0.0553, Trg VAT: 0.1942, Src MixUp: 0.2958, Trg MixUp: 0.5629, Src Train Acc: 99.96, Trg Train Acc: 93.97, Src Test Acc: 98.44, Trg Test Acc: 94.21, Server Test Acc: 76.52, Office Test Acc: 62.96, Conf Test Acc: 84.81
# Epoch: 076, TotalL: 7.0402, CrossE: 0.0105, CondE: 0.1907, disc: 0.5929, domain: 1.0691, Src VAT: 0.0542, Trg VAT: 0.1907, Src MixUp: 0.2735, Trg MixUp: 0.5650, Src Train Acc: 99.96, Trg Train Acc: 93.79, Src Test Acc: 98.05, Trg Test Acc: 92.75, Server Test Acc: 79.12, Office Test Acc: 68.97, Conf Test Acc: 85.19
# Epoch: 077, TotalL: 7.0056, CrossE: 0.0093, CondE: 0.1912, disc: 0.5898, domain: 1.0700, Src VAT: 0.0520, Trg VAT: 0.1912, Src MixUp: 0.2685, Trg MixUp: 0.5721, Src Train Acc: 100.00, Trg Train Acc: 93.92, Src Test Acc: 97.67, Trg Test Acc: 93.65, Server Test Acc: 73.70, Office Test Acc: 66.07, Conf Test Acc: 85.11
# Epoch: 078, TotalL: 7.0188, CrossE: 0.0098, CondE: 0.1860, disc: 0.5904, domain: 1.0725, Src VAT: 0.0519, Trg VAT: 0.1860, Src MixUp: 0.2708, Trg MixUp: 0.5719, Src Train Acc: 99.96, Trg Train Acc: 93.84, Src Test Acc: 96.89, Trg Test Acc: 89.68, Server Test Acc: 74.00, Office Test Acc: 75.31, Conf Test Acc: 83.70
# Epoch: 079, TotalL: 7.0179, CrossE: 0.0091, CondE: 0.1816, disc: 0.5929, domain: 1.0643, Src VAT: 0.0500, Trg VAT: 0.1816, Src MixUp: 0.2699, Trg MixUp: 0.5611, Src Train Acc: 100.00, Trg Train Acc: 94.10, Src Test Acc: 97.67, Trg Test Acc: 94.06, Server Test Acc: 77.04, Office Test Acc: 59.40, Conf Test Acc: 85.78
# Epoch: 080, TotalL: 7.0117, CrossE: 0.0093, CondE: 0.1822, disc: 0.5916, domain: 1.0661, Src VAT: 0.0511, Trg VAT: 0.1822, Src MixUp: 0.2767, Trg MixUp: 0.5641, Src Train Acc: 100.00, Trg Train Acc: 94.44, Src Test Acc: 98.44, Trg Test Acc: 94.03, Server Test Acc: 74.37, Office Test Acc: 58.84, Conf Test Acc: 84.07
# Epoch: 081, TotalL: 6.9782, CrossE: 0.0080, CondE: 0.1763, disc: 0.5892, domain: 1.0728, Src VAT: 0.0464, Trg VAT: 0.1763, Src MixUp: 0.2578, Trg MixUp: 0.5350, Src Train Acc: 100.00, Trg Train Acc: 94.79, Src Test Acc: 98.44, Trg Test Acc: 93.30, Server Test Acc: 70.95, Office Test Acc: 68.19, Conf Test Acc: 81.04
# Epoch: 082, TotalL: 7.0133, CrossE: 0.0096, CondE: 0.1756, disc: 0.5944, domain: 1.0677, Src VAT: 0.0497, Trg VAT: 0.1756, Src MixUp: 0.2727, Trg MixUp: 0.5500, Src Train Acc: 100.00, Trg Train Acc: 93.84, Src Test Acc: 98.83, Trg Test Acc: 94.44, Server Test Acc: 78.08, Office Test Acc: 70.52, Conf Test Acc: 88.07
# Epoch: 083, TotalL: 7.0001, CrossE: 0.0079, CondE: 0.1752, disc: 0.5864, domain: 1.0823, Src VAT: 0.0462, Trg VAT: 0.1752, Src MixUp: 0.2753, Trg MixUp: 0.5534, Src Train Acc: 100.00, Trg Train Acc: 94.14, Src Test Acc: 97.67, Trg Test Acc: 90.06, Server Test Acc: 75.33, Office Test Acc: 73.08, Conf Test Acc: 82.07
# Epoch: 084, TotalL: 6.9664, CrossE: 0.0074, CondE: 0.1783, disc: 0.5875, domain: 1.0812, Src VAT: 0.0441, Trg VAT: 0.1783, Src MixUp: 0.2541, Trg MixUp: 0.5473, Src Train Acc: 100.00, Trg Train Acc: 94.31, Src Test Acc: 98.83, Trg Test Acc: 89.82, Server Test Acc: 72.88, Office Test Acc: 71.19, Conf Test Acc: 82.07
# Epoch: 085, TotalL: 6.9546, CrossE: 0.0073, CondE: 0.1727, disc: 0.5868, domain: 1.0907, Src VAT: 0.0442, Trg VAT: 0.1727, Src MixUp: 0.2480, Trg MixUp: 0.5241, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 98.44, Trg Test Acc: 91.96, Server Test Acc: 78.90, Office Test Acc: 68.19, Conf Test Acc: 84.37
# Epoch: 086, TotalL: 6.9715, CrossE: 0.0080, CondE: 0.1723, disc: 0.5896, domain: 1.0807, Src VAT: 0.0455, Trg VAT: 0.1723, Src MixUp: 0.2561, Trg MixUp: 0.5241, Src Train Acc: 100.00, Trg Train Acc: 94.18, Src Test Acc: 98.44, Trg Test Acc: 94.44, Server Test Acc: 75.11, Office Test Acc: 56.95, Conf Test Acc: 83.70
# Epoch: 087, TotalL: 6.9605, CrossE: 0.0077, CondE: 0.1647, disc: 0.5930, domain: 1.0729, Src VAT: 0.0441, Trg VAT: 0.1647, Src MixUp: 0.2513, Trg MixUp: 0.5257, Src Train Acc: 100.00, Trg Train Acc: 94.70, Src Test Acc: 98.83, Trg Test Acc: 94.09, Server Test Acc: 77.04, Office Test Acc: 63.52, Conf Test Acc: 85.11
# Epoch: 088, TotalL: 6.9507, CrossE: 0.0072, CondE: 0.1641, disc: 0.5888, domain: 1.0804, Src VAT: 0.0427, Trg VAT: 0.1641, Src MixUp: 0.2509, Trg MixUp: 0.5275, Src Train Acc: 100.00, Trg Train Acc: 94.49, Src Test Acc: 98.44, Trg Test Acc: 95.99, Server Test Acc: 78.38, Office Test Acc: 66.96, Conf Test Acc: 87.93
# Epoch: 089, TotalL: 6.9636, CrossE: 0.0082, CondE: 0.1618, disc: 0.5933, domain: 1.0804, Src VAT: 0.0420, Trg VAT: 0.1618, Src MixUp: 0.2437, Trg MixUp: 0.5097, Src Train Acc: 99.96, Trg Train Acc: 93.97, Src Test Acc: 98.83, Trg Test Acc: 95.26, Server Test Acc: 76.23, Office Test Acc: 56.51, Conf Test Acc: 86.15
# Epoch: 090, TotalL: 6.9191, CrossE: 0.0065, CondE: 0.1612, disc: 0.5846, domain: 1.0848, Src VAT: 0.0397, Trg VAT: 0.1612, Src MixUp: 0.2338, Trg MixUp: 0.5338, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 98.44, Trg Test Acc: 93.86, Server Test Acc: 78.45, Office Test Acc: 66.85, Conf Test Acc: 86.00
# Epoch: 091, TotalL: 6.9284, CrossE: 0.0062, CondE: 0.1574, disc: 0.5910, domain: 1.0809, Src VAT: 0.0380, Trg VAT: 0.1574, Src MixUp: 0.2418, Trg MixUp: 0.5106, Src Train Acc: 100.00, Trg Train Acc: 94.18, Src Test Acc: 98.83, Trg Test Acc: 95.29, Server Test Acc: 77.56, Office Test Acc: 64.85, Conf Test Acc: 88.74
# Epoch: 092, TotalL: 6.9161, CrossE: 0.0061, CondE: 0.1539, disc: 0.5937, domain: 1.0796, Src VAT: 0.0369, Trg VAT: 0.1539, Src MixUp: 0.2317, Trg MixUp: 0.5083, Src Train Acc: 100.00, Trg Train Acc: 94.66, Src Test Acc: 98.05, Trg Test Acc: 93.30, Server Test Acc: 79.05, Office Test Acc: 70.86, Conf Test Acc: 86.81
# Epoch: 093, TotalL: 6.9252, CrossE: 0.0065, CondE: 0.1521, disc: 0.5902, domain: 1.0853, Src VAT: 0.0376, Trg VAT: 0.1521, Src MixUp: 0.2305, Trg MixUp: 0.4996, Src Train Acc: 100.00, Trg Train Acc: 94.40, Src Test Acc: 98.83, Trg Test Acc: 94.71, Server Test Acc: 81.95, Office Test Acc: 71.19, Conf Test Acc: 89.19
# Epoch: 094, TotalL: 6.9257, CrossE: 0.0065, CondE: 0.1536, disc: 0.5901, domain: 1.0805, Src VAT: 0.0381, Trg VAT: 0.1536, Src MixUp: 0.2383, Trg MixUp: 0.5125, Src Train Acc: 100.00, Trg Train Acc: 94.31, Src Test Acc: 98.83, Trg Test Acc: 94.76, Server Test Acc: 72.59, Office Test Acc: 60.96, Conf Test Acc: 82.89
# Epoch: 095, TotalL: 6.9338, CrossE: 0.0058, CondE: 0.1478, disc: 0.5896, domain: 1.0802, Src VAT: 0.0363, Trg VAT: 0.1478, Src MixUp: 0.2513, Trg MixUp: 0.4995, Src Train Acc: 100.00, Trg Train Acc: 94.36, Src Test Acc: 98.83, Trg Test Acc: 93.24, Server Test Acc: 75.56, Office Test Acc: 57.06, Conf Test Acc: 85.85
# Epoch: 096, TotalL: 6.9382, CrossE: 0.0064, CondE: 0.1555, disc: 0.5894, domain: 1.0869, Src VAT: 0.0377, Trg VAT: 0.1555, Src MixUp: 0.2471, Trg MixUp: 0.5146, Src Train Acc: 100.00, Trg Train Acc: 94.57, Src Test Acc: 99.61, Trg Test Acc: 92.42, Server Test Acc: 78.23, Office Test Acc: 74.42, Conf Test Acc: 86.00
# Epoch: 097, TotalL: 6.8804, CrossE: 0.0056, CondE: 0.1470, disc: 0.5888, domain: 1.0936, Src VAT: 0.0345, Trg VAT: 0.1470, Src MixUp: 0.2138, Trg MixUp: 0.4815, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 96.50, Trg Test Acc: 93.86, Server Test Acc: 73.11, Office Test Acc: 48.94, Conf Test Acc: 85.04
# Epoch: 098, TotalL: 6.8911, CrossE: 0.0059, CondE: 0.1444, disc: 0.5893, domain: 1.0751, Src VAT: 0.0358, Trg VAT: 0.1444, Src MixUp: 0.2246, Trg MixUp: 0.4906, Src Train Acc: 100.00, Trg Train Acc: 94.84, Src Test Acc: 98.83, Trg Test Acc: 95.38, Server Test Acc: 78.97, Office Test Acc: 63.18, Conf Test Acc: 87.78
# Epoch: 099, TotalL: 6.9098, CrossE: 0.0057, CondE: 0.1484, disc: 0.5854, domain: 1.0951, Src VAT: 0.0343, Trg VAT: 0.1484, Src MixUp: 0.2350, Trg MixUp: 0.4955, Src Train Acc: 100.00, Trg Train Acc: 94.88, Src Test Acc: 98.83, Trg Test Acc: 94.97, Server Test Acc: 79.94, Office Test Acc: 70.19, Conf Test Acc: 86.59
# Epoch: 100, TotalL: 6.8867, CrossE: 0.0050, CondE: 0.1436, disc: 0.5923, domain: 1.0835, Src VAT: 0.0329, Trg VAT: 0.1436, Src MixUp: 0.2219, Trg MixUp: 0.4758, Src Train Acc: 100.00, Trg Train Acc: 94.66, Src Test Acc: 99.61, Trg Test Acc: 95.53, Server Test Acc: 77.19, Office Test Acc: 64.07, Conf Test Acc: 87.33
# Epoch: 101, TotalL: 6.9008, CrossE: 0.0055, CondE: 0.1438, disc: 0.5912, domain: 1.0816, Src VAT: 0.0344, Trg VAT: 0.1438, Src MixUp: 0.2321, Trg MixUp: 0.4852, Src Train Acc: 100.00, Trg Train Acc: 94.70, Src Test Acc: 99.22, Trg Test Acc: 95.76, Server Test Acc: 78.23, Office Test Acc: 67.96, Conf Test Acc: 86.81
# Epoch: 102, TotalL: 6.8706, CrossE: 0.0049, CondE: 0.1375, disc: 0.5873, domain: 1.0807, Src VAT: 0.0322, Trg VAT: 0.1375, Src MixUp: 0.2203, Trg MixUp: 0.4908, Src Train Acc: 100.00, Trg Train Acc: 94.75, Src Test Acc: 98.44, Trg Test Acc: 92.69, Server Test Acc: 78.45, Office Test Acc: 73.08, Conf Test Acc: 85.04
# Epoch: 103, TotalL: 6.8865, CrossE: 0.0052, CondE: 0.1404, disc: 0.5895, domain: 1.0898, Src VAT: 0.0329, Trg VAT: 0.1404, Src MixUp: 0.2314, Trg MixUp: 0.4657, Src Train Acc: 100.00, Trg Train Acc: 95.01, Src Test Acc: 98.83, Trg Test Acc: 94.53, Server Test Acc: 75.78, Office Test Acc: 55.84, Conf Test Acc: 88.00
# Epoch: 104, TotalL: 6.8800, CrossE: 0.0048, CondE: 0.1359, disc: 0.5863, domain: 1.0879, Src VAT: 0.0318, Trg VAT: 0.1359, Src MixUp: 0.2276, Trg MixUp: 0.4695, Src Train Acc: 100.00, Trg Train Acc: 94.88, Src Test Acc: 99.61, Trg Test Acc: 94.74, Server Test Acc: 78.08, Office Test Acc: 57.51, Conf Test Acc: 87.70
# Epoch: 105, TotalL: 6.8575, CrossE: 0.0049, CondE: 0.1383, disc: 0.5859, domain: 1.0994, Src VAT: 0.0317, Trg VAT: 0.1383, Src MixUp: 0.2106, Trg MixUp: 0.4823, Src Train Acc: 100.00, Trg Train Acc: 94.66, Src Test Acc: 98.05, Trg Test Acc: 94.03, Server Test Acc: 74.52, Office Test Acc: 67.52, Conf Test Acc: 84.15
# Epoch: 106, TotalL: 6.8883, CrossE: 0.0054, CondE: 0.1354, disc: 0.6020, domain: 1.0812, Src VAT: 0.0339, Trg VAT: 0.1354, Src MixUp: 0.2271, Trg MixUp: 0.4521, Src Train Acc: 100.00, Trg Train Acc: 94.79, Src Test Acc: 97.67, Trg Test Acc: 94.00, Server Test Acc: 78.31, Office Test Acc: 70.30, Conf Test Acc: 87.63
# Epoch: 107, TotalL: 6.8671, CrossE: 0.0054, CondE: 0.1315, disc: 0.5922, domain: 1.0771, Src VAT: 0.0319, Trg VAT: 0.1315, Src MixUp: 0.2207, Trg MixUp: 0.4614, Src Train Acc: 99.96, Trg Train Acc: 95.05, Src Test Acc: 98.44, Trg Test Acc: 92.98, Server Test Acc: 73.70, Office Test Acc: 61.85, Conf Test Acc: 86.44
# Epoch: 108, TotalL: 6.8937, CrossE: 0.0061, CondE: 0.1341, disc: 0.5983, domain: 1.0765, Src VAT: 0.0331, Trg VAT: 0.1341, Src MixUp: 0.2286, Trg MixUp: 0.4756, Src Train Acc: 99.96, Trg Train Acc: 95.18, Src Test Acc: 98.44, Trg Test Acc: 94.82, Server Test Acc: 77.12, Office Test Acc: 69.52, Conf Test Acc: 86.44
# Epoch: 109, TotalL: 6.8723, CrossE: 0.0049, CondE: 0.1299, disc: 0.5930, domain: 1.0817, Src VAT: 0.0313, Trg VAT: 0.1299, Src MixUp: 0.2188, Trg MixUp: 0.4674, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 99.22, Trg Test Acc: 92.83, Server Test Acc: 80.53, Office Test Acc: 77.75, Conf Test Acc: 87.56
# Epoch: 110, TotalL: 6.8320, CrossE: 0.0044, CondE: 0.1229, disc: 0.5871, domain: 1.0784, Src VAT: 0.0293, Trg VAT: 0.1229, Src MixUp: 0.2051, Trg MixUp: 0.4539, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 99.22, Trg Test Acc: 95.38, Server Test Acc: 79.27, Office Test Acc: 68.41, Conf Test Acc: 90.00
# Epoch: 111, TotalL: 6.8821, CrossE: 0.0061, CondE: 0.1294, disc: 0.5962, domain: 1.0738, Src VAT: 0.0323, Trg VAT: 0.1294, Src MixUp: 0.2205, Trg MixUp: 0.4492, Src Train Acc: 99.96, Trg Train Acc: 94.62, Src Test Acc: 98.83, Trg Test Acc: 94.62, Server Test Acc: 79.72, Office Test Acc: 61.07, Conf Test Acc: 86.59
# Epoch: 112, TotalL: 6.8409, CrossE: 0.0043, CondE: 0.1272, disc: 0.5916, domain: 1.0756, Src VAT: 0.0290, Trg VAT: 0.1272, Src MixUp: 0.2133, Trg MixUp: 0.4525, Src Train Acc: 100.00, Trg Train Acc: 94.97, Src Test Acc: 99.22, Trg Test Acc: 95.20, Server Test Acc: 78.97, Office Test Acc: 69.86, Conf Test Acc: 88.30
# Epoch: 113, TotalL: 6.8452, CrossE: 0.0041, CondE: 0.1226, disc: 0.5899, domain: 1.0856, Src VAT: 0.0276, Trg VAT: 0.1226, Src MixUp: 0.2164, Trg MixUp: 0.4431, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 99.22, Trg Test Acc: 94.33, Server Test Acc: 74.67, Office Test Acc: 75.31, Conf Test Acc: 83.04
# Epoch: 114, TotalL: 6.8326, CrossE: 0.0040, CondE: 0.1246, disc: 0.5912, domain: 1.0799, Src VAT: 0.0278, Trg VAT: 0.1246, Src MixUp: 0.2076, Trg MixUp: 0.4603, Src Train Acc: 100.00, Trg Train Acc: 94.97, Src Test Acc: 99.61, Trg Test Acc: 95.55, Server Test Acc: 80.39, Office Test Acc: 64.96, Conf Test Acc: 89.85
# Epoch: 115, TotalL: 6.8360, CrossE: 0.0045, CondE: 0.1292, disc: 0.5913, domain: 1.0868, Src VAT: 0.0300, Trg VAT: 0.1292, Src MixUp: 0.2106, Trg MixUp: 0.4634, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 99.61, Trg Test Acc: 94.06, Server Test Acc: 78.23, Office Test Acc: 73.53, Conf Test Acc: 86.67
# Epoch: 116, TotalL: 6.8404, CrossE: 0.0045, CondE: 0.1164, disc: 0.5980, domain: 1.0765, Src VAT: 0.0285, Trg VAT: 0.1164, Src MixUp: 0.2053, Trg MixUp: 0.4401, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 97.28, Trg Test Acc: 89.06, Server Test Acc: 80.16, Office Test Acc: 73.75, Conf Test Acc: 88.22
# Epoch: 117, TotalL: 6.8607, CrossE: 0.0047, CondE: 0.1236, disc: 0.5964, domain: 1.0786, Src VAT: 0.0294, Trg VAT: 0.1236, Src MixUp: 0.2208, Trg MixUp: 0.4558, Src Train Acc: 100.00, Trg Train Acc: 94.97, Src Test Acc: 98.44, Trg Test Acc: 95.58, Server Test Acc: 76.00, Office Test Acc: 71.52, Conf Test Acc: 88.89
# Epoch: 118, TotalL: 6.8530, CrossE: 0.0045, CondE: 0.1198, disc: 0.5935, domain: 1.0884, Src VAT: 0.0294, Trg VAT: 0.1198, Src MixUp: 0.2133, Trg MixUp: 0.4603, Src Train Acc: 100.00, Trg Train Acc: 95.36, Src Test Acc: 99.22, Trg Test Acc: 95.47, Server Test Acc: 77.64, Office Test Acc: 65.52, Conf Test Acc: 89.11
# Epoch: 119, TotalL: 6.8193, CrossE: 0.0037, CondE: 0.1144, disc: 0.5887, domain: 1.0789, Src VAT: 0.0255, Trg VAT: 0.1144, Src MixUp: 0.2019, Trg MixUp: 0.4273, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 99.61, Trg Test Acc: 94.88, Server Test Acc: 80.46, Office Test Acc: 68.19, Conf Test Acc: 89.63
# Epoch: 120, TotalL: 6.8248, CrossE: 0.0040, CondE: 0.1096, disc: 0.5915, domain: 1.0861, Src VAT: 0.0264, Trg VAT: 0.1096, Src MixUp: 0.2075, Trg MixUp: 0.4317, Src Train Acc: 100.00, Trg Train Acc: 94.97, Src Test Acc: 99.22, Trg Test Acc: 96.55, Server Test Acc: 80.46, Office Test Acc: 72.41, Conf Test Acc: 89.19
# Epoch: 121, TotalL: 6.8164, CrossE: 0.0039, CondE: 0.1102, disc: 0.5898, domain: 1.0877, Src VAT: 0.0262, Trg VAT: 0.1102, Src MixUp: 0.2067, Trg MixUp: 0.4218, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 98.44, Trg Test Acc: 95.20, Server Test Acc: 81.35, Office Test Acc: 73.64, Conf Test Acc: 89.93
# Epoch: 122, TotalL: 6.8548, CrossE: 0.0054, CondE: 0.1128, disc: 0.6020, domain: 1.0793, Src VAT: 0.0297, Trg VAT: 0.1128, Src MixUp: 0.2189, Trg MixUp: 0.4408, Src Train Acc: 99.96, Trg Train Acc: 94.97, Src Test Acc: 98.83, Trg Test Acc: 95.00, Server Test Acc: 79.72, Office Test Acc: 64.18, Conf Test Acc: 88.15
# Epoch: 123, TotalL: 6.8179, CrossE: 0.0037, CondE: 0.1142, disc: 0.5886, domain: 1.0782, Src VAT: 0.0259, Trg VAT: 0.1142, Src MixUp: 0.2120, Trg MixUp: 0.4437, Src Train Acc: 100.00, Trg Train Acc: 95.40, Src Test Acc: 98.83, Trg Test Acc: 95.17, Server Test Acc: 80.24, Office Test Acc: 62.74, Conf Test Acc: 88.44
# Epoch: 124, TotalL: 6.8422, CrossE: 0.0043, CondE: 0.1162, disc: 0.5942, domain: 1.0885, Src VAT: 0.0275, Trg VAT: 0.1162, Src MixUp: 0.2128, Trg MixUp: 0.4440, Src Train Acc: 100.00, Trg Train Acc: 94.66, Src Test Acc: 98.83, Trg Test Acc: 96.05, Server Test Acc: 82.24, Office Test Acc: 73.53, Conf Test Acc: 90.00
# Epoch: 125, TotalL: 6.7976, CrossE: 0.0037, CondE: 0.1085, disc: 0.5896, domain: 1.0805, Src VAT: 0.0257, Trg VAT: 0.1085, Src MixUp: 0.1971, Trg MixUp: 0.4347, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 99.22, Trg Test Acc: 94.44, Server Test Acc: 78.31, Office Test Acc: 53.84, Conf Test Acc: 90.15
# Epoch: 126, TotalL: 6.8128, CrossE: 0.0038, CondE: 0.1105, disc: 0.5935, domain: 1.0797, Src VAT: 0.0260, Trg VAT: 0.1105, Src MixUp: 0.2109, Trg MixUp: 0.4337, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 98.83, Trg Test Acc: 93.19, Server Test Acc: 78.75, Office Test Acc: 55.95, Conf Test Acc: 87.04
# Epoch: 127, TotalL: 6.8108, CrossE: 0.0038, CondE: 0.1059, disc: 0.5952, domain: 1.0791, Src VAT: 0.0249, Trg VAT: 0.1059, Src MixUp: 0.2005, Trg MixUp: 0.4383, Src Train Acc: 100.00, Trg Train Acc: 95.31, Src Test Acc: 98.83, Trg Test Acc: 97.10, Server Test Acc: 79.57, Office Test Acc: 65.07, Conf Test Acc: 88.22
# Epoch: 128, TotalL: 6.8092, CrossE: 0.0037, CondE: 0.1058, disc: 0.5890, domain: 1.0938, Src VAT: 0.0246, Trg VAT: 0.1058, Src MixUp: 0.2027, Trg MixUp: 0.4176, Src Train Acc: 100.00, Trg Train Acc: 95.27, Src Test Acc: 99.22, Trg Test Acc: 94.94, Server Test Acc: 80.31, Office Test Acc: 68.52, Conf Test Acc: 89.19
# Epoch: 129, TotalL: 6.8135, CrossE: 0.0034, CondE: 0.1031, disc: 0.5994, domain: 1.0846, Src VAT: 0.0232, Trg VAT: 0.1031, Src MixUp: 0.1993, Trg MixUp: 0.4352, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 99.22, Trg Test Acc: 95.82, Server Test Acc: 77.86, Office Test Acc: 66.30, Conf Test Acc: 87.85
# Epoch: 130, TotalL: 6.8120, CrossE: 0.0040, CondE: 0.1079, disc: 0.5976, domain: 1.0785, Src VAT: 0.0254, Trg VAT: 0.1079, Src MixUp: 0.1965, Trg MixUp: 0.4384, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 98.83, Trg Test Acc: 95.67, Server Test Acc: 79.49, Office Test Acc: 67.52, Conf Test Acc: 89.11
# Epoch: 131, TotalL: 6.7957, CrossE: 0.0034, CondE: 0.1062, disc: 0.5881, domain: 1.0827, Src VAT: 0.0242, Trg VAT: 0.1062, Src MixUp: 0.1975, Trg MixUp: 0.4244, Src Train Acc: 100.00, Trg Train Acc: 95.18, Src Test Acc: 98.05, Trg Test Acc: 94.03, Server Test Acc: 75.04, Office Test Acc: 66.96, Conf Test Acc: 83.70
# Epoch: 132, TotalL: 6.8048, CrossE: 0.0037, CondE: 0.1017, disc: 0.5994, domain: 1.0720, Src VAT: 0.0249, Trg VAT: 0.1017, Src MixUp: 0.2018, Trg MixUp: 0.4160, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 99.22, Trg Test Acc: 95.44, Server Test Acc: 76.82, Office Test Acc: 67.96, Conf Test Acc: 87.56
# Epoch: 133, TotalL: 6.8047, CrossE: 0.0038, CondE: 0.1036, disc: 0.5938, domain: 1.0753, Src VAT: 0.0251, Trg VAT: 0.1036, Src MixUp: 0.1982, Trg MixUp: 0.4109, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 98.83, Trg Test Acc: 95.73, Server Test Acc: 81.50, Office Test Acc: 63.07, Conf Test Acc: 89.04
# Epoch: 134, TotalL: 6.7833, CrossE: 0.0033, CondE: 0.1038, disc: 0.5960, domain: 1.0679, Src VAT: 0.0240, Trg VAT: 0.1038, Src MixUp: 0.1988, Trg MixUp: 0.4012, Src Train Acc: 100.00, Trg Train Acc: 95.40, Src Test Acc: 98.83, Trg Test Acc: 93.24, Server Test Acc: 74.44, Office Test Acc: 72.30, Conf Test Acc: 81.93
# Epoch: 135, TotalL: 6.7898, CrossE: 0.0033, CondE: 0.1007, disc: 0.5881, domain: 1.0732, Src VAT: 0.0236, Trg VAT: 0.1007, Src MixUp: 0.2004, Trg MixUp: 0.4376, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 99.22, Trg Test Acc: 95.64, Server Test Acc: 79.42, Office Test Acc: 61.40, Conf Test Acc: 88.52
# Epoch: 136, TotalL: 6.8026, CrossE: 0.0036, CondE: 0.1040, disc: 0.5936, domain: 1.0809, Src VAT: 0.0250, Trg VAT: 0.1040, Src MixUp: 0.2050, Trg MixUp: 0.4193, Src Train Acc: 100.00, Trg Train Acc: 95.18, Src Test Acc: 98.05, Trg Test Acc: 95.47, Server Test Acc: 76.67, Office Test Acc: 64.96, Conf Test Acc: 87.33
# Epoch: 137, TotalL: 6.7928, CrossE: 0.0039, CondE: 0.0960, disc: 0.5955, domain: 1.0748, Src VAT: 0.0249, Trg VAT: 0.0960, Src MixUp: 0.1937, Trg MixUp: 0.4189, Src Train Acc: 100.00, Trg Train Acc: 95.40, Src Test Acc: 98.44, Trg Test Acc: 95.32, Server Test Acc: 80.24, Office Test Acc: 73.41, Conf Test Acc: 89.63
# Epoch: 138, TotalL: 6.7817, CrossE: 0.0031, CondE: 0.0966, disc: 0.5940, domain: 1.0808, Src VAT: 0.0221, Trg VAT: 0.0966, Src MixUp: 0.1902, Trg MixUp: 0.4253, Src Train Acc: 100.00, Trg Train Acc: 95.44, Src Test Acc: 97.28, Trg Test Acc: 93.36, Server Test Acc: 75.63, Office Test Acc: 60.29, Conf Test Acc: 85.11
# Epoch: 139, TotalL: 6.7751, CrossE: 0.0033, CondE: 0.0918, disc: 0.5901, domain: 1.0855, Src VAT: 0.0219, Trg VAT: 0.0918, Src MixUp: 0.1865, Trg MixUp: 0.4040, Src Train Acc: 100.00, Trg Train Acc: 95.14, Src Test Acc: 98.83, Trg Test Acc: 96.75, Server Test Acc: 82.17, Office Test Acc: 76.08, Conf Test Acc: 89.33
# Epoch: 140, TotalL: 6.7665, CrossE: 0.0032, CondE: 0.0940, disc: 0.5897, domain: 1.0830, Src VAT: 0.0221, Trg VAT: 0.0940, Src MixUp: 0.1876, Trg MixUp: 0.3936, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 99.22, Trg Test Acc: 95.88, Server Test Acc: 81.72, Office Test Acc: 71.08, Conf Test Acc: 90.52
# Epoch: 141, TotalL: 6.7648, CrossE: 0.0034, CondE: 0.0917, disc: 0.5864, domain: 1.0862, Src VAT: 0.0211, Trg VAT: 0.0917, Src MixUp: 0.1894, Trg MixUp: 0.3929, Src Train Acc: 99.96, Trg Train Acc: 95.31, Src Test Acc: 96.50, Trg Test Acc: 93.36, Server Test Acc: 78.08, Office Test Acc: 80.20, Conf Test Acc: 87.41
# Epoch: 142, TotalL: 6.7568, CrossE: 0.0030, CondE: 0.0899, disc: 0.5952, domain: 1.0782, Src VAT: 0.0211, Trg VAT: 0.0899, Src MixUp: 0.1778, Trg MixUp: 0.4040, Src Train Acc: 100.00, Trg Train Acc: 95.49, Src Test Acc: 98.83, Trg Test Acc: 95.61, Server Test Acc: 80.61, Office Test Acc: 71.08, Conf Test Acc: 89.85
# Epoch: 143, TotalL: 6.7836, CrossE: 0.0030, CondE: 0.0913, disc: 0.5982, domain: 1.0858, Src VAT: 0.0210, Trg VAT: 0.0913, Src MixUp: 0.1951, Trg MixUp: 0.4031, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 98.83, Trg Test Acc: 94.44, Server Test Acc: 79.64, Office Test Acc: 62.29, Conf Test Acc: 89.19
# Epoch: 144, TotalL: 6.7595, CrossE: 0.0028, CondE: 0.0875, disc: 0.5963, domain: 1.0807, Src VAT: 0.0203, Trg VAT: 0.0875, Src MixUp: 0.1871, Trg MixUp: 0.3766, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 98.83, Trg Test Acc: 96.55, Server Test Acc: 82.47, Office Test Acc: 66.30, Conf Test Acc: 90.67
# Epoch: 145, TotalL: 6.7681, CrossE: 0.0031, CondE: 0.0899, disc: 0.6031, domain: 1.0706, Src VAT: 0.0222, Trg VAT: 0.0899, Src MixUp: 0.1950, Trg MixUp: 0.3830, Src Train Acc: 100.00, Trg Train Acc: 95.40, Src Test Acc: 98.83, Trg Test Acc: 94.94, Server Test Acc: 81.58, Office Test Acc: 77.53, Conf Test Acc: 89.26
# Epoch: 146, TotalL: 6.7682, CrossE: 0.0029, CondE: 0.0882, disc: 0.6014, domain: 1.0627, Src VAT: 0.0210, Trg VAT: 0.0882, Src MixUp: 0.1882, Trg MixUp: 0.3912, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.22, Trg Test Acc: 95.47, Server Test Acc: 78.53, Office Test Acc: 58.06, Conf Test Acc: 89.70
# ...
# Epoch: 589, TotalL: 6.5388, CrossE: 0.0007, CondE: 0.0087, disc: 0.6796, domain: 0.7482, Src VAT: 0.0064, Trg VAT: 0.0087, Src MixUp: 0.1239, Trg MixUp: 0.2133, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.46, Server Test Acc: 82.47, Office Test Acc: 72.75, Conf Test Acc: 88.44
# Epoch: 590, TotalL: 6.5265, CrossE: 0.0006, CondE: 0.0072, disc: 0.6823, domain: 0.7380, Src VAT: 0.0061, Trg VAT: 0.0072, Src MixUp: 0.1229, Trg MixUp: 0.2048, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.05, Server Test Acc: 83.73, Office Test Acc: 75.19, Conf Test Acc: 89.63
# Epoch: 591, TotalL: 6.5332, CrossE: 0.0008, CondE: 0.0082, disc: 0.6850, domain: 0.7347, Src VAT: 0.0070, Trg VAT: 0.0082, Src MixUp: 0.1284, Trg MixUp: 0.2065, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.37, Server Test Acc: 82.91, Office Test Acc: 76.08, Conf Test Acc: 90.44
# Epoch: 592, TotalL: 6.5367, CrossE: 0.0008, CondE: 0.0086, disc: 0.6852, domain: 0.7359, Src VAT: 0.0072, Trg VAT: 0.0086, Src MixUp: 0.1316, Trg MixUp: 0.2128, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.93, Server Test Acc: 83.66, Office Test Acc: 77.20, Conf Test Acc: 89.56
# Epoch: 593, TotalL: 6.5309, CrossE: 0.0007, CondE: 0.0076, disc: 0.6847, domain: 0.7322, Src VAT: 0.0064, Trg VAT: 0.0076, Src MixUp: 0.1270, Trg MixUp: 0.2079, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.81, Server Test Acc: 83.73, Office Test Acc: 71.97, Conf Test Acc: 90.74
# Epoch: 594, TotalL: 6.5476, CrossE: 0.0009, CondE: 0.0097, disc: 0.6816, domain: 0.7417, Src VAT: 0.0076, Trg VAT: 0.0097, Src MixUp: 0.1326, Trg MixUp: 0.2161, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 98.44, Trg Test Acc: 93.48, Server Test Acc: 77.64, Office Test Acc: 56.28, Conf Test Acc: 86.59
# Epoch: 595, TotalL: 6.5513, CrossE: 0.0009, CondE: 0.0090, disc: 0.6799, domain: 0.7468, Src VAT: 0.0073, Trg VAT: 0.0090, Src MixUp: 0.1300, Trg MixUp: 0.2344, Src Train Acc: 100.00, Trg Train Acc: 95.49, Src Test Acc: 100.00, Trg Test Acc: 96.58, Server Test Acc: 84.47, Office Test Acc: 76.75, Conf Test Acc: 89.78
# Epoch: 596, TotalL: 6.5283, CrossE: 0.0007, CondE: 0.0076, disc: 0.6819, domain: 0.7423, Src VAT: 0.0062, Trg VAT: 0.0076, Src MixUp: 0.1269, Trg MixUp: 0.2005, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 96.20, Server Test Acc: 84.03, Office Test Acc: 75.75, Conf Test Acc: 90.37
# Epoch: 597, TotalL: 6.5199, CrossE: 0.0006, CondE: 0.0072, disc: 0.6831, domain: 0.7390, Src VAT: 0.0061, Trg VAT: 0.0072, Src MixUp: 0.1199, Trg MixUp: 0.2154, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.22, Trg Test Acc: 94.85, Server Test Acc: 79.35, Office Test Acc: 52.84, Conf Test Acc: 88.52
# Epoch: 598, TotalL: 6.5295, CrossE: 0.0007, CondE: 0.0076, disc: 0.6844, domain: 0.7373, Src VAT: 0.0062, Trg VAT: 0.0076, Src MixUp: 0.1246, Trg MixUp: 0.2055, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 96.64, Server Test Acc: 84.03, Office Test Acc: 76.42, Conf Test Acc: 90.52
# Epoch: 599, TotalL: 6.5241, CrossE: 0.0007, CondE: 0.0077, disc: 0.6861, domain: 0.7361, Src VAT: 0.0063, Trg VAT: 0.0077, Src MixUp: 0.1243, Trg MixUp: 0.2123, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.69, Server Test Acc: 84.03, Office Test Acc: 78.31, Conf Test Acc: 88.00
# Epoch: 600, TotalL: 6.5333, CrossE: 0.0007, CondE: 0.0078, disc: 0.6864, domain: 0.7349, Src VAT: 0.0068, Trg VAT: 0.0078, Src MixUp: 0.1305, Trg MixUp: 0.2154, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 97.13, Server Test Acc: 84.70, Office Test Acc: 79.42, Conf Test Acc: 89.48
# Epoch: 601, TotalL: 6.5463, CrossE: 0.0009, CondE: 0.0092, disc: 0.6829, domain: 0.7387, Src VAT: 0.0079, Trg VAT: 0.0092, Src MixUp: 0.1331, Trg MixUp: 0.2265, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.46, Server Test Acc: 84.77, Office Test Acc: 75.75, Conf Test Acc: 89.26
# Epoch: 602, TotalL: 6.5374, CrossE: 0.0008, CondE: 0.0090, disc: 0.6830, domain: 0.7386, Src VAT: 0.0071, Trg VAT: 0.0090, Src MixUp: 0.1316, Trg MixUp: 0.2182, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.54, Server Test Acc: 83.66, Office Test Acc: 77.09, Conf Test Acc: 90.00
# Epoch: 603, TotalL: 6.5401, CrossE: 0.0008, CondE: 0.0089, disc: 0.6845, domain: 0.7381, Src VAT: 0.0074, Trg VAT: 0.0089, Src MixUp: 0.1337, Trg MixUp: 0.2210, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.13, Server Test Acc: 80.68, Office Test Acc: 62.85, Conf Test Acc: 90.07
# Epoch: 604, TotalL: 6.5249, CrossE: 0.0007, CondE: 0.0076, disc: 0.6851, domain: 0.7324, Src VAT: 0.0062, Trg VAT: 0.0076, Src MixUp: 0.1257, Trg MixUp: 0.2183, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 96.11, Server Test Acc: 83.43, Office Test Acc: 70.86, Conf Test Acc: 88.44
# Epoch: 605, TotalL: 6.5373, CrossE: 0.0008, CondE: 0.0084, disc: 0.6832, domain: 0.7348, Src VAT: 0.0076, Trg VAT: 0.0084, Src MixUp: 0.1365, Trg MixUp: 0.2212, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.13, Server Test Acc: 82.84, Office Test Acc: 72.75, Conf Test Acc: 90.00
# Epoch: 606, TotalL: 6.5384, CrossE: 0.0009, CondE: 0.0080, disc: 0.6845, domain: 0.7401, Src VAT: 0.0074, Trg VAT: 0.0080, Src MixUp: 0.1231, Trg MixUp: 0.2202, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.31, Server Test Acc: 81.50, Office Test Acc: 73.19, Conf Test Acc: 89.56
# Epoch: 607, TotalL: 6.5400, CrossE: 0.0007, CondE: 0.0082, disc: 0.6839, domain: 0.7387, Src VAT: 0.0067, Trg VAT: 0.0082, Src MixUp: 0.1279, Trg MixUp: 0.2143, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.16, Server Test Acc: 82.76, Office Test Acc: 71.52, Conf Test Acc: 89.63
# Epoch: 608, TotalL: 6.5453, CrossE: 0.0013, CondE: 0.0094, disc: 0.6822, domain: 0.7413, Src VAT: 0.0083, Trg VAT: 0.0094, Src MixUp: 0.1315, Trg MixUp: 0.2183, Src Train Acc: 99.96, Trg Train Acc: 95.57, Src Test Acc: 100.00, Trg Test Acc: 96.69, Server Test Acc: 83.95, Office Test Acc: 72.97, Conf Test Acc: 88.74
# Epoch: 609, TotalL: 6.5190, CrossE: 0.0006, CondE: 0.0074, disc: 0.6838, domain: 0.7346, Src VAT: 0.0060, Trg VAT: 0.0074, Src MixUp: 0.1199, Trg MixUp: 0.2053, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 96.67, Server Test Acc: 83.51, Office Test Acc: 75.97, Conf Test Acc: 88.67
# Epoch: 610, TotalL: 6.5148, CrossE: 0.0007, CondE: 0.0074, disc: 0.6871, domain: 0.7268, Src VAT: 0.0065, Trg VAT: 0.0074, Src MixUp: 0.1197, Trg MixUp: 0.2103, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.08, Server Test Acc: 84.99, Office Test Acc: 75.97, Conf Test Acc: 90.89
# Epoch: 611, TotalL: 6.5458, CrossE: 0.0010, CondE: 0.0100, disc: 0.6879, domain: 0.7375, Src VAT: 0.0084, Trg VAT: 0.0100, Src MixUp: 0.1319, Trg MixUp: 0.2284, Src Train Acc: 100.00, Trg Train Acc: 95.49, Src Test Acc: 100.00, Trg Test Acc: 97.34, Server Test Acc: 84.99, Office Test Acc: 74.75, Conf Test Acc: 91.26
# Epoch: 612, TotalL: 6.5283, CrossE: 0.0007, CondE: 0.0082, disc: 0.6830, domain: 0.7346, Src VAT: 0.0064, Trg VAT: 0.0082, Src MixUp: 0.1226, Trg MixUp: 0.2253, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.51, Server Test Acc: 84.03, Office Test Acc: 73.53, Conf Test Acc: 90.15
# Epoch: 613, TotalL: 6.5308, CrossE: 0.0007, CondE: 0.0082, disc: 0.6842, domain: 0.7327, Src VAT: 0.0069, Trg VAT: 0.0082, Src MixUp: 0.1294, Trg MixUp: 0.2095, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.22, Trg Test Acc: 97.08, Server Test Acc: 82.17, Office Test Acc: 70.97, Conf Test Acc: 89.56
# Epoch: 614, TotalL: 6.5250, CrossE: 0.0008, CondE: 0.0082, disc: 0.6870, domain: 0.7284, Src VAT: 0.0071, Trg VAT: 0.0082, Src MixUp: 0.1256, Trg MixUp: 0.2137, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.16, Server Test Acc: 84.77, Office Test Acc: 75.42, Conf Test Acc: 90.59
# Epoch: 615, TotalL: 6.5248, CrossE: 0.0008, CondE: 0.0080, disc: 0.6898, domain: 0.7271, Src VAT: 0.0070, Trg VAT: 0.0080, Src MixUp: 0.1267, Trg MixUp: 0.2154, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 98.83, Trg Test Acc: 96.52, Server Test Acc: 81.58, Office Test Acc: 74.64, Conf Test Acc: 89.19
# Epoch: 616, TotalL: 6.5243, CrossE: 0.0007, CondE: 0.0080, disc: 0.6874, domain: 0.7304, Src VAT: 0.0067, Trg VAT: 0.0080, Src MixUp: 0.1251, Trg MixUp: 0.2119, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.16, Server Test Acc: 83.88, Office Test Acc: 74.42, Conf Test Acc: 90.30
# Epoch: 617, TotalL: 6.5270, CrossE: 0.0008, CondE: 0.0084, disc: 0.6885, domain: 0.7299, Src VAT: 0.0071, Trg VAT: 0.0084, Src MixUp: 0.1265, Trg MixUp: 0.2166, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 94.74, Server Test Acc: 81.50, Office Test Acc: 70.41, Conf Test Acc: 88.07
# Epoch: 618, TotalL: 6.5317, CrossE: 0.0008, CondE: 0.0086, disc: 0.6846, domain: 0.7315, Src VAT: 0.0073, Trg VAT: 0.0086, Src MixUp: 0.1262, Trg MixUp: 0.2151, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.61, Trg Test Acc: 96.11, Server Test Acc: 84.55, Office Test Acc: 76.97, Conf Test Acc: 91.63
# Epoch: 619, TotalL: 6.5635, CrossE: 0.0010, CondE: 0.0104, disc: 0.6876, domain: 0.7421, Src VAT: 0.0082, Trg VAT: 0.0104, Src MixUp: 0.1368, Trg MixUp: 0.2306, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.16, Server Test Acc: 82.76, Office Test Acc: 68.97, Conf Test Acc: 89.19
# Epoch: 620, TotalL: 6.5360, CrossE: 0.0008, CondE: 0.0088, disc: 0.6870, domain: 0.7274, Src VAT: 0.0072, Trg VAT: 0.0088, Src MixUp: 0.1282, Trg MixUp: 0.2122, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.40, Server Test Acc: 84.84, Office Test Acc: 74.19, Conf Test Acc: 90.15
# Epoch: 621, TotalL: 6.5222, CrossE: 0.0007, CondE: 0.0083, disc: 0.6851, domain: 0.7282, Src VAT: 0.0068, Trg VAT: 0.0083, Src MixUp: 0.1230, Trg MixUp: 0.2146, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.99, Server Test Acc: 83.21, Office Test Acc: 67.30, Conf Test Acc: 90.81
# Epoch: 622, TotalL: 6.5323, CrossE: 0.0008, CondE: 0.0091, disc: 0.6817, domain: 0.7353, Src VAT: 0.0074, Trg VAT: 0.0091, Src MixUp: 0.1308, Trg MixUp: 0.2205, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.08, Server Test Acc: 81.95, Office Test Acc: 65.18, Conf Test Acc: 89.33
# Epoch: 623, TotalL: 6.5273, CrossE: 0.0007, CondE: 0.0087, disc: 0.6839, domain: 0.7354, Src VAT: 0.0069, Trg VAT: 0.0087, Src MixUp: 0.1255, Trg MixUp: 0.2021, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 99.22, Trg Test Acc: 95.76, Server Test Acc: 79.87, Office Test Acc: 60.73, Conf Test Acc: 87.93
# Epoch: 624, TotalL: 6.5397, CrossE: 0.0008, CondE: 0.0084, disc: 0.6836, domain: 0.7395, Src VAT: 0.0071, Trg VAT: 0.0084, Src MixUp: 0.1248, Trg MixUp: 0.2223, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.28, Server Test Acc: 81.28, Office Test Acc: 75.31, Conf Test Acc: 90.00
# Epoch: 625, TotalL: 6.5592, CrossE: 0.0010, CondE: 0.0092, disc: 0.6828, domain: 0.7435, Src VAT: 0.0080, Trg VAT: 0.0092, Src MixUp: 0.1343, Trg MixUp: 0.2235, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.67, Server Test Acc: 84.55, Office Test Acc: 76.53, Conf Test Acc: 91.04
# Epoch: 626, TotalL: 6.5314, CrossE: 0.0007, CondE: 0.0083, disc: 0.6801, domain: 0.7418, Src VAT: 0.0067, Trg VAT: 0.0083, Src MixUp: 0.1247, Trg MixUp: 0.2321, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 96.90, Server Test Acc: 84.18, Office Test Acc: 75.75, Conf Test Acc: 90.07
# Epoch: 627, TotalL: 6.5278, CrossE: 0.0008, CondE: 0.0090, disc: 0.6826, domain: 0.7360, Src VAT: 0.0072, Trg VAT: 0.0090, Src MixUp: 0.1280, Trg MixUp: 0.2147, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.22, Server Test Acc: 82.84, Office Test Acc: 72.75, Conf Test Acc: 89.78
# Epoch: 628, TotalL: 6.5247, CrossE: 0.0007, CondE: 0.0080, disc: 0.6828, domain: 0.7352, Src VAT: 0.0065, Trg VAT: 0.0080, Src MixUp: 0.1253, Trg MixUp: 0.2168, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.31, Server Test Acc: 83.73, Office Test Acc: 74.08, Conf Test Acc: 90.74
# Epoch: 629, TotalL: 6.5243, CrossE: 0.0007, CondE: 0.0079, disc: 0.6856, domain: 0.7328, Src VAT: 0.0064, Trg VAT: 0.0079, Src MixUp: 0.1246, Trg MixUp: 0.2137, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 100.00, Trg Test Acc: 97.08, Server Test Acc: 82.62, Office Test Acc: 72.86, Conf Test Acc: 89.70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-699a02a1018f> in <module>
#      43
#      44   for source_data, target_data in zip(src_train_set, trg_train_set):
# ---> 45     train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])
#      46     train_disc_step(source_data[0], target_data[0])
#      47
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     400       # In this case we have created variables on the first call, so we run the
#     401       # defunned version which is guaranteed to never create variables.
# --> 402       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     403     elif self._stateful_fn is not None:
#     404       # In this case we have not created variables on the first call. So we can
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1322     """Calls a graph function specialized to the inputs."""
#    1323     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1324     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1325
#    1326   @property
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#     576     """
#     577     return self._call_flat(
# --> 578         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#     579          if isinstance(t, (ops.Tensor,
#     580                            resource_variable_ops.ResourceVariable))))
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args)
#     658     # Only need to override the gradient in graph mode and when we have outputs.
#     659     if context.executing_eagerly() or not self.outputs:
# --> 660       outputs = self._inference_function.call(ctx, args)
#     661     else:
#     662       self._register_gradient()
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args)
#     432             attrs=("executor_type", executor_type,
#     433                    "config_proto", config),
# --> 434             ctx=ctx)
#     435       # Replace empty list with None
#     436       outputs = outputs or None
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
