# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='1'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 1000
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
alpha           = 0.05
disc_activation = 'selu'
gen_activation  = 'selu'
notes           = "VMT_gauss_noise_cv_data_center_loss_test_domain_adapt_need" 

log_data = "num_classes-{}_batch_size-{}_train_src_days-{}_train_trg_days-{}_lr-{}_num_hidden-{}_num_features-{}_disc_act-{}_gen_act-{}_center_alpha-{}_notes-{}".format(num_classes, 
                                                                                                                                                                                  batch_size, 
                                                                                                                                                                                  train_src_days, 
                                                                                                                                                                                  train_trg_days, 
                                                                                                                                                                                  learning_rate, 
                                                                                                                                                                                  num_hidden, 
                                                                                                                                                                                  num_features,
                                                                                                                                                                                  disc_activation,
                                                                                                                                                                                  gen_activation,
                                                                                                                                                                                  alpha,
                                                                                                                                                                                  notes)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
classes = [n.decode("ascii", "ignore") for n in classes]
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9127, 128, 1024, 1) (9127, 2)
#  ['arahman3', 'harika', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8737, 128, 1024, 1) (8737, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8547, 128, 1024, 1) (8547, 2)
#  ['arahman3', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2563, 128, 1024, 1) (2563, 9) (3419, 128, 1024, 1) (3419, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (2563, 128, 1024, 1) (2563, 9) (3419, 128, 1024, 1) (3419, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/target_conf_data.h5', 'r')
X_data_conf = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data_conf = np.array(hf.get('y_data')).astype(np.int32)
classes_conf = list(hf.get('classes'))
classes_conf = [n.decode("ascii", "ignore") for n in classes_conf]
hf.close()

#map labels to source dataset labels
y_data_conf = np.array([classes.index(classes_conf[y_data_conf[i, 0]]) for i in range(y_data_conf.shape[0])])
y_data_conf = np.eye(len(classes))[y_data_conf]

print(X_data_conf.shape, y_data_conf.shape)

#standardise dataset
conf_mean = np.mean(X_data_conf)
X_data_conf -= conf_mean
conf_std  = np.std(X_data_conf)
X_data_conf /= conf_std

conf_test_set = tf.data.Dataset.from_tensor_slices((X_data_conf, y_data_conf))
conf_test_set = conf_test_set.batch(batch_size, drop_remainder=False)
conf_test_set = conf_test_set.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# (1350, 128, 1024, 1) (1350, 9)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/target_server_data.h5', 'r')
X_data_server = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data_server = np.array(hf.get('y_data')).astype(np.int32)
classes_server = list(hf.get('classes'))
classes_server = [n.decode("ascii", "ignore") for n in classes_server]
hf.close()

#map labels to source dataset labels
y_data_server = np.array([classes.index(classes_server[y_data_server[i, 0]]) for i in range(y_data_server.shape[0])])
y_data_server = np.eye(len(classes))[y_data_server]

print(X_data_server.shape, y_data_server.shape)

#standardise dataset
server_mean = np.mean(X_data_server)
X_data_server -= server_mean
server_std  = np.std(X_data_server)
X_data_server /= server_std

server_test_set = tf.data.Dataset.from_tensor_slices((X_data_server, y_data_server))
server_test_set = server_test_set.batch(batch_size, drop_remainder=False)
server_test_set = server_test_set.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# (1346, 128, 1024, 1) (1346, 9)

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/target_office_data.h5', 'r')
X_data_office = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data_office = np.array(hf.get('y_data')).astype(np.int32)
classes_office = list(hf.get('classes'))
classes_office = [n.decode("ascii", "ignore") for n in classes_office]
hf.close()

#map labels to source dataset labels
y_data_office = np.array([classes.index(classes_office[y_data_office[i, 0]]) for i in range(y_data_office.shape[0])])
y_data_office = np.eye(len(classes))[y_data_office]

print(X_data_office.shape, y_data_office.shape)

#standardise dataset
office_mean = np.mean(X_data_office)
X_data_office -= office_mean
office_std  = np.std(X_data_office)
X_data_office /= office_std

office_test_set = tf.data.Dataset.from_tensor_slices((X_data_office, y_data_office))
office_test_set = office_test_set.batch(batch_size, drop_remainder=False)
office_test_set = office_test_set.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# (899, 128, 1024, 1) (899, 9)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

class CenterLoss():
    def __init__(self, batch_size, num_classes, len_features, alpha):
      self.centers = tf.Variable(tf.zeros([num_classes, len_features]),
                                 dtype=tf.float32,
                                 trainable=False)
      self.alpha = alpha
      self.num_classes = num_classes
      self.batch_size = batch_size    
      self.margin = tf.constant(100, dtype="float32")
      self.norm = lambda x: tf.reduce_sum(tf.square(x), 1)
      self.EdgeWeights = tf.ones((self.num_classes,self.num_classes)) - \
                                  tf.eye(self.num_classes)

    def get_center_loss(self, features, labels):
      labels = tf.reshape(tf.argmax(labels, axis=-1), [-1])
      centers0 = tf.math.unsorted_segment_mean(features, 
                                               labels, 
                                               self.num_classes)
      center_pairwise_dist = tf.transpose(self.norm(tf.expand_dims(centers0, 2) - \
                                                    tf.transpose(centers0)))
      self.inter_loss = tf.math.reduce_sum(tf.multiply(tf.maximum(0.0, self.margin - center_pairwise_dist), 
                                                       self.EdgeWeights))

      unique_label, unique_idx, unique_count = tf.unique_with_counts(labels)
      appear_times = tf.gather(unique_count, unique_idx)
      appear_times = tf.reshape(appear_times, [-1, 1])
      centers_batch = tf.gather(self.centers, labels)
      diff = centers_batch - features
      diff /= tf.cast((1 + appear_times), tf.float32)
      diff *= self.alpha
      self.centers_update_op = tf.compat.v1.scatter_sub(self.centers, 
                                                        labels, 
                                                        diff)

      self.intra_loss   = tf.nn.l2_loss(features - centers_batch)
      self.center_loss  = self.intra_loss + self.inter_loss
      self.center_loss /= (self.num_classes*self.batch_size+self.num_classes*self.num_classes)
      return self.center_loss
      
def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
office_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='office_test_accuracy')
server_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='server_test_accuracy')
conf_test_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='conf_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True) 
    
    #VAT
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _                = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images, trg_mixup_labels = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _                = generator(tf.stop_gradient(trg_mixup_images),
                                                   training=True)
    
    #Disc
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(trg_mixup_labels), 
                                                 logits=trg_mixup_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)
    batch_center_loss   = center_loss.get_center_loss(src_enc, src_labels)

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss + \
                 1    * batch_center_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  with tf.control_dependencies([center_loss.centers_update_op]):
    gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)
  
@tf.function
def test_office_step(office_images, office_labels):
  office_logits, _ = generator(office_images, training=False)
  office_test_accuracy(office_labels, office_logits)
  
@tf.function
def test_server_step(server_images, server_labels):
  server_logits, _ = generator(server_images, training=False)
  server_test_accuracy(server_labels, server_logits)
  
@tf.function
def test_conf_step(conf_images, conf_labels):
  conf_logits, _ = generator(conf_images, training=False)
  conf_test_accuracy(conf_labels, conf_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}, Server Test Acc: {:.2f}, Office Test Acc: {:.2f}, Conf Test Acc: {:.2f}'

generator      = ResNet50(num_classes, num_features, gen_activation)
discriminator  = Discriminator(num_hidden, disc_activation)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
center_loss    = CenterLoss(batch_size, num_classes, num_features, alpha)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    tf.contrib.summary.scalar("office_test_accuracy", office_test_accuracy.result())
    tf.contrib.summary.scalar("server_test_accuracy", server_test_accuracy.result())
    tf.contrib.summary.scalar("conf_test_accuracy", conf_test_accuracy.result())
    
for epoch in range(epochs):
  global_step.assign_add(1)  
    
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  for data in office_test_set:
    test_office_step(data[0], data[1])

  for data in server_test_set:
    test_server_step(data[0], data[1])
    
  for data in conf_test_set:
    test_conf_step(data[0], data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100,
                             server_test_accuracy.result()*100,
                             office_test_accuracy.result()*100,
                             conf_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
  server_test_accuracy.reset_states()
  office_test_accuracy.reset_states()
  conf_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0829 19:31:03.938843 140669664954112 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0829 19:31:08.756563 140669664954112 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 21.3642, CrossE: 2.0437, CondE: 2.1220, disc: 0.7215, domain: 0.7979, Src VAT: 2.1216, Trg VAT: 2.1220, Src MixUp: 2.1447, Trg MixUp: 2.1415, Src Train Acc: 20.66, Trg Train Acc: 23.31, Src Test Acc: 29.57, Trg Test Acc: 31.24, Server Test Acc: 22.07, Office Test Acc: 18.46, Conf Test Acc: 31.48
# Epoch: 002, TotalL: 17.4000, CrossE: 1.7562, CondE: 1.9545, disc: 0.6999, domain: 0.8212, Src VAT: 1.9535, Trg VAT: 1.9545, Src MixUp: 2.0340, Trg MixUp: 2.0298, Src Train Acc: 35.03, Trg Train Acc: 36.50, Src Test Acc: 42.80, Trg Test Acc: 45.92, Server Test Acc: 27.79, Office Test Acc: 25.25, Conf Test Acc: 41.19
# Epoch: 003, TotalL: 15.4521, CrossE: 1.4401, CondE: 1.7889, disc: 0.6910, domain: 0.8247, Src VAT: 1.7817, Trg VAT: 1.7889, Src MixUp: 1.9386, Trg MixUp: 1.9243, Src Train Acc: 51.26, Trg Train Acc: 49.65, Src Test Acc: 48.25, Trg Test Acc: 39.63, Server Test Acc: 32.99, Office Test Acc: 35.26, Conf Test Acc: 41.85
# Epoch: 004, TotalL: 14.3301, CrossE: 1.2224, CondE: 1.6012, disc: 0.6775, domain: 0.8297, Src VAT: 1.5910, Trg VAT: 1.6012, Src MixUp: 1.8207, Trg MixUp: 1.8055, Src Train Acc: 57.29, Trg Train Acc: 53.91, Src Test Acc: 52.53, Trg Test Acc: 45.74, Server Test Acc: 35.29, Office Test Acc: 35.60, Conf Test Acc: 42.07
# Epoch: 005, TotalL: 13.7183, CrossE: 1.0945, CondE: 1.4624, disc: 0.6737, domain: 0.8372, Src VAT: 1.4522, Trg VAT: 1.4624, Src MixUp: 1.7391, Trg MixUp: 1.7051, Src Train Acc: 61.63, Trg Train Acc: 57.34, Src Test Acc: 57.20, Trg Test Acc: 48.84, Server Test Acc: 37.30, Office Test Acc: 40.27, Conf Test Acc: 42.52
# Epoch: 006, TotalL: 13.2767, CrossE: 1.0074, CondE: 1.3534, disc: 0.6734, domain: 0.8375, Src VAT: 1.3431, Trg VAT: 1.3534, Src MixUp: 1.6475, Trg MixUp: 1.6279, Src Train Acc: 64.71, Trg Train Acc: 59.16, Src Test Acc: 61.87, Trg Test Acc: 53.41, Server Test Acc: 37.82, Office Test Acc: 41.60, Conf Test Acc: 44.89
# Epoch: 007, TotalL: 12.8700, CrossE: 0.9203, CondE: 1.2698, disc: 0.6708, domain: 0.8365, Src VAT: 1.2556, Trg VAT: 1.2698, Src MixUp: 1.5932, Trg MixUp: 1.5776, Src Train Acc: 68.19, Trg Train Acc: 61.50, Src Test Acc: 66.15, Trg Test Acc: 57.41, Server Test Acc: 37.74, Office Test Acc: 42.83, Conf Test Acc: 46.89
# Epoch: 008, TotalL: 12.5582, CrossE: 0.8588, CondE: 1.1965, disc: 0.6670, domain: 0.8393, Src VAT: 1.1786, Trg VAT: 1.1965, Src MixUp: 1.5404, Trg MixUp: 1.5146, Src Train Acc: 70.79, Trg Train Acc: 63.54, Src Test Acc: 73.15, Trg Test Acc: 61.63, Server Test Acc: 37.82, Office Test Acc: 42.83, Conf Test Acc: 48.81
# Epoch: 009, TotalL: 12.2268, CrossE: 0.7916, CondE: 1.1354, disc: 0.6657, domain: 0.8436, Src VAT: 1.1093, Trg VAT: 1.1354, Src MixUp: 1.4823, Trg MixUp: 1.4756, Src Train Acc: 73.52, Trg Train Acc: 65.02, Src Test Acc: 74.32, Trg Test Acc: 61.13, Server Test Acc: 39.90, Office Test Acc: 43.83, Conf Test Acc: 51.93
# Epoch: 010, TotalL: 11.9682, CrossE: 0.7402, CondE: 1.0766, disc: 0.6627, domain: 0.8480, Src VAT: 1.0424, Trg VAT: 1.0766, Src MixUp: 1.4374, Trg MixUp: 1.4231, Src Train Acc: 74.91, Trg Train Acc: 67.27, Src Test Acc: 77.82, Trg Test Acc: 65.55, Server Test Acc: 37.59, Office Test Acc: 41.05, Conf Test Acc: 51.70
# Epoch: 011, TotalL: 11.7138, CrossE: 0.6809, CondE: 1.0313, disc: 0.6600, domain: 0.8498, Src VAT: 0.9892, Trg VAT: 1.0313, Src MixUp: 1.4165, Trg MixUp: 1.3904, Src Train Acc: 77.13, Trg Train Acc: 68.75, Src Test Acc: 79.38, Trg Test Acc: 63.79, Server Test Acc: 41.38, Office Test Acc: 42.71, Conf Test Acc: 53.63
# Epoch: 012, TotalL: 11.4886, CrossE: 0.6324, CondE: 0.9884, disc: 0.6570, domain: 0.8591, Src VAT: 0.9370, Trg VAT: 0.9884, Src MixUp: 1.3773, Trg MixUp: 1.3645, Src Train Acc: 79.21, Trg Train Acc: 70.62, Src Test Acc: 83.27, Trg Test Acc: 66.83, Server Test Acc: 41.31, Office Test Acc: 41.82, Conf Test Acc: 57.19
# Epoch: 013, TotalL: 11.2523, CrossE: 0.5835, CondE: 0.9435, disc: 0.6509, domain: 0.8641, Src VAT: 0.8829, Trg VAT: 0.9435, Src MixUp: 1.3365, Trg MixUp: 1.3309, Src Train Acc: 81.21, Trg Train Acc: 72.05, Src Test Acc: 84.44, Trg Test Acc: 69.99, Server Test Acc: 41.46, Office Test Acc: 40.93, Conf Test Acc: 56.74
# Epoch: 014, TotalL: 11.0144, CrossE: 0.5347, CondE: 0.8976, disc: 0.6481, domain: 0.8698, Src VAT: 0.8287, Trg VAT: 0.8976, Src MixUp: 1.2941, Trg MixUp: 1.2716, Src Train Acc: 83.20, Trg Train Acc: 74.31, Src Test Acc: 85.21, Trg Test Acc: 70.58, Server Test Acc: 45.39, Office Test Acc: 40.49, Conf Test Acc: 60.96
# Epoch: 015, TotalL: 10.7634, CrossE: 0.4760, CondE: 0.8571, disc: 0.6458, domain: 0.8780, Src VAT: 0.7763, Trg VAT: 0.8571, Src MixUp: 1.2617, Trg MixUp: 1.2584, Src Train Acc: 85.98, Trg Train Acc: 77.52, Src Test Acc: 86.38, Trg Test Acc: 70.66, Server Test Acc: 45.32, Office Test Acc: 42.05, Conf Test Acc: 62.59
# Epoch: 016, TotalL: 10.6035, CrossE: 0.4454, CondE: 0.8223, disc: 0.6412, domain: 0.8787, Src VAT: 0.7347, Trg VAT: 0.8223, Src MixUp: 1.2452, Trg MixUp: 1.2341, Src Train Acc: 87.07, Trg Train Acc: 78.65, Src Test Acc: 86.77, Trg Test Acc: 74.93, Server Test Acc: 48.81, Office Test Acc: 43.38, Conf Test Acc: 61.70
# Epoch: 017, TotalL: 10.3797, CrossE: 0.4009, CondE: 0.7830, disc: 0.6416, domain: 0.8874, Src VAT: 0.6883, Trg VAT: 0.7830, Src MixUp: 1.2060, Trg MixUp: 1.2080, Src Train Acc: 88.28, Trg Train Acc: 80.12, Src Test Acc: 85.60, Trg Test Acc: 71.98, Server Test Acc: 44.13, Office Test Acc: 40.38, Conf Test Acc: 61.26
# Epoch: 018, TotalL: 10.1641, CrossE: 0.3507, CondE: 0.7349, disc: 0.6386, domain: 0.8926, Src VAT: 0.6323, Trg VAT: 0.7349, Src MixUp: 1.1900, Trg MixUp: 1.1710, Src Train Acc: 90.19, Trg Train Acc: 81.42, Src Test Acc: 87.55, Trg Test Acc: 76.19, Server Test Acc: 49.03, Office Test Acc: 44.83, Conf Test Acc: 60.89
# Epoch: 019, TotalL: 9.9557, CrossE: 0.3160, CondE: 0.6968, disc: 0.6352, domain: 0.8956, Src VAT: 0.5885, Trg VAT: 0.6968, Src MixUp: 1.1489, Trg MixUp: 1.1450, Src Train Acc: 92.19, Trg Train Acc: 82.99, Src Test Acc: 89.49, Trg Test Acc: 78.68, Server Test Acc: 52.01, Office Test Acc: 47.61, Conf Test Acc: 62.74
# Epoch: 020, TotalL: 9.7871, CrossE: 0.2887, CondE: 0.6579, disc: 0.6327, domain: 0.9011, Src VAT: 0.5491, Trg VAT: 0.6579, Src MixUp: 1.1016, Trg MixUp: 1.1335, Src Train Acc: 92.75, Trg Train Acc: 85.29, Src Test Acc: 92.22, Trg Test Acc: 81.19, Server Test Acc: 55.27, Office Test Acc: 47.94, Conf Test Acc: 66.67
# Epoch: 021, TotalL: 9.5492, CrossE: 0.2461, CondE: 0.6149, disc: 0.6335, domain: 0.9043, Src VAT: 0.4963, Trg VAT: 0.6149, Src MixUp: 1.0546, Trg MixUp: 1.0776, Src Train Acc: 94.36, Trg Train Acc: 86.11, Src Test Acc: 90.27, Trg Test Acc: 79.50, Server Test Acc: 53.86, Office Test Acc: 46.72, Conf Test Acc: 68.22
# Epoch: 022, TotalL: 9.4502, CrossE: 0.2227, CondE: 0.5957, disc: 0.6248, domain: 0.9170, Src VAT: 0.4689, Trg VAT: 0.5957, Src MixUp: 1.0573, Trg MixUp: 1.0515, Src Train Acc: 94.92, Trg Train Acc: 86.46, Src Test Acc: 91.44, Trg Test Acc: 81.08, Server Test Acc: 56.46, Office Test Acc: 45.61, Conf Test Acc: 66.44
# Epoch: 023, TotalL: 9.2641, CrossE: 0.1980, CondE: 0.5653, disc: 0.6242, domain: 0.9204, Src VAT: 0.4309, Trg VAT: 0.5653, Src MixUp: 1.0120, Trg MixUp: 1.0219, Src Train Acc: 95.36, Trg Train Acc: 87.15, Src Test Acc: 91.83, Trg Test Acc: 82.68, Server Test Acc: 58.32, Office Test Acc: 53.39, Conf Test Acc: 71.56
# Epoch: 024, TotalL: 9.1869, CrossE: 0.1787, CondE: 0.5434, disc: 0.6231, domain: 0.9267, Src VAT: 0.4063, Trg VAT: 0.5434, Src MixUp: 1.0244, Trg MixUp: 1.0344, Src Train Acc: 96.01, Trg Train Acc: 86.68, Src Test Acc: 94.55, Trg Test Acc: 80.96, Server Test Acc: 62.18, Office Test Acc: 55.73, Conf Test Acc: 75.63
# Epoch: 025, TotalL: 8.9887, CrossE: 0.1544, CondE: 0.5124, disc: 0.6193, domain: 0.9318, Src VAT: 0.3724, Trg VAT: 0.5124, Src MixUp: 0.9500, Trg MixUp: 0.9766, Src Train Acc: 96.92, Trg Train Acc: 87.37, Src Test Acc: 94.55, Trg Test Acc: 81.11, Server Test Acc: 61.89, Office Test Acc: 53.39, Conf Test Acc: 75.41
# Epoch: 026, TotalL: 8.9375, CrossE: 0.1408, CondE: 0.4934, disc: 0.6201, domain: 0.9337, Src VAT: 0.3496, Trg VAT: 0.4934, Src MixUp: 0.9593, Trg MixUp: 0.9732, Src Train Acc: 97.31, Trg Train Acc: 87.93, Src Test Acc: 93.77, Trg Test Acc: 85.11, Server Test Acc: 61.74, Office Test Acc: 55.28, Conf Test Acc: 73.11
# Epoch: 027, TotalL: 8.8071, CrossE: 0.1187, CondE: 0.4759, disc: 0.6126, domain: 0.9402, Src VAT: 0.3216, Trg VAT: 0.4759, Src MixUp: 0.9389, Trg MixUp: 0.9695, Src Train Acc: 97.96, Trg Train Acc: 88.02, Src Test Acc: 94.55, Trg Test Acc: 83.62, Server Test Acc: 63.74, Office Test Acc: 58.51, Conf Test Acc: 76.15
# Epoch: 028, TotalL: 8.7320, CrossE: 0.1094, CondE: 0.4576, disc: 0.6159, domain: 0.9488, Src VAT: 0.3006, Trg VAT: 0.4576, Src MixUp: 0.9323, Trg MixUp: 0.9499, Src Train Acc: 98.26, Trg Train Acc: 90.41, Src Test Acc: 94.55, Trg Test Acc: 83.56, Server Test Acc: 60.18, Office Test Acc: 52.06, Conf Test Acc: 74.44
# Epoch: 029, TotalL: 8.6347, CrossE: 0.1005, CondE: 0.4446, disc: 0.6121, domain: 0.9536, Src VAT: 0.2806, Trg VAT: 0.4446, Src MixUp: 0.8875, Trg MixUp: 0.9394, Src Train Acc: 98.22, Trg Train Acc: 89.50, Src Test Acc: 96.50, Trg Test Acc: 84.88, Server Test Acc: 64.41, Office Test Acc: 56.06, Conf Test Acc: 77.78
# Epoch: 030, TotalL: 8.5713, CrossE: 0.0909, CondE: 0.4260, disc: 0.6115, domain: 0.9595, Src VAT: 0.2644, Trg VAT: 0.4260, Src MixUp: 0.8780, Trg MixUp: 0.9288, Src Train Acc: 98.22, Trg Train Acc: 90.36, Src Test Acc: 94.94, Trg Test Acc: 84.47, Server Test Acc: 64.49, Office Test Acc: 60.29, Conf Test Acc: 77.19
# Epoch: 031, TotalL: 8.4637, CrossE: 0.0780, CondE: 0.4019, disc: 0.6097, domain: 0.9592, Src VAT: 0.2402, Trg VAT: 0.4019, Src MixUp: 0.8509, Trg MixUp: 0.9072, Src Train Acc: 99.13, Trg Train Acc: 90.58, Src Test Acc: 92.22, Trg Test Acc: 83.09, Server Test Acc: 60.03, Office Test Acc: 55.84, Conf Test Acc: 71.19
# Epoch: 032, TotalL: 8.4896, CrossE: 0.0758, CondE: 0.3986, disc: 0.6142, domain: 0.9636, Src VAT: 0.2385, Trg VAT: 0.3986, Src MixUp: 0.8678, Trg MixUp: 0.9118, Src Train Acc: 99.22, Trg Train Acc: 90.58, Src Test Acc: 94.94, Trg Test Acc: 86.63, Server Test Acc: 64.34, Office Test Acc: 60.62, Conf Test Acc: 77.26
# Epoch: 033, TotalL: 8.3969, CrossE: 0.0654, CondE: 0.3910, disc: 0.6079, domain: 0.9702, Src VAT: 0.2167, Trg VAT: 0.3910, Src MixUp: 0.8500, Trg MixUp: 0.8866, Src Train Acc: 99.13, Trg Train Acc: 91.10, Src Test Acc: 96.11, Trg Test Acc: 84.64, Server Test Acc: 65.30, Office Test Acc: 56.73, Conf Test Acc: 77.41
# Epoch: 034, TotalL: 8.3626, CrossE: 0.0637, CondE: 0.3762, disc: 0.6077, domain: 0.9695, Src VAT: 0.2099, Trg VAT: 0.3762, Src MixUp: 0.8401, Trg MixUp: 0.8976, Src Train Acc: 99.35, Trg Train Acc: 91.28, Src Test Acc: 96.11, Trg Test Acc: 85.79, Server Test Acc: 66.64, Office Test Acc: 59.84, Conf Test Acc: 79.93
# Epoch: 035, TotalL: 8.3075, CrossE: 0.0573, CondE: 0.3647, disc: 0.6038, domain: 0.9737, Src VAT: 0.2010, Trg VAT: 0.3647, Src MixUp: 0.8226, Trg MixUp: 0.8788, Src Train Acc: 99.52, Trg Train Acc: 91.84, Src Test Acc: 94.55, Trg Test Acc: 82.07, Server Test Acc: 63.08, Office Test Acc: 53.62, Conf Test Acc: 76.67
# Epoch: 036, TotalL: 8.3059, CrossE: 0.0556, CondE: 0.3613, disc: 0.6086, domain: 0.9811, Src VAT: 0.1918, Trg VAT: 0.3613, Src MixUp: 0.8309, Trg MixUp: 0.8662, Src Train Acc: 99.57, Trg Train Acc: 91.32, Src Test Acc: 94.94, Trg Test Acc: 88.62, Server Test Acc: 67.83, Office Test Acc: 59.29, Conf Test Acc: 79.19
# Epoch: 037, TotalL: 8.1811, CrossE: 0.0455, CondE: 0.3487, disc: 0.6061, domain: 0.9858, Src VAT: 0.1706, Trg VAT: 0.3487, Src MixUp: 0.7823, Trg MixUp: 0.8586, Src Train Acc: 99.65, Trg Train Acc: 92.14, Src Test Acc: 97.28, Trg Test Acc: 87.98, Server Test Acc: 67.90, Office Test Acc: 60.96, Conf Test Acc: 80.89
# Epoch: 038, TotalL: 8.2037, CrossE: 0.0472, CondE: 0.3398, disc: 0.6062, domain: 0.9887, Src VAT: 0.1718, Trg VAT: 0.3398, Src MixUp: 0.7888, Trg MixUp: 0.8512, Src Train Acc: 99.48, Trg Train Acc: 91.84, Src Test Acc: 95.33, Trg Test Acc: 83.94, Server Test Acc: 63.74, Office Test Acc: 59.07, Conf Test Acc: 77.11
# Epoch: 039, TotalL: 8.1567, CrossE: 0.0399, CondE: 0.3269, disc: 0.6089, domain: 0.9856, Src VAT: 0.1547, Trg VAT: 0.3269, Src MixUp: 0.7975, Trg MixUp: 0.8504, Src Train Acc: 99.87, Trg Train Acc: 93.10, Src Test Acc: 96.11, Trg Test Acc: 89.70, Server Test Acc: 72.07, Office Test Acc: 67.07, Conf Test Acc: 83.11
# Epoch: 040, TotalL: 8.0950, CrossE: 0.0347, CondE: 0.3154, disc: 0.5985, domain: 0.9997, Src VAT: 0.1449, Trg VAT: 0.3154, Src MixUp: 0.7714, Trg MixUp: 0.8295, Src Train Acc: 99.78, Trg Train Acc: 92.88, Src Test Acc: 96.11, Trg Test Acc: 86.17, Server Test Acc: 65.68, Office Test Acc: 55.84, Conf Test Acc: 77.78
# Epoch: 041, TotalL: 8.0996, CrossE: 0.0365, CondE: 0.3136, disc: 0.6032, domain: 1.0089, Src VAT: 0.1450, Trg VAT: 0.3136, Src MixUp: 0.7634, Trg MixUp: 0.8308, Src Train Acc: 99.78, Trg Train Acc: 92.66, Src Test Acc: 97.67, Trg Test Acc: 87.54, Server Test Acc: 68.13, Office Test Acc: 64.07, Conf Test Acc: 82.00
# Epoch: 042, TotalL: 8.0778, CrossE: 0.0330, CondE: 0.3063, disc: 0.5993, domain: 1.0068, Src VAT: 0.1382, Trg VAT: 0.3063, Src MixUp: 0.7625, Trg MixUp: 0.8159, Src Train Acc: 99.83, Trg Train Acc: 92.53, Src Test Acc: 97.67, Trg Test Acc: 87.95, Server Test Acc: 69.39, Office Test Acc: 62.74, Conf Test Acc: 82.00
# Epoch: 043, TotalL: 8.0222, CrossE: 0.0324, CondE: 0.3033, disc: 0.5966, domain: 1.0158, Src VAT: 0.1306, Trg VAT: 0.3033, Src MixUp: 0.7353, Trg MixUp: 0.8294, Src Train Acc: 99.78, Trg Train Acc: 93.14, Src Test Acc: 96.89, Trg Test Acc: 89.35, Server Test Acc: 71.03, Office Test Acc: 66.52, Conf Test Acc: 82.67
# Epoch: 044, TotalL: 8.0056, CrossE: 0.0297, CondE: 0.2934, disc: 0.6000, domain: 1.0221, Src VAT: 0.1238, Trg VAT: 0.2934, Src MixUp: 0.7403, Trg MixUp: 0.8087, Src Train Acc: 99.78, Trg Train Acc: 93.58, Src Test Acc: 97.28, Trg Test Acc: 87.83, Server Test Acc: 70.95, Office Test Acc: 64.18, Conf Test Acc: 82.52
# Epoch: 045, TotalL: 7.9786, CrossE: 0.0274, CondE: 0.2867, disc: 0.6044, domain: 1.0157, Src VAT: 0.1192, Trg VAT: 0.2867, Src MixUp: 0.7204, Trg MixUp: 0.8110, Src Train Acc: 100.00, Trg Train Acc: 93.66, Src Test Acc: 95.72, Trg Test Acc: 82.22, Server Test Acc: 65.08, Office Test Acc: 61.96, Conf Test Acc: 78.74
# Epoch: 046, TotalL: 7.9671, CrossE: 0.0243, CondE: 0.2773, disc: 0.5958, domain: 1.0201, Src VAT: 0.1121, Trg VAT: 0.2773, Src MixUp: 0.7275, Trg MixUp: 0.7962, Src Train Acc: 99.96, Trg Train Acc: 94.01, Src Test Acc: 98.05, Trg Test Acc: 86.72, Server Test Acc: 66.57, Office Test Acc: 60.96, Conf Test Acc: 80.67
# Epoch: 047, TotalL: 7.9150, CrossE: 0.0251, CondE: 0.2693, disc: 0.6005, domain: 1.0453, Src VAT: 0.1050, Trg VAT: 0.2693, Src MixUp: 0.6843, Trg MixUp: 0.7778, Src Train Acc: 99.87, Trg Train Acc: 93.88, Src Test Acc: 95.33, Trg Test Acc: 89.50, Server Test Acc: 70.43, Office Test Acc: 62.18, Conf Test Acc: 79.70
# Epoch: 048, TotalL: 7.8838, CrossE: 0.0218, CondE: 0.2617, disc: 0.6005, domain: 1.0297, Src VAT: 0.0999, Trg VAT: 0.2617, Src MixUp: 0.6760, Trg MixUp: 0.7829, Src Train Acc: 99.96, Trg Train Acc: 94.18, Src Test Acc: 97.67, Trg Test Acc: 89.88, Server Test Acc: 69.09, Office Test Acc: 64.63, Conf Test Acc: 80.52
# Epoch: 049, TotalL: 7.8235, CrossE: 0.0174, CondE: 0.2439, disc: 0.5966, domain: 1.0229, Src VAT: 0.0902, Trg VAT: 0.2439, Src MixUp: 0.6666, Trg MixUp: 0.7544, Src Train Acc: 100.00, Trg Train Acc: 94.79, Src Test Acc: 97.67, Trg Test Acc: 88.62, Server Test Acc: 70.06, Office Test Acc: 65.18, Conf Test Acc: 83.41
# Epoch: 050, TotalL: 7.8404, CrossE: 0.0196, CondE: 0.2490, disc: 0.5946, domain: 1.0310, Src VAT: 0.0930, Trg VAT: 0.2490, Src MixUp: 0.6643, Trg MixUp: 0.7745, Src Train Acc: 99.96, Trg Train Acc: 94.10, Src Test Acc: 97.28, Trg Test Acc: 87.54, Server Test Acc: 68.28, Office Test Acc: 58.06, Conf Test Acc: 80.00
# Epoch: 051, TotalL: 7.8387, CrossE: 0.0192, CondE: 0.2436, disc: 0.5975, domain: 1.0337, Src VAT: 0.0927, Trg VAT: 0.2436, Src MixUp: 0.6662, Trg MixUp: 0.7611, Src Train Acc: 100.00, Trg Train Acc: 94.79, Src Test Acc: 96.50, Trg Test Acc: 87.22, Server Test Acc: 66.64, Office Test Acc: 64.63, Conf Test Acc: 77.63
# Epoch: 052, TotalL: 7.8328, CrossE: 0.0173, CondE: 0.2374, disc: 0.6051, domain: 1.0296, Src VAT: 0.0851, Trg VAT: 0.2374, Src MixUp: 0.6730, Trg MixUp: 0.7451, Src Train Acc: 99.91, Trg Train Acc: 94.10, Src Test Acc: 96.50, Trg Test Acc: 90.99, Server Test Acc: 71.10, Office Test Acc: 62.07, Conf Test Acc: 81.93
# Epoch: 053, TotalL: 7.8040, CrossE: 0.0167, CondE: 0.2334, disc: 0.6066, domain: 1.0144, Src VAT: 0.0837, Trg VAT: 0.2334, Src MixUp: 0.6642, Trg MixUp: 0.7248, Src Train Acc: 99.96, Trg Train Acc: 94.44, Src Test Acc: 91.44, Trg Test Acc: 78.50, Server Test Acc: 61.14, Office Test Acc: 55.28, Conf Test Acc: 72.52
# Epoch: 054, TotalL: 7.7883, CrossE: 0.0158, CondE: 0.2307, disc: 0.6048, domain: 1.0256, Src VAT: 0.0797, Trg VAT: 0.2307, Src MixUp: 0.6469, Trg MixUp: 0.7427, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 98.05, Trg Test Acc: 89.97, Server Test Acc: 69.54, Office Test Acc: 64.74, Conf Test Acc: 82.07
# Epoch: 055, TotalL: 7.7891, CrossE: 0.0150, CondE: 0.2301, disc: 0.5995, domain: 1.0343, Src VAT: 0.0775, Trg VAT: 0.2301, Src MixUp: 0.6555, Trg MixUp: 0.7353, Src Train Acc: 100.00, Trg Train Acc: 94.62, Src Test Acc: 96.89, Trg Test Acc: 87.95, Server Test Acc: 67.83, Office Test Acc: 58.62, Conf Test Acc: 79.19
# Epoch: 056, TotalL: 7.7482, CrossE: 0.0139, CondE: 0.2242, disc: 0.5924, domain: 1.0392, Src VAT: 0.0731, Trg VAT: 0.2242, Src MixUp: 0.6383, Trg MixUp: 0.7180, Src Train Acc: 99.96, Trg Train Acc: 95.23, Src Test Acc: 98.44, Trg Test Acc: 89.91, Server Test Acc: 72.14, Office Test Acc: 64.85, Conf Test Acc: 84.59
# Epoch: 057, TotalL: 7.7361, CrossE: 0.0149, CondE: 0.2210, disc: 0.5959, domain: 1.0423, Src VAT: 0.0747, Trg VAT: 0.2210, Src MixUp: 0.6227, Trg MixUp: 0.7006, Src Train Acc: 100.00, Trg Train Acc: 95.36, Src Test Acc: 97.28, Trg Test Acc: 87.48, Server Test Acc: 66.05, Office Test Acc: 59.84, Conf Test Acc: 79.48
# Epoch: 058, TotalL: 7.7516, CrossE: 0.0134, CondE: 0.2219, disc: 0.6008, domain: 1.0397, Src VAT: 0.0703, Trg VAT: 0.2219, Src MixUp: 0.6420, Trg MixUp: 0.7146, Src Train Acc: 99.96, Trg Train Acc: 95.27, Src Test Acc: 96.50, Trg Test Acc: 89.15, Server Test Acc: 67.53, Office Test Acc: 60.18, Conf Test Acc: 80.89
# Epoch: 059, TotalL: 7.6924, CrossE: 0.0113, CondE: 0.2088, disc: 0.5865, domain: 1.0476, Src VAT: 0.0643, Trg VAT: 0.2088, Src MixUp: 0.6141, Trg MixUp: 0.7141, Src Train Acc: 100.00, Trg Train Acc: 95.70, Src Test Acc: 97.28, Trg Test Acc: 91.08, Server Test Acc: 71.77, Office Test Acc: 63.18, Conf Test Acc: 83.63
# Epoch: 060, TotalL: 7.7090, CrossE: 0.0117, CondE: 0.2050, disc: 0.5971, domain: 1.0537, Src VAT: 0.0649, Trg VAT: 0.2050, Src MixUp: 0.6304, Trg MixUp: 0.6903, Src Train Acc: 100.00, Trg Train Acc: 95.36, Src Test Acc: 94.55, Trg Test Acc: 86.78, Server Test Acc: 65.23, Office Test Acc: 57.17, Conf Test Acc: 77.85
# Epoch: 061, TotalL: 7.6615, CrossE: 0.0103, CondE: 0.1975, disc: 0.5875, domain: 1.0643, Src VAT: 0.0600, Trg VAT: 0.1975, Src MixUp: 0.6067, Trg MixUp: 0.6984, Src Train Acc: 100.00, Trg Train Acc: 95.53, Src Test Acc: 96.89, Trg Test Acc: 92.40, Server Test Acc: 74.89, Office Test Acc: 67.74, Conf Test Acc: 84.15
# Epoch: 062, TotalL: 7.6705, CrossE: 0.0124, CondE: 0.1880, disc: 0.6040, domain: 1.0499, Src VAT: 0.0588, Trg VAT: 0.1880, Src MixUp: 0.6004, Trg MixUp: 0.6800, Src Train Acc: 99.83, Trg Train Acc: 95.70, Src Test Acc: 97.28, Trg Test Acc: 93.54, Server Test Acc: 73.40, Office Test Acc: 61.74, Conf Test Acc: 84.30
# Epoch: 063, TotalL: 7.6623, CrossE: 0.0107, CondE: 0.1860, disc: 0.6086, domain: 1.0400, Src VAT: 0.0592, Trg VAT: 0.1860, Src MixUp: 0.5923, Trg MixUp: 0.6782, Src Train Acc: 100.00, Trg Train Acc: 95.96, Src Test Acc: 97.28, Trg Test Acc: 86.66, Server Test Acc: 65.90, Office Test Acc: 59.62, Conf Test Acc: 78.52
# Epoch: 064, TotalL: 7.6626, CrossE: 0.0108, CondE: 0.1892, disc: 0.6087, domain: 1.0326, Src VAT: 0.0603, Trg VAT: 0.1892, Src MixUp: 0.5872, Trg MixUp: 0.6900, Src Train Acc: 100.00, Trg Train Acc: 95.96, Src Test Acc: 99.61, Trg Test Acc: 88.74, Server Test Acc: 69.84, Office Test Acc: 63.07, Conf Test Acc: 82.15
# Epoch: 065, TotalL: 7.6338, CrossE: 0.0089, CondE: 0.1833, disc: 0.5971, domain: 1.0470, Src VAT: 0.0530, Trg VAT: 0.1833, Src MixUp: 0.5921, Trg MixUp: 0.7009, Src Train Acc: 100.00, Trg Train Acc: 95.70, Src Test Acc: 98.83, Trg Test Acc: 92.66, Server Test Acc: 75.19, Office Test Acc: 62.51, Conf Test Acc: 85.19
# Epoch: 066, TotalL: 7.6401, CrossE: 0.0087, CondE: 0.1762, disc: 0.5945, domain: 1.0609, Src VAT: 0.0520, Trg VAT: 0.1762, Src MixUp: 0.6002, Trg MixUp: 0.6908, Src Train Acc: 100.00, Trg Train Acc: 95.92, Src Test Acc: 98.44, Trg Test Acc: 92.45, Server Test Acc: 74.15, Office Test Acc: 65.52, Conf Test Acc: 85.56
# Epoch: 067, TotalL: 7.6170, CrossE: 0.0092, CondE: 0.1749, disc: 0.5982, domain: 1.0539, Src VAT: 0.0522, Trg VAT: 0.1749, Src MixUp: 0.5675, Trg MixUp: 0.6861, Src Train Acc: 100.00, Trg Train Acc: 95.70, Src Test Acc: 99.22, Trg Test Acc: 92.63, Server Test Acc: 72.96, Office Test Acc: 66.96, Conf Test Acc: 84.89
# Epoch: 068, TotalL: 7.6131, CrossE: 0.0080, CondE: 0.1688, disc: 0.6003, domain: 1.0553, Src VAT: 0.0498, Trg VAT: 0.1688, Src MixUp: 0.5886, Trg MixUp: 0.6753, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 97.67, Trg Test Acc: 92.16, Server Test Acc: 75.11, Office Test Acc: 61.74, Conf Test Acc: 83.78
# Epoch: 069, TotalL: 7.6125, CrossE: 0.0083, CondE: 0.1697, disc: 0.6072, domain: 1.0573, Src VAT: 0.0476, Trg VAT: 0.1697, Src MixUp: 0.5773, Trg MixUp: 0.6630, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.83, Trg Test Acc: 91.69, Server Test Acc: 72.44, Office Test Acc: 67.19, Conf Test Acc: 83.85
# Epoch: 070, TotalL: 7.6036, CrossE: 0.0080, CondE: 0.1638, disc: 0.5962, domain: 1.0558, Src VAT: 0.0468, Trg VAT: 0.1638, Src MixUp: 0.5660, Trg MixUp: 0.6752, Src Train Acc: 100.00, Trg Train Acc: 95.88, Src Test Acc: 98.44, Trg Test Acc: 88.71, Server Test Acc: 68.13, Office Test Acc: 61.74, Conf Test Acc: 80.15
# Epoch: 071, TotalL: 7.5926, CrossE: 0.0080, CondE: 0.1693, disc: 0.5963, domain: 1.0548, Src VAT: 0.0446, Trg VAT: 0.1693, Src MixUp: 0.5714, Trg MixUp: 0.6553, Src Train Acc: 99.91, Trg Train Acc: 96.14, Src Test Acc: 98.44, Trg Test Acc: 94.65, Server Test Acc: 78.60, Office Test Acc: 73.53, Conf Test Acc: 87.41
# Epoch: 072, TotalL: 7.5959, CrossE: 0.0081, CondE: 0.1631, disc: 0.6076, domain: 1.0501, Src VAT: 0.0468, Trg VAT: 0.1631, Src MixUp: 0.5717, Trg MixUp: 0.6670, Src Train Acc: 100.00, Trg Train Acc: 96.57, Src Test Acc: 99.61, Trg Test Acc: 94.44, Server Test Acc: 76.00, Office Test Acc: 69.08, Conf Test Acc: 86.37
# Epoch: 073, TotalL: 7.5654, CrossE: 0.0068, CondE: 0.1541, disc: 0.5994, domain: 1.0432, Src VAT: 0.0439, Trg VAT: 0.1541, Src MixUp: 0.5702, Trg MixUp: 0.6446, Src Train Acc: 100.00, Trg Train Acc: 96.61, Src Test Acc: 99.61, Trg Test Acc: 89.56, Server Test Acc: 71.62, Office Test Acc: 61.96, Conf Test Acc: 84.22
# Epoch: 074, TotalL: 7.5796, CrossE: 0.0070, CondE: 0.1561, disc: 0.5935, domain: 1.0570, Src VAT: 0.0448, Trg VAT: 0.1561, Src MixUp: 0.5771, Trg MixUp: 0.6438, Src Train Acc: 100.00, Trg Train Acc: 96.53, Src Test Acc: 99.61, Trg Test Acc: 94.44, Server Test Acc: 76.30, Office Test Acc: 69.08, Conf Test Acc: 87.11
# Epoch: 075, TotalL: 7.5702, CrossE: 0.0073, CondE: 0.1561, disc: 0.6024, domain: 1.0581, Src VAT: 0.0445, Trg VAT: 0.1561, Src MixUp: 0.5580, Trg MixUp: 0.6617, Src Train Acc: 100.00, Trg Train Acc: 96.57, Src Test Acc: 96.50, Trg Test Acc: 93.10, Server Test Acc: 75.19, Office Test Acc: 68.85, Conf Test Acc: 83.56
# Epoch: 076, TotalL: 7.5489, CrossE: 0.0065, CondE: 0.1489, disc: 0.5960, domain: 1.0585, Src VAT: 0.0417, Trg VAT: 0.1489, Src MixUp: 0.5531, Trg MixUp: 0.6350, Src Train Acc: 100.00, Trg Train Acc: 96.57, Src Test Acc: 96.89, Trg Test Acc: 86.96, Server Test Acc: 69.24, Office Test Acc: 65.29, Conf Test Acc: 80.81
# Epoch: 077, TotalL: 7.5282, CrossE: 0.0059, CondE: 0.1486, disc: 0.5921, domain: 1.0726, Src VAT: 0.0395, Trg VAT: 0.1486, Src MixUp: 0.5468, Trg MixUp: 0.6460, Src Train Acc: 100.00, Trg Train Acc: 96.53, Src Test Acc: 98.83, Trg Test Acc: 92.02, Server Test Acc: 75.78, Office Test Acc: 65.96, Conf Test Acc: 87.41
# Epoch: 078, TotalL: 7.5393, CrossE: 0.0064, CondE: 0.1488, disc: 0.6023, domain: 1.0544, Src VAT: 0.0415, Trg VAT: 0.1488, Src MixUp: 0.5463, Trg MixUp: 0.6305, Src Train Acc: 100.00, Trg Train Acc: 96.53, Src Test Acc: 98.44, Trg Test Acc: 91.34, Server Test Acc: 70.43, Office Test Acc: 68.52, Conf Test Acc: 82.22
# Epoch: 079, TotalL: 7.5813, CrossE: 0.0084, CondE: 0.1431, disc: 0.6075, domain: 1.0550, Src VAT: 0.0450, Trg VAT: 0.1431, Src MixUp: 0.5742, Trg MixUp: 0.6304, Src Train Acc: 99.96, Trg Train Acc: 96.40, Src Test Acc: 98.83, Trg Test Acc: 91.61, Server Test Acc: 73.25, Office Test Acc: 62.74, Conf Test Acc: 84.52
# Epoch: 080, TotalL: 7.5018, CrossE: 0.0054, CondE: 0.1372, disc: 0.5945, domain: 1.0599, Src VAT: 0.0364, Trg VAT: 0.1372, Src MixUp: 0.5334, Trg MixUp: 0.6346, Src Train Acc: 100.00, Trg Train Acc: 96.83, Src Test Acc: 98.83, Trg Test Acc: 93.59, Server Test Acc: 76.23, Office Test Acc: 68.52, Conf Test Acc: 87.26
# Epoch: 081, TotalL: 7.5174, CrossE: 0.0060, CondE: 0.1348, disc: 0.6054, domain: 1.0577, Src VAT: 0.0392, Trg VAT: 0.1348, Src MixUp: 0.5336, Trg MixUp: 0.6181, Src Train Acc: 100.00, Trg Train Acc: 96.61, Src Test Acc: 97.28, Trg Test Acc: 94.09, Server Test Acc: 78.16, Office Test Acc: 76.08, Conf Test Acc: 85.85
# Epoch: 082, TotalL: 7.5439, CrossE: 0.0059, CondE: 0.1399, disc: 0.6059, domain: 1.0697, Src VAT: 0.0384, Trg VAT: 0.1399, Src MixUp: 0.5499, Trg MixUp: 0.6281, Src Train Acc: 100.00, Trg Train Acc: 96.61, Src Test Acc: 99.22, Trg Test Acc: 94.33, Server Test Acc: 77.27, Office Test Acc: 69.19, Conf Test Acc: 87.33
# Epoch: 083, TotalL: 7.5721, CrossE: 0.0143, CondE: 0.1460, disc: 0.6101, domain: 1.0442, Src VAT: 0.0489, Trg VAT: 0.1460, Src MixUp: 0.5368, Trg MixUp: 0.6257, Src Train Acc: 99.65, Trg Train Acc: 95.88, Src Test Acc: 98.44, Trg Test Acc: 92.45, Server Test Acc: 75.41, Office Test Acc: 66.07, Conf Test Acc: 85.63
# Epoch: 084, TotalL: 7.4940, CrossE: 0.0052, CondE: 0.1271, disc: 0.5962, domain: 1.0339, Src VAT: 0.0361, Trg VAT: 0.1271, Src MixUp: 0.5344, Trg MixUp: 0.6225, Src Train Acc: 100.00, Trg Train Acc: 96.74, Src Test Acc: 99.22, Trg Test Acc: 92.22, Server Test Acc: 76.23, Office Test Acc: 65.96, Conf Test Acc: 85.63
# Epoch: 085, TotalL: 7.4940, CrossE: 0.0053, CondE: 0.1281, disc: 0.6016, domain: 1.0503, Src VAT: 0.0356, Trg VAT: 0.1281, Src MixUp: 0.5353, Trg MixUp: 0.6207, Src Train Acc: 100.00, Trg Train Acc: 96.88, Src Test Acc: 98.44, Trg Test Acc: 91.99, Server Test Acc: 74.44, Office Test Acc: 71.64, Conf Test Acc: 86.00
# Epoch: 086, TotalL: 7.4845, CrossE: 0.0051, CondE: 0.1266, disc: 0.5940, domain: 1.0559, Src VAT: 0.0350, Trg VAT: 0.1266, Src MixUp: 0.5277, Trg MixUp: 0.6333, Src Train Acc: 100.00, Trg Train Acc: 96.96, Src Test Acc: 98.44, Trg Test Acc: 92.98, Server Test Acc: 74.81, Office Test Acc: 68.30, Conf Test Acc: 85.26
# Epoch: 087, TotalL: 7.5131, CrossE: 0.0060, CondE: 0.1340, disc: 0.6132, domain: 1.0552, Src VAT: 0.0380, Trg VAT: 0.1340, Src MixUp: 0.5297, Trg MixUp: 0.6315, Src Train Acc: 100.00, Trg Train Acc: 96.61, Src Test Acc: 100.00, Trg Test Acc: 94.88, Server Test Acc: 79.49, Office Test Acc: 74.86, Conf Test Acc: 88.00
# Epoch: 088, TotalL: 7.4516, CrossE: 0.0047, CondE: 0.1248, disc: 0.5930, domain: 1.0702, Src VAT: 0.0321, Trg VAT: 0.1248, Src MixUp: 0.4949, Trg MixUp: 0.6210, Src Train Acc: 100.00, Trg Train Acc: 96.79, Src Test Acc: 99.22, Trg Test Acc: 92.07, Server Test Acc: 71.92, Office Test Acc: 66.18, Conf Test Acc: 84.15
# Epoch: 089, TotalL: 7.4565, CrossE: 0.0048, CondE: 0.1125, disc: 0.6057, domain: 1.0519, Src VAT: 0.0321, Trg VAT: 0.1125, Src MixUp: 0.5067, Trg MixUp: 0.6118, Src Train Acc: 100.00, Trg Train Acc: 97.18, Src Test Acc: 99.22, Trg Test Acc: 91.55, Server Test Acc: 73.11, Office Test Acc: 62.74, Conf Test Acc: 84.15
# Epoch: 090, TotalL: 7.4509, CrossE: 0.0043, CondE: 0.1150, disc: 0.6037, domain: 1.0546, Src VAT: 0.0303, Trg VAT: 0.1150, Src MixUp: 0.5030, Trg MixUp: 0.5900, Src Train Acc: 100.00, Trg Train Acc: 97.57, Src Test Acc: 98.44, Trg Test Acc: 93.10, Server Test Acc: 74.89, Office Test Acc: 69.30, Conf Test Acc: 85.48
# Epoch: 091, TotalL: 7.4522, CrossE: 0.0045, CondE: 0.1101, disc: 0.6062, domain: 1.0429, Src VAT: 0.0315, Trg VAT: 0.1101, Src MixUp: 0.5096, Trg MixUp: 0.6010, Src Train Acc: 100.00, Trg Train Acc: 96.88, Src Test Acc: 99.61, Trg Test Acc: 92.48, Server Test Acc: 74.96, Office Test Acc: 67.63, Conf Test Acc: 86.81
# Epoch: 092, TotalL: 7.4457, CrossE: 0.0046, CondE: 0.1107, disc: 0.6089, domain: 1.0381, Src VAT: 0.0318, Trg VAT: 0.1107, Src MixUp: 0.5011, Trg MixUp: 0.5842, Src Train Acc: 100.00, Trg Train Acc: 97.44, Src Test Acc: 98.44, Trg Test Acc: 94.91, Server Test Acc: 76.75, Office Test Acc: 70.41, Conf Test Acc: 87.56
# Epoch: 093, TotalL: 7.5059, CrossE: 0.0054, CondE: 0.1160, disc: 0.6202, domain: 1.0350, Src VAT: 0.0352, Trg VAT: 0.1160, Src MixUp: 0.5267, Trg MixUp: 0.6083, Src Train Acc: 100.00, Trg Train Acc: 96.92, Src Test Acc: 97.67, Trg Test Acc: 93.48, Server Test Acc: 75.33, Office Test Acc: 66.85, Conf Test Acc: 85.63
# Epoch: 094, TotalL: 7.4234, CrossE: 0.0043, CondE: 0.1049, disc: 0.6057, domain: 1.0280, Src VAT: 0.0297, Trg VAT: 0.1049, Src MixUp: 0.4921, Trg MixUp: 0.5899, Src Train Acc: 100.00, Trg Train Acc: 97.22, Src Test Acc: 97.67, Trg Test Acc: 94.88, Server Test Acc: 78.75, Office Test Acc: 75.75, Conf Test Acc: 87.63
# Epoch: 095, TotalL: 7.4549, CrossE: 0.0051, CondE: 0.1099, disc: 0.6107, domain: 1.0298, Src VAT: 0.0335, Trg VAT: 0.1099, Src MixUp: 0.5068, Trg MixUp: 0.5922, Src Train Acc: 100.00, Trg Train Acc: 97.22, Src Test Acc: 98.44, Trg Test Acc: 95.26, Server Test Acc: 75.56, Office Test Acc: 69.30, Conf Test Acc: 85.26
# Epoch: 096, TotalL: 7.4340, CrossE: 0.0042, CondE: 0.1047, disc: 0.6069, domain: 1.0312, Src VAT: 0.0299, Trg VAT: 0.1047, Src MixUp: 0.5042, Trg MixUp: 0.5830, Src Train Acc: 100.00, Trg Train Acc: 97.44, Src Test Acc: 98.83, Trg Test Acc: 93.27, Server Test Acc: 76.08, Office Test Acc: 70.41, Conf Test Acc: 87.33
# Epoch: 097, TotalL: 7.4582, CrossE: 0.0045, CondE: 0.1069, disc: 0.6082, domain: 1.0372, Src VAT: 0.0306, Trg VAT: 0.1069, Src MixUp: 0.5156, Trg MixUp: 0.5897, Src Train Acc: 100.00, Trg Train Acc: 97.05, Src Test Acc: 99.22, Trg Test Acc: 92.86, Server Test Acc: 72.96, Office Test Acc: 65.52, Conf Test Acc: 84.07
# Epoch: 098, TotalL: 7.4307, CrossE: 0.0041, CondE: 0.1043, disc: 0.6100, domain: 1.0477, Src VAT: 0.0281, Trg VAT: 0.1043, Src MixUp: 0.4822, Trg MixUp: 0.5850, Src Train Acc: 100.00, Trg Train Acc: 97.31, Src Test Acc: 98.44, Trg Test Acc: 93.59, Server Test Acc: 74.96, Office Test Acc: 65.52, Conf Test Acc: 86.15
# Epoch: 099, TotalL: 7.4137, CrossE: 0.0042, CondE: 0.0986, disc: 0.6026, domain: 1.0303, Src VAT: 0.0296, Trg VAT: 0.0986, Src MixUp: 0.4864, Trg MixUp: 0.5745, Src Train Acc: 100.00, Trg Train Acc: 97.18, Src Test Acc: 99.61, Trg Test Acc: 93.45, Server Test Acc: 77.12, Office Test Acc: 68.97, Conf Test Acc: 88.30
# Epoch: 100, TotalL: 7.4405, CrossE: 0.0042, CondE: 0.0996, disc: 0.6159, domain: 1.0489, Src VAT: 0.0297, Trg VAT: 0.0996, Src MixUp: 0.4965, Trg MixUp: 0.5793, Src Train Acc: 100.00, Trg Train Acc: 97.27, Src Test Acc: 99.22, Trg Test Acc: 95.96, Server Test Acc: 77.49, Office Test Acc: 68.97, Conf Test Acc: 86.07
# Epoch: 101, TotalL: 7.4124, CrossE: 0.0040, CondE: 0.0967, disc: 0.6097, domain: 1.0260, Src VAT: 0.0287, Trg VAT: 0.0967, Src MixUp: 0.4907, Trg MixUp: 0.5739, Src Train Acc: 100.00, Trg Train Acc: 97.35, Src Test Acc: 99.22, Trg Test Acc: 94.30, Server Test Acc: 78.01, Office Test Acc: 72.19, Conf Test Acc: 88.30
# Epoch: 102, TotalL: 7.4041, CrossE: 0.0037, CondE: 0.0945, disc: 0.6114, domain: 1.0277, Src VAT: 0.0270, Trg VAT: 0.0945, Src MixUp: 0.4855, Trg MixUp: 0.5773, Src Train Acc: 100.00, Trg Train Acc: 97.40, Src Test Acc: 97.67, Trg Test Acc: 91.49, Server Test Acc: 73.70, Office Test Acc: 68.19, Conf Test Acc: 85.19
# Epoch: 103, TotalL: 7.4546, CrossE: 0.0050, CondE: 0.0944, disc: 0.6191, domain: 1.0106, Src VAT: 0.0304, Trg VAT: 0.0944, Src MixUp: 0.5171, Trg MixUp: 0.5705, Src Train Acc: 100.00, Trg Train Acc: 97.31, Src Test Acc: 98.44, Trg Test Acc: 93.45, Server Test Acc: 76.75, Office Test Acc: 70.52, Conf Test Acc: 86.74
# Epoch: 104, TotalL: 7.4079, CrossE: 0.0040, CondE: 0.0914, disc: 0.6202, domain: 1.0201, Src VAT: 0.0284, Trg VAT: 0.0914, Src MixUp: 0.4773, Trg MixUp: 0.5834, Src Train Acc: 100.00, Trg Train Acc: 97.44, Src Test Acc: 99.22, Trg Test Acc: 95.35, Server Test Acc: 80.24, Office Test Acc: 70.41, Conf Test Acc: 86.59
# Epoch: 105, TotalL: 7.4285, CrossE: 0.0042, CondE: 0.0920, disc: 0.6144, domain: 1.0249, Src VAT: 0.0289, Trg VAT: 0.0920, Src MixUp: 0.4977, Trg MixUp: 0.5537, Src Train Acc: 100.00, Trg Train Acc: 97.27, Src Test Acc: 99.61, Trg Test Acc: 95.82, Server Test Acc: 79.27, Office Test Acc: 74.30, Conf Test Acc: 87.11
# Epoch: 106, TotalL: 7.3978, CrossE: 0.0034, CondE: 0.0876, disc: 0.6159, domain: 1.0104, Src VAT: 0.0250, Trg VAT: 0.0876, Src MixUp: 0.4768, Trg MixUp: 0.5602, Src Train Acc: 100.00, Trg Train Acc: 97.35, Src Test Acc: 99.61, Trg Test Acc: 95.82, Server Test Acc: 78.31, Office Test Acc: 73.75, Conf Test Acc: 88.67
# Epoch: 107, TotalL: 7.4006, CrossE: 0.0035, CondE: 0.0849, disc: 0.6219, domain: 1.0269, Src VAT: 0.0247, Trg VAT: 0.0849, Src MixUp: 0.4761, Trg MixUp: 0.5756, Src Train Acc: 100.00, Trg Train Acc: 97.66, Src Test Acc: 98.83, Trg Test Acc: 95.06, Server Test Acc: 75.04, Office Test Acc: 68.63, Conf Test Acc: 85.41
# Epoch: 108, TotalL: 7.3796, CrossE: 0.0032, CondE: 0.0801, disc: 0.6065, domain: 1.0117, Src VAT: 0.0241, Trg VAT: 0.0801, Src MixUp: 0.4764, Trg MixUp: 0.5320, Src Train Acc: 100.00, Trg Train Acc: 97.40, Src Test Acc: 99.61, Trg Test Acc: 94.79, Server Test Acc: 75.78, Office Test Acc: 70.30, Conf Test Acc: 87.48
# Epoch: 109, TotalL: 7.3996, CrossE: 0.0037, CondE: 0.0855, disc: 0.6230, domain: 1.0143, Src VAT: 0.0264, Trg VAT: 0.0855, Src MixUp: 0.4753, Trg MixUp: 0.5598, Src Train Acc: 100.00, Trg Train Acc: 97.57, Src Test Acc: 99.22, Trg Test Acc: 95.41, Server Test Acc: 80.09, Office Test Acc: 75.75, Conf Test Acc: 88.81
# Epoch: 110, TotalL: 7.3759, CrossE: 0.0031, CondE: 0.0805, disc: 0.6099, domain: 1.0241, Src VAT: 0.0235, Trg VAT: 0.0805, Src MixUp: 0.4721, Trg MixUp: 0.5666, Src Train Acc: 100.00, Trg Train Acc: 97.53, Src Test Acc: 98.05, Trg Test Acc: 94.27, Server Test Acc: 75.48, Office Test Acc: 66.63, Conf Test Acc: 84.15
# Epoch: 111, TotalL: 7.3710, CrossE: 0.0035, CondE: 0.0821, disc: 0.6136, domain: 1.0160, Src VAT: 0.0253, Trg VAT: 0.0821, Src MixUp: 0.4649, Trg MixUp: 0.5717, Src Train Acc: 100.00, Trg Train Acc: 97.44, Src Test Acc: 99.61, Trg Test Acc: 93.30, Server Test Acc: 75.48, Office Test Acc: 70.63, Conf Test Acc: 86.81
# Epoch: 112, TotalL: 7.3843, CrossE: 0.0033, CondE: 0.0815, disc: 0.6248, domain: 1.0124, Src VAT: 0.0244, Trg VAT: 0.0815, Src MixUp: 0.4690, Trg MixUp: 0.5507, Src Train Acc: 100.00, Trg Train Acc: 97.31, Src Test Acc: 99.61, Trg Test Acc: 93.01, Server Test Acc: 76.15, Office Test Acc: 67.52, Conf Test Acc: 84.07
# Epoch: 113, TotalL: 7.3500, CrossE: 0.0030, CondE: 0.0760, disc: 0.6202, domain: 1.0156, Src VAT: 0.0224, Trg VAT: 0.0760, Src MixUp: 0.4508, Trg MixUp: 0.5345, Src Train Acc: 100.00, Trg Train Acc: 97.70, Src Test Acc: 99.61, Trg Test Acc: 93.54, Server Test Acc: 75.63, Office Test Acc: 66.96, Conf Test Acc: 85.63
# Epoch: 114, TotalL: 7.4106, CrossE: 0.0038, CondE: 0.0826, disc: 0.6407, domain: 1.0034, Src VAT: 0.0262, Trg VAT: 0.0826, Src MixUp: 0.4872, Trg MixUp: 0.5788, Src Train Acc: 100.00, Trg Train Acc: 97.40, Src Test Acc: 98.83, Trg Test Acc: 93.74, Server Test Acc: 76.45, Office Test Acc: 60.18, Conf Test Acc: 84.22
# Epoch: 115, TotalL: 7.3448, CrossE: 0.0030, CondE: 0.0727, disc: 0.6158, domain: 0.9980, Src VAT: 0.0220, Trg VAT: 0.0727, Src MixUp: 0.4465, Trg MixUp: 0.5426, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 99.61, Trg Test Acc: 95.58, Server Test Acc: 78.60, Office Test Acc: 73.75, Conf Test Acc: 87.41
# Epoch: 116, TotalL: 7.3640, CrossE: 0.0035, CondE: 0.0778, disc: 0.6302, domain: 0.9873, Src VAT: 0.0254, Trg VAT: 0.0778, Src MixUp: 0.4600, Trg MixUp: 0.5696, Src Train Acc: 100.00, Trg Train Acc: 97.53, Src Test Acc: 99.22, Trg Test Acc: 95.55, Server Test Acc: 74.44, Office Test Acc: 66.85, Conf Test Acc: 85.85
# Epoch: 117, TotalL: 7.3916, CrossE: 0.0037, CondE: 0.0755, disc: 0.6343, domain: 0.9922, Src VAT: 0.0255, Trg VAT: 0.0755, Src MixUp: 0.4801, Trg MixUp: 0.5619, Src Train Acc: 100.00, Trg Train Acc: 97.53, Src Test Acc: 99.61, Trg Test Acc: 94.00, Server Test Acc: 75.85, Office Test Acc: 65.74, Conf Test Acc: 87.85
# Epoch: 118, TotalL: 7.3641, CrossE: 0.0032, CondE: 0.0739, disc: 0.6189, domain: 0.9902, Src VAT: 0.0237, Trg VAT: 0.0739, Src MixUp: 0.4613, Trg MixUp: 0.5675, Src Train Acc: 100.00, Trg Train Acc: 97.57, Src Test Acc: 100.00, Trg Test Acc: 95.76, Server Test Acc: 80.83, Office Test Acc: 78.20, Conf Test Acc: 89.33
# Epoch: 119, TotalL: 7.3647, CrossE: 0.0036, CondE: 0.0739, disc: 0.6239, domain: 0.9943, Src VAT: 0.0244, Trg VAT: 0.0739, Src MixUp: 0.4544, Trg MixUp: 0.5684, Src Train Acc: 100.00, Trg Train Acc: 97.40, Src Test Acc: 98.83, Trg Test Acc: 93.10, Server Test Acc: 76.23, Office Test Acc: 69.74, Conf Test Acc: 87.19
# Epoch: 120, TotalL: 7.3545, CrossE: 0.0030, CondE: 0.0707, disc: 0.6150, domain: 0.9939, Src VAT: 0.0226, Trg VAT: 0.0707, Src MixUp: 0.4644, Trg MixUp: 0.5420, Src Train Acc: 100.00, Trg Train Acc: 97.70, Src Test Acc: 99.61, Trg Test Acc: 94.59, Server Test Acc: 77.12, Office Test Acc: 72.08, Conf Test Acc: 87.11
# Epoch: 121, TotalL: 7.3390, CrossE: 0.0031, CondE: 0.0675, disc: 0.6261, domain: 0.9882, Src VAT: 0.0228, Trg VAT: 0.0675, Src MixUp: 0.4458, Trg MixUp: 0.5327, Src Train Acc: 100.00, Trg Train Acc: 97.66, Src Test Acc: 100.00, Trg Test Acc: 95.09, Server Test Acc: 78.68, Office Test Acc: 73.08, Conf Test Acc: 88.44
# Epoch: 122, TotalL: 7.3633, CrossE: 0.0031, CondE: 0.0687, disc: 0.6329, domain: 0.9808, Src VAT: 0.0231, Trg VAT: 0.0687, Src MixUp: 0.4646, Trg MixUp: 0.5317, Src Train Acc: 100.00, Trg Train Acc: 97.66, Src Test Acc: 99.22, Trg Test Acc: 93.59, Server Test Acc: 75.04, Office Test Acc: 65.63, Conf Test Acc: 85.78
# Epoch: 123, TotalL: 7.3355, CrossE: 0.0032, CondE: 0.0638, disc: 0.6309, domain: 0.9828, Src VAT: 0.0221, Trg VAT: 0.0638, Src MixUp: 0.4411, Trg MixUp: 0.5060, Src Train Acc: 100.00, Trg Train Acc: 97.74, Src Test Acc: 99.61, Trg Test Acc: 96.02, Server Test Acc: 80.01, Office Test Acc: 70.52, Conf Test Acc: 87.48
# Epoch: 124, TotalL: 7.3529, CrossE: 0.0030, CondE: 0.0662, disc: 0.6291, domain: 0.9744, Src VAT: 0.0219, Trg VAT: 0.0662, Src MixUp: 0.4541, Trg MixUp: 0.5280, Src Train Acc: 100.00, Trg Train Acc: 97.66, Src Test Acc: 100.00, Trg Test Acc: 97.34, Server Test Acc: 79.49, Office Test Acc: 73.30, Conf Test Acc: 88.30
# Epoch: 125, TotalL: 7.3404, CrossE: 0.0028, CondE: 0.0626, disc: 0.6240, domain: 0.9790, Src VAT: 0.0213, Trg VAT: 0.0626, Src MixUp: 0.4459, Trg MixUp: 0.5345, Src Train Acc: 100.00, Trg Train Acc: 97.87, Src Test Acc: 98.44, Trg Test Acc: 93.59, Server Test Acc: 77.86, Office Test Acc: 68.19, Conf Test Acc: 88.00
# Epoch: 126, TotalL: 7.3292, CrossE: 0.0026, CondE: 0.0582, disc: 0.6271, domain: 0.9648, Src VAT: 0.0204, Trg VAT: 0.0582, Src MixUp: 0.4455, Trg MixUp: 0.5313, Src Train Acc: 100.00, Trg Train Acc: 98.05, Src Test Acc: 99.22, Trg Test Acc: 95.41, Server Test Acc: 76.97, Office Test Acc: 69.63, Conf Test Acc: 86.89
# Epoch: 127, TotalL: 7.3427, CrossE: 0.0028, CondE: 0.0602, disc: 0.6247, domain: 0.9717, Src VAT: 0.0206, Trg VAT: 0.0602, Src MixUp: 0.4593, Trg MixUp: 0.5325, Src Train Acc: 100.00, Trg Train Acc: 97.87, Src Test Acc: 100.00, Trg Test Acc: 95.12, Server Test Acc: 77.79, Office Test Acc: 70.52, Conf Test Acc: 87.11
# Epoch: 128, TotalL: 7.3144, CrossE: 0.0025, CondE: 0.0591, disc: 0.6326, domain: 0.9677, Src VAT: 0.0193, Trg VAT: 0.0591, Src MixUp: 0.4337, Trg MixUp: 0.5145, Src Train Acc: 100.00, Trg Train Acc: 97.87, Src Test Acc: 99.61, Trg Test Acc: 95.20, Server Test Acc: 76.37, Office Test Acc: 70.41, Conf Test Acc: 86.67
# Epoch: 129, TotalL: 7.3276, CrossE: 0.0029, CondE: 0.0605, disc: 0.6370, domain: 0.9669, Src VAT: 0.0214, Trg VAT: 0.0605, Src MixUp: 0.4386, Trg MixUp: 0.5340, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 98.44, Trg Test Acc: 94.44, Server Test Acc: 72.81, Office Test Acc: 63.63, Conf Test Acc: 81.93
# Epoch: 130, TotalL: 7.3314, CrossE: 0.0028, CondE: 0.0592, disc: 0.6349, domain: 0.9738, Src VAT: 0.0208, Trg VAT: 0.0592, Src MixUp: 0.4443, Trg MixUp: 0.5221, Src Train Acc: 100.00, Trg Train Acc: 97.79, Src Test Acc: 99.61, Trg Test Acc: 93.74, Server Test Acc: 78.38, Office Test Acc: 72.86, Conf Test Acc: 88.67
# Epoch: 131, TotalL: 7.3373, CrossE: 0.0025, CondE: 0.0574, disc: 0.6223, domain: 0.9736, Src VAT: 0.0199, Trg VAT: 0.0574, Src MixUp: 0.4591, Trg MixUp: 0.5120, Src Train Acc: 100.00, Trg Train Acc: 97.92, Src Test Acc: 98.83, Trg Test Acc: 93.59, Server Test Acc: 76.45, Office Test Acc: 68.85, Conf Test Acc: 88.44
# Epoch: 132, TotalL: 7.3192, CrossE: 0.0025, CondE: 0.0563, disc: 0.6386, domain: 0.9628, Src VAT: 0.0190, Trg VAT: 0.0563, Src MixUp: 0.4376, Trg MixUp: 0.4970, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 98.83, Trg Test Acc: 96.58, Server Test Acc: 79.49, Office Test Acc: 70.41, Conf Test Acc: 86.96
# Epoch: 133, TotalL: 7.3160, CrossE: 0.0025, CondE: 0.0564, disc: 0.6267, domain: 0.9592, Src VAT: 0.0197, Trg VAT: 0.0564, Src MixUp: 0.4376, Trg MixUp: 0.5187, Src Train Acc: 100.00, Trg Train Acc: 97.92, Src Test Acc: 99.22, Trg Test Acc: 97.43, Server Test Acc: 81.13, Office Test Acc: 75.75, Conf Test Acc: 88.07
# Epoch: 134, TotalL: 7.3172, CrossE: 0.0025, CondE: 0.0560, disc: 0.6390, domain: 0.9521, Src VAT: 0.0196, Trg VAT: 0.0560, Src MixUp: 0.4398, Trg MixUp: 0.5100, Src Train Acc: 100.00, Trg Train Acc: 98.05, Src Test Acc: 98.44, Trg Test Acc: 86.37, Server Test Acc: 67.09, Office Test Acc: 61.96, Conf Test Acc: 78.74
# Epoch: 135, TotalL: 7.3344, CrossE: 0.0029, CondE: 0.0582, disc: 0.6554, domain: 0.9453, Src VAT: 0.0212, Trg VAT: 0.0582, Src MixUp: 0.4460, Trg MixUp: 0.5130, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 99.61, Trg Test Acc: 96.72, Server Test Acc: 80.24, Office Test Acc: 74.86, Conf Test Acc: 88.67
# Epoch: 136, TotalL: 7.3241, CrossE: 0.0025, CondE: 0.0536, disc: 0.6423, domain: 0.9389, Src VAT: 0.0196, Trg VAT: 0.0536, Src MixUp: 0.4468, Trg MixUp: 0.4908, Src Train Acc: 100.00, Trg Train Acc: 97.92, Src Test Acc: 98.83, Trg Test Acc: 97.51, Server Test Acc: 79.64, Office Test Acc: 70.41, Conf Test Acc: 87.93
# Epoch: 137, TotalL: 7.2967, CrossE: 0.0022, CondE: 0.0508, disc: 0.6324, domain: 0.9489, Src VAT: 0.0177, Trg VAT: 0.0508, Src MixUp: 0.4291, Trg MixUp: 0.4948, Src Train Acc: 100.00, Trg Train Acc: 98.05, Src Test Acc: 98.83, Trg Test Acc: 94.24, Server Test Acc: 76.75, Office Test Acc: 68.30, Conf Test Acc: 85.11
# Epoch: 138, TotalL: 7.3256, CrossE: 0.0023, CondE: 0.0516, disc: 0.6365, domain: 0.9528, Src VAT: 0.0182, Trg VAT: 0.0516, Src MixUp: 0.4501, Trg MixUp: 0.5108, Src Train Acc: 100.00, Trg Train Acc: 97.96, Src Test Acc: 99.22, Trg Test Acc: 95.09, Server Test Acc: 74.29, Office Test Acc: 67.85, Conf Test Acc: 84.15
# Epoch: 139, TotalL: 7.2961, CrossE: 0.0022, CondE: 0.0491, disc: 0.6377, domain: 0.9431, Src VAT: 0.0176, Trg VAT: 0.0491, Src MixUp: 0.4253, Trg MixUp: 0.5047, Src Train Acc: 100.00, Trg Train Acc: 97.96, Src Test Acc: 99.22, Trg Test Acc: 96.17, Server Test Acc: 79.42, Office Test Acc: 72.30, Conf Test Acc: 88.89
# Epoch: 140, TotalL: 7.3002, CrossE: 0.0026, CondE: 0.0486, disc: 0.6425, domain: 0.9421, Src VAT: 0.0189, Trg VAT: 0.0486, Src MixUp: 0.4235, Trg MixUp: 0.4891, Src Train Acc: 100.00, Trg Train Acc: 98.05, Src Test Acc: 100.00, Trg Test Acc: 96.37, Server Test Acc: 80.98, Office Test Acc: 74.97, Conf Test Acc: 90.59
# Epoch: 141, TotalL: 7.3131, CrossE: 0.0024, CondE: 0.0506, disc: 0.6366, domain: 0.9351, Src VAT: 0.0185, Trg VAT: 0.0506, Src MixUp: 0.4461, Trg MixUp: 0.5145, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 98.44, Trg Test Acc: 93.54, Server Test Acc: 74.07, Office Test Acc: 67.30, Conf Test Acc: 85.56
# Epoch: 142, TotalL: 7.2943, CrossE: 0.0023, CondE: 0.0481, disc: 0.6371, domain: 0.9394, Src VAT: 0.0177, Trg VAT: 0.0481, Src MixUp: 0.4266, Trg MixUp: 0.4873, Src Train Acc: 100.00, Trg Train Acc: 98.00, Src Test Acc: 99.61, Trg Test Acc: 96.11, Server Test Acc: 79.57, Office Test Acc: 70.86, Conf Test Acc: 88.07
# Epoch: 143, TotalL: 7.2963, CrossE: 0.0023, CondE: 0.0470, disc: 0.6385, domain: 0.9252, Src VAT: 0.0183, Trg VAT: 0.0470, Src MixUp: 0.4352, Trg MixUp: 0.4870, Src Train Acc: 100.00, Trg Train Acc: 98.00, Src Test Acc: 100.00, Trg Test Acc: 96.26, Server Test Acc: 80.24, Office Test Acc: 74.75, Conf Test Acc: 89.41
# Epoch: 144, TotalL: 7.3043, CrossE: 0.0026, CondE: 0.0467, disc: 0.6635, domain: 0.9271, Src VAT: 0.0189, Trg VAT: 0.0467, Src MixUp: 0.4201, Trg MixUp: 0.4742, Src Train Acc: 100.00, Trg Train Acc: 97.92, Src Test Acc: 100.00, Trg Test Acc: 96.17, Server Test Acc: 80.46, Office Test Acc: 73.19, Conf Test Acc: 88.37
# Epoch: 145, TotalL: 7.2917, CrossE: 0.0023, CondE: 0.0452, disc: 0.6470, domain: 0.9237, Src VAT: 0.0177, Trg VAT: 0.0452, Src MixUp: 0.4216, Trg MixUp: 0.4924, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 95.88, Server Test Acc: 77.12, Office Test Acc: 69.41, Conf Test Acc: 87.93
# Epoch: 146, TotalL: 7.2855, CrossE: 0.0022, CondE: 0.0448, disc: 0.6420, domain: 0.9288, Src VAT: 0.0172, Trg VAT: 0.0448, Src MixUp: 0.4217, Trg MixUp: 0.4757, Src Train Acc: 100.00, Trg Train Acc: 97.83, Src Test Acc: 99.61, Trg Test Acc: 96.37, Server Test Acc: 80.46, Office Test Acc: 74.08, Conf Test Acc: 89.70
# Epoch: 147, TotalL: 7.2790, CrossE: 0.0021, CondE: 0.0442, disc: 0.6346, domain: 0.9294, Src VAT: 0.0165, Trg VAT: 0.0442, Src MixUp: 0.4194, Trg MixUp: 0.4820, Src Train Acc: 100.00, Trg Train Acc: 97.96, Src Test Acc: 99.61, Trg Test Acc: 96.14, Server Test Acc: 80.24, Office Test Acc: 74.75, Conf Test Acc: 89.33
# Epoch: 148, TotalL: 7.3102, CrossE: 0.0023, CondE: 0.0471, disc: 0.6562, domain: 0.9319, Src VAT: 0.0176, Trg VAT: 0.0471, Src MixUp: 0.4315, Trg MixUp: 0.4839, Src Train Acc: 100.00, Trg Train Acc: 97.96, Src Test Acc: 100.00, Trg Test Acc: 96.11, Server Test Acc: 79.72, Office Test Acc: 72.75, Conf Test Acc: 88.67
# ...
# Epoch: 437, TotalL: 7.0497, CrossE: 0.0006, CondE: 0.0071, disc: 0.6877, domain: 0.7268, Src VAT: 0.0059, Trg VAT: 0.0071, Src MixUp: 0.2741, Trg MixUp: 0.3116, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.22, Server Test Acc: 84.40, Office Test Acc: 78.64, Conf Test Acc: 92.67
# Epoch: 438, TotalL: 7.0590, CrossE: 0.0007, CondE: 0.0078, disc: 0.6911, domain: 0.7201, Src VAT: 0.0065, Trg VAT: 0.0078, Src MixUp: 0.2840, Trg MixUp: 0.3212, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.33, Server Test Acc: 83.21, Office Test Acc: 77.09, Conf Test Acc: 92.37
# Epoch: 439, TotalL: 7.0616, CrossE: 0.0006, CondE: 0.0078, disc: 0.6881, domain: 0.7259, Src VAT: 0.0062, Trg VAT: 0.0078, Src MixUp: 0.2839, Trg MixUp: 0.3115, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 97.95, Server Test Acc: 84.70, Office Test Acc: 80.65, Conf Test Acc: 93.26
# Epoch: 440, TotalL: 7.0622, CrossE: 0.0007, CondE: 0.0080, disc: 0.6891, domain: 0.7288, Src VAT: 0.0064, Trg VAT: 0.0080, Src MixUp: 0.2784, Trg MixUp: 0.3502, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.36, Server Test Acc: 85.59, Office Test Acc: 80.65, Conf Test Acc: 92.44
# Epoch: 441, TotalL: 7.0632, CrossE: 0.0006, CondE: 0.0076, disc: 0.6916, domain: 0.7270, Src VAT: 0.0061, Trg VAT: 0.0076, Src MixUp: 0.2806, Trg MixUp: 0.3280, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 97.63, Server Test Acc: 82.17, Office Test Acc: 74.30, Conf Test Acc: 91.19
# Epoch: 442, TotalL: 7.0950, CrossE: 0.0008, CondE: 0.0095, disc: 0.6866, domain: 0.7373, Src VAT: 0.0070, Trg VAT: 0.0095, Src MixUp: 0.2962, Trg MixUp: 0.3441, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 97.84, Server Test Acc: 82.39, Office Test Acc: 71.41, Conf Test Acc: 91.85
# Epoch: 443, TotalL: 7.0649, CrossE: 0.0007, CondE: 0.0079, disc: 0.6873, domain: 0.7249, Src VAT: 0.0066, Trg VAT: 0.0079, Src MixUp: 0.2832, Trg MixUp: 0.3300, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 97.84, Server Test Acc: 82.76, Office Test Acc: 70.30, Conf Test Acc: 90.89
# Epoch: 444, TotalL: 7.0597, CrossE: 0.0006, CondE: 0.0071, disc: 0.6881, domain: 0.7219, Src VAT: 0.0061, Trg VAT: 0.0071, Src MixUp: 0.2823, Trg MixUp: 0.3203, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.01, Server Test Acc: 83.14, Office Test Acc: 73.41, Conf Test Acc: 92.81
# Epoch: 445, TotalL: 7.0746, CrossE: 0.0007, CondE: 0.0087, disc: 0.6901, domain: 0.7234, Src VAT: 0.0069, Trg VAT: 0.0087, Src MixUp: 0.2914, Trg MixUp: 0.3306, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.42, Server Test Acc: 84.92, Office Test Acc: 80.20, Conf Test Acc: 92.59
# Epoch: 446, TotalL: 7.0720, CrossE: 0.0007, CondE: 0.0085, disc: 0.6891, domain: 0.7218, Src VAT: 0.0068, Trg VAT: 0.0085, Src MixUp: 0.2944, Trg MixUp: 0.3264, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 97.86, Server Test Acc: 84.18, Office Test Acc: 75.42, Conf Test Acc: 92.15
# Epoch: 447, TotalL: 7.0497, CrossE: 0.0007, CondE: 0.0077, disc: 0.6886, domain: 0.7233, Src VAT: 0.0065, Trg VAT: 0.0077, Src MixUp: 0.2723, Trg MixUp: 0.3262, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 98.30, Server Test Acc: 84.47, Office Test Acc: 81.42, Conf Test Acc: 92.67
# Epoch: 448, TotalL: 7.0453, CrossE: 0.0007, CondE: 0.0075, disc: 0.6903, domain: 0.7197, Src VAT: 0.0066, Trg VAT: 0.0075, Src MixUp: 0.2701, Trg MixUp: 0.3155, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 98.19, Server Test Acc: 84.18, Office Test Acc: 75.31, Conf Test Acc: 91.85
# Epoch: 449, TotalL: 7.0722, CrossE: 0.0007, CondE: 0.0082, disc: 0.6897, domain: 0.7263, Src VAT: 0.0066, Trg VAT: 0.0082, Src MixUp: 0.2845, Trg MixUp: 0.3351, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.36, Server Test Acc: 84.25, Office Test Acc: 78.09, Conf Test Acc: 92.37
# Epoch: 450, TotalL: 7.0588, CrossE: 0.0006, CondE: 0.0073, disc: 0.6866, domain: 0.7286, Src VAT: 0.0058, Trg VAT: 0.0073, Src MixUp: 0.2772, Trg MixUp: 0.3224, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 98.25, Server Test Acc: 84.10, Office Test Acc: 78.53, Conf Test Acc: 92.07
# Epoch: 451, TotalL: 7.0568, CrossE: 0.0007, CondE: 0.0072, disc: 0.6881, domain: 0.7255, Src VAT: 0.0063, Trg VAT: 0.0072, Src MixUp: 0.2716, Trg MixUp: 0.3397, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 97.75, Server Test Acc: 83.06, Office Test Acc: 76.86, Conf Test Acc: 92.30
# Epoch: 452, TotalL: 7.0710, CrossE: 0.0006, CondE: 0.0075, disc: 0.6881, domain: 0.7248, Src VAT: 0.0062, Trg VAT: 0.0075, Src MixUp: 0.2904, Trg MixUp: 0.3155, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.01, Server Test Acc: 84.25, Office Test Acc: 77.20, Conf Test Acc: 90.96
# Epoch: 453, TotalL: 7.0482, CrossE: 0.0006, CondE: 0.0071, disc: 0.6871, domain: 0.7232, Src VAT: 0.0059, Trg VAT: 0.0071, Src MixUp: 0.2721, Trg MixUp: 0.3228, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 97.57, Server Test Acc: 83.36, Office Test Acc: 76.53, Conf Test Acc: 92.44
# Epoch: 454, TotalL: 7.0532, CrossE: 0.0006, CondE: 0.0067, disc: 0.6894, domain: 0.7201, Src VAT: 0.0057, Trg VAT: 0.0067, Src MixUp: 0.2795, Trg MixUp: 0.3206, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.39, Server Test Acc: 84.62, Office Test Acc: 79.76, Conf Test Acc: 92.15
# Epoch: 455, TotalL: 7.0590, CrossE: 0.0006, CondE: 0.0073, disc: 0.6870, domain: 0.7232, Src VAT: 0.0060, Trg VAT: 0.0073, Src MixUp: 0.2833, Trg MixUp: 0.3264, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.10, Server Test Acc: 85.36, Office Test Acc: 78.42, Conf Test Acc: 92.59
# Epoch: 456, TotalL: 7.0588, CrossE: 0.0006, CondE: 0.0071, disc: 0.6910, domain: 0.7200, Src VAT: 0.0061, Trg VAT: 0.0071, Src MixUp: 0.2829, Trg MixUp: 0.3244, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 98.42, Server Test Acc: 84.99, Office Test Acc: 82.65, Conf Test Acc: 92.44
# Epoch: 457, TotalL: 7.0483, CrossE: 0.0007, CondE: 0.0076, disc: 0.6909, domain: 0.7198, Src VAT: 0.0066, Trg VAT: 0.0076, Src MixUp: 0.2744, Trg MixUp: 0.3102, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.36, Server Test Acc: 85.14, Office Test Acc: 80.09, Conf Test Acc: 91.56
# Epoch: 458, TotalL: 7.0994, CrossE: 0.0008, CondE: 0.0097, disc: 0.6870, domain: 0.7346, Src VAT: 0.0069, Trg VAT: 0.0097, Src MixUp: 0.2980, Trg MixUp: 0.3345, Src Train Acc: 100.00, Trg Train Acc: 98.05, Src Test Acc: 99.61, Trg Test Acc: 97.75, Server Test Acc: 83.88, Office Test Acc: 76.75, Conf Test Acc: 91.63
# Epoch: 459, TotalL: 7.0557, CrossE: 0.0006, CondE: 0.0074, disc: 0.6874, domain: 0.7265, Src VAT: 0.0056, Trg VAT: 0.0074, Src MixUp: 0.2765, Trg MixUp: 0.3252, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.54, Server Test Acc: 85.96, Office Test Acc: 81.87, Conf Test Acc: 93.26
# Epoch: 460, TotalL: 7.0557, CrossE: 0.0006, CondE: 0.0073, disc: 0.6886, domain: 0.7216, Src VAT: 0.0059, Trg VAT: 0.0073, Src MixUp: 0.2779, Trg MixUp: 0.3195, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 97.98, Server Test Acc: 83.80, Office Test Acc: 75.86, Conf Test Acc: 92.67
# Epoch: 461, TotalL: 7.0529, CrossE: 0.0006, CondE: 0.0072, disc: 0.6899, domain: 0.7249, Src VAT: 0.0061, Trg VAT: 0.0072, Src MixUp: 0.2713, Trg MixUp: 0.3123, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 97.46, Server Test Acc: 83.80, Office Test Acc: 73.64, Conf Test Acc: 90.81
# Epoch: 462, TotalL: 7.0548, CrossE: 0.0007, CondE: 0.0082, disc: 0.6882, domain: 0.7293, Src VAT: 0.0062, Trg VAT: 0.0082, Src MixUp: 0.2717, Trg MixUp: 0.3172, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.16, Server Test Acc: 85.51, Office Test Acc: 80.87, Conf Test Acc: 93.26
# Epoch: 463, TotalL: 7.0476, CrossE: 0.0006, CondE: 0.0069, disc: 0.6901, domain: 0.7196, Src VAT: 0.0057, Trg VAT: 0.0069, Src MixUp: 0.2723, Trg MixUp: 0.3132, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.77, Server Test Acc: 85.74, Office Test Acc: 82.09, Conf Test Acc: 91.93
# Epoch: 464, TotalL: 7.0535, CrossE: 0.0006, CondE: 0.0072, disc: 0.6897, domain: 0.7187, Src VAT: 0.0061, Trg VAT: 0.0072, Src MixUp: 0.2788, Trg MixUp: 0.3132, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 98.44, Trg Test Acc: 97.05, Server Test Acc: 80.46, Office Test Acc: 68.30, Conf Test Acc: 90.15
# Epoch: 465, TotalL: 7.0568, CrossE: 0.0006, CondE: 0.0072, disc: 0.6883, domain: 0.7214, Src VAT: 0.0063, Trg VAT: 0.0072, Src MixUp: 0.2832, Trg MixUp: 0.3267, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.16, Server Test Acc: 83.95, Office Test Acc: 77.75, Conf Test Acc: 92.15
# Epoch: 466, TotalL: 7.0533, CrossE: 0.0007, CondE: 0.0076, disc: 0.6944, domain: 0.7163, Src VAT: 0.0064, Trg VAT: 0.0076, Src MixUp: 0.2780, Trg MixUp: 0.3240, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.04, Server Test Acc: 83.88, Office Test Acc: 79.87, Conf Test Acc: 92.52
# Epoch: 467, TotalL: 7.0646, CrossE: 0.0007, CondE: 0.0077, disc: 0.6913, domain: 0.7199, Src VAT: 0.0064, Trg VAT: 0.0077, Src MixUp: 0.2837, Trg MixUp: 0.3356, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.60, Server Test Acc: 85.96, Office Test Acc: 82.98, Conf Test Acc: 93.93
# Epoch: 468, TotalL: 7.0626, CrossE: 0.0007, CondE: 0.0079, disc: 0.6881, domain: 0.7205, Src VAT: 0.0065, Trg VAT: 0.0079, Src MixUp: 0.2837, Trg MixUp: 0.3250, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 96.61, Server Test Acc: 81.43, Office Test Acc: 74.30, Conf Test Acc: 91.26
# Epoch: 469, TotalL: 7.0637, CrossE: 0.0007, CondE: 0.0079, disc: 0.6895, domain: 0.7215, Src VAT: 0.0069, Trg VAT: 0.0079, Src MixUp: 0.2836, Trg MixUp: 0.3246, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 97.43, Server Test Acc: 83.80, Office Test Acc: 73.64, Conf Test Acc: 91.93
# Epoch: 470, TotalL: 7.0779, CrossE: 0.0007, CondE: 0.0091, disc: 0.6871, domain: 0.7298, Src VAT: 0.0068, Trg VAT: 0.0091, Src MixUp: 0.2887, Trg MixUp: 0.3367, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 97.10, Server Test Acc: 80.01, Office Test Acc: 75.31, Conf Test Acc: 90.00
# Epoch: 471, TotalL: 7.0582, CrossE: 0.0006, CondE: 0.0068, disc: 0.6871, domain: 0.7267, Src VAT: 0.0056, Trg VAT: 0.0068, Src MixUp: 0.2733, Trg MixUp: 0.3201, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 95.20, Server Test Acc: 82.47, Office Test Acc: 71.64, Conf Test Acc: 91.33
# Epoch: 472, TotalL: 7.0532, CrossE: 0.0006, CondE: 0.0066, disc: 0.6892, domain: 0.7202, Src VAT: 0.0057, Trg VAT: 0.0066, Src MixUp: 0.2778, Trg MixUp: 0.3172, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.04, Server Test Acc: 84.18, Office Test Acc: 77.53, Conf Test Acc: 91.78
# Epoch: 473, TotalL: 7.0472, CrossE: 0.0006, CondE: 0.0071, disc: 0.6877, domain: 0.7199, Src VAT: 0.0060, Trg VAT: 0.0071, Src MixUp: 0.2724, Trg MixUp: 0.3173, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.22, Trg Test Acc: 98.33, Server Test Acc: 84.32, Office Test Acc: 77.42, Conf Test Acc: 90.74
# Epoch: 474, TotalL: 7.0550, CrossE: 0.0006, CondE: 0.0072, disc: 0.6886, domain: 0.7217, Src VAT: 0.0062, Trg VAT: 0.0072, Src MixUp: 0.2743, Trg MixUp: 0.3205, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 97.54, Server Test Acc: 82.62, Office Test Acc: 77.20, Conf Test Acc: 92.44
# Epoch: 475, TotalL: 7.0475, CrossE: 0.0006, CondE: 0.0069, disc: 0.6888, domain: 0.7222, Src VAT: 0.0058, Trg VAT: 0.0069, Src MixUp: 0.2692, Trg MixUp: 0.3157, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.16, Server Test Acc: 84.18, Office Test Acc: 79.64, Conf Test Acc: 91.93
# Epoch: 476, TotalL: 7.0373, CrossE: 0.0005, CondE: 0.0060, disc: 0.6884, domain: 0.7195, Src VAT: 0.0052, Trg VAT: 0.0060, Src MixUp: 0.2646, Trg MixUp: 0.3085, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.51, Server Test Acc: 84.47, Office Test Acc: 77.64, Conf Test Acc: 91.93
# Epoch: 477, TotalL: 7.0462, CrossE: 0.0006, CondE: 0.0066, disc: 0.6900, domain: 0.7196, Src VAT: 0.0055, Trg VAT: 0.0066, Src MixUp: 0.2734, Trg MixUp: 0.3106, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 99.61, Trg Test Acc: 98.04, Server Test Acc: 84.40, Office Test Acc: 76.97, Conf Test Acc: 92.81
# Epoch: 478, TotalL: 7.0523, CrossE: 0.0006, CondE: 0.0073, disc: 0.6900, domain: 0.7197, Src VAT: 0.0062, Trg VAT: 0.0073, Src MixUp: 0.2776, Trg MixUp: 0.3097, Src Train Acc: 100.00, Trg Train Acc: 98.09, Src Test Acc: 100.00, Trg Test Acc: 98.51, Server Test Acc: 85.07, Office Test Acc: 81.09, Conf Test Acc: 92.37
# Epoch: 479, TotalL: 7.1270, CrossE: 0.0034, CondE: 0.0125, disc: 0.6919, domain: 0.7405, Src VAT: 0.0088, Trg VAT: 0.0125, Src MixUp: 0.2955, Trg MixUp: 0.3403, Src Train Acc: 99.91, Trg Train Acc: 97.96,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f529ec3c0b50> in <module>
#      51                               trg_train_accuracy.result()*100), end="")
#      52
# ---> 53   for target_data in trg_test_set:
#      54     test_target_step(target_data[0], target_data[1])
#      55
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#    1895
#    1896   def __iter__(self):
# -> 1897     return iter(self._dataset)
#    1898
#    1899
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     285       RuntimeError: If eager execution is not enabled.
#     286     """
# --> 287     return iterator_ops.IteratorV2(self)
#     288
#     289   @abc.abstractproperty
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset)
#     562     with ops.device("/cpu:0"):
#     563       # pylint: disable=protected-access
# --> 564       dataset = dataset._apply_options()
#     565       ds_variant = dataset._variant_tensor
#     566       self._structure = dataset._element_structure
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/data/ops/dataset_ops.py in _apply_options(self)
#     253       else:
#     254         dataset = _OptimizeDataset(dataset, static_optimizations,
# --> 255                                    static_optimization_configs)
#     256
#     257     autotune = True
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations, optimization_configs)
#    3505         self._optimizations,
#    3506         optimization_configs=optimization_configs,
# -> 3507         **flat_structure(self))
#    3508     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#    3509
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/ops/gen_dataset_ops.py in optimize_dataset(input_dataset, optimizations, output_types, output_shapes, optimization_configs, name)
#    3381         input_dataset, optimizations, "output_types", output_types,
#    3382         "output_shapes", output_shapes, "optimization_configs",
# -> 3383         optimization_configs)
#    3384       return _result
#    3385     except _core._FallbackException:
#
# KeyboardInterrupt:
