# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='0'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 1.14.0

# %%
num_classes    = 9
batch_size     = 16
train_days     = 3
epochs         = 500
learning_rate  = 0.0001

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = np.expand_dims(hf.get('X_data'), axis=-1).astype(np.float32)
y_data = np.array(hf.get('y_data')).astype(np.int32)
classes = list(hf.get('classes'))
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (9145, 128, 1024, 1) (9145, 2)
#  [b'arahman3', b'harika', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)
# Out:
# (8740, 128, 1024, 1) (8740, 2)

# %%
#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)
# Out:
# (8550, 128, 1024, 1) (8550, 2)
#  [b'arahman3', b'hchen32', b'jlaivins', b'kjakkala', b'pjanakar', b'ppinyoan', b'pwang13', b'upattnai', b'wrang']

# %%
#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_days]
y_src = y_data[y_data[:, 1] < train_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg  = X_data[y_data[:, 1] >= train_days]
y_trg  = y_data[y_data[:, 1] >= train_days, 0]
y_trg = np.eye(len(classes))[y_trg]
X_train_trg, X_test_trg, y_train_trg, y_test_trg = train_test_split(X_trg,
                                                                    y_trg,
                                                                    stratify=y_trg,
                                                                    test_size=0.20,
                                                                    random_state=42)
del X_src, y_src, X_trg, y_trg

y_train_trg = y_train_trg.astype(np.int64)
y_test_trg  = y_test_trg.astype(np.int64)
y_train_src = y_train_src.astype(np.int64)
y_test_src  = y_test_src.astype(np.int64)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (4788, 128, 1024, 1) (4788, 9) (1197, 128, 1024, 1) (1197, 9)

# %%
#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (2308, 128, 1024, 1) (2308, 9) (257, 128, 1024, 1) (257, 9) (4788, 128, 1024, 1) (4788, 9) (1197, 128, 1024, 1) (1197, 9)

# %%
#get tf.data objects for each set
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
trg_train_set = trg_train_set.shuffle(X_train_trg.shape[0])
trg_train_set = trg_train_set.batch(batch_size, drop_remainder=True)
trg_train_set = trg_train_set.prefetch(tf.data.experimental.AUTOTUNE)
trg_train_set = trg_train_set.repeat(-1)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(tf.data.experimental.AUTOTUNE)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation('relu')(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2)):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation('relu')(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    return x


"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features):
    super().__init__(name='generator')
    bn_axis = -1

    #self.conv1_pad = tf.keras.layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')
    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.relu1 = tf.keras.layers.Activation('relu', name='relu1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a'))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b'))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a'))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b'))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation='relu',
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False):
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.relu1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    logits = self.logits(fc1)
    return logits, fc1

# %%
class Discriminator(tf.keras.Model):
  def __init__(self):
    super().__init__(name='discriminator')  
    self.dense1 = tf.keras.layers.Dense(100, activation='relu')
    self.logits = tf.keras.layers.Dense(1, activation=None)

  def call(self, inputs):
    x = self.dense1(inputs)
    x = self.logits(x)

    return x

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

def get_domain_confusion_loss(src_logits, trg_logits):
  discriminator_loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(src_logits),
                                                               logits=src_logits) + \
                       tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(trg_logits),
                                                               logits=trg_logits)
  return 0.5 * tf.reduce_mean(discriminator_loss)

def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _ = generator(images + noise, 
                                tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images, trg_labels):  
  with tf.GradientTape() as gen_tape:
    src_logits, src_enc = generator(src_images, training=True)
    trg_logits, trg_enc = generator(trg_images, training=True)  
    src_adver_images    = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _ = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images    = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _ = generator(tf.stop_gradient(trg_adver_images), training=True)
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)

    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(trg_logits), 
                                                 logits=trg_logits)
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(trg_logits)),
                                                 logits=trg_adver_logits)
    domain_loss         = get_domain_confusion_loss(src_logits=trg_disc_logits, 
                                                    trg_logits=src_disc_logits)

    total_loss = 1    * cross_entropy_loss + \
                 1e-2 * domain_loss + \
                 1e-2 * cross_cond_loss + \
                 1e-2 * trg_vat_loss + \
                 1    * src_vat_loss    
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(trg_labels, trg_logits)
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def train_disc_step(src_images, trg_images):  
  with tf.GradientTape() as disc_tape:
    _, src_enc          = generator(src_images, training=True)
    _, trg_enc          = generator(trg_images, training=True)  
    src_disc_logits     = discriminator(src_enc)
    trg_disc_logits     = discriminator(trg_enc)    
    domain_conf_loss    = get_domain_confusion_loss(src_logits=src_disc_logits, 
                                                    trg_logits=trg_disc_logits)
  
  disc_gradients = disc_tape.gradient(domain_conf_loss, 
                                      discriminator.trainable_variables)
  disc_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
  train_discriminator_loss(domain_conf_loss)

@tf.function
def test_source_step(source_images, source_labels):
  source_logits, _ = generator(source_images, training=False)
  src_test_accuracy(source_labels, source_logits)
    
@tf.function
def test_target_step(target_images, target_labels):
  target_logits, _ = generator(target_images, training=False)
  trg_test_accuracy(target_labels, target_logits)

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}'

generator      = ResNet50(num_classes, 256)
discriminator  = Discriminator()
disc_optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)

for epoch in range(epochs):
  for source_data, target_data in zip(src_train_set, trg_train_set):
    train_gen_step(source_data[0], source_data[1], target_data[0], target_data[1])    
    train_disc_step(source_data[0], target_data[0])

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()

  for target_data in trg_test_set:
    test_target_step(target_data[0], target_data[1])

  for source_data in src_test_set:
    test_source_step(source_data[0], source_data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100))

  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0818 15:00:12.662742 140437154838272 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 4.4457, CrossE: 2.2009, CondE: 2.1941, disc: 0.6943, domain: 0.6942, Src VAT: 2.1940, Trg VAT: 2.1941, Src Train Acc: 10.46, Trg Train Acc: 11.68, Src Test Acc: 11.28, Trg Test Acc: 11.11
# Epoch: 002, TotalL: 4.4100, CrossE: 2.1746, CondE: 2.1839, disc: 0.6943, domain: 0.6952, Src VAT: 2.1847, Trg VAT: 2.1839, Src Train Acc: 12.54, Trg Train Acc: 13.93, Src Test Acc: 18.68, Trg Test Acc: 18.80
# Epoch: 003, TotalL: 3.7646, CrossE: 1.8490, CondE: 1.8844, disc: 0.6983, domain: 0.7089, Src VAT: 1.8708, Trg VAT: 1.8844, Src Train Acc: 24.74, Trg Train Acc: 24.57, Src Test Acc: 24.12, Trg Test Acc: 26.65
# Epoch: 004, TotalL: 3.5022, CrossE: 1.7220, CondE: 1.7563, disc: 0.6984, domain: 0.7106, Src VAT: 1.7380, Trg VAT: 1.7563, Src Train Acc: 30.86, Trg Train Acc: 28.95, Src Test Acc: 27.63, Trg Test Acc: 30.74
# Epoch: 005, TotalL: 3.2990, CrossE: 1.6173, CondE: 1.6622, disc: 0.7033, domain: 0.7113, Src VAT: 1.6414, Trg VAT: 1.6622, Src Train Acc: 36.89, Trg Train Acc: 34.24, Src Test Acc: 30.35, Trg Test Acc: 36.76
# Epoch: 006, TotalL: 3.0346, CrossE: 1.4807, CondE: 1.5425, disc: 0.7068, domain: 0.7140, Src VAT: 1.5160, Trg VAT: 1.5425, Src Train Acc: 43.14, Trg Train Acc: 39.71, Src Test Acc: 41.63, Trg Test Acc: 45.78
# Epoch: 007, TotalL: 2.7527, CrossE: 1.3398, CondE: 1.4084, disc: 0.7087, domain: 0.7191, Src VAT: 1.3775, Trg VAT: 1.4084, Src Train Acc: 49.31, Trg Train Acc: 44.88, Src Test Acc: 51.36, Trg Test Acc: 50.46
# Epoch: 008, TotalL: 2.5280, CrossE: 1.2292, CondE: 1.2987, disc: 0.7061, domain: 0.7275, Src VAT: 1.2655, Trg VAT: 1.2987, Src Train Acc: 53.56, Trg Train Acc: 48.09, Src Test Acc: 54.47, Trg Test Acc: 54.05
# Epoch: 009, TotalL: 2.3677, CrossE: 1.1517, CondE: 1.2200, disc: 0.7048, domain: 0.7306, Src VAT: 1.1843, Trg VAT: 1.2200, Src Train Acc: 57.07, Trg Train Acc: 50.00, Src Test Acc: 57.98, Trg Test Acc: 57.14
# Epoch: 010, TotalL: 2.2346, CrossE: 1.0849, CondE: 1.1574, disc: 0.7039, domain: 0.7337, Src VAT: 1.1193, Trg VAT: 1.1574, Src Train Acc: 60.46, Trg Train Acc: 52.86, Src Test Acc: 60.31, Trg Test Acc: 59.31
# Epoch: 011, TotalL: 2.1168, CrossE: 1.0270, CondE: 1.1036, disc: 0.7027, domain: 0.7354, Src VAT: 1.0604, Trg VAT: 1.1036, Src Train Acc: 62.67, Trg Train Acc: 54.64, Src Test Acc: 64.59, Trg Test Acc: 60.32
# Epoch: 012, TotalL: 2.0150, CrossE: 0.9768, CondE: 1.0567, disc: 0.6999, domain: 0.7411, Src VAT: 1.0097, Trg VAT: 1.0567, Src Train Acc: 64.15, Trg Train Acc: 56.29, Src Test Acc: 65.37, Trg Test Acc: 60.32
# Epoch: 013, TotalL: 1.9238, CrossE: 0.9327, CondE: 1.0160, disc: 0.7013, domain: 0.7430, Src VAT: 0.9634, Trg VAT: 1.0160, Src Train Acc: 65.45, Trg Train Acc: 57.60, Src Test Acc: 68.48, Trg Test Acc: 61.07
# Epoch: 014, TotalL: 1.8391, CrossE: 0.8895, CondE: 0.9831, disc: 0.7024, domain: 0.7473, Src VAT: 0.9224, Trg VAT: 0.9831, Src Train Acc: 67.62, Trg Train Acc: 59.33, Src Test Acc: 69.65, Trg Test Acc: 62.91
# Epoch: 015, TotalL: 1.7547, CrossE: 0.8472, CondE: 0.9481, disc: 0.6989, domain: 0.7522, Src VAT: 0.8810, Trg VAT: 0.9481, Src Train Acc: 69.01, Trg Train Acc: 61.02, Src Test Acc: 70.82, Trg Test Acc: 63.91
# Epoch: 016, TotalL: 1.6704, CrossE: 0.8028, CondE: 0.9162, disc: 0.6972, domain: 0.7562, Src VAT: 0.8418, Trg VAT: 0.9162, Src Train Acc: 71.09, Trg Train Acc: 62.28, Src Test Acc: 72.37, Trg Test Acc: 65.08
# Epoch: 017, TotalL: 1.5892, CrossE: 0.7630, CondE: 0.8807, disc: 0.6941, domain: 0.7604, Src VAT: 0.8009, Trg VAT: 0.8807, Src Train Acc: 72.57, Trg Train Acc: 63.89, Src Test Acc: 73.93, Trg Test Acc: 66.67
# Epoch: 018, TotalL: 1.5064, CrossE: 0.7199, CondE: 0.8467, disc: 0.6904, domain: 0.7684, Src VAT: 0.7619, Trg VAT: 0.8467, Src Train Acc: 73.48, Trg Train Acc: 65.45, Src Test Acc: 78.60, Trg Test Acc: 68.76
# Epoch: 019, TotalL: 1.4234, CrossE: 0.6767, CondE: 0.8124, disc: 0.6908, domain: 0.7805, Src VAT: 0.7226, Trg VAT: 0.8124, Src Train Acc: 75.04, Trg Train Acc: 66.62, Src Test Acc: 81.71, Trg Test Acc: 71.01
# Epoch: 020, TotalL: 1.3414, CrossE: 0.6349, CondE: 0.7763, disc: 0.6890, domain: 0.7895, Src VAT: 0.6830, Trg VAT: 0.7763, Src Train Acc: 76.43, Trg Train Acc: 68.10, Src Test Acc: 83.66, Trg Test Acc: 72.35
# Epoch: 021, TotalL: 1.2587, CrossE: 0.5933, CondE: 0.7380, disc: 0.6887, domain: 0.7992, Src VAT: 0.6427, Trg VAT: 0.7380, Src Train Acc: 78.39, Trg Train Acc: 69.66, Src Test Acc: 84.44, Trg Test Acc: 74.02
# Epoch: 022, TotalL: 1.1899, CrossE: 0.5594, CondE: 0.7038, disc: 0.6896, domain: 0.8063, Src VAT: 0.6084, Trg VAT: 0.7038, Src Train Acc: 79.21, Trg Train Acc: 70.66, Src Test Acc: 84.82, Trg Test Acc: 75.61
# Epoch: 023, TotalL: 1.1170, CrossE: 0.5241, CondE: 0.6664, disc: 0.6897, domain: 0.8113, Src VAT: 0.5715, Trg VAT: 0.6664, Src Train Acc: 80.51, Trg Train Acc: 71.79, Src Test Acc: 84.82, Trg Test Acc: 76.78
# Epoch: 024, TotalL: 1.0464, CrossE: 0.4902, CondE: 0.6291, disc: 0.6886, domain: 0.8165, Src VAT: 0.5354, Trg VAT: 0.6291, Src Train Acc: 82.07, Trg Train Acc: 73.09, Src Test Acc: 84.44, Trg Test Acc: 77.53
# Epoch: 025, TotalL: 0.9786, CrossE: 0.4566, CondE: 0.5941, disc: 0.6883, domain: 0.8163, Src VAT: 0.5019, Trg VAT: 0.5941, Src Train Acc: 83.51, Trg Train Acc: 74.18, Src Test Acc: 84.44, Trg Test Acc: 77.78
# Epoch: 026, TotalL: 0.9140, CrossE: 0.4246, CondE: 0.5601, disc: 0.6887, domain: 0.8252, Src VAT: 0.4699, Trg VAT: 0.5601, Src Train Acc: 84.51, Trg Train Acc: 75.87, Src Test Acc: 85.99, Trg Test Acc: 78.70
# Epoch: 027, TotalL: 0.8577, CrossE: 0.3984, CondE: 0.5310, disc: 0.6860, domain: 0.8335, Src VAT: 0.4403, Trg VAT: 0.5310, Src Train Acc: 85.85, Trg Train Acc: 76.39, Src Test Acc: 85.60, Trg Test Acc: 79.78
# Epoch: 028, TotalL: 0.8000, CrossE: 0.3691, CondE: 0.5021, disc: 0.6861, domain: 0.8383, Src VAT: 0.4125, Trg VAT: 0.5021, Src Train Acc: 86.81, Trg Train Acc: 77.69, Src Test Acc: 87.94, Trg Test Acc: 80.28
# Epoch: 029, TotalL: 0.7614, CrossE: 0.3532, CondE: 0.4773, disc: 0.6841, domain: 0.8504, Src VAT: 0.3901, Trg VAT: 0.4773, Src Train Acc: 87.59, Trg Train Acc: 78.39, Src Test Acc: 89.11, Trg Test Acc: 79.95
# Epoch: 030, TotalL: 0.7183, CrossE: 0.3327, CondE: 0.4519, disc: 0.6839, domain: 0.8596, Src VAT: 0.3679, Trg VAT: 0.4519, Src Train Acc: 88.37, Trg Train Acc: 78.60, Src Test Acc: 89.49, Trg Test Acc: 79.95
# Epoch: 031, TotalL: 0.6745, CrossE: 0.3101, CondE: 0.4275, disc: 0.6816, domain: 0.8557, Src VAT: 0.3472, Trg VAT: 0.4275, Src Train Acc: 89.19, Trg Train Acc: 79.21, Src Test Acc: 89.49, Trg Test Acc: 80.87
# Epoch: 032, TotalL: 0.6461, CrossE: 0.2993, CondE: 0.4107, disc: 0.6800, domain: 0.8648, Src VAT: 0.3299, Trg VAT: 0.4107, Src Train Acc: 89.41, Trg Train Acc: 79.34, Src Test Acc: 89.88, Trg Test Acc: 80.79
# Epoch: 033, TotalL: 0.6079, CrossE: 0.2793, CondE: 0.3922, disc: 0.6772, domain: 0.8730, Src VAT: 0.3120, Trg VAT: 0.3922, Src Train Acc: 90.15, Trg Train Acc: 80.16, Src Test Acc: 91.05, Trg Test Acc: 81.87
# Epoch: 034, TotalL: 0.5887, CrossE: 0.2706, CondE: 0.3803, disc: 0.6803, domain: 0.8787, Src VAT: 0.3017, Trg VAT: 0.3803, Src Train Acc: 90.45, Trg Train Acc: 80.82, Src Test Acc: 91.83, Trg Test Acc: 81.79
# Epoch: 035, TotalL: 0.5528, CrossE: 0.2519, CondE: 0.3631, disc: 0.6737, domain: 0.8828, Src VAT: 0.2848, Trg VAT: 0.3631, Src Train Acc: 91.58, Trg Train Acc: 81.16, Src Test Acc: 92.22, Trg Test Acc: 81.87
# Epoch: 036, TotalL: 0.5202, CrossE: 0.2367, CondE: 0.3468, disc: 0.6788, domain: 0.8850, Src VAT: 0.2677, Trg VAT: 0.3468, Src Train Acc: 91.67, Trg Train Acc: 81.34, Src Test Acc: 91.83, Trg Test Acc: 82.29
# Epoch: 037, TotalL: 0.4966, CrossE: 0.2252, CondE: 0.3318, disc: 0.6773, domain: 0.8970, Src VAT: 0.2558, Trg VAT: 0.3318, Src Train Acc: 91.93, Trg Train Acc: 81.21, Src Test Acc: 92.61, Trg Test Acc: 81.37
# Epoch: 038, TotalL: 0.5050, CrossE: 0.2329, CondE: 0.3315, disc: 0.6722, domain: 0.8950, Src VAT: 0.2565, Trg VAT: 0.3315, Src Train Acc: 92.62, Trg Train Acc: 82.07, Src Test Acc: 92.61, Trg Test Acc: 82.29
# Epoch: 039, TotalL: 0.4552, CrossE: 0.2019, CondE: 0.3112, disc: 0.6724, domain: 0.9117, Src VAT: 0.2380, Trg VAT: 0.3112, Src Train Acc: 93.32, Trg Train Acc: 81.60, Src Test Acc: 92.22, Trg Test Acc: 82.29
# Epoch: 040, TotalL: 0.4471, CrossE: 0.2015, CondE: 0.3035, disc: 0.6758, domain: 0.9074, Src VAT: 0.2304, Trg VAT: 0.3035, Src Train Acc: 92.84, Trg Train Acc: 82.07, Src Test Acc: 92.61, Trg Test Acc: 80.79
# Epoch: 041, TotalL: 0.4480, CrossE: 0.2065, CondE: 0.2976, disc: 0.6744, domain: 0.9104, Src VAT: 0.2264, Trg VAT: 0.2976, Src Train Acc: 93.53, Trg Train Acc: 82.03, Src Test Acc: 93.39, Trg Test Acc: 84.63
# Epoch: 042, TotalL: 0.4032, CrossE: 0.1759, CondE: 0.2825, disc: 0.6757, domain: 0.9095, Src VAT: 0.2126, Trg VAT: 0.2825, Src Train Acc: 94.05, Trg Train Acc: 82.64, Src Test Acc: 91.05, Trg Test Acc: 81.54
# Epoch: 043, TotalL: 0.3685, CrossE: 0.1587, CondE: 0.2680, disc: 0.6781, domain: 0.9266, Src VAT: 0.1951, Trg VAT: 0.2680, Src Train Acc: 94.36, Trg Train Acc: 83.03, Src Test Acc: 92.61, Trg Test Acc: 81.95
# Epoch: 044, TotalL: 0.3720, CrossE: 0.1659, CondE: 0.2616, disc: 0.6851, domain: 0.9304, Src VAT: 0.1915, Trg VAT: 0.2616, Src Train Acc: 94.05, Trg Train Acc: 82.86, Src Test Acc: 92.61, Trg Test Acc: 80.37
# Epoch: 045, TotalL: 0.3434, CrossE: 0.1502, CondE: 0.2500, disc: 0.6772, domain: 0.9355, Src VAT: 0.1788, Trg VAT: 0.2500, Src Train Acc: 94.75, Trg Train Acc: 83.29, Src Test Acc: 94.94, Trg Test Acc: 84.96
# Epoch: 046, TotalL: 0.3441, CrossE: 0.1522, CondE: 0.2501, disc: 0.6725, domain: 0.9421, Src VAT: 0.1775, Trg VAT: 0.2501, Src Train Acc: 95.01, Trg Train Acc: 83.46, Src Test Acc: 93.39, Trg Test Acc: 80.87
# Epoch: 047, TotalL: 0.3197, CrossE: 0.1397, CondE: 0.2374, disc: 0.6747, domain: 0.9452, Src VAT: 0.1658, Trg VAT: 0.2374, Src Train Acc: 95.53, Trg Train Acc: 84.85, Src Test Acc: 92.22, Trg Test Acc: 84.21
# Epoch: 048, TotalL: 0.3221, CrossE: 0.1405, CondE: 0.2326, disc: 0.6804, domain: 0.9492, Src VAT: 0.1675, Trg VAT: 0.2326, Src Train Acc: 95.53, Trg Train Acc: 84.24, Src Test Acc: 93.00, Trg Test Acc: 82.62
# Epoch: 049, TotalL: 0.3211, CrossE: 0.1447, CondE: 0.2305, disc: 0.6812, domain: 0.9661, Src VAT: 0.1621, Trg VAT: 0.2305, Src Train Acc: 95.10, Trg Train Acc: 83.42, Src Test Acc: 87.94, Trg Test Acc: 76.86
# Epoch: 050, TotalL: 0.3079, CrossE: 0.1334, CondE: 0.2324, disc: 0.6643, domain: 0.9561, Src VAT: 0.1603, Trg VAT: 0.2324, Src Train Acc: 95.36, Trg Train Acc: 84.38, Src Test Acc: 90.66, Trg Test Acc: 76.36
# Epoch: 051, TotalL: 0.2865, CrossE: 0.1291, CondE: 0.2252, disc: 0.6691, domain: 0.9622, Src VAT: 0.1433, Trg VAT: 0.2252, Src Train Acc: 95.96, Trg Train Acc: 84.90, Src Test Acc: 90.66, Trg Test Acc: 78.86
# Epoch: 052, TotalL: 0.2955, CrossE: 0.1312, CondE: 0.2251, disc: 0.6729, domain: 0.9557, Src VAT: 0.1503, Trg VAT: 0.2251, Src Train Acc: 95.40, Trg Train Acc: 84.98, Src Test Acc: 94.55, Trg Test Acc: 83.71
# Epoch: 053, TotalL: 0.2495, CrossE: 0.1055, CondE: 0.2114, disc: 0.6689, domain: 0.9554, Src VAT: 0.1303, Trg VAT: 0.2114, Src Train Acc: 97.27, Trg Train Acc: 85.16, Src Test Acc: 93.39, Trg Test Acc: 79.37
# Epoch: 054, TotalL: 0.2465, CrossE: 0.1044, CondE: 0.1992, disc: 0.6718, domain: 0.9642, Src VAT: 0.1285, Trg VAT: 0.1992, Src Train Acc: 96.53, Trg Train Acc: 85.03, Src Test Acc: 94.55, Trg Test Acc: 83.63
# Epoch: 055, TotalL: 0.2999, CrossE: 0.1410, CondE: 0.2161, disc: 0.6887, domain: 0.9515, Src VAT: 0.1451, Trg VAT: 0.2161, Src Train Acc: 95.23, Trg Train Acc: 84.68, Src Test Acc: 94.94, Trg Test Acc: 85.30
# Epoch: 056, TotalL: 0.2145, CrossE: 0.0832, CondE: 0.1905, disc: 0.6580, domain: 0.9787, Src VAT: 0.1176, Trg VAT: 0.1905, Src Train Acc: 97.27, Trg Train Acc: 86.59, Src Test Acc: 94.16, Trg Test Acc: 83.63
# Epoch: 057, TotalL: 0.2986, CrossE: 0.1476, CondE: 0.2152, disc: 0.6812, domain: 0.9478, Src VAT: 0.1372, Trg VAT: 0.2152, Src Train Acc: 96.01, Trg Train Acc: 85.42, Src Test Acc: 91.05, Trg Test Acc: 77.94
# Epoch: 058, TotalL: 0.2179, CrossE: 0.0852, CondE: 0.1961, disc: 0.6673, domain: 0.9538, Src VAT: 0.1192, Trg VAT: 0.1961, Src Train Acc: 97.14, Trg Train Acc: 87.28, Src Test Acc: 96.89, Trg Test Acc: 90.06
# Epoch: 059, TotalL: 0.3285, CrossE: 0.1725, CondE: 0.2162, disc: 0.6791, domain: 0.9487, Src VAT: 0.1422, Trg VAT: 0.2162, Src Train Acc: 94.92, Trg Train Acc: 85.68, Src Test Acc: 94.94, Trg Test Acc: 87.89
# Epoch: 060, TotalL: 0.2016, CrossE: 0.0743, CondE: 0.1918, disc: 0.6480, domain: 0.9571, Src VAT: 0.1138, Trg VAT: 0.1918, Src Train Acc: 97.96, Trg Train Acc: 87.67, Src Test Acc: 96.50, Trg Test Acc: 90.64
# Epoch: 061, TotalL: 0.1931, CrossE: 0.0741, CondE: 0.1733, disc: 0.6580, domain: 0.9925, Src VAT: 0.1056, Trg VAT: 0.1733, Src Train Acc: 97.66, Trg Train Acc: 87.54, Src Test Acc: 95.72, Trg Test Acc: 84.63
# Epoch: 062, TotalL: 0.2039, CrossE: 0.0891, CondE: 0.1728, disc: 0.6553, domain: 0.9836, Src VAT: 0.1015, Trg VAT: 0.1728, Src Train Acc: 97.05, Trg Train Acc: 87.28, Src Test Acc: 96.89, Trg Test Acc: 89.06
# Epoch: 063, TotalL: 0.2700, CrossE: 0.1357, CondE: 0.1949, disc: 0.6629, domain: 0.9654, Src VAT: 0.1207, Trg VAT: 0.1949, Src Train Acc: 96.27, Trg Train Acc: 86.15, Src Test Acc: 97.67, Trg Test Acc: 89.81
# Epoch: 064, TotalL: 0.1665, CrossE: 0.0596, CondE: 0.1709, disc: 0.6511, domain: 0.9738, Src VAT: 0.0937, Trg VAT: 0.1709, Src Train Acc: 98.44, Trg Train Acc: 88.28, Src Test Acc: 94.16, Trg Test Acc: 80.45
# Epoch: 065, TotalL: 0.1694, CrossE: 0.0635, CondE: 0.1663, disc: 0.6560, domain: 1.0070, Src VAT: 0.0925, Trg VAT: 0.1663, Src Train Acc: 97.79, Trg Train Acc: 87.63, Src Test Acc: 96.89, Trg Test Acc: 88.47
# Epoch: 066, TotalL: 0.1611, CrossE: 0.0624, CondE: 0.1498, disc: 0.6615, domain: 1.0287, Src VAT: 0.0854, Trg VAT: 0.1498, Src Train Acc: 97.87, Trg Train Acc: 87.54, Src Test Acc: 95.33, Trg Test Acc: 86.38
# Epoch: 067, TotalL: 0.2367, CrossE: 0.1110, CondE: 0.1831, disc: 0.6762, domain: 1.0056, Src VAT: 0.1119, Trg VAT: 0.1831, Src Train Acc: 96.14, Trg Train Acc: 86.11, Src Test Acc: 97.67, Trg Test Acc: 91.23
# Epoch: 068, TotalL: 0.1436, CrossE: 0.0521, CondE: 0.1465, disc: 0.6529, domain: 1.0079, Src VAT: 0.0785, Trg VAT: 0.1465, Src Train Acc: 98.39, Trg Train Acc: 88.93, Src Test Acc: 96.11, Trg Test Acc: 90.23
# Epoch: 069, TotalL: 0.1833, CrossE: 0.0748, CondE: 0.1620, disc: 0.6657, domain: 1.0181, Src VAT: 0.0951, Trg VAT: 0.1620, Src Train Acc: 97.22, Trg Train Acc: 87.20, Src Test Acc: 96.89, Trg Test Acc: 89.72
# Epoch: 070, TotalL: 0.1614, CrossE: 0.0668, CondE: 0.1490, disc: 0.6536, domain: 1.0360, Src VAT: 0.0813, Trg VAT: 0.1490, Src Train Acc: 97.87, Trg Train Acc: 87.85, Src Test Acc: 89.11, Trg Test Acc: 78.20
# Epoch: 071, TotalL: 0.1777, CrossE: 0.0751, CondE: 0.1555, disc: 0.6617, domain: 1.0056, Src VAT: 0.0895, Trg VAT: 0.1555, Src Train Acc: 97.22, Trg Train Acc: 88.24, Src Test Acc: 96.89, Trg Test Acc: 91.73
# Epoch: 072, TotalL: 0.3021, CrossE: 0.1635, CondE: 0.1978, disc: 0.6845, domain: 0.9697, Src VAT: 0.1250, Trg VAT: 0.1978, Src Train Acc: 95.96, Trg Train Acc: 87.11, Src Test Acc: 98.05, Trg Test Acc: 91.98
# Epoch: 073, TotalL: 0.1281, CrossE: 0.0395, CondE: 0.1488, disc: 0.6491, domain: 0.9885, Src VAT: 0.0758, Trg VAT: 0.1488, Src Train Acc: 99.09, Trg Train Acc: 90.15, Src Test Acc: 97.67, Trg Test Acc: 92.06
# Epoch: 074, TotalL: 0.1223, CrossE: 0.0426, CondE: 0.1365, disc: 0.6497, domain: 1.0225, Src VAT: 0.0667, Trg VAT: 0.1365, Src Train Acc: 98.91, Trg Train Acc: 89.58, Src Test Acc: 93.39, Trg Test Acc: 80.70
# Epoch: 075, TotalL: 0.2135, CrossE: 0.1030, CondE: 0.1622, disc: 0.6607, domain: 0.9852, Src VAT: 0.0974, Trg VAT: 0.1622, Src Train Acc: 96.92, Trg Train Acc: 88.32, Src Test Acc: 98.44, Trg Test Acc: 91.81
# Epoch: 076, TotalL: 0.1114, CrossE: 0.0366, CondE: 0.1378, disc: 0.6344, domain: 1.0079, Src VAT: 0.0619, Trg VAT: 0.1378, Src Train Acc: 99.00, Trg Train Acc: 90.15, Src Test Acc: 98.05, Trg Test Acc: 92.15
# Epoch: 077, TotalL: 0.1575, CrossE: 0.0754, CondE: 0.1378, disc: 0.6408, domain: 1.0262, Src VAT: 0.0691, Trg VAT: 0.1378, Src Train Acc: 98.44, Trg Train Acc: 89.41, Src Test Acc: 97.28, Trg Test Acc: 90.48
# Epoch: 078, TotalL: 0.1264, CrossE: 0.0414, CondE: 0.1506, disc: 0.6439, domain: 1.0060, Src VAT: 0.0720, Trg VAT: 0.1506, Src Train Acc: 98.52, Trg Train Acc: 89.71, Src Test Acc: 97.28, Trg Test Acc: 91.73
# Epoch: 079, TotalL: 0.0967, CrossE: 0.0292, CondE: 0.1206, disc: 0.6388, domain: 1.0482, Src VAT: 0.0546, Trg VAT: 0.1206, Src Train Acc: 99.22, Trg Train Acc: 89.45, Src Test Acc: 96.89, Trg Test Acc: 91.14
# Epoch: 080, TotalL: 0.4696, CrossE: 0.2704, CondE: 0.2779, disc: 0.7112, domain: 0.9421, Src VAT: 0.1842, Trg VAT: 0.2779, Src Train Acc: 94.18, Trg Train Acc: 85.24, Src Test Acc: 96.89, Trg Test Acc: 90.48
# Epoch: 081, TotalL: 0.1450, CrossE: 0.0442, CondE: 0.1663, disc: 0.6467, domain: 0.9668, Src VAT: 0.0878, Trg VAT: 0.1663, Src Train Acc: 98.91, Trg Train Acc: 90.36, Src Test Acc: 97.67, Trg Test Acc: 92.15
# Epoch: 082, TotalL: 0.0976, CrossE: 0.0275, CondE: 0.1255, disc: 0.6342, domain: 1.0107, Src VAT: 0.0575, Trg VAT: 0.1255, Src Train Acc: 99.26, Trg Train Acc: 90.71, Src Test Acc: 98.05, Trg Test Acc: 91.90
# Epoch: 083, TotalL: 0.0928, CrossE: 0.0297, CondE: 0.1155, disc: 0.6338, domain: 1.0253, Src VAT: 0.0506, Trg VAT: 0.1155, Src Train Acc: 99.18, Trg Train Acc: 89.80, Src Test Acc: 98.83, Trg Test Acc: 91.81
# Epoch: 084, TotalL: 0.1430, CrossE: 0.0703, CondE: 0.1295, disc: 0.6504, domain: 0.9916, Src VAT: 0.0602, Trg VAT: 0.1295, Src Train Acc: 98.13, Trg Train Acc: 89.28, Src Test Acc: 95.72, Trg Test Acc: 87.30
# Epoch: 085, TotalL: 0.0950, CrossE: 0.0304, CondE: 0.1229, disc: 0.6308, domain: 0.9797, Src VAT: 0.0523, Trg VAT: 0.1229, Src Train Acc: 98.96, Trg Train Acc: 91.10, Src Test Acc: 97.28, Trg Test Acc: 91.56
# Epoch: 086, TotalL: 0.1262, CrossE: 0.0521, CondE: 0.1254, disc: 0.6415, domain: 1.0092, Src VAT: 0.0615, Trg VAT: 0.1254, Src Train Acc: 98.35, Trg Train Acc: 89.67, Src Test Acc: 95.33, Trg Test Acc: 87.13
# Epoch: 087, TotalL: 0.1411, CrossE: 0.0617, CondE: 0.1351, disc: 0.6422, domain: 0.9974, Src VAT: 0.0667, Trg VAT: 0.1351, Src Train Acc: 98.09, Trg Train Acc: 88.67, Src Test Acc: 98.83, Trg Test Acc: 91.90
# Epoch: 088, TotalL: 0.0902, CrossE: 0.0301, CondE: 0.1173, disc: 0.6267, domain: 1.0270, Src VAT: 0.0475, Trg VAT: 0.1173, Src Train Acc: 99.09, Trg Train Acc: 90.32, Src Test Acc: 97.28, Trg Test Acc: 91.40
# Epoch: 089, TotalL: 0.0757, CrossE: 0.0233, CondE: 0.1077, disc: 0.6191, domain: 1.0520, Src VAT: 0.0397, Trg VAT: 0.1077, Src Train Acc: 99.39, Trg Train Acc: 90.41, Src Test Acc: 98.44, Trg Test Acc: 91.06
# Epoch: 090, TotalL: 0.1436, CrossE: 0.0778, CondE: 0.1179, disc: 0.6298, domain: 1.0566, Src VAT: 0.0529, Trg VAT: 0.1179, Src Train Acc: 97.83, Trg Train Acc: 89.54, Src Test Acc: 96.50, Trg Test Acc: 90.23
# Epoch: 091, TotalL: 0.0814, CrossE: 0.0210, CondE: 0.1236, disc: 0.6253, domain: 1.0046, Src VAT: 0.0478, Trg VAT: 0.1236, Src Train Acc: 99.39, Trg Train Acc: 90.62, Src Test Acc: 96.50, Trg Test Acc: 89.39
# Epoch: 092, TotalL: 0.0779, CrossE: 0.0235, CondE: 0.1143, disc: 0.6308, domain: 1.0330, Src VAT: 0.0418, Trg VAT: 0.1143, Src Train Acc: 99.35, Trg Train Acc: 90.49, Src Test Acc: 98.05, Trg Test Acc: 91.65
# Epoch: 093, TotalL: 0.0522, CrossE: 0.0113, CondE: 0.0969, disc: 0.6183, domain: 1.0298, Src VAT: 0.0286, Trg VAT: 0.0969, Src Train Acc: 99.87, Trg Train Acc: 91.41, Src Test Acc: 97.67, Trg Test Acc: 90.23
# Epoch: 094, TotalL: 0.7758, CrossE: 0.4572, CondE: 0.3913, disc: 0.6944, domain: 0.9062, Src VAT: 0.3017, Trg VAT: 0.3913, Src Train Acc: 91.58, Trg Train Acc: 83.72, Src Test Acc: 96.50, Trg Test Acc: 88.22
# Epoch: 095, TotalL: 0.1894, CrossE: 0.0683, CondE: 0.1939, disc: 0.6590, domain: 0.9388, Src VAT: 0.1079, Trg VAT: 0.1939, Src Train Acc: 98.00, Trg Train Acc: 89.63, Src Test Acc: 98.05, Trg Test Acc: 91.65
# Epoch: 096, TotalL: 0.0772, CrossE: 0.0171, CondE: 0.1219, disc: 0.6323, domain: 0.9815, Src VAT: 0.0479, Trg VAT: 0.1219, Src Train Acc: 99.78, Trg Train Acc: 91.97, Src Test Acc: 98.05, Trg Test Acc: 91.23
# Epoch: 097, TotalL: 0.0551, CrossE: 0.0108, CondE: 0.1032, disc: 0.6256, domain: 1.0029, Src VAT: 0.0322, Trg VAT: 0.1032, Src Train Acc: 99.87, Trg Train Acc: 92.06, Src Test Acc: 98.05, Trg Test Acc: 92.23
# Epoch: 098, TotalL: 0.0590, CrossE: 0.0139, CondE: 0.1041, disc: 0.6278, domain: 1.0128, Src VAT: 0.0328, Trg VAT: 0.1041, Src Train Acc: 99.61, Trg Train Acc: 91.41, Src Test Acc: 97.28, Trg Test Acc: 91.06
# Epoch: 099, TotalL: 0.1433, CrossE: 0.0789, CondE: 0.1200, disc: 0.6594, domain: 1.0133, Src VAT: 0.0519, Trg VAT: 0.1200, Src Train Acc: 98.35, Trg Train Acc: 90.49, Src Test Acc: 98.44, Trg Test Acc: 90.39
# Epoch: 100, TotalL: 0.1011, CrossE: 0.0310, CondE: 0.1314, disc: 0.6443, domain: 0.9651, Src VAT: 0.0579, Trg VAT: 0.1314, Src Train Acc: 99.22, Trg Train Acc: 90.89, Src Test Acc: 98.05, Trg Test Acc: 91.81
# Epoch: 101, TotalL: 0.1204, CrossE: 0.0682, CondE: 0.1130, disc: 0.6376, domain: 1.0066, Src VAT: 0.0399, Trg VAT: 0.1130, Src Train Acc: 98.57, Trg Train Acc: 90.06, Src Test Acc: 66.93, Trg Test Acc: 57.89
# Epoch: 102, TotalL: 0.1431, CrossE: 0.0479, CondE: 0.1572, disc: 0.6463, domain: 0.9819, Src VAT: 0.0822, Trg VAT: 0.1572, Src Train Acc: 99.05, Trg Train Acc: 90.41, Src Test Acc: 96.11, Trg Test Acc: 89.97
# Epoch: 103, TotalL: 0.1473, CrossE: 0.0751, CondE: 0.1236, disc: 0.6289, domain: 1.0230, Src VAT: 0.0594, Trg VAT: 0.1236, Src Train Acc: 97.74, Trg Train Acc: 89.50, Src Test Acc: 91.05, Trg Test Acc: 79.78
# Epoch: 104, TotalL: 0.0835, CrossE: 0.0224, CondE: 0.1258, disc: 0.6128, domain: 0.9961, Src VAT: 0.0485, Trg VAT: 0.1258, Src Train Acc: 99.48, Trg Train Acc: 91.88, Src Test Acc: 98.05, Trg Test Acc: 92.40
# Epoch: 105, TotalL: 0.0455, CrossE: 0.0083, CondE: 0.0945, disc: 0.6008, domain: 1.0350, Src VAT: 0.0250, Trg VAT: 0.0945, Src Train Acc: 99.91, Trg Train Acc: 92.23, Src Test Acc: 98.44, Trg Test Acc: 92.48
# Epoch: 106, TotalL: 0.0371, CrossE: 0.0062, CondE: 0.0850, disc: 0.5969, domain: 1.0489, Src VAT: 0.0187, Trg VAT: 0.0850, Src Train Acc: 99.91, Trg Train Acc: 92.27, Src Test Acc: 98.44, Trg Test Acc: 92.73
# Epoch: 107, TotalL: 0.0334, CrossE: 0.0053, CondE: 0.0823, disc: 0.5977, domain: 1.0557, Src VAT: 0.0160, Trg VAT: 0.0823, Src Train Acc: 99.91, Trg Train Acc: 92.45, Src Test Acc: 98.44, Trg Test Acc: 91.98
# Epoch: 108, TotalL: 0.4104, CrossE: 0.2459, CondE: 0.2324, disc: 0.6533, domain: 0.9663, Src VAT: 0.1501, Trg VAT: 0.2324, Src Train Acc: 95.75, Trg Train Acc: 86.94, Src Test Acc: 97.67, Trg Test Acc: 91.48
# Epoch: 109, TotalL: 0.1143, CrossE: 0.0304, CondE: 0.1520, disc: 0.6182, domain: 0.9521, Src VAT: 0.0713, Trg VAT: 0.1520, Src Train Acc: 99.31, Trg Train Acc: 91.15, Src Test Acc: 97.67, Trg Test Acc: 91.48
# Epoch: 110, TotalL: 0.0523, CrossE: 0.0096, CondE: 0.1067, disc: 0.6067, domain: 1.0132, Src VAT: 0.0304, Trg VAT: 0.1067, Src Train Acc: 99.91, Trg Train Acc: 91.93, Src Test Acc: 98.05, Trg Test Acc: 91.90
# Epoch: 111, TotalL: 0.0389, CrossE: 0.0060, CondE: 0.0934, disc: 0.6022, domain: 1.0281, Src VAT: 0.0208, Trg VAT: 0.0934, Src Train Acc: 99.96, Trg Train Acc: 91.93, Src Test Acc: 98.05, Trg Test Acc: 91.48
# Epoch: 112, TotalL: 0.0332, CrossE: 0.0047, CondE: 0.0845, disc: 0.6026, domain: 1.0373, Src VAT: 0.0165, Trg VAT: 0.0845, Src Train Acc: 99.91, Trg Train Acc: 92.32, Src Test Acc: 97.28, Trg Test Acc: 91.81
# Epoch: 113, TotalL: 0.0300, CrossE: 0.0038, CondE: 0.0809, disc: 0.6004, domain: 1.0502, Src VAT: 0.0141, Trg VAT: 0.0809, Src Train Acc: 99.96, Trg Train Acc: 92.58, Src Test Acc: 97.67, Trg Test Acc: 91.23
# Epoch: 114, TotalL: 0.0312, CrossE: 0.0043, CondE: 0.0809, disc: 0.6048, domain: 1.0531, Src VAT: 0.0148, Trg VAT: 0.0809, Src Train Acc: 99.91, Trg Train Acc: 92.66, Src Test Acc: 98.05, Trg Test Acc: 91.73
# Epoch: 115, TotalL: 0.0266, CrossE: 0.0030, CondE: 0.0752, disc: 0.6027, domain: 1.0567, Src VAT: 0.0115, Trg VAT: 0.0752, Src Train Acc: 99.96, Trg Train Acc: 92.97, Src Test Acc: 96.11, Trg Test Acc: 89.97
# Epoch: 116, TotalL: 0.7519, CrossE: 0.4092, CondE: 0.4015, disc: 0.7062, domain: 0.9461, Src VAT: 0.3252, Trg VAT: 0.4015, Src Train Acc: 90.19, Trg Train Acc: 82.94, Src Test Acc: 96.50, Trg Test Acc: 90.98
# Epoch: 117, TotalL: 0.0870, CrossE: 0.0190, CondE: 0.1407, disc: 0.6591, domain: 0.9852, Src VAT: 0.0553, Trg VAT: 0.1407, Src Train Acc: 99.70, Trg Train Acc: 91.71, Src Test Acc: 98.05, Trg Test Acc: 91.40
# Epoch: 118, TotalL: 0.1970, CrossE: 0.1107, CondE: 0.1434, disc: 0.6863, domain: 1.0108, Src VAT: 0.0734, Trg VAT: 0.1434, Src Train Acc: 97.14, Trg Train Acc: 88.76, Src Test Acc: 90.27, Trg Test Acc: 82.71
# Epoch: 119, TotalL: 0.2062, CrossE: 0.0847, CondE: 0.1755, disc: 0.6540, domain: 0.9687, Src VAT: 0.1084, Trg VAT: 0.1755, Src Train Acc: 97.31, Trg Train Acc: 89.06, Src Test Acc: 98.05, Trg Test Acc: 87.97
# Epoch: 120, TotalL: 0.0761, CrossE: 0.0214, CondE: 0.1219, disc: 0.6222, domain: 0.9976, Src VAT: 0.0424, Trg VAT: 0.1219, Src Train Acc: 99.44, Trg Train Acc: 91.97, Src Test Acc: 98.44, Trg Test Acc: 92.15
# Epoch: 121, TotalL: 0.0425, CrossE: 0.0074, CondE: 0.0949, disc: 0.6116, domain: 1.0290, Src VAT: 0.0229, Trg VAT: 0.0949, Src Train Acc: 99.91, Trg Train Acc: 92.75, Src Test Acc: 98.05, Trg Test Acc: 92.15
# Epoch: 122, TotalL: 0.1481, CrossE: 0.0721, CondE: 0.1427, disc: 0.6399, domain: 1.0043, Src VAT: 0.0632, Trg VAT: 0.1427, Src Train Acc: 97.96, Trg Train Acc: 89.93, Src Test Acc: 98.44, Trg Test Acc: 91.56
# Epoch: 123, TotalL: 0.0612, CrossE: 0.0133, CondE: 0.1109, disc: 0.6194, domain: 1.0158, Src VAT: 0.0355, Trg VAT: 0.1109, Src Train Acc: 99.74, Trg Train Acc: 91.71, Src Test Acc: 98.44, Trg Test Acc: 92.56
# Epoch: 124, TotalL: 0.0351, CrossE: 0.0055, CondE: 0.0859, disc: 0.6023, domain: 1.0501, Src VAT: 0.0174, Trg VAT: 0.0859, Src Train Acc: 99.91, Trg Train Acc: 92.75, Src Test Acc: 98.05, Trg Test Acc: 91.90
# Epoch: 125, TotalL: 0.0925, CrossE: 0.0442, CondE: 0.1099, disc: 0.6237, domain: 1.0363, Src VAT: 0.0358, Trg VAT: 0.1099, Src Train Acc: 98.96, Trg Train Acc: 90.93, Src Test Acc: 98.44, Trg Test Acc: 91.90
# Epoch: 126, TotalL: 0.0910, CrossE: 0.0318, CondE: 0.1222, disc: 0.6270, domain: 1.0230, Src VAT: 0.0465, Trg VAT: 0.1222, Src Train Acc: 98.96, Trg Train Acc: 90.89, Src Test Acc: 98.05, Trg Test Acc: 92.82
# Epoch: 127, TotalL: 0.0415, CrossE: 0.0076, CondE: 0.0869, disc: 0.6083, domain: 1.0591, Src VAT: 0.0216, Trg VAT: 0.0869, Src Train Acc: 99.87, Trg Train Acc: 92.58, Src Test Acc: 98.44, Trg Test Acc: 92.06
# Epoch: 128, TotalL: 0.0287, CrossE: 0.0039, CondE: 0.0780, disc: 0.6006, domain: 1.0622, Src VAT: 0.0126, Trg VAT: 0.0780, Src Train Acc: 99.96, Trg Train Acc: 92.84, Src Test Acc: 96.89, Trg Test Acc: 90.98
# Epoch: 129, TotalL: 0.0264, CrossE: 0.0031, CondE: 0.0742, disc: 0.5985, domain: 1.0595, Src VAT: 0.0112, Trg VAT: 0.0742, Src Train Acc: 99.96, Trg Train Acc: 93.10, Src Test Acc: 96.89, Trg Test Acc: 91.73
# Epoch: 130, TotalL: 0.0245, CrossE: 0.0027, CondE: 0.0730, disc: 0.5980, domain: 1.0591, Src VAT: 0.0098, Trg VAT: 0.0730, Src Train Acc: 99.96, Trg Train Acc: 92.88, Src Test Acc: 98.44, Trg Test Acc: 92.65
# Epoch: 131, TotalL: 0.0240, CrossE: 0.0024, CondE: 0.0740, disc: 0.6034, domain: 1.0528, Src VAT: 0.0096, Trg VAT: 0.0740, Src Train Acc: 100.00, Trg Train Acc: 92.75, Src Test Acc: 97.67, Trg Test Acc: 92.40
# Epoch: 132, TotalL: 0.0235, CrossE: 0.0023, CondE: 0.0719, disc: 0.6024, domain: 1.0514, Src VAT: 0.0093, Trg VAT: 0.0719, Src Train Acc: 99.96, Trg Train Acc: 92.93, Src Test Acc: 98.05, Trg Test Acc: 92.06
# Epoch: 133, TotalL: 0.0239, CrossE: 0.0023, CondE: 0.0730, disc: 0.6094, domain: 1.0566, Src VAT: 0.0096, Trg VAT: 0.0730, Src Train Acc: 100.00, Trg Train Acc: 92.97, Src Test Acc: 97.28, Trg Test Acc: 91.90
# Epoch: 134, TotalL: 2.1974, CrossE: 1.1656, CondE: 1.0439, disc: 0.7275, domain: 0.8566, Src VAT: 1.0024, Trg VAT: 1.0439, Src Train Acc: 65.15, Trg Train Acc: 59.94, Src Test Acc: 78.99, Trg Test Acc: 72.93
# Epoch: 135, TotalL: 0.4431, CrossE: 0.1886, CondE: 0.3286, disc: 0.7232, domain: 0.8795, Src VAT: 0.2391, Trg VAT: 0.3286, Src Train Acc: 93.62, Trg Train Acc: 84.64, Src Test Acc: 98.05, Trg Test Acc: 89.97
# Epoch: 136, TotalL: 0.2200, CrossE: 0.0972, CondE: 0.2004, disc: 0.7036, domain: 0.9007, Src VAT: 0.1098, Trg VAT: 0.2004, Src Train Acc: 97.40, Trg Train Acc: 88.76, Src Test Acc: 98.44, Trg Test Acc: 91.23
# Epoch: 137, TotalL: 0.1152, CrossE: 0.0353, CondE: 0.1474, disc: 0.6887, domain: 0.9353, Src VAT: 0.0676, Trg VAT: 0.1474, Src Train Acc: 98.91, Trg Train Acc: 89.63, Src Test Acc: 98.44, Trg Test Acc: 91.81
# Epoch: 138, TotalL: 0.0545, CrossE: 0.0108, CondE: 0.1068, disc: 0.6801, domain: 0.9563, Src VAT: 0.0320, Trg VAT: 0.1068, Src Train Acc: 99.91, Trg Train Acc: 91.45, Src Test Acc: 97.67, Trg Test Acc: 91.14
# Epoch: 139, TotalL: 0.1271, CrossE: 0.0544, CondE: 0.1351, disc: 0.6878, domain: 0.9796, Src VAT: 0.0602, Trg VAT: 0.1351, Src Train Acc: 98.22, Trg Train Acc: 88.19, Src Test Acc: 98.05, Trg Test Acc: 91.56
# Epoch: 140, TotalL: 0.0439, CrossE: 0.0080, CondE: 0.0978, disc: 0.6619, domain: 0.9794, Src VAT: 0.0241, Trg VAT: 0.0978, Src Train Acc: 99.87, Trg Train Acc: 91.93, Src Test Acc: 98.44, Trg Test Acc: 91.14
# Epoch: 141, TotalL: 0.0840, CrossE: 0.0347, CondE: 0.0978, disc: 0.6690, domain: 0.9975, Src VAT: 0.0374, Trg VAT: 0.0978, Src Train Acc: 98.91, Trg Train Acc: 90.15, Src Test Acc: 98.44, Trg Test Acc: 90.06
# Epoch: 142, TotalL: 0.0466, CrossE: 0.0099, CondE: 0.0968, disc: 0.6557, domain: 0.9846, Src VAT: 0.0249, Trg VAT: 0.0968, Src Train Acc: 99.83, Trg Train Acc: 91.80, Src Test Acc: 98.83, Trg Test Acc: 91.73
# Epoch: 143, TotalL: 0.0292, CrossE: 0.0036, CondE: 0.0816, disc: 0.6502, domain: 0.9912, Src VAT: 0.0140, Trg VAT: 0.0816, Src Train Acc: 100.00, Trg Train Acc: 91.71, Src Test Acc: 98.83, Trg Test Acc: 92.65
# Epoch: 144, TotalL: 0.0289, CrossE: 0.0038, CondE: 0.0772, disc: 0.6481, domain: 0.9996, Src VAT: 0.0136, Trg VAT: 0.0772, Src Train Acc: 99.96, Trg Train Acc: 91.88, Src Test Acc: 98.44, Trg Test Acc: 92.48
# Epoch: 145, TotalL: 0.4768, CrossE: 0.2859, CondE: 0.2587, disc: 0.7100, domain: 0.9096, Src VAT: 0.1766, Trg VAT: 0.2587, Src Train Acc: 93.62, Trg Train Acc: 86.15, Src Test Acc: 98.05, Trg Test Acc: 90.56
# Epoch: 146, TotalL: 0.0893, CrossE: 0.0224, CondE: 0.1444, disc: 0.6672, domain: 0.9237, Src VAT: 0.0547, Trg VAT: 0.1444, Src Train Acc: 99.57, Trg Train Acc: 91.58, Src Test Acc: 98.44, Trg Test Acc: 91.98
# Epoch: 147, TotalL: 0.0470, CrossE: 0.0082, CondE: 0.1034, disc: 0.6556, domain: 0.9624, Src VAT: 0.0272, Trg VAT: 0.1034, Src Train Acc: 99.96, Trg Train Acc: 91.93, Src Test Acc: 99.22, Trg Test Acc: 91.98
# Epoch: 148, TotalL: 0.0350, CrossE: 0.0047, CondE: 0.0920, disc: 0.6520, domain: 0.9760, Src VAT: 0.0187, Trg VAT: 0.0920, Src Train Acc: 99.96, Trg Train Acc: 92.19, Src Test Acc: 98.44, Trg Test Acc: 92.15
# Epoch: 149, TotalL: 0.0289, CrossE: 0.0033, CondE: 0.0842, disc: 0.6502, domain: 0.9819, Src VAT: 0.0141, Trg VAT: 0.0842, Src Train Acc: 100.00, Trg Train Acc: 92.19, Src Test Acc: 98.83, Trg Test Acc: 92.40
# Epoch: 150, TotalL: 0.0255, CrossE: 0.0026, CondE: 0.0791, disc: 0.6466, domain: 0.9852, Src VAT: 0.0115, Trg VAT: 0.0791, Src Train Acc: 100.00, Trg Train Acc: 92.10, Src Test Acc: 98.83, Trg Test Acc: 92.40
# Epoch: 151, TotalL: 0.0228, CrossE: 0.0020, CondE: 0.0748, disc: 0.6452, domain: 0.9849, Src VAT: 0.0095, Trg VAT: 0.0748, Src Train Acc: 100.00, Trg Train Acc: 92.40, Src Test Acc: 98.83, Trg Test Acc: 92.31
# Epoch: 152, TotalL: 0.0214, CrossE: 0.0017, CondE: 0.0723, disc: 0.6455, domain: 0.9859, Src VAT: 0.0084, Trg VAT: 0.0723, Src Train Acc: 100.00, Trg Train Acc: 92.49, Src Test Acc: 98.83, Trg Test Acc: 92.48
# Epoch: 153, TotalL: 0.0204, CrossE: 0.0015, CondE: 0.0698, disc: 0.6461, domain: 0.9878, Src VAT: 0.0076, Trg VAT: 0.0698, Src Train Acc: 100.00, Trg Train Acc: 92.49, Src Test Acc: 98.83, Trg Test Acc: 92.40
# Epoch: 154, TotalL: 0.0196, CrossE: 0.0013, CondE: 0.0682, disc: 0.6457, domain: 0.9898, Src VAT: 0.0070, Trg VAT: 0.0682, Src Train Acc: 100.00, Trg Train Acc: 92.66, Src Test Acc: 98.83, Trg Test Acc: 92.56
# Epoch: 155, TotalL: 0.0191, CrossE: 0.0013, CondE: 0.0663, disc: 0.6478, domain: 0.9873, Src VAT: 0.0066, Trg VAT: 0.0663, Src Train Acc: 100.00, Trg Train Acc: 92.84, Src Test Acc: 98.44, Trg Test Acc: 92.48
# Epoch: 156, TotalL: 0.0186, CrossE: 0.0012, CondE: 0.0651, disc: 0.6495, domain: 0.9777, Src VAT: 0.0063, Trg VAT: 0.0651, Src Train Acc: 100.00, Trg Train Acc: 92.80, Src Test Acc: 98.44, Trg Test Acc: 92.40
# Epoch: 157, TotalL: 0.0183, CrossE: 0.0011, CondE: 0.0639, disc: 0.6530, domain: 0.9761, Src VAT: 0.0061, Trg VAT: 0.0639, Src Train Acc: 100.00, Trg Train Acc: 92.75, Src Test Acc: 98.44, Trg Test Acc: 92.65
# Epoch: 158, TotalL: 0.0185, CrossE: 0.0012, CondE: 0.0642, disc: 0.6539, domain: 0.9736, Src VAT: 0.0063, Trg VAT: 0.0642, Src Train Acc: 100.00, Trg Train Acc: 92.88, Src Test Acc: 98.83, Trg Test Acc: 93.07
# Epoch: 159, TotalL: 1.8537, CrossE: 1.0387, CondE: 0.8599, disc: 0.7321, domain: 0.8166, Src VAT: 0.7897, Trg VAT: 0.8599, Src Train Acc: 74.00, Trg Train Acc: 67.36, Src Test Acc: 86.77, Trg Test Acc: 83.12
# Epoch: 160, TotalL: 0.4290, CrossE: 0.1660, CondE: 0.3410, disc: 0.7327, domain: 0.8679, Src VAT: 0.2475, Trg VAT: 0.3410, Src Train Acc: 94.75, Trg Train Acc: 86.68, Src Test Acc: 96.50, Trg Test Acc: 91.23
# Epoch: 161, TotalL: 0.1405, CrossE: 0.0438, CondE: 0.1667, disc: 0.7200, domain: 0.9200, Src VAT: 0.0842, Trg VAT: 0.1667, Src Train Acc: 98.87, Trg Train Acc: 90.10, Src Test Acc: 97.67, Trg Test Acc: 90.64
# Epoch: 162, TotalL: 0.0809, CrossE: 0.0215, CondE: 0.1212, disc: 0.6976, domain: 0.9339, Src VAT: 0.0477, Trg VAT: 0.1212, Src Train Acc: 99.57, Trg Train Acc: 92.27, Src Test Acc: 98.05, Trg Test Acc: 91.81
# Epoch: 163, TotalL: 0.0676, CrossE: 0.0184, CondE: 0.1123, disc: 0.6951, domain: 0.9593, Src VAT: 0.0374, Trg VAT: 0.1123, Src Train Acc: 99.26, Trg Train Acc: 91.15, Src Test Acc: 98.05, Trg Test Acc: 91.31
# Epoch: 164, TotalL: 0.2047, CrossE: 0.1180, CondE: 0.1463, disc: 0.7149, domain: 0.9244, Src VAT: 0.0745, Trg VAT: 0.1463, Src Train Acc: 97.18, Trg Train Acc: 88.76, Src Test Acc: 98.83, Trg Test Acc: 93.07
# Epoch: 165, TotalL: 0.0520, CrossE: 0.0090, CondE: 0.1090, disc: 0.6659, domain: 0.9347, Src VAT: 0.0314, Trg VAT: 0.1090, Src Train Acc: 99.96, Trg Train Acc: 92.49, Src Test Acc: 98.83, Trg Test Acc: 92.82
# Epoch: 166, TotalL: 0.0353, CrossE: 0.0047, CondE: 0.0920, disc: 0.6572, domain: 0.9615, Src VAT: 0.0191, Trg VAT: 0.0920, Src Train Acc: 100.00, Trg Train Acc: 92.62, Src Test Acc: 98.44, Trg Test Acc: 92.65
# Epoch: 167, TotalL: 0.0293, CrossE: 0.0034, CondE: 0.0860, disc: 0.6505, domain: 0.9743, Src VAT: 0.0144, Trg VAT: 0.0860, Src Train Acc: 100.00, Trg Train Acc: 92.71, Src Test Acc: 98.44, Trg Test Acc: 92.90
# Epoch: 168, TotalL: 0.0256, CrossE: 0.0025, CondE: 0.0801, disc: 0.6499, domain: 0.9795, Src VAT: 0.0116, Trg VAT: 0.0801, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 98.83, Trg Test Acc: 93.07
# Epoch: 169, TotalL: 0.0232, CrossE: 0.0020, CondE: 0.0755, disc: 0.6505, domain: 0.9802, Src VAT: 0.0099, Trg VAT: 0.0755, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 98.83, Trg Test Acc: 92.65
# Epoch: 170, TotalL: 0.0217, CrossE: 0.0017, CondE: 0.0724, disc: 0.6507, domain: 0.9819, Src VAT: 0.0087, Trg VAT: 0.0724, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 98.83, Trg Test Acc: 92.73
# Epoch: 171, TotalL: 0.0209, CrossE: 0.0016, CondE: 0.0704, disc: 0.6533, domain: 0.9814, Src VAT: 0.0081, Trg VAT: 0.0704, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 98.83, Trg Test Acc: 92.90
# Epoch: 172, TotalL: 0.0198, CrossE: 0.0014, CondE: 0.0700, disc: 0.6547, domain: 0.9810, Src VAT: 0.0072, Trg VAT: 0.0700, Src Train Acc: 100.00, Trg Train Acc: 92.97, Src Test Acc: 98.83, Trg Test Acc: 93.23
# Epoch: 173, TotalL: 0.0197, CrossE: 0.0014, CondE: 0.0678, disc: 0.6606, domain: 0.9738, Src VAT: 0.0072, Trg VAT: 0.0678, Src Train Acc: 100.00, Trg Train Acc: 93.14, Src Test Acc: 98.83, Trg Test Acc: 93.23
# Epoch: 174, TotalL: 0.0189, CrossE: 0.0013, CondE: 0.0680, disc: 0.6632, domain: 0.9710, Src VAT: 0.0066, Trg VAT: 0.0680, Src Train Acc: 100.00, Trg Train Acc: 92.93, Src Test Acc: 99.22, Trg Test Acc: 93.07
# Epoch: 175, TotalL: 0.0190, CrossE: 0.0013, CondE: 0.0653, disc: 0.6714, domain: 0.9605, Src VAT: 0.0067, Trg VAT: 0.0653, Src Train Acc: 100.00, Trg Train Acc: 93.01, Src Test Acc: 99.22, Trg Test Acc: 92.98
# Epoch: 176, TotalL: 0.8576, CrossE: 0.4864, CondE: 0.4393, disc: 0.7019, domain: 0.8577, Src VAT: 0.3539, Trg VAT: 0.4393, Src Train Acc: 91.58, Trg Train Acc: 83.85, Src Test Acc: 92.22, Trg Test Acc: 85.38
# Epoch: 177, TotalL: 0.1103, CrossE: 0.0324, CondE: 0.1466, disc: 0.6630, domain: 0.9020, Src VAT: 0.0659, Trg VAT: 0.1466, Src Train Acc: 99.26, Trg Train Acc: 91.67, Src Test Acc: 97.28, Trg Test Acc: 92.48
# Epoch: 178, TotalL: 0.0608, CrossE: 0.0164, CondE: 0.1071, disc: 0.6575, domain: 0.9081, Src VAT: 0.0331, Trg VAT: 0.1071, Src Train Acc: 99.57, Trg Train Acc: 92.66, Src Test Acc: 98.83, Trg Test Acc: 92.56
# Epoch: 179, TotalL: 0.0338, CrossE: 0.0046, CondE: 0.0868, disc: 0.6479, domain: 0.9341, Src VAT: 0.0181, Trg VAT: 0.0868, Src Train Acc: 100.00, Trg Train Acc: 92.97, Src Test Acc: 98.83, Trg Test Acc: 92.82
# Epoch: 180, TotalL: 0.0261, CrossE: 0.0028, CondE: 0.0779, disc: 0.6484, domain: 0.9472, Src VAT: 0.0122, Trg VAT: 0.0779, Src Train Acc: 100.00, Trg Train Acc: 93.40, Src Test Acc: 98.83, Trg Test Acc: 93.07
# Epoch: 181, TotalL: 0.0233, CrossE: 0.0022, CondE: 0.0739, disc: 0.6500, domain: 0.9530, Src VAT: 0.0101, Trg VAT: 0.0739, Src Train Acc: 100.00, Trg Train Acc: 93.14, Src Test Acc: 98.83, Trg Test Acc: 93.15
# Epoch: 182, TotalL: 0.0215, CrossE: 0.0018, CondE: 0.0707, disc: 0.6516, domain: 0.9577, Src VAT: 0.0088, Trg VAT: 0.0707, Src Train Acc: 100.00, Trg Train Acc: 93.19, Src Test Acc: 98.83, Trg Test Acc: 93.07
# Epoch: 183, TotalL: 0.0206, CrossE: 0.0016, CondE: 0.0679, disc: 0.6538, domain: 0.9569, Src VAT: 0.0081, Trg VAT: 0.0679, Src Train Acc: 100.00, Trg Train Acc: 93.19, Src Test Acc: 99.22, Trg Test Acc: 93.23
# Epoch: 184, TotalL: 0.0198, CrossE: 0.0015, CondE: 0.0662, disc: 0.6560, domain: 0.9550, Src VAT: 0.0074, Trg VAT: 0.0662, Src Train Acc: 100.00, Trg Train Acc: 93.23, Src Test Acc: 99.22, Trg Test Acc: 93.82
# Epoch: 185, TotalL: 0.0191, CrossE: 0.0013, CondE: 0.0651, disc: 0.6547, domain: 0.9594, Src VAT: 0.0069, Trg VAT: 0.0651, Src Train Acc: 100.00, Trg Train Acc: 93.10, Src Test Acc: 99.22, Trg Test Acc: 93.82
# Epoch: 186, TotalL: 0.0185, CrossE: 0.0012, CondE: 0.0642, disc: 0.6538, domain: 0.9607, Src VAT: 0.0064, Trg VAT: 0.0642, Src Train Acc: 100.00, Trg Train Acc: 93.19, Src Test Acc: 99.22, Trg Test Acc: 93.48
# Epoch: 187, TotalL: 0.0180, CrossE: 0.0011, CondE: 0.0630, disc: 0.6520, domain: 0.9600, Src VAT: 0.0061, Trg VAT: 0.0630, Src Train Acc: 100.00, Trg Train Acc: 93.36, Src Test Acc: 99.22, Trg Test Acc: 93.48
# Epoch: 188, TotalL: 0.0176, CrossE: 0.0010, CondE: 0.0620, disc: 0.6540, domain: 0.9568, Src VAT: 0.0058, Trg VAT: 0.0620, Src Train Acc: 100.00, Trg Train Acc: 93.23, Src Test Acc: 99.22, Trg Test Acc: 93.65
# Epoch: 189, TotalL: 0.0172, CrossE: 0.0009, CondE: 0.0611, disc: 0.6588, domain: 0.9524, Src VAT: 0.0055, Trg VAT: 0.0611, Src Train Acc: 100.00, Trg Train Acc: 93.27, Src Test Acc: 99.22, Trg Test Acc: 93.57
# Epoch: 190, TotalL: 0.0168, CrossE: 0.0009, CondE: 0.0608, disc: 0.6680, domain: 0.9404, Src VAT: 0.0053, Trg VAT: 0.0608, Src Train Acc: 100.00, Trg Train Acc: 93.14, Src Test Acc: 99.22, Trg Test Acc: 93.48
# Epoch: 191, TotalL: 0.0166, CrossE: 0.0009, CondE: 0.0596, disc: 0.6767, domain: 0.9335, Src VAT: 0.0052, Trg VAT: 0.0596, Src Train Acc: 100.00, Trg Train Acc: 93.10, Src Test Acc: 99.22, Trg Test Acc: 93.48
# Epoch: 192, TotalL: 0.0167, CrossE: 0.0009, CondE: 0.0600, disc: 0.6808, domain: 0.9343, Src VAT: 0.0053, Trg VAT: 0.0600, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 99.22, Trg Test Acc: 93.82
# Epoch: 193, TotalL: 0.5884, CrossE: 0.3466, CondE: 0.3061, disc: 0.7172, domain: 0.9004, Src VAT: 0.2267, Trg VAT: 0.3061, Src Train Acc: 92.32, Trg Train Acc: 85.37, Src Test Acc: 96.11, Trg Test Acc: 88.64
# Epoch: 194, TotalL: 0.3378, CrossE: 0.1495, CondE: 0.2487, disc: 0.7139, domain: 0.9735, Src VAT: 0.1735, Trg VAT: 0.2487, Src Train Acc: 95.75, Trg Train Acc: 88.02, Src Test Acc: 96.50, Trg Test Acc: 88.72
# Epoch: 195, TotalL: 0.1312, CrossE: 0.0381, CondE: 0.1547, disc: 0.6791, domain: 0.9487, Src VAT: 0.0805, Trg VAT: 0.1547, Src Train Acc: 98.87, Trg Train Acc: 90.80, Src Test Acc: 98.44, Trg Test Acc: 91.90
# Epoch: 196, TotalL: 0.0628, CrossE: 0.0184, CondE: 0.1063, disc: 0.6622, domain: 0.9591, Src VAT: 0.0328, Trg VAT: 0.1063, Src Train Acc: 99.61, Trg Train Acc: 91.45, Src Test Acc: 96.89, Trg Test Acc: 91.73
# Epoch: 197, TotalL: 0.0963, CrossE: 0.0383, CondE: 0.1200, disc: 0.6690, domain: 0.9252, Src VAT: 0.0464, Trg VAT: 0.1200, Src Train Acc: 99.09, Trg Train Acc: 91.62, Src Test Acc: 98.83, Trg Test Acc: 93.23
# Epoch: 198, TotalL: 0.0339, CrossE: 0.0053, CondE: 0.0857, disc: 0.6532, domain: 0.9705, Src VAT: 0.0172, Trg VAT: 0.0857, Src Train Acc: 99.96, Trg Train Acc: 92.80, Src Test Acc: 98.83, Trg Test Acc: 93.48
# Epoch: 199, TotalL: 0.0247, CrossE: 0.0026, CondE: 0.0752, disc: 0.6508, domain: 0.9704, Src VAT: 0.0109, Trg VAT: 0.0752, Src Train Acc: 100.00, Trg Train Acc: 93.23, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 200, TotalL: 0.0213, CrossE: 0.0017, CondE: 0.0723, disc: 0.6503, domain: 0.9685, Src VAT: 0.0085, Trg VAT: 0.0723, Src Train Acc: 100.00, Trg Train Acc: 93.32, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 201, TotalL: 0.0194, CrossE: 0.0013, CondE: 0.0686, disc: 0.6500, domain: 0.9681, Src VAT: 0.0070, Trg VAT: 0.0686, Src Train Acc: 100.00, Trg Train Acc: 93.49, Src Test Acc: 98.83, Trg Test Acc: 93.57
# Epoch: 202, TotalL: 0.0187, CrossE: 0.0012, CondE: 0.0671, disc: 0.6481, domain: 0.9719, Src VAT: 0.0065, Trg VAT: 0.0671, Src Train Acc: 100.00, Trg Train Acc: 93.62, Src Test Acc: 98.83, Trg Test Acc: 93.57
# Epoch: 203, TotalL: 0.0183, CrossE: 0.0011, CondE: 0.0663, disc: 0.6460, domain: 0.9766, Src VAT: 0.0061, Trg VAT: 0.0663, Src Train Acc: 100.00, Trg Train Acc: 93.62, Src Test Acc: 98.83, Trg Test Acc: 93.48
# Epoch: 204, TotalL: 0.0181, CrossE: 0.0011, CondE: 0.0655, disc: 0.6461, domain: 0.9761, Src VAT: 0.0060, Trg VAT: 0.0655, Src Train Acc: 100.00, Trg Train Acc: 93.53, Src Test Acc: 98.83, Trg Test Acc: 93.32
# Epoch: 205, TotalL: 0.0179, CrossE: 0.0010, CondE: 0.0646, disc: 0.6474, domain: 0.9750, Src VAT: 0.0058, Trg VAT: 0.0646, Src Train Acc: 100.00, Trg Train Acc: 93.71, Src Test Acc: 98.83, Trg Test Acc: 93.15
# Epoch: 206, TotalL: 0.0177, CrossE: 0.0010, CondE: 0.0632, disc: 0.6490, domain: 0.9747, Src VAT: 0.0057, Trg VAT: 0.0632, Src Train Acc: 100.00, Trg Train Acc: 93.97, Src Test Acc: 98.83, Trg Test Acc: 93.32
# Epoch: 207, TotalL: 0.0173, CrossE: 0.0009, CondE: 0.0626, disc: 0.6528, domain: 0.9685, Src VAT: 0.0054, Trg VAT: 0.0626, Src Train Acc: 100.00, Trg Train Acc: 93.75, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 208, TotalL: 0.0169, CrossE: 0.0009, CondE: 0.0610, disc: 0.6554, domain: 0.9614, Src VAT: 0.0052, Trg VAT: 0.0610, Src Train Acc: 100.00, Trg Train Acc: 93.79, Src Test Acc: 98.83, Trg Test Acc: 93.48
# Epoch: 209, TotalL: 0.0166, CrossE: 0.0008, CondE: 0.0596, disc: 0.6572, domain: 0.9546, Src VAT: 0.0051, Trg VAT: 0.0596, Src Train Acc: 100.00, Trg Train Acc: 93.75, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 210, TotalL: 0.0162, CrossE: 0.0008, CondE: 0.0581, disc: 0.6618, domain: 0.9420, Src VAT: 0.0048, Trg VAT: 0.0581, Src Train Acc: 100.00, Trg Train Acc: 93.79, Src Test Acc: 98.83, Trg Test Acc: 93.57
# Epoch: 211, TotalL: 0.0161, CrossE: 0.0008, CondE: 0.0577, disc: 0.6659, domain: 0.9339, Src VAT: 0.0048, Trg VAT: 0.0577, Src Train Acc: 100.00, Trg Train Acc: 93.71, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 212, TotalL: 0.0157, CrossE: 0.0007, CondE: 0.0558, disc: 0.6684, domain: 0.9298, Src VAT: 0.0046, Trg VAT: 0.0558, Src Train Acc: 100.00, Trg Train Acc: 93.66, Src Test Acc: 98.83, Trg Test Acc: 93.65
# Epoch: 213, TotalL: 0.3854, CrossE: 0.3304, CondE: 0.0936, disc: 0.6940, domain: 0.9348, Src VAT: 0.0437, Trg VAT: 0.0936, Src Train Acc: 96.70, Trg Train Acc: 90.54, Src Test Acc: 23.74, Trg Test Acc: 23.06
# Epoch: 214, TotalL: 1.7812, CrossE: 0.8129, CondE: 1.0144, disc: 0.7318, domain: 0.7735, Src VAT: 0.9403, Trg VAT: 1.0144, Src Train Acc: 72.22, Trg Train Acc: 65.80, Src Test Acc: 93.77, Trg Test Acc: 89.06
# Epoch: 215, TotalL: 0.3624, CrossE: 0.1542, CondE: 0.2932, disc: 0.7344, domain: 0.8458, Src VAT: 0.1939, Trg VAT: 0.2932, Src Train Acc: 94.84, Trg Train Acc: 86.11, Src Test Acc: 96.89, Trg Test Acc: 91.65
# Epoch: 216, TotalL: 0.2209, CrossE: 0.0963, CondE: 0.2009, disc: 0.7124, domain: 0.8638, Src VAT: 0.1119, Trg VAT: 0.2009, Src Train Acc: 96.83, Trg Train Acc: 88.32, Src Test Acc: 97.67, Trg Test Acc: 93.73
# Epoch: 217, TotalL: 0.1143, CrossE: 0.0390, CondE: 0.1433, disc: 0.6966, domain: 0.8870, Src VAT: 0.0636, Trg VAT: 0.1433, Src Train Acc: 98.74, Trg Train Acc: 90.97, Src Test Acc: 96.89, Trg Test Acc: 92.82
# Epoch: 218, TotalL: 0.0615, CrossE: 0.0160, CondE: 0.1026, disc: 0.6884, domain: 0.9043, Src VAT: 0.0344, Trg VAT: 0.1026, Src Train Acc: 99.48, Trg Train Acc: 92.36, Src Test Acc: 97.67, Trg Test Acc: 92.98
# Epoch: 219, TotalL: 0.0878, CrossE: 0.0372, CondE: 0.1061, disc: 0.6800, domain: 0.9053, Src VAT: 0.0395, Trg VAT: 0.1061, Src Train Acc: 98.74, Trg Train Acc: 91.32, Src Test Acc: 98.05, Trg Test Acc: 93.57
# Epoch: 220, TotalL: 0.0444, CrossE: 0.0101, CondE: 0.0947, disc: 0.6734, domain: 0.9075, Src VAT: 0.0233, Trg VAT: 0.0947, Src Train Acc: 99.74, Trg Train Acc: 92.36, Src Test Acc: 96.89, Trg Test Acc: 91.56
# Epoch: 221, TotalL: 0.0276, CrossE: 0.0041, CondE: 0.0789, disc: 0.6636, domain: 0.9189, Src VAT: 0.0127, Trg VAT: 0.0789, Src Train Acc: 99.91, Trg Train Acc: 93.40, Src Test Acc: 98.83, Trg Test Acc: 93.40
# Epoch: 222, TotalL: 0.0230, CrossE: 0.0025, CondE: 0.0739, disc: 0.6616, domain: 0.9171, Src VAT: 0.0098, Trg VAT: 0.0739, Src Train Acc: 100.00, Trg Train Acc: 93.58, Src Test Acc: 97.67, Trg Test Acc: 93.40
# Epoch: 223, TotalL: 0.0194, CrossE: 0.0016, CondE: 0.0684, disc: 0.6588, domain: 0.9171, Src VAT: 0.0073, Trg VAT: 0.0684, Src Train Acc: 100.00, Trg Train Acc: 93.75, Src Test Acc: 97.28, Trg Test Acc: 93.65
# Epoch: 224, TotalL: 0.0177, CrossE: 0.0012, CondE: 0.0648, disc: 0.6571, domain: 0.9158, Src VAT: 0.0061, Trg VAT: 0.0648, Src Train Acc: 100.00, Trg Train Acc: 93.92, Src Test Acc: 97.67, Trg Test Acc: 93.48
# Epoch: 225, TotalL: 0.0169, CrossE: 0.0010, CondE: 0.0633, disc: 0.6569, domain: 0.9140, Src VAT: 0.0055, Trg VAT: 0.0633, Src Train Acc: 100.00, Trg Train Acc: 93.92, Src Test Acc: 97.28, Trg Test Acc: 93.57
# Epoch: 226, TotalL: 0.0162, CrossE: 0.0009, CondE: 0.0609, disc: 0.6575, domain: 0.9085, Src VAT: 0.0050, Trg VAT: 0.0609, Src Train Acc: 100.00, Trg Train Acc: 94.01, Src Test Acc: 97.67, Trg Test Acc: 93.65
# Epoch: 227, TotalL: 0.0154, CrossE: 0.0008, CondE: 0.0587, disc: 0.6597, domain: 0.8997, Src VAT: 0.0045, Trg VAT: 0.0587, Src Train Acc: 100.00, Trg Train Acc: 93.92, Src Test Acc: 98.05, Trg Test Acc: 93.82
# Epoch: 228, TotalL: 0.0150, CrossE: 0.0007, CondE: 0.0571, disc: 0.6608, domain: 0.8925, Src VAT: 0.0042, Trg VAT: 0.0571, Src Train Acc: 100.00, Trg Train Acc: 94.05, Src Test Acc: 98.05, Trg Test Acc: 93.57
# ...
# Epoch: 425, TotalL: 0.0113, CrossE: 0.0003, CondE: 0.0396, disc: 0.6745, domain: 0.8043, Src VAT: 0.0022, Trg VAT: 0.0396, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.83, Trg Test Acc: 95.66
# Epoch: 426, TotalL: 0.0111, CrossE: 0.0003, CondE: 0.0386, disc: 0.6757, domain: 0.8022, Src VAT: 0.0020, Trg VAT: 0.0386, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.83, Trg Test Acc: 95.74
# Epoch: 427, TotalL: 0.0110, CrossE: 0.0003, CondE: 0.0377, disc: 0.6770, domain: 0.8009, Src VAT: 0.0019, Trg VAT: 0.0377, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 99.22, Trg Test Acc: 95.66
# Epoch: 428, TotalL: 0.0108, CrossE: 0.0003, CondE: 0.0369, disc: 0.6798, domain: 0.7974, Src VAT: 0.0018, Trg VAT: 0.0369, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 99.22, Trg Test Acc: 95.74
# Epoch: 429, TotalL: 0.0107, CrossE: 0.0002, CondE: 0.0363, disc: 0.6833, domain: 0.7930, Src VAT: 0.0018, Trg VAT: 0.0363, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 99.22, Trg Test Acc: 95.49
# Epoch: 430, TotalL: 0.0106, CrossE: 0.0002, CondE: 0.0357, disc: 0.6866, domain: 0.7883, Src VAT: 0.0018, Trg VAT: 0.0357, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.83, Trg Test Acc: 95.66
# Epoch: 431, TotalL: 0.0105, CrossE: 0.0002, CondE: 0.0347, disc: 0.6893, domain: 0.7859, Src VAT: 0.0017, Trg VAT: 0.0347, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 99.22, Trg Test Acc: 95.66
# Epoch: 432, TotalL: 0.0104, CrossE: 0.0002, CondE: 0.0341, disc: 0.6918, domain: 0.7817, Src VAT: 0.0016, Trg VAT: 0.0341, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.83, Trg Test Acc: 95.66
# Epoch: 433, TotalL: 0.0102, CrossE: 0.0002, CondE: 0.0334, disc: 0.6932, domain: 0.7787, Src VAT: 0.0016, Trg VAT: 0.0334, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 99.22, Trg Test Acc: 95.57
# Epoch: 434, TotalL: 0.0102, CrossE: 0.0002, CondE: 0.0330, disc: 0.6943, domain: 0.7777, Src VAT: 0.0015, Trg VAT: 0.0330, Src Train Acc: 100.00, Trg Train Acc: 96.18, Src Test Acc: 99.22, Trg Test Acc: 95.74
# Epoch: 435, TotalL: 0.0101, CrossE: 0.0002, CondE: 0.0320, disc: 0.6940, domain: 0.7777, Src VAT: 0.0015, Trg VAT: 0.0320, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 99.61, Trg Test Acc: 95.99
# Epoch: 436, TotalL: 0.0100, CrossE: 0.0002, CondE: 0.0309, disc: 0.6974, domain: 0.7738, Src VAT: 0.0014, Trg VAT: 0.0309, Src Train Acc: 100.00, Trg Train Acc: 96.18, Src Test Acc: 99.61, Trg Test Acc: 96.07
# Epoch: 437, TotalL: 0.0098, CrossE: 0.0002, CondE: 0.0305, disc: 0.6994, domain: 0.7663, Src VAT: 0.0014, Trg VAT: 0.0305, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 99.61, Trg Test Acc: 96.32
# Epoch: 438, TotalL: 0.0097, CrossE: 0.0002, CondE: 0.0294, disc: 0.7041, domain: 0.7608, Src VAT: 0.0013, Trg VAT: 0.0294, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 99.61, Trg Test Acc: 96.41
# Epoch: 439, TotalL: 0.0098, CrossE: 0.0002, CondE: 0.0303, disc: 0.7143, domain: 0.7522, Src VAT: 0.0014, Trg VAT: 0.0303, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 99.61, Trg Test Acc: 96.41
# Epoch: 440, TotalL: 1.0161, CrossE: 0.5900, CondE: 0.4677, disc: 0.7154, domain: 0.7378, Src VAT: 0.4094, Trg VAT: 0.4677, Src Train Acc: 88.85, Trg Train Acc: 82.42, Src Test Acc: 96.89, Trg Test Acc: 91.31
# Epoch: 441, TotalL: 0.1152, CrossE: 0.0306, CondE: 0.1503, disc: 0.6899, domain: 0.7439, Src VAT: 0.0742, Trg VAT: 0.1503, Src Train Acc: 99.44, Trg Train Acc: 93.92, Src Test Acc: 98.05, Trg Test Acc: 94.74
# Epoch: 442, TotalL: 0.0328, CrossE: 0.0047, CondE: 0.0786, disc: 0.6803, domain: 0.7646, Src VAT: 0.0188, Trg VAT: 0.0786, Src Train Acc: 99.96, Trg Train Acc: 95.66, Src Test Acc: 98.05, Trg Test Acc: 94.82
# Epoch: 443, TotalL: 0.0199, CrossE: 0.0016, CondE: 0.0626, disc: 0.6746, domain: 0.7774, Src VAT: 0.0092, Trg VAT: 0.0626, Src Train Acc: 100.00, Trg Train Acc: 95.96, Src Test Acc: 98.05, Trg Test Acc: 95.07
# Epoch: 444, TotalL: 0.0166, CrossE: 0.0011, CondE: 0.0561, disc: 0.6719, domain: 0.7855, Src VAT: 0.0066, Trg VAT: 0.0561, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.05, Trg Test Acc: 95.24
# Epoch: 445, TotalL: 0.0148, CrossE: 0.0008, CondE: 0.0519, disc: 0.6702, domain: 0.7912, Src VAT: 0.0051, Trg VAT: 0.0519, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.05, Trg Test Acc: 95.32
# Epoch: 446, TotalL: 0.0137, CrossE: 0.0006, CondE: 0.0489, disc: 0.6691, domain: 0.7954, Src VAT: 0.0042, Trg VAT: 0.0489, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.05, Trg Test Acc: 95.41
# Epoch: 447, TotalL: 0.0130, CrossE: 0.0005, CondE: 0.0466, disc: 0.6689, domain: 0.7991, Src VAT: 0.0036, Trg VAT: 0.0466, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.05, Trg Test Acc: 95.49
# Epoch: 448, TotalL: 0.0125, CrossE: 0.0005, CondE: 0.0448, disc: 0.6689, domain: 0.8015, Src VAT: 0.0031, Trg VAT: 0.0448, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.44, Trg Test Acc: 95.66
# Epoch: 449, TotalL: 0.0121, CrossE: 0.0004, CondE: 0.0433, disc: 0.6691, domain: 0.8034, Src VAT: 0.0028, Trg VAT: 0.0433, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.44, Trg Test Acc: 95.66
# Epoch: 450, TotalL: 0.0118, CrossE: 0.0004, CondE: 0.0420, disc: 0.6696, domain: 0.8039, Src VAT: 0.0026, Trg VAT: 0.0420, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.44, Trg Test Acc: 95.66
# Epoch: 451, TotalL: 0.0116, CrossE: 0.0003, CondE: 0.0408, disc: 0.6698, domain: 0.8037, Src VAT: 0.0024, Trg VAT: 0.0408, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.44, Trg Test Acc: 95.66
# Epoch: 452, TotalL: 0.0114, CrossE: 0.0003, CondE: 0.0397, disc: 0.6700, domain: 0.8037, Src VAT: 0.0023, Trg VAT: 0.0397, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.44, Trg Test Acc: 95.74
# Epoch: 453, TotalL: 0.0113, CrossE: 0.0003, CondE: 0.0389, disc: 0.6711, domain: 0.8020, Src VAT: 0.0022, Trg VAT: 0.0389, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.83, Trg Test Acc: 95.82
# Epoch: 454, TotalL: 0.0111, CrossE: 0.0003, CondE: 0.0379, disc: 0.6729, domain: 0.7993, Src VAT: 0.0021, Trg VAT: 0.0379, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.83, Trg Test Acc: 95.82
# Epoch: 455, TotalL: 0.0110, CrossE: 0.0003, CondE: 0.0369, disc: 0.6748, domain: 0.7972, Src VAT: 0.0020, Trg VAT: 0.0369, Src Train Acc: 100.00, Trg Train Acc: 96.09, Src Test Acc: 98.83, Trg Test Acc: 95.99
# Epoch: 456, TotalL: 0.0109, CrossE: 0.0003, CondE: 0.0359, disc: 0.6769, domain: 0.7956, Src VAT: 0.0019, Trg VAT: 0.0359, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.83, Trg Test Acc: 96.07
# Epoch: 457, TotalL: 0.0107, CrossE: 0.0003, CondE: 0.0349, disc: 0.6783, domain: 0.7930, Src VAT: 0.0019, Trg VAT: 0.0349, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.83, Trg Test Acc: 96.07
# Epoch: 458, TotalL: 0.0107, CrossE: 0.0002, CondE: 0.0343, disc: 0.6810, domain: 0.7913, Src VAT: 0.0018, Trg VAT: 0.0343, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 96.07
# Epoch: 459, TotalL: 0.0106, CrossE: 0.0002, CondE: 0.0336, disc: 0.6835, domain: 0.7897, Src VAT: 0.0018, Trg VAT: 0.0336, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 96.24
# Epoch: 460, TotalL: 0.0106, CrossE: 0.0002, CondE: 0.0331, disc: 0.6862, domain: 0.7863, Src VAT: 0.0018, Trg VAT: 0.0331, Src Train Acc: 100.00, Trg Train Acc: 96.31, Src Test Acc: 98.44, Trg Test Acc: 96.32
# Epoch: 461, TotalL: 0.0104, CrossE: 0.0002, CondE: 0.0324, disc: 0.6885, domain: 0.7831, Src VAT: 0.0017, Trg VAT: 0.0324, Src Train Acc: 100.00, Trg Train Acc: 96.35, Src Test Acc: 98.44, Trg Test Acc: 96.24
# Epoch: 462, TotalL: 0.0103, CrossE: 0.0002, CondE: 0.0319, disc: 0.6901, domain: 0.7811, Src VAT: 0.0017, Trg VAT: 0.0319, Src Train Acc: 100.00, Trg Train Acc: 96.44, Src Test Acc: 98.44, Trg Test Acc: 96.07
# Epoch: 463, TotalL: 0.0102, CrossE: 0.0002, CondE: 0.0308, disc: 0.6911, domain: 0.7810, Src VAT: 0.0015, Trg VAT: 0.0308, Src Train Acc: 100.00, Trg Train Acc: 96.48, Src Test Acc: 98.05, Trg Test Acc: 96.16
# Epoch: 464, TotalL: 0.0102, CrossE: 0.0002, CondE: 0.0306, disc: 0.6914, domain: 0.7828, Src VAT: 0.0015, Trg VAT: 0.0306, Src Train Acc: 100.00, Trg Train Acc: 96.44, Src Test Acc: 98.05, Trg Test Acc: 96.16
# Epoch: 465, TotalL: 0.0102, CrossE: 0.0002, CondE: 0.0306, disc: 0.6917, domain: 0.7876, Src VAT: 0.0015, Trg VAT: 0.0306, Src Train Acc: 100.00, Trg Train Acc: 96.48, Src Test Acc: 98.05, Trg Test Acc: 95.99
# Epoch: 466, TotalL: 0.0101, CrossE: 0.0002, CondE: 0.0300, disc: 0.6925, domain: 0.7860, Src VAT: 0.0015, Trg VAT: 0.0300, Src Train Acc: 100.00, Trg Train Acc: 96.40, Src Test Acc: 97.67, Trg Test Acc: 96.16
# Epoch: 467, TotalL: 0.0101, CrossE: 0.0002, CondE: 0.0294, disc: 0.6930, domain: 0.7828, Src VAT: 0.0015, Trg VAT: 0.0294, Src Train Acc: 100.00, Trg Train Acc: 96.48, Src Test Acc: 97.67, Trg Test Acc: 95.99
# Epoch: 468, TotalL: 0.0100, CrossE: 0.0002, CondE: 0.0290, disc: 0.6965, domain: 0.7781, Src VAT: 0.0015, Trg VAT: 0.0290, Src Train Acc: 100.00, Trg Train Acc: 96.40, Src Test Acc: 97.67, Trg Test Acc: 96.16
# Epoch: 469, TotalL: 1.0518, CrossE: 0.5924, CondE: 0.5056, disc: 0.6924, domain: 0.7493, Src VAT: 0.4418, Trg VAT: 0.5056, Src Train Acc: 89.28, Trg Train Acc: 85.50, Src Test Acc: 97.67, Trg Test Acc: 92.31
# Epoch: 470, TotalL: 0.0978, CrossE: 0.0270, CondE: 0.1249, disc: 0.6689, domain: 0.7847, Src VAT: 0.0605, Trg VAT: 0.1249, Src Train Acc: 99.52, Trg Train Acc: 94.92, Src Test Acc: 99.61, Trg Test Acc: 94.15
# Epoch: 471, TotalL: 0.0550, CrossE: 0.0154, CondE: 0.0884, disc: 0.6614, domain: 0.8007, Src VAT: 0.0298, Trg VAT: 0.0884, Src Train Acc: 99.57, Trg Train Acc: 95.27, Src Test Acc: 99.22, Trg Test Acc: 93.15
# Epoch: 472, TotalL: 0.0273, CrossE: 0.0050, CondE: 0.0705, disc: 0.6563, domain: 0.8101, Src VAT: 0.0128, Trg VAT: 0.0705, Src Train Acc: 99.87, Trg Train Acc: 95.92, Src Test Acc: 99.22, Trg Test Acc: 95.49
# Epoch: 473, TotalL: 0.0219, CrossE: 0.0031, CondE: 0.0614, disc: 0.6521, domain: 0.8205, Src VAT: 0.0093, Trg VAT: 0.0614, Src Train Acc: 99.91, Trg Train Acc: 95.83, Src Test Acc: 99.22, Trg Test Acc: 95.15
# Epoch: 474, TotalL: 0.0177, CrossE: 0.0018, CondE: 0.0567, disc: 0.6493, domain: 0.8251, Src VAT: 0.0065, Trg VAT: 0.0567, Src Train Acc: 99.96, Trg Train Acc: 96.01, Src Test Acc: 98.83, Trg Test Acc: 95.57
# Epoch: 475, TotalL: 0.0154, CrossE: 0.0010, CondE: 0.0532, disc: 0.6476, domain: 0.8308, Src VAT: 0.0050, Trg VAT: 0.0532, Src Train Acc: 100.00, Trg Train Acc: 95.92, Src Test Acc: 98.83, Trg Test Acc: 95.41
# Epoch: 476, TotalL: 0.0141, CrossE: 0.0007, CondE: 0.0485, disc: 0.6476, domain: 0.8349, Src VAT: 0.0041, Trg VAT: 0.0485, Src Train Acc: 100.00, Trg Train Acc: 95.79, Src Test Acc: 98.83, Trg Test Acc: 95.32
# Epoch: 477, TotalL: 0.0130, CrossE: 0.0005, CondE: 0.0454, disc: 0.6481, domain: 0.8345, Src VAT: 0.0032, Trg VAT: 0.0454, Src Train Acc: 100.00, Trg Train Acc: 96.01, Src Test Acc: 99.22, Trg Test Acc: 95.57
# Epoch: 478, TotalL: 0.0125, CrossE: 0.0004, CondE: 0.0434, disc: 0.6485, domain: 0.8345, Src VAT: 0.0029, Trg VAT: 0.0434, Src Train Acc: 100.00, Trg Train Acc: 96.01, Src Test Acc: 98.83, Trg Test Acc: 95.49
# Epoch: 479, TotalL: 0.0122, CrossE: 0.0004, CondE: 0.0418, disc: 0.6495, domain: 0.8335, Src VAT: 0.0026, Trg VAT: 0.0418, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.83, Trg Test Acc: 95.41
# Epoch: 480, TotalL: 0.0119, CrossE: 0.0004, CondE: 0.0406, disc: 0.6500, domain: 0.8323, Src VAT: 0.0024, Trg VAT: 0.0406, Src Train Acc: 100.00, Trg Train Acc: 96.05, Src Test Acc: 98.83, Trg Test Acc: 95.41
# Epoch: 481, TotalL: 0.0117, CrossE: 0.0003, CondE: 0.0395, disc: 0.6506, domain: 0.8314, Src VAT: 0.0023, Trg VAT: 0.0395, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.83, Trg Test Acc: 95.41
# Epoch: 482, TotalL: 0.0116, CrossE: 0.0003, CondE: 0.0386, disc: 0.6513, domain: 0.8296, Src VAT: 0.0022, Trg VAT: 0.0386, Src Train Acc: 100.00, Trg Train Acc: 96.14, Src Test Acc: 98.83, Trg Test Acc: 95.49
# Epoch: 483, TotalL: 0.0115, CrossE: 0.0003, CondE: 0.0377, disc: 0.6522, domain: 0.8282, Src VAT: 0.0021, Trg VAT: 0.0377, Src Train Acc: 100.00, Trg Train Acc: 96.18, Src Test Acc: 98.83, Trg Test Acc: 95.66
# Epoch: 484, TotalL: 0.0113, CrossE: 0.0003, CondE: 0.0369, disc: 0.6530, domain: 0.8262, Src VAT: 0.0020, Trg VAT: 0.0369, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 95.57
# Epoch: 485, TotalL: 0.0112, CrossE: 0.0003, CondE: 0.0362, disc: 0.6540, domain: 0.8246, Src VAT: 0.0020, Trg VAT: 0.0362, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 95.74
# Epoch: 486, TotalL: 0.0111, CrossE: 0.0003, CondE: 0.0354, disc: 0.6559, domain: 0.8220, Src VAT: 0.0019, Trg VAT: 0.0354, Src Train Acc: 100.00, Trg Train Acc: 96.22, Src Test Acc: 98.83, Trg Test Acc: 95.66
# Epoch: 487, TotalL: 0.0110, CrossE: 0.0003, CondE: 0.0348, disc: 0.6572, domain: 0.8196, Src VAT: 0.0019, Trg VAT: 0.0348, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.83, Trg Test Acc: 95.57
# Epoch: 488, TotalL: 0.0109, CrossE: 0.0002, CondE: 0.0340, disc: 0.6596, domain: 0.8144, Src VAT: 0.0018, Trg VAT: 0.0340, Src Train Acc: 100.00, Trg Train Acc: 96.31, Src Test Acc: 98.83, Trg Test Acc: 95.57
# Epoch: 489, TotalL: 0.0108, CrossE: 0.0002, CondE: 0.0335, disc: 0.6619, domain: 0.8104, Src VAT: 0.0017, Trg VAT: 0.0335, Src Train Acc: 100.00, Trg Train Acc: 96.31, Src Test Acc: 98.83, Trg Test Acc: 95.41
# Epoch: 490, TotalL: 0.0106, CrossE: 0.0002, CondE: 0.0333, disc: 0.6642, domain: 0.8054, Src VAT: 0.0017, Trg VAT: 0.0333, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.83, Trg Test Acc: 95.24
# Epoch: 491, TotalL: 0.0105, CrossE: 0.0002, CondE: 0.0330, disc: 0.6672, domain: 0.8010, Src VAT: 0.0016, Trg VAT: 0.0330, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.83, Trg Test Acc: 95.41
# Epoch: 492, TotalL: 0.0103, CrossE: 0.0002, CondE: 0.0326, disc: 0.6709, domain: 0.7951, Src VAT: 0.0015, Trg VAT: 0.0326, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.83, Trg Test Acc: 95.57
# Epoch: 493, TotalL: 0.0102, CrossE: 0.0002, CondE: 0.0319, disc: 0.6745, domain: 0.7893, Src VAT: 0.0015, Trg VAT: 0.0319, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.44, Trg Test Acc: 95.99
# Epoch: 494, TotalL: 0.0101, CrossE: 0.0002, CondE: 0.0314, disc: 0.6789, domain: 0.7842, Src VAT: 0.0015, Trg VAT: 0.0314, Src Train Acc: 100.00, Trg Train Acc: 96.31, Src Test Acc: 97.67, Trg Test Acc: 95.91
# Epoch: 495, TotalL: 0.0101, CrossE: 0.0002, CondE: 0.0312, disc: 0.6833, domain: 0.7781, Src VAT: 0.0015, Trg VAT: 0.0312, Src Train Acc: 100.00, Trg Train Acc: 96.31, Src Test Acc: 97.67, Trg Test Acc: 95.74
# Epoch: 496, TotalL: 0.0100, CrossE: 0.0002, CondE: 0.0307, disc: 0.6897, domain: 0.7729, Src VAT: 0.0015, Trg VAT: 0.0307, Src Train Acc: 100.00, Trg Train Acc: 96.27, Src Test Acc: 98.05, Trg Test Acc: 96.32
# Epoch: 497, TotalL: 0.0099, CrossE: 0.0002, CondE: 0.0302, disc: 0.7035, domain: 0.7618, Src VAT: 0.0015, Trg VAT: 0.0302, Src Train Acc: 100.00, Trg Train Acc: 96.31, Src Test Acc: 98.05, Trg Test Acc: 95.91
# Epoch: 498, TotalL: 0.0097, CrossE: 0.0002, CondE: 0.0302, disc: 0.7066, domain: 0.7563, Src VAT: 0.0013, Trg VAT: 0.0302, Src Train Acc: 100.00, Trg Train Acc: 96.35, Src Test Acc: 97.67, Trg Test Acc: 95.91
# Epoch: 499, TotalL: 0.1968, CrossE: 0.1846, CondE: 0.0298, disc: 0.7326, domain: 0.7657, Src VAT: 0.0040, Trg VAT: 0.0298, Src Train Acc: 99.00, Trg Train Acc: 95.36, Src Test Acc: 22.18, Trg Test Acc: 22.81
# Epoch: 500, TotalL: 1.2809, CrossE: 0.6248, CondE: 0.6998, disc: 0.6983, domain: 0.7357, Src VAT: 0.6347, Trg VAT: 0.6998, Src Train Acc: 84.98, Trg Train Acc: 80.47, Src Test Acc: 98.44, Trg Test Acc: 92.82
