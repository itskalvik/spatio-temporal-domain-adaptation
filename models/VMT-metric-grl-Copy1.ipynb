# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from skimage.transform import resize
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='1'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 500
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
alpha           = 0.05
disc_activation = 'selu'
gen_activation  = 'selu'
train_trg_env_days = 2
notes           = "VMT_gauss_noise_cv_data_center_adapt_grl2d_serverconftime_{}trg_day_resize224".format(train_trg_env_days)

log_data = "classes-{}_bs-{}_train_src_days-{}_train_trg_days-{}_lr-{}_num_hidden-{}_num_feat-{}_disc_act-{}_gen_act-{}_center_alpha-{}_{}".format(num_classes, 
                                                                                                                                                        batch_size, 
                                                                                                                                                        train_src_days, 
                                                                                                                                                        train_trg_days, 
                                                                                                                                                        learning_rate, 
                                                                                                                                                        num_hidden, 
                                                                                                                                                        num_features,
                                                                                                                                                        disc_activation,
                                                                                                                                                        gen_activation,
                                                                                                                                                        alpha,
                                                                                                                                                        notes)

# %%
def resize_data(data, output_shape=(224, 224)):
  _, height, width, channels = data.shape
  data = data.transpose((1, 2, 3, 0)) 
  data = resize(data.reshape(height, width, -1), output_shape)
  data = data.reshape(*output_shape, channels, -1)
  data = data.transpose((3, 0, 1, 2))
  return data

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = resize_data(np.expand_dims(hf.get('X_data'), axis=-1))
y_data = np.array(hf.get('y_data'))
classes = list(hf.get('classes'))
classes = [n.decode("ascii", "ignore") for n in classes]
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)

#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)

#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)

#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg, X_data, y_data

#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

X_train_src = X_train_src.astype(np.float32)
y_train_src = y_train_src.astype(np.uint8)
X_test_src  = X_test_src.astype(np.float32)
y_test_src  = y_test_src.astype(np.uint8)
X_train_trg = X_train_trg.astype(np.float32)
y_train_trg = y_train_trg.astype(np.uint8)
X_test_trg  = X_test_trg.astype(np.float32)
y_test_trg  = y_test_trg.astype(np.uint8)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (9127, 224, 224, 1) (9127, 2)
#  ['arahman3', 'harika', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']
# (8737, 224, 224, 1) (8737, 2)
# (8547, 224, 224, 1) (8547, 2)
#  ['arahman3', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']
# (2308, 224, 224, 1) (2308, 9) (257, 224, 224, 1) (257, 9) (2563, 224, 224, 1) (2563, 9) (3419, 224, 224, 1) (3419, 9)

# %%
def get_trg_data(fname, src_classes, train_trg_days):
  #Read data
  hf = h5py.File(fname, 'r')
  X_data_trg = resize_data(np.expand_dims(hf.get('X_data'), axis=-1))
  y_data_trg = np.array(hf.get('y_data'))
  trg_classes = list(hf.get('classes'))
  trg_classes = [n.decode("ascii", "ignore") for n in trg_classes]
  hf.close()

  #split days of data to train and test
  X_train_trg = X_data_trg[y_data_trg[:, 1] < train_trg_days]
  y_train_trg = y_data_trg[y_data_trg[:, 1] < train_trg_days, 0]
  y_train_trg = np.array([src_classes.index(trg_classes[y_train_trg[i]]) for i in range(y_train_trg.shape[0])])
  y_train_trg = np.eye(len(src_classes))[y_train_trg]
  y_train_trg = y_train_trg.astype(np.int64)

  X_test_trg = X_data_trg[y_data_trg[:, 1] >= train_trg_days]
  y_test_trg = y_data_trg[y_data_trg[:, 1] >= train_trg_days, 0]
  y_test_trg = np.eye(len(src_classes))[y_test_trg]
  y_test_trg = y_test_trg.astype(np.int64)

  #standardise dataset  
  trg_mean     = np.mean(X_train_trg)
  X_train_trg -= trg_mean
  trg_std      = np.std(X_train_trg)
  X_train_trg /= trg_std

  X_test_trg  -= trg_mean
  X_test_trg  /= trg_std
  
  return X_train_trg.astype(np.float32), y_train_trg.astype(np.uint8), X_test_trg.astype(np.float32), y_test_trg.astype(np.uint8)

X_train_conf,   y_train_conf,   X_test_conf,   y_test_conf   = get_trg_data('/home/kjakkala/mmwave/data/target_conf_data.h5',   classes, train_trg_env_days)
X_train_server, y_train_server, X_test_server, y_test_server = get_trg_data('/home/kjakkala/mmwave/data/target_server_data.h5', classes, train_trg_env_days)
X_data_office,  y_data_office,  _,             _             = get_trg_data('/home/kjakkala/mmwave/data/target_office_data.h5', classes, 3)

print(X_train_conf.shape,   y_train_conf.shape,    X_test_conf.shape,   y_test_conf.shape)
print(X_train_server.shape, y_train_server.shape,  X_test_server.shape, y_test_server.shape)
print(X_data_office.shape, y_data_office.shape)
# Out:
# (900, 224, 224, 1) (900, 9) (450, 224, 224, 1) (450, 9)
# (898, 224, 224, 1) (898, 9) (448, 224, 224, 1) (448, 9)
# (899, 224, 224, 1) (899, 9)

# %%
#get tf.data objects for each set

#Test
conf_test_set = tf.data.Dataset.from_tensor_slices((X_test_conf, y_test_conf))
conf_test_set = conf_test_set.batch(batch_size, drop_remainder=False)
conf_test_set = conf_test_set.prefetch(batch_size)

server_test_set = tf.data.Dataset.from_tensor_slices((X_test_server, y_test_server))
server_test_set = server_test_set.batch(batch_size, drop_remainder=False)
server_test_set = server_test_set.prefetch(batch_size)

office_test_set = tf.data.Dataset.from_tensor_slices((X_data_office, y_data_office))
office_test_set = office_test_set.batch(batch_size, drop_remainder=False)
office_test_set = office_test_set.prefetch(batch_size)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(batch_size)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(batch_size)

#Train
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(batch_size)

server_train_set = tf.data.Dataset.from_tensor_slices((X_train_server, y_train_server))
server_train_set = server_train_set.shuffle(X_train_server.shape[0])
server_train_set = server_train_set.batch(batch_size, drop_remainder=True)
server_train_set = server_train_set.prefetch(batch_size)
server_train_set = server_train_set.repeat(-1)

conf_train_set = tf.data.Dataset.from_tensor_slices((X_train_conf, y_train_conf))
conf_train_set = conf_train_set.shuffle(X_train_conf.shape[0])
conf_train_set = conf_train_set.batch(batch_size, drop_remainder=True)
conf_train_set = conf_train_set.prefetch(batch_size)
conf_train_set = conf_train_set.repeat(-1)

if (X_train_trg.shape[0] > 0):
  time_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
  time_train_set = time_train_set.shuffle(X_train_trg.shape[0])
  time_train_set = time_train_set.batch(batch_size, drop_remainder=True)
  time_train_set = time_train_set.prefetch(batch_size)
  time_train_set = time_train_set.repeat(-1)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x

class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, num_classes, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(num_classes, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x
  
@tf.custom_gradient
def reverse_gradient(x, hp_lambda):
    def custom_grad(dy):
        return tf.math.multiply(tf.negative(dy), hp_lambda)
    return x, custom_grad
  
class GradientReversal(tf.keras.layers.Layer):
  def __init__(self):
    super(GradientReversal, self).__init__()
    
  def build(self, input_shapes):
    pass

  def call(self, inputs, lambda_hp):
    return reverse_gradient(inputs, lambda_hp)
  
"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, num_hidden, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    
    self.disc = Discriminator(num_hidden, 4, activation=self.activation)
    
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False, lambda_hp=1):    
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    
    grad_rev = GradientReversal()(fc1, lambda_hp)
    disc_logits = self.disc(grad_rev)
    
    logits = self.logits(fc1)
    return logits, fc1, disc_logits

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

class CenterLoss():
    def __init__(self, batch_size, num_classes, len_features, alpha):
      self.centers = tf.Variable(tf.zeros([num_classes, len_features]),
                                 dtype=tf.float32,
                                 trainable=False)
      self.alpha = alpha
      self.num_classes = num_classes
      self.batch_size = batch_size    
      self.margin = tf.constant(100, dtype="float32")
      self.norm = lambda x: tf.reduce_sum(tf.square(x), 1)
      self.EdgeWeights = tf.ones((self.num_classes,self.num_classes)) - \
                                  tf.eye(self.num_classes)

    def get_center_loss(self, features, labels):
      labels = tf.reshape(tf.argmax(labels, axis=-1), [-1])
      centers0 = tf.math.unsorted_segment_mean(features, 
                                               labels, 
                                               self.num_classes)
      center_pairwise_dist = tf.transpose(self.norm(tf.expand_dims(centers0, 2) - \
                                                    tf.transpose(centers0)))
      self.inter_loss = tf.math.reduce_sum(tf.multiply(tf.maximum(0.0, self.margin - center_pairwise_dist), 
                                                       self.EdgeWeights))

      unique_label, unique_idx, unique_count = tf.unique_with_counts(labels)
      appear_times = tf.gather(unique_count, unique_idx)
      appear_times = tf.reshape(appear_times, [-1, 1])
      centers_batch = tf.gather(self.centers, labels)
      diff = centers_batch - features
      diff /= tf.cast((1 + appear_times), tf.float32)
      diff *= self.alpha
      self.centers_update_op = tf.compat.v1.scatter_sub(self.centers, 
                                                        labels, 
                                                        diff)

      self.intra_loss   = tf.nn.l2_loss(features - centers_batch)
      self.center_loss  = self.intra_loss + self.inter_loss
      self.center_loss /= (self.num_classes*self.batch_size+self.num_classes*self.num_classes)
      return self.center_loss
      
def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _, _ = generator(images + noise, 
                                   tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
office_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='office_test_accuracy')
server_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='server_test_accuracy')
conf_test_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='conf_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images_ser, trg_labels_ser, trg_images_conf, trg_labels_conf, trg_images, trg_labels, lambda_hp):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc, src_disc                = generator(src_images,      training=True, lambda_hp=lambda_hp)
    trg_logits_ser, trg_enc_ser, trg_disc_ser    = generator(trg_images_ser,  training=True, lambda_hp=lambda_hp) 
    trg_logits_conf, trg_enc_conf, trg_disc_conf = generator(trg_images_conf, training=True, lambda_hp=lambda_hp) 
    trg_logits, trg_enc, trg_disc                = generator(trg_images,      training=True, lambda_hp=lambda_hp)
        
    #VAT
    src_adver_images            = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _, _      = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images_ser        = virtual_adversarial_images(trg_images_ser, tf.nn.softmax(trg_logits_ser))
    trg_adver_logits_ser, _, _  = generator(tf.stop_gradient(trg_adver_images_ser), training=True)
    trg_adver_images_conf       = virtual_adversarial_images(trg_images_conf, tf.nn.softmax(trg_logits_conf))
    trg_adver_logits_conf, _, _ = generator(tf.stop_gradient(trg_adver_images_conf), training=True)
    trg_adver_images            = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _, _      = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _, _             = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images_ser, trg_mixup_labels_ser = mixup_preprocess(trg_images_ser, trg_logits_ser, batch_size)
    trg_mixup_logits_ser, _, _                 = generator(tf.stop_gradient(trg_mixup_images_ser),
                                                           training=True)
    trg_mixup_images_conf, trg_mixup_labels_conf = mixup_preprocess(trg_images_conf, trg_logits_conf, batch_size)
    trg_mixup_logits_conf, _, _                  = generator(tf.stop_gradient(trg_mixup_images_conf),
                                                             training=True)
    trg_mixup_images, trg_mixup_labels      = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _, _                  = generator(tf.stop_gradient(trg_mixup_images),
                                                        training=True)
    
    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(tf.concat([trg_logits_ser, 
                                                                                 trg_logits_conf,
                                                                                 trg_logits], 0)), 
                                                 logits=tf.concat([trg_logits_ser, 
                                                                   trg_logits_conf,
                                                                   trg_logits], 0))
    
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(tf.concat([trg_logits_ser, 
                                                                                                  trg_logits_conf,
                                                                                                  trg_logits], 0))),
                                                 logits=tf.concat([trg_adver_logits_ser, 
                                                                   trg_adver_logits_conf,
                                                                   trg_adver_logits], 0))
    
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(tf.concat([trg_mixup_labels_ser, 
                                                                                    trg_mixup_labels_conf,
                                                                                    trg_mixup_labels], 0)), 
                                                 logits=tf.concat([trg_mixup_logits_ser, 
                                                                   trg_mixup_logits_conf,
                                                                   trg_mixup_logits], 0))
          
    batch_center_loss   = center_loss.get_center_loss(src_enc, src_labels)
    domain_loss         = get_cross_entropy_loss(labels=tf.one_hot(tf.cast(tf.concat([tf.zeros(tf.shape(src_disc)[0]),
                                                                                      tf.ones(tf.shape(trg_disc_ser)[0]),
                                                                                      tf.ones(tf.shape(trg_disc_conf)[0])*2,
                                                                                      tf.ones(tf.shape(trg_disc)[0])*3], 0), tf.uint8), 4),
                                                 logits = tf.concat([src_disc, 
                                                                     trg_disc_ser, 
                                                                     trg_disc_conf, 
                                                                     trg_disc], 0)) 

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss + \
                 1    * batch_center_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  with tf.control_dependencies([center_loss.centers_update_op]):
    gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(tf.concat([trg_labels_ser, trg_labels_conf], 0), tf.concat([trg_logits_ser, trg_logits_conf], 0))
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def test_step(images):
  return generator(images, training=False)[0]

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}, Server Test Acc: {:.2f}, Office Test Acc: {:.2f}, Conf Test Acc: {:.2f}'

generator      = ResNet50(num_classes, num_features, num_hidden, gen_activation)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
center_loss    = CenterLoss(batch_size, num_classes, num_features, alpha)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    tf.contrib.summary.scalar("office_test_accuracy", office_test_accuracy.result())
    tf.contrib.summary.scalar("server_test_accuracy", server_test_accuracy.result())
    tf.contrib.summary.scalar("conf_test_accuracy", conf_test_accuracy.result())

def get_lambda(p, delta=10):
  return ((2/(1 + np.exp(-delta*p))) - 1).astype(np.float32)

for epoch in range(epochs):  
  global_step.assign_add(1)  

  for source_data, target_data, server_data, conf_data in zip(src_train_set, time_train_set, server_train_set, conf_train_set):
    train_gen_step(source_data[0], source_data[1], server_data[0], server_data[1], conf_data[0], conf_data[1], target_data[0], target_data[1], get_lambda(epoch*2))

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for data in trg_test_set:
    trg_test_accuracy(test_step(data[0]), data[1])
    
  for data in src_test_set:
    src_test_accuracy(test_step(data[0]), data[1])
    
  for data in office_test_set:
    office_test_accuracy(test_step(data[0]), data[1])
    
  for data in server_test_set:
    server_test_accuracy(test_step(data[0]), data[1])
    
  for data in conf_test_set:
    conf_test_accuracy(test_step(data[0]), data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100,
                             server_test_accuracy.result()*100,
                             office_test_accuracy.result()*100,
                             conf_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
  server_test_accuracy.reset_states()
  office_test_accuracy.reset_states()
  conf_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0909 16:08:40.519464 140500812482304 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0909 16:08:43.629298 140500812482304 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 21.2947, CrossE: 2.1325, CondE: 2.1668, disc: 0.0000, domain: 1.3977, Src VAT: 2.1662, Trg VAT: 2.1668, Src MixUp: 2.1748, Trg MixUp: 2.1739, Src Train Acc: 18.36, Trg Train Acc: 15.76, Src Test Acc: 26.07, Trg Test Acc: 26.50, Server Test Acc: 19.20, Office Test Acc: 14.68, Conf Test Acc: 22.44
# Epoch: 002, TotalL: 17.1051, CrossE: 1.9330, CondE: 2.0738, disc: 0.0000, domain: 1.5093, Src VAT: 2.0737, Trg VAT: 2.0738, Src MixUp: 2.1123, Trg MixUp: 2.1122, Src Train Acc: 27.30, Trg Train Acc: 19.25, Src Test Acc: 29.18, Trg Test Acc: 30.80, Server Test Acc: 20.76, Office Test Acc: 17.24, Conf Test Acc: 23.56
# Epoch: 003, TotalL: 16.2490, CrossE: 1.8131, CondE: 1.9768, disc: 0.0000, domain: 1.3672, Src VAT: 1.9733, Trg VAT: 1.9768, Src MixUp: 2.0445, Trg MixUp: 2.0463, Src Train Acc: 30.64, Trg Train Acc: 22.22, Src Test Acc: 31.52, Trg Test Acc: 29.42, Server Test Acc: 24.33, Office Test Acc: 19.58, Conf Test Acc: 25.56
# Epoch: 004, TotalL: 15.7665, CrossE: 1.7406, CondE: 1.9142, disc: 0.0000, domain: 1.3461, Src VAT: 1.9059, Trg VAT: 1.9142, Src MixUp: 1.9968, Trg MixUp: 2.0015, Src Train Acc: 33.51, Trg Train Acc: 23.35, Src Test Acc: 32.68, Trg Test Acc: 30.97, Server Test Acc: 24.78, Office Test Acc: 20.69, Conf Test Acc: 30.44
# Epoch: 005, TotalL: 15.3808, CrossE: 1.6732, CondE: 1.8658, disc: 0.0000, domain: 1.2925, Src VAT: 1.8516, Trg VAT: 1.8658, Src MixUp: 1.9592, Trg MixUp: 1.9685, Src Train Acc: 35.76, Trg Train Acc: 24.63, Src Test Acc: 33.85, Trg Test Acc: 31.91, Server Test Acc: 25.45, Office Test Acc: 21.36, Conf Test Acc: 29.56
# Epoch: 006, TotalL: 15.0494, CrossE: 1.6088, CondE: 1.8240, disc: 0.0000, domain: 1.2871, Src VAT: 1.8057, Trg VAT: 1.8240, Src MixUp: 1.9284, Trg MixUp: 1.9387, Src Train Acc: 38.54, Trg Train Acc: 27.32, Src Test Acc: 40.08, Trg Test Acc: 34.19, Server Test Acc: 27.68, Office Test Acc: 23.14, Conf Test Acc: 30.44
# Epoch: 007, TotalL: 14.7305, CrossE: 1.5400, CondE: 1.7751, disc: 0.0000, domain: 1.2742, Src VAT: 1.7535, Trg VAT: 1.7751, Src MixUp: 1.8901, Trg MixUp: 1.9006, Src Train Acc: 42.36, Trg Train Acc: 29.47, Src Test Acc: 42.41, Trg Test Acc: 37.99, Server Test Acc: 31.03, Office Test Acc: 27.47, Conf Test Acc: 34.89
# Epoch: 008, TotalL: 14.3911, CrossE: 1.4576, CondE: 1.7187, disc: 0.0000, domain: 1.2417, Src VAT: 1.6938, Trg VAT: 1.7187, Src MixUp: 1.8542, Trg MixUp: 1.8561, Src Train Acc: 46.79, Trg Train Acc: 31.38, Src Test Acc: 45.53, Trg Test Acc: 39.05, Server Test Acc: 32.59, Office Test Acc: 29.92, Conf Test Acc: 34.00
# Epoch: 009, TotalL: 14.0286, CrossE: 1.3689, CondE: 1.6642, disc: 0.0000, domain: 1.2367, Src VAT: 1.6357, Trg VAT: 1.6642, Src MixUp: 1.8069, Trg MixUp: 1.8167, Src Train Acc: 51.13, Trg Train Acc: 33.31, Src Test Acc: 51.36, Trg Test Acc: 42.79, Server Test Acc: 33.04, Office Test Acc: 32.81, Conf Test Acc: 38.67
# Epoch: 010, TotalL: 13.6369, CrossE: 1.2628, CondE: 1.5866, disc: 0.0000, domain: 1.2189, Src VAT: 1.5514, Trg VAT: 1.5866, Src MixUp: 1.7419, Trg MixUp: 1.7621, Src Train Acc: 57.38, Trg Train Acc: 34.83, Src Test Acc: 53.70, Trg Test Acc: 46.30, Server Test Acc: 33.48, Office Test Acc: 34.82, Conf Test Acc: 42.89
# Epoch: 011, TotalL: 13.2166, CrossE: 1.1561, CondE: 1.5127, disc: 0.0000, domain: 1.2070, Src VAT: 1.4692, Trg VAT: 1.5127, Src MixUp: 1.6844, Trg MixUp: 1.7008, Src Train Acc: 61.24, Trg Train Acc: 37.20, Src Test Acc: 51.36, Trg Test Acc: 43.46, Server Test Acc: 35.71, Office Test Acc: 35.15, Conf Test Acc: 43.78
# Epoch: 012, TotalL: 12.7872, CrossE: 1.0553, CondE: 1.4361, disc: 0.0000, domain: 1.1855, Src VAT: 1.3730, Trg VAT: 1.4361, Src MixUp: 1.6051, Trg MixUp: 1.6497, Src Train Acc: 64.71, Trg Train Acc: 39.74, Src Test Acc: 54.47, Trg Test Acc: 47.56, Server Test Acc: 38.39, Office Test Acc: 35.04, Conf Test Acc: 43.78
# Epoch: 013, TotalL: 12.3847, CrossE: 0.9560, CondE: 1.3666, disc: 0.0000, domain: 1.1795, Src VAT: 1.2877, Trg VAT: 1.3666, Src MixUp: 1.5439, Trg MixUp: 1.5952, Src Train Acc: 68.45, Trg Train Acc: 42.12, Src Test Acc: 64.98, Trg Test Acc: 54.23, Server Test Acc: 38.17, Office Test Acc: 37.82, Conf Test Acc: 45.11
# Epoch: 014, TotalL: 11.9979, CrossE: 0.8616, CondE: 1.2993, disc: 0.0000, domain: 1.1666, Src VAT: 1.2011, Trg VAT: 1.2993, Src MixUp: 1.4716, Trg MixUp: 1.5477, Src Train Acc: 72.83, Trg Train Acc: 43.92, Src Test Acc: 62.26, Trg Test Acc: 49.87, Server Test Acc: 38.84, Office Test Acc: 38.04, Conf Test Acc: 42.67
# Epoch: 015, TotalL: 11.6586, CrossE: 0.7809, CondE: 1.2319, disc: 0.0000, domain: 1.1592, Src VAT: 1.1145, Trg VAT: 1.2319, Src MixUp: 1.4188, Trg MixUp: 1.4890, Src Train Acc: 75.13, Trg Train Acc: 44.97, Src Test Acc: 68.87, Trg Test Acc: 60.11, Server Test Acc: 41.29, Office Test Acc: 41.60, Conf Test Acc: 45.11
# Epoch: 016, TotalL: 11.3015, CrossE: 0.6967, CondE: 1.1729, disc: 0.0000, domain: 1.1502, Src VAT: 1.0307, Trg VAT: 1.1729, Src MixUp: 1.3485, Trg MixUp: 1.4443, Src Train Acc: 78.26, Trg Train Acc: 46.83, Src Test Acc: 71.21, Trg Test Acc: 59.84, Server Test Acc: 42.41, Office Test Acc: 41.16, Conf Test Acc: 49.33
# Epoch: 017, TotalL: 10.9178, CrossE: 0.6028, CondE: 1.1235, disc: 0.0000, domain: 1.1441, Src VAT: 0.9471, Trg VAT: 1.1235, Src MixUp: 1.2919, Trg MixUp: 1.4262, Src Train Acc: 82.25, Trg Train Acc: 49.96, Src Test Acc: 71.21, Trg Test Acc: 56.89, Server Test Acc: 39.51, Office Test Acc: 40.16, Conf Test Acc: 46.00
# Epoch: 018, TotalL: 10.6371, CrossE: 0.5411, CondE: 1.0683, disc: 0.0000, domain: 1.1496, Src VAT: 0.8723, Trg VAT: 1.0683, Src MixUp: 1.2314, Trg MixUp: 1.3756, Src Train Acc: 84.46, Trg Train Acc: 50.54, Src Test Acc: 77.04, Trg Test Acc: 66.19, Server Test Acc: 41.96, Office Test Acc: 42.71, Conf Test Acc: 47.33
# Epoch: 019, TotalL: 10.2970, CrossE: 0.4666, CondE: 1.0222, disc: 0.0000, domain: 1.1427, Src VAT: 0.7888, Trg VAT: 1.0222, Src MixUp: 1.1779, Trg MixUp: 1.3451, Src Train Acc: 86.94, Trg Train Acc: 51.22, Src Test Acc: 68.87, Trg Test Acc: 55.48, Server Test Acc: 39.73, Office Test Acc: 38.93, Conf Test Acc: 47.11
# Epoch: 020, TotalL: 10.0006, CrossE: 0.4033, CondE: 0.9691, disc: 0.0000, domain: 1.1466, Src VAT: 0.7231, Trg VAT: 0.9691, Src MixUp: 1.1185, Trg MixUp: 1.3052, Src Train Acc: 89.32, Trg Train Acc: 54.25, Src Test Acc: 74.32, Trg Test Acc: 63.56, Server Test Acc: 43.30, Office Test Acc: 39.82, Conf Test Acc: 41.56
# Epoch: 021, TotalL: 9.7173, CrossE: 0.3421, CondE: 0.9316, disc: 0.0000, domain: 1.1437, Src VAT: 0.6517, Trg VAT: 0.9316, Src MixUp: 1.0740, Trg MixUp: 1.2743, Src Train Acc: 91.67, Trg Train Acc: 55.27, Src Test Acc: 75.88, Trg Test Acc: 63.47, Server Test Acc: 44.20, Office Test Acc: 45.61, Conf Test Acc: 52.22
# Epoch: 022, TotalL: 9.4656, CrossE: 0.2965, CondE: 0.8897, disc: 0.0000, domain: 1.1434, Src VAT: 0.5911, Trg VAT: 0.8897, Src MixUp: 1.0084, Trg MixUp: 1.2439, Src Train Acc: 92.93, Trg Train Acc: 57.53, Src Test Acc: 83.27, Trg Test Acc: 72.42, Server Test Acc: 47.10, Office Test Acc: 46.27, Conf Test Acc: 55.11
# Epoch: 023, TotalL: 9.2219, CrossE: 0.2465, CondE: 0.8431, disc: 0.0000, domain: 1.1458, Src VAT: 0.5265, Trg VAT: 0.8431, Src MixUp: 0.9718, Trg MixUp: 1.2159, Src Train Acc: 95.18, Trg Train Acc: 58.96, Src Test Acc: 87.55, Trg Test Acc: 74.82, Server Test Acc: 47.10, Office Test Acc: 47.05, Conf Test Acc: 56.22
# Epoch: 024, TotalL: 9.0102, CrossE: 0.2095, CondE: 0.8262, disc: 0.0000, domain: 1.1438, Src VAT: 0.4794, Trg VAT: 0.8262, Src MixUp: 0.9314, Trg MixUp: 1.2119, Src Train Acc: 96.09, Trg Train Acc: 58.90, Src Test Acc: 81.71, Trg Test Acc: 67.59, Server Test Acc: 48.44, Office Test Acc: 51.28, Conf Test Acc: 57.78
# Epoch: 025, TotalL: 8.8369, CrossE: 0.1744, CondE: 0.7987, disc: 0.0000, domain: 1.1484, Src VAT: 0.4282, Trg VAT: 0.7987, Src MixUp: 0.9124, Trg MixUp: 1.2008, Src Train Acc: 97.44, Trg Train Acc: 61.59, Src Test Acc: 81.32, Trg Test Acc: 69.76, Server Test Acc: 43.75, Office Test Acc: 44.83, Conf Test Acc: 50.00
# Epoch: 026, TotalL: 8.6329, CrossE: 0.1426, CondE: 0.7717, disc: 0.0000, domain: 1.1527, Src VAT: 0.3885, Trg VAT: 0.7717, Src MixUp: 0.8497, Trg MixUp: 1.1799, Src Train Acc: 98.22, Trg Train Acc: 62.17, Src Test Acc: 85.99, Trg Test Acc: 74.85, Server Test Acc: 55.58, Office Test Acc: 52.17, Conf Test Acc: 63.56
# Epoch: 027, TotalL: 8.4969, CrossE: 0.1214, CondE: 0.7423, disc: 0.0000, domain: 1.1591, Src VAT: 0.3467, Trg VAT: 0.7423, Src MixUp: 0.8372, Trg MixUp: 1.1520, Src Train Acc: 98.74, Trg Train Acc: 62.87, Src Test Acc: 87.94, Trg Test Acc: 74.50, Server Test Acc: 56.70, Office Test Acc: 56.17, Conf Test Acc: 63.33
# Epoch: 028, TotalL: 8.3699, CrossE: 0.1036, CondE: 0.7165, disc: 0.0000, domain: 1.1604, Src VAT: 0.3137, Trg VAT: 0.7165, Src MixUp: 0.7956, Trg MixUp: 1.1136, Src Train Acc: 98.74, Trg Train Acc: 64.24, Src Test Acc: 90.27, Trg Test Acc: 79.32, Server Test Acc: 55.36, Office Test Acc: 56.84, Conf Test Acc: 64.67
# Epoch: 029, TotalL: 8.2374, CrossE: 0.0902, CondE: 0.7033, disc: 0.0000, domain: 1.1604, Src VAT: 0.2902, Trg VAT: 0.7033, Src MixUp: 0.7595, Trg MixUp: 1.1240, Src Train Acc: 99.22, Trg Train Acc: 64.93, Src Test Acc: 92.22, Trg Test Acc: 82.48, Server Test Acc: 58.48, Office Test Acc: 53.50, Conf Test Acc: 64.22
# Epoch: 030, TotalL: 8.1466, CrossE: 0.0739, CondE: 0.6767, disc: 0.0000, domain: 1.1622, Src VAT: 0.2580, Trg VAT: 0.6767, Src MixUp: 0.7472, Trg MixUp: 1.1040, Src Train Acc: 99.52, Trg Train Acc: 66.32, Src Test Acc: 87.16, Trg Test Acc: 74.90, Server Test Acc: 53.57, Office Test Acc: 54.17, Conf Test Acc: 63.78
# Epoch: 031, TotalL: 8.1007, CrossE: 0.0744, CondE: 0.6654, disc: 0.0000, domain: 1.1681, Src VAT: 0.2507, Trg VAT: 0.6654, Src MixUp: 0.7173, Trg MixUp: 1.1046, Src Train Acc: 99.18, Trg Train Acc: 66.56, Src Test Acc: 91.83, Trg Test Acc: 78.21, Server Test Acc: 54.69, Office Test Acc: 53.50, Conf Test Acc: 61.33
# Epoch: 032, TotalL: 8.0016, CrossE: 0.0629, CondE: 0.6491, disc: 0.0000, domain: 1.1598, Src VAT: 0.2198, Trg VAT: 0.6491, Src MixUp: 0.7104, Trg MixUp: 1.0834, Src Train Acc: 99.44, Trg Train Acc: 66.58, Src Test Acc: 89.88, Trg Test Acc: 79.64, Server Test Acc: 55.13, Office Test Acc: 55.39, Conf Test Acc: 62.89
# Epoch: 033, TotalL: 7.9560, CrossE: 0.0565, CondE: 0.6432, disc: 0.0000, domain: 1.1635, Src VAT: 0.2176, Trg VAT: 0.6432, Src MixUp: 0.6854, Trg MixUp: 1.0699, Src Train Acc: 99.74, Trg Train Acc: 67.84, Src Test Acc: 92.61, Trg Test Acc: 83.91, Server Test Acc: 56.92, Office Test Acc: 61.07, Conf Test Acc: 66.22
# Epoch: 034, TotalL: 7.8546, CrossE: 0.0488, CondE: 0.6374, disc: 0.0000, domain: 1.1501, Src VAT: 0.1962, Trg VAT: 0.6374, Src MixUp: 0.6564, Trg MixUp: 1.0716, Src Train Acc: 99.74, Trg Train Acc: 69.21, Src Test Acc: 89.88, Trg Test Acc: 75.55, Server Test Acc: 55.58, Office Test Acc: 55.51, Conf Test Acc: 63.78
# Epoch: 035, TotalL: 7.9097, CrossE: 0.0526, CondE: 0.6215, disc: 0.0000, domain: 1.1586, Src VAT: 0.1959, Trg VAT: 0.6215, Src MixUp: 0.6817, Trg MixUp: 1.0745, Src Train Acc: 99.70, Trg Train Acc: 67.93, Src Test Acc: 89.88, Trg Test Acc: 82.16, Server Test Acc: 55.58, Office Test Acc: 62.63, Conf Test Acc: 64.22
# Epoch: 036, TotalL: 7.7511, CrossE: 0.0383, CondE: 0.6061, disc: 0.0000, domain: 1.1354, Src VAT: 0.1683, Trg VAT: 0.6061, Src MixUp: 0.6289, Trg MixUp: 1.0472, Src Train Acc: 100.00, Trg Train Acc: 69.90, Src Test Acc: 90.27, Trg Test Acc: 80.26, Server Test Acc: 58.26, Office Test Acc: 60.40, Conf Test Acc: 66.44
# Epoch: 037, TotalL: 7.7156, CrossE: 0.0355, CondE: 0.6005, disc: 0.0000, domain: 1.1288, Src VAT: 0.1588, Trg VAT: 0.6005, Src MixUp: 0.6257, Trg MixUp: 1.0514, Src Train Acc: 100.00, Trg Train Acc: 71.77, Src Test Acc: 94.94, Trg Test Acc: 83.62, Server Test Acc: 60.71, Office Test Acc: 58.62, Conf Test Acc: 68.67
# Epoch: 038, TotalL: 7.7018, CrossE: 0.0349, CondE: 0.5817, disc: 0.0000, domain: 1.1426, Src VAT: 0.1541, Trg VAT: 0.5817, Src MixUp: 0.6092, Trg MixUp: 1.0328, Src Train Acc: 100.00, Trg Train Acc: 70.18, Src Test Acc: 93.77, Trg Test Acc: 83.30, Server Test Acc: 63.17, Office Test Acc: 59.96, Conf Test Acc: 69.56
# Epoch: 039, TotalL: 7.6500, CrossE: 0.0324, CondE: 0.5637, disc: 0.0000, domain: 1.1462, Src VAT: 0.1397, Trg VAT: 0.5637, Src MixUp: 0.5841, Trg MixUp: 1.0173, Src Train Acc: 99.74, Trg Train Acc: 70.94, Src Test Acc: 92.61, Trg Test Acc: 81.25, Server Test Acc: 62.05, Office Test Acc: 60.29, Conf Test Acc: 68.22
# Epoch: 040, TotalL: 7.5834, CrossE: 0.0274, CondE: 0.5587, disc: 0.0000, domain: 1.1255, Src VAT: 0.1273, Trg VAT: 0.5587, Src MixUp: 0.5758, Trg MixUp: 1.0244, Src Train Acc: 99.91, Trg Train Acc: 72.35, Src Test Acc: 90.27, Trg Test Acc: 72.74, Server Test Acc: 50.00, Office Test Acc: 52.73, Conf Test Acc: 59.56
# Epoch: 041, TotalL: 7.5498, CrossE: 0.0255, CondE: 0.5431, disc: 0.0000, domain: 1.1388, Src VAT: 0.1198, Trg VAT: 0.5431, Src MixUp: 0.5475, Trg MixUp: 0.9948, Src Train Acc: 99.96, Trg Train Acc: 72.42, Src Test Acc: 94.16, Trg Test Acc: 86.52, Server Test Acc: 61.83, Office Test Acc: 59.73, Conf Test Acc: 69.78
# Epoch: 042, TotalL: 7.4945, CrossE: 0.0222, CondE: 0.5418, disc: 0.0000, domain: 1.1244, Src VAT: 0.1103, Trg VAT: 0.5418, Src MixUp: 0.5320, Trg MixUp: 0.9977, Src Train Acc: 99.96, Trg Train Acc: 72.16, Src Test Acc: 92.22, Trg Test Acc: 83.30, Server Test Acc: 57.59, Office Test Acc: 53.62, Conf Test Acc: 66.00
# Epoch: 043, TotalL: 7.5996, CrossE: 0.0319, CondE: 0.5273, disc: 0.0000, domain: 1.1614, Src VAT: 0.1255, Trg VAT: 0.5273, Src MixUp: 0.5521, Trg MixUp: 0.9853, Src Train Acc: 99.78, Trg Train Acc: 72.66, Src Test Acc: 93.77, Trg Test Acc: 82.57, Server Test Acc: 60.04, Office Test Acc: 60.96, Conf Test Acc: 67.11
# Epoch: 044, TotalL: 7.4707, CrossE: 0.0208, CondE: 0.5210, disc: 0.0000, domain: 1.1225, Src VAT: 0.1030, Trg VAT: 0.5210, Src MixUp: 0.5351, Trg MixUp: 0.9618, Src Train Acc: 100.00, Trg Train Acc: 73.89, Src Test Acc: 93.77, Trg Test Acc: 85.76, Server Test Acc: 63.62, Office Test Acc: 64.07, Conf Test Acc: 70.67
# Epoch: 045, TotalL: 7.4248, CrossE: 0.0179, CondE: 0.5155, disc: 0.0000, domain: 1.1243, Src VAT: 0.0949, Trg VAT: 0.5155, Src MixUp: 0.5062, Trg MixUp: 0.9647, Src Train Acc: 100.00, Trg Train Acc: 75.09, Src Test Acc: 93.00, Trg Test Acc: 82.77, Server Test Acc: 63.62, Office Test Acc: 64.40, Conf Test Acc: 68.44
# Epoch: 046, TotalL: 7.4357, CrossE: 0.0182, CondE: 0.4959, disc: 0.0000, domain: 1.1322, Src VAT: 0.0944, Trg VAT: 0.4959, Src MixUp: 0.5161, Trg MixUp: 0.9516, Src Train Acc: 100.00, Trg Train Acc: 75.56, Src Test Acc: 94.94, Trg Test Acc: 88.42, Server Test Acc: 63.17, Office Test Acc: 60.51, Conf Test Acc: 71.33
# Epoch: 047, TotalL: 7.4001, CrossE: 0.0162, CondE: 0.4974, disc: 0.0000, domain: 1.1156, Src VAT: 0.0877, Trg VAT: 0.4974, Src MixUp: 0.5162, Trg MixUp: 0.9454, Src Train Acc: 100.00, Trg Train Acc: 74.91, Src Test Acc: 94.55, Trg Test Acc: 86.72, Server Test Acc: 61.38, Office Test Acc: 64.29, Conf Test Acc: 69.11
# Epoch: 048, TotalL: 7.4533, CrossE: 0.0200, CondE: 0.4925, disc: 0.0000, domain: 1.1473, Src VAT: 0.0959, Trg VAT: 0.4925, Src MixUp: 0.5192, Trg MixUp: 0.9382, Src Train Acc: 99.87, Trg Train Acc: 74.85, Src Test Acc: 95.72, Trg Test Acc: 87.13, Server Test Acc: 62.72, Office Test Acc: 61.85, Conf Test Acc: 70.00
# Epoch: 049, TotalL: 7.3384, CrossE: 0.0144, CondE: 0.4751, disc: 0.0000, domain: 1.1236, Src VAT: 0.0794, Trg VAT: 0.4751, Src MixUp: 0.4688, Trg MixUp: 0.9258, Src Train Acc: 100.00, Trg Train Acc: 74.93, Src Test Acc: 94.55, Trg Test Acc: 86.87, Server Test Acc: 63.17, Office Test Acc: 54.73, Conf Test Acc: 74.00
# Epoch: 050, TotalL: 7.3457, CrossE: 0.0143, CondE: 0.4648, disc: 0.0000, domain: 1.1378, Src VAT: 0.0772, Trg VAT: 0.4648, Src MixUp: 0.4824, Trg MixUp: 0.9191, Src Train Acc: 100.00, Trg Train Acc: 75.78, Src Test Acc: 92.22, Trg Test Acc: 80.20, Server Test Acc: 58.93, Office Test Acc: 57.62, Conf Test Acc: 66.22
# Epoch: 051, TotalL: 7.3382, CrossE: 0.0139, CondE: 0.4548, disc: 0.0000, domain: 1.1335, Src VAT: 0.0760, Trg VAT: 0.4548, Src MixUp: 0.4790, Trg MixUp: 0.9099, Src Train Acc: 100.00, Trg Train Acc: 76.32, Src Test Acc: 93.77, Trg Test Acc: 87.54, Server Test Acc: 61.16, Office Test Acc: 64.85, Conf Test Acc: 72.67
# Epoch: 052, TotalL: 7.3048, CrossE: 0.0121, CondE: 0.4531, disc: 0.0000, domain: 1.1230, Src VAT: 0.0701, Trg VAT: 0.4531, Src MixUp: 0.4732, Trg MixUp: 0.9137, Src Train Acc: 100.00, Trg Train Acc: 77.52, Src Test Acc: 93.77, Trg Test Acc: 84.32, Server Test Acc: 62.05, Office Test Acc: 63.63, Conf Test Acc: 71.33
# Epoch: 053, TotalL: 7.3366, CrossE: 0.0164, CondE: 0.4431, disc: 0.0000, domain: 1.1406, Src VAT: 0.0754, Trg VAT: 0.4431, Src MixUp: 0.4615, Trg MixUp: 0.8998, Src Train Acc: 99.91, Trg Train Acc: 77.43, Src Test Acc: 86.77, Trg Test Acc: 71.13, Server Test Acc: 54.69, Office Test Acc: 60.29, Conf Test Acc: 64.22
# Epoch: 054, TotalL: 7.3069, CrossE: 0.0125, CondE: 0.4360, disc: 0.0000, domain: 1.1373, Src VAT: 0.0693, Trg VAT: 0.4360, Src MixUp: 0.4663, Trg MixUp: 0.8935, Src Train Acc: 100.00, Trg Train Acc: 78.17, Src Test Acc: 96.11, Trg Test Acc: 87.04, Server Test Acc: 61.16, Office Test Acc: 65.29, Conf Test Acc: 70.44
# Epoch: 055, TotalL: 7.2404, CrossE: 0.0108, CondE: 0.4340, disc: 0.0000, domain: 1.1127, Src VAT: 0.0618, Trg VAT: 0.4340, Src MixUp: 0.4426, Trg MixUp: 0.8919, Src Train Acc: 100.00, Trg Train Acc: 78.08, Src Test Acc: 94.16, Trg Test Acc: 87.13, Server Test Acc: 60.71, Office Test Acc: 63.74, Conf Test Acc: 71.11
# Epoch: 056, TotalL: 7.2540, CrossE: 0.0108, CondE: 0.4214, disc: 0.0000, domain: 1.1304, Src VAT: 0.0630, Trg VAT: 0.4214, Src MixUp: 0.4470, Trg MixUp: 0.8776, Src Train Acc: 100.00, Trg Train Acc: 78.49, Src Test Acc: 94.55, Trg Test Acc: 86.81, Server Test Acc: 62.95, Office Test Acc: 64.96, Conf Test Acc: 71.78
# Epoch: 057, TotalL: 7.3041, CrossE: 0.0183, CondE: 0.4207, disc: 0.0000, domain: 1.1532, Src VAT: 0.0699, Trg VAT: 0.4207, Src MixUp: 0.4264, Trg MixUp: 0.8908, Src Train Acc: 99.74, Trg Train Acc: 78.52, Src Test Acc: 91.05, Trg Test Acc: 79.47, Server Test Acc: 64.51, Office Test Acc: 57.29, Conf Test Acc: 68.22
# Epoch: 058, TotalL: 7.2218, CrossE: 0.0100, CondE: 0.4105, disc: 0.0000, domain: 1.1300, Src VAT: 0.0577, Trg VAT: 0.4105, Src MixUp: 0.4263, Trg MixUp: 0.8702, Src Train Acc: 100.00, Trg Train Acc: 79.17, Src Test Acc: 95.33, Trg Test Acc: 87.60, Server Test Acc: 64.51, Office Test Acc: 65.96, Conf Test Acc: 72.22
# Epoch: 059, TotalL: 7.1857, CrossE: 0.0107, CondE: 0.4062, disc: 0.0000, domain: 1.1234, Src VAT: 0.0555, Trg VAT: 0.4062, Src MixUp: 0.4100, Trg MixUp: 0.8652, Src Train Acc: 99.91, Trg Train Acc: 80.01, Src Test Acc: 95.33, Trg Test Acc: 84.44, Server Test Acc: 63.17, Office Test Acc: 64.63, Conf Test Acc: 70.44
# Epoch: 060, TotalL: 7.1808, CrossE: 0.0079, CondE: 0.4004, disc: 0.0000, domain: 1.1253, Src VAT: 0.0494, Trg VAT: 0.4004, Src MixUp: 0.4142, Trg MixUp: 0.8584, Src Train Acc: 100.00, Trg Train Acc: 80.03, Src Test Acc: 94.94, Trg Test Acc: 89.91, Server Test Acc: 67.19, Office Test Acc: 67.96, Conf Test Acc: 76.89
# Epoch: 061, TotalL: 7.1643, CrossE: 0.0074, CondE: 0.3927, disc: 0.0000, domain: 1.1315, Src VAT: 0.0467, Trg VAT: 0.3927, Src MixUp: 0.4091, Trg MixUp: 0.8577, Src Train Acc: 100.00, Trg Train Acc: 79.82, Src Test Acc: 96.11, Trg Test Acc: 87.63, Server Test Acc: 72.10, Office Test Acc: 67.52, Conf Test Acc: 77.56
# Epoch: 062, TotalL: 7.1413, CrossE: 0.0077, CondE: 0.3902, disc: 0.0000, domain: 1.1204, Src VAT: 0.0479, Trg VAT: 0.3902, Src MixUp: 0.3987, Trg MixUp: 0.8417, Src Train Acc: 100.00, Trg Train Acc: 80.47, Src Test Acc: 95.33, Trg Test Acc: 85.49, Server Test Acc: 65.18, Office Test Acc: 59.07, Conf Test Acc: 73.78
# Epoch: 063, TotalL: 7.2367, CrossE: 0.0114, CondE: 0.3890, disc: 0.0000, domain: 1.1614, Src VAT: 0.0555, Trg VAT: 0.3890, Src MixUp: 0.4176, Trg MixUp: 0.8373, Src Train Acc: 99.91, Trg Train Acc: 79.01, Src Test Acc: 93.00, Trg Test Acc: 84.15, Server Test Acc: 60.04, Office Test Acc: 59.84, Conf Test Acc: 70.44
# Epoch: 064, TotalL: 7.1398, CrossE: 0.0075, CondE: 0.3681, disc: 0.0000, domain: 1.1311, Src VAT: 0.0451, Trg VAT: 0.3681, Src MixUp: 0.3932, Trg MixUp: 0.8331, Src Train Acc: 100.00, Trg Train Acc: 81.53, Src Test Acc: 95.33, Trg Test Acc: 88.91, Server Test Acc: 68.97, Office Test Acc: 67.74, Conf Test Acc: 75.78
# Epoch: 065, TotalL: 7.1610, CrossE: 0.0077, CondE: 0.3688, disc: 0.0000, domain: 1.1501, Src VAT: 0.0464, Trg VAT: 0.3688, Src MixUp: 0.3998, Trg MixUp: 0.8148, Src Train Acc: 100.00, Trg Train Acc: 81.10, Src Test Acc: 96.50, Trg Test Acc: 87.95, Server Test Acc: 66.07, Office Test Acc: 66.96, Conf Test Acc: 75.11
# Epoch: 066, TotalL: 7.1256, CrossE: 0.0064, CondE: 0.3617, disc: 0.0000, domain: 1.1341, Src VAT: 0.0408, Trg VAT: 0.3617, Src MixUp: 0.3884, Trg MixUp: 0.8217, Src Train Acc: 100.00, Trg Train Acc: 81.38, Src Test Acc: 92.61, Trg Test Acc: 82.51, Server Test Acc: 66.96, Office Test Acc: 70.30, Conf Test Acc: 73.33
# Epoch: 067, TotalL: 7.1556, CrossE: 0.0083, CondE: 0.3583, disc: 0.0000, domain: 1.1530, Src VAT: 0.0458, Trg VAT: 0.3583, Src MixUp: 0.3900, Trg MixUp: 0.8170, Src Train Acc: 100.00, Trg Train Acc: 82.05, Src Test Acc: 95.33, Trg Test Acc: 86.17, Server Test Acc: 54.91, Office Test Acc: 63.18, Conf Test Acc: 69.11
# Epoch: 068, TotalL: 7.0672, CrossE: 0.0055, CondE: 0.3486, disc: 0.0000, domain: 1.1262, Src VAT: 0.0363, Trg VAT: 0.3486, Src MixUp: 0.3573, Trg MixUp: 0.7956, Src Train Acc: 100.00, Trg Train Acc: 82.90, Src Test Acc: 96.89, Trg Test Acc: 89.76, Server Test Acc: 71.65, Office Test Acc: 67.74, Conf Test Acc: 76.00
# Epoch: 069, TotalL: 7.6590, CrossE: 0.1967, CondE: 0.3519, disc: 0.0000, domain: 1.2065, Src VAT: 0.0629, Trg VAT: 0.3519, Src MixUp: 0.3840, Trg MixUp: 0.7811, Src Train Acc: 96.61, Trg Train Acc: 79.84, Src Test Acc: 84.82, Trg Test Acc: 69.61, Server Test Acc: 56.47, Office Test Acc: 53.95, Conf Test Acc: 60.44
# Epoch: 070, TotalL: 7.2783, CrossE: 0.0169, CondE: 0.3484, disc: 0.0000, domain: 1.1673, Src VAT: 0.0624, Trg VAT: 0.3484, Src MixUp: 0.4191, Trg MixUp: 0.7973, Src Train Acc: 99.83, Trg Train Acc: 80.21, Src Test Acc: 96.50, Trg Test Acc: 90.76, Server Test Acc: 66.52, Office Test Acc: 67.19, Conf Test Acc: 77.11
# Epoch: 071, TotalL: 7.0765, CrossE: 0.0057, CondE: 0.3412, disc: 0.0000, domain: 1.0999, Src VAT: 0.0381, Trg VAT: 0.3412, Src MixUp: 0.3760, Trg MixUp: 0.7925, Src Train Acc: 100.00, Trg Train Acc: 82.81, Src Test Acc: 96.89, Trg Test Acc: 91.31, Server Test Acc: 65.40, Office Test Acc: 64.40, Conf Test Acc: 78.00
# Epoch: 072, TotalL: 7.0517, CrossE: 0.0056, CondE: 0.3387, disc: 0.0000, domain: 1.1088, Src VAT: 0.0379, Trg VAT: 0.3387, Src MixUp: 0.3631, Trg MixUp: 0.7840, Src Train Acc: 100.00, Trg Train Acc: 83.25, Src Test Acc: 96.89, Trg Test Acc: 88.89, Server Test Acc: 67.63, Office Test Acc: 60.96, Conf Test Acc: 72.44
# Epoch: 073, TotalL: 7.0515, CrossE: 0.0054, CondE: 0.3395, disc: 0.0000, domain: 1.1088, Src VAT: 0.0367, Trg VAT: 0.3395, Src MixUp: 0.3685, Trg MixUp: 0.7885, Src Train Acc: 100.00, Trg Train Acc: 83.90, Src Test Acc: 96.89, Trg Test Acc: 90.99, Server Test Acc: 68.75, Office Test Acc: 65.18, Conf Test Acc: 75.56
# Epoch: 074, TotalL: 7.0448, CrossE: 0.0049, CondE: 0.3304, disc: 0.0000, domain: 1.1182, Src VAT: 0.0347, Trg VAT: 0.3304, Src MixUp: 0.3676, Trg MixUp: 0.7833, Src Train Acc: 100.00, Trg Train Acc: 84.57, Src Test Acc: 95.33, Trg Test Acc: 89.50, Server Test Acc: 71.43, Office Test Acc: 70.86, Conf Test Acc: 77.56
# Epoch: 075, TotalL: 7.0248, CrossE: 0.0050, CondE: 0.3237, disc: 0.0000, domain: 1.1304, Src VAT: 0.0347, Trg VAT: 0.3237, Src MixUp: 0.3432, Trg MixUp: 0.7774, Src Train Acc: 100.00, Trg Train Acc: 84.42, Src Test Acc: 95.72, Trg Test Acc: 89.30, Server Test Acc: 71.65, Office Test Acc: 68.08, Conf Test Acc: 74.00
# Epoch: 076, TotalL: 7.0588, CrossE: 0.0054, CondE: 0.3258, disc: 0.0000, domain: 1.1477, Src VAT: 0.0361, Trg VAT: 0.3258, Src MixUp: 0.3596, Trg MixUp: 0.7781, Src Train Acc: 100.00, Trg Train Acc: 84.72, Src Test Acc: 94.94, Trg Test Acc: 88.53, Server Test Acc: 67.86, Office Test Acc: 72.53, Conf Test Acc: 75.78
# Epoch: 077, TotalL: 7.0927, CrossE: 0.0059, CondE: 0.3243, disc: 0.0000, domain: 1.1608, Src VAT: 0.0379, Trg VAT: 0.3243, Src MixUp: 0.3795, Trg MixUp: 0.7922, Src Train Acc: 100.00, Trg Train Acc: 84.83, Src Test Acc: 96.50, Trg Test Acc: 86.98, Server Test Acc: 70.98, Office Test Acc: 69.30, Conf Test Acc: 78.22
# Epoch: 078, TotalL: 7.0504, CrossE: 0.0052, CondE: 0.3158, disc: 0.0000, domain: 1.1451, Src VAT: 0.0342, Trg VAT: 0.3158, Src MixUp: 0.3655, Trg MixUp: 0.7523, Src Train Acc: 100.00, Trg Train Acc: 85.03, Src Test Acc: 95.33, Trg Test Acc: 88.77, Server Test Acc: 69.42, Office Test Acc: 71.86, Conf Test Acc: 77.11
# Epoch: 079, TotalL: 7.0162, CrossE: 0.0045, CondE: 0.3038, disc: 0.0000, domain: 1.1446, Src VAT: 0.0305, Trg VAT: 0.3038, Src MixUp: 0.3399, Trg MixUp: 0.7672, Src Train Acc: 100.00, Trg Train Acc: 84.94, Src Test Acc: 95.33, Trg Test Acc: 89.70, Server Test Acc: 61.83, Office Test Acc: 66.30, Conf Test Acc: 73.33
# Epoch: 080, TotalL: 7.4981, CrossE: 0.1145, CondE: 0.3213, disc: 0.0000, domain: 1.2303, Src VAT: 0.0676, Trg VAT: 0.3213, Src MixUp: 0.3857, Trg MixUp: 0.7608, Src Train Acc: 97.44, Trg Train Acc: 81.34, Src Test Acc: 93.77, Trg Test Acc: 84.32, Server Test Acc: 59.15, Office Test Acc: 66.30, Conf Test Acc: 70.89
# Epoch: 081, TotalL: 7.0752, CrossE: 0.0071, CondE: 0.2880, disc: 0.0000, domain: 1.1450, Src VAT: 0.0384, Trg VAT: 0.2880, Src MixUp: 0.3486, Trg MixUp: 0.7380, Src Train Acc: 100.00, Trg Train Acc: 84.96, Src Test Acc: 96.89, Trg Test Acc: 90.96, Server Test Acc: 70.09, Office Test Acc: 68.63, Conf Test Acc: 75.56
# Epoch: 082, TotalL: 6.9872, CrossE: 0.0040, CondE: 0.2805, disc: 0.0000, domain: 1.1181, Src VAT: 0.0277, Trg VAT: 0.2805, Src MixUp: 0.3270, Trg MixUp: 0.7259, Src Train Acc: 100.00, Trg Train Acc: 86.11, Src Test Acc: 97.28, Trg Test Acc: 91.02, Server Test Acc: 72.77, Office Test Acc: 69.30, Conf Test Acc: 76.67
# Epoch: 083, TotalL: 7.0019, CrossE: 0.0040, CondE: 0.2863, disc: 0.0000, domain: 1.1306, Src VAT: 0.0281, Trg VAT: 0.2863, Src MixUp: 0.3441, Trg MixUp: 0.7299, Src Train Acc: 100.00, Trg Train Acc: 86.81, Src Test Acc: 96.50, Trg Test Acc: 88.62, Server Test Acc: 73.66, Office Test Acc: 73.53, Conf Test Acc: 78.89
# Epoch: 084, TotalL: 6.9811, CrossE: 0.0038, CondE: 0.2825, disc: 0.0000, domain: 1.1293, Src VAT: 0.0275, Trg VAT: 0.2825, Src MixUp: 0.3321, Trg MixUp: 0.7346, Src Train Acc: 100.00, Trg Train Acc: 86.59, Src Test Acc: 96.89, Trg Test Acc: 91.11, Server Test Acc: 73.66, Office Test Acc: 70.41, Conf Test Acc: 77.78
# Epoch: 085, TotalL: 6.9752, CrossE: 0.0037, CondE: 0.2808, disc: 0.0000, domain: 1.1381, Src VAT: 0.0270, Trg VAT: 0.2808, Src MixUp: 0.3295, Trg MixUp: 0.7311, Src Train Acc: 100.00, Trg Train Acc: 87.07, Src Test Acc: 97.28, Trg Test Acc: 91.40, Server Test Acc: 70.98, Office Test Acc: 70.52, Conf Test Acc: 78.00
# Epoch: 086, TotalL: 7.0046, CrossE: 0.0044, CondE: 0.2755, disc: 0.0000, domain: 1.1587, Src VAT: 0.0287, Trg VAT: 0.2755, Src MixUp: 0.3285, Trg MixUp: 0.7157, Src Train Acc: 100.00, Trg Train Acc: 85.98, Src Test Acc: 96.50, Trg Test Acc: 90.47, Server Test Acc: 69.64, Office Test Acc: 69.63, Conf Test Acc: 79.56
# Epoch: 087, TotalL: 6.9741, CrossE: 0.0034, CondE: 0.2733, disc: 0.0000, domain: 1.1460, Src VAT: 0.0247, Trg VAT: 0.2733, Src MixUp: 0.3272, Trg MixUp: 0.7044, Src Train Acc: 100.00, Trg Train Acc: 86.48, Src Test Acc: 96.50, Trg Test Acc: 90.67, Server Test Acc: 69.20, Office Test Acc: 69.97, Conf Test Acc: 78.44
# Epoch: 088, TotalL: 7.0009, CrossE: 0.0040, CondE: 0.2716, disc: 0.0000, domain: 1.1594, Src VAT: 0.0274, Trg VAT: 0.2716, Src MixUp: 0.3363, Trg MixUp: 0.7263, Src Train Acc: 100.00, Trg Train Acc: 85.37, Src Test Acc: 95.72, Trg Test Acc: 90.79, Server Test Acc: 65.40, Office Test Acc: 65.63, Conf Test Acc: 77.56
# Epoch: 089, TotalL: 7.0239, CrossE: 0.0052, CondE: 0.2689, disc: 0.0000, domain: 1.1774, Src VAT: 0.0302, Trg VAT: 0.2689, Src MixUp: 0.3359, Trg MixUp: 0.7060, Src Train Acc: 100.00, Trg Train Acc: 85.68, Src Test Acc: 94.94, Trg Test Acc: 87.74, Server Test Acc: 64.51, Office Test Acc: 59.51, Conf Test Acc: 73.11
# Epoch: 090, TotalL: 7.0072, CrossE: 0.0040, CondE: 0.2662, disc: 0.0000, domain: 1.1761, Src VAT: 0.0271, Trg VAT: 0.2662, Src MixUp: 0.3380, Trg MixUp: 0.7104, Src Train Acc: 100.00, Trg Train Acc: 85.92, Src Test Acc: 97.67, Trg Test Acc: 91.78, Server Test Acc: 70.31, Office Test Acc: 68.41, Conf Test Acc: 79.33
# Epoch: 091, TotalL: 7.0623, CrossE: 0.0141, CondE: 0.2653, disc: 0.0000, domain: 1.1966, Src VAT: 0.0340, Trg VAT: 0.2653, Src MixUp: 0.3294, Trg MixUp: 0.7074, Src Train Acc: 99.70, Trg Train Acc: 86.52, Src Test Acc: 95.72, Trg Test Acc: 91.08, Server Test Acc: 73.44, Office Test Acc: 68.63, Conf Test Acc: 77.56
# Epoch: 092, TotalL: 6.9973, CrossE: 0.0039, CondE: 0.2608, disc: 0.0000, domain: 1.1734, Src VAT: 0.0252, Trg VAT: 0.2608, Src MixUp: 0.3195, Trg MixUp: 0.7108, Src Train Acc: 100.00, Trg Train Acc: 86.94, Src Test Acc: 96.50, Trg Test Acc: 90.17, Server Test Acc: 64.51, Office Test Acc: 62.74, Conf Test Acc: 70.67
# Epoch: 093, TotalL: 6.9548, CrossE: 0.0035, CondE: 0.2530, disc: 0.0000, domain: 1.1557, Src VAT: 0.0229, Trg VAT: 0.2530, Src MixUp: 0.3025, Trg MixUp: 0.6957, Src Train Acc: 100.00, Trg Train Acc: 87.02, Src Test Acc: 97.28, Trg Test Acc: 89.70, Server Test Acc: 68.97, Office Test Acc: 77.42, Conf Test Acc: 78.89
# Epoch: 094, TotalL: 6.9394, CrossE: 0.0030, CondE: 0.2394, disc: 0.0000, domain: 1.1577, Src VAT: 0.0208, Trg VAT: 0.2394, Src MixUp: 0.3005, Trg MixUp: 0.6824, Src Train Acc: 100.00, Trg Train Acc: 87.78, Src Test Acc: 97.67, Trg Test Acc: 92.16, Server Test Acc: 66.07, Office Test Acc: 68.63, Conf Test Acc: 76.00
# Epoch: 095, TotalL: 6.9330, CrossE: 0.0028, CondE: 0.2431, disc: 0.0000, domain: 1.1586, Src VAT: 0.0209, Trg VAT: 0.2431, Src MixUp: 0.3057, Trg MixUp: 0.6902, Src Train Acc: 100.00, Trg Train Acc: 88.39, Src Test Acc: 95.72, Trg Test Acc: 91.87, Server Test Acc: 77.01, Office Test Acc: 75.53, Conf Test Acc: 79.78
# Epoch: 096, TotalL: 7.2011, CrossE: 0.0255, CondE: 0.2590, disc: 0.0000, domain: 1.2434, Src VAT: 0.0467, Trg VAT: 0.2590, Src MixUp: 0.3730, Trg MixUp: 0.7130, Src Train Acc: 99.31, Trg Train Acc: 85.39, Src Test Acc: 97.28, Trg Test Acc: 91.87, Server Test Acc: 72.32, Office Test Acc: 70.63, Conf Test Acc: 80.00
# Epoch: 097, TotalL: 6.9231, CrossE: 0.0025, CondE: 0.2300, disc: 0.0000, domain: 1.1455, Src VAT: 0.0189, Trg VAT: 0.2300, Src MixUp: 0.2953, Trg MixUp: 0.6631, Src Train Acc: 100.00, Trg Train Acc: 88.43, Src Test Acc: 98.05, Trg Test Acc: 92.19, Server Test Acc: 72.32, Office Test Acc: 70.63, Conf Test Acc: 79.33
# Epoch: 098, TotalL: 6.9079, CrossE: 0.0023, CondE: 0.2287, disc: 0.0000, domain: 1.1491, Src VAT: 0.0182, Trg VAT: 0.2287, Src MixUp: 0.2881, Trg MixUp: 0.6612, Src Train Acc: 100.00, Trg Train Acc: 88.69, Src Test Acc: 97.28, Trg Test Acc: 91.49, Server Test Acc: 74.55, Office Test Acc: 70.19, Conf Test Acc: 78.89
# Epoch: 099, TotalL: 6.9093, CrossE: 0.0025, CondE: 0.2286, disc: 0.0000, domain: 1.1560, Src VAT: 0.0192, Trg VAT: 0.2286, Src MixUp: 0.2927, Trg MixUp: 0.6487, Src Train Acc: 100.00, Trg Train Acc: 88.59, Src Test Acc: 96.89, Trg Test Acc: 90.55, Server Test Acc: 76.56, Office Test Acc: 69.19, Conf Test Acc: 80.00
# Epoch: 100, TotalL: 6.9153, CrossE: 0.0024, CondE: 0.2290, disc: 0.0000, domain: 1.1549, Src VAT: 0.0184, Trg VAT: 0.2290, Src MixUp: 0.3002, Trg MixUp: 0.6483, Src Train Acc: 100.00, Trg Train Acc: 88.35, Src Test Acc: 97.28, Trg Test Acc: 93.33, Server Test Acc: 75.22, Office Test Acc: 71.41, Conf Test Acc: 80.44
# Epoch: 101, TotalL: 7.4100, CrossE: 0.1160, CondE: 0.2464, disc: 0.0000, domain: 1.2675, Src VAT: 0.0418, Trg VAT: 0.2464, Src MixUp: 0.3382, Trg MixUp: 0.6813, Src Train Acc: 98.22, Trg Train Acc: 84.40, Src Test Acc: 96.11, Trg Test Acc: 90.87, Server Test Acc: 67.63, Office Test Acc: 70.30, Conf Test Acc: 74.67
# Epoch: 102, TotalL: 6.9288, CrossE: 0.0028, CondE: 0.2190, disc: 0.0000, domain: 1.1461, Src VAT: 0.0191, Trg VAT: 0.2190, Src MixUp: 0.2969, Trg MixUp: 0.6544, Src Train Acc: 100.00, Trg Train Acc: 87.61, Src Test Acc: 95.72, Trg Test Acc: 93.07, Server Test Acc: 68.75, Office Test Acc: 68.85, Conf Test Acc: 75.78
# Epoch: 103, TotalL: 6.9000, CrossE: 0.0025, CondE: 0.2211, disc: 0.0000, domain: 1.1461, Src VAT: 0.0190, Trg VAT: 0.2211, Src MixUp: 0.2865, Trg MixUp: 0.6600, Src Train Acc: 100.00, Trg Train Acc: 88.06, Src Test Acc: 96.89, Trg Test Acc: 93.39, Server Test Acc: 74.11, Office Test Acc: 71.64, Conf Test Acc: 80.44
# Epoch: 104, TotalL: 6.8952, CrossE: 0.0023, CondE: 0.2188, disc: 0.0000, domain: 1.1476, Src VAT: 0.0179, Trg VAT: 0.2188, Src MixUp: 0.2882, Trg MixUp: 0.6509, Src Train Acc: 100.00, Trg Train Acc: 89.06, Src Test Acc: 96.89, Trg Test Acc: 92.66, Server Test Acc: 79.02, Office Test Acc: 73.41, Conf Test Acc: 80.89
# Epoch: 105, TotalL: 6.8877, CrossE: 0.0022, CondE: 0.2147, disc: 0.0000, domain: 1.1545, Src VAT: 0.0174, Trg VAT: 0.2147, Src MixUp: 0.2868, Trg MixUp: 0.6564, Src Train Acc: 100.00, Trg Train Acc: 89.54, Src Test Acc: 96.50, Trg Test Acc: 93.57, Server Test Acc: 72.77, Office Test Acc: 73.41, Conf Test Acc: 79.33
# Epoch: 106, TotalL: 6.8974, CrossE: 0.0022, CondE: 0.2124, disc: 0.0000, domain: 1.1579, Src VAT: 0.0175, Trg VAT: 0.2124, Src MixUp: 0.2956, Trg MixUp: 0.6415, Src Train Acc: 100.00, Trg Train Acc: 89.67, Src Test Acc: 98.44, Trg Test Acc: 91.55, Server Test Acc: 72.77, Office Test Acc: 73.08, Conf Test Acc: 80.22
# Epoch: 107, TotalL: 6.9337, CrossE: 0.0031, CondE: 0.2172, disc: 0.0000, domain: 1.1873, Src VAT: 0.0206, Trg VAT: 0.2172, Src MixUp: 0.2927, Trg MixUp: 0.6428, Src Train Acc: 100.00, Trg Train Acc: 89.02, Src Test Acc: 54.09, Trg Test Acc: 39.92, Server Test Acc: 45.76, Office Test Acc: 59.51, Conf Test Acc: 44.67
# Epoch: 108, TotalL: 6.9823, CrossE: 0.0045, CondE: 0.2094, disc: 0.0000, domain: 1.2086, Src VAT: 0.0225, Trg VAT: 0.2094, Src MixUp: 0.2997, Trg MixUp: 0.6451, Src Train Acc: 99.96, Trg Train Acc: 88.45, Src Test Acc: 97.28, Trg Test Acc: 93.54, Server Test Acc: 77.68, Office Test Acc: 77.31, Conf Test Acc: 81.11
# Epoch: 109, TotalL: 6.8791, CrossE: 0.0020, CondE: 0.2026, disc: 0.0000, domain: 1.1635, Src VAT: 0.0152, Trg VAT: 0.2026, Src MixUp: 0.2710, Trg MixUp: 0.6331, Src Train Acc: 100.00, Trg Train Acc: 89.80, Src Test Acc: 97.28, Trg Test Acc: 92.78, Server Test Acc: 69.64, Office Test Acc: 68.30, Conf Test Acc: 76.44
# Epoch: 110, TotalL: 6.8736, CrossE: 0.0018, CondE: 0.1969, disc: 0.0000, domain: 1.1617, Src VAT: 0.0148, Trg VAT: 0.1969, Src MixUp: 0.2798, Trg MixUp: 0.6294, Src Train Acc: 100.00, Trg Train Acc: 90.49, Src Test Acc: 96.50, Trg Test Acc: 89.56, Server Test Acc: 68.08, Office Test Acc: 71.75, Conf Test Acc: 74.00
# Epoch: 111, TotalL: 6.9520, CrossE: 0.0038, CondE: 0.2100, disc: 0.0000, domain: 1.2117, Src VAT: 0.0219, Trg VAT: 0.2100, Src MixUp: 0.2888, Trg MixUp: 0.6438, Src Train Acc: 99.96, Trg Train Acc: 90.04, Src Test Acc: 94.55, Trg Test Acc: 85.26, Server Test Acc: 75.00, Office Test Acc: 72.19, Conf Test Acc: 76.00
# Epoch: 112, TotalL: 6.9178, CrossE: 0.0024, CondE: 0.2001, disc: 0.0000, domain: 1.2007, Src VAT: 0.0170, Trg VAT: 0.2001, Src MixUp: 0.2794, Trg MixUp: 0.6300, Src Train Acc: 100.00, Trg Train Acc: 91.10, Src Test Acc: 97.67, Trg Test Acc: 93.07, Server Test Acc: 76.56, Office Test Acc: 73.75, Conf Test Acc: 82.89
# Epoch: 113, TotalL: 6.8626, CrossE: 0.0020, CondE: 0.1892, disc: 0.0000, domain: 1.1692, Src VAT: 0.0152, Trg VAT: 0.1892, Src MixUp: 0.2631, Trg MixUp: 0.6160, Src Train Acc: 100.00, Trg Train Acc: 91.28, Src Test Acc: 97.28, Trg Test Acc: 92.63, Server Test Acc: 78.12, Office Test Acc: 72.64, Conf Test Acc: 81.56
# Epoch: 114, TotalL: 6.8634, CrossE: 0.0019, CondE: 0.1814, disc: 0.0000, domain: 1.1745, Src VAT: 0.0142, Trg VAT: 0.1814, Src MixUp: 0.2706, Trg MixUp: 0.6067, Src Train Acc: 100.00, Trg Train Acc: 91.02, Src Test Acc: 97.28, Trg Test Acc: 93.48, Server Test Acc: 77.46, Office Test Acc: 75.19, Conf Test Acc: 81.78
# Epoch: 115, TotalL: 6.8672, CrossE: 0.0018, CondE: 0.1846, disc: 0.0000, domain: 1.1861, Src VAT: 0.0140, Trg VAT: 0.1846, Src MixUp: 0.2640, Trg MixUp: 0.6165, Src Train Acc: 100.00, Trg Train Acc: 90.99, Src Test Acc: 98.05, Trg Test Acc: 95.35, Server Test Acc: 73.88, Office Test Acc: 73.97, Conf Test Acc: 80.44
# Epoch: 116, TotalL: 6.8877, CrossE: 0.0018, CondE: 0.1863, disc: 0.0000, domain: 1.2040, Src VAT: 0.0144, Trg VAT: 0.1863, Src MixUp: 0.2754, Trg MixUp: 0.6046, Src Train Acc: 100.00, Trg Train Acc: 91.25, Src Test Acc: 96.89, Trg Test Acc: 93.04, Server Test Acc: 78.35, Office Test Acc: 71.86, Conf Test Acc: 80.89
# Epoch: 117, TotalL: 7.4501, CrossE: 0.1848, CondE: 0.2053, disc: 0.0000, domain: 1.2935, Src VAT: 0.0387, Trg VAT: 0.2053, Src MixUp: 0.3175, Trg MixUp: 0.6406, Src Train Acc: 97.27, Trg Train Acc: 87.87, Src Test Acc: 96.89, Trg Test Acc: 91.69, Server Test Acc: 75.67, Office Test Acc: 70.63, Conf Test Acc: 80.67
# Epoch: 118, TotalL: 6.9111, CrossE: 0.0025, CondE: 0.1790, disc: 0.0000, domain: 1.1843, Src VAT: 0.0168, Trg VAT: 0.1790, Src MixUp: 0.2752, Trg MixUp: 0.6043, Src Train Acc: 100.00, Trg Train Acc: 90.95, Src Test Acc: 98.05, Trg Test Acc: 92.75, Server Test Acc: 78.79, Office Test Acc: 77.31, Conf Test Acc: 81.33
# Epoch: 119, TotalL: 6.8495, CrossE: 0.0016, CondE: 0.1726, disc: 0.0000, domain: 1.1606, Src VAT: 0.0127, Trg VAT: 0.1726, Src MixUp: 0.2554, Trg MixUp: 0.5983, Src Train Acc: 100.00, Trg Train Acc: 91.67, Src Test Acc: 98.05, Trg Test Acc: 94.41, Server Test Acc: 75.89, Office Test Acc: 76.97, Conf Test Acc: 81.11
# Epoch: 120, TotalL: 6.8330, CrossE: 0.0015, CondE: 0.1673, disc: 0.0000, domain: 1.1621, Src VAT: 0.0122, Trg VAT: 0.1673, Src MixUp: 0.2507, Trg MixUp: 0.5914, Src Train Acc: 100.00, Trg Train Acc: 92.06, Src Test Acc: 96.89, Trg Test Acc: 94.36, Server Test Acc: 81.47, Office Test Acc: 75.97, Conf Test Acc: 82.67
# Epoch: 121, TotalL: 6.8321, CrossE: 0.0015, CondE: 0.1675, disc: 0.0000, domain: 1.1656, Src VAT: 0.0127, Trg VAT: 0.1675, Src MixUp: 0.2531, Trg MixUp: 0.5853, Src Train Acc: 100.00, Trg Train Acc: 92.32, Src Test Acc: 97.28, Trg Test Acc: 93.83, Server Test Acc: 79.24, Office Test Acc: 80.87, Conf Test Acc: 82.22
# Epoch: 122, TotalL: 6.8236, CrossE: 0.0015, CondE: 0.1659, disc: 0.0000, domain: 1.1619, Src VAT: 0.0125, Trg VAT: 0.1659, Src MixUp: 0.2503, Trg MixUp: 0.5918, Src Train Acc: 100.00, Trg Train Acc: 92.27, Src Test Acc: 98.05, Trg Test Acc: 94.50, Server Test Acc: 77.01, Office Test Acc: 73.75, Conf Test Acc: 82.67
# Epoch: 123, TotalL: 6.8293, CrossE: 0.0015, CondE: 0.1642, disc: 0.0000, domain: 1.1703, Src VAT: 0.0128, Trg VAT: 0.1642, Src MixUp: 0.2561, Trg MixUp: 0.5839, Src Train Acc: 100.00, Trg Train Acc: 92.27, Src Test Acc: 96.89, Trg Test Acc: 93.80, Server Test Acc: 81.70, Office Test Acc: 80.65, Conf Test Acc: 83.11
# Epoch: 124, TotalL: 6.8506, CrossE: 0.0016, CondE: 0.1619, disc: 0.0000, domain: 1.1835, Src VAT: 0.0131, Trg VAT: 0.1619, Src MixUp: 0.2729, Trg MixUp: 0.5778, Src Train Acc: 100.00, Trg Train Acc: 92.10, Src Test Acc: 98.05, Trg Test Acc: 94.50, Server Test Acc: 77.68, Office Test Acc: 77.31, Conf Test Acc: 81.56
# Epoch: 125, TotalL: 6.8571, CrossE: 0.0017, CondE: 0.1620, disc: 0.0000, domain: 1.2098, Src VAT: 0.0131, Trg VAT: 0.1620, Src MixUp: 0.2581, Trg MixUp: 0.5742, Src Train Acc: 100.00, Trg Train Acc: 91.99, Src Test Acc: 98.44, Trg Test Acc: 94.30, Server Test Acc: 76.56, Office Test Acc: 77.98, Conf Test Acc: 80.89
# Epoch: 126, TotalL: 6.8555, CrossE: 0.0016, CondE: 0.1586, disc: 0.0000, domain: 1.2113, Src VAT: 0.0126, Trg VAT: 0.1586, Src MixUp: 0.2567, Trg MixUp: 0.5827, Src Train Acc: 100.00, Trg Train Acc: 92.32, Src Test Acc: 97.28, Trg Test Acc: 94.00, Server Test Acc: 80.13, Office Test Acc: 76.20, Conf Test Acc: 81.78
# Epoch: 127, TotalL: 6.8414, CrossE: 0.0016, CondE: 0.1616, disc: 0.0000, domain: 1.2004, Src VAT: 0.0125, Trg VAT: 0.1616, Src MixUp: 0.2480, Trg MixUp: 0.5784, Src Train Acc: 100.00, Trg Train Acc: 92.12, Src Test Acc: 97.28, Trg Test Acc: 93.54, Server Test Acc: 79.24, Office Test Acc: 73.08, Conf Test Acc: 81.78
# Epoch: 128, TotalL: 6.9059, CrossE: 0.0023, CondE: 0.1666, disc: 0.0000, domain: 1.2343, Src VAT: 0.0149, Trg VAT: 0.1666, Src MixUp: 0.2712, Trg MixUp: 0.5933, Src Train Acc: 100.00, Trg Train Acc: 91.54, Src Test Acc: 96.89, Trg Test Acc: 88.24, Server Test Acc: 68.53, Office Test Acc: 74.30, Conf Test Acc: 74.44
# Epoch: 129, TotalL: 6.8725, CrossE: 0.0015, CondE: 0.1570, disc: 0.0000, domain: 1.2088, Src VAT: 0.0121, Trg VAT: 0.1570, Src MixUp: 0.2701, Trg MixUp: 0.5738, Src Train Acc: 100.00, Trg Train Acc: 92.32, Src Test Acc: 98.05, Trg Test Acc: 94.03, Server Test Acc: 79.91, Office Test Acc: 78.98, Conf Test Acc: 82.89
# Epoch: 130, TotalL: 6.8538, CrossE: 0.0016, CondE: 0.1574, disc: 0.0000, domain: 1.2113, Src VAT: 0.0123, Trg VAT: 0.1574, Src MixUp: 0.2575, Trg MixUp: 0.5590, Src Train Acc: 100.00, Trg Train Acc: 92.93, Src Test Acc: 98.05, Trg Test Acc: 94.24, Server Test Acc: 81.47, Office Test Acc: 79.76, Conf Test Acc: 81.78
# Epoch: 131, TotalL: 6.8832, CrossE: 0.0026, CondE: 0.1615, disc: 0.0000, domain: 1.2270, Src VAT: 0.0141, Trg VAT: 0.1615, Src MixUp: 0.2563, Trg MixUp: 0.5892, Src Train Acc: 99.96, Trg Train Acc: 92.23, Src Test Acc: 97.28, Trg Test Acc: 91.90, Server Test Acc: 72.32, Office Test Acc: 67.63, Conf Test Acc: 78.22
# Epoch: 132, TotalL: 6.8899, CrossE: 0.0028, CondE: 0.1593, disc: 0.0000, domain: 1.2301, Src VAT: 0.0152, Trg VAT: 0.1593, Src MixUp: 0.2654, Trg MixUp: 0.5786, Src Train Acc: 100.00, Trg Train Acc: 92.38, Src Test Acc: 96.89, Trg Test Acc: 93.27, Server Test Acc: 79.02, Office Test Acc: 72.97, Conf Test Acc: 78.22
# Epoch: 133, TotalL: 6.8614, CrossE: 0.0016, CondE: 0.1533, disc: 0.0000, domain: 1.2169, Src VAT: 0.0127, Trg VAT: 0.1533, Src MixUp: 0.2603, Trg MixUp: 0.5681, Src Train Acc: 100.00, Trg Train Acc: 92.38, Src Test Acc: 98.05, Trg Test Acc: 92.22, Server Test Acc: 81.47, Office Test Acc: 80.76, Conf Test Acc: 83.78
# Epoch: 134, TotalL: 6.8215, CrossE: 0.0014, CondE: 0.1457, disc: 0.0000, domain: 1.2004, Src VAT: 0.0114, Trg VAT: 0.1457, Src MixUp: 0.2411, Trg MixUp: 0.5569, Src Train Acc: 100.00, Trg Train Acc: 93.14, Src Test Acc: 97.67, Trg Test Acc: 94.44, Server Test Acc: 83.48, Office Test Acc: 80.42, Conf Test Acc: 83.33
# Epoch: 135, TotalL: 6.8243, CrossE: 0.0014, CondE: 0.1440, disc: 0.0000, domain: 1.2016, Src VAT: 0.0113, Trg VAT: 0.1440, Src MixUp: 0.2475, Trg MixUp: 0.5467, Src Train Acc: 100.00, Trg Train Acc: 93.21, Src Test Acc: 98.05, Trg Test Acc: 93.71, Server Test Acc: 77.68, Office Test Acc: 78.87, Conf Test Acc: 78.89
# Epoch: 136, TotalL: 6.8614, CrossE: 0.0022, CondE: 0.1549, disc: 0.0000, domain: 1.2282, Src VAT: 0.0139, Trg VAT: 0.1549, Src MixUp: 0.2477, Trg MixUp: 0.5683, Src Train Acc: 100.00, Trg Train Acc: 93.25, Src Test Acc: 97.28, Trg Test Acc: 94.82, Server Test Acc: 81.92, Office Test Acc: 80.76, Conf Test Acc: 80.44
# Epoch: 137, TotalL: 6.8788, CrossE: 0.0017, CondE: 0.1471, disc: 0.0000, domain: 1.2410, Src VAT: 0.0129, Trg VAT: 0.1471, Src MixUp: 0.2556, Trg MixUp: 0.5588, Src Train Acc: 100.00, Trg Train Acc: 93.25, Src Test Acc: 97.28, Trg Test Acc: 93.27, Server Test Acc: 76.79, Office Test Acc: 75.64, Conf Test Acc: 77.78
# Epoch: 138, TotalL: 6.8335, CrossE: 0.0013, CondE: 0.1415, disc: 0.0000, domain: 1.2130, Src VAT: 0.0105, Trg VAT: 0.1415, Src MixUp: 0.2453, Trg MixUp: 0.5442, Src Train Acc: 100.00, Trg Train Acc: 93.71, Src Test Acc: 98.05, Trg Test Acc: 95.26, Server Test Acc: 79.69, Office Test Acc: 78.53, Conf Test Acc: 80.22
# Epoch: 139, TotalL: 6.8169, CrossE: 0.0012, CondE: 0.1365, disc: 0.0000, domain: 1.2094, Src VAT: 0.0104, Trg VAT: 0.1365, Src MixUp: 0.2397, Trg MixUp: 0.5323, Src Train Acc: 100.00, Trg Train Acc: 93.06, Src Test Acc: 98.44, Trg Test Acc: 95.29, Server Test Acc: 83.71, Office Test Acc: 78.64, Conf Test Acc: 83.56
# Epoch: 140, TotalL: 6.8283, CrossE: 0.0013, CondE: 0.1390, disc: 0.0000, domain: 1.2091, Src VAT: 0.0107, Trg VAT: 0.1390, Src MixUp: 0.2527, Trg MixUp: 0.5549, Src Train Acc: 100.00, Trg Train Acc: 93.12, Src Test Acc: 96.89, Trg Test Acc: 94.97, Server Test Acc: 82.81, Office Test Acc: 81.09, Conf Test Acc: 80.44
# Epoch: 141, TotalL: 7.3043, CrossE: 0.1136, CondE: 0.1725, disc: 0.0000, domain: 1.3028, Src VAT: 0.0386, Trg VAT: 0.1725, Src MixUp: 0.3149, Trg MixUp: 0.5903, Src Train Acc: 97.87, Trg Train Acc: 90.69, Src Test Acc: 97.67, Trg Test Acc: 94.94, Server Test Acc: 78.35, Office Test Acc: 76.64, Conf Test Acc: 79.33
# Epoch: 142, TotalL: 6.8639, CrossE: 0.0016, CondE: 0.1433, disc: 0.0000, domain: 1.2067, Src VAT: 0.0126, Trg VAT: 0.1433, Src MixUp: 0.2694, Trg MixUp: 0.5491, Src Train Acc: 100.00, Trg Train Acc: 93.60, Src Test Acc: 97.67, Trg Test Acc: 95.20, Server Test Acc: 82.81, Office Test Acc: 79.64, Conf Test Acc: 81.33
# Epoch: 143, TotalL: 6.8227, CrossE: 0.0014, CondE: 0.1382, disc: 0.0000, domain: 1.1927, Src VAT: 0.0115, Trg VAT: 0.1382, Src MixUp: 0.2492, Trg MixUp: 0.5429, Src Train Acc: 100.00, Trg Train Acc: 93.68, Src Test Acc: 98.05, Trg Test Acc: 96.61, Server Test Acc: 83.04, Office Test Acc: 79.87, Conf Test Acc: 82.89
# Epoch: 144, TotalL: 6.8134, CrossE: 0.0013, CondE: 0.1348, disc: 0.0000, domain: 1.1913, Src VAT: 0.0110, Trg VAT: 0.1348, Src MixUp: 0.2476, Trg MixUp: 0.5443, Src Train Acc: 100.00, Trg Train Acc: 93.88, Src Test Acc: 98.05, Trg Test Acc: 96.84, Server Test Acc: 84.15, Office Test Acc: 79.64, Conf Test Acc: 82.00
# Epoch: 145, TotalL: 6.8109, CrossE: 0.0013, CondE: 0.1291, disc: 0.0000, domain: 1.1928, Src VAT: 0.0107, Trg VAT: 0.1291, Src MixUp: 0.2506, Trg MixUp: 0.5195, Src Train Acc: 100.00, Trg Train Acc: 93.73, Src Test Acc: 98.05, Trg Test Acc: 96.26, Server Test Acc: 83.71, Office Test Acc: 80.76, Conf Test Acc: 82.67
# Epoch: 146, TotalL: 6.8032, CrossE: 0.0012, CondE: 0.1265, disc: 0.0000, domain: 1.1989, Src VAT: 0.0103, Trg VAT: 0.1265, Src MixUp: 0.2441, Trg MixUp: 0.5304, Src Train Acc: 100.00, Trg Train Acc: 93.95, Src Test Acc: 97.67, Trg Test Acc: 96.11, Server Test Acc: 84.60, Office Test Acc: 83.31, Conf Test Acc: 82.44
# Epoch: 147, TotalL: 6.8035, CrossE: 0.0012, CondE: 0.1209, disc: 0.0000, domain: 1.2029, Src VAT: 0.0099, Trg VAT: 0.1209, Src MixUp: 0.2474, Trg MixUp: 0.5092, Src Train Acc: 100.00, Trg Train Acc: 94.21, Src Test Acc: 98.05, Trg Test Acc: 95.88, Server Test Acc: 84.38, Office Test Acc: 81.65, Conf Test Acc: 83.78
# Epoch: 148, TotalL: 6.7980, CrossE: 0.0012, CondE: 0.1199, disc: 0.0000, domain: 1.2107, Src VAT: 0.0101, Trg VAT: 0.1199, Src MixUp: 0.2376, Trg MixUp: 0.5235, Src Train Acc: 100.00, Trg Train Acc: 94.49, Src Test Acc: 97.28, Trg Test Acc: 95.53, Server Test Acc: 87.28, Office Test Acc: 80.31, Conf Test Acc: 81.56
# Epoch: 149, TotalL: 6.8325, CrossE: 0.0013, CondE: 0.1294, disc: 0.0000, domain: 1.2336, Src VAT: 0.0107, Trg VAT: 0.1294, Src MixUp: 0.2468, Trg MixUp: 0.5432, Src Train Acc: 100.00, Trg Train Acc: 93.82, Src Test Acc: 97.28, Trg Test Acc: 91.55, Server Test Acc: 78.35, Office Test Acc: 78.09, Conf Test Acc: 79.11
# Epoch: 150, TotalL: 6.8965, CrossE: 0.0025, CondE: 0.1298, disc: 0.0000, domain: 1.2640, Src VAT: 0.0137, Trg VAT: 0.1298, Src MixUp: 0.2643, Trg MixUp: 0.5404, Src Train Acc: 100.00, Trg Train Acc: 93.77, Src Test Acc: 98.05, Trg Test Acc: 94.56, Server Test Acc: 82.37, Office Test Acc: 81.65, Conf Test Acc: 82.89
# Epoch: 151, TotalL: 6.7966, CrossE: 0.0011, CondE: 0.1166, disc: 0.0000, domain: 1.2095, Src VAT: 0.0092, Trg VAT: 0.1166, Src MixUp: 0.2294, Trg MixUp: 0.5173, Src Train Acc: 100.00, Trg Train Acc: 94.21, Src Test Acc: 98.05, Trg Test Acc: 95.47, Server Test Acc: 82.14, Office Test Acc: 77.75, Conf Test Acc: 83.33
# Epoch: 152, TotalL: 6.7907, CrossE: 0.0010, CondE: 0.1148, disc: 0.0000, domain: 1.2085, Src VAT: 0.0091, Trg VAT: 0.1148, Src MixUp: 0.2325, Trg MixUp: 0.5087, Src Train Acc: 100.00, Trg Train Acc: 94.23, Src Test Acc: 98.05, Trg Test Acc: 96.05, Server Test Acc: 82.14, Office Test Acc: 76.42, Conf Test Acc: 80.22
# Epoch: 153, TotalL: 6.8001, CrossE: 0.0012, CondE: 0.1151, disc: 0.0000, domain: 1.2148, Src VAT: 0.0099, Trg VAT: 0.1151, Src MixUp: 0.2405, Trg MixUp: 0.5208, Src Train Acc: 100.00, Trg Train Acc: 94.34, Src Test Acc: 98.44, Trg Test Acc: 95.50, Server Test Acc: 83.04, Office Test Acc: 79.87, Conf Test Acc: 83.56
# Epoch: 154, TotalL: 6.8596, CrossE: 0.0017, CondE: 0.1252, disc: 0.0000, domain: 1.2599, Src VAT: 0.0131, Trg VAT: 0.1252, Src MixUp: 0.2602, Trg MixUp: 0.5307, Src Train Acc: 100.00, Trg Train Acc: 94.03, Src Test Acc: 97.67, Trg Test Acc: 96.29, Server Test Acc: 83.71, Office Test Acc: 81.42, Conf Test Acc: 84.22
# Epoch: 155, TotalL: 6.8202, CrossE: 0.0012, CondE: 0.1166, disc: 0.0000, domain: 1.2401, Src VAT: 0.0100, Trg VAT: 0.1166, Src MixUp: 0.2434, Trg MixUp: 0.5038, Src Train Acc: 100.00, Trg Train Acc: 94.40, Src Test Acc: 98.05, Trg Test Acc: 96.08, Server Test Acc: 83.48, Office Test Acc: 80.42, Conf Test Acc: 82.67
# Epoch: 156, TotalL: 6.8173, CrossE: 0.0012, CondE: 0.1201, disc: 0.0000, domain: 1.2452, Src VAT: 0.0098, Trg VAT: 0.1201, Src MixUp: 0.2288, Trg MixUp: 0.5124, Src Train Acc: 100.00, Trg Train Acc: 94.01, Src Test Acc: 98.05, Trg Test Acc: 95.91, Server Test Acc: 83.26, Office Test Acc: 79.42, Conf Test Acc: 82.89
# Epoch: 157, TotalL: 6.8060, CrossE: 0.0011, CondE: 0.1093, disc: 0.0000, domain: 1.2272, Src VAT: 0.0091, Trg VAT: 0.1093, Src MixUp: 0.2400, Trg MixUp: 0.5108, Src Train Acc: 100.00, Trg Train Acc: 94.34, Src Test Acc: 98.05, Trg Test Acc: 95.88, Server Test Acc: 80.58, Office Test Acc: 75.42, Conf Test Acc: 80.44
# Epoch: 158, TotalL: 6.8187, CrossE: 0.0012, CondE: 0.1131, disc: 0.0000, domain: 1.2399, Src VAT: 0.0097, Trg VAT: 0.1131, Src MixUp: 0.2407, Trg MixUp: 0.5107, Src Train Acc: 100.00, Trg Train Acc: 94.47, Src Test Acc: 98.05, Trg Test Acc: 95.12, Server Test Acc: 83.26, Office Test Acc: 77.20, Conf Test Acc: 82.22
# Epoch: 159, TotalL: 6.8270, CrossE: 0.0013, CondE: 0.1141, disc: 0.0000, domain: 1.2536, Src VAT: 0.0104, Trg VAT: 0.1141, Src MixUp: 0.2416, Trg MixUp: 0.5092, Src Train Acc: 100.00, Trg Train Acc: 94.36, Src Test Acc: 98.44, Trg Test Acc: 95.12, Server Test Acc: 85.27, Office Test Acc: 81.98, Conf Test Acc: 81.11
# Epoch: 160, TotalL: 6.8116, CrossE: 0.0013, CondE: 0.1156, disc: 0.0000, domain: 1.2490, Src VAT: 0.0104, Trg VAT: 0.1156, Src MixUp: 0.2297, Trg MixUp: 0.5073, Src Train Acc: 100.00, Trg Train Acc: 94.08, Src Test Acc: 98.05, Trg Test Acc: 95.70, Server Test Acc: 85.04, Office Test Acc: 81.87, Conf Test Acc: 85.11
# Epoch: 161, TotalL: 6.8284, CrossE: 0.0016, CondE: 0.1137, disc: 0.0000, domain: 1.2497, Src VAT: 0.0108, Trg VAT: 0.1137, Src MixUp: 0.2458, Trg MixUp: 0.5112, Src Train Acc: 100.00, Trg Train Acc: 94.57, Src Test Acc: 98.05, Trg Test Acc: 95.64, Server Test Acc: 85.49, Office Test Acc: 80.98, Conf Test Acc: 85.56
# Epoch: 162, TotalL: 6.8133, CrossE: 0.0011, CondE: 0.1072, disc: 0.0000, domain: 1.2481, Src VAT: 0.0095, Trg VAT: 0.1072, Src MixUp: 0.2369, Trg MixUp: 0.4997, Src Train Acc: 100.00, Trg Train Acc: 94.75, Src Test Acc: 98.05, Trg Test Acc: 96.90, Server Test Acc: 82.81, Office Test Acc: 78.31, Conf Test Acc: 83.33
# Epoch: 163, TotalL: 6.7826, CrossE: 0.0010, CondE: 0.1030, disc: 0.0000, domain: 1.2365, Src VAT: 0.0087, Trg VAT: 0.1030, Src MixUp: 0.2233, Trg MixUp: 0.4775, Src Train Acc: 100.00, Trg Train Acc: 94.75, Src Test Acc: 97.28, Trg Test Acc: 91.84, Server Test Acc: 82.14, Office Test Acc: 75.97, Conf Test Acc: 83.56
# Epoch: 164, TotalL: 6.7997, CrossE: 0.0011, CondE: 0.1061, disc: 0.0000, domain: 1.2546, Src VAT: 0.0092, Trg VAT: 0.1061, Src MixUp: 0.2260, Trg MixUp: 0.4913, Src Train Acc: 100.00, Trg Train Acc: 94.57, Src Test Acc: 98.44, Trg Test Acc: 93.33, Server Test Acc: 79.91, Office Test Acc: 83.43, Conf Test Acc: 80.89
# Epoch: 165, TotalL: 6.8027, CrossE: 0.0011, CondE: 0.1058, disc: 0.0000, domain: 1.2422, Src VAT: 0.0093, Trg VAT: 0.1058, Src MixUp: 0.2306, Trg MixUp: 0.4910, Src Train Acc: 100.00, Trg Train Acc: 94.38, Src Test Acc: 97.28, Trg Test Acc: 94.79, Server Test Acc: 85.71, Office Test Acc: 82.65, Conf Test Acc: 83.33
# Epoch: 166, TotalL: 6.8212, CrossE: 0.0013, CondE: 0.1058, disc: 0.0000, domain: 1.2734, Src VAT: 0.0097, Trg VAT: 0.1058, Src MixUp: 0.2329, Trg MixUp: 0.4865, Src Train Acc: 100.00, Trg Train Acc: 94.36, Src Test Acc: 98.05, Trg Test Acc: 94.88, Server Test Acc: 86.61, Office Test Acc: 82.65, Conf Test Acc: 85.78
# Epoch: 167, TotalL: 6.7716, CrossE: 0.0009, CondE: 0.0958, disc: 0.0000, domain: 1.2374, Src VAT: 0.0079, Trg VAT: 0.0958, Src MixUp: 0.2163, Trg MixUp: 0.4730, Src Train Acc: 100.00, Trg Train Acc: 94.47, Src Test Acc: 97.67, Trg Test Acc: 95.88, Server Test Acc: 87.50, Office Test Acc: 85.54, Conf Test Acc: 85.11
# Epoch: 168, TotalL: 6.8542, CrossE: 0.0025, CondE: 0.1118, disc: 0.0000, domain: 1.2716, Src VAT: 0.0127, Trg VAT: 0.1118, Src MixUp: 0.2417, Trg MixUp: 0.5022, Src Train Acc: 99.91, Trg Train Acc: 94.38, Src Test Acc: 98.05, Trg Test Acc: 93.68, Server Test Acc: 86.61, Office Test Acc: 82.31, Conf Test Acc: 81.56
# Epoch: 169, TotalL: 6.8243, CrossE: 0.0012, CondE: 0.1065, disc: 0.0000, domain: 1.2600, Src VAT: 0.0096, Trg VAT: 0.1065, Src MixUp: 0.2338, Trg MixUp: 0.4911, Src Train Acc: 100.00, Trg Train Acc: 94.38, Src Test Acc: 98.05, Trg Test Acc: 95.03, Server Test Acc: 85.27, Office Test Acc: 83.76, Conf Test Acc: 80.00
# Epoch: 170, TotalL: 6.8065, CrossE: 0.0011, CondE: 0.0966, disc: 0.0000, domain: 1.2512, Src VAT: 0.0088, Trg VAT: 0.0966, Src MixUp: 0.2373, Trg MixUp: 0.4759, Src Train Acc: 100.00, Trg Train Acc: 94.86, Src Test Acc: 98.05, Trg Test Acc: 95.14, Server Test Acc: 83.04, Office Test Acc: 84.87, Conf Test Acc: 83.56
# Epoch: 171, TotalL: 6.7752, CrossE: 0.0009, CondE: 0.0941, disc: 0.0000, domain: 1.2362, Src VAT: 0.0083, Trg VAT: 0.0941, Src MixUp: 0.2248, Trg MixUp: 0.4650, Src Train Acc: 100.00, Trg Train Acc: 95.07, Src Test Acc: 97.67, Trg Test Acc: 96.90, Server Test Acc: 87.50, Office Test Acc: 79.98, Conf Test Acc: 82.67
# Epoch: 172, TotalL: 6.7691, CrossE: 0.0010, CondE: 0.0949, disc: 0.0000, domain: 1.2404, Src VAT: 0.0085, Trg VAT: 0.0949, Src MixUp: 0.2174, Trg MixUp: 0.4616, Src Train Acc: 100.00, Trg Train Acc: 94.77, Src Test Acc: 98.05, Trg Test Acc: 95.23, Server Test Acc: 83.71, Office Test Acc: 80.20, Conf Test Acc: 82.89
# Epoch: 173, TotalL: 6.7847, CrossE: 0.0010, CondE: 0.0950, disc: 0.0000, domain: 1.2482, Src VAT: 0.0087, Trg VAT: 0.0950, Src MixUp: 0.2308, Trg MixUp: 0.4686, Src Train Acc: 100.00, Trg Train Acc: 94.88, Src Test Acc: 98.83, Trg Test Acc: 95.20, Server Test Acc: 83.71, Office Test Acc: 80.42, Conf Test Acc: 81.11
# Epoch: 174, TotalL: 7.2199, CrossE: 0.1188, CondE: 0.1198, disc: 0.0000, domain: 1.3210, Src VAT: 0.0301, Trg VAT: 0.1198, Src MixUp: 0.2651, Trg MixUp: 0.4967, Src Train Acc: 97.96, Trg Train Acc: 91.75, Src Test Acc: 95.72, Trg Test Acc: 91.93, Server Test Acc: 73.88, Office Test Acc: 76.20, Conf Test Acc: 80.67
# Epoch: 175, TotalL: 6.8730, CrossE: 0.0020, CondE: 0.1108, disc: 0.0000, domain: 1.2691, Src VAT: 0.0109, Trg VAT: 0.1108, Src MixUp: 0.2449, Trg MixUp: 0.4936, Src Train Acc: 99.96, Trg Train Acc: 94.42, Src Test Acc: 98.05, Trg Test Acc: 96.69, Server Test Acc: 83.26, Office Test Acc: 78.53, Conf Test Acc: 81.78
# Epoch: 176, TotalL: 6.7758, CrossE: 0.0008, CondE: 0.0959, disc: 0.0000, domain: 1.2286, Src VAT: 0.0071, Trg VAT: 0.0959, Src MixUp: 0.2117, Trg MixUp: 0.4789, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 98.44, Trg Test Acc: 95.93, Server Test Acc: 81.70, Office Test Acc: 78.75, Conf Test Acc: 81.33
# Epoch: 177, TotalL: 6.7572, CrossE: 0.0007, CondE: 0.0904, disc: 0.0000, domain: 1.2144, Src VAT: 0.0066, Trg VAT: 0.0904, Src MixUp: 0.2120, Trg MixUp: 0.4578, Src Train Acc: 100.00, Trg Train Acc: 95.14, Src Test Acc: 98.05, Trg Test Acc: 97.08, Server Test Acc: 84.60, Office Test Acc: 81.42, Conf Test Acc: 83.11
