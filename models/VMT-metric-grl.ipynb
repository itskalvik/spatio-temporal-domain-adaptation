# %%
import os
import h5py
import numpy as np
import tensorflow as tf
from skimage.transform import resize
from sklearn.model_selection import train_test_split
os.environ['CUDA_VISIBLE_DEVICES']='0'

tf.enable_eager_execution()
print(tf.__version__)
# Out:
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/kjakkala/.local/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0

# %%
num_classes     = 9
batch_size      = 8
train_src_days  = 3
train_trg_days  = 3
epochs          = 500
learning_rate   = 0.0001
num_hidden      = [1024, 512]
num_features    = 256
alpha           = 0.05
disc_activation = 'selu'
gen_activation  = 'selu'
train_trg_env_days = 2
notes           = "VMT_gauss_noise_cv_data_center_adapt_grl_serverconftime_{}trg_day_resize224".format(train_trg_env_days)

log_data = "classes-{}_bs-{}_train_src_days-{}_train_trg_days-{}_lr-{}_num_hidden-{}_num_feat-{}_disc_act-{}_gen_act-{}_center_alpha-{}_{}".format(num_classes, 
                                                                                                                                                        batch_size, 
                                                                                                                                                        train_src_days, 
                                                                                                                                                        train_trg_days, 
                                                                                                                                                        learning_rate, 
                                                                                                                                                        num_hidden, 
                                                                                                                                                        num_features,
                                                                                                                                                        disc_activation,
                                                                                                                                                        gen_activation,
                                                                                                                                                        alpha,
                                                                                                                                                        notes)

# %%
def resize_data(data, output_shape=(224, 224)):
  _, height, width, channels = data.shape
  data = data.transpose((1, 2, 3, 0)) 
  data = resize(data.reshape(height, width, -1), output_shape)
  data = data.reshape(*output_shape, channels, -1)
  data = data.transpose((3, 0, 1, 2))
  return data

# %%
#Read data
hf = h5py.File('/home/kjakkala/mmwave/data/source_data.h5', 'r')
X_data = resize_data(np.expand_dims(hf.get('X_data'), axis=-1))
y_data = np.array(hf.get('y_data'))
classes = list(hf.get('classes'))
classes = [n.decode("ascii", "ignore") for n in classes]
hf.close()
print(X_data.shape, y_data.shape, "\n", classes)

#balence dataset to 95 samples per day for each person
X_data_tmp = []
y_data_tmp = []
for day in range(10):
  for idx in range(len(classes)):
    X_data_tmp.extend(X_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
    y_data_tmp.extend(y_data[(y_data[:, 0] == idx) & (y_data[:, 1] == day)][:95])
X_data = np.array(X_data_tmp)
y_data = np.array(y_data_tmp)
del X_data_tmp, y_data_tmp
print(X_data.shape, y_data.shape)

#remove harika's data
X_data = np.delete(X_data, np.where(y_data[:, 0] == 1)[0], 0)
y_data = np.delete(y_data, np.where(y_data[:, 0] == 1)[0], 0)

#update labes to handle 9 classes instead of 10
y_data[y_data[:, 0] >= 2, 0] -= 1
del classes[1]
print(X_data.shape, y_data.shape, "\n", classes)

#split days of data to train and test
X_src = X_data[y_data[:, 1] < train_src_days]
y_src = y_data[y_data[:, 1] < train_src_days, 0]
y_src = np.eye(len(classes))[y_src]
X_train_src, X_test_src, y_train_src, y_test_src = train_test_split(X_src,
                                                                    y_src,
                                                                    stratify=y_src,
                                                                    test_size=0.10,
                                                                    random_state=42)

X_trg = X_data[y_data[:, 1] >= train_src_days]
y_trg = y_data[y_data[:, 1] >= train_src_days]
X_train_trg = X_trg[y_trg[:, 1] < train_src_days+train_trg_days]
y_train_trg = y_trg[y_trg[:, 1] < train_src_days+train_trg_days, 0]
y_train_trg = np.eye(len(classes))[y_train_trg]

X_test_trg = X_data[y_data[:, 1] >= train_src_days+train_trg_days]
y_test_trg = y_data[y_data[:, 1] >= train_src_days+train_trg_days, 0]
y_test_trg = np.eye(len(classes))[y_test_trg]

del X_src, y_src, X_trg, y_trg, X_data, y_data

#standardise dataset
src_mean = np.mean(X_train_src)
X_train_src -= src_mean
src_std  = np.std(X_train_src)
X_train_src /= src_std

X_test_src -= src_mean
X_test_src /= src_std

trg_mean = np.mean(X_train_trg)
X_train_trg -= trg_mean
trg_std  = np.std(X_train_trg)
X_train_trg /= trg_std

X_test_trg -= src_mean
X_test_trg /= src_std

X_train_src = X_train_src.astype(np.float32)
y_train_src = y_train_src.astype(np.uint8)
X_test_src  = X_test_src.astype(np.float32)
y_test_src  = y_test_src.astype(np.uint8)
X_train_trg = X_train_trg.astype(np.float32)
y_train_trg = y_train_trg.astype(np.uint8)
X_test_trg  = X_test_trg.astype(np.float32)
y_test_trg  = y_test_trg.astype(np.uint8)

print(X_train_src.shape, y_train_src.shape,  X_test_src.shape, y_test_src.shape, X_train_trg.shape, y_train_trg.shape, X_test_trg.shape, y_test_trg.shape)
# Out:
# (9127, 224, 224, 1) (9127, 2)
#  ['arahman3', 'harika', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']
# (8737, 224, 224, 1) (8737, 2)
# (8547, 224, 224, 1) (8547, 2)
#  ['arahman3', 'hchen32', 'jlaivins', 'kjakkala', 'pjanakar', 'ppinyoan', 'pwang13', 'upattnai', 'wrang']
# (2308, 224, 224, 1) (2308, 9) (257, 224, 224, 1) (257, 9) (2563, 224, 224, 1) (2563, 9) (3419, 224, 224, 1) (3419, 9)

# %%
def get_trg_data(fname, src_classes, train_trg_days):
  #Read data
  hf = h5py.File(fname, 'r')
  X_data_trg = resize_data(np.expand_dims(hf.get('X_data'), axis=-1))
  y_data_trg = np.array(hf.get('y_data'))
  trg_classes = list(hf.get('classes'))
  trg_classes = [n.decode("ascii", "ignore") for n in trg_classes]
  hf.close()

  #split days of data to train and test
  X_train_trg = X_data_trg[y_data_trg[:, 1] < train_trg_days]
  y_train_trg = y_data_trg[y_data_trg[:, 1] < train_trg_days, 0]
  y_train_trg = np.array([src_classes.index(trg_classes[y_train_trg[i]]) for i in range(y_train_trg.shape[0])])
  y_train_trg = np.eye(len(src_classes))[y_train_trg]
  y_train_trg = y_train_trg.astype(np.int64)

  X_test_trg = X_data_trg[y_data_trg[:, 1] >= train_trg_days]
  y_test_trg = y_data_trg[y_data_trg[:, 1] >= train_trg_days, 0]
  y_test_trg = np.eye(len(src_classes))[y_test_trg]
  y_test_trg = y_test_trg.astype(np.int64)

  #standardise dataset  
  trg_mean     = np.mean(X_train_trg)
  X_train_trg -= trg_mean
  trg_std      = np.std(X_train_trg)
  X_train_trg /= trg_std

  X_test_trg  -= trg_mean
  X_test_trg  /= trg_std
  
  return X_train_trg.astype(np.float32), y_train_trg.astype(np.uint8), X_test_trg.astype(np.float32), y_test_trg.astype(np.uint8)

X_train_conf,   y_train_conf,   X_test_conf,   y_test_conf   = get_trg_data('/home/kjakkala/mmwave/data/target_conf_data.h5',   classes, train_trg_env_days)
X_train_server, y_train_server, X_test_server, y_test_server = get_trg_data('/home/kjakkala/mmwave/data/target_server_data.h5', classes, train_trg_env_days)
X_data_office,  y_data_office,  _,             _             = get_trg_data('/home/kjakkala/mmwave/data/target_office_data.h5', classes, 3)

print(X_train_conf.shape,   y_train_conf.shape,    X_test_conf.shape,   y_test_conf.shape)
print(X_train_server.shape, y_train_server.shape,  X_test_server.shape, y_test_server.shape)
print(X_data_office.shape, y_data_office.shape)
# Out:
# (900, 224, 224, 1) (900, 9) (450, 224, 224, 1) (450, 9)
# (898, 224, 224, 1) (898, 9) (448, 224, 224, 1) (448, 9)
# (899, 224, 224, 1) (899, 9)

# %%
#get tf.data objects for each set

#Test
conf_test_set = tf.data.Dataset.from_tensor_slices((X_test_conf, y_test_conf))
conf_test_set = conf_test_set.batch(batch_size, drop_remainder=False)
conf_test_set = conf_test_set.prefetch(batch_size)

server_test_set = tf.data.Dataset.from_tensor_slices((X_test_server, y_test_server))
server_test_set = server_test_set.batch(batch_size, drop_remainder=False)
server_test_set = server_test_set.prefetch(batch_size)

office_test_set = tf.data.Dataset.from_tensor_slices((X_data_office, y_data_office))
office_test_set = office_test_set.batch(batch_size, drop_remainder=False)
office_test_set = office_test_set.prefetch(batch_size)

src_test_set = tf.data.Dataset.from_tensor_slices((X_test_src, y_test_src))
src_test_set = src_test_set.batch(batch_size, drop_remainder=False)
src_test_set = src_test_set.prefetch(batch_size)

trg_test_set = tf.data.Dataset.from_tensor_slices((X_test_trg, y_test_trg))
trg_test_set = trg_test_set.batch(batch_size, drop_remainder=False)
trg_test_set = trg_test_set.prefetch(batch_size)

#Train
src_train_set = tf.data.Dataset.from_tensor_slices((X_train_src, y_train_src))
src_train_set = src_train_set.shuffle(X_train_src.shape[0])
src_train_set = src_train_set.batch(batch_size, drop_remainder=True)
src_train_set = src_train_set.prefetch(batch_size)

server_train_set = tf.data.Dataset.from_tensor_slices((X_train_server, y_train_server))
server_train_set = server_train_set.shuffle(X_train_server.shape[0])
server_train_set = server_train_set.batch(batch_size, drop_remainder=True)
server_train_set = server_train_set.prefetch(batch_size)
server_train_set = server_train_set.repeat(-1)

conf_train_set = tf.data.Dataset.from_tensor_slices((X_train_conf, y_train_conf))
conf_train_set = conf_train_set.shuffle(X_train_conf.shape[0])
conf_train_set = conf_train_set.batch(batch_size, drop_remainder=True)
conf_train_set = conf_train_set.prefetch(batch_size)
conf_train_set = conf_train_set.repeat(-1)

if (X_train_trg.shape[0] > 0):
  time_train_set = tf.data.Dataset.from_tensor_slices((X_train_trg, y_train_trg))
  time_train_set = time_train_set.shuffle(X_train_trg.shape[0])
  time_train_set = time_train_set.batch(batch_size, drop_remainder=True)
  time_train_set = time_train_set.prefetch(batch_size)
  time_train_set = time_train_set.repeat(-1)

# %%
L2_WEIGHT_DECAY = 1e-4
BATCH_NORM_DECAY = 0.9
BATCH_NORM_EPSILON = 1e-5

class GaussianNoise(tf.keras.layers.Layer):
  def __init__(self, std):
    super(GaussianNoise, self).__init__()
    self.std = std

  def build(self, input_shapes):
    pass

  def call(self, inputs, training=False):
    eps = tf.random.normal(shape=tf.shape(inputs), mean=0.0, stddev=self.std)
    return tf.where(training, inputs + eps, inputs)

class IdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x = tf.keras.layers.add([x, input_tensor])
    x = tf.keras.layers.Activation(self.activation)(x)
    return x


"""A block that has a conv layer at shortcut.

Note that from stage 3,
the second conv layer at main path is with strides=(2, 2)
And the shortcut should have strides=(2, 2) as well

Args:
  kernel_size: the kernel size of middle conv layer at main path
  filters: list of integers, the filters of 3 conv layer at main path
  stage: integer, current stage label, used for generating layer names
  block: 'a','b'..., current block label, used for generating layer names
  strides: Strides for the second conv layer in the block.

Returns:
  A Keras model instance for the block.
"""
class ConvBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters, stage, block, strides=(2, 2), activation='relu'):
    self.activation = activation
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    super().__init__(name='stage-' + str(stage) + '_block-' + block)

    filters1, filters2, filters3 = filters
    bn_axis = -1

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2a')
    self.bn2a = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2a')

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size,
                                         strides=strides,
                                         padding='same',
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2b')
    self.bn2b = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2b')

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '2c')
    self.bn2c = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '2c')

    self.conv2s = tf.keras.layers.Conv2D(filters3, (1, 1),
                                         strides=strides,
                                         use_bias=False,
                                         kernel_initializer='he_normal',
                                         kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                         name=conv_name_base + '1')
    self.bn2s = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                   momentum=BATCH_NORM_DECAY,
                                                   epsilon=BATCH_NORM_EPSILON,
                                                   name=bn_name_base + '1')
    self.gauss1   = GaussianNoise(1)

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.keras.layers.Activation(self.activation)(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    shortcut = self.conv2s(input_tensor)
    shortcut = self.bn2s(shortcut, training=training)

    x = tf.keras.layers.add([x, shortcut])
    x = tf.keras.layers.Activation(self.activation)(x)
    x = self.gauss1(x)
    return x

class Discriminator(tf.keras.Model):
  def __init__(self, num_hidden, num_classes, activation='relu'):
    super().__init__(name='discriminator')  
    self.hidden_layers = []
    for dim in num_hidden:
      self.hidden_layers.append(tf.keras.layers.Dense(dim, activation=activation))
    self.logits = tf.keras.layers.Dense(num_classes, activation=None)

  def call(self, x):
    for layer in self.hidden_layers:
      x = layer(x)
    x = self.logits(x)

    return x
  
@tf.custom_gradient
def reverse_gradient(x, hp_lambda):
    def custom_grad(dy):
        return tf.math.multiply(tf.negative(dy), hp_lambda)
    return x, custom_grad
  
class GradientReversal(tf.keras.layers.Layer):
  def __init__(self):
    super(GradientReversal, self).__init__()
    
  def build(self, input_shapes):
    pass

  def call(self, inputs, lambda_hp):
    return reverse_gradient(inputs, lambda_hp)
  
"""Instantiates the ResNet50 architecture.

Args:
  num_classes: `int` number of classes for image classification.

Returns:
    A Keras model instance.
"""
class ResNet50(tf.keras.Model):
  def __init__(self, num_classes, num_features, num_hidden, activation='relu'):
    super().__init__(name='generator')
    bn_axis = -1
    self.activation = activation

    self.conv1 = tf.keras.layers.Conv2D(32, (7, 7),
                                        strides=(2, 2),
                                        padding='valid',
                                        use_bias=False,
                                        kernel_initializer='he_normal',
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='conv1')
    self.bn1 = tf.keras.layers.BatchNormalization(axis=bn_axis,
                                                  momentum=BATCH_NORM_DECAY,
                                                  epsilon=BATCH_NORM_EPSILON,
                                                  name='bn_conv1')
    self.act1 = tf.keras.layers.Activation(self.activation, name=self.activation+'1')
    self.max_pool1 = tf.keras.layers.MaxPooling2D((3, 3),
                                                  strides=(2, 2),
                                                  padding='same',
                                                  name='max_pool1')

    self.blocks = []
    self.blocks.append(ConvBlock(3, [32, 32, 128], strides=(1, 1), stage=2, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [32, 32, 128], stage=2, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=3, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=3, block='b', activation=self.activation))

    self.blocks.append(ConvBlock(3, [64, 64, 256], stage=4, block='a', activation=self.activation))
    self.blocks.append(IdentityBlock(3, [64, 64, 256], stage=4, block='b', activation=self.activation))

    self.avg_pool = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')
    self.fc1 = tf.keras.layers.Dense(num_features,
                                     activation=self.activation,
                                     kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                     kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                     name='fc1')
    
    self.disc = Discriminator(num_hidden, 4, activation=self.activation)
    
    self.logits = tf.keras.layers.Dense(num_classes,
                                        activation=None,
                                        kernel_initializer=tf.keras.initializers.RandomNormal(stddev=0.01),
                                        kernel_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        bias_regularizer=tf.keras.regularizers.l2(L2_WEIGHT_DECAY),
                                        name='logits')

  def call(self, img_input, training=False, lambda_hp=1):    
    x = self.conv1(img_input)
    x = self.bn1(x, training=training)
    x = self.act1(x)
    x = self.max_pool1(x)

    for block in self.blocks:
      x = block(x)

    x = self.avg_pool(x)
    fc1 = self.fc1(x)
    
    grad_rev = GradientReversal()(fc1, lambda_hp)
    disc_logits = self.disc(grad_rev)
    
    logits = self.logits(fc1)
    return logits, fc1, disc_logits

# %%
def get_cross_entropy_loss(labels, logits):
  loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits)
  return tf.reduce_mean(loss)

class CenterLoss():
    def __init__(self, batch_size, num_classes, len_features, alpha):
      self.centers = tf.Variable(tf.zeros([num_classes, len_features]),
                                 dtype=tf.float32,
                                 trainable=False)
      self.alpha = alpha
      self.num_classes = num_classes
      self.batch_size = batch_size    
      self.margin = tf.constant(100, dtype="float32")
      self.norm = lambda x: tf.reduce_sum(tf.square(x), 1)
      self.EdgeWeights = tf.ones((self.num_classes,self.num_classes)) - \
                                  tf.eye(self.num_classes)

    def get_center_loss(self, features, labels):
      labels = tf.reshape(tf.argmax(labels, axis=-1), [-1])
      centers0 = tf.math.unsorted_segment_mean(features, 
                                               labels, 
                                               self.num_classes)
      center_pairwise_dist = tf.transpose(self.norm(tf.expand_dims(centers0, 2) - \
                                                    tf.transpose(centers0)))
      self.inter_loss = tf.math.reduce_sum(tf.multiply(tf.maximum(0.0, self.margin - center_pairwise_dist), 
                                                       self.EdgeWeights))

      unique_label, unique_idx, unique_count = tf.unique_with_counts(labels)
      appear_times = tf.gather(unique_count, unique_idx)
      appear_times = tf.reshape(appear_times, [-1, 1])
      centers_batch = tf.gather(self.centers, labels)
      diff = centers_batch - features
      diff /= tf.cast((1 + appear_times), tf.float32)
      diff *= self.alpha
      self.centers_update_op = tf.compat.v1.scatter_sub(self.centers, 
                                                        labels, 
                                                        diff)

      self.intra_loss   = tf.nn.l2_loss(features - centers_batch)
      self.center_loss  = self.intra_loss + self.inter_loss
      self.center_loss /= (self.num_classes*self.batch_size+self.num_classes*self.num_classes)
      return self.center_loss
      
def virtual_adversarial_images(images, logits, pert_norm_radius=3.5):  
  with tf.GradientTape() as tape:
    # Get normalised noise matrix
    noise = tf.random.normal(shape=tf.shape(images))
    noise = 1e-6 * tf.nn.l2_normalize(noise, axis=tf.range(1, len(noise.shape)))

    # Add noise to image and get new logits
    noise_logits, _, _ = generator(images + noise, 
                                   tf.constant(False, dtype=tf.bool))

    # Get loss from noisey logits
    noise_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=logits, logits=noise_logits)
    noise_loss = tf.reduce_mean(noise_loss)

  # Based on perturbed image loss, get direction of greatest error
  adversarial_noise = tape.gradient(noise_loss, 
                                    [noise],
                                    unconnected_gradients='zero')[0]

  adversarial_noise = tf.nn.l2_normalize(adversarial_noise, 
                                         axis=tf.range(1, 4))

  # return images with adversarial perturbation
  return images + pert_norm_radius * adversarial_noise

def mixup_preprocess(x, y, batch_size, alpha=1):
    # random sample the lambda value from beta distribution.
    weight     = np.random.beta(alpha, alpha, batch_size)
    x_weight   = weight.reshape(batch_size, 1, 1, 1)
    y_weight   = weight.reshape(batch_size, 1)
    
    # Perform the mixup.
    indices = tf.random.shuffle(tf.range(batch_size))
    mixup_images = (x * x_weight) + (tf.gather(x, indices) * (1 - x_weight))
    mixup_labels = (y * y_weight) + (tf.gather(y, indices) * (1 - y_weight))    
    
    return mixup_images, tf.nn.softmax(mixup_labels)

# %%
train_total_loss         = tf.keras.metrics.Mean(name='train_total_loss')
train_domain_loss        = tf.keras.metrics.Mean(name='train_domain_loss')
train_src_vat_loss       = tf.keras.metrics.Mean(name='train_src_vat_loss')
train_trg_vat_loss       = tf.keras.metrics.Mean(name='train_trg_vat_loss')
train_src_mixup_loss     = tf.keras.metrics.Mean(name='train_src_mixup_loss')
train_trg_mixup_loss     = tf.keras.metrics.Mean(name='train_trg_mixup_loss')
train_cond_entropy_loss  = tf.keras.metrics.Mean(name='train_cond_entropy_loss')
train_cross_entropy_loss = tf.keras.metrics.Mean(name='train_cross_entropy_loss')
train_discriminator_loss = tf.keras.metrics.Mean(name='train_discriminator_loss')
src_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='src_test_accuracy')
trg_test_accuracy        = tf.keras.metrics.CategoricalAccuracy(name='trg_test_accuracy')
office_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='office_test_accuracy')
server_test_accuracy     = tf.keras.metrics.CategoricalAccuracy(name='server_test_accuracy')
conf_test_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='conf_test_accuracy')
src_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='src_train_accuracy')
trg_train_accuracy       = tf.keras.metrics.CategoricalAccuracy(name='trg_train_accuracy')

@tf.function
def train_gen_step(src_images, src_labels, trg_images_ser, trg_labels_ser, trg_images_conf, trg_labels_conf, trg_images, trg_labels, lambda_hp):  
  with tf.GradientTape() as gen_tape:
    #Logits
    src_logits, src_enc, src_disc                = generator(src_images,      training=True, lambda_hp=lambda_hp)
    trg_logits_ser, trg_enc_ser, trg_disc_ser    = generator(trg_images_ser,  training=True, lambda_hp=lambda_hp) 
    trg_logits_conf, trg_enc_conf, trg_disc_conf = generator(trg_images_conf, training=True, lambda_hp=lambda_hp) 
    trg_logits, trg_enc, trg_disc                = generator(trg_images,      training=True, lambda_hp=lambda_hp)
        
    #VAT
    src_adver_images            = virtual_adversarial_images(src_images, tf.nn.softmax(src_logits))
    src_adver_logits, _, _      = generator(tf.stop_gradient(src_adver_images), training=True)
    trg_adver_images_ser        = virtual_adversarial_images(trg_images_ser, tf.nn.softmax(trg_logits_ser))
    trg_adver_logits_ser, _, _  = generator(tf.stop_gradient(trg_adver_images_ser), training=True)
    trg_adver_images_conf       = virtual_adversarial_images(trg_images_conf, tf.nn.softmax(trg_logits_conf))
    trg_adver_logits_conf, _, _ = generator(tf.stop_gradient(trg_adver_images_conf), training=True)
    trg_adver_images            = virtual_adversarial_images(trg_images, tf.nn.softmax(trg_logits))
    trg_adver_logits, _, _      = generator(tf.stop_gradient(trg_adver_images), training=True)
    
    #MixUp
    src_mixup_images, src_mixup_labels = mixup_preprocess(src_images, src_logits, batch_size)
    src_mixup_logits, _, _             = generator(tf.stop_gradient(src_mixup_images),
                                                   training=True)
    trg_mixup_images_ser, trg_mixup_labels_ser = mixup_preprocess(trg_images_ser, trg_logits_ser, batch_size)
    trg_mixup_logits_ser, _, _                 = generator(tf.stop_gradient(trg_mixup_images_ser),
                                                           training=True)
    trg_mixup_images_conf, trg_mixup_labels_conf = mixup_preprocess(trg_images_conf, trg_logits_conf, batch_size)
    trg_mixup_logits_conf, _, _                  = generator(tf.stop_gradient(trg_mixup_images_conf),
                                                             training=True)
    trg_mixup_images, trg_mixup_labels      = mixup_preprocess(trg_images, trg_logits, batch_size)
    trg_mixup_logits, _, _                  = generator(tf.stop_gradient(trg_mixup_images),
                                                        training=True)
    
    cross_entropy_loss  = get_cross_entropy_loss(labels=src_labels, 
                                                 logits=src_logits)
    cross_cond_loss     = get_cross_entropy_loss(labels=tf.nn.softmax(tf.concat([trg_logits_ser, 
                                                                                 trg_logits_conf,
                                                                                 trg_logits], 0)), 
                                                 logits=tf.concat([trg_logits_ser, 
                                                                   trg_logits_conf,
                                                                   trg_logits], 0))
    
    src_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(src_logits)),
                                                 logits=src_adver_logits)
    trg_vat_loss        = get_cross_entropy_loss(labels=tf.nn.softmax(tf.stop_gradient(tf.concat([trg_logits_ser, 
                                                                                                  trg_logits_conf,
                                                                                                  trg_logits], 0))),
                                                 logits=tf.concat([trg_adver_logits_ser, 
                                                                   trg_adver_logits_conf,
                                                                   trg_adver_logits], 0))
    
    src_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(src_mixup_labels), 
                                                 logits=src_mixup_logits)
    trg_mixup_loss      = get_cross_entropy_loss(labels=tf.stop_gradient(tf.concat([trg_mixup_labels_ser, 
                                                                                    trg_mixup_labels_conf,
                                                                                    trg_mixup_labels], 0)), 
                                                 logits=tf.concat([trg_mixup_logits_ser, 
                                                                   trg_mixup_logits_conf,
                                                                   trg_mixup_logits], 0))
          
    batch_center_loss   = center_loss.get_center_loss(src_enc, src_labels)
    domain_loss         = get_cross_entropy_loss(labels=tf.one_hot(tf.cast(tf.concat([tf.zeros(tf.shape(src_disc)[0]),
                                                                                      tf.ones(tf.shape(trg_disc_ser)[0]),
                                                                                      tf.ones(tf.shape(trg_disc_conf)[0])*2,
                                                                                      tf.ones(tf.shape(trg_disc)[0])*3], 0), tf.uint8), 4),
                                                 logits = tf.concat([src_disc, 
                                                                     trg_disc_ser, 
                                                                     trg_disc_conf, 
                                                                     trg_disc], 0)) 

    total_loss = cross_entropy_loss + \
                 8e-2 * domain_loss + \
                 8e-2 * cross_cond_loss + \
                 1    * src_mixup_loss +\
                 8e-2 * trg_mixup_loss +\
                 8e-2 * trg_vat_loss + \
                 1    * src_vat_loss + \
                 1    * batch_center_loss
    
  gen_gradients = gen_tape.gradient(total_loss, generator.trainable_variables)
  with tf.control_dependencies([center_loss.centers_update_op]):
    gen_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))

  src_train_accuracy(src_labels, src_logits)
  trg_train_accuracy(tf.concat([trg_labels_ser, trg_labels_conf], 0), tf.concat([trg_logits_ser, trg_logits_conf], 0))
  train_cross_entropy_loss(cross_entropy_loss)
  train_cond_entropy_loss(cross_cond_loss)
  train_src_mixup_loss(src_mixup_loss)
  train_trg_mixup_loss(trg_mixup_loss)
  train_src_vat_loss(src_vat_loss)
  train_trg_vat_loss(trg_vat_loss)
  train_domain_loss(domain_loss)
  train_total_loss(total_loss)
  
@tf.function
def test_step(images):
  return generator(images, training=False)[0]

# %%
train_template = 'Epoch: {:03d}, TotalL: {:.4f}, CrossE: {:.4f}, CondE: {:.4f}, disc: {:.4f}, domain: {:.4f}, Src VAT: {:.4f}, Trg VAT: {:.4f}, Src MixUp: {:.4f}, Trg MixUp: {:.4f}, Src Train Acc: {:.2f}, Trg Train Acc: {:.2f}, '
test_template  = 'Src Test Acc: {:.2f}, Trg Test Acc: {:.2f}, Server Test Acc: {:.2f}, Office Test Acc: {:.2f}, Conf Test Acc: {:.2f}'

generator      = ResNet50(num_classes, num_features, num_hidden, gen_activation)
gen_optimizer  = tf.keras.optimizers.Adam(learning_rate = learning_rate, beta_1 = 0.5)
center_loss    = CenterLoss(batch_size, num_classes, num_features, alpha)

summary_writer = tf.contrib.summary.create_file_writer('../logs/{}'.format(log_data), flush_millis=10000)
summary_writer.set_as_default()
global_step = tf.train.get_or_create_global_step()

def log_loss():
  with tf.contrib.summary.always_record_summaries():
    tf.contrib.summary.scalar("train_total_loss", train_total_loss.result())
    tf.contrib.summary.scalar("train_cross_entropy_loss", train_cross_entropy_loss.result())
    tf.contrib.summary.scalar("train_cond_entropy_loss", train_cond_entropy_loss.result())
    tf.contrib.summary.scalar("src_train_accuracy", src_train_accuracy.result())
    tf.contrib.summary.scalar("trg_train_accuracy", trg_train_accuracy.result())
    tf.contrib.summary.scalar("train_discriminator_loss", train_discriminator_loss.result())
    tf.contrib.summary.scalar("train_domain_loss", train_domain_loss.result())
    tf.contrib.summary.scalar("train_src_vat_loss", train_src_vat_loss.result())
    tf.contrib.summary.scalar("train_trg_vat_loss", train_trg_vat_loss.result())
    tf.contrib.summary.scalar("train_src_mixup_loss", train_src_mixup_loss.result())
    tf.contrib.summary.scalar("train_trg_mixup_loss", train_trg_mixup_loss.result())
    tf.contrib.summary.scalar("src_test_accuracy", src_test_accuracy.result())
    tf.contrib.summary.scalar("trg_test_accuracy", trg_test_accuracy.result())
    tf.contrib.summary.scalar("office_test_accuracy", office_test_accuracy.result())
    tf.contrib.summary.scalar("server_test_accuracy", server_test_accuracy.result())
    tf.contrib.summary.scalar("conf_test_accuracy", conf_test_accuracy.result())

def get_lambda(p, delta=10):
  return ((2/(1 + np.exp(-delta*p))) - 1).astype(np.float32)

for epoch in range(epochs):  
  global_step.assign_add(1)  

  for source_data, target_data, server_data, conf_data in zip(src_train_set, time_train_set, server_train_set, conf_train_set):
    train_gen_step(source_data[0], source_data[1], server_data[0], server_data[1], conf_data[0], conf_data[1], target_data[0], target_data[1], get_lambda(epoch))

  print(train_template.format(epoch+1,
                              train_total_loss.result(),
                              train_cross_entropy_loss.result(),
                              train_cond_entropy_loss.result(),
                              train_discriminator_loss.result(),
                              train_domain_loss.result(),
                              train_src_vat_loss.result(),
                              train_trg_vat_loss.result(),
                              train_src_mixup_loss.result(),
                              train_trg_mixup_loss.result(),
                              src_train_accuracy.result()*100,
                              trg_train_accuracy.result()*100), end="")

  for data in trg_test_set:
    trg_test_accuracy(test_step(data[0]), data[1])
    
  for data in src_test_set:
    src_test_accuracy(test_step(data[0]), data[1])
    
  for data in office_test_set:
    office_test_accuracy(test_step(data[0]), data[1])
    
  for data in server_test_set:
    server_test_accuracy(test_step(data[0]), data[1])
    
  for data in conf_test_set:
    conf_test_accuracy(test_step(data[0]), data[1])
    
  print(test_template.format(src_test_accuracy.result()*100,
                             trg_test_accuracy.result()*100,
                             server_test_accuracy.result()*100,
                             office_test_accuracy.result()*100,
                             conf_test_accuracy.result()*100))

  log_loss()
  
  train_total_loss.reset_states()
  train_cross_entropy_loss.reset_states()
  train_cond_entropy_loss.reset_states()
  src_train_accuracy.reset_states()
  trg_train_accuracy.reset_states()
  train_discriminator_loss.reset_states()
  train_domain_loss.reset_states()
  train_src_vat_loss.reset_states()
  train_trg_vat_loss.reset_states()
  train_src_mixup_loss.reset_states()
  train_trg_mixup_loss.reset_states()
  src_test_accuracy.reset_states()
  trg_test_accuracy.reset_states()
  server_test_accuracy.reset_states()
  office_test_accuracy.reset_states()
  conf_test_accuracy.reset_states()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0909 16:08:30.918821 140116161996544 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0909 16:08:34.098748 140116161996544 deprecation.py:323] From /home/kjakkala/.local/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:4075: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch: 001, TotalL: 20.1823, CrossE: 2.0974, CondE: 2.1622, disc: 0.0000, domain: 1.4067, Src VAT: 2.1628, Trg VAT: 2.1622, Src MixUp: 2.1723, Trg MixUp: 2.1731, Src Train Acc: 19.40, Trg Train Acc: 16.30, Src Test Acc: 15.95, Trg Test Acc: 19.16, Server Test Acc: 18.08, Office Test Acc: 14.91, Conf Test Acc: 20.00
# Epoch: 002, TotalL: 16.9834, CrossE: 1.8856, CondE: 2.0331, disc: 0.0000, domain: 1.4585, Src VAT: 2.0336, Trg VAT: 2.0331, Src MixUp: 2.0766, Trg MixUp: 2.0884, Src Train Acc: 27.52, Trg Train Acc: 22.24, Src Test Acc: 18.29, Trg Test Acc: 21.15, Server Test Acc: 21.43, Office Test Acc: 20.91, Conf Test Acc: 22.89
# Epoch: 003, TotalL: 16.2617, CrossE: 1.7826, CondE: 1.9306, disc: 0.0000, domain: 1.3746, Src VAT: 1.9264, Trg VAT: 1.9306, Src MixUp: 2.0284, Trg MixUp: 2.0111, Src Train Acc: 30.51, Trg Train Acc: 23.70, Src Test Acc: 25.68, Trg Test Acc: 28.43, Server Test Acc: 24.11, Office Test Acc: 28.81, Conf Test Acc: 29.56
# Epoch: 004, TotalL: 15.7739, CrossE: 1.7205, CondE: 1.8759, disc: 0.0000, domain: 1.3535, Src VAT: 1.8679, Trg VAT: 1.8759, Src MixUp: 1.9865, Trg MixUp: 1.9695, Src Train Acc: 33.51, Trg Train Acc: 24.85, Src Test Acc: 34.24, Trg Test Acc: 33.96, Server Test Acc: 26.34, Office Test Acc: 29.03, Conf Test Acc: 30.22
# Epoch: 005, TotalL: 15.3833, CrossE: 1.6549, CondE: 1.8224, disc: 0.0000, domain: 1.3339, Src VAT: 1.8123, Trg VAT: 1.8224, Src MixUp: 1.9550, Trg MixUp: 1.9292, Src Train Acc: 37.72, Trg Train Acc: 25.98, Src Test Acc: 35.41, Trg Test Acc: 35.07, Server Test Acc: 24.78, Office Test Acc: 29.25, Conf Test Acc: 32.22
# Epoch: 006, TotalL: 15.0155, CrossE: 1.5812, CondE: 1.7781, disc: 0.0000, domain: 1.3201, Src VAT: 1.7672, Trg VAT: 1.7781, Src MixUp: 1.9335, Trg MixUp: 1.8987, Src Train Acc: 42.01, Trg Train Acc: 27.04, Src Test Acc: 40.08, Trg Test Acc: 37.26, Server Test Acc: 25.22, Office Test Acc: 31.48, Conf Test Acc: 32.22
# Epoch: 007, TotalL: 14.5683, CrossE: 1.4738, CondE: 1.7266, disc: 0.0000, domain: 1.2806, Src VAT: 1.7102, Trg VAT: 1.7266, Src MixUp: 1.8805, Trg MixUp: 1.8597, Src Train Acc: 46.01, Trg Train Acc: 29.51, Src Test Acc: 43.97, Trg Test Acc: 37.09, Server Test Acc: 25.45, Office Test Acc: 31.26, Conf Test Acc: 35.78
# Epoch: 008, TotalL: 14.2091, CrossE: 1.3842, CondE: 1.6629, disc: 0.0000, domain: 1.2702, Src VAT: 1.6400, Trg VAT: 1.6629, Src MixUp: 1.8420, Trg MixUp: 1.8071, Src Train Acc: 49.39, Trg Train Acc: 31.32, Src Test Acc: 50.19, Trg Test Acc: 41.01, Server Test Acc: 29.02, Office Test Acc: 35.26, Conf Test Acc: 36.67
# Epoch: 009, TotalL: 13.7850, CrossE: 1.2767, CondE: 1.5947, disc: 0.0000, domain: 1.2497, Src VAT: 1.5638, Trg VAT: 1.5947, Src MixUp: 1.7876, Trg MixUp: 1.7604, Src Train Acc: 53.30, Trg Train Acc: 33.16, Src Test Acc: 51.36, Trg Test Acc: 45.28, Server Test Acc: 31.03, Office Test Acc: 37.49, Conf Test Acc: 38.00
# Epoch: 010, TotalL: 13.3374, CrossE: 1.1520, CondE: 1.5223, disc: 0.0000, domain: 1.2384, Src VAT: 1.4772, Trg VAT: 1.5223, Src MixUp: 1.7393, Trg MixUp: 1.7040, Src Train Acc: 59.85, Trg Train Acc: 35.94, Src Test Acc: 58.75, Trg Test Acc: 49.43, Server Test Acc: 32.81, Office Test Acc: 39.04, Conf Test Acc: 39.78
# Epoch: 011, TotalL: 12.9233, CrossE: 1.0556, CondE: 1.4519, disc: 0.0000, domain: 1.2262, Src VAT: 1.3895, Trg VAT: 1.4519, Src MixUp: 1.6753, Trg MixUp: 1.6411, Src Train Acc: 64.02, Trg Train Acc: 37.67, Src Test Acc: 56.03, Trg Test Acc: 45.36, Server Test Acc: 35.04, Office Test Acc: 39.15, Conf Test Acc: 38.22
# Epoch: 012, TotalL: 12.5055, CrossE: 0.9514, CondE: 1.3884, disc: 0.0000, domain: 1.2259, Src VAT: 1.3040, Trg VAT: 1.3884, Src MixUp: 1.6160, Trg MixUp: 1.5996, Src Train Acc: 68.58, Trg Train Acc: 40.17, Src Test Acc: 60.70, Trg Test Acc: 50.69, Server Test Acc: 36.61, Office Test Acc: 42.38, Conf Test Acc: 40.00
# Epoch: 013, TotalL: 12.0981, CrossE: 0.8484, CondE: 1.3225, disc: 0.0000, domain: 1.2074, Src VAT: 1.2147, Trg VAT: 1.3225, Src MixUp: 1.5512, Trg MixUp: 1.5506, Src Train Acc: 72.87, Trg Train Acc: 41.49, Src Test Acc: 64.20, Trg Test Acc: 54.90, Server Test Acc: 38.39, Office Test Acc: 43.38, Conf Test Acc: 39.33
# Epoch: 014, TotalL: 11.7683, CrossE: 0.7747, CondE: 1.2620, disc: 0.0000, domain: 1.2004, Src VAT: 1.1332, Trg VAT: 1.2620, Src MixUp: 1.5003, Trg MixUp: 1.5080, Src Train Acc: 76.09, Trg Train Acc: 42.64, Src Test Acc: 68.09, Trg Test Acc: 58.91, Server Test Acc: 40.40, Office Test Acc: 41.05, Conf Test Acc: 44.00
# Epoch: 015, TotalL: 11.4225, CrossE: 0.6849, CondE: 1.2111, disc: 0.0000, domain: 1.1893, Src VAT: 1.0494, Trg VAT: 1.2111, Src MixUp: 1.4716, Trg MixUp: 1.4707, Src Train Acc: 79.34, Trg Train Acc: 45.38, Src Test Acc: 70.43, Trg Test Acc: 59.67, Server Test Acc: 41.07, Office Test Acc: 40.38, Conf Test Acc: 43.11
# Epoch: 016, TotalL: 11.0846, CrossE: 0.6080, CondE: 1.1605, disc: 0.0000, domain: 1.1760, Src VAT: 0.9708, Trg VAT: 1.1605, Src MixUp: 1.4019, Trg MixUp: 1.4361, Src Train Acc: 82.25, Trg Train Acc: 47.79, Src Test Acc: 73.93, Trg Test Acc: 61.36, Server Test Acc: 45.76, Office Test Acc: 40.38, Conf Test Acc: 48.44
# Epoch: 017, TotalL: 10.7818, CrossE: 0.5373, CondE: 1.1154, disc: 0.0000, domain: 1.1765, Src VAT: 0.8988, Trg VAT: 1.1154, Src MixUp: 1.3596, Trg MixUp: 1.4052, Src Train Acc: 85.55, Trg Train Acc: 49.74, Src Test Acc: 75.49, Trg Test Acc: 64.93, Server Test Acc: 45.54, Office Test Acc: 39.15, Conf Test Acc: 50.44
# Epoch: 018, TotalL: 10.4940, CrossE: 0.4644, CondE: 1.0614, disc: 0.0000, domain: 1.1761, Src VAT: 0.8204, Trg VAT: 1.0614, Src MixUp: 1.3313, Trg MixUp: 1.3620, Src Train Acc: 87.50, Trg Train Acc: 51.26, Src Test Acc: 77.43, Trg Test Acc: 66.57, Server Test Acc: 46.43, Office Test Acc: 45.38, Conf Test Acc: 49.11
# Epoch: 019, TotalL: 10.1783, CrossE: 0.4036, CondE: 1.0232, disc: 0.0000, domain: 1.1709, Src VAT: 0.7489, Trg VAT: 1.0232, Src MixUp: 1.2533, Trg MixUp: 1.3472, Src Train Acc: 90.32, Trg Train Acc: 52.86, Src Test Acc: 80.16, Trg Test Acc: 65.72, Server Test Acc: 45.76, Office Test Acc: 42.60, Conf Test Acc: 52.00
# Epoch: 020, TotalL: 9.9663, CrossE: 0.3561, CondE: 0.9802, disc: 0.0000, domain: 1.1682, Src VAT: 0.6822, Trg VAT: 0.9802, Src MixUp: 1.2260, Trg MixUp: 1.3073, Src Train Acc: 91.84, Trg Train Acc: 54.51, Src Test Acc: 85.21, Trg Test Acc: 70.11, Server Test Acc: 47.32, Office Test Acc: 42.27, Conf Test Acc: 52.00
# Epoch: 021, TotalL: 9.7075, CrossE: 0.2981, CondE: 0.9432, disc: 0.0000, domain: 1.1650, Src VAT: 0.6223, Trg VAT: 0.9432, Src MixUp: 1.1908, Trg MixUp: 1.2897, Src Train Acc: 94.14, Trg Train Acc: 56.71, Src Test Acc: 87.94, Trg Test Acc: 72.48, Server Test Acc: 50.22, Office Test Acc: 41.49, Conf Test Acc: 54.89
# Epoch: 022, TotalL: 9.4608, CrossE: 0.2517, CondE: 0.8998, disc: 0.0000, domain: 1.1690, Src VAT: 0.5596, Trg VAT: 0.8998, Src MixUp: 1.1298, Trg MixUp: 1.2380, Src Train Acc: 95.40, Trg Train Acc: 58.49, Src Test Acc: 85.99, Trg Test Acc: 72.77, Server Test Acc: 49.55, Office Test Acc: 42.71, Conf Test Acc: 56.22
# Epoch: 023, TotalL: 9.2971, CrossE: 0.2200, CondE: 0.8729, disc: 0.0000, domain: 1.1698, Src VAT: 0.5140, Trg VAT: 0.8729, Src MixUp: 1.1071, Trg MixUp: 1.2367, Src Train Acc: 95.92, Trg Train Acc: 60.05, Src Test Acc: 85.60, Trg Test Acc: 73.85, Server Test Acc: 50.00, Office Test Acc: 48.72, Conf Test Acc: 56.00
# Epoch: 024, TotalL: 9.1267, CrossE: 0.1896, CondE: 0.8428, disc: 0.0000, domain: 1.1645, Src VAT: 0.4691, Trg VAT: 0.8428, Src MixUp: 1.0719, Trg MixUp: 1.2047, Src Train Acc: 97.27, Trg Train Acc: 61.83, Src Test Acc: 85.99, Trg Test Acc: 76.16, Server Test Acc: 53.12, Office Test Acc: 46.61, Conf Test Acc: 60.44
# Epoch: 025, TotalL: 8.9591, CrossE: 0.1601, CondE: 0.8172, disc: 0.0000, domain: 1.1638, Src VAT: 0.4280, Trg VAT: 0.8172, Src MixUp: 1.0292, Trg MixUp: 1.1969, Src Train Acc: 97.83, Trg Train Acc: 63.06, Src Test Acc: 83.66, Trg Test Acc: 73.71, Server Test Acc: 53.79, Office Test Acc: 51.06, Conf Test Acc: 59.78
# Epoch: 026, TotalL: 8.8278, CrossE: 0.1378, CondE: 0.7865, disc: 0.0000, domain: 1.1695, Src VAT: 0.3834, Trg VAT: 0.7865, Src MixUp: 1.0184, Trg MixUp: 1.1799, Src Train Acc: 98.13, Trg Train Acc: 64.39, Src Test Acc: 85.21, Trg Test Acc: 71.66, Server Test Acc: 54.69, Office Test Acc: 42.16, Conf Test Acc: 59.11
# Epoch: 027, TotalL: 8.6834, CrossE: 0.1162, CondE: 0.7730, disc: 0.0000, domain: 1.1607, Src VAT: 0.3585, Trg VAT: 0.7730, Src MixUp: 0.9779, Trg MixUp: 1.1481, Src Train Acc: 98.91, Trg Train Acc: 65.54, Src Test Acc: 87.55, Trg Test Acc: 78.97, Server Test Acc: 54.24, Office Test Acc: 52.95, Conf Test Acc: 59.78
# Epoch: 028, TotalL: 8.5583, CrossE: 0.0987, CondE: 0.7550, disc: 0.0000, domain: 1.1610, Src VAT: 0.3169, Trg VAT: 0.7550, Src MixUp: 0.9505, Trg MixUp: 1.1437, Src Train Acc: 99.05, Trg Train Acc: 65.65, Src Test Acc: 88.72, Trg Test Acc: 77.24, Server Test Acc: 51.79, Office Test Acc: 54.84, Conf Test Acc: 60.67
# Epoch: 029, TotalL: 8.5307, CrossE: 0.0965, CondE: 0.7380, disc: 0.0000, domain: 1.1680, Src VAT: 0.3052, Trg VAT: 0.7380, Src MixUp: 0.9353, Trg MixUp: 1.1283, Src Train Acc: 99.05, Trg Train Acc: 65.67, Src Test Acc: 93.39, Trg Test Acc: 83.18, Server Test Acc: 58.26, Office Test Acc: 48.83, Conf Test Acc: 62.22
# Epoch: 030, TotalL: 8.4061, CrossE: 0.0772, CondE: 0.7147, disc: 0.0000, domain: 1.1628, Src VAT: 0.2700, Trg VAT: 0.7147, Src MixUp: 0.9125, Trg MixUp: 1.1173, Src Train Acc: 99.48, Trg Train Acc: 67.64, Src Test Acc: 92.22, Trg Test Acc: 81.92, Server Test Acc: 55.36, Office Test Acc: 55.39, Conf Test Acc: 63.56
# Epoch: 031, TotalL: 8.3186, CrossE: 0.0666, CondE: 0.7004, disc: 0.0000, domain: 1.1549, Src VAT: 0.2506, Trg VAT: 0.7004, Src MixUp: 0.8924, Trg MixUp: 1.1096, Src Train Acc: 99.74, Trg Train Acc: 68.71, Src Test Acc: 86.77, Trg Test Acc: 78.85, Server Test Acc: 56.03, Office Test Acc: 46.50, Conf Test Acc: 62.67
# Epoch: 032, TotalL: 8.2859, CrossE: 0.0617, CondE: 0.6878, disc: 0.0000, domain: 1.1581, Src VAT: 0.2345, Trg VAT: 0.6878, Src MixUp: 0.8968, Trg MixUp: 1.0976, Src Train Acc: 99.61, Trg Train Acc: 69.57, Src Test Acc: 92.22, Trg Test Acc: 81.84, Server Test Acc: 54.02, Office Test Acc: 46.94, Conf Test Acc: 60.44
# Epoch: 033, TotalL: 8.1959, CrossE: 0.0552, CondE: 0.6822, disc: 0.0000, domain: 1.1557, Src VAT: 0.2218, Trg VAT: 0.6822, Src MixUp: 0.8535, Trg MixUp: 1.0988, Src Train Acc: 99.83, Trg Train Acc: 70.27, Src Test Acc: 88.72, Trg Test Acc: 79.76, Server Test Acc: 53.79, Office Test Acc: 54.51, Conf Test Acc: 61.33
# Epoch: 034, TotalL: 8.1455, CrossE: 0.0498, CondE: 0.6571, disc: 0.0000, domain: 1.1634, Src VAT: 0.2056, Trg VAT: 0.6571, Src MixUp: 0.8373, Trg MixUp: 1.0603, Src Train Acc: 99.87, Trg Train Acc: 69.97, Src Test Acc: 94.94, Trg Test Acc: 83.83, Server Test Acc: 56.03, Office Test Acc: 56.28, Conf Test Acc: 59.78
# Epoch: 035, TotalL: 8.0849, CrossE: 0.0461, CondE: 0.6434, disc: 0.0000, domain: 1.1551, Src VAT: 0.1911, Trg VAT: 0.6434, Src MixUp: 0.8175, Trg MixUp: 1.0605, Src Train Acc: 99.83, Trg Train Acc: 70.81, Src Test Acc: 94.94, Trg Test Acc: 85.49, Server Test Acc: 60.04, Office Test Acc: 57.62, Conf Test Acc: 64.00
# Epoch: 036, TotalL: 8.0344, CrossE: 0.0398, CondE: 0.6281, disc: 0.0000, domain: 1.1511, Src VAT: 0.1781, Trg VAT: 0.6281, Src MixUp: 0.7992, Trg MixUp: 1.0511, Src Train Acc: 99.91, Trg Train Acc: 71.55, Src Test Acc: 90.66, Trg Test Acc: 80.75, Server Test Acc: 58.04, Office Test Acc: 55.17, Conf Test Acc: 62.67
# Epoch: 037, TotalL: 7.9771, CrossE: 0.0371, CondE: 0.6115, disc: 0.0000, domain: 1.1503, Src VAT: 0.1641, Trg VAT: 0.6115, Src MixUp: 0.7717, Trg MixUp: 1.0334, Src Train Acc: 99.87, Trg Train Acc: 72.11, Src Test Acc: 89.49, Trg Test Acc: 79.73, Server Test Acc: 64.51, Office Test Acc: 54.17, Conf Test Acc: 65.11
# Epoch: 038, TotalL: 7.9661, CrossE: 0.0330, CondE: 0.6057, disc: 0.0000, domain: 1.1482, Src VAT: 0.1553, Trg VAT: 0.6057, Src MixUp: 0.7840, Trg MixUp: 1.0250, Src Train Acc: 99.91, Trg Train Acc: 71.92, Src Test Acc: 92.22, Trg Test Acc: 82.83, Server Test Acc: 61.61, Office Test Acc: 53.95, Conf Test Acc: 64.89
# Epoch: 039, TotalL: 7.9107, CrossE: 0.0311, CondE: 0.5902, disc: 0.0000, domain: 1.1393, Src VAT: 0.1492, Trg VAT: 0.5902, Src MixUp: 0.7430, Trg MixUp: 1.0033, Src Train Acc: 100.00, Trg Train Acc: 73.63, Src Test Acc: 94.16, Trg Test Acc: 86.90, Server Test Acc: 62.05, Office Test Acc: 56.73, Conf Test Acc: 67.11
# Epoch: 040, TotalL: 7.9304, CrossE: 0.0313, CondE: 0.5807, disc: 0.0000, domain: 1.1517, Src VAT: 0.1468, Trg VAT: 0.5807, Src MixUp: 0.7695, Trg MixUp: 1.0009, Src Train Acc: 100.00, Trg Train Acc: 73.46, Src Test Acc: 94.16, Trg Test Acc: 85.90, Server Test Acc: 64.29, Office Test Acc: 59.18, Conf Test Acc: 66.67
# Epoch: 041, TotalL: 7.8882, CrossE: 0.0277, CondE: 0.5626, disc: 0.0000, domain: 1.1495, Src VAT: 0.1318, Trg VAT: 0.5626, Src MixUp: 0.7586, Trg MixUp: 0.9927, Src Train Acc: 99.91, Trg Train Acc: 74.50, Src Test Acc: 91.44, Trg Test Acc: 81.05, Server Test Acc: 57.81, Office Test Acc: 48.16, Conf Test Acc: 64.89
# Epoch: 042, TotalL: 7.8515, CrossE: 0.0273, CondE: 0.5702, disc: 0.0000, domain: 1.1432, Src VAT: 0.1320, Trg VAT: 0.5702, Src MixUp: 0.7441, Trg MixUp: 0.9877, Src Train Acc: 99.96, Trg Train Acc: 73.83, Src Test Acc: 95.72, Trg Test Acc: 87.28, Server Test Acc: 57.14, Office Test Acc: 62.85, Conf Test Acc: 66.00
# Epoch: 043, TotalL: 7.8354, CrossE: 0.0243, CondE: 0.5671, disc: 0.0000, domain: 1.1375, Src VAT: 0.1255, Trg VAT: 0.5671, Src MixUp: 0.7518, Trg MixUp: 0.9720, Src Train Acc: 100.00, Trg Train Acc: 74.78, Src Test Acc: 94.55, Trg Test Acc: 87.92, Server Test Acc: 60.49, Office Test Acc: 61.96, Conf Test Acc: 67.11
# Epoch: 044, TotalL: 7.7809, CrossE: 0.0224, CondE: 0.5474, disc: 0.0000, domain: 1.1319, Src VAT: 0.1152, Trg VAT: 0.5474, Src MixUp: 0.7160, Trg MixUp: 0.9734, Src Train Acc: 99.96, Trg Train Acc: 75.30, Src Test Acc: 95.33, Trg Test Acc: 86.78, Server Test Acc: 60.71, Office Test Acc: 59.18, Conf Test Acc: 66.67
# Epoch: 045, TotalL: 7.7671, CrossE: 0.0215, CondE: 0.5462, disc: 0.0000, domain: 1.1402, Src VAT: 0.1125, Trg VAT: 0.5462, Src MixUp: 0.7192, Trg MixUp: 0.9628, Src Train Acc: 100.00, Trg Train Acc: 76.22, Src Test Acc: 93.00, Trg Test Acc: 85.29, Server Test Acc: 63.39, Office Test Acc: 56.84, Conf Test Acc: 66.67
# Epoch: 046, TotalL: 7.7507, CrossE: 0.0216, CondE: 0.5302, disc: 0.0000, domain: 1.1425, Src VAT: 0.1117, Trg VAT: 0.5302, Src MixUp: 0.6897, Trg MixUp: 0.9483, Src Train Acc: 100.00, Trg Train Acc: 76.54, Src Test Acc: 95.33, Trg Test Acc: 89.03, Server Test Acc: 64.96, Office Test Acc: 59.29, Conf Test Acc: 68.89
# Epoch: 047, TotalL: 7.7291, CrossE: 0.0213, CondE: 0.5122, disc: 0.0000, domain: 1.1437, Src VAT: 0.1030, Trg VAT: 0.5122, Src MixUp: 0.6867, Trg MixUp: 0.9377, Src Train Acc: 99.87, Trg Train Acc: 77.19, Src Test Acc: 97.28, Trg Test Acc: 88.45, Server Test Acc: 62.28, Office Test Acc: 57.73, Conf Test Acc: 66.89
# Epoch: 048, TotalL: 7.6880, CrossE: 0.0189, CondE: 0.5042, disc: 0.0000, domain: 1.1473, Src VAT: 0.0978, Trg VAT: 0.5042, Src MixUp: 0.6611, Trg MixUp: 0.9357, Src Train Acc: 99.96, Trg Train Acc: 76.78, Src Test Acc: 93.77, Trg Test Acc: 80.78, Server Test Acc: 58.71, Office Test Acc: 42.16, Conf Test Acc: 66.00
# Epoch: 049, TotalL: 7.6590, CrossE: 0.0169, CondE: 0.5028, disc: 0.0000, domain: 1.1421, Src VAT: 0.0906, Trg VAT: 0.5028, Src MixUp: 0.6559, Trg MixUp: 0.9304, Src Train Acc: 99.96, Trg Train Acc: 77.54, Src Test Acc: 96.50, Trg Test Acc: 88.39, Server Test Acc: 61.83, Office Test Acc: 62.63, Conf Test Acc: 65.11
# Epoch: 050, TotalL: 7.6692, CrossE: 0.0166, CondE: 0.4945, disc: 0.0000, domain: 1.1411, Src VAT: 0.0902, Trg VAT: 0.4945, Src MixUp: 0.6698, Trg MixUp: 0.9268, Src Train Acc: 100.00, Trg Train Acc: 77.52, Src Test Acc: 96.89, Trg Test Acc: 90.61, Server Test Acc: 66.96, Office Test Acc: 66.52, Conf Test Acc: 68.44
# Epoch: 051, TotalL: 7.6268, CrossE: 0.0144, CondE: 0.4880, disc: 0.0000, domain: 1.1397, Src VAT: 0.0833, Trg VAT: 0.4880, Src MixUp: 0.6546, Trg MixUp: 0.9064, Src Train Acc: 100.00, Trg Train Acc: 78.12, Src Test Acc: 96.50, Trg Test Acc: 88.48, Server Test Acc: 65.85, Office Test Acc: 64.29, Conf Test Acc: 66.22
# Epoch: 052, TotalL: 7.5706, CrossE: 0.0130, CondE: 0.4805, disc: 0.0000, domain: 1.1342, Src VAT: 0.0773, Trg VAT: 0.4805, Src MixUp: 0.6252, Trg MixUp: 0.9085, Src Train Acc: 100.00, Trg Train Acc: 79.67, Src Test Acc: 90.66, Trg Test Acc: 80.99, Server Test Acc: 52.68, Office Test Acc: 53.62, Conf Test Acc: 59.33
# Epoch: 053, TotalL: 7.5750, CrossE: 0.0134, CondE: 0.4667, disc: 0.0000, domain: 1.1436, Src VAT: 0.0768, Trg VAT: 0.4667, Src MixUp: 0.6168, Trg MixUp: 0.9007, Src Train Acc: 100.00, Trg Train Acc: 79.47, Src Test Acc: 94.94, Trg Test Acc: 86.96, Server Test Acc: 56.70, Office Test Acc: 62.29, Conf Test Acc: 64.00
# Epoch: 054, TotalL: 7.5904, CrossE: 0.0130, CondE: 0.4564, disc: 0.0000, domain: 1.1450, Src VAT: 0.0755, Trg VAT: 0.4564, Src MixUp: 0.6316, Trg MixUp: 0.8929, Src Train Acc: 100.00, Trg Train Acc: 79.45, Src Test Acc: 95.72, Trg Test Acc: 90.58, Server Test Acc: 63.17, Office Test Acc: 59.62, Conf Test Acc: 67.33
# Epoch: 055, TotalL: 7.5646, CrossE: 0.0123, CondE: 0.4547, disc: 0.0000, domain: 1.1433, Src VAT: 0.0717, Trg VAT: 0.4547, Src MixUp: 0.6201, Trg MixUp: 0.8782, Src Train Acc: 100.00, Trg Train Acc: 79.38, Src Test Acc: 97.28, Trg Test Acc: 89.76, Server Test Acc: 64.96, Office Test Acc: 59.73, Conf Test Acc: 66.00
# Epoch: 056, TotalL: 7.5701, CrossE: 0.0133, CondE: 0.4566, disc: 0.0000, domain: 1.1541, Src VAT: 0.0758, Trg VAT: 0.4566, Src MixUp: 0.6099, Trg MixUp: 0.8830, Src Train Acc: 100.00, Trg Train Acc: 79.75, Src Test Acc: 93.00, Trg Test Acc: 83.21, Server Test Acc: 60.71, Office Test Acc: 68.08, Conf Test Acc: 67.11
# Epoch: 057, TotalL: 7.5809, CrossE: 0.0123, CondE: 0.4515, disc: 0.0000, domain: 1.1545, Src VAT: 0.0707, Trg VAT: 0.4515, Src MixUp: 0.6350, Trg MixUp: 0.8756, Src Train Acc: 100.00, Trg Train Acc: 79.90, Src Test Acc: 95.33, Trg Test Acc: 89.06, Server Test Acc: 58.48, Office Test Acc: 67.52, Conf Test Acc: 66.22
# Epoch: 058, TotalL: 7.5154, CrossE: 0.0106, CondE: 0.4337, disc: 0.0000, domain: 1.1405, Src VAT: 0.0644, Trg VAT: 0.4337, Src MixUp: 0.6009, Trg MixUp: 0.8727, Src Train Acc: 100.00, Trg Train Acc: 81.81, Src Test Acc: 96.50, Trg Test Acc: 90.26, Server Test Acc: 68.30, Office Test Acc: 68.63, Conf Test Acc: 70.44
# Epoch: 059, TotalL: 7.4920, CrossE: 0.0102, CondE: 0.4331, disc: 0.0000, domain: 1.1395, Src VAT: 0.0623, Trg VAT: 0.4331, Src MixUp: 0.5820, Trg MixUp: 0.8662, Src Train Acc: 100.00, Trg Train Acc: 81.14, Src Test Acc: 96.89, Trg Test Acc: 89.53, Server Test Acc: 63.62, Office Test Acc: 71.30, Conf Test Acc: 68.89
# Epoch: 060, TotalL: 7.5096, CrossE: 0.0103, CondE: 0.4212, disc: 0.0000, domain: 1.1497, Src VAT: 0.0611, Trg VAT: 0.4212, Src MixUp: 0.5987, Trg MixUp: 0.8510, Src Train Acc: 100.00, Trg Train Acc: 81.68, Src Test Acc: 96.11, Trg Test Acc: 89.70, Server Test Acc: 69.64, Office Test Acc: 64.52, Conf Test Acc: 69.33
# Epoch: 061, TotalL: 7.5022, CrossE: 0.0095, CondE: 0.4128, disc: 0.0000, domain: 1.1552, Src VAT: 0.0583, Trg VAT: 0.4128, Src MixUp: 0.5934, Trg MixUp: 0.8342, Src Train Acc: 100.00, Trg Train Acc: 80.84, Src Test Acc: 97.28, Trg Test Acc: 87.36, Server Test Acc: 60.27, Office Test Acc: 60.18, Conf Test Acc: 68.00
# Epoch: 062, TotalL: 7.4821, CrossE: 0.0088, CondE: 0.4055, disc: 0.0000, domain: 1.1470, Src VAT: 0.0549, Trg VAT: 0.4055, Src MixUp: 0.5850, Trg MixUp: 0.8316, Src Train Acc: 100.00, Trg Train Acc: 82.05, Src Test Acc: 96.89, Trg Test Acc: 92.02, Server Test Acc: 67.86, Office Test Acc: 64.52, Conf Test Acc: 70.00
# Epoch: 063, TotalL: 7.4916, CrossE: 0.0110, CondE: 0.4035, disc: 0.0000, domain: 1.1574, Src VAT: 0.0579, Trg VAT: 0.4035, Src MixUp: 0.5741, Trg MixUp: 0.8328, Src Train Acc: 99.91, Trg Train Acc: 81.66, Src Test Acc: 97.67, Trg Test Acc: 91.78, Server Test Acc: 67.41, Office Test Acc: 68.19, Conf Test Acc: 73.11
# Epoch: 064, TotalL: 7.5191, CrossE: 0.0110, CondE: 0.3990, disc: 0.0000, domain: 1.1622, Src VAT: 0.0603, Trg VAT: 0.3990, Src MixUp: 0.5873, Trg MixUp: 0.8273, Src Train Acc: 100.00, Trg Train Acc: 81.62, Src Test Acc: 97.67, Trg Test Acc: 92.16, Server Test Acc: 69.42, Office Test Acc: 65.07, Conf Test Acc: 72.00
# Epoch: 065, TotalL: 7.4668, CrossE: 0.0082, CondE: 0.3863, disc: 0.0000, domain: 1.1429, Src VAT: 0.0511, Trg VAT: 0.3863, Src MixUp: 0.5865, Trg MixUp: 0.8223, Src Train Acc: 100.00, Trg Train Acc: 82.23, Src Test Acc: 97.28, Trg Test Acc: 90.99, Server Test Acc: 66.07, Office Test Acc: 66.30, Conf Test Acc: 70.44
# Epoch: 066, TotalL: 7.4069, CrossE: 0.0071, CondE: 0.3811, disc: 0.0000, domain: 1.1340, Src VAT: 0.0468, Trg VAT: 0.3811, Src MixUp: 0.5557, Trg MixUp: 0.8135, Src Train Acc: 100.00, Trg Train Acc: 83.16, Src Test Acc: 98.05, Trg Test Acc: 91.69, Server Test Acc: 68.08, Office Test Acc: 62.40, Conf Test Acc: 72.00
# Epoch: 067, TotalL: 7.4122, CrossE: 0.0071, CondE: 0.3756, disc: 0.0000, domain: 1.1450, Src VAT: 0.0465, Trg VAT: 0.3756, Src MixUp: 0.5573, Trg MixUp: 0.8019, Src Train Acc: 100.00, Trg Train Acc: 82.68, Src Test Acc: 96.89, Trg Test Acc: 89.15, Server Test Acc: 67.19, Office Test Acc: 61.40, Conf Test Acc: 69.78
# Epoch: 068, TotalL: 7.4102, CrossE: 0.0065, CondE: 0.3737, disc: 0.0000, domain: 1.1441, Src VAT: 0.0429, Trg VAT: 0.3737, Src MixUp: 0.5541, Trg MixUp: 0.8118, Src Train Acc: 100.00, Trg Train Acc: 82.10, Src Test Acc: 94.94, Trg Test Acc: 86.98, Server Test Acc: 61.61, Office Test Acc: 53.39, Conf Test Acc: 66.44
# Epoch: 069, TotalL: 7.4005, CrossE: 0.0068, CondE: 0.3660, disc: 0.0000, domain: 1.1409, Src VAT: 0.0447, Trg VAT: 0.3660, Src MixUp: 0.5500, Trg MixUp: 0.8010, Src Train Acc: 100.00, Trg Train Acc: 83.27, Src Test Acc: 96.89, Trg Test Acc: 91.49, Server Test Acc: 69.87, Office Test Acc: 68.85, Conf Test Acc: 73.33
# Epoch: 070, TotalL: 7.4244, CrossE: 0.0073, CondE: 0.3577, disc: 0.0000, domain: 1.1649, Src VAT: 0.0450, Trg VAT: 0.3577, Src MixUp: 0.5494, Trg MixUp: 0.7825, Src Train Acc: 100.00, Trg Train Acc: 82.86, Src Test Acc: 96.11, Trg Test Acc: 92.95, Server Test Acc: 72.77, Office Test Acc: 65.29, Conf Test Acc: 74.89
# Epoch: 071, TotalL: 7.4080, CrossE: 0.0066, CondE: 0.3558, disc: 0.0000, domain: 1.1538, Src VAT: 0.0434, Trg VAT: 0.3558, Src MixUp: 0.5559, Trg MixUp: 0.7841, Src Train Acc: 100.00, Trg Train Acc: 83.55, Src Test Acc: 97.28, Trg Test Acc: 92.54, Server Test Acc: 69.20, Office Test Acc: 65.29, Conf Test Acc: 72.89
# Epoch: 072, TotalL: 7.3680, CrossE: 0.0060, CondE: 0.3532, disc: 0.0000, domain: 1.1455, Src VAT: 0.0409, Trg VAT: 0.3532, Src MixUp: 0.5367, Trg MixUp: 0.7768, Src Train Acc: 100.00, Trg Train Acc: 84.57, Src Test Acc: 97.28, Trg Test Acc: 93.19, Server Test Acc: 67.63, Office Test Acc: 66.85, Conf Test Acc: 70.00
# Epoch: 073, TotalL: 7.3932, CrossE: 0.0070, CondE: 0.3455, disc: 0.0000, domain: 1.1623, Src VAT: 0.0427, Trg VAT: 0.3455, Src MixUp: 0.5432, Trg MixUp: 0.7695, Src Train Acc: 100.00, Trg Train Acc: 84.51, Src Test Acc: 97.67, Trg Test Acc: 92.95, Server Test Acc: 68.08, Office Test Acc: 67.96, Conf Test Acc: 72.89
# Epoch: 074, TotalL: 7.3727, CrossE: 0.0060, CondE: 0.3359, disc: 0.0000, domain: 1.1557, Src VAT: 0.0397, Trg VAT: 0.3359, Src MixUp: 0.5329, Trg MixUp: 0.7632, Src Train Acc: 100.00, Trg Train Acc: 84.70, Src Test Acc: 97.28, Trg Test Acc: 90.73, Server Test Acc: 63.39, Office Test Acc: 67.96, Conf Test Acc: 69.33
# Epoch: 075, TotalL: 7.3460, CrossE: 0.0055, CondE: 0.3307, disc: 0.0000, domain: 1.1554, Src VAT: 0.0369, Trg VAT: 0.3307, Src MixUp: 0.5173, Trg MixUp: 0.7560, Src Train Acc: 100.00, Trg Train Acc: 84.83, Src Test Acc: 96.50, Trg Test Acc: 90.49, Server Test Acc: 67.19, Office Test Acc: 64.96, Conf Test Acc: 70.89
# Epoch: 076, TotalL: 7.3538, CrossE: 0.0056, CondE: 0.3268, disc: 0.0000, domain: 1.1613, Src VAT: 0.0364, Trg VAT: 0.3268, Src MixUp: 0.5281, Trg MixUp: 0.7578, Src Train Acc: 99.96, Trg Train Acc: 84.98, Src Test Acc: 96.89, Trg Test Acc: 90.87, Server Test Acc: 62.72, Office Test Acc: 69.74, Conf Test Acc: 67.78
# Epoch: 077, TotalL: 7.3775, CrossE: 0.0059, CondE: 0.3335, disc: 0.0000, domain: 1.1684, Src VAT: 0.0377, Trg VAT: 0.3335, Src MixUp: 0.5308, Trg MixUp: 0.7594, Src Train Acc: 100.00, Trg Train Acc: 84.35, Src Test Acc: 96.89, Trg Test Acc: 90.73, Server Test Acc: 66.96, Office Test Acc: 67.30, Conf Test Acc: 68.44
# Epoch: 078, TotalL: 7.3441, CrossE: 0.0049, CondE: 0.3197, disc: 0.0000, domain: 1.1632, Src VAT: 0.0341, Trg VAT: 0.3197, Src MixUp: 0.5216, Trg MixUp: 0.7592, Src Train Acc: 100.00, Trg Train Acc: 84.98, Src Test Acc: 96.89, Trg Test Acc: 92.51, Server Test Acc: 71.43, Office Test Acc: 69.52, Conf Test Acc: 74.00
# Epoch: 079, TotalL: 7.3148, CrossE: 0.0050, CondE: 0.3212, disc: 0.0000, domain: 1.1557, Src VAT: 0.0347, Trg VAT: 0.3212, Src MixUp: 0.5079, Trg MixUp: 0.7586, Src Train Acc: 100.00, Trg Train Acc: 85.98, Src Test Acc: 95.72, Trg Test Acc: 89.70, Server Test Acc: 64.96, Office Test Acc: 71.52, Conf Test Acc: 68.89
# Epoch: 080, TotalL: 7.3160, CrossE: 0.0048, CondE: 0.3146, disc: 0.0000, domain: 1.1521, Src VAT: 0.0334, Trg VAT: 0.3146, Src MixUp: 0.5106, Trg MixUp: 0.7381, Src Train Acc: 100.00, Trg Train Acc: 86.31, Src Test Acc: 97.28, Trg Test Acc: 93.21, Server Test Acc: 75.89, Office Test Acc: 68.63, Conf Test Acc: 73.33
# Epoch: 081, TotalL: 7.2948, CrossE: 0.0047, CondE: 0.3091, disc: 0.0000, domain: 1.1625, Src VAT: 0.0328, Trg VAT: 0.3091, Src MixUp: 0.4959, Trg MixUp: 0.7390, Src Train Acc: 100.00, Trg Train Acc: 86.35, Src Test Acc: 94.94, Trg Test Acc: 88.71, Server Test Acc: 60.27, Office Test Acc: 71.64, Conf Test Acc: 63.78
# Epoch: 082, TotalL: 7.2990, CrossE: 0.0048, CondE: 0.3059, disc: 0.0000, domain: 1.1593, Src VAT: 0.0333, Trg VAT: 0.3059, Src MixUp: 0.4966, Trg MixUp: 0.7285, Src Train Acc: 100.00, Trg Train Acc: 86.63, Src Test Acc: 98.05, Trg Test Acc: 93.48, Server Test Acc: 70.76, Office Test Acc: 66.74, Conf Test Acc: 72.22
# Epoch: 083, TotalL: 7.3077, CrossE: 0.0050, CondE: 0.2983, disc: 0.0000, domain: 1.1766, Src VAT: 0.0329, Trg VAT: 0.2983, Src MixUp: 0.4784, Trg MixUp: 0.7372, Src Train Acc: 100.00, Trg Train Acc: 85.87, Src Test Acc: 97.67, Trg Test Acc: 91.46, Server Test Acc: 66.29, Office Test Acc: 63.18, Conf Test Acc: 68.89
# Epoch: 084, TotalL: 7.2940, CrossE: 0.0044, CondE: 0.2995, disc: 0.0000, domain: 1.1702, Src VAT: 0.0304, Trg VAT: 0.2995, Src MixUp: 0.4876, Trg MixUp: 0.7255, Src Train Acc: 100.00, Trg Train Acc: 85.46, Src Test Acc: 97.67, Trg Test Acc: 93.27, Server Test Acc: 70.31, Office Test Acc: 64.40, Conf Test Acc: 70.89
# Epoch: 085, TotalL: 7.2693, CrossE: 0.0043, CondE: 0.2963, disc: 0.0000, domain: 1.1698, Src VAT: 0.0301, Trg VAT: 0.2963, Src MixUp: 0.4687, Trg MixUp: 0.7348, Src Train Acc: 100.00, Trg Train Acc: 86.24, Src Test Acc: 94.94, Trg Test Acc: 90.90, Server Test Acc: 68.30, Office Test Acc: 60.07, Conf Test Acc: 72.22
# Epoch: 086, TotalL: 7.2805, CrossE: 0.0041, CondE: 0.2766, disc: 0.0000, domain: 1.1761, Src VAT: 0.0285, Trg VAT: 0.2766, Src MixUp: 0.4690, Trg MixUp: 0.7032, Src Train Acc: 100.00, Trg Train Acc: 87.24, Src Test Acc: 97.28, Trg Test Acc: 93.80, Server Test Acc: 72.54, Office Test Acc: 71.41, Conf Test Acc: 73.11
# Epoch: 087, TotalL: 7.2489, CrossE: 0.0032, CondE: 0.2714, disc: 0.0000, domain: 1.1647, Src VAT: 0.0238, Trg VAT: 0.2714, Src MixUp: 0.4624, Trg MixUp: 0.7117, Src Train Acc: 100.00, Trg Train Acc: 87.48, Src Test Acc: 98.05, Trg Test Acc: 93.65, Server Test Acc: 73.66, Office Test Acc: 69.97, Conf Test Acc: 74.44
# Epoch: 088, TotalL: 7.2522, CrossE: 0.0034, CondE: 0.2754, disc: 0.0000, domain: 1.1521, Src VAT: 0.0252, Trg VAT: 0.2754, Src MixUp: 0.4825, Trg MixUp: 0.7057, Src Train Acc: 100.00, Trg Train Acc: 87.59, Src Test Acc: 97.28, Trg Test Acc: 91.84, Server Test Acc: 68.30, Office Test Acc: 70.86, Conf Test Acc: 70.89
# Epoch: 089, TotalL: 7.2570, CrossE: 0.0036, CondE: 0.2770, disc: 0.0000, domain: 1.1674, Src VAT: 0.0263, Trg VAT: 0.2770, Src MixUp: 0.4724, Trg MixUp: 0.7136, Src Train Acc: 100.00, Trg Train Acc: 87.52, Src Test Acc: 97.28, Trg Test Acc: 91.37, Server Test Acc: 70.98, Office Test Acc: 62.18, Conf Test Acc: 70.00
# Epoch: 090, TotalL: 7.2557, CrossE: 0.0036, CondE: 0.2746, disc: 0.0000, domain: 1.1661, Src VAT: 0.0259, Trg VAT: 0.2746, Src MixUp: 0.4673, Trg MixUp: 0.7041, Src Train Acc: 100.00, Trg Train Acc: 86.83, Src Test Acc: 97.28, Trg Test Acc: 93.95, Server Test Acc: 72.32, Office Test Acc: 67.74, Conf Test Acc: 70.67
# Epoch: 091, TotalL: 7.2388, CrossE: 0.0035, CondE: 0.2668, disc: 0.0000, domain: 1.1671, Src VAT: 0.0249, Trg VAT: 0.2668, Src MixUp: 0.4610, Trg MixUp: 0.6969, Src Train Acc: 100.00, Trg Train Acc: 87.54, Src Test Acc: 98.83, Trg Test Acc: 93.19, Server Test Acc: 65.40, Office Test Acc: 73.19, Conf Test Acc: 69.11
# Epoch: 092, TotalL: 7.2410, CrossE: 0.0035, CondE: 0.2670, disc: 0.0000, domain: 1.1745, Src VAT: 0.0252, Trg VAT: 0.2670, Src MixUp: 0.4566, Trg MixUp: 0.7005, Src Train Acc: 100.00, Trg Train Acc: 87.07, Src Test Acc: 97.28, Trg Test Acc: 91.63, Server Test Acc: 77.23, Office Test Acc: 61.62, Conf Test Acc: 74.44
# Epoch: 093, TotalL: 7.2450, CrossE: 0.0032, CondE: 0.2600, disc: 0.0000, domain: 1.1743, Src VAT: 0.0237, Trg VAT: 0.2600, Src MixUp: 0.4675, Trg MixUp: 0.7000, Src Train Acc: 100.00, Trg Train Acc: 87.70, Src Test Acc: 98.44, Trg Test Acc: 94.24, Server Test Acc: 69.20, Office Test Acc: 71.19, Conf Test Acc: 72.00
# Epoch: 094, TotalL: 7.2308, CrossE: 0.0032, CondE: 0.2553, disc: 0.0000, domain: 1.1677, Src VAT: 0.0236, Trg VAT: 0.2553, Src MixUp: 0.4635, Trg MixUp: 0.6855, Src Train Acc: 100.00, Trg Train Acc: 88.19, Src Test Acc: 98.44, Trg Test Acc: 94.00, Server Test Acc: 69.64, Office Test Acc: 70.08, Conf Test Acc: 73.56
# Epoch: 095, TotalL: 7.2510, CrossE: 0.0034, CondE: 0.2539, disc: 0.0000, domain: 1.1839, Src VAT: 0.0239, Trg VAT: 0.2539, Src MixUp: 0.4706, Trg MixUp: 0.6774, Src Train Acc: 100.00, Trg Train Acc: 87.98, Src Test Acc: 97.28, Trg Test Acc: 93.57, Server Test Acc: 71.21, Office Test Acc: 75.53, Conf Test Acc: 73.56
# Epoch: 096, TotalL: 7.2111, CrossE: 0.0029, CondE: 0.2504, disc: 0.0000, domain: 1.1703, Src VAT: 0.0221, Trg VAT: 0.2504, Src MixUp: 0.4511, Trg MixUp: 0.6739, Src Train Acc: 100.00, Trg Train Acc: 89.37, Src Test Acc: 98.44, Trg Test Acc: 95.06, Server Test Acc: 73.21, Office Test Acc: 72.08, Conf Test Acc: 74.44
# Epoch: 097, TotalL: 7.2493, CrossE: 0.0037, CondE: 0.2493, disc: 0.0000, domain: 1.1950, Src VAT: 0.0257, Trg VAT: 0.2493, Src MixUp: 0.4651, Trg MixUp: 0.6724, Src Train Acc: 100.00, Trg Train Acc: 89.11, Src Test Acc: 96.50, Trg Test Acc: 92.63, Server Test Acc: 81.03, Office Test Acc: 70.41, Conf Test Acc: 76.00
# Epoch: 098, TotalL: 7.2334, CrossE: 0.0031, CondE: 0.2400, disc: 0.0000, domain: 1.1825, Src VAT: 0.0221, Trg VAT: 0.2400, Src MixUp: 0.4597, Trg MixUp: 0.6617, Src Train Acc: 100.00, Trg Train Acc: 88.43, Src Test Acc: 97.28, Trg Test Acc: 95.50, Server Test Acc: 75.00, Office Test Acc: 70.52, Conf Test Acc: 74.67
# Epoch: 099, TotalL: 7.1984, CrossE: 0.0030, CondE: 0.2368, disc: 0.0000, domain: 1.1776, Src VAT: 0.0220, Trg VAT: 0.2368, Src MixUp: 0.4378, Trg MixUp: 0.6573, Src Train Acc: 100.00, Trg Train Acc: 88.93, Src Test Acc: 98.83, Trg Test Acc: 95.12, Server Test Acc: 75.45, Office Test Acc: 73.30, Conf Test Acc: 74.67
# Epoch: 100, TotalL: 7.2295, CrossE: 0.0036, CondE: 0.2325, disc: 0.0000, domain: 1.1915, Src VAT: 0.0232, Trg VAT: 0.2325, Src MixUp: 0.4435, Trg MixUp: 0.6458, Src Train Acc: 100.00, Trg Train Acc: 89.39, Src Test Acc: 99.22, Trg Test Acc: 93.95, Server Test Acc: 73.44, Office Test Acc: 71.52, Conf Test Acc: 73.56
# Epoch: 101, TotalL: 7.1956, CrossE: 0.0025, CondE: 0.2231, disc: 0.0000, domain: 1.1761, Src VAT: 0.0191, Trg VAT: 0.2231, Src MixUp: 0.4430, Trg MixUp: 0.6511, Src Train Acc: 100.00, Trg Train Acc: 89.76, Src Test Acc: 99.22, Trg Test Acc: 95.58, Server Test Acc: 77.23, Office Test Acc: 75.31, Conf Test Acc: 76.00
# Epoch: 102, TotalL: 7.1810, CrossE: 0.0024, CondE: 0.2206, disc: 0.0000, domain: 1.1673, Src VAT: 0.0186, Trg VAT: 0.2206, Src MixUp: 0.4307, Trg MixUp: 0.6558, Src Train Acc: 100.00, Trg Train Acc: 89.78, Src Test Acc: 98.83, Trg Test Acc: 94.82, Server Test Acc: 73.88, Office Test Acc: 75.75, Conf Test Acc: 77.11
# Epoch: 103, TotalL: 7.1659, CrossE: 0.0024, CondE: 0.2198, disc: 0.0000, domain: 1.1608, Src VAT: 0.0190, Trg VAT: 0.2198, Src MixUp: 0.4301, Trg MixUp: 0.6440, Src Train Acc: 100.00, Trg Train Acc: 90.17, Src Test Acc: 96.89, Trg Test Acc: 93.71, Server Test Acc: 80.58, Office Test Acc: 70.19, Conf Test Acc: 76.89
# Epoch: 104, TotalL: 7.2360, CrossE: 0.0033, CondE: 0.2268, disc: 0.0000, domain: 1.2075, Src VAT: 0.0225, Trg VAT: 0.2268, Src MixUp: 0.4604, Trg MixUp: 0.6578, Src Train Acc: 100.00, Trg Train Acc: 88.78, Src Test Acc: 98.83, Trg Test Acc: 94.88, Server Test Acc: 75.67, Office Test Acc: 73.97, Conf Test Acc: 74.67
# Epoch: 105, TotalL: 7.1846, CrossE: 0.0026, CondE: 0.2199, disc: 0.0000, domain: 1.1857, Src VAT: 0.0197, Trg VAT: 0.2199, Src MixUp: 0.4328, Trg MixUp: 0.6531, Src Train Acc: 100.00, Trg Train Acc: 90.32, Src Test Acc: 98.05, Trg Test Acc: 95.23, Server Test Acc: 75.89, Office Test Acc: 69.97, Conf Test Acc: 75.56
# Epoch: 106, TotalL: 7.2176, CrossE: 0.0029, CondE: 0.2202, disc: 0.0000, domain: 1.2019, Src VAT: 0.0213, Trg VAT: 0.2202, Src MixUp: 0.4514, Trg MixUp: 0.6384, Src Train Acc: 100.00, Trg Train Acc: 90.62, Src Test Acc: 98.44, Trg Test Acc: 94.91, Server Test Acc: 80.36, Office Test Acc: 74.97, Conf Test Acc: 77.78
# Epoch: 107, TotalL: 7.1887, CrossE: 0.0027, CondE: 0.2106, disc: 0.0000, domain: 1.1898, Src VAT: 0.0200, Trg VAT: 0.2106, Src MixUp: 0.4373, Trg MixUp: 0.6250, Src Train Acc: 100.00, Trg Train Acc: 90.76, Src Test Acc: 98.83, Trg Test Acc: 94.85, Server Test Acc: 79.24, Office Test Acc: 79.31, Conf Test Acc: 76.22
# Epoch: 108, TotalL: 7.1926, CrossE: 0.0025, CondE: 0.2139, disc: 0.0000, domain: 1.1875, Src VAT: 0.0191, Trg VAT: 0.2139, Src MixUp: 0.4417, Trg MixUp: 0.6298, Src Train Acc: 100.00, Trg Train Acc: 90.91, Src Test Acc: 97.28, Trg Test Acc: 93.89, Server Test Acc: 74.11, Office Test Acc: 78.20, Conf Test Acc: 73.78
# Epoch: 109, TotalL: 7.1593, CrossE: 0.0022, CondE: 0.1979, disc: 0.0000, domain: 1.1942, Src VAT: 0.0175, Trg VAT: 0.1979, Src MixUp: 0.4153, Trg MixUp: 0.6248, Src Train Acc: 100.00, Trg Train Acc: 91.15, Src Test Acc: 98.44, Trg Test Acc: 94.68, Server Test Acc: 75.00, Office Test Acc: 77.86, Conf Test Acc: 74.00
# Epoch: 110, TotalL: 7.1649, CrossE: 0.0022, CondE: 0.2004, disc: 0.0000, domain: 1.1869, Src VAT: 0.0168, Trg VAT: 0.2004, Src MixUp: 0.4195, Trg MixUp: 0.6151, Src Train Acc: 100.00, Trg Train Acc: 90.99, Src Test Acc: 96.50, Trg Test Acc: 93.59, Server Test Acc: 75.45, Office Test Acc: 65.63, Conf Test Acc: 74.89
# Epoch: 111, TotalL: 7.1380, CrossE: 0.0020, CondE: 0.1982, disc: 0.0000, domain: 1.1818, Src VAT: 0.0156, Trg VAT: 0.1982, Src MixUp: 0.4064, Trg MixUp: 0.6161, Src Train Acc: 100.00, Trg Train Acc: 90.99, Src Test Acc: 98.83, Trg Test Acc: 94.91, Server Test Acc: 74.11, Office Test Acc: 78.42, Conf Test Acc: 73.56
# Epoch: 112, TotalL: 7.1665, CrossE: 0.0021, CondE: 0.1990, disc: 0.0000, domain: 1.1907, Src VAT: 0.0168, Trg VAT: 0.1990, Src MixUp: 0.4260, Trg MixUp: 0.6192, Src Train Acc: 100.00, Trg Train Acc: 90.82, Src Test Acc: 98.83, Trg Test Acc: 94.36, Server Test Acc: 74.33, Office Test Acc: 74.08, Conf Test Acc: 75.33
# Epoch: 113, TotalL: 7.1196, CrossE: 0.0019, CondE: 0.1884, disc: 0.0000, domain: 1.1861, Src VAT: 0.0154, Trg VAT: 0.1884, Src MixUp: 0.3860, Trg MixUp: 0.5965, Src Train Acc: 100.00, Trg Train Acc: 91.60, Src Test Acc: 98.83, Trg Test Acc: 94.18, Server Test Acc: 72.99, Office Test Acc: 72.97, Conf Test Acc: 72.22
# Epoch: 114, TotalL: 7.1734, CrossE: 0.0021, CondE: 0.1921, disc: 0.0000, domain: 1.2030, Src VAT: 0.0161, Trg VAT: 0.1921, Src MixUp: 0.4247, Trg MixUp: 0.6119, Src Train Acc: 100.00, Trg Train Acc: 91.06, Src Test Acc: 98.44, Trg Test Acc: 95.14, Server Test Acc: 81.47, Office Test Acc: 74.30, Conf Test Acc: 77.33
# Epoch: 115, TotalL: 7.1611, CrossE: 0.0022, CondE: 0.1919, disc: 0.0000, domain: 1.2009, Src VAT: 0.0167, Trg VAT: 0.1919, Src MixUp: 0.4233, Trg MixUp: 0.5997, Src Train Acc: 100.00, Trg Train Acc: 91.60, Src Test Acc: 98.05, Trg Test Acc: 94.82, Server Test Acc: 77.90, Office Test Acc: 68.97, Conf Test Acc: 78.89
# Epoch: 116, TotalL: 7.1352, CrossE: 0.0019, CondE: 0.1855, disc: 0.0000, domain: 1.1905, Src VAT: 0.0154, Trg VAT: 0.1855, Src MixUp: 0.4044, Trg MixUp: 0.5940, Src Train Acc: 100.00, Trg Train Acc: 91.80, Src Test Acc: 98.44, Trg Test Acc: 96.20, Server Test Acc: 77.46, Office Test Acc: 72.86, Conf Test Acc: 76.67
# Epoch: 117, TotalL: 7.1093, CrossE: 0.0018, CondE: 0.1805, disc: 0.0000, domain: 1.1809, Src VAT: 0.0146, Trg VAT: 0.1805, Src MixUp: 0.3974, Trg MixUp: 0.5820, Src Train Acc: 100.00, Trg Train Acc: 92.14, Src Test Acc: 98.83, Trg Test Acc: 95.93, Server Test Acc: 81.25, Office Test Acc: 79.98, Conf Test Acc: 78.44
# Epoch: 118, TotalL: 7.1202, CrossE: 0.0019, CondE: 0.1840, disc: 0.0000, domain: 1.1904, Src VAT: 0.0156, Trg VAT: 0.1840, Src MixUp: 0.4030, Trg MixUp: 0.5884, Src Train Acc: 100.00, Trg Train Acc: 92.56, Src Test Acc: 98.44, Trg Test Acc: 92.75, Server Test Acc: 73.44, Office Test Acc: 73.75, Conf Test Acc: 72.00
# Epoch: 119, TotalL: 7.1959, CrossE: 0.0027, CondE: 0.1879, disc: 0.0000, domain: 1.2333, Src VAT: 0.0191, Trg VAT: 0.1879, Src MixUp: 0.4266, Trg MixUp: 0.6017, Src Train Acc: 100.00, Trg Train Acc: 91.75, Src Test Acc: 97.28, Trg Test Acc: 92.95, Server Test Acc: 65.62, Office Test Acc: 74.86, Conf Test Acc: 68.89
# Epoch: 120, TotalL: 7.1413, CrossE: 0.0021, CondE: 0.1701, disc: 0.0000, domain: 1.2115, Src VAT: 0.0153, Trg VAT: 0.1701, Src MixUp: 0.4033, Trg MixUp: 0.5748, Src Train Acc: 100.00, Trg Train Acc: 91.97, Src Test Acc: 98.83, Trg Test Acc: 95.12, Server Test Acc: 81.47, Office Test Acc: 73.86, Conf Test Acc: 77.78
# Epoch: 121, TotalL: 7.1256, CrossE: 0.0020, CondE: 0.1751, disc: 0.0000, domain: 1.2016, Src VAT: 0.0156, Trg VAT: 0.1751, Src MixUp: 0.3987, Trg MixUp: 0.5839, Src Train Acc: 100.00, Trg Train Acc: 92.36, Src Test Acc: 98.05, Trg Test Acc: 93.77, Server Test Acc: 76.79, Office Test Acc: 72.41, Conf Test Acc: 76.67
# Epoch: 122, TotalL: 7.1382, CrossE: 0.0020, CondE: 0.1764, disc: 0.0000, domain: 1.2048, Src VAT: 0.0159, Trg VAT: 0.1764, Src MixUp: 0.4119, Trg MixUp: 0.5827, Src Train Acc: 100.00, Trg Train Acc: 92.19, Src Test Acc: 99.22, Trg Test Acc: 96.23, Server Test Acc: 80.13, Office Test Acc: 80.31, Conf Test Acc: 78.22
# Epoch: 123, TotalL: 7.1215, CrossE: 0.0019, CondE: 0.1675, disc: 0.0000, domain: 1.2099, Src VAT: 0.0147, Trg VAT: 0.1675, Src MixUp: 0.3943, Trg MixUp: 0.5872, Src Train Acc: 100.00, Trg Train Acc: 92.43, Src Test Acc: 98.83, Trg Test Acc: 95.67, Server Test Acc: 75.22, Office Test Acc: 79.87, Conf Test Acc: 75.78
# Epoch: 124, TotalL: 7.1458, CrossE: 0.0021, CondE: 0.1735, disc: 0.0000, domain: 1.2168, Src VAT: 0.0152, Trg VAT: 0.1735, Src MixUp: 0.4051, Trg MixUp: 0.5791, Src Train Acc: 100.00, Trg Train Acc: 92.06, Src Test Acc: 97.67, Trg Test Acc: 92.07, Server Test Acc: 72.77, Office Test Acc: 78.75, Conf Test Acc: 74.44
# Epoch: 125, TotalL: 7.1027, CrossE: 0.0015, CondE: 0.1589, disc: 0.0000, domain: 1.1970, Src VAT: 0.0123, Trg VAT: 0.1589, Src MixUp: 0.3905, Trg MixUp: 0.5680, Src Train Acc: 100.00, Trg Train Acc: 92.51, Src Test Acc: 98.44, Trg Test Acc: 96.11, Server Test Acc: 78.79, Office Test Acc: 77.09, Conf Test Acc: 80.00
# Epoch: 126, TotalL: 7.0890, CrossE: 0.0016, CondE: 0.1588, disc: 0.0000, domain: 1.2018, Src VAT: 0.0131, Trg VAT: 0.1588, Src MixUp: 0.3738, Trg MixUp: 0.5690, Src Train Acc: 100.00, Trg Train Acc: 92.64, Src Test Acc: 99.22, Trg Test Acc: 96.23, Server Test Acc: 77.46, Office Test Acc: 76.86, Conf Test Acc: 79.11
# Epoch: 127, TotalL: 7.1099, CrossE: 0.0016, CondE: 0.1596, disc: 0.0000, domain: 1.2041, Src VAT: 0.0129, Trg VAT: 0.1596, Src MixUp: 0.3946, Trg MixUp: 0.5785, Src Train Acc: 100.00, Trg Train Acc: 92.69, Src Test Acc: 97.28, Trg Test Acc: 95.73, Server Test Acc: 79.91, Office Test Acc: 73.75, Conf Test Acc: 79.33
# Epoch: 128, TotalL: 7.0825, CrossE: 0.0014, CondE: 0.1516, disc: 0.0000, domain: 1.2007, Src VAT: 0.0122, Trg VAT: 0.1516, Src MixUp: 0.3780, Trg MixUp: 0.5574, Src Train Acc: 100.00, Trg Train Acc: 93.36, Src Test Acc: 98.44, Trg Test Acc: 96.52, Server Test Acc: 78.79, Office Test Acc: 81.54, Conf Test Acc: 77.78
# Epoch: 129, TotalL: 7.1022, CrossE: 0.0016, CondE: 0.1552, disc: 0.0000, domain: 1.2091, Src VAT: 0.0132, Trg VAT: 0.1552, Src MixUp: 0.3937, Trg MixUp: 0.5539, Src Train Acc: 100.00, Trg Train Acc: 93.14, Src Test Acc: 99.22, Trg Test Acc: 96.17, Server Test Acc: 81.47, Office Test Acc: 78.20, Conf Test Acc: 78.67
# Epoch: 130, TotalL: 7.3519, CrossE: 0.0397, CondE: 0.1768, disc: 0.0000, domain: 1.2872, Src VAT: 0.0338, Trg VAT: 0.1768, Src MixUp: 0.4276, Trg MixUp: 0.5979, Src Train Acc: 98.83, Trg Train Acc: 91.28, Src Test Acc: 98.05, Trg Test Acc: 95.17, Server Test Acc: 75.45, Office Test Acc: 83.31, Conf Test Acc: 75.78
# Epoch: 131, TotalL: 7.1126, CrossE: 0.0016, CondE: 0.1483, disc: 0.0000, domain: 1.2090, Src VAT: 0.0124, Trg VAT: 0.1483, Src MixUp: 0.3900, Trg MixUp: 0.5551, Src Train Acc: 100.00, Trg Train Acc: 93.42, Src Test Acc: 98.44, Trg Test Acc: 96.84, Server Test Acc: 79.91, Office Test Acc: 80.53, Conf Test Acc: 79.33
# Epoch: 132, TotalL: 7.0642, CrossE: 0.0014, CondE: 0.1432, disc: 0.0000, domain: 1.1917, Src VAT: 0.0115, Trg VAT: 0.1432, Src MixUp: 0.3680, Trg MixUp: 0.5375, Src Train Acc: 100.00, Trg Train Acc: 93.86, Src Test Acc: 98.44, Trg Test Acc: 96.46, Server Test Acc: 78.12, Office Test Acc: 79.20, Conf Test Acc: 75.11
# Epoch: 133, TotalL: 7.0800, CrossE: 0.0013, CondE: 0.1412, disc: 0.0000, domain: 1.1918, Src VAT: 0.0114, Trg VAT: 0.1412, Src MixUp: 0.3870, Trg MixUp: 0.5409, Src Train Acc: 100.00, Trg Train Acc: 93.64, Src Test Acc: 98.44, Trg Test Acc: 96.72, Server Test Acc: 80.58, Office Test Acc: 74.53, Conf Test Acc: 79.11
# Epoch: 134, TotalL: 7.0672, CrossE: 0.0013, CondE: 0.1397, disc: 0.0000, domain: 1.1932, Src VAT: 0.0114, Trg VAT: 0.1397, Src MixUp: 0.3784, Trg MixUp: 0.5460, Src Train Acc: 100.00, Trg Train Acc: 93.55, Src Test Acc: 99.22, Trg Test Acc: 96.40, Server Test Acc: 79.24, Office Test Acc: 82.42, Conf Test Acc: 76.22
# Epoch: 135, TotalL: 7.0646, CrossE: 0.0014, CondE: 0.1398, disc: 0.0000, domain: 1.2005, Src VAT: 0.0119, Trg VAT: 0.1398, Src MixUp: 0.3714, Trg MixUp: 0.5452, Src Train Acc: 100.00, Trg Train Acc: 93.42, Src Test Acc: 98.83, Trg Test Acc: 96.69, Server Test Acc: 80.36, Office Test Acc: 79.64, Conf Test Acc: 78.00
# Epoch: 136, TotalL: 7.0547, CrossE: 0.0013, CondE: 0.1370, disc: 0.0000, domain: 1.2028, Src VAT: 0.0112, Trg VAT: 0.1370, Src MixUp: 0.3620, Trg MixUp: 0.5490, Src Train Acc: 100.00, Trg Train Acc: 93.73, Src Test Acc: 97.28, Trg Test Acc: 94.56, Server Test Acc: 77.46, Office Test Acc: 81.76, Conf Test Acc: 74.89
# Epoch: 137, TotalL: 7.0836, CrossE: 0.0015, CondE: 0.1391, disc: 0.0000, domain: 1.2154, Src VAT: 0.0124, Trg VAT: 0.1391, Src MixUp: 0.3788, Trg MixUp: 0.5454, Src Train Acc: 100.00, Trg Train Acc: 93.62, Src Test Acc: 98.44, Trg Test Acc: 96.40, Server Test Acc: 78.12, Office Test Acc: 77.75, Conf Test Acc: 77.11
# Epoch: 138, TotalL: 7.0872, CrossE: 0.0014, CondE: 0.1389, disc: 0.0000, domain: 1.2231, Src VAT: 0.0116, Trg VAT: 0.1389, Src MixUp: 0.3790, Trg MixUp: 0.5435, Src Train Acc: 100.00, Trg Train Acc: 93.79, Src Test Acc: 98.83, Trg Test Acc: 94.82, Server Test Acc: 79.02, Office Test Acc: 73.86, Conf Test Acc: 75.78
# Epoch: 139, TotalL: 7.0983, CrossE: 0.0014, CondE: 0.1382, disc: 0.0000, domain: 1.2172, Src VAT: 0.0115, Trg VAT: 0.1382, Src MixUp: 0.3881, Trg MixUp: 0.5461, Src Train Acc: 100.00, Trg Train Acc: 93.75, Src Test Acc: 98.05, Trg Test Acc: 96.55, Server Test Acc: 80.80, Office Test Acc: 72.53, Conf Test Acc: 79.11
# Epoch: 140, TotalL: 7.0671, CrossE: 0.0014, CondE: 0.1327, disc: 0.0000, domain: 1.2144, Src VAT: 0.0113, Trg VAT: 0.1327, Src MixUp: 0.3643, Trg MixUp: 0.5374, Src Train Acc: 100.00, Trg Train Acc: 93.86, Src Test Acc: 98.44, Trg Test Acc: 96.43, Server Test Acc: 81.03, Office Test Acc: 80.65, Conf Test Acc: 78.89
# Epoch: 141, TotalL: 7.2639, CrossE: 0.0283, CondE: 0.1517, disc: 0.0000, domain: 1.2790, Src VAT: 0.0245, Trg VAT: 0.1517, Src MixUp: 0.4010, Trg MixUp: 0.5629, Src Train Acc: 99.52, Trg Train Acc: 92.73, Src Test Acc: 98.83, Trg Test Acc: 96.64, Server Test Acc: 82.14, Office Test Acc: 82.76, Conf Test Acc: 80.67
# Epoch: 142, TotalL: 7.0636, CrossE: 0.0011, CondE: 0.1289, disc: 0.0000, domain: 1.2140, Src VAT: 0.0092, Trg VAT: 0.1289, Src MixUp: 0.3556, Trg MixUp: 0.5359, Src Train Acc: 100.00, Trg Train Acc: 93.68, Src Test Acc: 98.44, Trg Test Acc: 96.67, Server Test Acc: 78.79, Office Test Acc: 76.42, Conf Test Acc: 77.78
# Epoch: 143, TotalL: 7.0392, CrossE: 0.0011, CondE: 0.1242, disc: 0.0000, domain: 1.1957, Src VAT: 0.0097, Trg VAT: 0.1242, Src MixUp: 0.3500, Trg MixUp: 0.5249, Src Train Acc: 100.00, Trg Train Acc: 93.88, Src Test Acc: 98.83, Trg Test Acc: 96.67, Server Test Acc: 83.04, Office Test Acc: 84.87, Conf Test Acc: 80.67
# Epoch: 144, TotalL: 7.0410, CrossE: 0.0011, CondE: 0.1241, disc: 0.0000, domain: 1.2034, Src VAT: 0.0099, Trg VAT: 0.1241, Src MixUp: 0.3567, Trg MixUp: 0.5196, Src Train Acc: 100.00, Trg Train Acc: 94.08, Src Test Acc: 98.83, Trg Test Acc: 96.81, Server Test Acc: 83.48, Office Test Acc: 78.64, Conf Test Acc: 80.22
# Epoch: 145, TotalL: 7.0395, CrossE: 0.0011, CondE: 0.1225, disc: 0.0000, domain: 1.2101, Src VAT: 0.0099, Trg VAT: 0.1225, Src MixUp: 0.3548, Trg MixUp: 0.5176, Src Train Acc: 100.00, Trg Train Acc: 94.03, Src Test Acc: 98.83, Trg Test Acc: 97.10, Server Test Acc: 80.80, Office Test Acc: 81.31, Conf Test Acc: 78.22
# Epoch: 146, TotalL: 7.0417, CrossE: 0.0012, CondE: 0.1188, disc: 0.0000, domain: 1.2082, Src VAT: 0.0103, Trg VAT: 0.1188, Src MixUp: 0.3589, Trg MixUp: 0.5176, Src Train Acc: 100.00, Trg Train Acc: 94.21, Src Test Acc: 98.44, Trg Test Acc: 94.30, Server Test Acc: 83.48, Office Test Acc: 80.65, Conf Test Acc: 82.22
# Epoch: 147, TotalL: 7.0643, CrossE: 0.0014, CondE: 0.1248, disc: 0.0000, domain: 1.2273, Src VAT: 0.0112, Trg VAT: 0.1248, Src MixUp: 0.3645, Trg MixUp: 0.5246, Src Train Acc: 100.00, Trg Train Acc: 94.16, Src Test Acc: 98.83, Trg Test Acc: 97.22, Server Test Acc: 83.71, Office Test Acc: 83.09, Conf Test Acc: 81.33
# Epoch: 148, TotalL: 7.0635, CrossE: 0.0014, CondE: 0.1270, disc: 0.0000, domain: 1.2345, Src VAT: 0.0111, Trg VAT: 0.1270, Src MixUp: 0.3629, Trg MixUp: 0.5346, Src Train Acc: 100.00, Trg Train Acc: 94.23, Src Test Acc: 98.05, Trg Test Acc: 97.22, Server Test Acc: 82.81, Office Test Acc: 77.86, Conf Test Acc: 80.67
# Epoch: 149, TotalL: 7.0874, CrossE: 0.0014, CondE: 0.1290, disc: 0.0000, domain: 1.2354, Src VAT: 0.0116, Trg VAT: 0.1290, Src MixUp: 0.3806, Trg MixUp: 0.5298, Src Train Acc: 100.00, Trg Train Acc: 94.03, Src Test Acc: 99.22, Trg Test Acc: 96.69, Server Test Acc: 81.92, Office Test Acc: 79.87, Conf Test Acc: 79.11
# Epoch: 150, TotalL: 7.0738, CrossE: 0.0013, CondE: 0.1201, disc: 0.0000, domain: 1.2281, Src VAT: 0.0105, Trg VAT: 0.1201, Src MixUp: 0.3736, Trg MixUp: 0.5066, Src Train Acc: 100.00, Trg Train Acc: 94.29, Src Test Acc: 99.22, Trg Test Acc: 97.13, Server Test Acc: 85.04, Office Test Acc: 80.76, Conf Test Acc: 81.56
# Epoch: 151, TotalL: 7.0643, CrossE: 0.0013, CondE: 0.1205, disc: 0.0000, domain: 1.2293, Src VAT: 0.0107, Trg VAT: 0.1205, Src MixUp: 0.3663, Trg MixUp: 0.5010, Src Train Acc: 100.00, Trg Train Acc: 94.55, Src Test Acc: 98.83, Trg Test Acc: 96.49, Server Test Acc: 79.69, Office Test Acc: 75.42, Conf Test Acc: 75.78
# Epoch: 152, TotalL: 7.0794, CrossE: 0.0011, CondE: 0.1169, disc: 0.0000, domain: 1.2450, Src VAT: 0.0095, Trg VAT: 0.1169, Src MixUp: 0.3687, Trg MixUp: 0.5128, Src Train Acc: 100.00, Trg Train Acc: 94.36, Src Test Acc: 98.05, Trg Test Acc: 97.16, Server Test Acc: 81.03, Office Test Acc: 79.53, Conf Test Acc: 79.56
# Epoch: 153, TotalL: 7.0780, CrossE: 0.0011, CondE: 0.1172, disc: 0.0000, domain: 1.2312, Src VAT: 0.0096, Trg VAT: 0.1172, Src MixUp: 0.3800, Trg MixUp: 0.5083, Src Train Acc: 100.00, Trg Train Acc: 94.25, Src Test Acc: 98.83, Trg Test Acc: 95.82, Server Test Acc: 79.69, Office Test Acc: 86.87, Conf Test Acc: 80.00
# Epoch: 154, TotalL: 7.0499, CrossE: 0.0011, CondE: 0.1137, disc: 0.0000, domain: 1.2256, Src VAT: 0.0097, Trg VAT: 0.1137, Src MixUp: 0.3610, Trg MixUp: 0.5030, Src Train Acc: 100.00, Trg Train Acc: 94.51, Src Test Acc: 98.05, Trg Test Acc: 96.37, Server Test Acc: 81.25, Office Test Acc: 82.54, Conf Test Acc: 79.11
# Epoch: 155, TotalL: 7.0545, CrossE: 0.0014, CondE: 0.1208, disc: 0.0000, domain: 1.2323, Src VAT: 0.0112, Trg VAT: 0.1208, Src MixUp: 0.3562, Trg MixUp: 0.5199, Src Train Acc: 100.00, Trg Train Acc: 94.16, Src Test Acc: 98.44, Trg Test Acc: 96.75, Server Test Acc: 81.47, Office Test Acc: 79.09, Conf Test Acc: 81.33
# Epoch: 156, TotalL: 7.0610, CrossE: 0.0012, CondE: 0.1141, disc: 0.0000, domain: 1.2437, Src VAT: 0.0101, Trg VAT: 0.1141, Src MixUp: 0.3564, Trg MixUp: 0.5054, Src Train Acc: 100.00, Trg Train Acc: 94.14, Src Test Acc: 98.44, Trg Test Acc: 96.90, Server Test Acc: 83.04, Office Test Acc: 82.20, Conf Test Acc: 79.33
# Epoch: 157, TotalL: 7.0545, CrossE: 0.0012, CondE: 0.1132, disc: 0.0000, domain: 1.2318, Src VAT: 0.0100, Trg VAT: 0.1132, Src MixUp: 0.3607, Trg MixUp: 0.5078, Src Train Acc: 100.00, Trg Train Acc: 94.38, Src Test Acc: 99.61, Trg Test Acc: 96.81, Server Test Acc: 78.35, Office Test Acc: 85.09, Conf Test Acc: 76.89
# Epoch: 158, TotalL: 7.0256, CrossE: 0.0011, CondE: 0.1116, disc: 0.0000, domain: 1.2286, Src VAT: 0.0096, Trg VAT: 0.1116, Src MixUp: 0.3360, Trg MixUp: 0.4978, Src Train Acc: 100.00, Trg Train Acc: 94.40, Src Test Acc: 99.22, Trg Test Acc: 97.13, Server Test Acc: 84.15, Office Test Acc: 84.43, Conf Test Acc: 82.22
# Epoch: 159, TotalL: 7.0681, CrossE: 0.0012, CondE: 0.1180, disc: 0.0000, domain: 1.2362, Src VAT: 0.0100, Trg VAT: 0.1180, Src MixUp: 0.3696, Trg MixUp: 0.5035, Src Train Acc: 100.00, Trg Train Acc: 94.38, Src Test Acc: 98.44, Trg Test Acc: 96.81, Server Test Acc: 80.80, Office Test Acc: 75.75, Conf Test Acc: 80.44
# Epoch: 160, TotalL: 7.0581, CrossE: 0.0012, CondE: 0.1129, disc: 0.0000, domain: 1.2281, Src VAT: 0.0101, Trg VAT: 0.1129, Src MixUp: 0.3693, Trg MixUp: 0.5007, Src Train Acc: 100.00, Trg Train Acc: 94.42, Src Test Acc: 99.22, Trg Test Acc: 97.28, Server Test Acc: 85.04, Office Test Acc: 79.42, Conf Test Acc: 82.22
# Epoch: 161, TotalL: 7.0575, CrossE: 0.0014, CondE: 0.1190, disc: 0.0000, domain: 1.2330, Src VAT: 0.0112, Trg VAT: 0.1190, Src MixUp: 0.3590, Trg MixUp: 0.5218, Src Train Acc: 100.00, Trg Train Acc: 94.49, Src Test Acc: 99.22, Trg Test Acc: 97.63, Server Test Acc: 83.26, Office Test Acc: 80.87, Conf Test Acc: 82.44
# Epoch: 162, TotalL: 7.0516, CrossE: 0.0011, CondE: 0.1084, disc: 0.0000, domain: 1.2384, Src VAT: 0.0096, Trg VAT: 0.1084, Src MixUp: 0.3585, Trg MixUp: 0.4920, Src Train Acc: 100.00, Trg Train Acc: 94.31, Src Test Acc: 99.22, Trg Test Acc: 97.05, Server Test Acc: 82.81, Office Test Acc: 78.09, Conf Test Acc: 80.44
# Epoch: 163, TotalL: 7.0360, CrossE: 0.0011, CondE: 0.1083, disc: 0.0000, domain: 1.2406, Src VAT: 0.0094, Trg VAT: 0.1083, Src MixUp: 0.3477, Trg MixUp: 0.4858, Src Train Acc: 100.00, Trg Train Acc: 94.55, Src Test Acc: 98.83, Trg Test Acc: 97.46, Server Test Acc: 83.48, Office Test Acc: 83.65, Conf Test Acc: 81.56
# Epoch: 164, TotalL: 7.0331, CrossE: 0.0011, CondE: 0.1056, disc: 0.0000, domain: 1.2417, Src VAT: 0.0095, Trg VAT: 0.1056, Src MixUp: 0.3421, Trg MixUp: 0.4835, Src Train Acc: 100.00, Trg Train Acc: 94.84, Src Test Acc: 98.83, Trg Test Acc: 97.28, Server Test Acc: 85.71, Office Test Acc: 79.20, Conf Test Acc: 82.22
# Epoch: 165, TotalL: 7.0463, CrossE: 0.0011, CondE: 0.1059, disc: 0.0000, domain: 1.2466, Src VAT: 0.0093, Trg VAT: 0.1059, Src MixUp: 0.3497, Trg MixUp: 0.4959, Src Train Acc: 100.00, Trg Train Acc: 94.66, Src Test Acc: 97.67, Trg Test Acc: 94.56, Server Test Acc: 74.11, Office Test Acc: 80.20, Conf Test Acc: 73.78
# Epoch: 166, TotalL: 7.0396, CrossE: 0.0010, CondE: 0.1042, disc: 0.0000, domain: 1.2357, Src VAT: 0.0089, Trg VAT: 0.1042, Src MixUp: 0.3540, Trg MixUp: 0.4845, Src Train Acc: 100.00, Trg Train Acc: 94.88, Src Test Acc: 99.61, Trg Test Acc: 97.46, Server Test Acc: 86.38, Office Test Acc: 81.20, Conf Test Acc: 82.44
# Epoch: 167, TotalL: 7.0360, CrossE: 0.0012, CondE: 0.1047, disc: 0.0000, domain: 1.2459, Src VAT: 0.0094, Trg VAT: 0.1047, Src MixUp: 0.3389, Trg MixUp: 0.4868, Src Train Acc: 100.00, Trg Train Acc: 94.99, Src Test Acc: 98.83, Trg Test Acc: 97.22, Server Test Acc: 84.15, Office Test Acc: 83.09, Conf Test Acc: 80.67
# Epoch: 168, TotalL: 7.0296, CrossE: 0.0010, CondE: 0.1031, disc: 0.0000, domain: 1.2357, Src VAT: 0.0087, Trg VAT: 0.1031, Src MixUp: 0.3473, Trg MixUp: 0.4798, Src Train Acc: 100.00, Trg Train Acc: 94.62, Src Test Acc: 98.83, Trg Test Acc: 97.34, Server Test Acc: 85.27, Office Test Acc: 84.65, Conf Test Acc: 82.67
# Epoch: 169, TotalL: 7.0659, CrossE: 0.0011, CondE: 0.1050, disc: 0.0000, domain: 1.2569, Src VAT: 0.0095, Trg VAT: 0.1050, Src MixUp: 0.3604, Trg MixUp: 0.4858, Src Train Acc: 100.00, Trg Train Acc: 94.70, Src Test Acc: 98.83, Trg Test Acc: 95.61, Server Test Acc: 77.23, Office Test Acc: 80.42, Conf Test Acc: 76.67
# Epoch: 170, TotalL: 7.0392, CrossE: 0.0010, CondE: 0.0951, disc: 0.0000, domain: 1.2514, Src VAT: 0.0083, Trg VAT: 0.0951, Src MixUp: 0.3418, Trg MixUp: 0.4745, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 99.22, Trg Test Acc: 97.63, Server Test Acc: 85.71, Office Test Acc: 81.87, Conf Test Acc: 80.67
# Epoch: 171, TotalL: 7.0286, CrossE: 0.0009, CondE: 0.0966, disc: 0.0000, domain: 1.2489, Src VAT: 0.0081, Trg VAT: 0.0966, Src MixUp: 0.3371, Trg MixUp: 0.4779, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 99.22, Trg Test Acc: 97.22, Server Test Acc: 84.82, Office Test Acc: 81.31, Conf Test Acc: 81.33
# Epoch: 172, TotalL: 7.0505, CrossE: 0.0010, CondE: 0.1026, disc: 0.0000, domain: 1.2495, Src VAT: 0.0086, Trg VAT: 0.1026, Src MixUp: 0.3575, Trg MixUp: 0.4835, Src Train Acc: 100.00, Trg Train Acc: 94.73, Src Test Acc: 98.44, Trg Test Acc: 96.26, Server Test Acc: 76.56, Office Test Acc: 77.20, Conf Test Acc: 78.00
# Epoch: 173, TotalL: 7.0146, CrossE: 0.0009, CondE: 0.0927, disc: 0.0000, domain: 1.2325, Src VAT: 0.0082, Trg VAT: 0.0927, Src MixUp: 0.3373, Trg MixUp: 0.4704, Src Train Acc: 100.00, Trg Train Acc: 94.86, Src Test Acc: 98.83, Trg Test Acc: 97.16, Server Test Acc: 82.81, Office Test Acc: 83.98, Conf Test Acc: 79.33
# Epoch: 174, TotalL: 7.0018, CrossE: 0.0009, CondE: 0.0905, disc: 0.0000, domain: 1.2336, Src VAT: 0.0077, Trg VAT: 0.0905, Src MixUp: 0.3285, Trg MixUp: 0.4714, Src Train Acc: 100.00, Trg Train Acc: 94.92, Src Test Acc: 99.61, Trg Test Acc: 97.81, Server Test Acc: 83.48, Office Test Acc: 79.64, Conf Test Acc: 80.44
# Epoch: 175, TotalL: 7.0028, CrossE: 0.0009, CondE: 0.0917, disc: 0.0000, domain: 1.2386, Src VAT: 0.0080, Trg VAT: 0.0917, Src MixUp: 0.3288, Trg MixUp: 0.4542, Src Train Acc: 100.00, Trg Train Acc: 94.84, Src Test Acc: 98.44, Trg Test Acc: 96.78, Server Test Acc: 82.59, Office Test Acc: 85.87, Conf Test Acc: 78.22
# Epoch: 176, TotalL: 7.0117, CrossE: 0.0009, CondE: 0.0896, disc: 0.0000, domain: 1.2402, Src VAT: 0.0083, Trg VAT: 0.0896, Src MixUp: 0.3334, Trg MixUp: 0.4580, Src Train Acc: 100.00, Trg Train Acc: 94.79, Src Test Acc: 98.44, Trg Test Acc: 97.28, Server Test Acc: 84.15, Office Test Acc: 79.42, Conf Test Acc: 79.78
# Epoch: 177, TotalL: 7.0323, CrossE: 0.0010, CondE: 0.0931, disc: 0.0000, domain: 1.2542, Src VAT: 0.0082, Trg VAT: 0.0931, Src MixUp: 0.3427, Trg MixUp: 0.4724, Src Train Acc: 100.00, Trg Train Acc: 94.84, Src Test Acc: 100.00, Trg Test Acc: 96.67, Server Test Acc: 84.15, Office Test Acc: 82.65, Conf Test Acc: 80.00
# Epoch: 178, TotalL: 7.0122, CrossE: 0.0009, CondE: 0.0898, disc: 0.0000, domain: 1.2492, Src VAT: 0.0077, Trg VAT: 0.0898, Src MixUp: 0.3312, Trg MixUp: 0.4680, Src Train Acc: 100.00, Trg Train Acc: 94.77, Src Test Acc: 99.22, Trg Test Acc: 97.19, Server Test Acc: 85.94, Office Test Acc: 80.76, Conf Test Acc: 82.22
# Epoch: 179, TotalL: 7.0115, CrossE: 0.0010, CondE: 0.0901, disc: 0.0000, domain: 1.2510, Src VAT: 0.0084, Trg VAT: 0.0901, Src MixUp: 0.3314, Trg MixUp: 0.4690, Src Train Acc: 100.00, Trg Train Acc: 94.79, Src Test Acc: 98.44, Trg Test Acc: 95.20, Server Test Acc: 82.14, Office Test Acc: 73.75, Conf Test Acc: 76.00
# Epoch: 180, TotalL: 7.0749, CrossE: 0.0013, CondE: 0.1012, disc: 0.0000, domain: 1.2784, Src VAT: 0.0102, Trg VAT: 0.1012, Src MixUp: 0.3591, Trg MixUp: 0.4834, Src Train Acc: 100.00, Trg Train Acc: 94.73, Src Test Acc: 99.22, Trg Test Acc: 97.25, Server Test Acc: 81.47, Office Test Acc: 83.76, Conf Test Acc: 81.11
# Epoch: 181, TotalL: 7.0284, CrossE: 0.0009, CondE: 0.0892, disc: 0.0000, domain: 1.2586, Src VAT: 0.0079, Trg VAT: 0.0892, Src MixUp: 0.3353, Trg MixUp: 0.4695, Src Train Acc: 100.00, Trg Train Acc: 95.03, Src Test Acc: 99.22, Trg Test Acc: 96.40, Server Test Acc: 81.47, Office Test Acc: 75.19, Conf Test Acc: 76.89
# Epoch: 182, TotalL: 6.9796, CrossE: 0.0008, CondE: 0.0839, disc: 0.0000, domain: 1.2309, Src VAT: 0.0073, Trg VAT: 0.0839, Src MixUp: 0.3129, Trg MixUp: 0.4488, Src Train Acc: 100.00, Trg Train Acc: 94.97, Src Test Acc: 99.22, Trg Test Acc: 97.72, Server Test Acc: 83.71, Office Test Acc: 82.31, Conf Test Acc: 79.11
# Epoch: 183, TotalL: 7.0211, CrossE: 0.0010, CondE: 0.0911, disc: 0.0000, domain: 1.2512, Src VAT: 0.0083, Trg VAT: 0.0911, Src MixUp: 0.3377, Trg MixUp: 0.4704, Src Train Acc: 100.00, Trg Train Acc: 95.25, Src Test Acc: 99.22, Trg Test Acc: 98.04, Server Test Acc: 87.72, Office Test Acc: 82.09, Conf Test Acc: 82.00
# Epoch: 184, TotalL: 7.0001, CrossE: 0.0009, CondE: 0.0858, disc: 0.0000, domain: 1.2529, Src VAT: 0.0079, Trg VAT: 0.0858, Src MixUp: 0.3217, Trg MixUp: 0.4591, Src Train Acc: 100.00, Trg Train Acc: 95.20, Src Test Acc: 98.05, Trg Test Acc: 97.75, Server Test Acc: 84.60, Office Test Acc: 83.98, Conf Test Acc: 81.33
# Epoch: 185, TotalL: 7.0241, CrossE: 0.0010, CondE: 0.0856, disc: 0.0000, domain: 1.2563, Src VAT: 0.0081, Trg VAT: 0.0856, Src MixUp: 0.3405, Trg MixUp: 0.4507, Src Train Acc: 100.00, Trg Train Acc: 95.03, Src Test Acc: 97.28, Trg Test Acc: 95.79, Server Test Acc: 77.46, Office Test Acc: 80.87, Conf Test Acc: 75.11
# Epoch: 186, TotalL: 7.0375, CrossE: 0.0010, CondE: 0.0890, disc: 0.0000, domain: 1.2712, Src VAT: 0.0083, Trg VAT: 0.0890, Src MixUp: 0.3374, Trg MixUp: 0.4579, Src Train Acc: 100.00, Trg Train Acc: 94.99, Src Test Acc: 98.83, Trg Test Acc: 96.78, Server Test Acc: 83.71, Office Test Acc: 76.64, Conf Test Acc: 79.11
# Epoch: 187, TotalL: 6.9826, CrossE: 0.0008, CondE: 0.0785, disc: 0.0000, domain: 1.2385, Src VAT: 0.0070, Trg VAT: 0.0785, Src MixUp: 0.3159, Trg MixUp: 0.4424, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 99.61, Trg Test Acc: 97.72, Server Test Acc: 86.83, Office Test Acc: 80.09, Conf Test Acc: 82.44
# Epoch: 188, TotalL: 7.0283, CrossE: 0.0010, CondE: 0.0856, disc: 0.0000, domain: 1.2594, Src VAT: 0.0084, Trg VAT: 0.0856, Src MixUp: 0.3474, Trg MixUp: 0.4583, Src Train Acc: 100.00, Trg Train Acc: 95.01, Src Test Acc: 99.22, Trg Test Acc: 97.63, Server Test Acc: 83.04, Office Test Acc: 82.54, Conf Test Acc: 81.11
# Epoch: 189, TotalL: 7.0164, CrossE: 0.0009, CondE: 0.0859, disc: 0.0000, domain: 1.2512, Src VAT: 0.0080, Trg VAT: 0.0859, Src MixUp: 0.3360, Trg MixUp: 0.4550, Src Train Acc: 100.00, Trg Train Acc: 95.10, Src Test Acc: 98.83, Trg Test Acc: 97.51, Server Test Acc: 82.37, Office Test Acc: 81.54, Conf Test Acc: 80.44
# Epoch: 190, TotalL: 6.9912, CrossE: 0.0008, CondE: 0.0789, disc: 0.0000, domain: 1.2411, Src VAT: 0.0068, Trg VAT: 0.0789, Src MixUp: 0.3220, Trg MixUp: 0.4375, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 99.22, Trg Test Acc: 97.31, Server Test Acc: 83.71, Office Test Acc: 82.09, Conf Test Acc: 81.33
# Epoch: 191, TotalL: 7.0150, CrossE: 0.0009, CondE: 0.0825, disc: 0.0000, domain: 1.2569, Src VAT: 0.0075, Trg VAT: 0.0825, Src MixUp: 0.3341, Trg MixUp: 0.4504, Src Train Acc: 100.00, Trg Train Acc: 95.23, Src Test Acc: 98.83, Trg Test Acc: 96.52, Server Test Acc: 74.78, Office Test Acc: 77.20, Conf Test Acc: 74.89
# Epoch: 192, TotalL: 7.0213, CrossE: 0.0008, CondE: 0.0831, disc: 0.0000, domain: 1.2539, Src VAT: 0.0071, Trg VAT: 0.0831, Src MixUp: 0.3398, Trg MixUp: 0.4552, Src Train Acc: 100.00, Trg Train Acc: 95.05, Src Test Acc: 99.61, Trg Test Acc: 97.78, Server Test Acc: 84.38, Office Test Acc: 86.54, Conf Test Acc: 82.44
# Epoch: 193, TotalL: 6.9880, CrossE: 0.0008, CondE: 0.0781, disc: 0.0000, domain: 1.2455, Src VAT: 0.0069, Trg VAT: 0.0781, Src MixUp: 0.3212, Trg MixUp: 0.4465, Src Train Acc: 100.00, Trg Train Acc: 95.29, Src Test Acc: 99.22, Trg Test Acc: 97.72, Server Test Acc: 85.71, Office Test Acc: 81.20, Conf Test Acc: 80.67
# Epoch: 194, TotalL: 7.0116, CrossE: 0.0009, CondE: 0.0809, disc: 0.0000, domain: 1.2608, Src VAT: 0.0076, Trg VAT: 0.0809, Src MixUp: 0.3327, Trg MixUp: 0.4429, Src Train Acc: 100.00, Trg Train Acc: 95.14, Src Test Acc: 98.44, Trg Test Acc: 97.54, Server Test Acc: 80.80, Office Test Acc: 82.54, Conf Test Acc: 78.22
# Epoch: 195, TotalL: 7.0098, CrossE: 0.0009, CondE: 0.0815, disc: 0.0000, domain: 1.2637, Src VAT: 0.0077, Trg VAT: 0.0815, Src MixUp: 0.3282, Trg MixUp: 0.4484, Src Train Acc: 100.00, Trg Train Acc: 95.18, Src Test Acc: 98.44, Trg Test Acc: 97.46, Server Test Acc: 84.15, Office Test Acc: 80.42, Conf Test Acc: 82.00
# Epoch: 196, TotalL: 6.9831, CrossE: 0.0008, CondE: 0.0766, disc: 0.0000, domain: 1.2462, Src VAT: 0.0070, Trg VAT: 0.0766, Src MixUp: 0.3166, Trg MixUp: 0.4377, Src Train Acc: 100.00, Trg Train Acc: 95.18, Src Test Acc: 99.22, Trg Test Acc: 98.04, Server Test Acc: 85.04, Office Test Acc: 85.76, Conf Test Acc: 82.67
# Epoch: 197, TotalL: 7.0015, CrossE: 0.0008, CondE: 0.0772, disc: 0.0000, domain: 1.2553, Src VAT: 0.0071, Trg VAT: 0.0772, Src MixUp: 0.3304, Trg MixUp: 0.4424, Src Train Acc: 100.00, Trg Train Acc: 95.33, Src Test Acc: 97.67, Trg Test Acc: 97.08, Server Test Acc: 83.04, Office Test Acc: 85.32, Conf Test Acc: 81.33
# Epoch: 198, TotalL: 6.9975, CrossE: 0.0008, CondE: 0.0769, disc: 0.0000, domain: 1.2566, Src VAT: 0.0069, Trg VAT: 0.0769, Src MixUp: 0.3209, Trg MixUp: 0.4359, Src Train Acc: 100.00, Trg Train Acc: 95.20, Src Test Acc: 98.83, Trg Test Acc: 97.37, Server Test Acc: 88.62, Office Test Acc: 83.09, Conf Test Acc: 83.33
